# %%
import spacy
from collections import Counter
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\82107\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nlp = spacy.load("en_core_web_sm")

# %%
file = open("data/doc_data.txt", 'r')

lists = file.readlines()

file.close()

lists
# Out:
# ['FORUM: World Health Organization\n',
#  'QUESTION OF: Addressing the Mental Health of Refugees and Migrants\n',
#  'MAIN-SUBMITTER: Malawi\n',
#  'CO-SUBMITTERS: Iran, Turkmenistan, Philippines, Yemen, Ireland, UK\n',
#  '\n',
#  'THE WORLD HEALTH ORGANIZATION,\n',
#  '\n',
#  'Bearing in mind that the Universal Health Coverage (UHC) means all individuals and communities receive the health services they need without suffering financial hardship,\n',
#  '\n',
#  'Noting that the United Nations General Assembly (UNGA) passed a convention on the status of refugees on July 28th, 1951, \n',
#  '                         \n',
#  'Reminding all nations that the resolution New York Declaration for Refugees and Migrants (A/RES/71/1) passed, this protects the rights of refugees and migrants, \n',
#  '\n',
#  'Recalling the Global Action Plan to Promote the Health of Refugees and Migrants drafted on October 19, 2018, that develops a framework of priorities and guiding principles to promote the health of refugees and migrants,\n',
#  '\n',
#  'Recognizing the rights of individuals to leave any country, including their own, and the rights and freedoms set forth in the Universal Declaration of Human Rights, including health-related rights, belong to all people, including migrants, refugees, and other non-nationals,\n',
#  '\n',
#  "Stressing the fact that there are an estimated 1 billion migrants in the world today of whom 258 million are international migrants and 763 million internal migrants which is one in seven of the world's population,\n",
#  '\n',
#  '1. Requests nations to cooperate with NGOs such as UNHCR (United Nations High Commissioner for Refugees) to assist refugees in ways such as but not limited to:\n',
#  'a. adapting the Educate a Child (EAC) multi-year program to enroll out-of-school children (OOSC) in primary education\n',
#  'b. extending the Accelerated Education (AE) programs to promote access to certified education for children and adolescents who have missed out on substantial amounts of schooling\n',
#  'c. improving the quality of education in order to furnish a secure future to eradicate fears of an insecure future that may further contribute towards the deterioration of one’s mental health capacity, through:\n',
#  'i. the provision of used and unwanted books, papers, and stationary from MEDCs\n',
#  'ii. the creation of education programs that emphasize basic, primary education for children in order to furnish basic literacy skills and vocational education for adults to provide skills for jobs that contribute more towards the local economy, especially after repatriation;\n',
#  '\n',
#  '2. Encourages nations to raise awareness in More Economically Developed Countries (MEDCs) through ways such as but not limited to; \n',
#  'a. inviting professional speakers to speak:\n',
#  'i. with the funds of NGOs in more economically developed countries\n',
#  'ii. about the importance of solving the mental health of refugees and migrants\n',
#  'b. creating areas of fundraising allowing people to donate to organizations such as the Doctors without Borders and the organizations would mainly focus on helping to:\n',
#  'i. advance research in mental health especially faced by the refugees and migrants\n',
#  'ii. provide therapists and counselors to refugee camps or areas with migrants with many people with mental health issues\n',
#  'c. raising awareness to the people about how there are refugees in their countries which would make the refugees feel more trust and comfort in their host country through advertisements such as:\n',
#  'i. posters\n',
#  'ii. advertisements on television;\n',
#  '\n',
#  '3. Further encourages NGOs in charge of helping these refugees and migrants to create more therapeutic services aimed to help refugees and migrants with mental health issues in their country through ways such as but not limited to;\n',
#  'a. creating training sessions to train helpers and help out in therapeutic services through: \n',
#  'i. supplies for these doctors provided through NGOs\n',
#  'ii. incentives such as getting paid for helping out in the therapeutic services\n',
#  'iii. have these helpers support these therapeutic services\n',
#  'b. creating more support groups which would be part of the therapeutic services through ways such as:\n',
#  'i. separating the patients based off of the type of mental health issue they have\n',
#  'ii. having each patient talk about their struggles and sharing ideas on ways to deal with the struggles\n',
#  'c. suggesting governments to create health services directed to refugees and asylum-seekers in ways such as but not limited to:\n',
#  'i. directing a portion of tax payments towards creating free regular health checkups in hospitals or related clinics for them\n',
#  'ii. encouraging LEDCs to invest the money saved into critical healthcare needs, such as providing universal health care and increasing the doctor/bed ratio towards the general population, if this is affordable for the specific LEDCs;\n',
#  '\n',
#  '4. Recommends the creation of more programmes in charge of allowing education through ways such as:\n',
#  'a. allowing refugees and migrants with mental health issues to attend school with others after they have basic knowledge through ways such:\n',
#  'i. inviting Teachers Without Borders who would be willing to help out and provide support by teaching these refugees and migrants through education\n',
#  'ii. providing knowledge to them which would allow refugees and migrants to eventually get a job\n',
#  'b. introducing activities after their school day in order to allow them to find personal interests:\n',
#  'i. having funds from the programme to help support, and also donations from MEDCs\n',
#  'ii. creating activities such as sports, playing music and others\n',
#  'c. provide occupational training which would prepare refugees for finding and working at jobs:\n',
#  'i. hiring counselors funded by the programmes to help find jobs the refugees are interested at\n',
#  'ii. hosting the training daily \n',
#  'd. teaching the refugees and migrants the language of their host countries in order for them to find a job easier through ways such as but not limited to:\n',
#  'i. inviting people who speak the language of the refugees and migrants’ and also knows how to speak the language of the host country \n',
#  'ii. having MEDCs to provide textbooks which would enhance the learning of the language;\n',
#  '\n',
#  '5. Calls for the creation of more organizations in charge of helping refugees and migrants to provide services that would make it easier for migrants and refugees to make appointments with doctors by:\n',
#  'a. speak the language of the host country which allows:\n',
#  'i. easier communication between counselors and refugees speaking in another language\n',
#  'ii. accuracy for counselors to provide tips to help the refugee/migrants\n',
#  'b. creating a transportation service especially in charge of driving refugees/migrants with mental health issues to medical facilities if not in refugee camps by:\n',
#  'i. having buses that daily drive to medical services allowing the refugees and migrants to attend\n',
#  'ii. taking in funds from the new organization in charge of helping the refugees and migrants;\n',
#  '\n',
#  '6. Requests government organizations like the Substance Abuse and Mental Health Services administrations (SAMHSA) to create events for the refugees/migrants with mental health disorders such as but not limited to:\n',
#  'a. creating activities in this event for refugees and migrants in order to:\n',
#  'i. build a more trusting relationship with the host government\n',
#  'ii. allow them to have a sense of comfort and go to authorities helping them achieve mental health stability \n',
#  'b. these events would also teach them how to seek help in authorities ways such as:\n',
#  'i. having a part of the event be about ways to seek these authorities\n',
#  'ii. a created video teaching them how to find the authority with translations to the language the refugees and migrants speak\n',
#  'iii. the video would be created by workers working at the authorities helping refugees/migrants with mental health issues;\n',
#  '\n',
#  '7. Further requests all nations take actions to move towards UHC in ways such as but not limited to:\n',
#  'a. strengthening health systems by:\n',
#  'i. reaching out to Non-Government Organizations (NGOs) for funds so that the poor are able to obtain the services they need\n',
#  'ii. improving the quality of doctors and nurses\n',
#  'b. improving health service by:\n',
#  'i. relocating high quality doctors from More Economically Developed Countries (MEDCs) to refugee camps to train personnel and treat those suffering from mental illnesses\n',
#  'ii. facilitating healthcare workforce expansion by increasing organizational capacity, including the ability to educate and train those who volunteer\n',
#  'c. expanding the availability of healthcare services by increasing the number of hospitals.\n',
#  '\n',
#  'FORUM: Economic and Social Council\n',
#  'QUESTION OF: Promoting Cooperation Between Countries of the Global South (South-South Development) for Development\n',
#  'Main Submitted: Benin\n',
#  'CO-SUBMITTED BY: India, Belarus, and Ecuador\n',
#  '\n',
#  'THE ECONOMIC AND SOCIAL COUNCIL,\n',
#  '\n',
#  'Aware of the fact that there are only twenty-nine countries in the south-south cooperation,\n',
#  '\n',
#  'Recognizing that resolution A/RES/62/209 stresses that south-south cooperation is an important factor of a country’s development,\n',
#  '\n',
#  'Emphasizing the fact that south-south cooperation is set up to meet the sustainable development goals (SDGs),\n',
#  '\n',
#  'Keeping in mind that Benin has hosted a conference to promote relations between countries in the south-south cooperation,\n',
#  '\n',
#  '\n',
#  '1. Recommends nations of the South-South Cooperation to increase the number of trades in set countries goods through ways such as but not limited to:\n',
#  'a. deciding the main export and focusing on producing that supply so that:\n',
#  'i. the nation can have a stable source of export\n',
#  'ii. the nation can fully focus on research and focus funds on only one thing\n',
#  'b. prioritizing export before import to assure that:\n',
#  'i. nations are selling more than they are buying, therefore, making more profit\n',
#  'ii. nations have remaining funds;\n',
#  '\n',
#  '2. Strongly encourages the members of the south-south cooperation to promote interactions within the global south for reasons such as but not limited to:\n',
#  'a. help with the situation of countries in the south-south cooperation in ways such as but not limited to:\n',
#  'i. give advice during war\n',
#  'ii. provide aid during natural disasters\n',
#  'b. exchange ideas and knowledge for purposes such as but not limited to:\n',
#  'i. possible projects\n',
#  'ii. war\n',
#  'iii. natural disasters;\n',
#  '3. Calls upon member states, mainly MEDCs, to further sell goods and medical supplies to LEDCs, or promote tourism to such places for reasons such as but not limited to:\n',
#  'a. help LEDCs to lift citizens from poverty\n',
#  'b. improve overall sanitation and disease prevention in ways such as but not limited to:\n',
#  'i. donate money to hospitals to purchase better medical supplies\n',
#  'ii. provide free vaccinations to citizens \n',
#  'c. assist economic growth of LEDCs through increased tourism;\n',
#  '\n',
#  '4. Desiring all nations of the global south to join the south-south cooperation through ways such as but not limited to:\n',
#  'a. fund profitable projects such as but not limited to:\n',
#  'i. building public transportation\n',
#  'ii. improving public facilities\n',
#  'b. engaging in long-term loan treaties for investing in countries before they become a more economically developed country (MEDC) for purposes such as but not limited to:\n',
#  'i. building public transportation\n',
#  'ii. improving urban infrastructure\n',
#  'iii. promoting tourism\n',
#  'iv. creating more job opportunities;\n',
#  '\n',
#  '5. Recommends the MEDCs to send workers to develop and modernize LEDCs who are partaking in the South-South Cooperation by for reasons such as but not limited to:\n',
#  'a. partnering with companies and programs that help provide migrant workers in LEDCs job opportunities such as but not limited to:\n',
#  'i. RBC\n',
#  'ii. Enbridge \n',
#  'b. increasing awareness to MEDCs of that LEDCs need help through promotions such as but not limited to:\n',
#  'i. social media\n',
#  'ii. news media;\n',
#  '\n',
#  '6. Encourages the MEDCs participating in the South-South Cooperation to send UN officials to LEDCs in order to increase the local literacy rate by: \n',
#  'a. encouraging NGOs and MEDCs to offer donations and contribute to the funds for the teacher’s grants\n',
#  'b. arranging the teachers to go to the LEDCs with the lowest literacy rate as a priority for reasons such as but not limited to:\n',
#  'i. improve job opportunities\n',
#  'ii. boosts economy\n',
#  'c. MEDCs help fund schools in LEDCs that promote bilingual education for students in the future for reasons such as but not limited to:\n',
#  'i. becoming Government officials\n',
#  'ii. becoming an ambassador\n',
#  'iii. becoming local tour guides.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'COMMITTEE: United Nations Human Settlement Programme (UN Habitat) \n',
#  'QUESTION OF: Improving Urban planning and Design on National Frameworks\n',
#  'MAIN SUBMITTER: Czech Republic \n',
#  'CO-SUBMITTER: Lebanon, Republic of Korea, Ukraine \n',
#  '\n',
#  'THE UNITED NATIONS HUMAN SETTLEMENT PROGRAMME,\n',
#  '\n',
#  'Acknowledging that the world’s urban population is expected to double by 2050,\n',
#  '\n',
#  'Fully aware that urbanization of cities can increase city industries and population which can lead to the improvement in economy of the nation,\n',
#  '\n',
#  'Bearing in mind that cities such as Burundi, Monrovia, and Laos are suffering under political and  economic instability, meaning that supports to rebuild its nations are required,\n',
#  '\n',
#  'Desiring to improve the living condition and standards for citizens through urban development and planning,\n',
#  'Urges all countries affiliated with the United Nations to recognize the importance of urban design,\n',
#  '1) Recommends regional leaders in a nation to meet every 6 months with their state government to strengthen relationships between states and to discuss topics such as but not limited to:\n',
#  'a) further development of infrastructure\n',
#  'b) adaptation to climate change\n',
#  'c) use of sustainable energy\n',
#  'd) eradication of poverty;\n',
#  '\n',
#  '2) Encourages nations worldwide to have annual meetings to discuss things such as but not limited to:\n',
#  'a) worldwide eradication of poverty\n',
#  'b) successful changes \n',
#  'c) further development of infrastructure;\n',
#  '\n',
#  '3) Strongly urges all states to conduct urban development activities with their citizen: the activities that can include things such as but not limited to:\n',
#  'a) interactive games\n',
#  'b) video and audio learning \n',
#  'c) question and answer sessions with qualified and authorized urban planners; \n',
#  '\n',
#  '4) Suggests all nations to further help eradicate poverty in ways such as but not limited to:\n',
#  'a) provide free primary and secondary education \n',
#  'b) access to new technology and innovations\n',
#  'c) job training and job opportunities\n',
#  'd) basic necessities:\n',
#  'i) shelter \n',
#  'ii) clothes \n',
#  'iii) food and water;  \n',
#  ' \n',
#  '5) Urges all nations to create policies and plans to accommodate the population and create integrated, connected cities and neighborhoods to help promote: \n',
#  'a) a safe environment \n',
#  'b) decent and stable houses\n',
#  'c) schooling \n',
#  'd) help create healthy relationships amongst people;\n',
#  '\n',
#  '6) Requests all nations to create platforms and campaigns that can help the general public to share their opinions about things such as but limited to:\n',
#  'a) improvements needed in the society\n',
#  'b) possible future infrastructure ideas;\n',
#  '\n',
#  '7) Calls upon countries to spread social and economic diversity through their nations to further advance in urbanization in ways such as but not limited to:\n',
#  'a) educating citizen about different religions and cultures through campaigns and billboard advertisements which can include diverse religions and cultural beliefs\n',
#  'b) spreading awareness by raising questions such as but not limited to:\n',
#  'i) why there are different social classes\n',
#  'ii) why it is an issue \n',
#  'iii) effects and impacts \n',
#  'iv) ways to help \n',
#  'c) celebrating the different cultures in that society through:\n',
#  'i) having multi-cultural events \n',
#  'ii) interactive learning (voluntary)\n',
#  'd) having government school taking student of field trips to learn about the different cultures through visiting:  \n',
#  'i) museums\n',
#  'ii) cultural places for worship\n',
#  'iii) restaurants of a specific cuisine;\n',
#  '\n',
#  '8) Invites all nations to work with the United Nations to help mainstream urban planning and design within an approach to the urban sector of the country; \n',
#  '\n',
#  '9) Encourages MEDC nations to become the provider of essential financial support to LEDC nations for the urban development and planning which can lead to the development of the nations and improvement in the quality of living standards for citizens to strength the relationships between nations;\n',
#  '\n',
#  '10) Emphasizes on the necessity of taking feedbacks from local community and other citizens in order to make improvements on its urbanization of the city by ways such as but not limited to:\n',
#  'a) through local governments\n',
#  'b) through NGOs\n',
#  'c) suggests that member nations hold annual surveys for citizens to provide their improvements and opinions on things such as but not limited to:\n',
#  'i) utilization of public spaces \n',
#  'ii) necessary infrastructures\n',
#  'iii) possible ways to improve measures \n',
#  'iv) ways to mitigate the urban divide \n',
#  'v) the use of mix-land;\n',
#  '11) Encourages all nations to spread awareness about the importance of urban planning in ways such as:\n',
#  'a) placing posters put up in public areas\n',
#  'b) advertising on television and other social media platforms \n',
#  'c) encouraging schools to spending time educating students on the idea of urban planning and design as a career;\n',
#  '\n',
#  '12) Suggests that further studies should be conducted on the following:\n',
#  'a) noting aspects that hold a large role in the success of a well-urbanized city\n',
#  'b) major issues affect the lives of people in Less Economically Developed Countries (LEDCs) living there the most, and therefore decide which problems are needed to be prioritized\n',
#  'c) monitoring cities that undergo the new plans to determine whether the changes made have been successful or not;\n',
#  '\n',
#  '\n',
#  '\n',
#  ' \n',
#  'FORUM: General Assembly 3 (II)\n',
#  'QUESTION OF: Countering unfair treatment and discrimination against individuals with physical/mental disabilities and inherited disorders\n',
#  'SUBMITTED BY: Philippines\n',
#  '\n',
#  'THE GENERAL ASSEMBLY 3,\n',
#  '\n',
#  'Affirming the role of the General Assembly in promoting equality of all global citizens,\n',
#  '\n',
#  'Aware that over a billion people, about 15% of the world’s population, have some form of a disability, \n',
#  '\n',
#  'Reminding all nations of the Convention on the Rights of Persons with Disabilities, adopted in 2006 and entered into force in 2008, which aims to promote, protect and ensure the full and equal enjoyment of all human rights and fundamental freedoms by all persons with disabilities,\n',
#  '\n',
#  'Reaffirming its Resolution 7/9 of 27 March 2008, which encourages governments to carry out the action in support of the human rights of people with disabilities, \n',
#  '\n',
#  'Recognizing that dealing with disabilities requires a comprehensive approach that addresses not only the treatment of the patient but includes prevention as well as development goals in general,\n',
#  '\n',
#  'Recognizing also that addressed disabilities also needs to take into account for the broader environmental factors that are associated with the disease as education, employment, economic situation, racial and cultural issues,\n',
#  ' \n',
#  '1. Encourages all nations to help people better understand disabilities and inherited disorders through ways such as, but not limited to:\n',
#  'a) establishing a Committee of Health Campaigns to commit primarily in creating campaigns to raise awareness and to change prejudice on physical and mental illness through ways such as but not limited to:\n',
#  'i. spreading positive and unprejudiced imagery of the disabled              \n',
#  'ii. publicizing campaigns, which will be managed and promoted by NGOs such as the International Disability Alliance (IDA) through popular social media\n',
#  'iii. printing easily accessible campaigns in which the general public may participate in without much pressure\n',
#  'iv. having representatives travel to different nations to hold anti-discrimination activities or addressing the unfair treatment in places such as schools or public places\n',
#  'b) exposing children at a young age to tolerate differences in people such as those with disabilities and inherited disorders through ways such as but not limited to:\n',
#  'i. integrating these social issues into televised programs such as tv shows and movies\n',
#  'ii. encouraging authors to satirize society’s marginalization of people with disabilities and inherited disorders\n',
#  'c) setting up informative websites relating to disability crisis;\n',
#  '\n',
#  '2. Proposes international organizations such as Organization for Education of Sustainable Development (OESD), and the United Nations Educational, Scientific and Cultural Organization (UNESCO) to participate in providing preventative and managerial education regarding disabled through means such as but not limited to:\n',
#  'a) providing education about the disabled to the citizens through means such as but not limited to:\n',
#  'i. videos\n',
#  'ii. handbills\n',
#  'iii. the campaigns mentioned in clause 1\n',
#  'b) incorporating programs such as simulations into the school curriculum to help students better understand and recognize the challenges faced by people with disabilities;\n',
#  '\n',
#  '3. Recommends better quality treatments for disabilities by means such as but not limited to:\n',
#  'a) supplying a systematic research system funded by the United Nations, NGOs, and donations from the public by:\n',
#  'i. suggesting specialists report exact results of experiments through WHO publications\n',
#  'ii. urging member nations to increase the budget expended for Research and Development (R&D) programs\n',
#  'b) encouraging the recruitment of health experts to manage disabilities through means such as but not limited to:\n',
#  'i. empowering individual countries to separately examine their disabilities\n',
#  'ii. researching for development in the field of psychology to be able to treat patients \n',
#  'c) implementing selective strategies by categorizing people into groups of  ‘dangerous’, ‘warning’, ‘cautionable’, and ‘safe’ based on medical checkups for those suffering from trauma or abuse and helping treat and improve conditions for said people by means such as but not limited to:\n',
#  'i. providing people who qualify with musical and art therapy in pursuit of prevention offered by the International Association of Art Therapy (IAAT) and Doctors Without Border to perform checkups and help treat these people\n',
#  "ii. recommending doctors, health professionals, and specialists to help the 'dangerous' and 'warning' groups by providing them with monthly checkups;\n",
#  '\n',
#  '2. Calls upon national governments to offer comfortable environments for people with disabilities and inherited disorders in the workforce through ways such as but not limited to:\n',
#  'a) setting up services such as:\n',
#  'i. emotional and physical therapy\n',
#  'ii. social assistance programs\n',
#  'iii. support groups where those who have already recovered can assist ones who are still going through difficulties\n',
#  'b) helping people with disabilities feel more encouraged to participate in the workforce through ways such as:\n',
#  'i. allowing modified work schedules upon request\n',
#  'ii. permitting flexible leave policies when the people mentioned offers a reason as to why they need the leave\n',
#  'c) establishing a set percentage of disabled workers required in each company,\n',
#  'd) having companies sign agreements to ensure the company understands and considers the situation the disabled person faces;\n',
#  '\n',
#  '3. Further recommends the international community to create and attend an annual conference organized by the UN on the treatment of people with disabilities and inherited disorders, which will:\n',
#  'a) analyze and improve conditions for those with disabilities and inherited disorders by: \n',
#  'i. evaluating the current situation and its effects on people\n',
#  'ii. discussing ways to implement further action on this issue\n',
#  'b) include specific representatives such as:\n',
#  'i. a majority being ones with disabilities and inherited disorders in order to face the issue from their perspective\n',
#  'ii. officials from third-party organizations such as NGOs\n',
#  'iii. government officials which can help carry out the action.\n',
#  '\n',
#  'FORUM: General Assembly 4 Special Political and Decolonization\n',
#  'QUESTION OF: China’s One Belt One Road Initiative\n',
#  'SUBMITTED BY: Republic of Korea\n',
#  'CO-SUBMITTERS: Kenya, Republic of Ghana, Angola\n',
#  '\n',
#  'THE GENERAL ASSEMBLY,\n',
#  '\n',
#  'Fully aware that in September of 2013, president Xi Jinping of the People’s Republic of China, announced the creation of the OBOR initiative which aims to boost global trading between China and regions like Africa, Europe, and other parts of Asia,\n',
#  '\n',
#  'Reminding all nations that the One Belt and One Road Initiative (OBOR initiative) claims to build connection and cooperation and that nations should keep on track of the OBOR plan’s condition,\n',
#  '\n',
#  'Taking into account that they are constantly changing and evolving with the initiative \n',
#  'beginning to include financial integration/cooperation in science and technology/cultural and academic exchanges,\n',
#  '\n',
#  'Deeply concerned about the accusations of imperialism, and worries of activism labor, harm to environment, etc.,\n',
#  '\n',
#  '1. Encourages countries who take part of the One Belt One Road to agree and work out the payment that would be sufficient, and fair for workers, to ensure that everyone is well paid so that it wouldn’t go against the idea of OBOR (benefiting everyone) and no potential corruption or protests will break out, through:\n',
#  'a) urging the Chinese companies to create more local employment opportunities for the local workers\n',
#  'b) requesting countries to view the project as a job, paying workers\n',
#  'c) encouraging China to provide incentives and new job opportunities for the current Chinese workers working the project to leave jobs to the local people\n',
#  'd) sorting out fair payment between countries depending on their financial status and growth, as well as economy status;\n',
#  '\n',
#  '2. Strongly encourages that the countries participating in the China One Belt One Road\n',
#  'Initiative are given protection to the environmental damages that strongly harms the \n',
#  'environment from debris and trash through the construction of the road and provides basic protection to countries in such ways but not limited to: \n',
#  'a. finding volunteers to clean up marine areas that the OBOR had crossed during construction\n',
#  'b. including school clubs, correctional institutions, or community service agencies as extra and community service hours, to aid the country’s people and establish a creative way for punishment and volunteer work\n',
#  'c. setting laws to not overfish the marine life due to the complications of extinctions already happening around those areas;\n',
#  '\n',
#  '3. Strongly affirms the initiative should bring a mutually favorable and economically beneficial relation between participating countries and not for few of the countries:\n',
#  'a) recommending the initiative bring in more less economically developed countries (LEDCs) with larger investment opportunities\n',
#  'b) partnering the companies from other more developed countries to work the Chinese companies to help the local business projects\n',
#  'c) allowing a more transparent and less-imperialistic values to be showed within projects across the entire initiative\n',
#  'd) emphasizing to the Chinese government that the initiative should create a friendly and steadily growing economy for the local governments and communities\n',
#  'e) ensuring there should be more market driven building projects, so all nations involved would have a higher possibility of positive return\n',
#  'f) encouraging more partnerships between Chinese and local companies\n',
#  'g) providing more opportunities to local companies\n',
#  'h) allowing other developing countries to obtain and opportunity to grow their economy as well;\n',
#  '\n',
#  '4. Calls upon the Chinese government and the member states participating in the One Belt, One Road to hire more local workers to work on local building projects by:\n',
#  'a) urging the Chinese companies to create more local employment opportunities for the local workers\n',
#  'b) encouraging China to provide incentives and new job opportunities for the current Chinese workers working the project to leave jobs to the local people\n',
#  'c) emphasizing further incentives that could be made for the Chinese government, if it complies with these regulations;\n',
#  '\n',
#  '5. Calls for realizing LEDCs’ role in the project, as there are many countries that own natural resources or a good geographical spot for transportation but not as prosperous as other countries, through allowing and encouraging the LEDCS to:\n',
#  'a) set up goals which are designed based on the country’s own financial system\n',
#  'b) embrace the People’s Republic of China and other countries’ help without relying on that country\n',
#  'c) cooperate with each other and figure better ways to improve the economy\n',
#  'd) not be under other countries’ control and to be more independent\n',
#  'e) cultivate more talented people by popularizing education\n',
#  'f) consider reforms for some industries to empower the country financially\n',
#  'g) consider how to make efficient use of all kinds of contributions\n',
#  'h) designate the academics and educators:\n',
#  'i. the LEDCs should build more libraries, and these libraries do not have to be in large scale, instead, the best way is to add more books in a long run and put more effort on how to attract people come here to read books, but make sure there’s a national library for advanced knowledges\n',
#  'ii. the LEDCs should try to make people get to know about internet and modern technologies, this action could be an important link between the citizens and modern world, the LEDCs’ people should be cultivated with more confidence and self-esteem, the educator should tell the students about the real situation about everything and figure out how to motivate them with this kind of situation, and the LEDCs should bring down the cost of tuition and try to bring as many educators as they can\n',
#  'iii. hoping the whole plan of trying to empower LEDCs could start from making people’s life better, the LEDCs’ governments should take better care of people’s livelihood, and try to provide as steady environments for living, working and studying as they can provide clean food, clean water and health care, a country could become prosperous only if the people are healthy for work and study and establish more public facilities;\n',
#  '\n',
#  '6. Confirms China’s full reasoning of the creation of OBOR to cancel and decline the accusations of imperialism through requesting countries who take part in the OBOR along with China to discuss about China’s full reasoning of why the OBOR was created, making sure everything is clear and agreements and policies are made;\n',
#  '\n',
#  '7. Reminds member nations that the OBOR project is supposed to be a growing project, for China and countries which are willing to participate, and that it would be necessary to monitor and create policies to prevent any corruption caused by the OBOR, and:\n',
#  'a) stresses it should be beneficial to all countries, to create cooperation and unity with each other\n',
#  'b) hopes the project can lead to economic growth, country growth, and solution to problems such as unemployment, world hunger, and poverty.\n',
#  '    \n',
#  '\n',
#  '\n',
#  '\n',
#  'FORUM: General Assembly 3 (II)\n',
#  'QUESTION OF: Measures to reduce the incidence of hate crimes \n',
#  'SUBMITTED BY: Republic of Korea \n',
#  '\n',
#  'THE GENERAL ASSEMBLY,\n',
#  '\n',
#  'Recalling the Universal Declaration of Human Rights, International Covenant on Civil and Political Rights, World Conference on Racism, the International Covenant on Economic, Social and Cultural Rights and other appropriate human rights instructions and instruments, \n',
#  '\n',
#  'Recognizing that all human rights are universal, interdependent, and interrelated and that the international community must treat each and every human equally and objectively, considering every national and regional system to advance and secure all human rights,\n',
#  '\n',
#  'Reaffirming that violence in any form, whether it be physical, mental, or any other form, can never be accepted or tolerated,\n',
#  '\n',
#  'Reflecting that not only do hate crime victims suffer a humongous impact, but the community as a whole gets affected as hate crimes are reflections of attitudes of the community to some degree,\n',
#  '\n',
#  'Stressing that social media is becoming a way to spread violence and promote negativity instead of positivity, for example Facebook admitting its service has been used to spread violence in Myanmar, \n',
#  '\n',
#  '1. Requests governments and non-governmental organizations (NGO) to collaborate in order to raise awareness and general knowledge through ways such as but not limited to: \n',
#  'a. taking part in organizations with aims of reducing hate crimes to create better and more advanced projects that can resolve the issue of hate crimes by creating charity events in order to:\n',
#  'i. raise money to promote and advance participating organizations \n',
#  'ii. develop volunteer opportunities to support these organizations\n',
#  'b. promoting mandatory public speeches and lectures every three months by educating the public about previous hate crimes and ways to prevent them \n',
#  'c. seeking assistance from outside professionals such as hate crime related experts, anti-racism organizations and individuals who were personally involved in hate crimes to share their experiences and to challenge biases regarding the topic of hate crimes\n',
#  'd. working with schools, businesses, organizations, and community groups to sponsor posters or essays that explain how bias-related crimes can hurt the community \n',
#  'e. raising awareness of hate crimes in a community by creating short documentaries, videos, images, or clips that can be broadcasted in places such as schools and churches\n',
#  'f. educating the community by commemorating discrimination and hatred in the past through museums and exhibitions with ways such as but not limited to:\n',
#  'i. donating to the Institute of Education to fund a field trip to the museum for youths\n',
#  'ii. using photographs and videos to show support and explanations of this issue;\n',
#  '\t\n',
#  '2. Requests for nations to support organizations such as Community Alliance to Combat Hate (CATCH) and National Association for the Advancement of Colored People (NAACP) to help in the process of reducing hate crimes in ways such as: \n',
#  'a. supporting more organizations such as the American Physiological Association (APA) which helps share information on psychology \n',
#  'b. requesting relevant stakeholders to donate money in order to help solve issues efficiently  \n',
#  'c. providing materials to train police officers and prosecutors to investigate hate crimes;\n',
#  '\n',
#  '3. Encourages the promotion of education about hate crimes for students in primary and secondary school by offering assistance to help students understand the concept of hate crimes in ways such as:\n',
#  'a. inviting guest speakers or volunteers from networks such as International Network for Hate Studies (INHS) to educate people about topics relating to hate crimes such as ways to solve issues regarding hate crimes in a less direct and more peaceful manner \n',
#  'b. mandating a few hours of education regarding the racism in primary schools to prevent potential racist attitude and to promote anti-racism by starting a peer education program to teach bias awareness to children\n',
#  'c. educating teachers of primary and secondary schools regarding hate crimes to prevent the teaching of wrongful information to students and to further increase awareness on the issue\n',
#  'd. requesting the government to educate students by teaching them to not judge by appearance and race \n',
#  'e. providing training and educational materials to block the access of youths to hate sites with ways such as but not limited to:\n',
#  'i. distributing programs that will block access to hate sites\n',
#  'ii. providing advice to teachers on how to teach the students about cyber hate\n',
#  'iii. teaching the youth on how to recognize and react to hate on the internet \n',
#  'f. promoting more positive and beneficial after school activities for teens\n',
#  'g. creating elective classes or clubs in schools to raise awareness of bias to younger students through ways such as but not limited to: \n',
#  'i. making posters about different social groups to put around the school \n',
#  'ii. establishing sponsored fairs with activities relating to the seriousness of hate crime\n',
#  'iii. preventions of hate crimes or anything related to hate crimes to teach about hate crimes and raise money at the same time\n',
#  'iv. using children’s creativity to encourage things such as but not limited to singing, writing, drawing to spread the idea of anti-violence \n',
#  'h. creating elective classes or clubs in schools to raise bias awareness to younger children through ways such as but not limited to: \n',
#  'i. making posters about different social groups to put around the school \n',
#  'ii. establishing sponsored fairs with activities relating to seriousness preventions of hate crimes or anything related to hate crimes to teach about hate crimes and raise money at the same time\n',
#  'iii. using children’s creativity to encourage things such as but not limited to singing, writing, drawing to spread the idea of anti-violence\n',
#  'i. advocating violence prevention through ways such as but not limited to:\n',
#  'i. setting up posters in public seminars \n',
#  'ii. educating citizens of all ages, especially teenagers to accept differences and believe that all humans are born equal \n',
#  'iii. establishing a connection with the government for papers or poster regarding the prevention of hate crimes\n',
#  'iv. promoting more positive and beneficial after school activities for teens;\n',
#  '\n',
#  '4. Advises nations on forming legislation and policy which protects the rights and equality for all groups of people to prevent hate crime in ways such as but not limited to:\n',
#  'a. allowing experts from other nations and organizations to overlook their legal system and to amend it further to prevent further hate crimes\n',
#  'b. regularly amending and examining the effectiveness of the legal system regarding the hate crimes in order to further prevent hate crimes\n',
#  'c. encouraging laws regarding the collection of hate crimes statistics for the public to access\n',
#  'd. improving the adequacy of hate crime legislation through ways such as but not limited publishing researched based reports;\n',
#  '\n',
#  '5. Requests nations to cooperate with NGOs and governments to support victims of bias-motivated hate crimes through ways such as but not limited to: \n',
#  'a. offering physical help such as shelter and money to victims of hate crimes \n',
#  'b. providing more support in training to identify and solving hate crimes for police and sheriffs\n',
#  'c. creating a specialized department for hate crimes in order to: \n',
#  'i. have specialized trainers to help record all details of the hate crime as all information is important and can be forgotten quickly \n',
#  'ii. collaborate with psychology departments to give precise advice or help comfort the victims \n',
#  'd. calling upon member nations to diversify the events during hate crime committers jail time by having mandatory on categories such as but not limited to anti-racism, sex education and religions\n',
#  'e. providing psychiatrist assistants in such ways but not limited to group meetings or individual counselling;\n',
#  '\n',
#  '6. Implores nations to establish harsher punishment regarding hate crimes in ways such as but not limited to: \n',
#  'a. requiring community service along with jail time\n',
#  'b. establishing a universal guideline to forbid any spread of hate to ban all hate, not just crimes;\n',
#  '\n',
#  '7. Urges governments to control social media for national security in order to prevent unwanted incidents in ways such as but not limited to: \n',
#  'a. recruiting people with experience in technology to join the government to monitor actions on social media to ensure that social media is not used to promote violence \n',
#  'b. collaborating between social media owners and the government to ensure posts and comments on social media are positive and harmless to others \n',
#  'c. giving the government power to shut down social media in times of crises as the spread of information will restrict potential manipulations and disinformation\n',
#  'd. making it an obligation to moderate and censor content that may lead to crimes\n',
#  'e. raising awareness through traditional and print media such as but not limited to:\n',
#  'i. television programs\n',
#  'ii. radio shows\n',
#  'iii. posters\n',
#  'iv. flyers.\n',
#  'Committee: GA3: Social, Cultural and Humanitarian\n',
#  'Topic: Measure to reduce the incidence of hate crimes\n',
#  'Main Submitter: Romania\n',
#  '\n',
#  'GENERAL ASSEMBLY 3,\n',
#  '\n',
#  'Deeply concerned that manifestation of discrimination is still happening, with incidents like religious minorities massacred in ISIS occupied Iraq and Syria and the recent shooting at the mosque in Christchurch, \n',
#  '\n',
#  'Calling to mind Resolution A/RES/70/157 adopted by the General assembly on 3 March 2016, which called for increased efforts in reducing hate crimes by all member states,\n',
#  '\n',
#  'Reaffirming that all human beings are entitled to the rights to laid out by the Universal Declaration of Human Rights, especially articles 7, 12,18, and 26 (2),\n',
#  '\n',
#  'Bearing in mind that although there are both state and federal laws against hate crimes, the proving of motive or bias of hate crime is quite difficult, \n',
#  '\n',
#  'Noting with concern that there is no internationally accepted definition of hate crime, \n',
#  '\n',
#  'Recognizing hate crime has increased by 18% in the last year with racial crimes at 81%, sexual at 11%, religion at 6%, disability at 5% and transgender at 1%, this proves hate crimes are a pressing issue,\n',
#  '\n',
#  '1. Expresses its hope with the action plans led by the Office of the High Commissioner for Human Rights (OHCHR) and the Organization for Security and Cooperation in Europe (OSCE) in ways such as but not limited to:\n',
#  'a. promoting and protecting human rights in ways such as but not limited to:\n',
#  'i. creating campaigns to encourage anti-hate crime that will be led by designated officials\n',
#  'ii. stopping violence against ethnic minorities and other groups such as the LGBT community that hate crime is generally directed upon\n',
#  'iii. creating advertisements so that anti-hate crime information can be spread,\n',
#  'iv. creating punishments for people not following human rights\n',
#  'v. encouraging other people to promote and protect human rights\n',
#  'b. creating a committee on the Elimination of Racial and Sexual Discrimination (CERSD) who oversee subjects such as but not limited to:\n',
#  'i. independent experts who monitor the implementation of the Convention on the Elimination of All Forms of Racial and Sexual Discrimination by state parties\n',
#  'ii. monitoring state parties to submit regular reports on how the rights are being implemented\n',
#  'iii. addressing its concerns to the state party involved and giving recommendations\n',
#  'iv. holding three sessions per year in Geneva on the topic of hate crimes;\n',
#  '2. Further requests member countries to develop a strategy focusing on subjects such as but not limited to:\n',
#  'a. strengthening human rights laws regarding hate crime and hate speech\n',
#  'b. encouraging youth and young adults to make a stand against hate crime\n',
#  'c. gender equality and equal rights and opportunities for people of all races and sexual orientations as well as religious backgrounds\n',
#  'd. involving communities in ways such as but not limited to:\n',
#  'i. fundraisers raising money for victims of hate crime\n',
#  'ii. informative courses and programs at schools;\n',
#  '2. Urges speeches to be made and presented by designated officials with information including but not limited to:\n',
#  'a.  updated statistics that provide insight into current hate crime statutes in nations\n',
#  'b.  recount of recent and relevant events regarding hate crimes\n',
#  'c. proposed solutions to reducing hate crime and how communities can help reduce hate crime;\n',
#  '3. Recommends that the next generation will have more education to reduce hate crimes in ways such as but not limited to:\n',
#  'a. teaching the youth about the issue and consequences of hate crime\n',
#  'b.  creating programs to inform people by establishing a UN-affiliated team that produces items such as but not limited to:\n',
#  'i. posters\n',
#  'ii. web videos;\n',
#  '4. Encourages member states to fund broad-based awareness-raising and advocacy campaigns to achieve visibility and develop a better understanding of the topic through ways such as but not limited to:\n',
#  'a. training the community\n',
#  'b. encouraging all individuals to take steps in their daily lives to lessen hate crimes in ways such as but not limited to:\n',
#  'i. using social media\n',
#  'ii. having government-funded scholarly centers to provide basic education regarding the topic;\n',
#  '\n',
#  '5. Calls upon the member states to set up supportive agencies and organizations to help victims of hate crime through ways such as but not limited to:\n',
#  'a. rehabilitation centers for the victims of hate crime to recuperate after an attack\n',
#  'b. campaigns to raise funds for hate crime victims;\n',
#  '6. Further recommends that an international summit on hate crime be held discussing subjects such as but not limited to:\n',
#  'a. an internationally accepted definition of hate crime\n',
#  'b. international standards for the handling of hate crime, such as but not limited to:\n',
#  'i. punishment for hate crime\n',
#  'ii. prosecution of those who commit hate crimes\n',
#  'iii. protection of the victims of hate crimes;\n',
#  '7. Emphasizes the importance of informing the public on the issue of hate crimes through ways such as but not limited to:\n',
#  'a. using social media to decrease the stigma surrounding hate crimes and those who are victims of hate crime\n',
#  'b. educating civilians on hate crimes through means as but not limited to:\n',
#  'i. news articles\n',
#  'ii. speeches made by Government officials on the issue of hate crimes\n',
#  'iii. educational programs in schools informing young people on the subject of hate crime.\n',
#  '\n',
#  'FORUM: Human Rights Council \n',
# ...
#  'i. creating government schools with free/cheap education \n',
#  'ii. creating scholarships for public and private schools based on academic, physical and artistic achievement \n',
#  'iii. promoting the education of both genders\n',
#  'iv. promoting education across minorities\n',
#  'c. creating infrastructure in ways such as but not limited to:\n',
#  'i. developing sustainable building foundations throughout larger buildings\n',
#  'ii. providing more accessible public transportation throughout all major and minor cities\n',
#  'iii. developing more frequent places for work, healthcare and real-estate throughout rural areas in the nation\n',
#  'd. distributing wealth more evenly by consulting NGOs and companies associated to the global south to minimize transactional and distribution cost of secondary production, instead transitioning from primary production straight to treasury production, as many countries of the global south rely largely on primary productions; \n',
#  '5. Recommends all nations currently in conflict to set up relationships and to create allies in order to promote goals, such as but not limited to;\n',
#  'a. peace, or a period with a lack of conflict in such ways, but not limited to\n',
#  'i. creating trade alliances between nations with conflict\n',
#  'ii. creating monetary incentives for these nations \n',
#  'iii. giving more power in the UN for a limited period of time\n',
#  'iv. establishing an interdependence\n',
#  'b. conservation of resources to improve the development of economy and relations with other nations, such as but not limited to:\n',
#  'i. recommending governments to conserve resources to use for trade \n',
#  'ii. limiting the distribution of resources to citizens.\n',
#  '\n',
#  '\n',
#  'FORUM: World Health Organization\n',
#  'QUESTION OF: Technological development for medical means, such as that of virtual reality in therapy and rehabilitation.\n',
#  'SUBMITTED BY: Cuba\n',
#  '\n',
#  'THE WORLD HEALTH ORGANIZATION,\n',
#  'Aware of the negative social effects that virtual reality may bring,\n',
#  'Having considered both the positive and negative effects on people’s minds virtual reality may bring,\n',
#  '1. Requests technology companies finance long term research into all possible problems with virtual reality, for instance, social isolation, that may lead to security problems;\n',
#  '2. Affirms that abusing virtual reality may cause social isolation, depression, and many other problems that may result in a drug overdose;\n',
#  '3. Emphasizes that there are alternatives to virtual reality that are not as expensive or resource heavy as virtual realit;\n',
#  '4. Further reminds that many nations lack the resources to both implement virtual reality technology and to combat the negative impact that virtual reality may bring.\n',
#  '5. Invites companies to invest in developing countries so that they will have the resources to implement and manage virtual reality technology;\n',
#  '6. Hopes that organizations can provide us with information on how to prevent the negative effects virtual realities could bring.\n',
#  'FORUM: General Assembly\n',
#  'QUESTION OF: Utilizing modern technology to make equal access and inclusion of persons with disabilities in urban development\n',
#  'MAIN SUBMITTED BY: Ethiopia\n',
#  '\n',
#  '\n',
#  'THE UNITED NATIONS GENERAL ASSEMBLY,\n',
#  '\n',
#  'Bearing in mind that 15% of the world’s population has some form of disability that restricts daily life activities,\n',
#  '\n',
#  'Fully aware that people with disability is more vulnerable to discrimination and is subject to unfair treatment,\n',
#  '\n',
#  'Fully believing the renovation of old buildings to bear the disabled in mind is necessary to benefit the disabled, \n',
#  '\n',
#  'Recognizing that organizations such as the International Labour Organization (ILO) are promoting equal opportunities for everyone and advocating for the rights of the disabled,\n',
#  '\n',
#  '1. Calls upon the effective implementation and enforcement of existing disability laws and policies to provide for equal employment and training opportunities to contribute to the reduction of poverty and economic inclusion of people with disabilities in ways such as but not limited to:\n',
#  'a. implementation of vocational training and rehabilitation programmes to the disabled with assistance from the ILO in ways such as:\n',
#  'i. increase the number of people with disabilities taking training courses in colleges,\n',
#  'b. changing attitudes and motivating the public;\n',
#  '\n',
#  '2. Encourages the renovation and creation of buildings that bears the disabled in mind and improving public transportation in ways such as but not limited to:\n',
#  'a. advocating the Ethiopian government to construct ramps near staircases,\n',
#  'b. creation of a widespread metro bus and subway system to expand accessibility of public transportation;\n',
#  '\n',
#  '3. Urges to spread awareness and to support social inclusion for people with disabilities in ways such as but not limited to:\n',
#  'a. spreading awareness of disability exclusion through the use of television and/or social media,\n',
#  'b. donating to causes and organization that supports disability inclusion in ways such as:\n',
#  'i. teaming up with the International Committee of the Red Cross (ICRC) and Ethiopian Basketball Federation (EBF) to promote social inclusion of people with disabilities by involving them in a wheelchair basketball game;\n',
#  '\n',
#  '4. Hopes to empower people with disabilities and their organizations to be self-reliant in ways such as but not limited to:\n',
#  'a. creating job opportunities for people with disabilities to generate their own income,\n',
#  'b. increasing inclusion of people with disabilities within their community;\n',
#  '\n',
#  '5. Asks member states and United Nations countries to share knowledge of and/or actively pursue the development of modern technology that could potentially ease the lives of people with disabilities in ways such as:\n',
#  'a. giving or sharing Ethiopian government technology that is not made available to them,\n',
#  'b. assisting companies or organizations in Ethiopia that aims to help with social inclusion of people with disabilities.\n',
#  'FORUM: \n',
#  'QUESTION: Utilizing Modern Technology to Make Equal Access and Inclusion of Persons with Disabilities in Urban Development\n',
#  'MAIN SUBMITTED BY: United States  \n',
#  '\n',
#  'THE UNITED NATION GENERAL ASSEMBLY,     \n',
#  'Deeply concerned that the fact in United States, approximately 36.3 million Americans experience one or more disabilities, which is equivalent to one out of every eight Americans according from U.S. Census Bureau (2011). Also, people with disabilities travel less frequently and rely on public transportation more than the general population (U.S. General Accounting Office, 2003),   \n',
#  'Aware of that the technology system has developed well in United States following the passage of the Americans With Disabilities Act (ADA) in 1990, \n',
#  'Noting with that the stakeholders DESA and UN-Habitat have also organized DESA Forums on accessible and disability-inclusive urban development in New York, June 2016 published analytical research and guidance on accessibility and development, and have facilitated and supported intergovernmental processes and bodies to advance accessibility, \n',
#  'Approving the Americans with Disabilities Act (1990),    \n',
#  ' \n',
#  '1. Encourages every persons with disabilities to live independently in United States or even other countries and participate fully in all aspects of life, States Parties shall take appropriate measures such as but not limited to:\n',
#  'a. Setting the complete nformation communication, technolog and system and other facilities,\n',
#  'b. Opening the services or providing to the public, both in urban and in rural areas:\n',
#  'i. Buildings, roads, transportation and other indoor and outdoor facilities, \n',
#  'ii. Schools, housing, medical facilities and workplaces,\n',
#  'iii. Information, communications and electronic services and emergency services;\n',
#  '2. Recommends state to cooperate with United States to develop some research to protect the people with disabilities to protect the person with disabilities and make equal access in the urban environment such as but not limited to: \n',
#  'a. Cooperating with United Nations High-level Meeting on Disability and Development  and its action-oriented Outcome Document (A/RES/68/3) stressed the importance of ensuring,\n',
#  'b. As of 15 July 2016, United States worked with 165 States and European Union party to the Convention which include:\n',
#  'i. Convention on the Rights of Persons with Disabilities, Article 4 ? General obligations,\n',
#  'ii. Accessibility for and inclusion of persons with disabilities in all aspects of development, and recommended giving due consideration to all persons with disabilities, Article 9? General obligations,\n',
#  'c. States Parties shall also take appropriate measures such as but not limited to:\n',
#  'i. To develop, promulgate and monitor the implementation of minimum standards and guidelines for the accessibility of facilities and services open or provided to the public,\n',
#  'ii. To ensure that private entities that offer facilities and services which are open or provided to the public take into account all aspects of accessibility for persons with disabilities,\n',
#  'iii. To provide training for stakeholders on accessibility issues facing persons with disabilities,\n',
#  'iv. To provide forms of live assistance and intermediaries, including guides, readers and professional sign language interpreters, to facilitate  accessibility to buildings and other facilities open to the public;\n',
#  '3. Emphasizing the importance of protecting the inclusion of person with disabilities by using modern technology in the urban environment such as but not limited to: \n',
#  'a. Access pioneered the housing model of integrating persons with psychiatric disabilities in low-income families,\n',
#  'b. Encourage other countries to support 2030 Agenda for Sustainable Development. Disability is specifically referenced in seven targets of the Sustainable Development Goals (SDGs) in the 2030 Agenda, \n',
#  'c. Subject to periodic amendment of the person with disabilities to reflect changing circumstances and conditions:\n',
#  'i. Prohibits discrimination on the basis of disability in programs conducted by Federal agencies, in programs receiving Federal financial assistance,\n',
#  'ii. Promote accessibility for people with disabilities in 1973, with an initial mandate to ensure access to federally funded facilities by using modern technology;\n',
#  '4. Calls upon member states to create a society in which the wellbeing of equal access and inclusion of person with disabilities by using modern technology is ensured through ways such as but not limited to:\n',
#  'a. Cooperating with interested governments, civil society organizations and professional societies, with technical assistance of the United Nations Economic and Social Commission for Asia and the Pacific during 1993 to 2002:\n',
#  'i. Starting pilot action in accessible urban planning and pedestrian movement at national and local levels was undertaken during the first Asian,\n',
#  'b. Promoting this concept to some poor countries such as Beirut, Republic of Lebanon by using accessible planning and redevelopment of Beirut which include:\n',
#  'i. Measures to influence planning, design and reconstruction of a barrier-free Beirut Central District,\n',
#  'ii. Using technical documentation on accessibility concepts and standards, and suggested instruments to apply;\n',
#  '5. Requests all member states to raise awareness to the international level through:\n',
#  'a. Utilizing social media or website to garnered many people to promote the every person with disabilities can get equal access and inclusion,\n',
#  'b. Through the international organization (ESCAP), United Nations Centre for Human Settlements (HABITAT), US and other countries jointly issue a series of publications of this issue and planning and design principles, technical guidelines and implementation strategies. \n',
#  'Forum: General Assembly 6 (GA6)\n',
#  'Issue: (801) Responsibilities of States for International Wrongful Acts\n',
#  '\n',
#  'THE GENERAL ASSEMBLY 6, \n',
#  '\n',
#  'Reminding the importance of being internationally responsible, as well as the amount of responsibility and punishments for violating the international law,\n',
#  '\n',
#  'Recognizing the benefits of nations being internationally well-behaved and the construction of an universal international law,\n',
#  '\n',
#  'Alarmed by the fact that the lacking of international consensus regarding to the issue have destroyed both the social and economic bonds of nations, and have killed and wounded millions in various conflicts while leaving the same internally displaced or as refugees,\n',
#  '\n',
#  'Bearing in mind that there are 51 nations that have signed the treaty on the prohibition of nuclear weapons in the 72nd session of the United Nations General Assembly held in New York City, this is a positive step towards nuclear disarmament,\n',
#  '\n',
#  '\n',
#  '1. Calls upon nations to create a priority list when considering the acceptance of refugees seeking long-term asylum based on terms such as but not limited to:\n',
#  'a. The vocational abilities and socioeconomic status of refugees in order to ensure that migrants can properly adjust within the employment field of the host nation\n',
#  'b. The geographical positioning of the country of origin in order to prevent cultural assimilation as a result of large influx of foreign asylum seekers\n',
#  'c. The economic and diplomatic relations between the nation of refugee and the nation from which asylees escape from\n',
#  'd. Reserves the right to reject applicants based on such terms and instead adopting alternative methods of assistance such as but not limited to the allocation of:\n',
#  'i. Military resources\n',
#  'ii. Certified volunteers to assist in areas of conflict\n',
#  'iii. Donation of food and other resources required for improvement of infrastructure;\n',
#  '\n',
#  '2. Further recommends the establishment of an international standard system for regulating the influx of refugees through ways such as but not limited to:\n',
#  'a. Determining each refugee’s abilities in ways such as but not limited to:\n',
#  'i. Background checks regarding their educational and vocational qualification levels\n',
#  'ii. Standardized testing of language abilities\n',
#  'b. establishing a time frame decided by each state in which they must apply for approval for permanent residency and actual residency\n',
#  'c. Making refugees sign immigration contracts that tie their terms of stay with the contribution they make to the new society\n',
#  'd. Rejecting any asylum approvals without a well-founded fear of returning to their home country;\n',
#  '\n',
#  '3. Encourages all nations to find solutions to the issue of the regulation of nuclear weapons, through ways such as but not limited to creating strict and detailed laws controlling the use of nuclear weapons and violent forces;\n',
#  '\n',
#  '4. Requests each member state to strengthen the United Nations Peacebuilding Commission (PBC) in order to completely assess the efficiency and necessity of peacekeeping tasks by ways such as but not limited to:\n',
#  'a. increase its professional human resources such as but not limited to professionals with expertise in subjects such as sustainable development research and architect \n',
#  'b. cooperating with NGOs for the purpose of lowering the cost of essential supplies\n',
#  '\n',
#  '5. Strongly urges the nations to take the responsibilities of illegal or wrongful behaviours by ways such as but not limited to:\n',
#  'a. public press conference to express their apologies\n',
#  'b. Having peace talks and creating agreements regarding to the conflicts between nations in order to ensure the obligation on wrongful act of each states; \n',
#  ...]

# %%
doc = ' '.join(lists)

# %%
tokenized = nltk.word_tokenize(doc)

# %%
nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if(pos[:2] == 'NN')]
print (nouns)
# Out:
# ['FORUM', 'World', 'Health', 'Organization', 'QUESTION', 'Mental', 'Health', 'Refugees', 'Migrants', 'MAIN-SUBMITTER', 'CO-SUBMITTERS', 'Iran', 'Turkmenistan', 'Philippines', 'Yemen', 'Ireland', 'UK', 'THE', 'WORLD', 'HEALTH', 'ORGANIZATION', 'Bearing', 'mind', 'Universal', 'Health', 'Coverage', 'UHC', 'individuals', 'communities', 'health', 'services', 'hardship', 'United', 'Nations', 'General', 'Assembly', 'UNGA', 'convention', 'status', 'refugees', 'July', 'nations', 'resolution', 'New', 'York', 'Declaration', 'Refugees', 'Migrants', 'A/RES/71/1', 'rights', 'refugees', 'migrants', 'Global', 'Action', 'Plan', 'Health', 'Refugees', 'Migrants', 'October', 'framework', 'priorities', 'principles', 'health', 'refugees', 'migrants', 'rights', 'individuals', 'country', 'rights', 'freedoms', 'forth', 'Universal', 'Declaration', 'Human', 'Rights', 'rights', 'belong', 'people', 'migrants', 'refugees', 'non-nationals', 'fact', 'migrants', 'world', 'today', 'migrants', 'migrants', 'world', 'population', 'Requests', 'nations', 'NGOs', 'UNHCR', 'United', 'Nations', 'High', 'Commissioner', 'Refugees', 'refugees', 'ways', 'a.', 'Educate', 'Child', 'EAC', 'program', 'children', 'OOSC', 'education', 'b.', 'Education', 'AE', 'programs', 'access', 'education', 'children', 'adolescents', 'amounts', 'c.', 'quality', 'education', 'order', 'future', 'fears', 'insecure', 'future', 'deterioration', '’', 'health', 'capacity', 'i.', 'provision', 'books', 'papers', 'MEDCs', 'ii', 'creation', 'education', 'programs', 'education', 'children', 'order', 'literacy', 'skills', 'education', 'adults', 'skills', 'jobs', 'towards', 'economy', 'repatriation', 'Encourages', 'nations', 'awareness', 'Countries', 'MEDCs', 'ways', 'speakers', 'i.', 'funds', 'NGOs', 'countries', 'importance', 'health', 'refugees', 'migrants', 'areas', 'people', 'organizations', 'Doctors', 'Borders', 'organizations', 'i.', 'advance', 'research', 'health', 'refugees', 'migrants', 'therapists', 'counselors', 'camps', 'areas', 'migrants', 'people', 'health', 'issues', 'awareness', 'people', 'refugees', 'countries', 'refugees', 'trust', 'comfort', 'host', 'country', 'advertisements', 'i.', 'posters', 'advertisements', 'television', 'encourages', 'NGOs', 'charge', 'refugees', 'migrants', 'services', 'refugees', 'migrants', 'health', 'issues', 'country', 'ways', 'sessions', 'helpers', 'services', 'i.', 'supplies', 'doctors', 'NGOs', 'ii', 'incentives', 'services', 'iii', 'helpers', 'services', 'support', 'groups', 'part', 'services', 'ways', 'i.', 'patients', 'type', 'health', 'issue', 'patient', 'talk', 'struggles', 'ideas', 'ways', 'struggles', 'governments', 'health', 'services', 'refugees', 'asylum-seekers', 'ways', 'i.', 'portion', 'tax', 'payments', 'health', 'checkups', 'hospitals', 'clinics', 'LEDCs', 'money', 'healthcare', 'needs', 'health', 'care', 'doctor/bed', 'ratio', 'population', 'LEDCs', 'creation', 'programmes', 'charge', 'education', 'ways', 'a.', 'refugees', 'migrants', 'health', 'issues', 'school', 'others', 'knowledge', 'ways', 'i.', 'Teachers', 'Borders', 'support', 'refugees', 'migrants', 'education', 'ii', 'knowledge', 'refugees', 'migrants', 'job', 'b.', 'activities', 'school', 'day', 'order', 'interests', 'i.', 'funds', 'programme', 'support', 'donations', 'MEDCs', 'ii', 'activities', 'sports', 'music', 'others', 'training', 'refugees', 'jobs', 'i.', 'counselors', 'programmes', 'jobs', 'refugees', 'ii', 'training', 'd.', 'refugees', 'migrants', 'language', 'host', 'countries', 'order', 'job', 'ways', 'people', 'language', 'refugees', 'migrants', '’', 'language', 'host', 'country', 'ii', 'MEDCs', 'textbooks', 'learning', 'language', 'Calls', 'creation', 'organizations', 'charge', 'refugees', 'migrants', 'services', 'migrants', 'refugees', 'appointments', 'doctors', 'a.', 'language', 'host', 'country', 'i.', 'communication', 'counselors', 'refugees', 'language', 'ii', 'accuracy', 'counselors', 'tips', 'refugee/migrants', 'transportation', 'service', 'charge', 'refugees/ ...

# %%
count = Counter(nouns)

# %%
words = dict(count.most_common())

# %%
# 가장 많이 등장하는 단어를 추려보자. 얏 그런데 ii가 많네. 이건 선언문이라 그러함. 이런 단어는 모두 전처리에서 삭제할것!!!
words
# Out:
# {'ii': 237,
#  'nations': 218,
#  'i.': 213,
#  'ways': 195,
#  'United': 159,
#  'countries': 137,
#  'people': 133,
#  '’': 116,
#  'b': 115,
#  'member': 105,
#  'order': 104,
#  'Nations': 103,
#  'a.': 99,
#  'iii': 97,
#  'weapons': 96,
#  'organizations': 92,
#  'government': 91,
#  'states': 89,
#  'education': 73,
#  'disabilities': 73,
#  'crimes': 71,
#  'UN': 68,
#  'nation': 67,
#  'b.': 64,
#  'development': 64,
#  'information': 63,
#  'NGOs': 62,
#  'citizens': 61,
#  ']': 61,
#  'i': 60,
#  'Council': 58,
#  'children': 57,
#  'awareness': 54,
#  'governments': 54,
#  'LEDCs': 54,
#  'country': 53,
#  'measures': 51,
#  'rights': 50,
#  'programs': 50,
#  'International': 50,
#  'States': 49,
#  'security': 48,
#  'world': 47,
#  'means': 47,
#  'health': 46,
#  'refugees': 46,
#  'money': 46,
#  'General': 45,
#  'use': 45,
#  'crime': 45,
#  'areas': 44,
#  'exploitation': 44,
#  'issue': 42,
#  's': 42,
#  'system': 42,
#  'Assembly': 41,
#  'support': 41,
#  'schools': 41,
#  'hate': 41,
#  'issues': 40,
#  'facilities': 40,
#  'Security': 40,
#  'BY': 39,
#  'THE': 38,
#  'c.': 38,
#  'funds': 38,
#  'energy': 38,
#  'corruption': 38,
#  'laws': 38,
#  'victims': 38,
#  'youth': 38,
#  'child': 38,
#  'Nuclear': 38,
#  'workers': 37,
#  'abuse': 37,
#  'Calls': 36,
#  'Development': 36,
#  'media': 36,
#  'students': 36,
#  'c': 36,
#  'policies': 36,
#  'community': 36,
#  'systems': 35,
#  'cooperation': 35,
#  'trafficking': 35,
#  'Requests': 34,
#  'infrastructure': 34,
#  'QUESTION': 33,
#  'actions': 33,
#  'Korea': 33,
#  'fact': 32,
#  'access': 32,
#  'Encourages': 32,
#  'iv': 32,
#  'water': 32,
#  'resources': 32,
#  'law': 32,
#  '[': 32,
#  'threat': 32,
#  'research': 31,
#  'activities': 31,
#  'opportunities': 31,
#  'state': 31,
#  'methods': 31,
#  'services': 30,
#  'creation': 30,
#  'training': 30,
#  'number': 30,
#  'assistance': 30,
#  'violence': 30,
#  'trade': 30,
#  'MEDCs': 29,
#  'transportation': 29,
#  'companies': 29,
#  'technology': 29,
#  'DEL': 29,
#  'FORUM': 28,
#  'groups': 28,
#  'job': 28,
#  'power': 28,
#  'Japan': 28,
#  'individuals': 27,
#  'officials': 27,
#  'environment': 27,
#  'China': 27,
#  'importance': 26,
#  'projects': 26,
#  'campaigns': 26,
#  'society': 26,
#  '%': 26,
#  'bomb': 26,
#  'fission': 26,
#  'Organization': 25,
#  'migrants': 25,
#  'members': 25,
#  'Republic': 25,
#  'reports': 25,
#  'purpose': 24,
#  'Rights': 23,
#  'Recommends': 23,
#  'Convention': 23,
#  'slums': 23,
#  'carbon': 23,
#  'World': 22,
#  'mind': 22,
#  'jobs': 22,
#  'school': 22,
#  'organization': 22,
#  'time': 22,
#  'years': 22,
#  'veto': 22,
#  'threats': 22,
#  'data': 22,
#  'https': 22,
#  'program': 21,
#  'conference': 21,
#  'aid': 21,
#  'purposes': 21,
#  'poverty': 21,
#  'MAIN': 21,
#  'conditions': 21,
#  'SUBMITTED': 21,
#  'process': 21,
#  'Urges': 21,
#  'Kingdom': 21,
#  'amount': 21,
#  'cases': 21,
#  'communities': 20,
#  'South': 20,
#  'd': 20,
#  'public': 20,
#  'force': 20,
#  'Committee': 20,
#  'report': 20,
#  'experts': 20,
#  'efforts': 20,
#  'concern': 20,
#  'peace': 20,
#  'funding': 20,
#  'Cooperation': 19,
#  'reasons': 19,
#  'rate': 19,
#  'effects': 19,
#  'agencies': 19,
#  'solutions': 19,
#  'Fund': 19,
#  '”': 19,
#  'space': 19,
#  'treaty': 19,
#  'arms': 19,
#  'sources': 19,
#  'usage': 19,
#  'status': 18,
#  'Human': 18,
#  'population': 18,
#  'OBOR': 18,
#  'protection': 18,
#  'regulations': 18,
#  'materials': 18,
#  'spread': 18,
#  'income': 18,
#  'women': 18,
#  'North': 18,
#  'UK': 17,
#  'economy': 17,
#  'events': 17,
#  'treaties': 17,
#  'treatment': 17,
#  'action': 17,
#  'work': 17,
#  'initiative': 17,
#  'regions': 17,
#  'Deeply': 17,
#  'civilians': 17,
#  'region': 17,
#  'Union': 17,
#  'conflicts': 17,
#  'mass': 17,
#  'bombs': 17,
#  'knowledge': 16,
#  'Social': 16,
#  'food': 16,
#  'form': 16,
#  'crisis': 16,
#  'policy': 16,
#  'Office': 16,
#  'centers': 16,
#  'safety': 16,
#  'need': 16,
#  'drug': 16,
#  'weapon': 16,
#  'Treaty': 16,
#  'Project': 16,
#  'DPRK': 16,
#  'Yemen': 15,
#  'Bearing': 15,
#  'resolution': 15,
#  'Global': 15,
#  'prevention': 15,
#  'planning': 15,
#  'GENERAL': 15,
#  'ASSEMBLY': 15,
#  'equality': 15,
#  'disarmament': 15,
#  'devices': 15,
#  'debt': 15,
#  'Health': 14,
#  'quality': 14,
#  'supplies': 14,
#  'incentives': 14,
#  'd.': 14,
#  'help': 14,
#  'goals': 14,
#  'teachers': 14,
#  'living': 14,
#  'change': 14,
#  'lives': 14,
#  'disability': 14,
#  'persons': 14,
#  'representatives': 14,
#  'institutions': 14,
#  'legislation': 14,
#  'statistics': 14,
#  'parties': 14,
#  'lack': 14,
#  'Bulgaria': 14,
#  'COVID-19': 14,
#  'proliferation': 14,
#  'future': 13,
#  'Countries': 13,
#  'advertisements': 13,
#  'part': 13,
#  'healthcare': 13,
#  'language': 13,
#  'service': 13,
#  'Aware': 13,
#  'situation': 13,
#  'places': 13,
#  'Fully': 13,
#  'cities': 13,
#  'standards': 13,
#  'discrimination': 13,
#  'building': 13,
#  'gender': 13,
#  'consequences': 13,
#  'Crime': 13,
#  'UNODC': 13,
#  'acts': 13,
#  'Weapons': 13,
#  'climate': 13,
#  'area': 13,
#  'settlements': 13,
#  'ability': 12,
#  'Economic': 12,
#  'COUNCIL': 12,
#  'war': 12,
#  'sanitation': 12,
#  'plans': 12,
#  'problems': 12,
#  'Resolution': 12,
#  'employment': 12,
#  'person': 12,
#  'plan': 12,
#  'volunteers': 12,
#  'police': 12,
#  'year': 12,
#  'conflict': 12,
#  'transparency': 12,
#  'progress': 12,
#  'inclusion': 12,
#  'uses': 12,
#  'reaction': 12,
#  'emissions': 12,
#  'wage': 12,
#  'Southeast': 12,
#  'farmers': 12,
#  'explosions': 12,
#  'President': 12,
#  'Manhattan': 12,
#  'CO-SUBMITTERS': 11,
#  'Child': 11,
#  'towards': 11,
#  'posters': 11,
#  'tax': 11,
#  'communication': 11,
#  'disorders': 11,
#  'fund': 11,
#  'National': 11,
#  'UNITED': 11,
#  'industries': 11,
#  'share': 11,
#  'field': 11,
#  'Sustainable': 11,
#  'trading': 11,
#  'life': 11,
#  'level': 11,
#  'meeting': 11,
#  'inequality': 11,
#  'Trade': 11,
#  'drugs': 11,
#  'Kim': 11,
#  'sectors': 11,
#  'Refugees': 10,
#  'skills': 10,
#  'hospitals': 10,
#  'refugee': 10,
#  'export': 10,
#  'source': 10,
#  'disasters': 10,
#  'priority': 10,
#  'COMMITTEE': 10,
#  'NATIONS': 10,
#  'topics': 10,
#  'meetings': 10,
#  'monitoring': 10,
#  'account': 10,
#  'Africa': 10,
#  'project': 10,
#  'concerns': 10,
#  'generation': 10,
#  'UNICEF': 10,
#  'resolutions': 10,
#  'risk': 10,
#  'Germany': 10,
#  'seats': 10,
#  'benefits': 10,
#  'wildlife': 10,
#  'term': 10,
#  'enforcement': 10,
#  'accessibility': 10,
#  'June': 10,
#  'societies': 10,
#  'levels': 10,
#  'responsibility': 10,
#  'terms': 10,
#  'attacks': 10,
#  'rates': 10,
#  'UNSC': 10,
#  'IGOs': 10,
#  'corporations': 10,
#  'poaching': 10,
#  'fusion': 10,
#  'plutonium': 10,
#  'framework': 9,
#  'amounts': 9,
#  'needs': 9,
#  'care': 9,
#  'authorities': 9,
#  'personnel': 9,
#  'relations': 9,
#  'supply': 9,
#  'Programme': 9,
#  'aspects': 9,
#  'professionals': 9,
#  'Belt': 9,
#  'Road': 9,
#  'People': 9,
#  'Europe': 9,
#  'labor': 9,
#  'way': 9,
#  'punishment': 9,
#  'speeches': 9,
#  'topic': 9,
#  'concept': 9,
#  'cyber': 9,
#  'incidents': 9,
#  'implementation': 9,
#  'summit': 9,
#  'Children': 9,
#  'talks': 9,
#  '“': 9,
#  'types': 9,
#  'Women': 9,
#  'representation': 9,
#  'position': 9,
#  'destruction': 9,
#  'explosives': 9,
#  'reality': 9,
#  'European': 9,
#  'guidelines': 9,
#  'abilities': 9,
#  'place': 9,
#  'class': 9,
#  'procedures': 9,
#  'hand': 9,
#  'men': 9,
#  'problem': 9,
#  'analysis': 9,
#  'workplace': 9,
#  'anti-corruption': 9,
#  'material': 9,
#  'Wildlife': 9,
#  'tests': 9,
#  'High': 8,
#  'Commissioner': 8,
#  'television': 8,
#  'doctors': 8,
#  'ideas': 8,
#  'relationship': 8,
#  'Organizations': 8,
#  'tourism': 8,
#  'disease': 8,
#  'growth': 8,
#  'city': 8,
#  'design': 8,
#  'things': 8,
#  'approach': 8,
#  'infrastructures': 8,
#  'idea': 8,
#  'age': 8,
#  'agreements': 8,
#  'One': 8,
#  'construction': 8,
#  'technologies': 8,
#  'cost': 8,
#  'solution': 8,
#  'impact': 8,
#  'sites': 8,
#  'punishments': 8,
#  'subjects': 8,
#  'rehabilitation': 8,
#  'Agenda': 8,
#  'forms': 8,
#  'November': 8,
#  'circumstances': 8,
#  'factories': 8,
#  'goal': 8,
#  'P5': 8,
#  'routes': 8,
#  'practices': 8,
#  'interest': 8,
#  'Law': 8,
#  'welfare': 8,
#  'distribution': 8,
#  'asylum': 8,
#  'locations': 8,
#  'Energy': 8,
#  'severity': 8,
#  'damage': 8,
#  'Peaceful': 8,
#  'Space': 8,
#  'chain': 8,
#  'investigation': 8,
#  'debates': 8,
#  'weaponry': 8,
#  'Cyber': 8,
#  'scientists': 8,
#  'Man': 8,
#  'missile': 8,
#  'ECPAT': 8,
#  'New': 7,
#  'October': 7,
#  'principles': 7,
#  'Education': 7,
#  'adults': 7,
#  'host': 7,
#  'type': 7,
#  'stability': 7,
#  'Developed': 7,
#  'expansion': 7,
#  'Main': 7,
#  'SOCIAL': 7,
#  'set': 7,
#  'goods': 7,
#  'advice': 7,
#  'changes': 7,
#  'shelter': 7,
#  'improvements': 7,
#  'sector': 7,
#  'necessity': 7,
#  'spending': 7,
#  'Disabilities': 7,
#  'recruitment': 7,
#  'strategies': 7,
#  '‘': 7,
#  'Association': 7,
#  'majority': 7,
#  'September': 7,
#  'Asia': 7,
#  'harm': 7,
#  't': 7,
#  'control': 7,
#  'internet': 7,
#  'unemployment': 7,
#  'Measures': 7,
#  'promotion': 7,
#  'increase': 7,
#  'seminars': 7,
#  'effectiveness': 7,
#  'sex': 7,
#  'committee': 7,
#  'Peru': 7,
#  'Alarmed': 7,
#  'situations': 7,
#  'parents': 7,
#  'case': 7,
#  'background': 7,
#  'Protocol': 7,
#  'causes': 7,
#  'fines': 7,
#  'offenders': 7,
#  'Framework': 7,
#  'Bank': 7,
#  'rules': 7,
#  'conferences': 7,
#  'manufacturing': 7,
#  'obligations': 7,
#  'Commission': 7,
#  'efficiency': 7,
#  'responsibilities': 7,
#  'act': 7,
#  'humanity': 7,
#  'respect': 7,
#  'Agreed': 7,
#  'ref': 7,
#  'Sweden': 7,
#  'Pakistan': 7,
#  'EDIT': 7,
#  'War': 7,
#  'NEO': 7,
#  'response': 7,
#  'medication': 7,
#  'Kyoto': 7,
#  'pollution': 7,
#  'coalition': 7,
#  'terrorism': 7,
#  'cybersecurity': 7,
#  'matters': 7,
#  'Saudi': 7,
#  'Arabia': 7,
#  'penalties': 7,
#  'Yemeni': 7,
#  'risks': 7,
#  'focus': 7,
#  'relocation': 7,
#  'Declaration': 6,
#  'capacity': 6,
#  'literacy': 6,
#  'counselors': 6,
#  'sessions': 6,
#  'donations': 6,
#  'authority': 6,
#  'requests': 6,
#  'Economically': 6,
#  'South-South': 6,
#  'ECONOMIC': 6,
#  'AND': 6,
#  'south': 6,
#  'exchange': 6,
#  'Urban': 6,
#  'leaders': 6,
#  'question': 6,
#  'create': 6,
#  'platforms': 6,
#  'opinions': 6,
#  'classes': 6,
#  'role': 6,
#  'II': 6,
#  'Research': 6,
#  'therapy': 6,
#  'environments': 6,
#  'ones': 6,
#  'request': 6,
#  'Initiative': 6,
#  'business': 6,
#  'opportunity': 6,
#  'effort': 6,
#  'networks': 6,
#  'Network': 6,
#  'radio': 6,
#  'Sexual': 6,
#  'courses': 6,
#  'Emergency': 6,
#  'family': 6,
#  'emergency': 6,
#  'instances': 6,
#  'families': 6,
#  'right': 6,
#  'addition': 6,
#  'criteria': 6,
#  'Question': 6,
#  'theft': 6,
#  'initiatives': 6,
#  'Drugs': 6,
#  'Disarmament': 6,
#  'products': 6,
#  'participation': 6,
#  'movements': 6,
#  'America': 6,
#  'December': 6,
#  'taxes': 6,
#  'ILO': 6,
#  'Americans': 6,
#  'housing': 6,
#  'Goals': 6,
#  'testing': 6,
#  'TV': 6,
#  'lead': 6,
#  'engagement': 6,
#  'contamination': 6,
#  'examination': 6,
#  'violations': 6,
#  'Outer': 6,
#  'attention': 6,
#  'identification': 6,
#  'Change': 6,
#  'EU': 6,
#  'resilience': 6,
#  'mediums': 6,
#  'mechanisms': 6,
#  'quo': 6,
#  'consent': 6,
#  'voluntourism': 6,
#  'UNDP': 6,
#  'Against': 6,
#  'Kuwait': 6,
#  'effect': 6,
#  'populace': 6,
#  'danger': 6,
#  'fields': 6,
#  'Status': 6,
#  'nature': 6,
#  'intention': 6,
#  'headquarters': 6,
#  'entrepreneurs': 6,
#  'device': 6,
#  'reactions': 6,
#  'fallout': 6,
#  'arsenals': 6,
#  'Soviet': 6,
#  'non-proliferation': 6,
#  'Non-Proliferation': 6,
#  'NPT': 6,
#  'uranium': 6,
#  'Szil': 6,
#  'rd': 6,
#  'Roosevelt': 6,
#  'University': 6,
#  'Fat': 6,
#  'Hiroshima': 6,
#  'Nagasaki': 6,
#  'elimination': 6,
#  'Resolutions': 6,
#  'sanctions': 6,
#  'Oct.': 6,
#  'Universal': 5,
#  'Action': 5,
#  'camps': 5,
#  'charge': 5,
#  'patients': 5,
#  'others': 5,
#  'day': 5,
#  'CO-SUBMITTED': 5,
#  'India': 5,
#  'Belarus': 5,
#  'import': 5,
#  'news': 5,
#  'Habitat': 5,
#  'HUMAN': 5,
#  'improvement': 5,
#  'condition': 5,
#  'months': 5,
#  'relationships': 5,
#  'impacts': 5,
#  'surveys': 5,
#  'spaces': 5,
#  'success': 5,
#  'Less': 5,
#  'March': 5,
#  'Scientific': 5,
#  'Cultural': 5,
#  'videos': 5,
#  'challenges': 5,
#  'workforce': 5,
#  'percentage': 5,
#  'everyone': 5,
#  'debris': 5,
#  'possibility': 5,
#  'e': 5,
#  'stakeholders': 5,
#  'bias': 5,
#  'details': 5,
#  'group': 5,
#  'experience': 5,
#  'content': 5,
#  'assembly': 5,
#  'party': 5,
#  'speech': 5,
#  'understanding': 5,
#  'steps': 5,
#  'Affairs': 5,
#  'seat': 5,
#  'checks': 5,
#  'wages': 5,
#  'targets': 5,
#  'management': 5,
#  'Nation': 5,
#  'gains': 5,
#  'border': 5,
#  'Vietnam': 5,
#  'consideration': 5,
#  'processes': 5,
#  'branch': 5,
#  'charities': 5,
#  'production': 5,
#  'conservation': 5,
#  'bodies': 5,
#  'workplaces': 5,
#  'Information': 5,
#  'Centre': 5,
#  'allocation': 5,
#  'forces': 5,
#  'selling': 5,
#  'PMSC': 5,
#  'Atomic': 5,
#  'Agency': 5,
#  'Tabled': 5,
#  'Arms': 5,
#  'body': 5,
#  'Advisory': 5,
#  'filters': 5,
#  'aim': 5,
#  'April': 5,
#  'ENVIRONMENTAL': 5,
#  'COMMISSION': 5,
#  'Climate': 5,
#  'PSAs': 5,
#  'coal': 5,
#  'cause': 5,
#  'industry': 5,
#  'borders': 5,
#  'frameworks': 5,
#  'network': 5,
#  'dangers': 5,
#  'stockpiles': 5,
#  'end': 5,
#  'viruses': 5,
#  'misuse': 5,
#  'safeguards': 5,
#  'GA': 5,
#  'documents': 5,
#  'culture': 5,
#  'history': 5,
#  'death': 5,
#  'ground': 5,
#  'variety': 5,
#  'Corruption': 5,
#  'official': 5,
#  'Al': 5,
#  'Qaeda': 5,
#  'politicians': 5,
#  'relief': 5,
#  'Service': 5,
#  'ivory': 5,
#  'release': 5,
#  'marriage': 5,
#  'July': 4,
#  'York': 4,
#  'UNHCR': 4,
#  'books': 4,
#  'Borders': 4,
#  'checkups': 4,
#  'programmes': 4,
#  'interests': 4,
#  'event': 4,
#  'Benin': 4,
#  'profit': 4,
#  'teacher': 4,
#  'grants': 4,
#  'guides': 4,
#  'SUBMITTER': 4,
#  'PROGRAMME': 4,
#  'urbanization': 4,
#  'eradication': 4,
#  'necessities': 4,
#  'cultures': 4,
#  'student': 4,
#  'studies': 4,
#  'Persons': 4,
#  'differences': 4,
#  'shows': 4,
#  'Educational': 4,
#  'UNESCO': 4,
#  'curriculum': 4,
#  'specialists': 4,
#  'WHO': 4,
#  'reason': 4,
#  'Kenya': 4,
#  'parts': 4,
#  'payment': 4,
#  'volunteer': 4,
#  'investment': 4,
#  'libraries': 4,
#  'example': 4,
#  'officers': 4,
#  'manner': 4,
#  'ages': 4,
#  'minorities': 4,
#  'definition': 4,
#  'v.': 4,
#  'prosecution': 4,
#  'articles': 4,
#  'Indonesia': 4,
#  'Uruguay': 4,
#  'RIGHTS': 4,
#  'establishment': 4,
#  'soldiers': 4,
#  'African': 4,
#  'girls': 4,
#  'series': 4,
#  'markets': 4,
#  'prostitution': 4,
#  'perpetrators': 4,
#  'replacement': 4,
#  'reformation': 4,
#  'minimum': 4,
#  'Treaties': 4,
#  'presence': 4,
#  'WTO': 4,
#  'transport': 4,
#  'species': 4,
#  'restrictions': 4,
#  'Monetary': 4,
#  'Forum': 4,
#  'deaths': 4,
#  'entrepreneurship': 4,
#  'buildings': 4,
#  'reduction': 4,
#  'U.S.': 4,
#  'Act': 4,
#  'Parties': 4,
#  'roads': 4,
#  'communications': 4,
#  'entities': 4,
#  'basis': 4,
#  'mandate': 4,
#  'Pacific': 4,
#  'Wrongful': 4,
#  'result': 4,
#  'influx': 4,
#  'residency': 4,
#  'contribution': 4,
#  'fear': 4,
#  'regulation': 4,
#  'newspaper': 4,
#  'restriction': 4,
#  'IHL': 4,
#  'violation': 4,
#  'Add': 4,
#  'Egypt': 4,
#  'panel': 4,
#  'evidence': 4,
#  'USA': 4,
#  'collision': 4,
#  'satellite': 4,
#  'zone': 4,
#  'center': 4,
#  'missions': 4,
#  'equipment': 4,
#  'ban': 4,
#  'accordance': 4,
#  'database': 4,
#  'populations': 4,
#  'workshops': 4,
#  'online': 4,
#  'zones': 4,
#  'collaboration': 4,
#  'emission': 4,
#  'tons': 4,
#  'Administration': 4,
#  'UNFCCC': 4,
#  'Panel': 4,
#  'limits': 4,
#  'decrease': 4,
#  'matter': 4,
#  'Internet': 4,
#  'News': 4,
#  'messages': 4,
#  'curriculums': 4,
#  'structures': 4,
#  'council': 4,
#  'check': 4,
#  'gun': 4,
#  'reporting': 4,
#  'casualties': 4,
#  'tracking': 4,
#  'Center': 4,
#  'hopes': 4,
#  'Arab': 4,
#  'discussion': 4,
#  'Exploitation': 4,
#  'tools': 4,
#  'scope': 4,
#  'lessons': 4,
#  'operation': 4,
#  'orphanage': 4,
#  'blockchain': 4,
#  'remuneration': 4,
#  'impunity': 4,
#  'mechanism': 4,
#  'Transparency': 4,
#  'TI': 4,
#  'Houthis': 4,
#  'sentiments': 4,
#  'organisations': 4,
#  'gaps': 4,
#  'taxation': 4,
#  'perception': 4,
#  'crop': 4,
#  'farms': 4,
#  'platform': 4,
#  'operations': 4,
#  'animal': 4,
#  'animals': 4,
#  'settlement': 4,
#  'inhabitants': 4,
#  'Fission': 4,
#  'neutron': 4,
#  'atom': 4,
#  'radiation': 4,
#  'computer': 4,
#  'alarm': 4,
#  'command': 4,
#  'PNE': 4,
#  'canals': 4,
#  'Explosions': 4,
#  'capabilities': 4,
#  'Definition': 4,
#  'Key': 4,
#  'Weapon': 4,
#  'Proliferation': 4,
#  'NSS': 4,
#  'Barack': 4,
#  'Obama': 4,
#  'Physics': 4,
#  'atoms': 4,
#  'Curie': 4,
#  'discovery': 4,
#  'Le': 4,
#  'Enrico': 4,
#  'Fermi': 4,
#  'reactors': 4,
#  'Uranium': 4,
#  'Columbia': 4,
#  'Oak': 4,
#  'Ridge': 4,
#  'site': 4,
#  'thousands': 4,
#  'facility': 4,
#  'Boy': 4,
#  'implosion': 4,
#  'August': 4,
#  'Many': 4,
#  'May': 4,
#  'front': 4,
#  'stockpile': 4,
#  'warheads': 4,
#  'Set': 4,
#  'First': 4,
#  'sabotage': 4,
#  ...}

# %%
from wordcloud import WordCloud 

import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords

# %%
# %matplotlib inline

import matplotlib
from IPython.display import set_matplotlib_formats
matplotlib.rc('font',family = 'Malgun Gothic')

set_matplotlib_formats('retina')

matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', background_color='white',colormap = "Accent_r",
                      width=1500, height=1000).generate_from_frequencies(words)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()
