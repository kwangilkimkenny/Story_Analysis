# %% [markdown]
# # Harvard, Yale, Stanford, MIT, Caltech, University of Pennsylvania, Brown 최상위 학교 분석
#
#   "undergrad_schools_applied": "[54068] [seattle-pacific-university-seattle-wa] Seattle Pacific University (Seattle, WA)\n[230923]  ...

# %%
import spacy
import re

spacy.prefer_gpu()
nlp = spacy.load("en_core_web_lg")

from collections import Counter
from string import punctuation
import json
import pandas as pd

# %%
#데이터 전처리 : 리트로 출력
def cleaning(datas):

    fin_datas = []

    for data in datas:
        # 영문자 이외 문자는 공백으로 변환
        only_english = re.sub('[^a-zA-Z]', ' ', data)
    
        # 데이터를 리스트에 추가 
        fin_datas.append(only_english)

    return fin_datas

# %%
#데이터 전처리 2 : txt로 출력
def cleaning(data):

    remove_ = re.sub(r"\t", " ", str(data)) # 제거
    remove__ = re.sub(r"\n", " ", str(data)) # 제거

    data = remove__

    remove = data.replace("schema"," ") # 변환
    remove = data.replace("fields"," ") # 변환
    remove = data.replace("u2019"," ") # 변환
    remove = data.replace("name"," ") # 변환
    remove = data.replace("index"," ") # 변환
    remove = data.replace("type"," ") # 변환
    remove = data.replace("integer"," ") # 변환
    remove = data.replace("personal_essay"," ") # 변환
    remove = data.replace("string"," ") # 변환
    remove = data.replace("pandas_version"," ") # 변환
    remove = data.replace("0.20.0"," ") # 변환
    remove = data.replace("data"," ") # 변환


    remove = data.replace("  "," ") # 변환

    remove__ = remove__.replace("   ", " ")
    remove__ = remove__.replace("  ", " ")
    remove__ = remove__.replace(" ", ",")
    remove__ = remove__.replace("{}:[]", ",")
    remove__ = remove__.replace("…/", " ")
    remove__ = remove__.replace("…", " ")
    remove__ = remove__.replace("/", " ")
    remove__ = remove__.replace(" ", ",")
    remove__ = remove__.replace(")", ",")
    remove__ = remove__.replace("(", ",")
    preprossed = remove__.split(",") # 단어를 리스트로 변환

    remove__ = result.replace("   ", " ")
    remove__ = remove__.replace("  ", " ")
    remove__ = remove__.replace(" ", ",")
    remove__ = remove__.replace("\\\\", ",")
    remove__ = remove__.replace("{}:[]", ",")
    remove__ = remove__.replace("…/", " ")
    remove__ = remove__.replace("…", " ")
    remove__ = remove__.replace("/", " ")
    remove__ = remove__.replace(" ", ",")
    remove__ = remove__.replace(")", ",")
    remove__ = remove__.replace("(", ",")
    preprossed = remove__.split(",") # 단어를 리스트로 변환


    return preprossed

# %%
def get_hotwords(text):
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN'] # 1
    doc = nlp(text.lower()) # 2
    for token in doc:
        # 3
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        # 4
        if(token.pos_ in pos_tag):
            result.append(token.text)
                
    return result # 5

# %%
with open("./DataEssay/essayData.json") as f:
    data = json.load(f)

# %%
data["data"][0]["undergrad_schools_applied"]
# Out:
# '[476] [columbia-university-new-york-ny] Columbia University (New York, NY)\n[230923] [enrolled] Enrolled\n[231629] [undecided] Undecided\nBachelor of Arts\nNo\n[529] [fordham-university-new-york-ny] Fordham University (New York, NY)\n[5737] [accepted] Accepted\n[231629] [undecided] Undecided\nBachelor of Arts\nNo\n'

# %%
data_str = data["data"][0]["undergrad_schools_applied"]

# %%
words_list = data_str.split()
words_list
# Out:
# ['[476]',
#  '[columbia-university-new-york-ny]',
#  'Columbia',
#  'University',
#  '(New',
#  'York,',
#  'NY)',
#  '[230923]',
#  '[enrolled]',
#  'Enrolled',
#  '[231629]',
#  '[undecided]',
#  'Undecided',
#  'Bachelor',
#  'of',
#  'Arts',
#  'No',
#  '[529]',
#  '[fordham-university-new-york-ny]',
#  'Fordham',
#  'University',
#  '(New',
#  'York,',
#  'NY)',
#  '[5737]',
#  '[accepted]',
#  'Accepted',
#  '[231629]',
#  '[undecided]',
#  'Undecided',
#  'Bachelor',
#  'of',
#  'Arts',
#  'No']

# %%
words_list[0]
# Out:
# '[476]'

# %%
# 학교 이름 추출 - 학교이름을 추출하여 상위 5개 학교이라면 extracurricular_activitie 데이터 별도 추출하는 코드 작성할 것
words_list[1]
# Out:
# '[columbia-university-new-york-ny]'

# %% [markdown]
# # 상위 5개 학교의 데이터 추출 : Harvard, Yale, Stanford, MIT, Caltech, University of Pennsylvania, Brown
# 5개 학교 키값:
#     [harvard-university-cambridge-ma] ,
#     [yale-university-new-haven-ct],
#     [stanford-university-stanford-ca],
#     [massachusetts-institute-of-technology-cambridge-ma],
#     [university-of-pennsylvania-philadelphia-pa],
#     [california-institute-of-technology-pasadena-ca],
#     [brown-university-providence-ri],

# %%
top_college = ['[harvard-university-cambridge-ma]', 
    '[yale-university-new-haven-ct]', 
    '[stanford-university-stanford-ca]', 
    '[massachusetts-institute-of-technology-cambridge-ma]',
    '[university-of-pennsylvania-philadelphia-pa]',
    '[california-institute-of-technology-pasadena-ca]',
    '[brown-university-providence-ri]']

# %%
## 정규식 이용 하여 []안의 단어를 추출한다. 나중에 숫자를 제거한다.
def get_ext_data(input_text):
    p = re.compile(r"\[(.+)\](.+)")
    try:
        m = p.match(input_text + " ")
        ext_result = m.group(1)
    except:
        ext_result = ""
    
    return ext_result

# %%
get_ext_data([391456])
# Out:
# ''

# %%
from tqdm import tqdm

with open("./DataEssay/essayData.json") as f:
    data = json.load(f)

get_all_result__ = []

for i in tqdm(range(len(data["data"]))):
    
    data_str = data["data"][i]["undergrad_schools_applied"]
    words_list = data_str.split()
    if words_list[1] in top_college:
        # top_college 에 Erolled 학교가 있다면, 해당 데이터의  Extracurricular_activite를 추출한다. 이부분 함수로 처리할 것
        data_ext_curr = data["data"][i]["extracurricular_activitie"]
        print("essay no:", i)
        print("------------------------------------------------------")
        print(data_ext_curr)
        print("------------------------------------------------------")
        words_list_ = data_ext_curr.split()
        print("words_list_ :", words_list_)
        print("------------------------------------------------------")
        for j in words_list_:
            print('j :', j)
            result = get_ext_data(j)
            print("result :", result)
            #숫자인지 판단하고, 숫자가 아니면 append
            if result.isdigit():
                pass
            else:
                get_all_result__.append(result)
    else:
        pass
# Out:
#   2%|▏         | 21/1000 [00:00<00:05, 193.18it/s]
# essay no: 2
# ------------------------------------------------------
# [391456] [academic] Academic
# [6401] [2yr] 2
# [5622] [president] President
# [391471] [robotics] Robotics
# [6401] [2yr] 2
# [5622] [president] President
#
# ------------------------------------------------------
# words_list_ : ['[391456]', '[academic]', 'Academic', '[6401]', '[2yr]', '2', '[5622]', '[president]', 'President', '[391471]', '[robotics]', 'Robotics', '[6401]', '[2yr]', '2', '[5622]', '[president]', 'President']
# ------------------------------------------------------
# j : [391456]
# result : 391456
# j : [academic]
# result : academic
# j : Academic
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [391471]
# result : 391471
# j : [robotics]
# result : robotics
# j : Robotics
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# essay no: 5
# ------------------------------------------------------
# [5538] [debate-club-team] Debate Club/Team
# [6403] [4yr] 4
# [6331] [member] Member
# [10916] [regional-state-recognition] Regional/State Recognition
# [391468] [music-vocal] Music: Vocal
# [6402] [3yr] 3
# [8998] [lead-role] Lead role
# [5628] [national-recognition] National Recognition
# [5550] [student-government-council] Student Council / Government
# [6401] [2yr] 2
# [5622] [president] President
# [5625] [school-award] School Award
# [5606] [tutoring-mentoring] Tutoring/Mentoring
# [6401] [2yr] 2
# [6331] [member] Member
# [391476] [other-club-activity] Other Club/Activity
# [6402] [3yr] 3
# [5623] [founder] Founder
# [391924] [international-recognition] International Recognition
#
# ------------------------------------------------------
# words_list_ : ['[5538]', '[debate-club-team]', 'Debate', 'Club/Team', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[391468]', '[music-vocal]', 'Music:', 'Vocal', '[6402]', '[3yr]', '3', '[8998]', '[lead-role]', 'Lead', 'role', '[5628]', '[national-recognition]', 'National', 'Recognition', '[5550]', '[student-government-council]', 'Student', 'Council', '/', 'Government', '[6401]', '[2yr]', '2', '[5622]', '[president]', 'President', '[5625]', '[school-award]', 'School', 'Award', '[5606]', '[tutoring-mentoring]', 'Tutoring/Mentoring', '[6401]', '[2yr]', '2', '[6331]', '[member]', 'Member', '[391476]', '[other-club-activity]', 'Other', 'Club/Activity', '[6402]', '[3yr]', '3', '[5623]', '[founder]', 'Founder', '[391924]', '[international-recognition]', 'International', 'Recognition']
# ------------------------------------------------------
# j : [5538]
# result : 5538
# j : [debate-club-team]
# result : debate-club-team
# j : Debate
# result :
# j : Club/Team
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [391468]
# result : 391468
# j : [music-vocal]
# result : music-vocal
# j : Music:
# result :
# j : Vocal
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5628]
# result : 5628
# j : [national-recognition]
# result : national-recognition
# j : National
# result :
# j : Recognition
# result :
# j : [5550]
# result : 5550
# j : [student-government-council]
# result : student-government-council
# j : Student
# result :
# j : Council
# result :
# j : /
# result :
# j : Government
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5625]
# result : 5625
# j : [school-award]
# result : school-award
# j : School
# result :
# j : Award
# result :
# j : [5606]
# result : 5606
# j : [tutoring-mentoring]
# result : tutoring-mentoring
# j : Tutoring/Mentoring
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [391476]
# result : 391476
# j : [other-club-activity]
# result : other-club-activity
# j : Other
# result :
# j : Club/Activity
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [5623]
# result : 5623
# j : [founder]
# result : founder
# j : Founder
# result :
# j : [391924]
# result : 391924
# j : [international-recognition]
# result : international-recognition
# j : International
# result :
# j : Recognition
# result :
# essay no: 6
# ------------------------------------------------------
#
# ------------------------------------------------------
# words_list_ : []
# ------------------------------------------------------
# essay no: 14
# ------------------------------------------------------
# [391470] [research] Research
# [6400] [1yr] 1
# [391981] [employee] Employee
# [5609] [computer-technology-volunteer] Computer / Technology Volunteer
# [6400] [1yr] 1
# [6331] [member] Member
# [391470] [research] Research
# [6400] [1yr] 1
# [6331] [member] Member
# [391470] [research] Research
# [6400] [1yr] 1
# [6331] [member] Member
# [5538] [debate-club-team] Debate Club/Team
# [6403] [4yr] 4
# [5622] [president] President
# [5609] [computer-technology-volunteer] Computer / Technology Volunteer
# [6403] [4yr] 4
# [5622] [president] President
# [5630] [won-national-award] Won National Award
# [5609] [computer-technology-volunteer] Computer / Technology Volunteer
# [6402] [3yr] 3
# [5623] [founder] Founder
#
# ------------------------------------------------------
# words_list_ : ['[391470]', '[research]', 'Research', '[6400]', '[1yr]', '1', '[391981]', '[employee]', 'Employee', '[5609]', '[computer-technology-volunteer]', 'Computer', '/', 'Technology', 'Volunteer', '[6400]', '[1yr]', '1', '[6331]', '[member]', 'Member', '[391470]', '[research]', 'Research', '[6400]', '[1yr]', '1', '[6331]', '[member]', 'Member', '[391470]', '[research]', 'Research', '[6400]', '[1yr]', '1', '[6331]', '[member]', 'Member', '[5538]', '[debate-club-team]', 'Debate', 'Club/Team', '[6403]', '[4yr]', '4', '[5622]', '[president]', 'President', '[5609]', '[computer-technology-volunteer]', 'Computer', '/', 'Technology', 'Volunteer', '[6403]', '[4yr]', '4', '[5622]', '[president]', 'President', '[5630]', '[won-national-award]', 'Won', 'National', 'Award', '[5609]', '[computer-technology-volunteer]', 'Computer', '/', 'Technology', 'Volunteer', '[6402]', '[3yr]', '3', '[5623]', '[founder]', 'Founder']
# ------------------------------------------------------
# j : [391470]
# result : 391470
# j : [research]
# result : research
# j : Research
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [391981]
# result : 391981
# j : [employee]
# result : employee
# j : Employee
# result :
# j : [5609]
# result : 5609
# j : [computer-technology-volunteer]
# result : computer-technology-volunteer
# j : Computer
# result :
# j : /
# result :
# j : Technology
# result :
# j : Volunteer
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [391470]
# result : 391470
# j : [research]
# result : research
# j : Research
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [391470]
# result : 391470
# j : [research]
# result : research
# j : Research
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5538]
# result : 5538
# j : [debate-club-team]
# result : debate-club-team
# j : Debate
# result :
# j : Club/Team
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5609]
# result : 5609
# j : [computer-technology-volunteer]
# result : computer-technology-volunteer
# j : Computer
# result :
# j : /
# result :
# j : Technology
# result :
# j : Volunteer
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5630]
# result : 5630
# j : [won-national-award]
# result : won-national-award
# j : Won
# result :
# j : National
# result :
# j : Award
# result :
# j : [5609]
# result : 5609
# j : [computer-technology-volunteer]
# result : computer-technology-volunteer
# j : Computer
# result :
# j : /
# result :
# j : Technology
# result :
# j : Volunteer
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [5623]
# result : 5623
# j : [founder]
# result : founder
# j : Founder
# result :
# essay no: 15
# ------------------------------------------------------
# [5567] [school-jazz-orchestra] School Jazz / Orchestra
# [6403] [4yr] 4
# [6331] [member] Member
# [391459] [cultural] Cultural
# [6400] [1yr] 1
# [5622] [president] President
# [5543] [science-club-team] Science Club/Team
# [6402] [3yr] 3
# [8998] [lead-role] Lead role
# [391484] [other-award] Other Award
# [11665] [dance] Dance
# [6402] [3yr] 3
# [6331] [member] Member
# [5536] [academic-decathlon] Academic Decathlon
# [6400] [1yr] 1
# [6331] [member] Member
# [10916] [regional-state-recognition] Regional/State Recognition
# [391467] [music-instrumental] Music: Instrumental
# [6401] [2yr] 2
# [8998] [lead-role] Lead role
# [5543] [science-club-team] Science Club/Team
# [6401] [2yr] 2
# [5621] [executive-board] Executive Board
#
# ------------------------------------------------------
# words_list_ : ['[5567]', '[school-jazz-orchestra]', 'School', 'Jazz', '/', 'Orchestra', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member', '[391459]', '[cultural]', 'Cultural', '[6400]', '[1yr]', '1', '[5622]', '[president]', 'President', '[5543]', '[science-club-team]', 'Science', 'Club/Team', '[6402]', '[3yr]', '3', '[8998]', '[lead-role]', 'Lead', 'role', '[391484]', '[other-award]', 'Other', 'Award', '[11665]', '[dance]', 'Dance', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[5536]', '[academic-decathlon]', 'Academic', 'Decathlon', '[6400]', '[1yr]', '1', '[6331]', '[member]', 'Member', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[391467]', '[music-instrumental]', 'Music:', 'Instrumental', '[6401]', '[2yr]', '2', '[8998]', '[lead-role]', 'Lead', 'role', '[5543]', '[science-club-team]', 'Science', 'Club/Team', '[6401]', '[2yr]', '2', '[5621]', '[executive-board]', 'Executive', 'Board']
# ------------------------------------------------------
# j : [5567]
# result : 5567
# j : [school-jazz-orchestra]
# result : school-jazz-orchestra
# j : School
# result :
# j : Jazz
# result :
# j : /
# result :
# j : Orchestra
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [391459]
# result : 391459
# j : [cultural]
# result : cultural
# j : Cultural
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5543]
# result : 5543
# j : [science-club-team]
# result : science-club-team
# j : Science
# result :
# j : Club/Team
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [391484]
# result : 391484
# j : [other-award]
# result : other-award
# j : Other
# result :
# j : Award
# result :
# j : [11665]
# result : 11665
# j : [dance]
# result : dance
# j : Dance
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5536]
# result : 5536
# j : [academic-decathlon]
# result : academic-decathlon
# j : Academic
# result :
# j : Decathlon
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [391467]
# result : 391467
# j : [music-instrumental]
# result : music-instrumental
# j : Music:
# result :
# j : Instrumental
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5543]
# result : 5543
# j : [science-club-team]
# result : science-club-team
# j : Science
# result :
# j : Club/Team
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5621]
# result : 5621
# j : [executive-board]
# result : executive-board
# j : Executive
# result :
# j : Board
# result :
# essay no: 16
# ------------------------------------------------------
# [391458] [career-oriented] Career Oriented
# [6401] [2yr] 2
# [5622] [president] President
# [391458] [career-oriented] Career Oriented
# [6401] [2yr] 2
# [5622] [president] President
# [5609] [computer-technology-volunteer] Computer / Technology Volunteer
# [6403] [4yr] 4
# [6331] [member] Member
# [391484] [other-award] Other Award
# [5550] [student-government-council] Student Council / Government
# [6402] [3yr] 3
# [6331] [member] Member
# [391456] [academic] Academic
# [6403] [4yr] 4
# [5622] [president] President
# [10916] [regional-state-recognition] Regional/State Recognition
# [391456] [academic] Academic
# [6401] [2yr] 2
# [8998] [lead-role] Lead role
# [5630] [won-national-award] Won National Award
#
# ------------------------------------------------------
# words_list_ : ['[391458]', '[career-oriented]', 'Career', 'Oriented', '[6401]', '[2yr]', '2', '[5622]', '[president]', 'President', '[391458]', '[career-oriented]', 'Career', 'Oriented', '[6401]', '[2yr]', '2', '[5622]', '[president]', 'President', '[5609]', '[computer-technology-volunteer]', 'Computer', '/', 'Technology', 'Volunteer', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member', '[391484]', '[other-award]', 'Other', 'Award', '[5550]', '[student-government-council]', 'Student', 'Council', '/', 'Government', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[391456]', '[academic]', 'Academic', '[6403]', '[4yr]', '4', '[5622]', '[president]', 'President', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[391456]', '[academic]', 'Academic', '[6401]', '[2yr]', '2', '[8998]', '[lead-role]', 'Lead', 'role', '[5630]', '[won-national-award]', 'Won', 'National', 'Award']
# ------------------------------------------------------
# j : [391458]
# result : 391458
# j : [career-oriented]
# result : career-oriented
# j : Career
# result :
# j : Oriented
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [391458]
# result : 391458
# j : [career-oriented]
# result : career-oriented
# j : Career
# result :
# j : Oriented
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5609]
# result : 5609
# j : [computer-technology-volunteer]
# result : computer-technology-volunteer
# j : Computer
# result :
# j : /
# result :
# j : Technology
# result :
# j : Volunteer
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [391484]
# result : 391484
# j : [other-award]
# result : other-award
# j : Other
# result :
# j : Award
# result :
# j : [5550]
# result : 5550
# j : [student-government-council]
# result : student-government-council
# j : Student
# result :
# j : Council
# result :
# j : /
# result :
# j : Government
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [391456]
# result : 391456
# j : [academic]
# result : academic
# j : Academic
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [391456]
# result : 391456
# j : [academic]
# result : academic
# j : Academic
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5630]
# result : 5630
# j : [won-national-award]
# result : won-national-award
# j : Won
# result :
# j : National
# result :
# j : Award
# result :
# essay no: 20
# ------------------------------------------------------
# [391467] [music-instrumental] Music: Instrumental
# [6411] [12yr] 12
# [6331] [member] Member
# [5629] [awarded-monetary-prize] Awarded Monetary Prize
# [5631] [received-scholarship-for-achievement] Received Scholarship For Achievement
# [10916] [regional-state-recognition] Regional/State Recognition
# [391474] [social-justice] Social Justice
# [6401] [2yr] 2
# [6331] [member] Member
# [5627] [recognized-in-local-media] Recognized in Local Media
# [10149] [community-cleanup-service] Community Cleanup / Service
# [6401] [2yr] 2
# [5623] [founder] Founder
# [5627] [recognized-in-local-media] Recognized in Local Media
# [10917] [quiz-bowl-academic-bowl] Quiz Bowl/Academic Bowl
# [6403] [4yr] 4
# [8998] [lead-role] Lead role
# [10916] [regional-state-recognition] Regional/State Recognition
# [5544] [math-team] Math Team
# [6403] [4yr] 4
# [8998] [lead-role] Lead role
# [10916] [regional-state-recognition] Regional/State Recognition
# [10149] [community-cleanup-service] Community Cleanup / Service
# [6402] [3yr] 3
# [5621] [executive-board] Executive Board
# [391484] [other-award] Other Award
# [391456] [academic] Academic
# [6402] [3yr] 3
# [6331] [member] Member
# [5627] [recognized-in-local-media] Recognized in Local Media
# [5631] [received-scholarship-for-achievement] Received Scholarship For Achievement
# [391475] [theater-drama] Theater/Drama
# [6401] [2yr] 2
# [5621] [executive-board] Executive Board
# [5627] [recognized-in-local-media] Recognized in Local Media
# [391476] [other-club-activity] Other Club/Activity
# [6402] [3yr] 3
# [5622] [president] President
# [5550] [student-government-council] Student Council / Government
# [6403] [4yr] 4
# [5624] [committee-leader] Committee Leader
# [5610] [church] Church
# [6401] [2yr] 2
# [391981] [employee] Employee
#
# ------------------------------------------------------
# words_list_ : ['[391467]', '[music-instrumental]', 'Music:', 'Instrumental', '[6411]', '[12yr]', '12', '[6331]', '[member]', 'Member', '[5629]', '[awarded-monetary-prize]', 'Awarded', 'Monetary', 'Prize', '[5631]', '[received-scholarship-for-achievement]', 'Received', 'Scholarship', 'For', 'Achievement', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[391474]', '[social-justice]', 'Social', 'Justice', '[6401]', '[2yr]', '2', '[6331]', '[member]', 'Member', '[5627]', '[recognized-in-local-media]', 'Recognized', 'in', 'Local', 'Media', '[10149]', '[community-cleanup-service]', 'Community', 'Cleanup', '/', 'Service', '[6401]', '[2yr]', '2', '[5623]', '[founder]', 'Founder', '[5627]', '[recognized-in-local-media]', 'Recognized', 'in', 'Local', 'Media', '[10917]', '[quiz-bowl-academic-bowl]', 'Quiz', 'Bowl/Academic', 'Bowl', '[6403]', '[4yr]', '4', '[8998]', '[lead-role]', 'Lead', 'role', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[5544]', '[math-team]', 'Math', 'Team', '[6403]', '[4yr]', '4', '[8998]', '[lead-role]', 'Lead', 'role', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[10149]', '[community-cleanup-service]', 'Community', 'Cleanup', '/', 'Service', '[6402]', '[3yr]', '3', '[5621]', '[executive-board]', 'Executive', 'Board', '[391484]', '[other-award]', 'Other', 'Award', '[391456]', '[academic]', 'Academic', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[5627]', '[recognized-in-local-media]', 'Recognized', 'in', 'Local', 'Media', '[5631]', '[received-scholarship-for-achievement]', 'Received', 'Scholarship', 'For', 'Achievement', '[391475]', '[theater-drama]', 'Theater/Drama', '[6401]', '[2yr]', '2', '[5621]', '[executive-board]', 'Executive', 'Board', '[5627]', '[recognized-in-local-media]', 'Recognized', 'in', 'Local', 'Media', '[391476]', '[other-club-activity]', 'Other', 'Club/Activity', '[6402]', '[3yr]', '3', '[5622]', '[president]', 'President', '[5550]', '[student-government-council]', 'Student', 'Council', '/', 'Government', '[6403]', '[4yr]', '4', '[5624]', '[committee-leader]', 'Committee', 'Leader', '[5610]', '[church]', 'Church', '[6401]', '[2yr]', '2', '[391981]', '[employee]', 'Employee']
# ------------------------------------------------------
# j : [391467]
# result : 391467
# j : [music-instrumental]
# result : music-instrumental
# j : Music:
# result :
# j : Instrumental
# result :
# j : [6411]
# result : 6411
# j : [12yr]
# result : 12yr
# j : 12
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5629]
# result : 5629
# j : [awarded-monetary-prize]
# result : awarded-monetary-prize
# j : Awarded
# result :
# j : Monetary
# result :
# j : Prize
# result :
# j : [5631]
# result : 5631
# j : [received-scholarship-for-achievement]
# result : received-scholarship-for-achievement
# j : Received
# result :
# j : Scholarship
# result :
# j : For
# result :
# j : Achievement
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [391474]
# result : 391474
# j : [social-justice]
# result : social-justice
# j : Social
# result :
# j : Justice
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5627]
# result : 5627
# j : [recognized-in-local-media]
# result : recognized-in-local-media
# j : Recognized
# result :
# j : in
# result :
# j : Local
# result :
# j : Media
# result :
# j : [10149]
# result : 10149
# j : [community-cleanup-service]
# result : community-cleanup-service
# j : Community
# result :
# j : Cleanup
# result :
# j : /
# result :
# j : Service
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5623]
# result : 5623
# j : [founder]
# result : founder
# j : Founder
# result :
# j : [5627]
# result : 5627
# j : [recognized-in-local-media]
# result : recognized-in-local-media
# j : Recognized
# result :
# j : in
# result :
# j : Local
# result :
# j : Media
# result :
# j : [10917]
# result : 10917
# j : [quiz-bowl-academic-bowl]
# result : quiz-bowl-academic-bowl
# j : Quiz
# result :
# j : Bowl/Academic
# result :
# j : Bowl
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [5544]
# result : 5544
# j : [math-team]
# result : math-team
# j : Math
# result :
# j : Team
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [10149]
# result : 10149
# j : [community-cleanup-service]
# result : community-cleanup-service
# j : Community
# result :
# j : Cleanup
# result :
# j : /
# result :
# j : Service
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [5621]
# result : 5621
# j : [executive-board]
# result : executive-board
# j : Executive
# result :
# j : Board
# result :
# j : [391484]
# result : 391484
# j : [other-award]
# result : other-award
# j : Other
# result :
# j : Award
# result :
# j : [391456]
# result : 391456
# j : [academic]
# result : academic
# j : Academic
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5627]
# result : 5627
# j : [recognized-in-local-media]
# result : recognized-in-local-media
# j : Recognized
# result :
# j : in
# result :
# j : Local
# result :
# j : Media
# result :
# j : [5631]
# result : 5631
# j : [received-scholarship-for-achievement]
# result : received-scholarship-for-achievement
# j : Received
# result :
# j : Scholarship
# result :
# j : For
# result :
# j : Achievement
# result :
# j : [391475]
# result : 391475
# j : [theater-drama]
# result : theater-drama
# j : Theater/Drama
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5621]
# result : 5621
# j : [executive-board]
# result : executive-board
# j : Executive
# result :
# j : Board
# result :
# j : [5627]
# result : 5627
# j : [recognized-in-local-media]
# result : recognized-in-local-media
# j : Recognized
# result :
# j : in
# result :
# j : Local
# result :
# j : Media
# result :
# j : [391476]
# result : 391476
# j : [other-club-activity]
# result : other-club-activity
# j : Other
# result :
# j : Club/Activity
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5550]
# result : 5550
# j : [student-government-council]
# result : student-government-council
# j : Student
# result :
# j : Council
# result :
# j : /
# result :
# j : Government
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [5624]
# result : 5624
# j : [committee-leader]
# result : committee-leader
# j : Committee
# result :
# j : Leader
# result :
# j : [5610]
# result : 5610
# j : [church]
# result : church
# j : Church
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [391981]
# result : 391981
# j : [employee]
# result : employee
# j : Employee
# result :
# essay no: 21
# ------------------------------------------------------
#
# ------------------------------------------------------
# words_list_ : []
# ------------------------------------------------------
# essay no: 24
# ------------------------------------------------------
# [391460] [environmental] Environmental
# [6403] [4yr] 4
# [5622] [president] President
# [5630] [won-national-award] Won National Award
# [391458] [career-oriented] Career Oriented
# [6402] [3yr] 3
# [391981] [employee] Employee
# [391458] [career-oriented] Career Oriented
# [6402] [3yr] 3
# [6331] [member] Member
# [391456] [academic] Academic
# [6401] [2yr] 2
# [6331] [member] Member
# [5630] [won-national-award] Won National Award
# [5549] [school-newspaper-magazine-journalism] School Newspaper/Magazine/Journalism
# [6403] [4yr] 4
# [6331] [member] Member
#
# ------------------------------------------------------
# words_list_ : ['[391460]', '[environmental]', 'Environmental', '[6403]', '[4yr]', '4', '[5622]', '[president]', 'President', '[5630]', '[won-national-award]', 'Won', 'National', 'Award', '[391458]', '[career-oriented]', 'Career', 'Oriented', '[6402]', '[3yr]', '3', '[391981]', '[employee]', 'Employee', '[391458]', '[career-oriented]', 'Career', 'Oriented', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[391456]', '[academic]', 'Academic', '[6401]', '[2yr]', '2', '[6331]', '[member]', 'Member', '[5630]', '[won-national-award]', 'Won', 'National', 'Award', '[5549]', '[school-newspaper-magazine-journalism]', 'School', 'Newspaper/Magazine/Journalism', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member']
# ------------------------------------------------------
# j : [391460]
# result : 391460
# j : [environmental]
# result : environmental
# j : Environmental
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5630]
# result : 5630
# j : [won-national-award]
# result : won-national-award
# j : Won
# result :
# j : National
# result :
# j : Award
# result :
# j : [391458]
# result : 391458
# j : [career-oriented]
# result : career-oriented
# j : Career
# result :
# j : Oriented
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [391981]
# result : 391981
# j : [employee]
# result : employee
# j : Employee
# result :
# j : [391458]
# result : 391458
# j : [career-oriented]
# result : career-oriented
# j : Career
# result :
# j : Oriented
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [391456]
# result : 391456
# j : [academic]
# result : academic
# j : Academic
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5630]
# result : 5630
# j : [won-national-award]
# result : won-national-award
# j : Won
# result :
# j : National
# result :
# j : Award
# result :
# j : [5549]
# result : 5549
# j : [school-newspaper-magazine-journalism]
# result : school-newspaper-magazine-journalism
# j : School
# result :
# j : Newspaper/Magazine/Journalism
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# essay no: 25
# ------------------------------------------------------
# [5568] [marching-band] Marching Band
# [6403] [4yr] 4
# [8998] [lead-role] Lead role
# [5559] [school-theater-plays] School Theater/Plays
# [6403] [4yr] 4
# [6331] [member] Member
# [391470] [research] Research
# [6400] [1yr] 1
# [6331] [member] Member
# [10917] [quiz-bowl-academic-bowl] Quiz Bowl/Academic Bowl
# [6403] [4yr] 4
# [8998] [lead-role] Lead role
# [5544] [math-team] Math Team
# [6403] [4yr] 4
# [5622] [president] President
# [5606] [tutoring-mentoring] Tutoring/Mentoring
# [6400] [1yr] 1
# [6331] [member] Member
#
# ------------------------------------------------------
# words_list_ : ['[5568]', '[marching-band]', 'Marching', 'Band', '[6403]', '[4yr]', '4', '[8998]', '[lead-role]', 'Lead', 'role', '[5559]', '[school-theater-plays]', 'School', 'Theater/Plays', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member', '[391470]', '[research]', 'Research', '[6400]', '[1yr]', '1', '[6331]', '[member]', 'Member', '[10917]', '[quiz-bowl-academic-bowl]', 'Quiz', 'Bowl/Academic', 'Bowl', '[6403]', '[4yr]', '4', '[8998]', '[lead-role]', 'Lead', 'role', '[5544]', '[math-team]', 'Math', 'Team', '[6403]', '[4yr]', '4', '[5622]', '[president]', 'President', '[5606]', '[tutoring-mentoring]', 'Tutoring/Mentoring', '[6400]', '[1yr]', '1', '[6331]', '[member]', 'Member']
# ------------------------------------------------------
# j : [5568]
# result : 5568
# j : [marching-band]
# result : marching-band
# j : Marching
# result :
# j : Band
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5559]
# result : 5559
# j : [school-theater-plays]
# result : school-theater-plays
# j : School
# result :
# j : Theater/Plays
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [391470]
# result : 391470
# j : [research]
# result : research
# j : Research
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [10917]
# result : 10917
# j : [quiz-bowl-academic-bowl]
# result : quiz-bowl-academic-bowl
# j : Quiz
# result :
# j : Bowl/Academic
# result :
# j : Bowl
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5544]
# result : 5544
# j : [math-team]
# result : math-team
# j : Math
# result :
# j : Team
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5606]
# result : 5606
# j : [tutoring-mentoring]
# result : tutoring-mentoring
# j : Tutoring/Mentoring
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# essay no: 28
# ------------------------------------------------------
# [391476] [other-club-activity] Other Club/Activity
# [6402] [3yr] 3
# [8998] [lead-role] Lead role
# [391456] [academic] Academic
# [6400] [1yr] 1
# [6331] [member] Member
# [5550] [student-government-council] Student Council / Government
# [6403] [4yr] 4
# [6331] [member] Member
#
# ------------------------------------------------------
# words_list_ : ['[391476]', '[other-club-activity]', 'Other', 'Club/Activity', '[6402]', '[3yr]', '3', '[8998]', '[lead-role]', 'Lead', 'role', '[391456]', '[academic]', 'Academic', '[6400]', '[1yr]', '1', '[6331]', '[member]', 'Member', '[5550]', '[student-government-council]', 'Student', 'Council', '/', 'Government', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member']
# ------------------------------------------------------
# j : [391476]
# result : 391476
# j : [other-club-activity]
# result : other-club-activity
# j : Other
# result :
# j : Club/Activity
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [391456]
# result : 391456
# j : [academic]
# result : academic
# j : Academic
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5550]
# result : 5550
# j : [student-government-council]
# result : student-government-council
# j : Student
# result :
# j : Council
# result :
# j : /
# result :
# j : Government
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# essay no: 29
# ------------------------------------------------------
# [391470] [research] Research
# [6401] [2yr] 2
# [8998] [lead-role] Lead role
# [5628] [national-recognition] National Recognition
# [5629] [awarded-monetary-prize] Awarded Monetary Prize
# [5630] [won-national-award] Won National Award
# [5631] [received-scholarship-for-achievement] Received Scholarship For Achievement
# [10916] [regional-state-recognition] Regional/State Recognition
# [391484] [other-award] Other Award
# [391924] [international-recognition] International Recognition
# [391470] [research] Research
# [6400] [1yr] 1
# [391981] [employee] Employee
# [391470] [research] Research
# [6400] [1yr] 1
# [391981] [employee] Employee
# [5550] [student-government-council] Student Council / Government
# [6402] [3yr] 3
# [5621] [executive-board] Executive Board
# [6836] [model-congress-UN] Model Congress / Model UN
# [6406] [7yr] 7
# [5622] [president] President
# [5629] [awarded-monetary-prize] Awarded Monetary Prize
# [391467] [music-instrumental] Music: Instrumental
# [6403] [4yr] 4
# [6331] [member] Member
# [5625] [school-award] School Award
# [5626] [community-award] Community Award
# [5627] [recognized-in-local-media] Recognized in Local Media
# [5628] [national-recognition] National Recognition
# [5631] [received-scholarship-for-achievement] Received Scholarship For Achievement
# [10916] [regional-state-recognition] Regional/State Recognition
# [391484] [other-award] Other Award
# [5602] [hospital-volunteer] Hospital Volunteer
# [6404] [5yr] 5
# [6331] [member] Member
# [5626] [community-award] Community Award
# [391484] [other-award] Other Award
#
# ------------------------------------------------------
# words_list_ : ['[391470]', '[research]', 'Research', '[6401]', '[2yr]', '2', '[8998]', '[lead-role]', 'Lead', 'role', '[5628]', '[national-recognition]', 'National', 'Recognition', '[5629]', '[awarded-monetary-prize]', 'Awarded', 'Monetary', 'Prize', '[5630]', '[won-national-award]', 'Won', 'National', 'Award', '[5631]', '[received-scholarship-for-achievement]', 'Received', 'Scholarship', 'For', 'Achievement', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[391484]', '[other-award]', 'Other', 'Award', '[391924]', '[international-recognition]', 'International', 'Recognition', '[391470]', '[research]', 'Research', '[6400]', '[1yr]', '1', '[391981]', '[employee]', 'Employee', '[391470]', '[research]', 'Research', '[6400]', '[1yr]', '1', '[391981]', '[employee]', 'Employee', '[5550]', '[student-government-council]', 'Student', 'Council', '/', 'Government', '[6402]', '[3yr]', '3', '[5621]', '[executive-board]', 'Executive', 'Board', '[6836]', '[model-congress-UN]', 'Model', 'Congress', '/', 'Model', 'UN', '[6406]', '[7yr]', '7', '[5622]', '[president]', 'President', '[5629]', '[awarded-monetary-prize]', 'Awarded', 'Monetary', 'Prize', '[391467]', '[music-instrumental]', 'Music:', 'Instrumental', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member', '[5625]', '[school-award]', 'School', 'Award', '[5626]', '[community-award]', 'Community', 'Award', '[5627]', '[recognized-in-local-media]', 'Recognized', 'in', 'Local', 'Media', '[5628]', '[national-recognition]', 'National', 'Recognition', '[5631]', '[received-scholarship-for-achievement]', 'Received', 'Scholarship', 'For', 'Achievement', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[391484]', '[other-award]', 'Other', 'Award', '[5602]', '[hospital-volunteer]', 'Hospital', 'Volunteer', '[6404]', '[5yr]', '5', '[6331]', '[member]', 'Member', '[5626]', '[community-award]', 'Community', 'Award', '[391484]', '[other-award]', 'Other', 'Award']
# ------------------------------------------------------
# j : [391470]
# result : 391470
# j : [research]
# result : research
# j : Research
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5628]
# result : 5628
# j : [national-recognition]
# result : national-recognition
# j : National
# result :
# j : Recognition
# result :
# j : [5629]
# result : 5629
# j : [awarded-monetary-prize]
# result : awarded-monetary-prize
# j : Awarded
# result :
# j : Monetary
# result :
# j : Prize
# result :
# j : [5630]
# result : 5630
# j : [won-national-award]
# result : won-national-award
# j : Won
# result :
# j : National
# result :
# j : Award
# result :
# j : [5631]
# result : 5631
# j : [received-scholarship-for-achievement]
# result : received-scholarship-for-achievement
# j : Received
# result :
# j : Scholarship
# result :
# j : For
# result :
# j : Achievement
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [391484]
# result : 391484
# j : [other-award]
# result : other-award
# j : Other
# result :
# j : Award
# result :
# j : [391924]
# result : 391924
# j : [international-recognition]
# result : international-recognition
# j : International
# result :
# j : Recognition
# result :
# j : [391470]
# result : 391470
# j : [research]
# result : research
# j : Research
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [391981]
# result : 391981
# j : [employee]
# result : employee
# j : Employee
# result :
# j : [391470]
# result : 391470
# j : [research]
# result : research
# j : Research
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [391981]
# result : 391981
# j : [employee]
# result : employee
# j : Employee
# result :
# j : [5550]
# result : 5550
# j : [student-government-council]
# result : student-government-council
# j : Student
# result :
# j : Council
# result :
# j : /
# result :
# j : Government
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [5621]
# result : 5621
# j : [executive-board]
# result : executive-board
# j : Executive
# result :
# j : Board
# result :
# j : [6836]
# result : 6836
# j : [model-congress-UN]
# result : model-congress-UN
# j : Model
# result :
# j : Congress
# result :
# j : /
# result :
# j : Model
# result :
# j : UN
# result :
# j : [6406]
# result : 6406
# j : [7yr]
# result : 7yr
# j : 7
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5629]
# result : 5629
# j : [awarded-monetary-prize]
# result : awarded-monetary-prize
# j : Awarded
# result :
# j : Monetary
# result :
# j : Prize
# result :
# j : [391467]
# result : 391467
# j : [music-instrumental]
# result : music-instrumental
# j : Music:
# result :
# j : Instrumental
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5625]
# result : 5625
# j : [school-award]
# result : school-award
# j : School
# result :
# j : Award
# result :
# j : [5626]
# result : 5626
# j : [community-award]
# result : community-award
# j : Community
# result :
# j : Award
# result :
# j : [5627]
# result : 5627
# j : [recognized-in-local-media]
# result : recognized-in-local-media
# j : Recognized
# result :
# j : in
# result :
# j : Local
# result :
# j : Media
# result :
# j : [5628]
# result : 5628
# j : [national-recognition]
# result : national-recognition
# j : National
# result :
# j : Recognition
# result :
# j : [5631]
# result : 5631
# j : [received-scholarship-for-achievement]
# result : received-scholarship-for-achievement
# j : Received
# result :
# j : Scholarship
# result :
# j : For
# result :
# j : Achievement
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [391484]
# result : 391484
# j : [other-award]
# result : other-award
# j : Other
# result :
# j : Award
# result :
# j : [5602]
# result : 5602
# j : [hospital-volunteer]
# result : hospital-volunteer
# j : Hospital
#   4%|▍         | 41/1000 [00:00<00:05, 171.95it/s]
# result :
# j : Volunteer
# result :
# j : [6404]
# result : 6404
# j : [5yr]
# result : 5yr
# j : 5
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5626]
# result : 5626
# j : [community-award]
# result : community-award
# j : Community
# result :
# j : Award
# result :
# j : [391484]
# result : 391484
# j : [other-award]
# result : other-award
# j : Other
# result :
# j : Award
# result :
# essay no: 34
# ------------------------------------------------------
# [6420] [nonprofit-ngo-or-charitable-organization] Nonprofit, NGO or Charitable Organization
# [6401] [2yr] 2
# [6331] [member] Member
# [5626] [community-award] Community Award
# [5631] [received-scholarship-for-achievement] Received Scholarship For Achievement
# [391475] [theater-drama] Theater/Drama
# [6401] [2yr] 2
# [8998] [lead-role] Lead role
# [6836] [model-congress-UN] Model Congress / Model UN
# [6402] [3yr] 3
# [6331] [member] Member
# [391458] [career-oriented] Career Oriented
# [6401] [2yr] 2
# [6331] [member] Member
# [5550] [student-government-council] Student Council / Government
# [6400] [1yr] 1
# [8998] [lead-role] Lead role
# [5606] [tutoring-mentoring] Tutoring/Mentoring
# [6401] [2yr] 2
# [6331] [member] Member
#
# ------------------------------------------------------
# words_list_ : ['[6420]', '[nonprofit-ngo-or-charitable-organization]', 'Nonprofit,', 'NGO', 'or', 'Charitable', 'Organization', '[6401]', '[2yr]', '2', '[6331]', '[member]', 'Member', '[5626]', '[community-award]', 'Community', 'Award', '[5631]', '[received-scholarship-for-achievement]', 'Received', 'Scholarship', 'For', 'Achievement', '[391475]', '[theater-drama]', 'Theater/Drama', '[6401]', '[2yr]', '2', '[8998]', '[lead-role]', 'Lead', 'role', '[6836]', '[model-congress-UN]', 'Model', 'Congress', '/', 'Model', 'UN', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[391458]', '[career-oriented]', 'Career', 'Oriented', '[6401]', '[2yr]', '2', '[6331]', '[member]', 'Member', '[5550]', '[student-government-council]', 'Student', 'Council', '/', 'Government', '[6400]', '[1yr]', '1', '[8998]', '[lead-role]', 'Lead', 'role', '[5606]', '[tutoring-mentoring]', 'Tutoring/Mentoring', '[6401]', '[2yr]', '2', '[6331]', '[member]', 'Member']
# ------------------------------------------------------
# j : [6420]
# result : 6420
# j : [nonprofit-ngo-or-charitable-organization]
# result : nonprofit-ngo-or-charitable-organization
# j : Nonprofit,
# result :
# j : NGO
# result :
# j : or
# result :
# j : Charitable
# result :
# j : Organization
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5626]
# result : 5626
# j : [community-award]
# result : community-award
# j : Community
# result :
# j : Award
# result :
# j : [5631]
# result : 5631
# j : [received-scholarship-for-achievement]
# result : received-scholarship-for-achievement
# j : Received
# result :
# j : Scholarship
# result :
# j : For
# result :
# j : Achievement
# result :
# j : [391475]
# result : 391475
# j : [theater-drama]
# result : theater-drama
# j : Theater/Drama
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [6836]
# result : 6836
# j : [model-congress-UN]
# result : model-congress-UN
# j : Model
# result :
# j : Congress
# result :
# j : /
# result :
# j : Model
# result :
# j : UN
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [391458]
# result : 391458
# j : [career-oriented]
# result : career-oriented
# j : Career
# result :
# j : Oriented
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5550]
# result : 5550
# j : [student-government-council]
# result : student-government-council
# j : Student
# result :
# j : Council
# result :
# j : /
# result :
# j : Government
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5606]
# result : 5606
# j : [tutoring-mentoring]
# result : tutoring-mentoring
# j : Tutoring/Mentoring
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# essay no: 36
# ------------------------------------------------------
# [5573] [jewish-student-union] Jewish Student Union
# [6404] [5yr] 5
# [5622] [president] President
# [5626] [community-award] Community Award
# [391470] [research] Research
# [6402] [3yr] 3
# [5624] [committee-leader] Committee Leader
# [391484] [other-award] Other Award
# [5609] [computer-technology-volunteer] Computer / Technology Volunteer
# [6401] [2yr] 2
# [5624] [committee-leader] Committee Leader
#
# ------------------------------------------------------
# words_list_ : ['[5573]', '[jewish-student-union]', 'Jewish', 'Student', 'Union', '[6404]', '[5yr]', '5', '[5622]', '[president]', 'President', '[5626]', '[community-award]', 'Community', 'Award', '[391470]', '[research]', 'Research', '[6402]', '[3yr]', '3', '[5624]', '[committee-leader]', 'Committee', 'Leader', '[391484]', '[other-award]', 'Other', 'Award', '[5609]', '[computer-technology-volunteer]', 'Computer', '/', 'Technology', 'Volunteer', '[6401]', '[2yr]', '2', '[5624]', '[committee-leader]', 'Committee', 'Leader']
# ------------------------------------------------------
# j : [5573]
# result : 5573
# j : [jewish-student-union]
# result : jewish-student-union
# j : Jewish
# result :
# j : Student
# result :
# j : Union
# result :
# j : [6404]
# result : 6404
# j : [5yr]
# result : 5yr
# j : 5
# result :
# j : [5622]
# result : 5622
# j : [president]
# result : president
# j : President
# result :
# j : [5626]
# result : 5626
# j : [community-award]
# result : community-award
# j : Community
# result :
# j : Award
# result :
# j : [391470]
# result : 391470
# j : [research]
# result : research
# j : Research
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [5624]
# result : 5624
# j : [committee-leader]
# result : committee-leader
# j : Committee
# result :
# j : Leader
# result :
# j : [391484]
# result : 391484
# j : [other-award]
# result : other-award
# j : Other
# result :
# j : Award
# result :
# j : [5609]
# result : 5609
# j : [computer-technology-volunteer]
# result : computer-technology-volunteer
# j : Computer
# result :
# j : /
# result :
# j : Technology
# result :
# j : Volunteer
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5624]
# result : 5624
# j : [committee-leader]
# result : committee-leader
# j : Committee
# result :
# j : Leader
# result :
# essay no: 37
# ------------------------------------------------------
# [391467] [music-instrumental] Music: Instrumental
# [6403] [4yr] 4
# [6331] [member] Member
# [5627] [recognized-in-local-media] Recognized in Local Media
# ...
# j : Honor
# result :
# j : Society
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5621]
# result : 5621
# j : [executive-board]
# result : executive-board
# j : Executive
# result :
# j : Board
# result :
# j : [5538]
# result : 5538
# j : [debate-club-team]
# result : debate-club-team
# j : Debate
# result :
# j : Club/Team
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [5621]
# result : 5621
# j : [executive-board]
# result : executive-board
# j : Executive
# result :
# j : Board
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [5606]
# result : 5606
# j : [tutoring-mentoring]
# result : tutoring-mentoring
# j : Tutoring/Mentoring
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5559]
# result : 5559
# j : [school-theater-plays]
# result : school-theater-plays
# j : School
# result :
# j : theater/plays
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5625]
# result : 5625
# j : [school-award]
# result : school-award
# j : School
# result :
# j : Award
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [5600]
# result : 5600
# j : [nursing-home-volunteer]
# result : nursing-home-volunteer
# j : Nursing
# result :
# j : Home
# result :
# j : Volunteer
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# essay no: 994
# ------------------------------------------------------
# [5543] [science-club-team] Science Club/Team
# [6402] [3yr] 3
# [8998] [lead-role] Lead role
# [5627] [recognized-in-local-media] Recognized in Local Media
# [5628] [national-recognition] National Recognition
# [5544] [math-team] Math Team
# [6402] [3yr] 3
# [6331] [member] Member
# [5541] [national-honor-society] National Honor Society
# [6402] [3yr] 3
# [6331] [member] Member
# [5625] [school-award] School Award
# [5606] [tutoring-mentoring] Tutoring/Mentoring
# [6403] [4yr] 4
# [6331] [member] Member
# [5567] [school-jazz-orchestra] School Jazz / Orchestra
# [6401] [2yr] 2
# [6331] [member] Member
# [5605] [volunteer-coach] Volunteer Coach
# [6402] [3yr] 3
# [6331] [member] Member
# [10916] [regional-state-recognition] Regional/State Recognition
# [5613] [after-school-sports-coach] After School Sports Coach
# [6400] [1yr] 1
# [8998] [lead-role] Lead role
#
# ------------------------------------------------------
# words_list_ : ['[5543]', '[science-club-team]', 'Science', 'Club/Team', '[6402]', '[3yr]', '3', '[8998]', '[lead-role]', 'Lead', 'role', '[5627]', '[recognized-in-local-media]', 'Recognized', 'in', 'Local', 'Media', '[5628]', '[national-recognition]', 'National', 'Recognition', '[5544]', '[math-team]', 'Math', 'Team', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[5541]', '[national-honor-society]', 'National', 'Honor', 'Society', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[5625]', '[school-award]', 'School', 'Award', '[5606]', '[tutoring-mentoring]', 'Tutoring/Mentoring', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member', '[5567]', '[school-jazz-orchestra]', 'School', 'Jazz', '/', 'Orchestra', '[6401]', '[2yr]', '2', '[6331]', '[member]', 'Member', '[5605]', '[volunteer-coach]', 'Volunteer', 'Coach', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[5613]', '[after-school-sports-coach]', 'After', 'School', 'Sports', 'Coach', '[6400]', '[1yr]', '1', '[8998]', '[lead-role]', 'Lead', 'role']
# ------------------------------------------------------
# j : [5543]
# result : 5543
# j : [science-club-team]
# result : science-club-team
# j : Science
# result :
# j : Club/Team
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5627]
# result : 5627
# j : [recognized-in-local-media]
# result : recognized-in-local-media
# j : Recognized
# result :
# j : in
# result :
# j : Local
# result :
# j : Media
# result :
# j : [5628]
# result : 5628
# j : [national-recognition]
# result : national-recognition
# j : National
# result :
# j : Recognition
# result :
# j : [5544]
# result : 5544
# j : [math-team]
# result : math-team
# j : Math
# result :
# j : Team
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5541]
# result : 5541
# j : [national-honor-society]
# result : national-honor-society
# j : National
# result :
# j : Honor
# result :
# j : Society
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5625]
# result : 5625
# j : [school-award]
# result : school-award
# j : School
# result :
# j : Award
# result :
# j : [5606]
# result : 5606
# j : [tutoring-mentoring]
# result : tutoring-mentoring
# j : Tutoring/Mentoring
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5567]
# result : 5567
# j : [school-jazz-orchestra]
# result : school-jazz-orchestra
# j : School
# result :
# j : Jazz
# result :
# j : /
# result :
# j : Orchestra
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5605]
# result : 5605
# j : [volunteer-coach]
# result : volunteer-coach
# j : Volunteer
# result :
# j : Coach
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [5613]
# result : 5613
# j : [after-school-sports-coach]
# result : after-school-sports-coach
# j : After
# result :
# j : School
# result :
# j : Sports
# result :
# j : Coach
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# essay no: 995
# ------------------------------------------------------
# [5541] [national-honor-society] National Honor Society
# [6401] [2yr] 2
# [5625] [school-award] School Award
# [10916] [regional-state-recognition] Regional/State Recognition
# [5565] [local-orchestra-symphony-band] Local Orchestra / Symphony / Band
# [6402] [3yr] 3
# [10149] [community-cleanup-service] Community Cleanup / Service
# [6403] [4yr] 4
#
# ------------------------------------------------------
# words_list_ : ['[5541]', '[national-honor-society]', 'National', 'Honor', 'Society', '[6401]', '[2yr]', '2', '[5625]', '[school-award]', 'School', 'Award', '[10916]', '[regional-state-recognition]', 'Regional/State', 'Recognition', '[5565]', '[local-orchestra-symphony-band]', 'Local', 'Orchestra', '/', 'Symphony', '/', 'Band', '[6402]', '[3yr]', '3', '[10149]', '[community-cleanup-service]', 'Community', 'Cleanup', '/', 'Service', '[6403]', '[4yr]', '4']
# ------------------------------------------------------
# j : [5541]
# result : 5541
# j : [national-honor-society]
# result : national-honor-society
# j : National
# result :
# j : Honor
# result :
# j : Society
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [5625]
# result : 5625
# j : [school-award]
# result : school-award
# j : School
# result :
# j : Award
# result :
# j : [10916]
# result : 10916
# j : [regional-state-recognition]
# result : regional-state-recognition
# j : Regional/State
# result :
# j : Recognition
# result :
# j : [5565]
# result : 5565
# j : [local-orchestra-symphony-band]
# result : local-orchestra-symphony-band
# j : Local
# result :
# j : Orchestra
# result :
# j : /
# result :
# j : Symphony
# result :
# j : /
# result :
# j : Band
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [10149]
# result : 10149
# j : [community-cleanup-service]
# result : community-cleanup-service
# j : Community
# result :
# j : Cleanup
# result :
# j : /
# result :
# j : Service
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# essay no: 996
# ------------------------------------------------------
# [6836] [model-congress-UN] Model Congress / Model UN
# [6402] [3yr] 3
# [8998] [lead-role] Lead role
# [5582] [equestrian] Equestrian
# [6411] [12yr] 12
# [5546] [homecoming-committee] Homecoming committee
# [6400] [1yr] 1
# [8998] [lead-role] Lead role
# [5606] [tutoring-mentoring] Tutoring/Mentoring
# [6403] [4yr] 4
# [6331] [member] Member
# [5567] [school-jazz-orchestra] School Jazz / Orchestra
# [6403] [4yr] 4
# [8998] [lead-role] Lead role
#
# ------------------------------------------------------
# words_list_ : ['[6836]', '[model-congress-UN]', 'Model', 'Congress', '/', 'Model', 'UN', '[6402]', '[3yr]', '3', '[8998]', '[lead-role]', 'Lead', 'role', '[5582]', '[equestrian]', 'Equestrian', '[6411]', '[12yr]', '12', '[5546]', '[homecoming-committee]', 'Homecoming', 'committee', '[6400]', '[1yr]', '1', '[8998]', '[lead-role]', 'Lead', 'role', '[5606]', '[tutoring-mentoring]', 'Tutoring/Mentoring', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member', '[5567]', '[school-jazz-orchestra]', 'School', 'Jazz', '/', 'Orchestra', '[6403]', '[4yr]', '4', '[8998]', '[lead-role]', 'Lead', 'role']
# ------------------------------------------------------
# j : [6836]
# result : 6836
# j : [model-congress-UN]
# result : model-congress-UN
# j : Model
# result :
# j : Congress
# result :
# j : /
# result :
# j : Model
# result :
# j : UN
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5582]
# result : 5582
# j : [equestrian]
# result : equestrian
# j : Equestrian
# result :
# j : [6411]
# result : 6411
# j : [12yr]
# result : 12yr
# j : 12
# result :
# j : [5546]
# result : 5546
# j : [homecoming-committee]
# result : homecoming-committee
# j : Homecoming
# result :
# j : committee
# result :
# j : [6400]
# result : 6400
# j : [1yr]
# result : 1yr
# j : 1
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# j : [5606]
# result : 5606
# j : [tutoring-mentoring]
# result : tutoring-mentoring
# j : Tutoring/Mentoring
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5567]
# result : 5567
# j : [school-jazz-orchestra]
# result : school-jazz-orchestra
# j : School
# result :
# j : Jazz
# result :
# j : /
# result :
# j : Orchestra
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [8998]
# result : 8998
# j : [lead-role]
# result : lead-role
# j : Lead
# result :
# j : role
# result :
# essay no: 999
# ------------------------------------------------------
# [5538] [debate-club-team] Debate Club/Team
# [6401] [2yr] 2
# [6331] [member] Member
# [5584] [charity-drive-organizing] Charity Drive Organizing
# [6403] [4yr] 4
# [5621] [executive-board] Executive Board
# [5610] [church] Church
# [6403] [4yr] 4
# [6331] [member] Member
# [5629] [awarded-monetary-prize] Awarded Monetary Prize
# [6837] [athletics-organization] Athletics Organization
# [6402] [3yr] 3
# [5623] [founder] Founder
# [5627] [recognized-in-local-media] Recognized in Local Media
# [5616] [french-club] French Club
# [6402] [3yr] 3
# [6331] [member] Member
# [5602] [hospital-volunteer] Hospital Volunteer
# [6403] [4yr] 4
# [6331] [member] Member
# [5626] [community-award] Community Award
# [5552] [key-club] Key Club
# [6402] [3yr] 3
# [6331] [member] Member
# [5603] [library-volunteer] Library Volunteer
# [6401] [2yr] 2
# [6331] [member] Member
# [5606] [tutoring-mentoring] Tutoring/Mentoring
# [6402] [3yr] 3
# [6331] [member] Member
#
# ------------------------------------------------------
# words_list_ : ['[5538]', '[debate-club-team]', 'Debate', 'Club/Team', '[6401]', '[2yr]', '2', '[6331]', '[member]', 'Member', '[5584]', '[charity-drive-organizing]', 'Charity', 'Drive', 'Organizing', '[6403]', '[4yr]', '4', '[5621]', '[executive-board]', 'Executive', 'Board', '[5610]', '[church]', 'Church', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member', '[5629]', '[awarded-monetary-prize]', 'Awarded', 'Monetary', 'Prize', '[6837]', '[athletics-organization]', 'Athletics', 'Organization', '[6402]', '[3yr]', '3', '[5623]', '[founder]', 'Founder', '[5627]', '[recognized-in-local-media]', 'Recognized', 'in', 'Local', 'Media', '[5616]', '[french-club]', 'French', 'Club', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[5602]', '[hospital-volunteer]', 'Hospital', 'Volunteer', '[6403]', '[4yr]', '4', '[6331]', '[member]', 'Member', '[5626]', '[community-award]', 'Community', 'Award', '[5552]', '[key-club]', 'Key', 'Club', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member', '[5603]', '[library-volunteer]', 'Library', 'Volunteer', '[6401]', '[2yr]', '2', '[6331]', '[member]', 'Member', '[5606]', '[tutoring-mentoring]', 'Tutoring/Mentoring', '[6402]', '[3yr]', '3', '[6331]', '[member]', 'Member']
# ------------------------------------------------------
# j : [5538]
# result : 5538
# j : [debate-club-team]
# result : debate-club-team
# j : Debate
# result :
# j : Club/Team
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5584]
# result : 5584
# j : [charity-drive-organizing]
# result : charity-drive-organizing
# j : Charity
# result :
# j : Drive
# result :
# j : Organizing
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [5621]
# result : 5621
# j : [executive-board]
# result : executive-board
# j : Executive
# result :
# j : Board
# 100%|██████████| 1000/1000 [00:07<00:00, 142.75it/s]
# result :
# j : [5610]
# result : 5610
# j : [church]
# result : church
# j : Church
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5629]
# result : 5629
# j : [awarded-monetary-prize]
# result : awarded-monetary-prize
# j : Awarded
# result :
# j : Monetary
# result :
# j : Prize
# result :
# j : [6837]
# result : 6837
# j : [athletics-organization]
# result : athletics-organization
# j : Athletics
# result :
# j : Organization
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [5623]
# result : 5623
# j : [founder]
# result : founder
# j : Founder
# result :
# j : [5627]
# result : 5627
# j : [recognized-in-local-media]
# result : recognized-in-local-media
# j : Recognized
# result :
# j : in
# result :
# j : Local
# result :
# j : Media
# result :
# j : [5616]
# result : 5616
# j : [french-club]
# result : french-club
# j : French
# result :
# j : Club
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5602]
# result : 5602
# j : [hospital-volunteer]
# result : hospital-volunteer
# j : Hospital
# result :
# j : Volunteer
# result :
# j : [6403]
# result : 6403
# j : [4yr]
# result : 4yr
# j : 4
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5626]
# result : 5626
# j : [community-award]
# result : community-award
# j : Community
# result :
# j : Award
# result :
# j : [5552]
# result : 5552
# j : [key-club]
# result : key-club
# j : Key
# result :
# j : Club
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5603]
# result : 5603
# j : [library-volunteer]
# result : library-volunteer
# j : Library
# result :
# j : Volunteer
# result :
# j : [6401]
# result : 6401
# j : [2yr]
# result : 2yr
# j : 2
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :
# j : [5606]
# result : 5606
# j : [tutoring-mentoring]
# result : tutoring-mentoring
# j : Tutoring/Mentoring
# result :
# j : [6402]
# result : 6402
# j : [3yr]
# result : 3yr
# j : 3
# result :
# j : [6331]
# result : 6331
# j : [member]
# result : member
# j : Member
# result :

# %%
get_all_result__
# Out:
# ['academic',
#  '',
#  '2yr',
#  '',
#  'president',
#  '',
#  'robotics',
#  '',
#  '2yr',
#  '',
#  'president',
#  '',
#  'debate-club-team',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'music-vocal',
#  '',
#  '',
#  '3yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'national-recognition',
#  '',
#  '',
#  'student-government-council',
#  '',
#  '',
#  '',
#  '',
#  '2yr',
#  '',
#  'president',
#  '',
#  'school-award',
#  '',
#  '',
#  'tutoring-mentoring',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'other-club-activity',
#  '',
#  '',
#  '3yr',
#  '',
#  'founder',
#  '',
#  'international-recognition',
#  '',
#  '',
#  'research',
#  '',
#  '1yr',
#  '',
#  'employee',
#  '',
#  'computer-technology-volunteer',
#  '',
#  '',
#  '',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'research',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'research',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'debate-club-team',
#  '',
#  '',
#  '4yr',
#  '',
#  'president',
#  '',
#  'computer-technology-volunteer',
#  '',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'president',
#  '',
#  'won-national-award',
#  '',
#  '',
#  '',
#  'computer-technology-volunteer',
#  '',
#  '',
#  '',
#  '',
#  '3yr',
#  '',
#  'founder',
#  '',
#  'school-jazz-orchestra',
#  '',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'cultural',
#  '',
#  '1yr',
#  '',
#  'president',
#  '',
#  'science-club-team',
#  '',
#  '',
#  '3yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'other-award',
#  '',
#  '',
#  'dance',
#  '',
#  '3yr',
#  '',
#  'member',
#  '',
#  'academic-decathlon',
#  '',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'music-instrumental',
#  '',
#  '',
#  '2yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'science-club-team',
#  '',
#  '',
#  '2yr',
#  '',
#  'executive-board',
#  '',
#  '',
#  'career-oriented',
#  '',
#  '',
#  '2yr',
#  '',
#  'president',
#  '',
#  'career-oriented',
#  '',
#  '',
#  '2yr',
#  '',
#  'president',
#  '',
#  'computer-technology-volunteer',
#  '',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'other-award',
#  '',
#  '',
#  'student-government-council',
#  '',
#  '',
#  '',
#  '',
#  '3yr',
#  '',
#  'member',
#  '',
#  'academic',
#  '',
#  '4yr',
#  '',
#  'president',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'academic',
#  '',
#  '2yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'won-national-award',
#  '',
#  '',
#  '',
#  'music-instrumental',
#  '',
#  '',
#  '12yr',
#  '',
#  'member',
#  '',
#  'awarded-monetary-prize',
#  '',
#  '',
#  '',
#  'received-scholarship-for-achievement',
#  '',
#  '',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'social-justice',
#  '',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'community-cleanup-service',
#  '',
#  '',
#  '',
#  '',
#  '2yr',
#  '',
#  'founder',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'quiz-bowl-academic-bowl',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'math-team',
#  '',
#  '',
#  '4yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'community-cleanup-service',
#  '',
#  '',
#  '',
#  '',
#  '3yr',
#  '',
#  'executive-board',
#  '',
#  '',
#  'other-award',
#  '',
#  '',
#  'academic',
#  '',
#  '3yr',
#  '',
#  'member',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'received-scholarship-for-achievement',
#  '',
#  '',
#  '',
#  '',
#  'theater-drama',
#  '',
#  '2yr',
#  '',
#  'executive-board',
#  '',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'other-club-activity',
#  '',
#  '',
#  '3yr',
#  '',
#  'president',
#  '',
#  'student-government-council',
#  '',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'committee-leader',
#  '',
#  '',
#  'church',
#  '',
#  '2yr',
#  '',
#  'employee',
#  '',
#  'environmental',
#  '',
#  '4yr',
#  '',
#  'president',
#  '',
#  'won-national-award',
#  '',
#  '',
#  '',
#  'career-oriented',
#  '',
#  '',
#  '3yr',
#  '',
#  'employee',
#  '',
#  'career-oriented',
#  '',
#  '',
#  '3yr',
#  '',
#  'member',
#  '',
#  'academic',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'won-national-award',
#  '',
#  '',
#  '',
#  'school-newspaper-magazine-journalism',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'marching-band',
#  '',
#  '',
#  '4yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'school-theater-plays',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'research',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'quiz-bowl-academic-bowl',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'math-team',
#  '',
#  '',
#  '4yr',
#  '',
#  'president',
#  '',
#  'tutoring-mentoring',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'other-club-activity',
#  '',
#  '',
#  '3yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'academic',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'student-government-council',
#  '',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'research',
#  '',
#  '2yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'national-recognition',
#  '',
#  '',
#  'awarded-monetary-prize',
#  '',
#  '',
#  '',
#  'won-national-award',
#  '',
#  '',
#  '',
#  'received-scholarship-for-achievement',
#  '',
#  '',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'other-award',
#  '',
#  '',
#  'international-recognition',
#  '',
#  '',
#  'research',
#  '',
#  '1yr',
#  '',
#  'employee',
#  '',
#  'research',
#  '',
#  '1yr',
#  '',
#  'employee',
#  '',
#  'student-government-council',
#  '',
#  '',
#  '',
#  '',
#  '3yr',
#  '',
#  'executive-board',
#  '',
#  '',
#  'model-congress-UN',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7yr',
#  '',
#  'president',
#  '',
#  'awarded-monetary-prize',
#  '',
#  '',
#  '',
#  'music-instrumental',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'school-award',
#  '',
#  '',
#  'community-award',
#  '',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'national-recognition',
#  '',
#  '',
#  'received-scholarship-for-achievement',
#  '',
#  '',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'other-award',
#  '',
#  '',
#  'hospital-volunteer',
#  '',
#  '',
#  '5yr',
#  '',
#  'member',
#  '',
#  'community-award',
#  '',
#  '',
#  'other-award',
#  '',
#  '',
#  'nonprofit-ngo-or-charitable-organization',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'community-award',
#  '',
#  '',
#  'received-scholarship-for-achievement',
#  '',
#  '',
#  '',
#  '',
#  'theater-drama',
#  '',
#  '2yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'model-congress-UN',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '3yr',
#  '',
#  'member',
#  '',
#  'career-oriented',
#  '',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'student-government-council',
#  '',
#  '',
#  '',
#  '',
#  '1yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'tutoring-mentoring',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'jewish-student-union',
#  '',
#  '',
#  '',
#  '5yr',
#  '',
#  'president',
#  '',
#  'community-award',
#  '',
#  '',
#  'research',
#  '',
#  '3yr',
#  '',
#  'committee-leader',
#  '',
#  '',
#  'other-award',
#  '',
#  '',
#  'computer-technology-volunteer',
#  '',
#  '',
#  '',
#  '',
#  '2yr',
#  '',
#  'committee-leader',
#  '',
#  '',
#  'music-instrumental',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'received-scholarship-for-achievement',
#  '',
#  '',
#  '',
#  '',
#  'research',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'other-award',
#  '',
#  '',
#  'research',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'research',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'quiz-bowl-academic-bowl',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'won-national-award',
#  '',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'student-government-council',
#  '',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'national-honor-society',
#  '',
#  '',
#  '',
#  '1yr',
#  '',
#  'president',
#  '',
#  'nonprofit-ngo-or-charitable-organization',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '3yr',
#  '',
#  'executive-board',
#  '',
#  '',
#  'community-cleanup-service',
#  '',
#  '',
#  '',
#  '',
#  '3yr',
#  '',
#  'founder',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'other-club-activity',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'awarded-monetary-prize',
#  '',
#  '',
#  '',
#  'won-national-award',
#  '',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'music-instrumental',
#  '',
#  '',
#  '4yr',
#  '',
#  'member',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'foreign-exchange',
#  '',
#  '',
#  '1yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'other-club-activity',
#  '',
#  '',
#  '1yr',
#  '',
#  'member',
#  '',
#  'research',
#  '',
#  '1yr',
#  '',
#  'employee',
#  '',
#  'cultural',
#  '',
#  '3yr',
#  '',
#  'committee-leader',
#  '',
#  '',
#  'local-orchestra-symphony-band',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'chinese-club',
#  '',
#  '',
#  '3yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'athletics-organization',
#  '',
#  '',
#  '1yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'american-cancer-society',
#  '',
#  '',
#  '',
#  '4yr',
#  '',
#  'president',
#  '',
#  'debate-club-team',
#  '',
#  '',
#  '4yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'won-national-award',
#  '',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'model-congress-UN',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2yr',
#  '',
#  'founder',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'local-orchestra-symphony-band',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'science-club-team',
#  '',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'career-oriented',
#  '',
#  '',
#  '3yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'awarded-monetary-prize',
#  '',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'hospital-volunteer',
#  '',
#  '',
#  '2yr',
#  '',
#  'member',
#  '',
#  'nonprofit-ngo-or-charitable-organization',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2yr',
#  '',
#  'president',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'music-instrumental',
#  '',
#  '',
#  '12yr',
#  '',
#  'member',
#  '',
#  'recognized-in-local-media',
#  '',
#  '',
#  '',
#  '',
#  'national-recognition',
#  '',
#  '',
#  'awarded-monetary-prize',
#  '',
#  '',
#  '',
#  'won-national-award',
#  '',
#  '',
#  '',
#  'received-scholarship-for-achievement',
#  '',
#  '',
#  '',
#  '',
#  'regional-state-recognition',
#  '',
#  '',
#  'international-recognition',
#  '',
#  '',
#  'school-jazz-orchestra',
#  '',
#  '',
#  '',
#  '',
#  '7yr',
#  '',
#  'lead-role',
#  '',
#  '',
#  'community-award',
#  '',
#  '',
#  ...]

# %%
# yr들어간 리스트값은 제거
get_all_result_ = [] 
for m in get_all_result__:
    if 'yr' in m:
        pass
    else:
        get_all_result_.append(m)

# %%
# remove null
get_all_result_ = list(filter(None, get_all_result_))

# %%
count={}
for i in get_all_result_:
    try: count[i] += 1
    except: count[i]=1
print(count)
# Out:
# {'academic': 39, 'president': 337, 'robotics': 6, 'debate-club-team': 89, 'member': 843, 'regional-state-recognition': 379, 'music-vocal': 10, 'lead-role': 510, 'national-recognition': 220, 'student-government-council': 117, 'school-award': 346, 'tutoring-mentoring': 143, 'other-club-activity': 41, 'founder': 166, 'international-recognition': 25, 'research': 49, 'employee': 42, 'computer-technology-volunteer': 44, 'won-national-award': 167, 'school-jazz-orchestra': 39, 'cultural': 8, 'science-club-team': 100, 'other-award': 42, 'dance': 31, 'academic-decathlon': 9, 'music-instrumental': 32, 'executive-board': 183, 'career-oriented': 18, 'awarded-monetary-prize': 120, 'received-scholarship-for-achievement': 96, 'social-justice': 9, 'recognized-in-local-media': 255, 'community-cleanup-service': 70, 'quiz-bowl-academic-bowl': 54, 'math-team': 67, 'theater-drama': 14, 'committee-leader': 85, 'church': 24, 'environmental': 3, 'school-newspaper-magazine-journalism': 84, 'marching-band': 21, 'school-theater-plays': 41, 'model-congress-UN': 58, 'community-award': 220, 'hospital-volunteer': 31, 'nonprofit-ngo-or-charitable-organization': 53, 'jewish-student-union': 5, 'national-honor-society': 150, 'foreign-exchange': 3, 'local-orchestra-symphony-band': 33, 'chinese-club': 6, 'athletics-organization': 13, 'american-cancer-society': 8, 'school-band': 25, 'chess': 9, 'gay-straight-alliance': 13, 'school-choir': 27, 'family-responsibilities': 6, 'deca-distributive-education-clubs-of-america': 14, 'multicultural-international-club': 11, 'key-club': 37, 'science-math': 24, 'foreign-language': 9, 'french-club': 22, 'library-volunteer': 16, 'american-red-cross': 11, 'art': 17, 'italian-club': 2, 'conservancy-volunteer': 4, 'photography-film': 14, 'volunteer-coach': 11, 'lgbt': 5, 'future-business-leaders-of-america-fbla': 20, 'improv-club-team': 4, 'choir': 26, 'charity-drive-organizing': 15, 'after-school-sports-coach': 8, 'rotary-club': 9, 'yearbook': 17, 'clean-ocean-beach-sweeps-river-cleanup': 6, 'school-spirit': 4, 'nursing-home-volunteer': 10, 'religious': 6, 'after-school-program-coordinator': 10, 'spanish-club': 29, 'book-buddies': 4, 'film': 4, 'outdoors-hiking-club': 9, 'prom-committee': 13, 'german-club': 3, 'mock-trial': 7, 'political-campaign': 20, 'drama-production-crew': 5, 'community-or-summer-theater-plays': 11, 'equestrian': 3, 'animal-foster-care-provider-animal-rescue': 4, 'boy-girl-scouts': 19, 'philosophy-club': 6, 'student-activities-committee': 10, 'big-brother-big-sister': 7, 'habitat-for-humanity': 8, 'junior-classical-league-latin-club': 10, 'diversity-committee-minority-initiative': 17, 'other-religious-affiliation': 5, 'junior-r.o.t.c': 1, 'homecoming-committee': 8, 'green-club': 4, 'broadcast-journalism-media-television': 10, 'march-of-dimes': 2, 'special-olympics': 2, 'best-buddies': 3, 'younglife-christian': 1, 'culinary': 4, 'japanese-club': 3, 'beta-club': 8, 'latino-student-association': 2, '4-h': 1, 'muslim-students-association': 2, 'help-save-our-environment': 2, 'admissions-or-post-acceptance-committee': 4, 'black-student-union': 6, 'world-global-affairs-club': 7, 'asian-club-asian-interactive-youth-association': 4, 'disaster-relief': 2, 'mathematics-engineering-science-and-achievement-mesa': 4, 'buddhist-club': 1, 'lions-club': 1, 'ymca-ywca': 1, 'emergency-medical-service-fire-dept-volunteer': 1, 'biking-cycling': 1, 'students-against-drunk-driving-destructive-decisions-sadd': 2, 'american-heart-association': 1}

# %%
word_list = sorted(count.items(), key=lambda x: x[1], reverse=True)

# %%
word_list
# Out:
# [('member', 843),
#  ('lead-role', 510),
#  ('regional-state-recognition', 379),
#  ('school-award', 346),
#  ('president', 337),
#  ('recognized-in-local-media', 255),
#  ('national-recognition', 220),
#  ('community-award', 220),
#  ('executive-board', 183),
#  ('won-national-award', 167),
#  ('founder', 166),
#  ('national-honor-society', 150),
#  ('tutoring-mentoring', 143),
#  ('awarded-monetary-prize', 120),
#  ('student-government-council', 117),
#  ('science-club-team', 100),
#  ('received-scholarship-for-achievement', 96),
#  ('debate-club-team', 89),
#  ('committee-leader', 85),
#  ('school-newspaper-magazine-journalism', 84),
#  ('community-cleanup-service', 70),
#  ('math-team', 67),
#  ('model-congress-UN', 58),
#  ('quiz-bowl-academic-bowl', 54),
#  ('nonprofit-ngo-or-charitable-organization', 53),
#  ('research', 49),
#  ('computer-technology-volunteer', 44),
#  ('employee', 42),
#  ('other-award', 42),
#  ('other-club-activity', 41),
#  ('school-theater-plays', 41),
#  ('academic', 39),
#  ('school-jazz-orchestra', 39),
#  ('key-club', 37),
#  ('local-orchestra-symphony-band', 33),
#  ('music-instrumental', 32),
#  ('dance', 31),
#  ('hospital-volunteer', 31),
#  ('spanish-club', 29),
#  ('school-choir', 27),
#  ('choir', 26),
#  ('international-recognition', 25),
#  ('school-band', 25),
#  ('church', 24),
#  ('science-math', 24),
#  ('french-club', 22),
#  ('marching-band', 21),
#  ('future-business-leaders-of-america-fbla', 20),
#  ('political-campaign', 20),
#  ('boy-girl-scouts', 19),
#  ('career-oriented', 18),
#  ('art', 17),
#  ('yearbook', 17),
#  ('diversity-committee-minority-initiative', 17),
#  ('library-volunteer', 16),
#  ('charity-drive-organizing', 15),
#  ('theater-drama', 14),
#  ('deca-distributive-education-clubs-of-america', 14),
#  ('photography-film', 14),
#  ('athletics-organization', 13),
#  ('gay-straight-alliance', 13),
#  ('prom-committee', 13),
#  ('multicultural-international-club', 11),
#  ('american-red-cross', 11),
#  ('volunteer-coach', 11),
#  ('community-or-summer-theater-plays', 11),
#  ('music-vocal', 10),
#  ('nursing-home-volunteer', 10),
#  ('after-school-program-coordinator', 10),
#  ('student-activities-committee', 10),
#  ('junior-classical-league-latin-club', 10),
#  ('broadcast-journalism-media-television', 10),
#  ('academic-decathlon', 9),
#  ('social-justice', 9),
#  ('chess', 9),
#  ('foreign-language', 9),
#  ('rotary-club', 9),
#  ('outdoors-hiking-club', 9),
#  ('cultural', 8),
#  ('american-cancer-society', 8),
#  ('after-school-sports-coach', 8),
#  ('habitat-for-humanity', 8),
#  ('homecoming-committee', 8),
#  ('beta-club', 8),
#  ('mock-trial', 7),
#  ('big-brother-big-sister', 7),
#  ('world-global-affairs-club', 7),
#  ('robotics', 6),
#  ('chinese-club', 6),
#  ('family-responsibilities', 6),
#  ('clean-ocean-beach-sweeps-river-cleanup', 6),
#  ('religious', 6),
#  ('philosophy-club', 6),
#  ('black-student-union', 6),
#  ('jewish-student-union', 5),
#  ('lgbt', 5),
#  ('drama-production-crew', 5),
#  ('other-religious-affiliation', 5),
#  ('conservancy-volunteer', 4),
#  ('improv-club-team', 4),
#  ('school-spirit', 4),
#  ('book-buddies', 4),
#  ('film', 4),
#  ('animal-foster-care-provider-animal-rescue', 4),
#  ('green-club', 4),
#  ('culinary', 4),
#  ('admissions-or-post-acceptance-committee', 4),
#  ('asian-club-asian-interactive-youth-association', 4),
#  ('mathematics-engineering-science-and-achievement-mesa', 4),
#  ('environmental', 3),
#  ('foreign-exchange', 3),
#  ('german-club', 3),
#  ('equestrian', 3),
#  ('best-buddies', 3),
#  ('japanese-club', 3),
#  ('italian-club', 2),
#  ('march-of-dimes', 2),
#  ('special-olympics', 2),
#  ('latino-student-association', 2),
#  ('muslim-students-association', 2),
#  ('help-save-our-environment', 2),
#  ('disaster-relief', 2),
#  ('students-against-drunk-driving-destructive-decisions-sadd', 2),
#  ('junior-r.o.t.c', 1),
#  ('younglife-christian', 1),
#  ('4-h', 1),
#  ('buddhist-club', 1),
#  ('lions-club', 1),
#  ('ymca-ywca', 1),
#  ('emergency-medical-service-fire-dept-volunteer', 1),
#  ('biking-cycling', 1),
#  ('american-heart-association', 1)]

# %%
file_path = "./DataEssay/refile/top_college_extracurricular_activities_keywords_1000_result.json"
with open(file_path, 'w') as outfile:
    json.dump(word_list, outfile)
