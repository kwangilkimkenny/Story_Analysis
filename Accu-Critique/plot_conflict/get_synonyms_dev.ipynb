# %%
# !pip install spacy-wordnet
# Out:
# Collecting spacy-wordnet
#   Downloading spacy_wordnet-0.0.5-py2.py3-none-any.whl (650 kB)
# Collecting nltk<3.4,>=3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
# Requirement already satisfied: six in c:\users\cacki\anaconda3\envs\py37torch\lib\site-packages (from nltk<3.4,>=3.3->spacy-wordnet) (1.15.0)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py): started
#   Building wheel for nltk (setup.py): finished with status 'done'
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394468 sha256=52b51fb4d9d5aadf6f14b6a2d4c216cb68436d30ea38d12c3c16ca6198e4f81d
#   Stored in directory: c:\users\cacki\appdata\local\pip\cache\wheels\9b\fd\0c\d92302c876e5de87ebd7fc0979d82edb93e2d8d768bf71fac4
# Successfully built nltk
# Installing collected packages: nltk, spacy-wordnet
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.6.2
#     Uninstalling nltk-3.6.2:
#       Successfully uninstalled nltk-3.6.2
# Successfully installed nltk-3.3 spacy-wordnet-0.0.5

# %%
import spacy

from spacy_wordnet.wordnet_annotator import WordnetAnnotator 

# Load an spacy model (supported models are "es", "en" and "pt") 
nlp = spacy.load('en_core_web_lg')
# Spacy 3.x
nlp.add_pipe("spacy_wordnet", after='tagger', config={'lang': nlp.lang})
# Spacy 2.x
# self.nlp_en.add_pipe(WordnetAnnotator(self.nlp_en.lang))
token = nlp('prices')[0]

# wordnet object link spacy token with nltk wordnet interface by giving acces to
# synsets and lemmas 
token._.wordnet.synsets()
token._.wordnet.lemmas()

# And automatically tags with wordnet domains
token._.wordnet.wordnet_domains()
# Out:
# []

# %%
sentences_domains = ['book_keeping',
 'numismatics',
 'betting',
 'banking',
 'insurance',
 'racing',
 'social',
 'money',
 'finance',
 'post',
 'law',
 'commerce',
 'enterprise',
 'telegraphy',
 'mathematics',
 'industry',
 'economy',
 'tax',
 'free_time',
 'jewellery',
 'statistics',
 'exchange',
 'buildings',
 'diplomacy',
 'book_keeping',
 'factotum',
 'agriculture',
 'electrotechnology',
 'numismatics',
 'person',
 'telephony',
 'metrology',
 'politics',
 'betting',
 'banking',
 'sociology',
 'insurance',
 'racing',
 'publishing',
 'social',
 'money',
 'card',
 'finance',
 'post',
 'law',
 'topography',
 'tourism',
 'commerce',
 'philology',
 'telegraphy',
 'enterprise',
 'mathematics',
 'time_period',
 'town_planning',
 'animal_husbandry',
 'pure_science',
 'computer_science',
 'economy',
 'industry',
 'tax',
 'quality',
 'free_time',
 'philately',
 'railway',
 'jewellery',
 'telecommunication',
 'statistics',
 'exchange',
 'economy',
 'music',
 'social',
 'economy',
 'commerce',
 'social',
 'commerce']

enriched_sentence = []
#sentence = nlp('I want to withdraw 5,000 euros')
sentence = nlp("""My hand lingered on the cold metal doorknob. I closed my eyes as the Vancouver breeze ran its chilling fingers through my hair. The man I was about to meet was infamous for demanding perfection. But the beguiling music that faintly fluttered past the unlatched window’s curtain drew me forward, inviting me to cross the threshold. Stepping into the apartment, under the watchful gaze of an emerald-eyed cat portrait, I entered the sweeping B Major scale.

Led by my intrinsic attraction towards music, coupled with the textured layers erupting the instant my fingers grazed the ivory keys, driving the hammers to shoot vibrations up in the air all around me, I soon fell in love with this new extension of my body and mind. My mom began to notice my aptitude for piano when I began returning home with trophies in my arms. These precious experiences fueled my conviction as a rising musician, but despite my confidence, I felt like something was missing.

Back in the drafty apartment, I smiled nervously and walked towards the piano from which the music emanated. Ian Parker, my new piano teacher, eyes-closed and dressed in black glided his hands effortlessly across the keys. I stood beside a leather chair, waiting as he finished the phrase. He stood up. I sat down.

Chopin Black Key Etude — a piece I knew so well I could play it eyes-closed. I took a breath and positioned my right hand in a G-flat 2nd inversion. 
Just one measure in, I was stopped. 
	“Start again.”
	Taken by surprise, I spun left. His eyes were on the score, not me. 
	I started again. Past the first measure, first phrase, then stopped again. What is going on? 
	
	“Are you listening?”
I nodded. Of course I am. 
“But are you really listening?”

As we slowly dissected each measure, I felt my confidence slip away. The piece was being chipped into fragments. Unlike my previous teachers, who listened to a full performance before giving critical feedback, Ian stopped me every five seconds. One hour later, we only got through half a page. 

Each consecutive week, the same thing happened. I struggled to meet his expectations. 
“I’m not here to teach you just how to play. I’m here to teach you how to listen.” 
I realized what Ian meant — listening involves taking what we hear and asking: is this the sound I want? What story am I telling through my interpretation? 

Absorbed in the music, I allowed my instincts and muscle memory to take over, flying past the broken tritones or neapolitan chords. But even if I was playing the right notes, it didn’t matter. Becoming immersed in the cascading arpeggio waterfalls, thundering basses, and fairydust trills was actually the easy part, which brought me joy and fueled my love for music in the first place. However, music is not just about me. True artists perform for their audience, and to bring them the same joy, to turn playing into magic-making, they must listen as the audience. 

The lesson Ian taught me echoes beyond practice rooms and concert halls. I’ve learned to listen as I explore the hidden dialogue between voices, to pauses and silence, equally as powerful as words. Listening is performing as a soloist backed up by an orchestra. Listening is calmly responding during heated debates and being the last to speak in a SPS Harkness discussion. It’s even bouncing jokes around the dining table with family. I’ve grown to envision how my voice will impact the stories of those listening to me.

To this day, my lessons with Ian continue to be tough, consisting of 80% discussion and 20% playing. When we were both so immersed in the music that I managed to get to the end of the piece before he looked up to say, “Bravo.” Now, even when I practice piano alone, I repeat my refrain: Are you listening?  """
)


# For each token in the sentence
for token in sentence:
    # We get those synsets within the desired domains
    synsets = token._.wordnet.wordnet_synsets_for_domain(sentences_domains)
    print("synsets:", synsets)
    if not synsets:
        enriched_sentence.append(token.text)
    else:
        lemmas_for_synset = [lemma for s in synsets for lemma in s.lemma_names()]
        # If we found a synset in the economy domains
        # we get the variants and add them to the enriched sentence
        enriched_sentence.append('({})'.format(','.join(set(lemmas_for_synset))))

# Let's see our enriched sentence
print(' '.join(enriched_sentence))
result = ' '.join(enriched_sentence)
type(result)
# Out:
# synsets: []
# synsets: [Synset('hand.n.01'), Synset('hired_hand.n.01'), Synset('handwriting.n.01'), Synset('hand.n.06'), Synset('hand.n.08'), Synset('hand.n.09'), Synset('hand.n.10'), Synset('bridge_player.n.01'), Synset('pass.v.05')]
# synsets: []
# synsets: [Synset('on.a.01')]
# synsets: []
# synsets: []
# synsets: [Synset('metallic_element.n.01'), Synset('alloy.n.01'), Synset('metallic.a.01')]
# synsets: [Synset('doorknob.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('close_up.v.01'), Synset('close.v.06'), Synset('close.v.07'), Synset('close.v.09'), Synset('close.v.10'), Synset('closed.a.02')]
# synsets: []
# synsets: [Synset('eye.n.01'), Synset('center.n.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02'), Synset('equally.r.01')]
# synsets: []
# synsets: [Synset('vancouver.n.02')]
# synsets: [Synset('cinch.n.01'), Synset('breeze.v.02')]
# synsets: [Synset('run.v.01'), Synset('run.v.03'), Synset('operate.v.01'), Synset('run.v.06'), Synset('function.v.01'), Synset('range.v.01'), Synset('campaign.v.01'), Synset('tend.v.01'), Synset('run.v.19'), Synset('carry.v.15'), Synset('run.v.25'), Synset('run.v.26'), Synset('run.v.29'), Synset('ply.v.03'), Synset('hunt.v.01'), Synset('race.v.02'), Synset('melt.v.01')]
# synsets: [Synset('information_technology.n.01')]
# synsets: [Synset('cool.v.01')]
# synsets: [Synset('finger.n.01'), Synset('finger.n.02'), Synset('finger.v.03'), Synset('finger.v.04')]
# synsets: []
# synsets: []
# synsets: [Synset('hair.n.01'), Synset('haircloth.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('man.n.01'), Synset('serviceman.n.01'), Synset('man.n.03'), Synset('homo.n.02'), Synset('man.n.05'), Synset('valet.n.01'), Synset('man.n.08')]
# synsets: []
# synsets: [Synset('washington.n.02'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('approximately.r.01'), Synset('about.r.07')]
# synsets: []
# synsets: [Synset('meet.n.01'), Synset('converge.v.01'), Synset('meet.v.04'), Synset('meet.v.05'), Synset('meet.v.06'), Synset('meet.v.07'), Synset('meet.v.10'), Synset('touch.v.05')]
# synsets: [Synset('washington.n.02'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: []
# synsets: [Synset('demand.v.01'), Synset('necessitate.v.01'), Synset('demand.v.03'), Synset('demand.v.04'), Synset('demand.v.05')]
# synsets: []
# synsets: []
# synsets: [Synset('merely.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('past.n.01'), Synset('past.n.02'), Synset('past.a.01'), Synset('by.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('window.n.01'), Synset('window.n.03'), Synset('window.n.05'), Synset('windowpane.n.01'), Synset('window.n.07'), Synset('window.n.08')]
# synsets: []
# synsets: [Synset('curtain.n.01')]
# synsets: [Synset('trace.v.02'), Synset('draw.v.04'), Synset('draw.v.06'), Synset('describe.v.01'), Synset('draw.v.09'), Synset('withdraw.v.09'), Synset('draw.v.14'), Synset('draw.v.18'), Synset('absorb.v.04'), Synset('attract.v.01'), Synset('string.v.01'), Synset('tie.v.02'), Synset('draw.v.36')]
# synsets: [Synset('maine.n.01')]
# synsets: [Synset('forward.v.01'), Synset('ahead.r.03')]
# synsets: []
# synsets: []
# synsets: [Synset('maine.n.01')]
# synsets: []
# synsets: [Synset('crisscross.n.01'), Synset('cross.n.03'), Synset('hybrid.n.03'), Synset('hybridization.n.01'), Synset('traverse.v.01'), Synset('intersect.v.01'), Synset('cross.v.07'), Synset('crossbreed.v.01')]
# synsets: []
# synsets: [Synset('threshold.n.01'), Synset('doorway.n.01'), Synset('doorsill.n.01')]
# synsets: []
# synsets: [Synset('step.v.03'), Synset('step.v.07'), Synset('pace.v.03')]
# synsets: []
# synsets: []
# synsets: [Synset('apartment.n.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('emerald.n.01'), Synset('emerald.n.02'), Synset('emerald.n.03')]
# synsets: []
# synsets: []
# synsets: [Synset('computerized_tomography.n.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('enter.v.02'), Synset('enroll.v.01'), Synset('record.v.01'), Synset('insert.v.01')]
# synsets: []
# synsets: []
# synsets: [Synset('bel.n.01'), Synset('barn.n.02')]
# synsets: [Synset('major.n.02'), Synset('major.n.03'), Synset('major.v.01'), Synset('major.a.01'), Synset('major.a.03'), Synset('major.a.05'), Synset('major.a.07')]
# synsets: [Synset('scale.n.01'), Synset('scale.n.02'), Synset('scale.n.03'), Synset('scale.n.06'), Synset('scale.n.07'), Synset('scale.n.08'), Synset('scale.v.01'), Synset('scale.v.02'), Synset('scale.v.04'), Synset('scale.v.07'), Synset('scale.v.08')]
# synsets: []
# synsets: []
# synsets: [Synset('light-emitting_diode.n.01'), Synset('run.v.03'), Synset('head.v.02'), Synset('conduct.v.02'), Synset('precede.v.04')]
# synsets: [Synset('by.r.01')]
# synsets: []
# synsets: [Synset('intrinsic.a.01')]
# synsets: [Synset('attraction.n.02')]
# synsets: []
# synsets: [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04')]
# synsets: []
# synsets: [Synset('couple.v.02'), Synset('copulate.v.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('layer.n.01'), Synset('layer.n.02')]
# synsets: [Synset('erupt.v.05'), Synset('erupt.v.08')]
# synsets: []
# synsets: [Synset('blink_of_an_eye.n.01'), Synset('moment.n.01'), Synset('instantaneous.s.01')]
# synsets: []
# synsets: [Synset('finger.n.01'), Synset('finger.n.02'), Synset('finger.v.03'), Synset('finger.v.04')]
# synsets: [Synset('crop.v.04')]
# synsets: []
# synsets: [Synset('ivory.n.01')]
# synsets: [Synset('key.n.01'), Synset('key.n.03'), Synset('key.n.04'), Synset('key.n.05'), Synset('key.n.07'), Synset('key.n.12'), Synset('keystone.n.02'), Synset('key.n.15'), Synset('key.v.04')]
# synsets: []
# synsets: [Synset('driving.n.02'), Synset('drive.v.01'), Synset('drive.v.02'), Synset('drive.v.19')]
# synsets: []
# synsets: [Synset('hammer.n.02'), Synset('mallet.n.02'), Synset('hammer.n.07'), Synset('hammer.v.01'), Synset('forge.v.01')]
# synsets: []
# synsets: [Synset('shoot.n.01'), Synset('shoot.v.02'), Synset('film.v.01'), Synset('photograph.v.01'), Synset('shoot.v.14'), Synset('fritter.v.01'), Synset('shoot.v.18')]
# synsets: [Synset('vibration.n.01'), Synset('oscillation.n.02')]
# synsets: [Synset('up.a.01'), Synset('up.s.07')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: []
# synsets: [Synset('air.n.01'), Synset('air.n.02'), Synset('atmosphere.n.03'), Synset('tune.n.01'), Synset('air.n.08'), Synset('air_travel.n.01'), Synset('air.v.02'), Synset('air.v.03'), Synset('publicize.v.01')]
# synsets: [Synset('all.a.01'), Synset('wholly.r.01')]
# synsets: [Synset('approximately.r.01')]
# synsets: [Synset('maine.n.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('hide.n.01'), Synset('fell.n.03'), Synset('fell.v.01'), Synset('fall.v.01'), Synset('descend.v.01'), Synset('fall.v.04'), Synset('decrease.v.01')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: [Synset('love.n.01'), Synset('beloved.n.01'), Synset('love.n.04'), Synset('love.v.02')]
# synsets: []
# synsets: []
# synsets: [Synset('new.a.01'), Synset('newly.r.01')]
# synsets: [Synset('extension.n.01'), Synset('extension.n.02'), Synset('propagation.n.01'), Synset('extension.n.06'), Synset('extension.n.09'), Synset('extension.n.10'), Synset('annex.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('body.n.01'), Synset('body.n.02'), Synset('body.n.04'), Synset('torso.n.01'), Synset('body.n.06'), Synset('consistency.n.01'), Synset('soundbox.n.01')]
# synsets: []
# synsets: [Synset('mind.n.01'), Synset('take_care.v.02'), Synset('heed.v.01')]
# synsets: []
# synsets: []
# synsets: [Synset('ma.n.01')]
# synsets: [Synset('get_down.v.07')]
# synsets: []
# synsets: [Synset('notice.n.04'), Synset('poster.n.01'), Synset('notice.n.07'), Synset('detect.v.01'), Synset('comment.v.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('piano.n.01'), Synset('piano.n.02')]
# synsets: []
# synsets: []
# synsets: [Synset('get_down.v.07')]
# synsets: [Synset('return.v.01'), Synset('refund.v.01'), Synset('render.v.05'), Synset('return.v.14'), Synset('render.v.04')]
# synsets: [Synset('home.n.01'), Synset('dwelling.n.01'), Synset('home.n.03'), Synset('home.n.07'), Synset('family.n.01'), Synset('home.s.03'), Synset('home.r.02')]
# synsets: []
# synsets: []
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: []
# synsets: [Synset('weaponry.n.01'), Synset('coat_of_arms.n.01'), Synset('arm.n.01'), Synset('weapon.n.01'), Synset('branch.n.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('fuel.v.01'), Synset('fueled.a.01')]
# synsets: []
# synsets: [Synset('conviction.n.02')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02'), Synset('equally.r.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02')]
# synsets: [Synset('rebellion.n.02'), Synset('rise.v.01'), Synset('rise.v.02'), Synset('originate.v.01')]
# synsets: [Synset('musician.n.01'), Synset('musician.n.02')]
# synsets: []
# synsets: [Synset('merely.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('assurance.n.01'), Synset('confidence.n.04')]
# synsets: []
# synsets: []
# synsets: [Synset('felt.n.01'), Synset('feel.v.03')]
# synsets: [Synset('wish.v.02'), Synset('like.a.01'), Synset('alike.a.01')]
# synsets: []
# synsets: [Synset('washington.n.02'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('neglect.v.01'), Synset('miss.v.06')]
# synsets: []
# synsets: []
# synsets: [Synset('back.n.01'), Synset('rear.n.05'), Synset('back.n.03'), Synset('binding.n.05'), Synset('back.n.08'), Synset('back.v.01'), Synset('back.v.02'), Synset('back.v.05'), Synset('bet_on.v.01'), Synset('back.r.01'), Synset('back.r.02'), Synset('back.r.03')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('apartment.n.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('walk.v.01'), Synset('walk.v.04'), Synset('walk.v.09')]
# synsets: []
# synsets: []
# synsets: [Synset('piano.n.01'), Synset('piano.n.02')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('parker.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('new.a.01'), Synset('newly.r.01')]
# synsets: [Synset('piano.n.01'), Synset('piano.n.02')]
# synsets: [Synset('teacher.n.01')]
# synsets: []
# synsets: [Synset('eye.n.01'), Synset('center.n.01')]
# synsets: []
# synsets: [Synset('close_up.v.01'), Synset('close.v.06'), Synset('close.v.07'), Synset('close.v.09'), Synset('close.v.10'), Synset('closed.a.02')]
# synsets: []
# synsets: [Synset('snip.v.02'), Synset('dress.v.15')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: [Synset('black.n.05'), Synset('blacken.v.01'), Synset('black.a.01'), Synset('black.a.02')]
# synsets: []
# synsets: []
# synsets: [Synset('hands.n.01'), Synset('work_force.n.01'), Synset('hand.n.01'), Synset('hired_hand.n.01'), Synset('handwriting.n.01'), Synset('hand.n.06'), Synset('hand.n.08'), Synset('hand.n.09'), Synset('hand.n.10'), Synset('bridge_player.n.01'), Synset('pass.v.05')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('key.n.01'), Synset('key.n.03'), Synset('key.n.04'), Synset('key.n.05'), Synset('key.n.07'), Synset('key.n.12'), Synset('keystone.n.02'), Synset('key.n.15'), Synset('key.v.04')]
# synsets: []
# synsets: []
# synsets: [Synset('digest.v.03'), Synset('resist.v.04'), Synset('stand.v.12')]
# synsets: []
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02')]
# synsets: [Synset('leather.n.01')]
# synsets: [Synset('chair.n.01'), Synset('president.n.04'), Synset('electric_chair.n.01')]
# synsets: []
# synsets: [Synset('expect.v.03'), Synset('wait.v.04')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02'), Synset('equally.r.01')]
# synsets: []
# synsets: [Synset('complete.v.01'), Synset('end.v.01')]
# synsets: []
# synsets: [Synset('phrase.n.01'), Synset('phrase.n.02')]
# synsets: []
# synsets: []
# synsets: [Synset('digest.v.03'), Synset('resist.v.04'), Synset('stand.v.12')]
# synsets: [Synset('up.a.01'), Synset('up.s.07')]
# synsets: []
# synsets: []
# synsets: [Synset('saturday.n.01'), Synset('sit.v.04'), Synset('ride.v.01')]
# synsets: [Synset('depressed.s.01'), Synset('down.s.07'), Synset('down.r.01'), Synset('down.r.03')]
# synsets: []
# synsets: []
# synsets: [Synset('chopin.n.01'), Synset('chopin.n.03')]
# synsets: [Synset('black.n.05'), Synset('blacken.v.01'), Synset('black.a.01'), Synset('black.a.02')]
# synsets: [Synset('key.n.01'), Synset('key.n.03'), Synset('key.n.04'), Synset('key.n.05'), Synset('key.n.07'), Synset('key.n.12'), Synset('keystone.n.02'), Synset('key.n.15'), Synset('key.v.04')]
# synsets: [Synset('etude.n.01')]
# synsets: []
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02')]
# synsets: [Synset('musical_composition.n.01'), Synset('while.n.01'), Synset('assemble.v.01'), Synset('nibble.v.03')]
# synsets: []
# synsets: [Synset('know.v.01'), Synset('know.v.02'), Synset('acknowledge.v.06')]
# synsets: [Synset('sol.n.03'), Synset('then.r.01'), Synset('therefore.r.01')]
# synsets: [Synset('well.n.04'), Synset('well.n.05'), Synset('well.r.01'), Synset('well.r.06'), Synset('well.r.12')]
# synsets: []
# synsets: []
# synsets: [Synset('play.n.01'), Synset('play.n.02'), Synset('play.n.08'), Synset('playing_period.n.01'), Synset('play.n.14'), Synset('turn.n.03'), Synset('gambling.n.01'), Synset('play.v.01'), Synset('play.v.03'), Synset('act.v.03'), Synset('play.v.05'), Synset('play.v.06'), Synset('play.v.07'), Synset('play.v.10'), Synset('play.v.11'), Synset('play.v.15'), Synset('act.v.10'), Synset('play.v.29'), Synset('bet.v.02'), Synset('play.v.33'), Synset('meet.v.10')]
# synsets: [Synset('information_technology.n.01')]
# synsets: [Synset('eye.n.01'), Synset('center.n.01')]
# synsets: []
# synsets: [Synset('close_up.v.01'), Synset('close.v.06'), Synset('close.v.07'), Synset('close.v.09'), Synset('close.v.10'), Synset('closed.a.02')]
# synsets: []
# synsets: []
# synsets: [Synset('assume.v.03'), Synset('bring.v.01'), Synset('choose.v.01'), Synset('accept.v.02'), Synset('necessitate.v.01'), Synset('take.v.15'), Synset('film.v.01'), Synset('remove.v.01'), Synset('consume.v.02'), Synset('take.v.19'), Synset('assume.v.05'), Synset('take.v.24'), Synset('aim.v.01'), Synset('lease.v.04'), Synset('subscribe.v.05'), Synset('take.v.33'), Synset('contain.v.05')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02')]
# synsets: []
# synsets: []
# synsets: [Synset('put.v.01')]
# synsets: []
# synsets: [Synset('right.n.01'), Synset('right.n.04'), Synset('right.n.05'), Synset('right.n.07'), Synset('right.n.08'), Synset('right.v.01'), Synset('correct.v.01'), Synset('correct.a.01'), Synset('right.a.04'), Synset('properly.r.01'), Synset('correctly.r.01')]
# synsets: [Synset('hand.n.01'), Synset('hired_hand.n.01'), Synset('handwriting.n.01'), Synset('hand.n.06'), Synset('hand.n.08'), Synset('hand.n.09'), Synset('hand.n.10'), Synset('bridge_player.n.01'), Synset('pass.v.05')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02')]
# synsets: [Synset('gram.n.01'), Synset('g.n.05'), Synset('gigabyte.n.01'), Synset('gigabyte.n.02')]
# synsets: []
# synsets: [Synset('flat.n.03'), Synset('flatcar.n.01'), Synset('apartment.n.01'), Synset('flat.a.05'), Synset('flat.a.06')]
# synsets: []
# synsets: [Synset('inversion.n.06')]
# synsets: []
# synsets: []
# synsets: [Synset('just.a.01'), Synset('fair.a.01'), Synset('merely.r.01'), Synset('precisely.r.01')]
# synsets: []
# synsets: [Synset('measure.n.02'), Synset('bill.n.01'), Synset('measurement.n.01'), Synset('standard.n.01'), Synset('meter.n.03'), Synset('measure.n.07'), Synset('measuring_stick.n.01'), Synset('measure.v.01'), Synset('quantify.v.02'), Synset('measure.v.03'), Synset('measure.v.04')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('washington.n.02'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('stop.v.01'), Synset('discontinue.v.01'), Synset('stop.v.05'), Synset('end.v.01'), Synset('hold_on.v.02')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('start.n.01'), Synset('beginning.n.02'), Synset('start.n.03'), Synset('start.n.06'), Synset('starting_signal.n.01'), Synset('start.n.08'), Synset('get_down.v.07'), Synset('start.v.06'), Synset('start.v.08')]
# synsets: [Synset('again.r.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('assume.v.03'), Synset('bring.v.01'), Synset('choose.v.01'), Synset('accept.v.02'), Synset('necessitate.v.01'), Synset('take.v.15'), Synset('film.v.01'), Synset('remove.v.01'), Synset('consume.v.02'), Synset('take.v.19'), Synset('assume.v.05'), Synset('take.v.24'), Synset('aim.v.01'), Synset('lease.v.04'), Synset('subscribe.v.05'), Synset('take.v.33'), Synset('contain.v.05')]
# synsets: [Synset('by.r.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('spin.v.04'), Synset('spin.v.06')]
# synsets: [Synset('left.n.03'), Synset('leave.v.01'), Synset('exit.v.01'), Synset('entrust.v.02'), Synset('impart.v.01')]
# synsets: []
# synsets: []
# synsets: [Synset('eye.n.01'), Synset('center.n.01')]
# synsets: [Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('on.a.01')]
# synsets: []
# synsets: [Synset('mark.n.01'), Synset('score.n.02'), Synset('score.n.03'), Synset('score.n.04'), Synset('score.n.07'), Synset('score.n.10'), Synset('score.v.01'), Synset('score.v.02'), Synset('score.v.03'), Synset('score.v.04'), Synset('grade.v.03')]
# synsets: []
# synsets: [Synset('not.r.01')]
# synsets: [Synset('maine.n.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('get_down.v.07'), Synset('start.v.06'), Synset('start.v.08')]
# synsets: [Synset('again.r.01')]
# synsets: []
# synsets: [Synset('past.n.01'), Synset('past.n.02'), Synset('past.a.01'), Synset('by.r.01')]
# synsets: []
# synsets: [Synset('first.n.02'), Synset('beginning.n.02'), Synset('first_gear.n.01'), Synset('first.a.01'), Synset('first.a.06')]
# synsets: [Synset('measure.n.02'), Synset('bill.n.01'), Synset('measurement.n.01'), Synset('standard.n.01'), Synset('meter.n.03'), Synset('measure.n.07'), Synset('measuring_stick.n.01'), Synset('measure.v.01'), Synset('quantify.v.02'), Synset('measure.v.03'), Synset('measure.v.04')]
# synsets: []
# synsets: [Synset('first.n.02'), Synset('beginning.n.02'), Synset('first_gear.n.01'), Synset('first.a.01'), Synset('first.a.06')]
# synsets: [Synset('phrase.n.01'), Synset('phrase.n.02')]
# synsets: []
# synsets: [Synset('then.n.01'), Synset('then.r.01')]
# synsets: [Synset('stop.v.01'), Synset('discontinue.v.01'), Synset('stop.v.05'), Synset('end.v.01'), Synset('hold_on.v.02')]
# synsets: [Synset('again.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('travel.v.01'), Synset('go.v.03'), Synset('run.v.03'), Synset('sound.v.02'), Synset('function.v.01'), Synset('survive.v.01'), Synset('die.v.01'), Synset('move.v.15'), Synset('fit.v.02'), Synset('fail.v.04')]
# synsets: [Synset('on.a.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('are.n.01'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('course.n.01'), Synset('course.n.02'), Synset('path.n.04'), Synset('course.n.08'), Synset('course.n.09'), Synset('run.v.06')]
# synsets: []
# synsets: [Synset('americium.n.01'), Synset('amplitude_modulation.n.01'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('merely.r.01')]
# synsets: [Synset('are.n.01'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: [Synset('actually.r.01')]
# synsets: [Synset('heed.v.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02'), Synset('equally.r.01')]
# synsets: []
# synsets: [Synset('slowly.r.01')]
# synsets: [Synset('analyze.v.02')]
# synsets: []
# synsets: [Synset('measure.n.02'), Synset('bill.n.01'), Synset('measurement.n.01'), Synset('standard.n.01'), Synset('meter.n.03'), Synset('measure.n.07'), Synset('measuring_stick.n.01'), Synset('measure.v.01'), Synset('quantify.v.02'), Synset('measure.v.03'), Synset('measure.v.04')]
# synsets: []
# synsets: []
# synsets: [Synset('felt.n.01'), Synset('feel.v.03')]
# synsets: []
# synsets: [Synset('assurance.n.01'), Synset('confidence.n.04')]
# synsets: [Synset('slip.n.03'), Synset('cutting.n.02'), Synset('slip.n.05'), Synset('mooring.n.01'), Synset('slip.n.07'), Synset('slip.n.10')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('musical_composition.n.01'), Synset('while.n.01'), Synset('assemble.v.01'), Synset('nibble.v.03')]
# synsets: [Synset('washington.n.02'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('being.n.01'), Synset('organism.n.01'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: []
# synsets: [Synset('fragment.n.03')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('teacher.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: []
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02')]
# synsets: [Synset('full_moon.n.01'), Synset('full.a.01'), Synset('fully.r.01')]
# synsets: [Synset('performance.n.01'), Synset('performance.n.02'), Synset('performance.n.03'), Synset('performance.n.04'), Synset('operation.n.08')]
# synsets: []
# synsets: [Synset('giving.n.01'), Synset('giving.n.02'), Synset('yield.v.01'), Synset('give.v.03'), Synset('give.v.04'), Synset('hold.v.03'), Synset('give.v.08'), Synset('render.v.04'), Synset('impart.v.01'), Synset('pass.v.05'), Synset('give.v.18'), Synset('give.v.20'), Synset('grant.v.05'), Synset('feed.v.02'), Synset('contribute.v.02'), Synset('give.v.27'), Synset('give.v.28'), Synset('give.v.29'), Synset('give.v.37')]
# synsets: [Synset('critical.a.01'), Synset('critical.a.03'), Synset('critical.a.06'), Synset('critical.a.07')]
# synsets: [Synset('feedback.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('stop.v.01'), Synset('discontinue.v.01'), Synset('stop.v.05'), Synset('end.v.01'), Synset('hold_on.v.02')]
# synsets: [Synset('maine.n.01')]
# synsets: []
# synsets: [Synset('five-spot.n.03')]
# synsets: [Synset('moment.n.02'), Synset('moment.n.01'), Synset('second.n.06'), Synset('second_gear.n.01'), Synset('irregular.n.02')]
# synsets: []
# synsets: []
# synsets: [Synset('hour.n.01'), Synset('hour.n.02'), Synset('hour.n.03')]
# synsets: [Synset('late.a.01'), Synset('subsequently.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('merely.r.01'), Synset('entirely.r.02'), Synset('only.r.06')]
# synsets: [Synset('get.v.01'), Synset('receive.v.02'), Synset('arrive.v.01'), Synset('bring.v.04'), Synset('have.v.17'), Synset('induce.v.02'), Synset('get.v.11'), Synset('get.v.14'), Synset('make.v.02'), Synset('get.v.22'), Synset('get.v.27'), Synset('get_down.v.07')]
# synsets: []
# synsets: [Synset('one-half.n.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02')]
# synsets: [Synset('page.n.01'), Synset('page.n.02'), Synset('page.n.03'), Synset('page.n.04'), Synset('page.n.05'), Synset('page.v.01'), Synset('foliate.v.04')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('week.n.01'), Synset('workweek.n.01'), Synset('week.n.03')]
# synsets: []
# synsets: []
# synsets: [Synset('same.a.01'), Synset('same.a.02')]
# synsets: [Synset('thing.n.02'), Synset('thing.n.04'), Synset('matter.n.01'), Synset('thing.n.08')]
# synsets: [Synset('happen.v.01'), Synset('happen.v.04'), Synset('find.v.01')]
# synsets: []
# synsets: []
# synsets: [Synset('contend.v.06')]
# synsets: []
# synsets: [Synset('meet.n.01'), Synset('converge.v.01'), Synset('meet.v.04'), Synset('meet.v.05'), Synset('meet.v.06'), Synset('meet.v.07'), Synset('meet.v.10'), Synset('touch.v.05')]
# synsets: []
# synsets: [Synset('expectation.n.01'), Synset('arithmetic_mean.n.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('not.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('teach.n.01'), Synset('teach.v.01')]
# synsets: []
# synsets: [Synset('just.a.01'), Synset('fair.a.01'), Synset('merely.r.01'), Synset('precisely.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('play.n.01'), Synset('play.n.02'), Synset('play.n.08'), Synset('playing_period.n.01'), Synset('play.n.14'), Synset('turn.n.03'), Synset('gambling.n.01'), Synset('play.v.01'), Synset('play.v.03'), Synset('act.v.03'), Synset('play.v.05'), Synset('play.v.06'), Synset('play.v.07'), Synset('play.v.10'), Synset('play.v.11'), Synset('play.v.15'), Synset('act.v.10'), Synset('play.v.29'), Synset('bet.v.02'), Synset('play.v.33'), Synset('meet.v.10')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('teach.n.01'), Synset('teach.v.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('gain.v.08'), Synset('realize.v.05'), Synset('realize.v.06')]
# synsets: []
# synsets: []
# synsets: [Synset('mean.v.01'), Synset('mean.v.03'), Synset('mean.v.07')]
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: [Synset('necessitate.v.01')]
# synsets: [Synset('assume.v.03'), Synset('bring.v.01'), Synset('choose.v.01'), Synset('accept.v.02'), Synset('necessitate.v.01'), Synset('take.v.15'), Synset('film.v.01'), Synset('remove.v.01'), Synset('consume.v.02'), Synset('take.v.19'), Synset('assume.v.05'), Synset('take.v.24'), Synset('aim.v.01'), Synset('lease.v.04'), Synset('subscribe.v.05'), Synset('take.v.33'), Synset('contain.v.05')]
# synsets: []
# synsets: []
# synsets: [Synset('hear.v.01'), Synset('hear.v.03')]
# synsets: []
# synsets: [Synset('request.n.02'), Synset('ask.v.01'), Synset('ask.v.02'), Synset('ask.v.04'), Synset('necessitate.v.01'), Synset('ask.v.07')]
# synsets: []
# synsets: [Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: []
# synsets: [Synset('sound.n.01'), Synset('sound.n.02'), Synset('sound.n.03'), Synset('sound.n.04'), Synset('audio.n.01'), Synset('phone.n.02'), Synset('sound.n.08'), Synset('sound.v.01'), Synset('sound.v.02'), Synset('sound.v.03'), Synset('voice.v.02'), Synset('sound.v.06'), Synset('fathom.v.02'), Synset('sound.a.01')]
# synsets: []
# synsets: [Synset('privation.n.01'), Synset('lack.n.01'), Synset('need.n.02'), Synset('want.v.02')]
# synsets: []
# synsets: []
# synsets: [Synset('narrative.n.01'), Synset('story.n.02'), Synset('floor.n.02'), Synset('history.n.02'), Synset('report.n.03')]
# synsets: [Synset('americium.n.01'), Synset('amplitude_modulation.n.01'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: [Synset('state.v.01'), Synset('tell.v.02'), Synset('tell.v.03'), Synset('tell.v.05'), Synset('distinguish.v.01')]
# synsets: []
# synsets: []
# synsets: [Synset('rendition.n.04'), Synset('interpretation.n.03'), Synset('interpretation.n.04')]
# synsets: []
# synsets: []
# synsets: [Synset('absorb.v.03'), Synset('absorb.v.04')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: []
# synsets: [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04')]
# synsets: []
# synsets: []
# synsets: [Synset('let.v.01'), Synset('permit.v.01'), Synset('allow.v.03'), Synset('allow.v.04'), Synset('allow.v.09')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('muscle.n.01'), Synset('muscleman.n.01'), Synset('brawn.n.01')]
# synsets: [Synset('memory.n.02'), Synset('memory.n.04')]
# synsets: []
# synsets: [Synset('return.n.06'), Synset('assume.v.03'), Synset('bring.v.01'), Synset('choose.v.01'), Synset('accept.v.02'), Synset('necessitate.v.01'), Synset('take.v.15'), Synset('film.v.01'), Synset('remove.v.01'), Synset('consume.v.02'), Synset('take.v.19'), Synset('assume.v.05'), Synset('take.v.24'), Synset('aim.v.01'), Synset('lease.v.04'), Synset('subscribe.v.05'), Synset('take.v.33'), Synset('contain.v.05')]
# synsets: [Synset('over.r.01')]
# synsets: []
# synsets: [Synset('fly.v.01'), Synset('fly.v.09')]
# synsets: [Synset('past.n.01'), Synset('past.n.02'), Synset('past.a.01'), Synset('by.r.01')]
# synsets: []
# synsets: [Synset('interrupt.v.04'), Synset('break.v.04'), Synset('transgress.v.01'), Synset('break_in.v.01'), Synset('break_in.v.06'), Synset('violate.v.01'), Synset('unwrap.v.02'), Synset('fail.v.04'), Synset('separate.v.08'), Synset('bankrupt.v.01'), Synset('break.v.38'), Synset('break.v.46'), Synset('break.v.48'), Synset('broken.a.01')]
# synsets: []
# synsets: [Synset('oregon.n.01'), Synset('operating_room.n.01')]
# synsets: []
# synsets: [Synset('chord.n.01'), Synset('chord.n.02'), Synset('chord.v.01'), Synset('harmonize.v.06')]
# synsets: []
# synsets: [Synset('merely.r.01')]
# synsets: [Synset('evening.n.01'), Synset('flush.v.04'), Synset('even.a.01'), Synset('even.a.03'), Synset('even.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('washington.n.02'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('playing.n.01'), Synset('playing.n.02'), Synset('acting.n.01'), Synset('play.v.01'), Synset('play.v.03'), Synset('act.v.03'), Synset('play.v.05'), Synset('play.v.06'), Synset('play.v.07'), Synset('play.v.10'), Synset('play.v.11'), Synset('play.v.15'), Synset('act.v.10'), Synset('play.v.29'), Synset('bet.v.02'), Synset('play.v.33'), Synset('meet.v.10')]
# synsets: []
# synsets: [Synset('right.n.01'), Synset('right.n.04'), Synset('right.n.05'), Synset('right.n.07'), Synset('right.n.08'), Synset('right.v.01'), Synset('correct.v.01'), Synset('correct.a.01'), Synset('right.a.04'), Synset('properly.r.01'), Synset('correctly.r.01')]
# synsets: [Synset('note.n.01'), Synset('note.n.02'), Synset('note.n.03'), Synset('bill.n.03'), Synset('note.n.07'), Synset('eminence.n.01'), Synset('note.n.09'), Synset('note.v.01')]
# synsets: []
# synsets: [Synset('information_technology.n.01')]
# synsets: [Synset('make.v.01'), Synset('perform.v.01'), Synset('practice.v.01'), Synset('suffice.v.01'), Synset('act.v.02')]
# synsets: []
# synsets: [Synset('matter.n.01'), Synset('topic.n.02'), Synset('matter.n.06')]
# synsets: []
# synsets: []
# synsets: [Synset('immerse.v.01')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: []
# synsets: [Synset('cascade.v.02')]
# synsets: [Synset('arpeggio.n.01')]
# synsets: [Synset('waterfall.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('bass.n.01'), Synset('bass.n.02'), Synset('bass.n.03'), Synset('bass.n.07')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('trill.n.01'), Synset('warble.v.01')]
# synsets: [Synset('washington.n.02'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('actually.r.01')]
# synsets: []
# synsets: [Synset('easy.a.01'), Synset('easy.s.11'), Synset('easily.r.01'), Synset('slowly.r.01'), Synset('easy.r.03')]
# synsets: [Synset('region.n.01'), Synset('function.n.03'), Synset('character.n.04'), Synset('share.n.01'), Synset('part.n.09'), Synset('part.n.10'), Synset('part.n.11'), Synset('separate.v.08'), Synset('separate.v.02'), Synset('partially.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('bring.v.01'), Synset('bring.v.02'), Synset('bring.v.04')]
# synsets: [Synset('maine.n.01')]
# synsets: [Synset('joy.n.02')]
# synsets: []
# synsets: [Synset('fuel.v.01'), Synset('fueled.a.01')]
# synsets: []
# synsets: [Synset('love.n.01'), Synset('beloved.n.01'), Synset('love.n.04'), Synset('love.v.02')]
# synsets: []
# synsets: [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: []
# synsets: [Synset('first.n.02'), Synset('beginning.n.02'), Synset('first_gear.n.01'), Synset('first.a.01'), Synset('first.a.06')]
# synsets: [Synset('topographic_point.n.01'), Synset('place.n.02'), Synset('place.n.03'), Synset('home.n.01'), Synset('position.n.06'), Synset('position.n.01'), Synset('place.n.10'), Synset('seat.n.01'), Synset('place.n.12'), Synset('plaza.n.01'), Synset('place.n.15'), Synset('space.n.07'), Synset('put.v.01'), Synset('place.v.02'), Synset('rate.v.01'), Synset('locate.v.03'), Synset('target.v.01'), Synset('identify.v.01'), Synset('place.v.11'), Synset('place.v.12'), Synset('invest.v.01'), Synset('station.v.01'), Synset('place.v.15')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04')]
# synsets: [Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('not.r.01')]
# synsets: [Synset('just.a.01'), Synset('fair.a.01'), Synset('merely.r.01'), Synset('precisely.r.01')]
# synsets: [Synset('approximately.r.01'), Synset('about.r.07')]
# synsets: [Synset('maine.n.01')]
# synsets: []
# synsets: [Synset('true.a.01')]
# synsets: [Synset('artist.n.01')]
# synsets: [Synset('perform.v.01'), Synset('perform.v.03')]
# synsets: []
# synsets: []
# synsets: [Synset('audience.n.01'), Synset('audience.n.02')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('bring.v.01'), Synset('bring.v.02'), Synset('bring.v.04')]
# synsets: []
# synsets: []
# synsets: [Synset('same.a.01'), Synset('same.a.02')]
# synsets: [Synset('joy.n.02')]
# synsets: []
# synsets: []
# synsets: [Synset('turn.n.03'), Synset('go.n.01'), Synset('act.n.04'), Synset('turn.n.12'), Synset('turn.v.01'), Synset('change_state.v.01'), Synset('change_by_reversal.v.01'), Synset('turn.v.08'), Synset('plow.v.01'), Synset('turn.v.13'), Synset('flex.v.05')]
# synsets: [Synset('playing.n.01'), Synset('playing.n.02'), Synset('acting.n.01'), Synset('play.v.01'), Synset('play.v.03'), Synset('act.v.03'), Synset('play.v.05'), Synset('play.v.06'), Synset('play.v.07'), Synset('play.v.10'), Synset('play.v.11'), Synset('play.v.15'), Synset('act.v.10'), Synset('play.v.29'), Synset('bet.v.02'), Synset('play.v.33'), Synset('meet.v.10')]
# synsets: []
# synsets: [Synset('magic_trick.n.01')]
# synsets: []
# synsets: [Synset('make.v.01'), Synset('make.v.02'), Synset('make.v.03'), Synset('induce.v.02'), Synset('produce.v.02'), Synset('draw.v.04'), Synset('create.v.05'), Synset('gain.v.08'), Synset('form.v.02'), Synset('make.v.15'), Synset('make.v.16'), Synset('construct.v.01'), Synset('make.v.18'), Synset('name.v.03'), Synset('have.v.17'), Synset('reach.v.01'), Synset('lay_down.v.01'), Synset('make.v.24'), Synset('hold.v.03'), Synset('cook.v.02')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02'), Synset('equally.r.01')]
# synsets: []
# synsets: [Synset('audience.n.01'), Synset('audience.n.02')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('lesson.n.01')]
# synsets: []
# synsets: [Synset('teach.v.01')]
# synsets: [Synset('maine.n.01')]
# synsets: [Synset('echo.n.01')]
# synsets: []
# synsets: [Synset('practice.n.01'), Synset('practice.n.05'), Synset('practice.v.01')]
# synsets: [Synset('suite.n.02'), Synset('room.n.01'), Synset('room.n.02')]
# synsets: []
# synsets: [Synset('concert.n.01'), Synset('concert.v.01')]
# synsets: [Synset('hallway.n.01'), Synset('anteroom.n.01'), Synset('hall.n.03'), Synset('dormitory.n.01'), Synset('manor_hall.n.01'), Synset('mansion.n.02'), Synset('hall.n.12'), Synset('hall.n.13')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('teach.v.01')]
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02'), Synset('equally.r.01')]
# synsets: []
# synsets: [Synset('research.v.02'), Synset('explore.v.02')]
# synsets: []
# synsets: [Synset('hide.v.01')]
# synsets: [Synset('negotiation.n.01')]
# synsets: []
# synsets: [Synset('voice.n.01'), Synset('voice.n.02'), Synset('voice.n.07'), Synset('spokesperson.n.01'), Synset('part.n.11'), Synset('voice.v.02')]
# synsets: []
# synsets: []
# synsets: [Synset('pause.n.01')]
# synsets: []
# synsets: [Synset('silence.n.02'), Synset('secrecy.n.01')]
# synsets: []
# synsets: [Synset('equally.r.01'), Synset('evenly.r.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02'), Synset('equally.r.01')]
# synsets: [Synset('powerful.a.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02'), Synset('equally.r.01')]
# synsets: [Synset('words.n.01'), Synset('lyric.n.01'), Synset('words.n.03'), Synset('word.n.01'), Synset('discussion.n.02'), Synset('word.n.07'), Synset('bible.n.01')]
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: [Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('acting.n.01'), Synset('perform.v.01'), Synset('perform.v.03')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02'), Synset('equally.r.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02')]
# synsets: [Synset('soloist.n.01')]
# synsets: [Synset('back.v.01'), Synset('back.v.02'), Synset('back.v.05'), Synset('bet_on.v.01')]
# synsets: [Synset('up.a.01'), Synset('up.s.07')]
# synsets: [Synset('by.r.01')]
# synsets: []
# synsets: [Synset('orchestra.n.01'), Synset('orchestra.n.02')]
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: [Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: [Synset('react.v.01'), Synset('answer.v.01')]
# synsets: []
# synsets: [Synset('heat.v.01'), Synset('heat.v.02'), Synset('heat.v.04')]
# synsets: [Synset('debate.n.02')]
# synsets: []
# synsets: [Synset('being.n.01'), Synset('organism.n.01'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: [Synset('stopping_point.n.01'), Synset('death.n.05'), Synset('last.n.05'), Synset('last.n.06'), Synset('end.n.03'), Synset('last.v.01'), Synset('survive.v.01'), Synset('last.a.02')]
# synsets: []
# synsets: [Synset('talk.v.02'), Synset('talk.v.01'), Synset('speak.v.03')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: [Synset('angstrom.n.01'), Synset('ampere.n.02')]
# synsets: []
# synsets: []
# synsets: [Synset('discussion.n.02')]
# synsets: []
# synsets: [Synset('information_technology.n.01')]
# synsets: []
# synsets: [Synset('evening.n.01'), Synset('flush.v.04'), Synset('even.a.01'), Synset('even.a.03'), Synset('even.r.01')]
# synsets: [Synset('bounce.v.04'), Synset('bounce.v.06')]
# synsets: [Synset('joke.n.01'), Synset('jest.n.02'), Synset('antic.n.01'), Synset('joke.v.01'), Synset('joke.v.02')]
# synsets: [Synset('approximately.r.01')]
# synsets: []
# synsets: [Synset('dining.n.01'), Synset('dine.v.01'), Synset('dine.v.02')]
# synsets: [Synset('table.n.01'), Synset('table.n.02'), Synset('table.v.02')]
# synsets: []
# synsets: [Synset('family.n.01'), Synset('family.n.02'), Synset('class.n.01'), Synset('family.n.04'), Synset('kin.n.01'), Synset('family.n.06'), Synset('syndicate.n.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('grow.v.04'), Synset('originate.v.01'), Synset('grow.v.07')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('voice.n.01'), Synset('voice.n.02'), Synset('voice.n.07'), Synset('spokesperson.n.01'), Synset('part.n.11'), Synset('voice.v.02')]
# synsets: [Synset('will.n.03'), Synset('will.v.02')]
# synsets: [Synset('affect.v.01')]
# synsets: []
# synsets: [Synset('narrative.n.01'), Synset('story.n.02'), Synset('floor.n.02'), Synset('history.n.02'), Synset('report.n.03')]
# synsets: []
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: []
# synsets: [Synset('maine.n.01')]
# synsets: []
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('day.n.01'), Synset('day.n.02'), Synset('day.n.03'), Synset('day.n.04'), Synset('day.n.05'), Synset('day.n.07'), Synset('sidereal_day.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('lesson.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('proceed.v.02')]
# synsets: []
# synsets: [Synset('beryllium.n.01'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: [Synset('street_fighter.n.02'), Synset('hood.n.01'), Synset('bully.n.01'), Synset('tough.a.07')]
# synsets: []
# synsets: [Synset('consist.v.04')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('discussion.n.02')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('playing.n.01'), Synset('playing.n.02'), Synset('acting.n.01'), Synset('play.v.01'), Synset('play.v.03'), Synset('act.v.03'), Synset('play.v.05'), Synset('play.v.06'), Synset('play.v.07'), Synset('play.v.10'), Synset('play.v.11'), Synset('play.v.15'), Synset('act.v.10'), Synset('play.v.29'), Synset('bet.v.02'), Synset('play.v.33'), Synset('meet.v.10')]
# synsets: []
# synsets: []
# synsets: []
# synsets: [Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: [Synset('sol.n.03'), Synset('then.r.01'), Synset('therefore.r.01')]
# synsets: [Synset('immerse.v.01')]
# synsets: [Synset('inch.n.01'), Synset('indiana.n.01')]
# synsets: []
# synsets: [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04')]
# synsets: []
# synsets: []
# synsets: [Synset('manage.v.02'), Synset('oversee.v.01')]
# synsets: []
# synsets: [Synset('get.v.01'), Synset('receive.v.02'), Synset('arrive.v.01'), Synset('bring.v.04'), Synset('have.v.17'), Synset('induce.v.02'), Synset('get.v.11'), Synset('get.v.14'), Synset('make.v.02'), Synset('get.v.22'), Synset('get.v.27'), Synset('get_down.v.07')]
# synsets: []
# synsets: []
# synsets: [Synset('end.n.01'), Synset('end.n.02'), Synset('end.n.03'), Synset('goal.n.01'), Synset('end.n.05'), Synset('conclusion.n.08'), Synset('end.v.01'), Synset('end.v.02'), Synset('end.v.04')]
# synsets: []
# synsets: []
# synsets: [Synset('musical_composition.n.01'), Synset('while.n.01'), Synset('assemble.v.01'), Synset('nibble.v.03')]
# synsets: []
# synsets: []
# synsets: [Synset('look.v.01'), Synset('look.v.02'), Synset('search.v.02'), Synset('expect.v.03')]
# synsets: [Synset('up.a.01'), Synset('up.s.07')]
# synsets: []
# synsets: [Synset('state.v.01'), Synset('allege.v.01'), Synset('read.v.02'), Synset('pronounce.v.01')]
# synsets: []
# synsets: []
# synsets: [Synset('assassin.n.01')]
# synsets: []
# synsets: []
# synsets: [Synset('now.n.01'), Synset('immediately.r.01')]
# synsets: []
# synsets: [Synset('evening.n.01'), Synset('flush.v.04'), Synset('even.a.01'), Synset('even.a.03'), Synset('even.r.01')]
# synsets: []
# synsets: []
# synsets: [Synset('practice.n.01'), Synset('practice.n.05'), Synset('practice.v.01')]
# synsets: [Synset('piano.n.01'), Synset('piano.n.02')]
# synsets: [Synset('entirely.r.02')]
# synsets: []
# synsets: []
# synsets: [Synset('repeat.v.01'), Synset('duplicate.v.01'), Synset('recur.v.01'), Synset('reprise.v.01')]
# synsets: []
# synsets: [Synset('refrain.n.01')]
# synsets: []
# synsets: [Synset('are.n.01'), Synset('be.v.01'), Synset('exist.v.01'), Synset('constitute.v.01'), Synset('cost.v.01')]
# synsets: []
# synsets: [Synset('heed.v.01')]
# synsets: []
# synsets: []
# My (pass_on,reach,script,hand,hired_man,manus,mitt,deal,turn_over,paw,give,handwriting,pass,hired_hand,bridge_player) lingered (on) the cold (metallic,metallic_element,metal,alloy) (doorknob,doorhandle) . I (shut_down,closed,close_up,close_down,close,fold) my (eye,middle,heart,optic,oculus,centre,center) (every_bit,angstrom,ampere,as,amp,A,angstrom_unit,equally) the (Vancouver) (walkover,snap,child's_play,pushover,piece_of_cake,breeze,duck_soup,cinch,picnic) (extend,course,hunt_down,tend,carry,track_down,melt,pass,execute,operate,flow,hunt,race,feed,ply,lead,campaign,go,work,melt_down,range,function,lean,incline,black_market,be_given,run) (information_technology,IT) (cool_down,cool,chill) (finger's_breadth,fingerbreadth,finger,digit) through my (hair,haircloth) . The (adult_male,valet,human,military_man,serviceman,gentleman's_gentleman,human_being,man,gentleman,valet_de_chambre,homo,military_personnel) I (constitute,Evergreen_State,Washington,be,represent,make_up,cost,WA,comprise,exist) (about,nigh,around,or_so,virtually,nearly,roughly,near,close_to,some,well-nigh,most,approximately,more_or_less,almost,just_about) to (touch,foregather,take_on,fit,assemble,forgather,adjoin,satisfy,sports_meeting,fulfill,meet,gather,match,fill,converge,fulfil,encounter,play,cope_with,conform_to,contact) (constitute,Evergreen_State,Washington,be,represent,make_up,cost,WA,comprise,exist) infamous for (take,call_for,postulate,require,need,demand,necessitate,involve,exact,ask) perfection . (just,but,only,simply,merely) the beguiling (music,euphony) that faintly fluttered (past_times,yesteryear,past,by) the unlatched (window,windowpane) ’s (drape,drapery,curtain,mantle,pall) (pull_in,string,suck,withdraw,make,draw_off,line,sop_up,suck_up,take_up,tie,delineate,depict,cast,trace,take_out,soak_up,draw,imbibe,attract,thread,describe,absorb,take_in,pull,draw_in) (ME,Maine,Pine_Tree_State) (onward,forward,forwards,send_on,forrader,ahead,onwards) , inviting (ME,Maine,Pine_Tree_State) to (cross,cut_across,hybridise,crisscross,hybridisation,crossbreed,hybridizing,hybrid,hybridization,mark,track,intersect,traverse,cover,crossing,cut_through,Cross,get_over,crossbreeding,interbreeding,pass_over,hybridize,get_across,interbreed) the (doorway,room_access,door,threshold,doorstep,doorsill) . (step,pace) into the (flat,apartment) , under the watchful gaze of an (emerald) - eyed (CT,computed_tomography,computerized_tomography,computed_axial_tomography,computerized_axial_tomography,CAT) portrait , I (insert,record,enrol,enter,enroll,recruit,put_down,infix,inscribe,participate,introduce) the sweeping (b,barn,Bel,B) (major,John_R._Major,John_Major,Major,John_Roy_Major) (musical_scale,scale_of_measurement,scale,weighing_machine,graduated_table,surmount,ordered_series) .
#
# ...
# 	 “ (start,offset,commence,first,start_out,starting_line,starting_signal,get,scratch,starting_time,commencement,kickoff,set_about,set_out,embark_on,beginning,scratch_line,outset,starting,head_start,begin,start_up,get-go,get_down,showtime) (again,once_again,over_again,once_more) . ”
# 	 (remove,postulate,take_on,withdraw,pick_out,submit,subscribe_to,strike,consume,involve,take_up,ask,hire,take_aim,bring,convey,require,rent,aim,choose,need,ingest,shoot,train,have,call_for,subscribe,engage,contain,necessitate,take,take_away,direct,hold,take_in,assume,charter,accept,lease,demand,adopt,acquire,select,film) (past,by) surprise , I (spin) (pass_on,left_hand,go_forth,go_out,exit,go_away,leave,entrust,impart,give,get_out,left) . His (eye,middle,heart,optic,oculus,centre,center) (constitute,make_up,represent,be,cost,comprise,exist) (on) the (musical_score,tally,hit,grade,score,mark,nock,rack_up) , (not,non) (ME,Maine,Pine_Tree_State) .
# 	 I (start,commence,set_out,embark_on,set_about,begin,start_out,start_up,get_down,get) (again,once_again,over_again,once_more) . (past_times,yesteryear,past,by) the (start,offset,first_gear,showtime,low_gear,low,beginning,first,kickoff,number_1,outset,get-go,starting_time,commencement,number_one) (beat,amount,measuring_rod,appraise,mensuration,bar,measure_out,evaluate,measuring_stick,measurement,bill,measuring,criterion,value,assess,valuate,mensurate,measure,standard,meter,cadence,touchstone,metre,quantify,quantity) , (start,offset,first_gear,showtime,low_gear,low,beginning,first,kickoff,number_1,outset,get-go,starting_time,commencement,number_one) (phrase,musical_phrase) , (and_then,and_so,then,so) (finish,give_up,hold_on,terminate,cease,end,discontinue,lay_off,stop,quit,halt) (again,once_again,over_again,once_more) . What (constitute,make_up,represent,be,cost,comprise,exist) (extend,endure,give_way,snuff_it,sound,croak,perish,pass,fit,break_down,travel,move,drop_dead,go_away,operate,conk,conk_out,go_bad,locomote,cash_in_one's_chips,survive,live,give_out,hold_up,exit,lead,die,go,pass_away,work,depart,hold_out,last,give-up_the_ghost,function,kick_the_bucket,expire,decease,choke,buy_the_farm,live_on,fail,break,run,pop_off) (on) ?
#
# 	 “ (constitute,are,make_up,represent,be,cost,ar,comprise,exist) you (heed,listen,mind) ? ”
#  I nodded . Of (course,path,row,feed,course_of_instruction,class,line,flow,track,run,course_of_study) I (amplitude_modulation,constitute,make_up,represent,be,cost,americium,atomic_number_95,AM,comprise,Am,exist) .
#  “ (just,but,only,simply,merely) (constitute,are,make_up,represent,be,cost,ar,comprise,exist) you (actually,really) (heed,listen,mind) ? ”
#
#  (every_bit,angstrom,ampere,as,amp,A,angstrom_unit,equally) we (easy,slowly,tardily,slow) (break_down,dissect,analyse,take_apart,analyze) each (beat,amount,measuring_rod,appraise,mensuration,bar,measure_out,evaluate,measuring_stick,measurement,bill,measuring,criterion,value,assess,valuate,mensurate,measure,standard,meter,cadence,touchstone,metre,quantify,quantity) , I (felt,sense,feel) my (sureness,confidence,self-confidence,authority,assurance,trust,self-assurance) (trip,slip,cutting,moorage,slip_of_paper,berth,mooring) away . The (piece,opus,assemble,spell,put_together,tack,set_up,patch,composition,while,piece_of_music,tack_together,pick,musical_composition,nibble) (constitute,Evergreen_State,Washington,be,represent,make_up,cost,WA,comprise,exist) (constitute,organism,make_up,represent,be,cost,beingness,comprise,existence,exist,being) chipped into (fragment) . Unlike my previous (instructor,teacher) , who (heed,listen,mind) to (angstrom,ampere,amp,A,angstrom_unit) (fully,to_the_full,full,full_phase_of_the_moon,full_moon,full-of-the-moon) (carrying_into_action,public_presentation,operation,carrying_out,functioning,execution,performance) before (contribute,make,kick_in,dedicate,yield,give,pass,grant,giving,turn_over,leave,chip_in,return,have,reach,afford,feed,generate,gift,throw,present,pass_on,consecrate,hold,hand,apply,devote,impart,render,commit) (critical) (feedback) , Ian (finish,give_up,hold_on,terminate,cease,end,discontinue,lay_off,stop,quit,halt) (ME,Maine,Pine_Tree_State) every (five-spot,five) (irregular,moment,minute,second_gear,instant,second,arcsecond,bit,mo) . One (time_of_day,hr,60_minutes,hour) (after,later,late,afterward,subsequently,afterwards,later_on) , we (just,solely,alone,but,exclusively,only,only_if,simply,only_when,merely,entirely) (start,commence,start_out,make,capture,cause,get,receive,stimulate,bring,convey,set_about,incur,have,set_out,arrive,find,catch,begin,fetch,induce,get_down,obtain,acquire,come) through (one-half,half) (angstrom,ampere,amp,A,angstrom_unit) (page,pageboy,Thomas_Nelson_Page,Sir_Frederick_Handley_Page,foliate,Page,paginate) .
#
#  Each consecutive (hebdomad,calendar_week,workweek,week) , the (same) (thing,matter,affair) (fall_out,encounter,pass_off,hap,materialize,find,chance,go_on,materialise,happen,bump,come_about,pass,take_place,occur) . I (fight,contend,struggle) to (touch,foregather,take_on,fit,assemble,forgather,adjoin,satisfy,sports_meeting,fulfill,meet,gather,match,fill,converge,fulfil,encounter,play,cope_with,conform_to,contact) his (expected_value,expectation,first_moment,outlook,prospect,arithmetic_mean) .
#  “ I ’m (not,non) here to (instruct,Blackbeard,learn,Edward_Thatch,Edward_Teach,Thatch,Teach,teach) you (just,but,only,exactly,simply,precisely,fair,merely) how to (drama,caper,represent,take_on,gambling,frolic,period_of_play,wager,romp,roleplay,child's_play,bet,spiel,playing_period,act,meet,gambol,playact,turn,gaming,recreate,encounter,play,dramatic_play) . I ’m here to (instruct,Blackbeard,learn,Edward_Thatch,Edward_Teach,Thatch,Teach,teach) you how to (heed,listen,mind) . ”
#  I (earn,take_in,gain,pull_in,bring_in,make,realize,realise,clear) what Ian (intend,signify,stand_for,mean) — (heed,listen,mind) (take,call_for,postulate,require,need,demand,necessitate,involve,ask) (remove,postulate,take_on,withdraw,pick_out,submit,subscribe_to,strike,consume,involve,take_up,ask,hire,take_aim,bring,convey,require,rent,aim,choose,need,ingest,shoot,train,have,call_for,subscribe,engage,contain,necessitate,take,take_away,direct,hold,take_in,assume,charter,accept,lease,demand,adopt,acquire,select,film) what we (try,hear) and (take,ask,asking,expect,call_for,postulate,require,request,need,demand,inquire,necessitate,involve,enquire) : (constitute,make_up,represent,be,cost,comprise,exist) this the (vocalise,audio,auditory_sensation,sound,fathom,speech_sound,phone,go,vocalize,voice) I (require,lack,want,deficiency,need,neediness,privation,deprivation) ? What (news_report,chronicle,tale,narration,write_up,narrative,story,floor,history,report,level,account,storey) (amplitude_modulation,constitute,make_up,represent,be,cost,americium,atomic_number_95,AM,comprise,Am,exist) I (recite,recount,secern,state,severalize,separate,tell,severalise,say,secernate,distinguish,tell_apart,narrate,differentiate) through my (rendering,interpretation,rendition,interpreting) ?
#
#  (soak_up,imbibe,draw,take_in,suck,sop_up,take_over,suck_up,absorb,take_up) (inch,Hoosier_State,Indiana,in,IN) the (music,euphony) , I (earmark,permit,let,reserve,countenance,appropriate,grant,allow,set_aside) my instincts and (brawn,musculus,muscularity,heftiness,muscleman,brawniness,sinew,muscle) (storage,computer_memory,computer_storage,memory,remembering,store,memory_board) to (remove,issue,postulate,take_on,withdraw,pick_out,submit,subscribe_to,strike,consume,involve,yield,take_up,ask,hire,take_aim,bring,takings,convey,require,rent,aim,choose,need,ingest,shoot,train,return,proceeds,have,call_for,subscribe,engage,contain,necessitate,take,take_away,direct,hold,take_in,assume,charter,accept,lease,demand,adopt,payoff,acquire,select,film) (over) , (wing,fly) (past_times,yesteryear,past,by) the (breach,let_on,give_way,break_up,bring_out,break_down,give_away,expose,divulge,break_in,smash,part,conk_out,go_bad,get_around,bust,interrupt,reveal,give_out,transgress,infract,disclose,die,go,violate,go_against,unwrap,broken,separate,offend,let_out,discover,split,fail,bankrupt,break,ruin,get_out,split_up) tritones (Oregon,OR,operating_room,operating_theatre,Beaver_State,surgery,operating_theater) neapolitan (chord,harmonise,harmonize) . (just,but,only,simply,merely) (flush,level,even,evening,eventide,eve,even_out) if I (constitute,Evergreen_State,Washington,be,represent,make_up,cost,WA,comprise,exist) (performing,act,meet,represent,recreate,playing,encounter,take_on,play,playact,wager,bet,roleplay,playacting,acting,spiel) the (redress,the_right_way,decently,right,aright,right_hand,correct,properly,decent,correctly,rightfulness,in_good_order,rectify,compensate,right_wing) (notation,line,banker's_bill,short_letter,annotation,Federal_Reserve_note,promissory_note,note,eminence,musical_note,banknote,remark,mention,bill,government_note,bank_bill,bank_note,note_of_hand,observe,billet,greenback,tone,distinction,preeminence) , (information_technology,IT) (do,practise,suffice,serve,act,exercise,perform,make,behave,answer,practice,execute) n’t (topic,matter,affair,issue,subject,thing) . Becoming (plunge,immerse) (inch,Hoosier_State,Indiana,in,IN) the (cascade) (arpeggio) (falls,waterfall) , thundering (basso,bass,bass_part) , and fairydust (trill,warble,quaver,shake) (constitute,Evergreen_State,Washington,be,represent,make_up,cost,WA,comprise,exist) (actually,really) the (slowly,easily,soft,easy,slow,tardily) (theatrical_role,section,break_up,office,disunite,character,percentage,voice,partially,portion,role,part,region,share,partly,persona,division,function,separate,split,parting,break,divide,split_up) , which (take,bring,convey,fetch,get) (ME,Maine,Pine_Tree_State) (pleasure,delight,joy) and (fuel,fueled) my (enjoy,honey,dear,love,beloved,dearest,sexual_love,erotic_love) for (music,euphony) (inch,Hoosier_State,Indiana,in,IN) the (start,offset,first_gear,showtime,low_gear,low,beginning,first,kickoff,number_1,outset,get-go,starting_time,commencement,number_one) (pose,rate,rank,invest,office,topographic_point,place,spot,grade,station,aim,blank_space,situation,space,order,berth,property,send,locate,put,position,localise,seat,plaza,piazza,range,post,direct,billet,site,home,target,identify,localize,lay,commit,set,point) . However , (music,euphony) (constitute,make_up,represent,be,cost,comprise,exist) (not,non) (just,but,only,exactly,simply,precisely,fair,merely) (about,nigh,around,or_so,virtually,nearly,roughly,near,close_to,some,well-nigh,most,approximately,more_or_less,almost,just_about) (ME,Maine,Pine_Tree_State) . (true) (artist,creative_person) (do,perform,execute) for their (audience) , and to (take,bring,convey,fetch,get) them the (same) (pleasure,delight,joy) , to (deform,twist,plow,release,plough,bend,change_by_reversal,routine,tour,bit,flex,change_state,spell,act,number,turn,go,reverse,play) (performing,act,meet,represent,recreate,playing,encounter,take_on,play,playact,wager,bet,roleplay,playacting,acting,spiel) into (deception,trick,thaumatur ...
#
#  The (lesson) Ian (instruct,learn,teach) (ME,Maine,Pine_Tree_State) (reverberation,echo,sound_reflection,replication) beyond (practise,do,pattern,exercise,practice) (suite,elbow_room,way,room,rooms) and (concert) (mansion,entrance_hall,dorm,residence,manse,antechamber,vestibule,hall,dormitory,hallway,anteroom,foyer,manor_hall,student_residence,mansion_house,lobby,residence_hall) . I ’ve (instruct,learn,teach) to (heed,listen,mind) (every_bit,angstrom,ampere,as,amp,A,angstrom_unit,equally) I (explore,search,research) the (hide,conceal) (negotiation,dialogue,talks) between (vocalism,vocalize,vocalise,vox,representative,sound,part,interpreter,spokesperson,vocalization,vocalisation,voice,phonation) , to (interruption,break,suspension,intermission,pause) and (secrecy,silence,quiet,secretiveness) , (evenly,every_bit,as,equally) (every_bit,angstrom,ampere,as,amp,A,angstrom_unit,equally) (powerful) (every_bit,angstrom,ampere,as,amp,A,angstrom_unit,equally) (Bible,Holy_Writ,Word,lyric,discussion,Book,language,word,Holy_Scripture,Scripture,give-and-take,words,Word_of_God,Good_Book,Christian_Bible) . (heed,listen,mind) (constitute,make_up,represent,be,cost,comprise,exist) (do,performing,playing,perform,playacting,acting,execute) (every_bit,angstrom,ampere,as,amp,A,angstrom_unit,equally) (angstrom,ampere,amp,A,angstrom_unit) (soloist) (game,gage,bet_on,punt,stake,support,back,plunk_for,plump_for,indorse,endorse) (up) (past,by) an (orchestra) . (heed,listen,mind) (constitute,make_up,represent,be,cost,comprise,exist) calmly (answer,respond,reply,react) during (heat_up,heat,hot_up) (disputation,public_debate,debate) and (constitute,organism,make_up,represent,be,cost,beingness,comprise,existence,exist,being) the (endure,survive,final_stage,hold_up,death,live_on,finale,end,conclusion,live,close,finish,stopping_point,go,hold_out,last,finis) to (mouth,verbalise,utter,verbalize,talk,speak) (inch,Hoosier_State,Indiana,in,IN) (angstrom,ampere,amp,A,angstrom_unit) SPS Harkness (give-and-take,word,discussion) . (information_technology,IT) ’s (flush,level,even,evening,eventide,eve,even_out) (bounce) (prank,antic,joke,gag,jocularity,trick,caper,put-on,jest,laugh,jape) (about,around,or_so,roughly,close_to,some,approximately,more_or_less,just_about) the (dining,dine) (tabular_array,tabulate,tabularize,table,tabularise) with (mob,house,folk,kin,sept,menage,family,class,phratry,family_unit,household,category,syndicate,kinfolk,crime_syndicate,kinsfolk,family_line,kinsperson,home) . I ’ve (originate,develop,produce,uprise,grow,farm,rise,arise,raise,spring_up) to envision how my (vocalism,vocalize,vocalise,vox,representative,sound,part,interpreter,spokesperson,vocalization,vocalisation,voice,phonation) (testament,will) (touch,touch_on,bear_on,impact,bear_upon,affect) the (news_report,chronicle,tale,narration,write_up,narrative,story,floor,history,report,level,account,storey) of those (heed,listen,mind) to (ME,Maine,Pine_Tree_State) .
#
#  To this (24-hour_interval,twenty-four_hours,sidereal_day,daylight,solar_day,mean_solar_day,daytime,twenty-four_hour_period,day) , my (lesson) with Ian (proceed,go_forward,continue) to (glucinium,constitute,make_up,represent,be,cost,beryllium,comprise,atomic_number_4,Be,exist) (yob,roughneck,bully,ruffian,toughie,yobo,tough,hooligan,goon,hood,strong-armer,rowdy,street_fighter,hoodlum,yobbo,thug,punk) , (consist,comprise) of 80 % (give-and-take,word,discussion) and 20 % (performing,act,meet,represent,recreate,playing,encounter,take_on,play,playact,wager,bet,roleplay,playacting,acting,spiel) . When we (constitute,make_up,represent,be,cost,comprise,exist) both (hence,thus,sol,and_so,then,soh,and_then,thence,therefore,so) (plunge,immerse) (inch,Hoosier_State,Indiana,in,IN) the (music,euphony) that I (handle,deal,manage,supervise,care,superintend,oversee) to (start,commence,start_out,make,capture,cause,get,receive,stimulate,bring,convey,set_about,incur,have,set_out,arrive,find,catch,begin,fetch,induce,get_down,obtain,acquire,come) to the (finish,final_stage,stop,ending,terminate,end,conclusion,cease,goal,close,terminal,last,closing) of the (piece,opus,assemble,spell,put_together,tack,set_up,patch,composition,while,piece_of_music,tack_together,pick,musical_composition,nibble) before he (await,expect,search,appear,seem,wait,look) (up) to (aver,state,enunciate,read,articulate,tell,say,enounce,sound_out,allege,pronounce) , “ (assassin,bravo,assassinator) . ” (straight_off,immediately,forthwith,now,instantly,like_a_shot,at_once,straightaway,directly,right_away) , (flush,level,even,evening,eventide,eve,even_out) when I (practise,do,pattern,exercise,practice) (forte-piano,piano,pianissimo,pianoforte) (solely,alone,exclusively,only,entirely) , I (replicate,reiterate,duplicate,reprise,reduplicate,iterate,ingeminate,recapitulate,double,reprize,repeat,recur,retell,restate) my (chorus,refrain) : (constitute,are,make_up,represent,be,cost,ar,comprise,exist) you (heed,listen,mind) ?
# str

# %%
import re
get_syn_words = re.findall('\(([^)]+)', result)
print(get_syn_words)
# Out:
# ['pass_on,reach,script,hand,hired_man,manus,mitt,deal,turn_over,paw,give,handwriting,pass,hired_hand,bridge_player', 'on', 'metallic,metallic_element,metal,alloy', 'doorknob,doorhandle', 'shut_down,closed,close_up,close_down,close,fold', 'eye,middle,heart,optic,oculus,centre,center', 'every_bit,angstrom,ampere,as,amp,A,angstrom_unit,equally', 'Vancouver', "walkover,snap,child's_play,pushover,piece_of_cake,breeze,duck_soup,cinch,picnic", 'extend,course,hunt_down,tend,carry,track_down,melt,pass,execute,operate,flow,hunt,race,feed,ply,lead,campaign,go,work,melt_down,range,function,lean,incline,black_market,be_given,run', 'information_technology,IT', 'cool_down,cool,chill', "finger's_breadth,fingerbreadth,finger,digit", 'hair,haircloth', "adult_male,valet,human,military_man,serviceman,gentleman's_gentleman,human_being,man,gentleman,valet_de_chambre,homo,military_personnel", 'constitute,Evergreen_State,Washington,be,represent,make_up,cost,WA,comprise,exist', 'about,nigh,around,or_so,virtually,nearly,roughly,near,close_to,some,well-nigh,most,approximately,more_or_less,almost,just_about', 'touch,foregather,take_on,fit,assemble,forgather,adjoin,satisfy,sports_meeting,fulfill,meet,gather,match,fill,converge,fulfil,encounter,play,cope_with,conform_to,contact', 'constitute,Evergreen_State,Washington,be,represent,make_up,cost,WA,comprise,exist', 'take,call_for,postulate,require,need,demand,necessitate,involve,exact,ask', 'just,but,only,simply,merely', 'music,euphony', 'past_times,yesteryear,past,by', 'window,windowpane', 'drape,drapery,curtain,mantle,pall', 'pull_in,string,suck,withdraw,make,draw_off,line,sop_up,suck_up,take_up,tie,delineate,depict,cast,trace,take_out,soak_up,draw,imbibe,attract,thread,describe,absorb,take_in,pull,draw_in', 'ME,Maine,Pine_Tree_State', 'onward,forward,forwards,send_on,forrader,ahead,onwards', 'ME,Maine,Pine_Tree_State', 'cross,cut_across,hybridise,crisscross,hybridisation,crossbreed,hybridizing,hybrid,hybridization,mark,track,intersect,traverse,cover,crossing,cut_through,Cross,get_over,crossbreeding,interbreeding,pass_over,hybridize,get_across,interbreed', 'doorway,room_access,door,threshold,doorstep,doorsill', 'step,pace', 'flat,apartment', 'emerald', 'CT,computed_tomography,computerized_tomography,computed_axial_tomography,computerized_axial_tomography,CAT', 'insert,record,enrol,enter,enroll,recruit,put_down,infix,inscribe,participate,introduce', 'b,barn,Bel,B', 'major,John_R._Major,John_Major,Major,John_Roy_Major', 'musical_scale,scale_of_measurement,scale,weighing_machine,graduated_table,surmount,ordered_series', 'extend,direct,LED,head,precede,conduct,lead,light-emitting_diode,go,run,pass', 'past,by', 'intrinsic,intrinsical', 'attraction', 'music,euphony', 'copulate,mate,couple_up,pair,couple,couple_on', 'layer,bed', 'belch,break_out,erupt,recrudesce,extravasate', 'jiffy,trice,wink,moment,minute,split_second,heartbeat,blink_of_an_eye,flash,twinkling,instant,second,instantaneous,New_York_minute', "finger's_breadth,fingerbreadth,finger,digit", 'pasture,graze,crop', 'tusk,ivory', 'key,keystone,Key,tonality,headstone,Francis_Scott_Key', 'motor,driving,drive', 'forge,mallet,power_hammer,hammer', 'dissipate,take,frivol_away,fool_away,fool,snap,fritter,shoot,fritter_away,pip,photograph,film', 'quiver,quivering,oscillation,vibration', 'up', 'inch,Hoosier_State,Indiana,in,IN', 'strain,melody,aviation,beam,transmit,bare,send,atmosphere,publicise,melodic_phrase,airwave,air_travel,tune,melodic_line,line,broadcast,publicize,air', 'wholly,altogether,all,completely,whole,totally,entirely', 'about,around,or_so,roughly,close_to,some,approximately,more_or_less,just_about', 'ME,Maine,Pine_Tree_State', 'go_down,hide,strike_down,fall,lessen,fell,descend,come_down,cut_down,decrease,drop,diminish,come', 'inch,Hoosier_State,Indiana,in,IN', 'enjoy,honey,dear,love,beloved,dearest,sexual_love,erotic_love', 'newly,new,fresh,freshly', 'extension_phone,wing,file_name_extension,filename_extension,prolongation,lengthiness,telephone_ ...

# %%
from nltk.tokenize import word_tokenize

# %%
ext_syn_words_all = []
for i in get_syn_words:
    w_array = word_tokenize(i)
    for j in w_array:
        k = re.sub(',', '', j)
        ext_syn_words_all.append(k)
    
ext_syn_re = list(filter(None, ext_syn_words_all))
ext_syn_re
# Out:
# ['pass_on',
#  'reach',
#  'script',
#  'hand',
#  'hired_man',
#  'manus',
#  'mitt',
#  'deal',
#  'turn_over',
#  'paw',
#  'give',
#  'handwriting',
#  'pass',
#  'hired_hand',
#  'bridge_player',
#  'on',
#  'metallic',
#  'metallic_element',
#  'metal',
#  'alloy',
#  'doorknob',
#  'doorhandle',
#  'shut_down',
#  'closed',
#  'close_up',
#  'close_down',
#  'close',
#  'fold',
#  'eye',
#  'middle',
#  'heart',
#  'optic',
#  'oculus',
#  'centre',
#  'center',
#  'every_bit',
#  'angstrom',
#  'ampere',
#  'as',
#  'amp',
#  'A',
#  'angstrom_unit',
#  'equally',
#  'Vancouver',
#  'walkover',
#  'snap',
#  "child's_play",
#  'pushover',
#  'piece_of_cake',
#  'breeze',
#  'duck_soup',
#  'cinch',
#  'picnic',
#  'extend',
#  'course',
#  'hunt_down',
#  'tend',
#  'carry',
#  'track_down',
#  'melt',
#  'pass',
#  'execute',
#  'operate',
#  'flow',
#  'hunt',
#  'race',
#  'feed',
#  'ply',
#  'lead',
#  'campaign',
#  'go',
#  'work',
#  'melt_down',
#  'range',
#  'function',
#  'lean',
#  'incline',
#  'black_market',
#  'be_given',
#  'run',
#  'information_technology',
#  'IT',
#  'cool_down',
#  'cool',
#  'chill',
#  "finger's_breadth",
#  'fingerbreadth',
#  'finger',
#  'digit',
#  'hair',
#  'haircloth',
#  'adult_male',
#  'valet',
#  'human',
#  'military_man',
#  'serviceman',
#  "gentleman's_gentleman",
#  'human_being',
#  'man',
#  'gentleman',
#  'valet_de_chambre',
#  'homo',
#  'military_personnel',
#  'constitute',
#  'Evergreen_State',
#  'Washington',
#  'be',
#  'represent',
#  'make_up',
#  'cost',
#  'WA',
#  'comprise',
#  'exist',
#  'about',
#  'nigh',
#  'around',
#  'or_so',
#  'virtually',
#  'nearly',
#  'roughly',
#  'near',
#  'close_to',
#  'some',
#  'well-nigh',
#  'most',
#  'approximately',
#  'more_or_less',
#  'almost',
#  'just_about',
#  'touch',
#  'foregather',
#  'take_on',
#  'fit',
#  'assemble',
#  'forgather',
#  'adjoin',
#  'satisfy',
#  'sports_meeting',
#  'fulfill',
#  'meet',
#  'gather',
#  'match',
#  'fill',
#  'converge',
#  'fulfil',
#  'encounter',
#  'play',
#  'cope_with',
#  'conform_to',
#  'contact',
#  'constitute',
#  'Evergreen_State',
#  'Washington',
#  'be',
#  'represent',
#  'make_up',
#  'cost',
#  'WA',
#  'comprise',
#  'exist',
#  'take',
#  'call_for',
#  'postulate',
#  'require',
#  'need',
#  'demand',
#  'necessitate',
#  'involve',
#  'exact',
#  'ask',
#  'just',
#  'but',
#  'only',
#  'simply',
#  'merely',
#  'music',
#  'euphony',
#  'past_times',
#  'yesteryear',
#  'past',
#  'by',
#  'window',
#  'windowpane',
#  'drape',
#  'drapery',
#  'curtain',
#  'mantle',
#  'pall',
#  'pull_in',
#  'string',
#  'suck',
#  'withdraw',
#  'make',
#  'draw_off',
#  'line',
#  'sop_up',
#  'suck_up',
#  'take_up',
#  'tie',
#  'delineate',
#  'depict',
#  'cast',
#  'trace',
#  'take_out',
#  'soak_up',
#  'draw',
#  'imbibe',
#  'attract',
#  'thread',
#  'describe',
#  'absorb',
#  'take_in',
#  'pull',
#  'draw_in',
#  'ME',
#  'Maine',
#  'Pine_Tree_State',
#  'onward',
#  'forward',
#  'forwards',
#  'send_on',
#  'forrader',
#  'ahead',
#  'onwards',
#  'ME',
#  'Maine',
#  'Pine_Tree_State',
#  'cross',
#  'cut_across',
#  'hybridise',
#  'crisscross',
#  'hybridisation',
#  'crossbreed',
#  'hybridizing',
#  'hybrid',
#  'hybridization',
#  'mark',
#  'track',
#  'intersect',
#  'traverse',
#  'cover',
#  'crossing',
#  'cut_through',
#  'Cross',
#  'get_over',
#  'crossbreeding',
#  'interbreeding',
#  'pass_over',
#  'hybridize',
#  'get_across',
#  'interbreed',
#  'doorway',
#  'room_access',
#  'door',
#  'threshold',
#  'doorstep',
#  'doorsill',
#  'step',
#  'pace',
#  'flat',
#  'apartment',
#  'emerald',
#  'CT',
#  'computed_tomography',
#  'computerized_tomography',
#  'computed_axial_tomography',
#  'computerized_axial_tomography',
#  'CAT',
#  'insert',
#  'record',
#  'enrol',
#  'enter',
#  'enroll',
#  'recruit',
#  'put_down',
#  'infix',
#  'inscribe',
#  'participate',
#  'introduce',
#  'b',
#  'barn',
#  'Bel',
#  'B',
#  'major',
#  'John_R._Major',
#  'John_Major',
#  'Major',
#  'John_Roy_Major',
#  'musical_scale',
#  'scale_of_measurement',
#  'scale',
#  'weighing_machine',
#  'graduated_table',
#  'surmount',
#  'ordered_series',
#  'extend',
#  'direct',
#  'LED',
#  'head',
#  'precede',
#  'conduct',
#  'lead',
#  'light-emitting_diode',
#  'go',
#  'run',
#  'pass',
#  'past',
#  'by',
#  'intrinsic',
#  'intrinsical',
#  'attraction',
#  'music',
#  'euphony',
#  'copulate',
#  'mate',
#  'couple_up',
#  'pair',
#  'couple',
#  'couple_on',
#  'layer',
#  'bed',
#  'belch',
#  'break_out',
#  'erupt',
#  'recrudesce',
#  'extravasate',
#  'jiffy',
#  'trice',
#  'wink',
#  'moment',
#  'minute',
#  'split_second',
#  'heartbeat',
#  'blink_of_an_eye',
#  'flash',
#  'twinkling',
#  'instant',
#  'second',
#  'instantaneous',
#  'New_York_minute',
#  "finger's_breadth",
#  'fingerbreadth',
#  'finger',
#  'digit',
#  'pasture',
#  'graze',
#  'crop',
#  'tusk',
#  'ivory',
#  'key',
#  'keystone',
#  'Key',
#  'tonality',
#  'headstone',
#  'Francis_Scott_Key',
#  'motor',
#  'driving',
#  'drive',
#  'forge',
#  'mallet',
#  'power_hammer',
#  'hammer',
#  'dissipate',
#  'take',
#  'frivol_away',
#  'fool_away',
#  'fool',
#  'snap',
#  'fritter',
#  'shoot',
#  'fritter_away',
#  'pip',
#  'photograph',
#  'film',
#  'quiver',
#  'quivering',
#  'oscillation',
#  'vibration',
#  'up',
#  'inch',
#  'Hoosier_State',
#  'Indiana',
#  'in',
#  'IN',
#  'strain',
#  'melody',
#  'aviation',
#  'beam',
#  'transmit',
#  'bare',
#  'send',
#  'atmosphere',
#  'publicise',
#  'melodic_phrase',
#  'airwave',
#  'air_travel',
#  'tune',
#  'melodic_line',
#  'line',
#  'broadcast',
#  'publicize',
#  'air',
#  'wholly',
#  'altogether',
#  'all',
#  'completely',
#  'whole',
#  'totally',
#  'entirely',
#  'about',
#  'around',
#  'or_so',
#  'roughly',
#  'close_to',
#  'some',
#  'approximately',
#  'more_or_less',
#  'just_about',
#  'ME',
#  'Maine',
#  'Pine_Tree_State',
#  'go_down',
#  'hide',
#  'strike_down',
#  'fall',
#  'lessen',
#  'fell',
#  'descend',
#  'come_down',
#  'cut_down',
#  'decrease',
#  'drop',
#  'diminish',
#  'come',
#  'inch',
#  'Hoosier_State',
#  'Indiana',
#  'in',
#  'IN',
#  'enjoy',
#  'honey',
#  'dear',
#  'love',
#  'beloved',
#  'dearest',
#  'sexual_love',
#  'erotic_love',
#  'newly',
#  'new',
#  'fresh',
#  'freshly',
#  'extension_phone',
#  'wing',
#  'file_name_extension',
#  'filename_extension',
#  'prolongation',
#  'lengthiness',
#  'telephone_extension',
#  'extension',
#  'propagation',
#  'annexe',
#  'annex',
#  'organic_structure',
#  'physical_structure',
#  'consistence',
#  'eubstance',
#  'body',
#  'torso',
#  'consistency',
#  'soundbox',
#  'trunk',
#  'brain',
#  'listen',
#  'nous',
#  'head',
#  'heed',
#  'psyche',
#  'mind',
#  'take_care',
#  'mommy',
#  'momma',
#  'mummy',
#  'mamma',
#  'mum',
#  'mom',
#  'ma',
#  'mammy',
#  'mama',
#  'start',
#  'commence',
#  'set_out',
#  'set_about',
#  'begin',
#  'start_out',
#  'get_down',
#  'get',
#  'placard',
#  'posting',
#  'bill',
#  'observe',
#  'point_out',
#  'card',
#  'detect',
#  'poster',
#  'discover',
#  'find',
#  'comment',
#  'remark',
#  'notice',
#  'forte-piano',
#  'piano',
#  'pianissimo',
#  'pianoforte',
#  'start',
#  'commence',
#  'set_out',
#  'set_about',
#  'begin',
#  'start_out',
#  'get_down',
#  'get',
#  'refund',
#  'repay',
#  'give_back',
#  'generate',
#  'yield',
#  'render',
#  'return',
#  'deliver',
#  'give',
#  'domicile',
#  'house',
#  'menage',
#  'household',
#  'internal',
#  'family',
#  'home',
#  'national',
#  'dwelling',
#  'abode',
#  'habitation',
#  'dwelling_house',
#  'place',
#  'interior',
#  'inch',
#  'Hoosier_State',
#  'Indiana',
#  'in',
#  'IN',
#  'coat_of_arms',
#  'blazonry',
#  'subdivision',
#  'munition',
#  'weapon',
#  'weaponry',
#  'weapon_system',
#  'blazon',
#  'arms',
#  'branch',
#  'weapons_system',
#  'arm',
#  'implements_of_war',
#  'fuel',
#  'fueled',
#  'sentence',
#  'judgment_of_conviction',
#  'conviction',
#  'condemnation',
#  'every_bit',
#  'angstrom',
#  'ampere',
#  'as',
#  'amp',
#  'A',
#  'angstrom_unit',
#  'equally',
#  'angstrom',
#  'ampere',
#  'amp',
#  'A',
#  'angstrom_unit',
#  'uprising',
#  'originate',
#  'go_up',
#  'develop',
#  'come_up',
#  'move_up',
#  'uprise',
#  'grow',
#  'rise',
#  'insurrection',
#  'lift',
#  'rebellion',
#  'rising',
#  'arise',
#  'climb',
#  'revolt',
#  'spring_up',
#  'musician',
#  'instrumentalist',
#  'player',
#  'just',
#  'but',
#  'only',
#  'simply',
#  'merely',
#  'sureness',
#  'confidence',
#  'self-confidence',
#  'authority',
#  'assurance',
#  'trust',
#  'self-assurance',
#  'felt',
#  'sense',
#  'feel',
#  'similar',
#  'wish',
#  'like',
#  'care',
#  'alike',
#  'constitute',
#  'Evergreen_State',
#  'Washington',
#  'be',
#  'represent',
#  'make_up',
#  'cost',
#  'WA',
#  'comprise',
#  'exist',
#  'miss',
#  'overleap',
#  'neglect',
#  'lack',
#  'leave_out',
#  'overlook',
#  'omit',
#  'pretermit',
#  'drop',
#  'game',
#  'punt',
#  'backwards',
#  'rearward',
#  'book_binding',
#  'back',
#  'plunk_for',
#  'indorse',
#  'backward',
#  'binding',
#  'cover',
#  'dorsum',
#  'bet_on',
#  'stake',
#  'support',
#  'rearwards',
#  'plump_for',
#  'endorse',
#  'gage',
#  'rear',
#  'backrest',
#  'inch',
#  'Hoosier_State',
#  'Indiana',
#  'in',
#  'IN',
#  'flat',
#  'apartment',
#  'walk',
#  'forte-piano',
#  'piano',
#  'pianissimo',
#  'pianoforte',
#  'music',
#  'euphony',
#  'Yardbird_Parker',
#  'Parker',
#  'Bird_Parker',
#  'Charlie_Parker',
#  'Charles_Christopher_Parker',
#  'newly',
#  'new',
#  'fresh',
#  'freshly',
#  'forte-piano',
#  'piano',
#  'pianissimo',
#  'pianoforte',
#  'instructor',
#  'teacher',
#  'eye',
#  'middle',
#  'heart',
#  'optic',
#  'oculus',
#  'centre',
#  'center',
#  'shut_down',
#  'closed',
#  'close_up',
#  'close_down',
#  'close',
#  'fold',
#  'clip',
#  'cut_back',
#  'crop',
#  'groom',
#  'lop',
#  'trim',
#  'snip',
#  'curry',
#  'dress',
#  'prune',
#  'inch',
#  'Hoosier_State',
#  'Indiana',
#  'in',
#  'IN',
#  'blackamoor',
#  'melanize',
#  'Negroid',
#  'Black',
#  'blacken',
#  'black',
#  'nigrify',
#  'melanise',
#  'Black_person',
#  'Negro',
#  'custody',
#  'hired_man',
#  'deal',
#  'give',
#  'handwriting',
#  'pass',
#  'turn_over',
#  'manpower',
#  'paw',
#  'reach',
#  'manus',
#  'hands',
#  'script',
#  'hired_hand',
#  'pass_on',
#  'hand',
#  'men',
#  'mitt',
#  'work_force',
#  'workforce',
#  'bridge_player',
#  'key',
#  'keystone',
#  'Key',
#  'tonality',
#  'headstone',
#  'Francis_Scott_Key',
#  'digest',
#  'endure',
#  'bear',
#  'stomach',
#  'tolerate',
#  'support',
#  'stand',
#  'stick_out',
#  'suffer',
#  'resist',
#  'brook',
#  'abide',
#  'put_up',
#  'fend',
#  'angstrom',
#  'ampere',
#  'amp',
#  'A',
#  'angstrom_unit',
#  'leather',
#  'death_chair',
#  'chairwoman',
#  'hot_seat',
#  'president',
#  'chair',
#  'chairperson',
#  'electric_chair',
#  'chairman',
#  'await',
#  'expect',
#  'waitress',
#  'wait',
#  'look',
#  'every_bit',
#  'angstrom',
#  'ampere',
#  'as',
#  'amp',
#  'A',
#  'angstrom_unit',
#  'equally',
#  'complete',
#  'terminate',
#  'end',
#  'cease',
#  'finish',
#  'stop',
#  'phrase',
#  'musical_phrase',
#  'digest',
#  'endure',
#  'bear',
#  'stomach',
#  'tolerate',
#  'support',
#  'stand',
#  'stick_out',
#  'suffer',
#  'resist',
#  'brook',
#  'abide',
#  'put_up',
#  'fend',
#  'up',
#  'Saturday',
#  'ride',
#  'sit',
#  'Sabbatum',
#  'Sat',
#  'downward',
#  'downwards',
#  'downwardly',
#  'depressed',
#  'down',
#  'Chopin',
#  'Frederic_Francois_Chopin',
#  'blackamoor',
#  'melanize',
#  'Negroid',
#  'Black',
#  'blacken',
#  'black',
#  'nigrify',
#  'melanise',
#  'Black_person',
#  'Negro',
#  'key',
#  'keystone',
#  'Key',
#  'tonality',
#  'headstone',
#  'Francis_Scott_Key',
#  'etude',
#  'angstrom',
#  'ampere',
#  'amp',
#  'A',
#  'angstrom_unit',
#  'piece',
#  'opus',
#  'assemble',
#  'spell',
#  'put_together',
#  'tack',
#  'set_up',
#  'patch',
#  'composition',
#  'while',
#  'piece_of_music',
#  'tack_together',
#  'pick',
#  'musical_composition',
#  'nibble',
#  'cognize',
#  'recognize',
#  'recognise',
#  'cognise',
#  'acknowledge',
#  'know',
#  'hence',
#  'thus',
#  'sol',
#  'and_so',
#  'then',
#  'soh',
#  'and_then',
#  'thence',
#  'therefore',
#  'so',
#  'comfortably',
#  'well',
#  'good',
#  'drama',
#  'caper',
#  'represent',
#  'take_on',
#  'gambling',
#  'frolic',
#  'period_of_play',
#  'wager',
#  'romp',
#  'roleplay',
#  "child's_play",
#  'bet',
#  'spiel',
#  'playing_period',
#  'act',
#  'meet',
#  'gambol',
#  'playact',
#  'turn',
#  'gaming',
#  'recreate',
#  'encounter',
#  'play',
#  'dramatic_play',
#  'information_technology',
#  'IT',
#  'eye',
#  'middle',
#  'heart',
#  'optic',
#  'oculus',
#  'centre',
#  'center',
#  'shut_down',
#  'closed',
#  'close_up',
#  'close_down',
#  'close',
#  'fold',
#  'remove',
#  'postulate',
#  'take_on',
#  'withdraw',
#  'pick_out',
#  'submit',
#  'subscribe_to',
#  'strike',
#  'consume',
#  'involve',
#  'take_up',
#  'ask',
#  'hire',
#  'take_aim',
#  'bring',
#  'convey',
#  'require',
#  'rent',
#  'aim',
#  'choose',
#  'need',
#  'ingest',
#  'shoot',
#  'train',
#  'have',
#  'call_for',
#  'subscribe',
#  'engage',
#  'contain',
#  'necessitate',
#  'take',
#  'take_away',
#  'direct',
#  'hold',
#  'take_in',
#  'assume',
#  'charter',
#  'accept',
#  'lease',
#  'demand',
#  'adopt',
#  'acquire',
#  'select',
#  'film',
#  'angstrom',
#  'ampere',
#  'amp',
#  'A',
#  'angstrom_unit',
#  'pose',
#  'put',
#  'position',
#  'lay',
#  'place',
#  'set',
#  'redress',
#  'the_right_way',
#  'decently',
#  'right',
#  'aright',
#  'right_hand',
#  'correct',
#  'properly',
#  'decent',
#  'correctly',
#  'rightfulness',
#  'in_good_order',
#  'rectify',
#  'compensate',
#  'right_wing',
#  'pass_on',
#  'reach',
#  'script',
#  'hand',
#  ...]
