# %% [markdown]
# https://radimrehurek.com/gensim/models/coherencemodel.html

# %%
from gensim.test.utils import common_corpus, common_dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel
# Out:
# /Users/kimkwangil/opt/anaconda3/envs/py37pytorch/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model = LdaModel(common_corpus, 5, common_dictionary)
# Out:
# /Users/kimkwangil/opt/anaconda3/envs/py37pytorch/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
cm = CoherenceModel(model=model, corpus=common_corpus, coherence='u_mass')
coherence = cm.get_coherence()  # get coherence value
# Out:
# /Users/kimkwangil/opt/anaconda3/envs/py37pytorch/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
coherence
# Out:
# /Users/kimkwangil/opt/anaconda3/envs/py37pytorch/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -14.679371186797123

# %%
from gensim.test.utils import common_corpus, common_dictionary
from gensim.models.coherencemodel import CoherenceModel
topics = [
    ['human', 'computer', 'system', 'interface']
]

# %%
v
# Out:
# [[(0, 1), (1, 1), (2, 1)],
#  [(0, 1), (3, 1), (4, 1), (5, 1), (6, 1), (7, 1)],
#  [(2, 1), (5, 1), (7, 1), (8, 1)],
#  [(1, 1), (5, 2), (8, 1)],
#  [(3, 1), (6, 1), (7, 1)],
#  [(9, 1)],
#  [(9, 1), (10, 1)],
#  [(9, 1), (10, 1), (11, 1)],
#  [(4, 1), (10, 1), (11, 1)]]

# %%
common_dictionary

# %%
cm = CoherenceModel(topics=topics, corpus=common_corpus, dictionary=common_dictionary, coherence='u_mass')
coherence = cm.get_coherence()  # get coherence value

# %%
coherence
# Out:
# -0.7607246985689725

# %%
# -*- coding: utf-8 -*- 
from konlpy.tag import Mecab 
from tqdm import tqdm 
import re 
import pickle 
import csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-d3e5395c045c> in <module>
#       1 # -*- coding: utf-8 -*-
# ----> 2 from konlpy.tag import Mecab
#       3 from tqdm import tqdm
#       4 import re
#       5 import pickle
#
# ModuleNotFoundError: No module named 'konlpy'

# %%
def clean_text(text):
    text = text.replace(".", " ").strip() 
    text = text.replace("·", " ").strip() 
    pattern = '[^ ㄱ-ㅣ가-힣|0-9|a-zA-Z]+' 
    text = re.sub(pattern=pattern, repl='', string=text) 
    return text

# %%
def get_nouns(tokenizer, sentence): 
#     """ 단어의 길이가 2이상인 일반명사(NNG), 고유명사(NNP), 외국어(SL)만을 반환한다. 
#     :param tokenizer: :param sentence: :return: """ 
    tagged = tokenizer.pos(sentence) 
    nouns = [s for s, t in tagged if t in ['SL', 'NNG', 'NNP'] and len(s) > 1]
    return nouns

# %%
def tokenize(df):
    tokenizer = Mecab(dicpath='/Users/kimkwangil/Documents/001_ESSAYFITAI/Accu-Critique/CollegeSuppEssay') 
    processed_data = [] 
    for sent in tqdm(df['description']): 
        sentence = clean_text(sent.replace('\n', '').strip()) 
        processed_data.append(get_nouns(tokenizer, sentence)) 
    return processed_data

# %%
def save_processed_data(processed_data): 
    """ 토큰 분리한 데이터를 csv로 저장 :param processed_data: :return: """ 
    with open('./data/tokenized_data.csv', 'w', newline='', encoding='utf-8') as f: 
        writer = csv.writer(f) 
        for data in processed_data: 
            writer.writerow(data) 

if __name__ == '__main__': 
    # 유공자 공훈조서 데이터를 읽어들인다. 
    df = pd.read_csv('./historical_records.csv') 
    processed_data = tokenize(df) # description 부분을 토크나이징 한다. 
    # 토큰 분리한 데이터를 저장 
    save_processed_data(processed_data)

# %%
# -*- coding: utf-8 -*- 
from konlpy.tag import Mecab 
from tqdm import tqdm 
import re 
from gensim.models.ldamodel import LdaModel 
from gensim.models.callbacks import CoherenceMetric 
from gensim import corpora 
from gensim.models.callbacks import PerplexityMetric
import logging
import pickle
#import pyLDAvis.gensim
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step): 
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics) 
        model_list.append(model) 
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# %%
def find_optimal_number_of_topics(dictionary, corpus, processed_data):
    limit = 40;
    start = 2;
    step = 6;
    
    model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=processed_data, start=start, limit=limit, step=step)
    
    x = range(start, limit, step)
    
    plt.plot(x, coherence_values)
    plt.xlabel("Num Topics")
    plt.ylabel("Coherence score")
    plt.legend(("coherence_values"), loc='best')
    plt.show()

# %%
if __name__ == '__main__': 
    processed_data = [sent.strip().split(",") for sent in tqdm(open('./tokenized_data.csv', 'r', encoding='utf-8').readlines())] 
    # 정수 인코딩과 빈도수 생성 
    dictionary = corpora.Dictionary(processed_data) 
    # 출현빈도가 적거나 자주 등장하는 단어는 제거 
    dictionary.filter_extremes(no_below=10, no_above=0.05) 
    corpus = [dictionary.doc2bow(text) for text in processed_data] 
    print('Number of unique tokens: %d' % len(dictionary)) 
    print('Number of documents: %d' % len(corpus)) 
    
    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) 
    
    # 최적의 토픽 수 찾기 find_optimal_number_of_topics(dictionary, corpus, processed_data)
# Out:
# 100%|██████████| 15925/15925 [00:00<00:00, 155745.57it/s]
# Number of unique tokens: 5998
# Number of documents: 15925

# %%
processed_data
# Out:
# [['일본',
#   '동경',
#   '박열',
#   '흑도회',
#   '기관지',
#   '흑도',
#   '흑우회',
#   '기관지',
#   '태선인',
#   '현사회',
#   '간행',
#   '무정부주의',
#   '선전',
#   '회원',
#   '규합',
#   '노력',
#   '박열',
#   '주도',
#   '무정부주의',
#   '단체',
#   '불령사',
#   '가입',
#   '활동',
#   '동년',
#   '동경',
#   '대지진',
#   '직후',
#   '체포',
#   '박열',
#   '대역사건',
#   '기소',
#   '사형',
#   '이후',
#   '무기징역',
#   '감형',
#   '우쓰노미야형무소',
#   '우도궁형무소',
#   '도치기지소',
#   '회목지소',
#   '수감',
#   '옥중',
#   '순국',
#   '박열',
#   '의기투합',
#   '일본',
#   '제국주의',
#   '반대',
#   '활동',
#   '시작',
#   '흑도회',
#   '가입',
#   '박열',
#   '기관지',
#   '흑도',
#   '발간',
#   '책임',
#   '흑우회',
#   '조직',
#   '사상연구',
#   '연설회',
#   '추진',
#   '기관지',
#   '민중운동',
#   '한글',
#   '발행',
#   '후토이센진',
#   '창간',
#   '현사회',
#   '이름',
#   '개칭',
#   '지속',
#   '발간',
#   '무정부주의',
#   '운동가',
#   '규합',
#   '불령사',
#   '조직',
#   '불령사',
#   '한국',
#   '형평운동',
#   '지지',
#   '한편',
#   '노동운동',
#   '적극',
#   '지원',
#   '무정부주의',
#   '입각',
#   '항일투쟁',
#   '전개',
#   '의열단',
#   '의열투쟁',
#   '추진',
#   '폭탄',
#   '도쿄',
#   '반입',
#   '일왕',
#   '정부',
#   '요인',
#   '암살',
#   '계획',
#   '도쿄대지진',
#   '직후',
#   '보호',
#   '감속',
#   '명목',
#   '도쿄',
#   '세타가야',
#   '경찰서',
#   '구금',
#   '취조',
#   '도중',
#   '폭탄',
#   '반입',
#   '사실',
#   '대역사건',
#   '주모자',
#   '구금',
#   '박열',
#   '결혼',
#   '일제',
#   '사법',
#   '당국',
#   '항일',
#   '활동',
#   '항변',
#   '재판',
#   '만세',
#   '대심원',
#   '특별형사부',
#   '형법',
#   '폭발물취체규칙위반',
#   '사형',
#   '언도',
#   '무기징역',
#   '감형',
#   '옥고',
#   '옥중',
#   '순국',
#   '정부',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['인천상업학교',
#   '출신',
#   '명치대학생',
#   '송재필',
#   '학병',
#   '반대',
#   '결의문',
#   '적경',
#   '탐지',
#   '송재필',
#   '동급생',
#   '한국인',
#   '학생',
#   '친목회',
#   '결성',
#   '트집',
#   '체포',
#   '고문',
#   '순국',
#   '충남',
#   '서산',
#   '사람',
#   '인천상업학교',
#   '재학',
#   '한국인',
#   '학생',
#   '차별',
#   '대우',
#   '한국인',
#   '학생',
#   '비밀리',
#   '친목회',
#   '조직',
#   '고락',
#   '결의',
#   '일본인',
#   '교장',
#   '야마',
#   '모도',
#   '억압',
#   '반대',
#   '학교',
#   '졸업앨범',
#   '제작',
#   '졸업',
#   '항일운동',
#   '계속',
#   '약속',
#   '학교',
#   '출신',
#   '일본',
#   '명치',
#   '진학',
#   '송재필',
#   '보성전문학교',
#   '친구',
#   '방문',
#   '학병',
#   '반대운동',
#   '전개',
#   '결의',
#   '각처',
#   '편지',
#   '연락',
#   '충북',
#   '동서',
#   '발각',
#   '친목회',
#   '가입',
#   '고윤희',
#   '김여수',
#   '형설',
#   '정태윤',
#   '동기생',
#   '동서',
#   '치안유지법',
#   '위반',
#   '혐의',
#   '대전',
#   '검사국',
#   '송치',
#   '일경',
#   '고문',
#   '옥고',
#   '여독',
#   '대전형무소',
#   '옥사',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['대한독립청년단',
#   '안면',
#   '지단',
#   '설치',
#   '군자금',
#   '모집활동',
#   '일경',
#   '피체',
#   '공주',
#   '지방',
#   '법원',
#   '정치범',
#   '처벌',
#   '반역',
#   '징역',
#   '집행유예',
#   '활동',
#   '사실',
#   '확인',
#   '충남',
#   '서산',
#   '태안',
#   '사람',
#   '독립운동',
#   '당시',
#   '서산군',
#   '안면도',
#   '만세',
#   '시위',
#   '주도',
#   '이후',
#   '비밀결사',
#   '대한독립청년단',
#   '가입',
#   '항일활동',
#   '독립청년단',
#   '윤종정',
#   '안영식',
#   '평양',
#   '기독교',
#   '중심',
#   '조직',
#   '임시정부',
#   '지원',
#   '단체',
#   '주요',
#   '활동',
#   '임시정부',
#   '통신',
#   '연락',
#   '군자금',
#   '모집',
#   '비밀',
#   '출판',
#   '이종성',
#   '이종헌',
#   '임정호',
#   '오몽근',
#   '서산군',
#   '안면도',
#   '독립청년단',
#   '지단',
#   '독립',
#   '지단',
#   '조직',
#   '이후',
#   '가정',
#   '청년',
#   '역방',
#   '동지',
#   '규합',
#   '단원',
#   '군자금',
#   '모집',
#   '착수',
#   '군자금',
#   '모금',
#   '동지',
#   '일경',
#   '동년',
#   '공주지방법원',
#   '정치범',
#   '처벌',
#   '위반',
#   '징역',
#   '집행유예',
#   '언도',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['경술국치',
#   '통탄',
#   '매일신보',
#   '애국',
#   '사상',
#   '고취',
#   '독립투사',
#   '양성',
#   '무관학교',
#   '설립',
#   '참가',
#   '활동',
#   '일경',
#   '체포',
#   '징역형',
#   '옥고',
#   '출옥',
#   '감시',
#   '취체',
#   '상해',
#   '탈출',
#   '세월',
#   '광복',
#   '환국',
#   '사실',
#   '확인',
#   '황해도',
#   '송화군',
#   '연중',
#   '수리',
#   '양기탁',
#   '안창호',
#   '전덕기',
#   '중심',
#   '국권회복',
#   '비밀결사',
#   '신민회',
#   '창립',
#   '가입',
#   '지회',
#   '활동',
#   '신민회',
#   '만주',
#   '무관학교',
#   '설립',
#   '독립군',
#   '기지',
#   '창건',
#   '사업',
#   '추진',
#   '적극',
#   '참가',
#   '초순',
#   '만주',
#   '안동현',
#   '독립군',
#   '기지',
#   '후보지',
#   '시찰',
#   '물색',
#   '평안북도',
#   '용천',
#   '신민회',
#   '회원',
#   '김용규',
#   '고일청',
#   '김용삼',
#   '김희',
#   '김성주',
#   '동지',
#   '하순',
#   '연락',
#   '근거지',
#   '성공',
#   '익룡',
#   '안동현',
#   '상업',
#   '경영',
#   '안동',
#   '만주',
#   '중국',
#   '통로',
#   '거점',
#   '설립',
#   '한편',
#   '다수',
#   '청년',
#   '북경무관학교',
#   '입학',
#   '알선',
#   '입학',
#   '자금',
#   '공급',
#   '한편',
#   '서간도',
#   '독립군',
#   '기지',
#   '무관학교',
#   '이주민',
#   '모집',
#   '사업',
#   '일제',
#   '신민회',
#   '무관학교',
#   '독립군',
#   '기지',
#   '창건',
#   '운동',
#   '탄압',
#   '관계',
#   '인사',
#   '검거',
#   '소위',
#   '양기탁',
#   '보안법위반',
#   '사건',
#   '징역',
#   '언도',
#   '경성형무소',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['부산',
#   '전영진',
#   '박귀선',
#   '이인형',
#   '등사판',
#   '일본',
#   '통치',
#   '조선',
#   '독립',
#   '내용',
#   '격문',
#   '인쇄',
#   '노동자',
#   '배포',
#   '선전',
#   '활동',
#   '피체',
#   '징역',
#   '집행유예',
#   '사실',
#   '확인',
#   '경남',
#   '산청',
#   '사람',
#   '평소',
#   '일제',
#   '식민지',
#   '통치',
#   '반대',
#   '민족',
#   '의식',
#   '부산',
#   '전영진',
#   '박귀선',
#   '이인형',
#   '독립',
#   '의식',
#   '고취',
#   '격문',
#   '인쇄',
#   '배포',
#   '항일투쟁',
#   '전개',
#   '일본',
#   '식민지',
#   '통치',
#   '독립',
#   '혁명',
#   '노동자',
#   '선두',
#   '농민',
#   '소시민',
#   '조직',
#   '단결',
#   '일반',
#   '의식',
#   '각성',
#   '등사판',
#   '내용',
#   '격문',
#   '인쇄',
#   '노동자',
#   '배포',
#   '선전',
#   '동년',
#   '일경',
#   '부산지방법원',
#   '유죄',
#   '판결',
#   '공소',
#   '대구복심법원',
#   '출판법',
#   '보안법',
#   '위반',
#   '징역',
#   '집행유예',
#   '출옥',
#   '노동조합',
#   '운동',
#   '참가',
#   '김상혁',
#   '전남',
#   '지방',
#   '노동조합',
#   '건설',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['만주',
#   '집안',
#   '옥석',
#   '대한민국임시정부',
#   '육군주만참의부',
#   '대원',
#   '활동',
#   '중국',
#   '보갑대',
#   '교전',
#   '전사',
#   '순국',
#   '사실',
#   '확인',
#   '평북',
#   '정주',
#   '사람',
#   '중반',
#   '만주',
#   '지역',
#   '대표',
#   '독립운동',
#   '단체',
#   '참의부',
#   '가담',
#   '활동',
#   '강경근',
#   '활동',
#   '참의부',
#   '통의부',
#   '이념',
#   '문제',
#   '통의부',
#   '의군부',
#   '분열',
#   '중립',
#   '입장',
#   '견지',
#   '통의부',
#   '의용군',
#   '중대',
#   '임시정부',
#   '연계',
#   '조직',
#   '압록강',
#   '연안',
#   '지역',
#   '관할',
#   '독립운동',
#   '단체',
#   '참의부',
#   '중앙',
#   '의회',
#   '군사',
#   '민정',
#   '통괄',
#   '창설',
#   '당시',
#   '주요',
#   '부서',
#   '간부',
#   '다음',
#   '의장',
#   '중대장',
#   '광운',
#   '중대장',
#   '최석순',
#   '중대장',
#   '중대장',
#   '창빈',
#   '중대장',
#   '김창대',
#   '훈련대장',
#   '참의부',
#   '군사',
#   '활동',
#   '전개',
#   '활동',
#   '중대장',
#   '광운',
#   '중대장',
#   '최석순',
#   '이해',
#   '광운',
#   '피살',
#   '최석순',
#   '의장',
#   '중대장',
#   '군사',
#   '활동',
#   '주도',
#   '강경근',
#   '참여',
#   '참의부',
#   '군사',
#   '활동',
#   '국내',
#   '진격',
#   '대표',
#   '참의부',
#   '압록강',
#   '유역',
#   '지리',
#   '이점',
#   '최대한',
#   '활용',
#   '국경',
#   '일본군',
#   '초소',
#   '습격',
#   '대일',
#   '항쟁',
#   '전개',
#   '독립신문',
#   '일자',
#   '통계',
#   '참의부',
#   '군대',
#   '차례',
#   '정도',
#   '국내',
#   '진격',
#   '군자금',
#   '모금',
#   '무장활동',
#   '전개',
#   '계절',
#   '독립군',
#   '자연',
#   '이용',
#   '대일투쟁',
#   '시절',
#   '감안',
#   '숫자',
#   '통계',
#   '독립군',
#   '평안도',
#   '의주군',
#   '초산군',
#   '강계군',
#   '선천군',
#   '영변군',
#   '위원군',
#   '태천군',
#   '용천군',
#   '자성군',
#   '평안도',
#   '지역',
#   '중심',
#   '활동',
#   '전개',
#   '지역',
#   '평안도',
#   '지역',
#   '압록강',
#   '대안',
#   '평안도',
#   '지역',
#   '지역',
#   '이점',
#   '참의부',
#   '주민',
#   '독립군',
#   '병사',
#   '가운데',
#   '평안도',
#   '출신',
#   '지리',
#   '효과',
#   '게릴라전',
#   '수행',
#   '부원',
#   '활동',
#   '강경근',
#   '집안',
#   '옥석',
#   '독립운동',
#   '전개',
#   '친일',
#   '중국',
#   '보갑대',
#   '충돌',
#   '계동',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['거류민단',
#   '간사',
#   '선임',
#   '활동',
#   '대한적십자회',
#   '상의원',
#   '선출',
#   '국민대표회의',
#   '태극',
#   '대표',
#   '참가',
#   '성명서',
#   '발표',
#   '교민',
#   '의원',
#   '인성학교',
#   '유지',
#   '활동',
#   '교민',
#   '총무',
#   '의정원',
#   '평안도',
#   '의사',
#   '선임',
#   '활동',
#   '한국',
#   '독립기념일',
#   '교민',
#   '단장',
#   '대리',
#   '총무',
#   '불조계',
#   '북문',
#   '민국',
#   '침례',
#   '기념식',
#   '참여',
#   '동년',
#   '상해',
#   '인성학교',
#   '교감',
#   '활동',
#   '한국유일당',
#   '독립당',
#   '창설',
#   '성회',
#   '집행',
#   '위원',
#   '참석',
#   '이후',
#   '남경',
#   '활동',
#   '피살',
#   '활동',
#   '사실',
#   '확인',
#   '평북',
#   '정주',
#   '사람',
#   '중국',
#   '망명',
#   '동년',
#   '상해',
#   '여운형',
#   '대한민국임시정부',
#   '거류민단',
#   '규칙',
#   '기초',
#   '조직',
#   '상해대한인거류민단',
#   '간사',
#   '선임',
#   '지역',
#   '한인',
#   '자치',
#   '활동',
#   '통솔',
#   '한편',
#   '임시정부',
#   '민족운동',
#   '후원',
#   '임시정부',
#   '후원',
#   '전시',
#   '부상자',
#   '구호',
#   '목적',
#   '조직',
#   '대한적십자회',
#   '상의원',
#   '선출',
#   '김구',
#   '활동',
#   '한편',
#   '국내',
#   '요파',
#   '연락',
#   '사회주의',
#   '운동',
#   '민족운동',
#   '방략',
#   '모색',
#   '임시정부',
#   '조직',
#   '개편',
#   '창조',
#   '조파',
#   '분립',
#   '태극',
#   '대표',
#   '국민대표회의',
#   '참가',
#   '안창호',
#   '주장',
#   '조파',
#   '성명',
#   '지지',
#   '동년',
#   '지역',
#   '재류',
#   '한인',
#   '독립운동가',
#   '조직',
#   '교민',
#   '의원',
#   '활동',
#   '교민',
#   '단과',
#   '중국',
#   '상해',
#   '재류',
#   '일반',
#   '동포',
#   '자질',
#   '민족정신',
#   '교육',
#   '설립',
#   '인성학교',
#   '운영',
#   '활성',
#   '노력',
#   '교민',
#   '단장',
#   '이유필',
#   '의원',
#   '김승학',
#   '교민',
#   '의사회',
#   '개최',
#   '교민',
#   '조직',
#   '제정',
#   '교민',
#   '조례',
#   '개정',
#   '부과금',
#   '징수',
#   '재정',
#   '충원',
#   '논의',
#   '통과',
#   '대한민국임시정부',
#   '임시의정원',
#   '의원',
#   '동년',
#   '교민',
#   '총무',
#   '임시의정원',
#   '평안도',
#   '의사',
#   '선임',
#   '활동',
#   '최석순',
#   '대통령',
#   '이승만',
#   '탄핵',
#   '안건',
#   '임시',
#   '정원',
#   '제출',
#   '이승만',
#   '축출',
#   '불란서',
#   '조계',
#   '교민',
#   '단장',
#   '대리',
#   '한국',
#   '독립선언',
#   '기념식',
#   '거행',
#   '식사',
#   '낭독',
#   '동년',
#   '인성학교',
#   '교감',
#   '동포',
#   '자제',
#   '대상',
#   '민족',
#   '교육',
#   '실시',
#   '중국',
#   '상해',
#   '개최',
#   '한국유일당',
#   '조직',
#   '성회',
#   '참석',
#   '집행',
#   '위원',
#   '선정',
#   '한인',
#   '독립운동',
#   '단체',
#   '통합',
#   '노력',
#   '이후',
#   '남경',
#   '활동',
#   '피살',
#   '독립운동',
#   '마감',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '독립장',
#   '추서'],
#  ['공립협회',
#   '대한',
#   '국민회',
#   '메리다지방회',
#   '가입',
#   '활동',
#   '대한',
#   '국민회',
#   '라지',
#   '방회',
#   '대의원',
#   '재무',
#   '회장',
#   '총회',
#   '건축',
#   '위원',
#   '집행위원장',
#   '통신원',
#   '역임',
#   '차례',
#   '독립운동',
#   '자금',
#   '지원',
#   '멕시코',
#   '대한',
#   '국민회',
#   '지방회',
#   '대의원',
#   '지방회',
#   '회장',
#   '역임',
#   '독립운동',
#   '자금',
#   '지원',
#   '공립협회',
#   '회원',
#   '대한',
#   '국민회',
#   '메리다지방회',
#   '회원',
#   '지방회',
#   '대의원',
#   '지방회',
#   '재무',
#   '지방회',
#   '회장',
#   '대한',
#   '국민회',
#   '총회',
#   '건축',
#   '위원',
#   '지방회',
#   '집행위원장',
#   '활동',
#   '지방회',
#   '통신',
#   '지방통신원',
#   '통신',
#   '사무',
#   '차례',
#   '독립운동',
#   '자금',
#   '지원',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['경북', '안동군', '풍산면', '이준태', '권오설', '풍산', '소작', '인회', '창립', '집행', '위원', '활동'],
#  ['대동단',
#   '가입',
#   '독립운동',
#   '자금',
#   '납부',
#   '군자금',
#   '모집',
#   '활동',
#   '일경',
#   '피체',
#   '대구복심법원',
#   '징역',
#   '사실',
#   '확인',
#   '전북',
#   '남원',
#   '사람',
#   '대동단',
#   '가입',
#   '김재구',
#   '한태현',
#   '남원',
#   '지방',
#   '중심',
#   '조직',
#   '확대',
#   '한편',
#   '서울',
#   '대동단',
#   '본부',
#   '교부',
#   '각종',
#   '선전물',
#   '배포',
#   '독립',
#   '의식',
#   '고취',
#   '군자금',
#   '모집',
#   '대동단',
#   '본부',
#   '제공',
#   '독립운동',
#   '대동단',
#   '최익환',
#   '민족',
#   '단결',
#   '표방',
#   '서울',
#   '결성',
#   '독립운동',
#   '단체',
#   '본부',
#   '서울',
#   '전국',
#   '각처',
#   '지단',
#   '설치',
#   '동단',
#   '당시',
#   '사회',
#   '각층',
#   '황족',
#   '진신',
#   '유림',
#   '종교',
#   '교육',
#   '상공',
#   '노동',
#   '청년',
#   '군인',
#   '부인',
#   '지역',
#   '구역',
#   '분류',
#   '각층',
#   '인사',
#   '통일',
#   '종합',
#   '국민',
#   '조직',
#   '구상',
#   '강경진',
#   '활약',
#   '남원',
#   '지단',
#   '청년',
#   '단원',
#   '근간',
#   '조직',
#   '활동',
#   '자금',
#   '수합',
#   '서울',
#   '대동단',
#   '본부',
#   '지원',
#   '대동단',
#   '본부',
#   '주도',
#   '의친왕',
#   '망명',
#   '계획',
#   '일경',
#   '발각',
#   '대동단',
#   '조직',
#   '전모',
#   '동단',
#   '전라북도',
#   '지단',
#   '자연',
#   '발각',
#   '광주지방법원',
#   '군산',
#   '지청',
#   '징역',
#   '언도',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['충남',
#   '예산군',
#   '대흥면',
#   '동서리',
#   '대흥공립보통학교',
#   '학생',
#   '광주학생운동',
#   '일제',
#   '탄압',
#   '대항',
#   '만세',
#   '시위',
#   '운동',
#   '가담',
#   '활동',
#   '피체',
#   '옥고',
#   '사실',
#   '확인',
#   '충남',
#   '예산',
#   '사람',
#   '충남',
#   '예산군',
#   '대흥면',
#   '손지리',
#   '김만복',
#   '광주학생운동',
#   '일제',
#   '탄압',
#   '대항',
#   '동맹휴교',
#   '만세',
#   '시위',
#   '전개',
#   '지시',
#   '동년',
#   '대흥면',
#   '동서리',
#   '대흥공립보통학교',
#   '학생',
#   '윤소현',
#   '배덕',
#   '신화균',
#   '규합',
#   '만세',
#   '시위',
#   '전개',
#   '결의',
#   '오후',
#   '동서리',
#   '학생',
#   '일제',
#   '편파',
#   '조치',
#   '비난',
#   '만세',
#   '시위운동',
#   '주도',
#   '활동',
#   '전개',
#   '일경',
#   '옥고',
#   '정부',
#   '공훈',
#   '대통령표창',
#   '수여'],
#  ['임실',
#   '천도교',
#   '교구장',
#   '영태',
#   '독립선언서',
#   '실면',
#   '요소',
#   '게시',
#   '독립만세운동',
#   '고취',
#   '활동',
#   '체포',
#   '징역',
#   '사실',
#   '확인',
#   '전라북도',
#   '임실',
#   '사람',
#   '천도교인',
#   '서울',
#   '독립선언서',
#   '임실',
#   '읍내',
#   '관공서',
#   '게시판',
#   '게시',
#   '이날',
#   '운암면',
#   '지천리',
#   '천도교',
#   '구실',
#   '교구장',
#   '영태',
#   '박판',
#   '한준석',
#   '최양옥',
#   '우성오',
#   '황성진',
#   '김영원',
#   '박성근',
#   '교도',
#   '독립선언서',
#   '이날',
#   '독립선언서',
#   '학교',
#   '경찰서',
#   '면사무소',
#   '장터',
#   '관공서',
#   '게시판',
#   '게시',
#   '서울',
#   '독립만세운동',
#   '지역',
#   '주민',
#   '독립사상',
#   '고취',
#   '임실',
#   '장날',
#   '전개',
#   '독립만세시위',
#   '정신',
#   '배경',
#   '체포',
#   '이해',
#   '고등',
#   '법원',
#   '보안법',
#   '위반',
#   '혐의',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['동지',
#   '국내',
#   '평북',
#   '창성군',
#   '대창',
#   '면장',
#   '살해',
#   '동군',
#   '삼림',
#   '주사',
#   '강황',
#   '습격',
#   '살해',
#   '다수',
#   '군자금',
#   '모금',
#   '임강현',
#   '두도',
#   '도구',
#   '지역',
#   '강서',
#   '복부',
#   '순사',
#   '이하',
#   '충돌',
#   '전투',
#   '일경',
#   '피살',
#   '순국',
#   '사실',
#   '확인',
#   '만주',
#   '활동',
#   '독립운동가',
#   '운동',
#   '이후',
#   '만주',
#   '지역',
#   '독립운동',
#   '단체',
#   '조직',
#   '서간',
#   '지역',
#   '조직',
#   '대표',
#   '단체',
#   '서로군정서',
#   '대한독립단',
#   '단체',
#   '서간',
#   '지역',
#   '집안',
#   '유하',
#   '통화',
#   '등지',
#   '중심',
#   '군자금',
#   '모집',
#   '친일파',
#   '처단',
#   '국내',
#   '진공',
#   '작전',
#   '전개',
#   '국내',
#   '치안',
#   '두려움',
#   '일제',
#   '훈춘사건',
#   '조작',
#   '간도',
#   '출병',
#   '독립운동',
#   '단체',
#   '공격',
#   '한편',
#   '일반',
#   '양민',
#   '대량',
#   '학살',
#   '독립운동가',
#   '가운데',
#   '일부',
#   '독립운동',
#   '단체',
#   '정비',
#   '움직임',
#   '일부',
#   '인사',
#   '일제',
#   '귀순',
#   '일부',
#   '러시',
#   '아령',
#   '피신',
#   '시기',
#   '강계선',
#   '동지',
#   '국내',
#   '친일파',
#   '평북',
#   '창성군',
#   '대창',
#   '면장',
#   '처단',
#   '삼림',
#   '주사',
#   '장인',
#   '강황',
#   '습격',
#   '처단',
#   '발사',
#   '독립운동',
#   '전개',
#   '수차례',
#   '군자금',
#   '모금',
#   '활동',
#   '만주',
#   '이동한',
#   '강계선',
#   '만주',
#   '무장활동',
#   '전개',
#   '주목',
#   '일제',
#   '일경',
#   '임강현',
#   '파견',
#   '강계선',
#   '체포',
#   '동지',
#   '김재순',
#   '만주',
#   '임강현',
#   '도구',
#   '조도',
#   '지역',
#   '강서',
#   '복부',
#   '순사',
#   '이하',
#   '충돌',
#   '전투',
#   '전개',
#   '김재순',
#   '체포',
#   '강계선',
#   '전사',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['전남',
#   '제주',
#   '한림면',
#   '협재리',
#   '홍경옥',
#   '장용진',
#   '사회과학',
#   '서적',
#   '윤독',
#   '사회주의',
#   '사상',
#   '함양',
#   '소재',
#   '구우공립보통학교',
#   '이전',
#   '문제',
#   '무산',
#   '농민',
#   '부담',
#   '가중',
#   '이전',
#   '반대',
#   '진정서',
#   '반대',
#   '결의',
#   '무명',
#   '비밀',
#   '결사',
#   '조직',
#   '소년부',
#   '담당',
#   '동지',
#   '규합',
#   '활동',
#   '피체',
#   '징역',
#   '사실',
#   '확인',
#   '제주',
#   '사람',
#   '제주도',
#   '한림면',
#   '협재리',
#   '홍경옥',
#   '장용진',
#   '사회과학',
#   '서적',
#   '윤독',
#   '사회주의',
#   '사상',
#   '함양',
#   '소재',
#   '구우공립보통학교',
#   '이전',
#   '문제',
#   '무산',
#   '농민',
#   '부담',
#   '가중',
#   '이전',
#   '반대',
#   '진정서',
#   '반대',
#   '결의',
#   '하순',
#   '장용진',
#   '홍경옥',
#   '협재리',
#   '무명',
#   '비밀결사',
#   '소년부',
#   '담당',
#   '동지',
#   '규합',
#   '활동',
#   '일경',
#   '광주지방법원',
#   '목포지청',
#   '치안유지법',
#   '위반',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['전북',
#   '남원군',
#   '상치',
#   '정리',
#   '유종',
#   '의진',
#   '참여',
#   '활동',
#   '일군',
#   '체포',
#   '피살',
#   '순국',
#   '사실',
#   '확인',
#   '전북',
#   '남원',
#   '출신',
#   '유종',
#   '진에',
#   '참여',
#   '전북',
#   '남원',
#   '활동',
#   '유종',
#   '유생',
#   '정읍',
#   '동학',
#   '농민',
#   '항쟁',
#   '참여',
#   '창의',
#   '전북',
#   '순창',
#   '태인',
#   '전남',
#   '담양',
#   '장성',
#   '광주',
#   '활동',
#   '의병장',
#   '음력',
#   '전북',
#   '순창',
#   '장성',
#   '일대',
#   '부하',
#   '활동',
#   '음력',
#   '순창',
#   '담양',
#   '광주',
#   '일대',
#   '장순흥',
#   '총기',
#   '휴대',
#   '의병',
#   '지휘',
#   '식료품',
#   '짚신',
#   '군수품',
#   '모집',
#   '순창군',
#   '쌍치면',
#   '학선리',
#   '오룡',
#   '전사',
#   '강관수',
#   '남원',
#   '상치',
#   '정리',
#   '광주',
#   '파견',
#   '일본군',
#   '토벌대',
#   '보병',
#   '신현숙',
#   '신석우',
#   '춘원',
#   '체포',
#   '취조',
#   '결과',
#   '의병',
#   '동년',
#   '상치',
#   '북방',
#   '곡리',
#   '총살',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['제주도',
#   '구좌',
#   '세화리',
#   '신재홍',
#   '오문',
#   '비밀결사',
#   '혁우동맹',
#   '조직',
#   '청년',
#   '책임',
#   '계몽활동',
#   '사회주의',
#   '사상',
#   '고취',
#   '방안',
#   '논의',
#   '상순',
#   '이후',
#   '조선공산당',
#   '제주',
#   '이카',
#   '기관',
#   '책임자',
#   '활동',
#   '구좌',
#   '등지',
#   '해녀',
#   '권익',
#   '옹호',
#   '운동',
#   '단체',
#   '지도',
#   '조종',
#   '활동',
#   '전개',
#   '제주도',
#   '해녀',
#   '사건',
#   '체포',
#   '징역',
#   '사실',
#   '확인',
#   '제주공립농업학교',
#   '졸업',
#   '영명학교',
#   '교사',
#   '야학',
#   '계몽운동',
#   '전개',
#   '동아일보',
#   '기자',
#   '활동',
#   '강철',
#   '필명',
#   '항일',
#   '의식',
#   '고취',
#   '기고',
#   '제주도',
#   '구좌',
#   '제주시',
#   '구좌읍',
#   '세화리',
#   '신재홍',
#   '오문',
#   '비밀결사',
#   '혁우동맹',
#   '조직',
#   '항일운동',
#   '전개',
#   '혁우동맹',
#   '제주청년동맹',
#   '산하',
#   '지부',
#   '일제',
#   '탄압',
#   '활동',
#   '비밀결사',
#   '형태',
#   '조직',
#   '사회주의',
#   '단체',
#   '혁우동맹',
#   '청년',
#   '대상',
#   '사회주의',
#   '사상',
#   '고취',
#   '대중',
#   '계몽',
#   '활동',
#   '주요',
#   '방침',
#   '이때',
#   '청년',
#   '책임',
#   '청년',
#   '단원',
#   '포섭',
#   '혁우동맹',
#   '상순',
#   '조선공산당',
#   '제주',
#   '체이',
#   '카로',
#   '조직',
#   '정비',
#   '기관',
#   '책임자',
#   '선임',
#   '제주도',
#   '구좌',
#   '등지',
#   '해녀',
#   '대상',
#   '항일',
#   '의식',
#   '고취',
#   '사회',
#   '방면',
#   '운동',
#   '단체',
#   '지도',
#   '주도',
#   '역할',
#   '수행',
#   '구좌',
#   '중심',
#   '제주',
#   '해녀',
#   '항일',
#   '시위운동',
#   '제주도',
#   '체이',
#   '역할',
#   '작용',
#   '당시',
#   '제주',
#   '해녀',
#   '해녀어업조합',
#   '어용',
#   '해산물',
#   '매수',
#   '가격',
#   '부정',
#   '항의',
#   '시위운동',
#   '전개',
#   '일제',
#   '해녀',
#   '세화주재소',
#   '시위',
#   '여파',
#   '해녀',
#   '청년',
#   '운동가',
#   '대대',
#   '검속',
#   '해녀',
#   '대표',
#   '구속',
#   '해녀',
#   '시위',
#   '배후',
#   '조직',
#   '강창보',
#   '사회주의',
#   '운동가',
#   '체포',
#   '강관',
#   '이때',
#   '일경',
#   '체포',
#   '대구복심법원',
#   '징역',
#   '선고',
#   '옥고',
#   '출옥',
#   '일가',
#   '함경도',
#   '청진',
#   '이사',
#   '옥중',
#   '고문',
#   '후유증',
#   '투병',
#   '생활',
#   '계속',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['충북',
#   '음성군',
#   '맹동면',
#   '마산리',
#   '와우형',
#   '강혜수',
#   '강대길',
#   '이용근',
#   '독립만세운동',
#   '주동',
#   '체포',
#   '사실',
#   '확인',
#   '충북',
#   '음성군',
#   '만세',
#   '운동',
#   '주도',
#   '맹동면',
#   '소재지',
#   '쌍정리',
#   '시작',
#   '시위',
#   '전체',
#   '확대',
#   '강구원',
#   '맹동면',
#   '마산리',
#   '와우형',
#   '강대길',
#   '횃불',
#   '독립만세운동',
#   '대대',
#   '전개',
#   '강구원',
#   '체포',
#   '공주지방법원',
#   '보안법',
#   '위반',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['평남',
#   '순천군',
#   '중국',
#   '관전',
#   '광복군사령부',
#   '사령장',
#   '조맹선',
#   '연결',
#   '대한독립청년단',
#   '군자금',
#   '모집',
#   '체포',
#   '징역',
#   '음력',
#   '평남',
#   '순천군',
#   '대한독립청년단',
#   '조직',
#   '평남',
#   '성천군',
#   '개천군',
#   '순천군',
#   '평북',
#   '영변군',
#   '단원',
#   '독립운동',
#   '자금',
#   '모집',
#   '체포',
#   '옥고',
#   '궁이',
#   '평남',
#   '개천군',
#   '개천면',
#   '운양리',
#   '출신',
#   '음력',
#   '강국',
#   '이병탁',
#   '독립청년단',
#   '조직',
#   '회원',
#   '모집',
#   '독립청년단',
#   '중국',
#   '관전',
#   '소재',
#   '광복군',
#   '사령관',
#   '조맹선',
#   '연락',
#   '국내',
#   '군자금',
#   '모집',
#   '대한민국임시정부',
#   '조선',
#   '관공리',
#   '처단',
#   '목적',
#   '무기',
#   '구입',
#   '독립군',
#   '국내',
#   '합류',
#   '독립',
#   '달성',
#   '목표',
#   '강국',
#   '대한독립청년단',
#   '율수',
#   '음력',
#   '순천군',
#   '북창',
#   '군자금',
#   '모집',
#   '이후',
#   '단원',
#   '평남',
#   '성천군',
#   '개천군',
#   '순천군',
#   '평북',
#   '영변군',
#   '군자금',
#   '모집',
#   '체포',
#   '평양지방법원',
#   '제령',
#   '위반',
#   '징역',
#   '평양형무소',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['황해도',
#   '수안군',
#   '천도교인',
#   '김영만',
#   '민족대표',
#   '손병희',
#   '발표',
#   '독립선언서',
#   '배부',
#   '독립운동',
#   '종용',
#   '찬성',
#   '천도교',
#   '신도',
#   '수안군',
#   '헌병',
#   '분대',
#   '독립',
#   '만세',
#   '구내',
#   '돌입',
#   '활동',
#   '피체',
#   '징역',
#   '사실',
#   '확인',
#   '황해도',
#   '수안군',
#   '읍내',
#   '천교',
#   '도인',
#   '중심',
#   '전개',
#   '규모',
#   '만세',
#   '운동',
#   '주도',
#   '시위',
#   '전개',
#   '동부',
#   '산악',
#   '지대',
#   '수안',
#   '곡산',
#   '천도교',
#   '전파',
#   '천도교',
#   '거사가',
#   '계획',
#   '전개',
#   '곡산',
#   '천도교인',
#   '이경섭',
#   '서울',
#   '만세',
#   '운동',
#   '소식',
#   '수안',
#   '천도교',
#   '교구장',
#   '차례',
#   '천도교',
#   '관계자',
#   '논의',
#   '군내',
#   '천도교',
#   '동원',
#   '독립선언서',
#   '배포',
#   '만세',
#   '운동',
#   '전개',
#   '계획',
#   '천도교',
#   '전도사',
#   '강국',
#   '각처',
#   '동지',
#   '거사',
#   '계획',
#   '전달',
#   '한편',
#   '대천',
#   '오동',
#   '연암',
#   '공포',
#   '천도교인',
#   '애국',
#   '동지',
#   '거사',
#   '계획',
#   '전달',
#   '군중',
#   '동원',
#   '아침',
#   '강국',
#   '다수',
#   '천도교',
#   '읍내',
#   '천도교',
#   '구실',
#   '헌병',
#   '분견',
#   '만세',
#   '행진',
#   '시위대',
#   '병분',
#   '견소',
#   '조선',
#   '독립',
#   '헌병대',
#   '철수',
#   '요구',
#   '일제',
#   '헌병',
#   '차별',
#   '사격',
#   '시위',
#   '군중',
#   '차례',
#   '시위',
#   '강국',
#   '경성복심법원',
#   '소요죄',
#   '징역',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서',
#   'span',
#   'stylefontfamily'],
#  ['전남',
#   '제주도',
#   '서귀',
#   '서홍리',
#   '소재',
#   '천주교회',
#   '신자',
#   '영국인',
#   '선교사',
#   '신부',
#   '붕해',
#   '성당',
#   '귀면',
#   '서홍리',
#   '자신',
#   '장소',
#   '중일전쟁',
#   '일제',
#   '양민',
#   '학살',
#   '원조',
#   '중국',
#   '선전',
#   '일제',
#   '고전',
#   '시국담',
#   '피체',
#   '금고',
#   '사실',
#   '확인',
#   '제주',
#   '사람',
#   '천주교',
#   '신자',
#   '동네',
#   '주민',
#   '원우',
#   '중일전쟁',
#   '일본',
#   '승리',
#   '라디오',
#   '방송',
#   '일본',
#   '상당',
#   '피해',
#   '전쟁',
#   '장기',
#   '일본',
#   '장래',
#   '위험',
#   '사이',
#   '원원',
#   '차례',
#   '시국담',
#   '인도',
#   '차이',
#   '반도',
#   '이해관계',
#   '영국',
#   '일본',
#   '사이',
#   '전쟁',
#   '가능',
#   '영일',
#   '전쟁',
#   '발발',
#   '일본',
#   '패전',
#   '필연',
#   '일본',
#   '전쟁',
#   '소득',
#   '이번',
#   '장개석',
#   '강화',
#   '요청',
#   '독일',
#   '패전',
#   '강국',
#   '일본',
#   '공격',
#   '일본',
#   '위험',
#   '내용',
#   '발언',
#   '일제',
#   '제주도',
#   '중국',
#   '도양',
#   '폭격',
#   '발진기',
#   '도내',
#   '반일',
#   '세력',
#   '색출',
#   '제거',
#   '적성국',
#   '영국',
#   '국적',
#   '아일랜드인',
#   '선교사',
#   '소속',
#   '천주교회',
#   '조직',
#   '탄압',
#   '파괴',
#   '대상',
#   '시작',
#   '배경',
#   '발언',
#   '유언비어',
#   '유포',
#   '이유',
#   '아일랜드인',
#   '선교사',
#   '천주교',
#   '신도',
#   '일경',
#   '광주지방법원',
#   '소위',
#   '해군',
#   '형법',
#   '위반',
#   '금고',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국포장',
#   '추서'],
#  ['경기도',
#   '가평',
#   '의병장',
#   '활동',
#   '연천헌병분파주재소',
#   '체포',
#   '총살',
#   '순국',
#   '사실',
#   '확인',
#   '제국',
#   '을사조약',
#   '강제',
#   '체결',
#   '국권',
#   '피탈',
#   '정미',
#   '조약',
#   '군대',
#   '산당',
#   '일제',
#   '식민지',
#   '상황',
#   '민족',
#   '무력',
#   '투쟁',
#   '의병운동',
#   '재개',
#   '해산',
#   '군인',
#   '의병',
#   '대열',
#   '참여',
#   '전국',
#   '민족',
#   '전쟁',
#   '확대',
#   '시기',
#   '무력',
#   '투쟁',
#   '국권',
#   '회복',
#   '경기도',
#   '가평',
#   '일대',
#   '의병',
#   '활동',
#   '의병활동',
#   '연천헌병분파주재소',
#   '피살',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['중국',
#   '만주',
#   '대한독립단',
#   '가입',
#   '길림성',
#   '환인',
#   '대한의군부',
#   '무부',
#   '부감',
#   '재무',
#   '부원',
#   '대한민국임시정부',
#   '독판',
#   '참모장',
#   '활동',
#   '사실',
#   '확인',
#   '만주',
#   '대한독립단',
#   '가입',
#   '대한의군부',
#   '무부',
#   '부감',
#   '재무',
#   '부원',
#   '대한민국임시정부',
#   '독판',
#   '참모장',
#   '활동',
#   '의병장',
#   '의암',
#   '유인석',
#   '문하',
#   '유하',
#   '삼원보',
#   '의병장',
#   '출신',
#   '박장호',
#   '조맹선',
#   '중심',
#   '결성',
#   '대한독립단',
#   '가입',
#   '활동',
#   '대한독립단',
#   '창립',
#   '총회',
#   '송상규',
#   '조응',
#   '이정근',
#   '참모',
#   '선임',
#   '이후',
#   '독립',
#   '단원',
#   '김승학',
#   '박승무',
#   '평북',
#   '박천',
#   '정석주',
#   '대한독립군',
#   '박천군',
#   '단장',
#   '사령장',
#   '전달',
#   '장병규',
#   '신태익',
#   '윤성권',
#   '국내',
#   '독립',
#   '국내',
#   '지단',
#   '설치',
#   '군자금',
#   '모집',
#   '활동',
#   '전개',
#   '대한독립단',
#   '통의부',
#   '의군부',
#   '개편',
#   '환인',
#   '대한의군부',
#   '무부',
#   '부감',
#   '재무',
#   '부원',
#   '활동',
#   '대한민국임시정부',
#   '주만',
#   '독판',
#   '중앙회의',
#   '참모장',
#   '당선',
#   '활동',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['경기도',
#   '장단군',
#   '진남',
#   '군중',
#   '독립',
#   '만세',
#   '고창',
#   '면사무소',
#   '공격',
#   '시위',
#   '전개',
#   '체포',
#   '징역',
#   '사실',
#   '확인',
#   '경기도',
#   '장단군',
#   '진남',
#   '전개',
#   '만세',
#   '운동',
#   '참가',
#   '선두',
#   '군중',
#   '시위',
#   '주도',
#   '진남',
#   '장리',
#   '성화학교',
#   '뒤편',
#   '군중',
#   '독립',
#   '만세',
#   '이창영',
#   '시위',
#   '참가',
#   '만세',
#   '이창영',
#   '시위',
#   '군중',
#   '남면',
#   '면사무소',
#   '제안',
#   '강규수',
#   '이창영',
#   '한기동',
#   '정순',
#   '선두',
#   '군중',
#   '인솔',
#   '면사무소',
#   '행진',
#   '면사무소',
#   '강규수',
#   '소리',
#   '면장',
#   '면사무소',
#   '강규수',
#   '면사무소',
#   '면장',
#   '이창영',
#   '곤봉',
#   '면사무소',
#   '장지문',
#   '강규수',
#   '한기동',
#   '정순',
#   '군중',
#   '사무소',
#   '유리문',
#   '파손',
#   '동시',
#   '군중',
#   '가세',
#   '시작',
#   '결과',
#   '면사무소',
#   '현관',
#   '입구',
#   '좌측',
#   '유리문',
#   '유리창',
#   '사무소',
#   '입구',
#   '문등',
#   '유리',
#   '파손',
#   '시위',
#   '체포',
#   '강규수',
#   '고등',
#   '법원',
#   '소요',
#   '보안법',
#   '위반',
#   '징역',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['전북',
#   '옥구군',
#   '개정면',
#   '구암리',
#   '영명중학교',
#   '재학',
#   '동교',
#   '교사',
#   '이두열',
#   '연세',
#   '주동한',
#   '군산',
#   '장날',
#   '독립',
#   '만세',
#   '거사',
#   '계획',
#   '참가',
#   '학교',
#   '독립선언서',
#   '복사',
#   '거사',
#   '준비',
#   '주동',
#   '교사',
#   '사전',
#   '검속',
#   '양기철',
#   '전세종',
#   '다수',
#   '학생',
#   '태극기',
#   '군산',
#   '시내',
#   '행진',
#   '합세',
#   '시민',
#   '군중',
#   '군산경찰서',
#   '시내',
#   '각처',
#   '독립선언서',
#   '살포',
#   '독립',
#   '만세',
#   '고창',
#   '피체',
#   '징역',
#   '사실',
#   '확인',
#   '제주',
#   '사람',
#   '당시',
#   '전북',
#   '옥구군',
#   '개정면',
#   '구암리',
#   '영명중학교',
#   '학생',
#   '학교',
#   '교사',
#   '이두열',
#   '연세',
#   '주도',
#   '독립',
#   '만세',
#   '시위운동',
#   '참여',
#   '학교',
#   '독립선언서',
#   '복사',
#   '거사',
#   '준비',
#   '주동',
#   '인물',
#   '사전',
#   '검거',
#   '양기철',
#   '전세종',
#   '군산',
#   '장날',
#   '이용',
#   '합세',
#   '주민',
#   '군산경찰서',
#   '시내',
#   '지역',
#   '독립선언서',
#   '배포',
#   '독립',
#   '만세',
#   '고창',
#   '시위행진',
#   '일경',
#   '광주지방법원',
#   '군산',
#   '지청',
#   '보안법',
#   '출판법',
#   '위반',
#   '유죄',
#   '판결',
#   '공소',
#   '대구복심법원',
#   '원판결',
#   '취소',
#   '징역',
#   '상고',
#   '고등',
#   '법원',
#   '기각',
#   '확정',
#   '옥고',
#   '출옥',
#   '고향',
#   '제주',
#   '모슬포',
#   '광선학교',
#   '설립',
#   '민족',
#   '교육',
#   '실시',
#   '인재',
#   '양성',
#   '활동',
#   '계속',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['원산',
#   '보광학교',
#   '재학',
#   '운동',
#   '기념',
#   '만세',
#   '시위',
#   '주도',
#   '징역',
#   '집행유예',
#   '함남',
#   '기자',
#   '대회',
#   '개최',
#   '일경',
#   '조지',
#   '규탄',
#   '연설회',
#   '개최',
#   '행진',
#   '시위',
#   '피체',
#   '징역',
#   '사실',
#   '확인',
#   '함남',
#   '덕원',
#   '사람',
#   '원산',
#   '보광학교',
#   '재학',
#   '독립운동',
#   '기념',
#   '시위',
#   '주도',
#   '군중',
#   '학교',
#   '원산',
#   '역전',
#   '번화가',
#   '격문',
#   '살포',
#   '활동',
#   '일경',
#   '경성복심법원',
#   '제령',
#   '위반',
#   '징역',
#   '집행유예',
#   '출옥',
#   '조선일보',
#   '원산',
#   '지국',
#   '경영',
#   '민족정신',
#   '계몽운동',
#   '진력',
#   '함남기자연맹',
#   '주최',
#   '함남기자대회',
#   '개최',
#   '일경',
#   '금지',
#   '경찰',
#   '탄핵',
#   '연설회',
#   '개최',
#   '시위행진',
#   '경성복심법원',
#   '보안법',
#   '위반',
#   '공무',
#   '집행',
#   '방해죄',
#   '금고',
#   '옥고',
#   '출옥',
#   '조선일보',
#   '원산지',
#   '국장',
#   '언론',
#   '항일운동',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['사건',
#   '징역',
#   '이듬해',
#   '무죄',
#   '방면',
#   '평남',
#   '평양',
#   '정일선',
#   '조선',
#   '독립선언식',
#   '거행',
#   '계획',
#   '동년',
#   '평양',
#   '숭덕학교',
#   '운동장',
#   '독립만세운동',
#   '주도',
#   '활동',
#   '체포',
#   '징역',
#   '미결',
#   '구류',
#   '통산',
#   '사실',
#   '확인',
#   '평남',
#   '평양',
#   '한국',
#   '독립선언식',
#   '거행',
#   '계획',
#   '숭덕학교',
#   '운동장',
#   '독립만세운동',
#   '주도',
#   '사건',
#   '체포',
#   '무죄',
#   '방면',
#   '강규찬',
#   '선우혁',
#   '연락',
#   '독립운동',
#   '계획',
#   '천도교',
#   '합동',
#   '운동',
#   '교섭',
#   '평양',
#   '독립선언식',
#   '협동',
#   '거행',
#   '결정',
#   '숭덕학교',
#   '교정',
#   '고종',
#   '도식',
#   '독립',
#   '포식',
#   '거행',
#   '강규찬',
#   '조선',
#   '독립',
#   '연설',
#   '사람',
#   '독립',
#   '만세',
#   '거리',
#   '진출',
#   '상인',
#   '철시',
#   '시위행진',
#   '가담',
#   '평양경찰서',
#   '천도교',
#   '구당',
#   '남산현교회',
#   '행진',
#   '군중',
#   '합세',
#   '도청',
#   '재판소',
#   '평양역',
#   '광장',
#   '평양부',
#   '평양형무소',
#   '시가지',
#   '독립',
#   '만세',
#   '오후',
#   '시위',
#   '군중',
#   '평양경찰서',
#   '경찰',
#   '충돌',
#   '투쟁',
#   '가운데',
#   '사람',
#   '상당',
#   '검거',
#   '학생',
#   '행진',
#   '만세',
#   '만세',
#   '운동',
#   '열기',
#   '계속',
#   '강규찬',
#   '체포',
#   '경성지방법원',
#   '보안법',
#   '위반',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['음력',
#   '중국',
#   '길림성',
#   '장백',
#   '도구',
#   '군비단',
#   '가입',
#   '동년',
#   '음력',
#   '함남',
#   '풍산',
#   '군자금',
#   '모집활동',
#   '음력',
#   '국민대회',
#   '참석',
#   '동년',
#   '음력',
#   '노령',
#   '활동',
#   '체포',
#   '징역',
#   '옥고',
#   '사실',
#   '확인',
#   '극모',
#   '음력',
#   '단신',
#   '중국',
#   '길림성',
#   '장백',
#   '도구',
#   '이주',
#   '군비단',
#   '가입',
#   '동년',
#   '음력',
#   '군비단',
#   '이동백',
#   '권유',
#   '함남',
#   '풍산',
#   '군자금',
#   '모집',
#   '활동',
#   '의학',
#   '공부',
#   '경험',
#   '군비단',
#   '군의',
#   '러시',
#   '아령',
#   '이만',
#   '파견',
#   '음력',
#   '국민대표회의',
#   '참석',
#   '파견',
#   '동년',
#   '음력',
#   '노령',
#   '활동',
#   '체포',
#   '경성복심법원',
#   '제령',
#   '위반',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['충남', '청양군', '운곡면', '독립만세운동', '참여', '활동', '체포'],
#  ['만주',
#   '정서',
#   '총사령부',
#   '사관',
#   '근무',
#   '서백리아',
#   '사관학교',
#   '교관',
#   '근무',
#   '공산주의',
#   '반대',
#   '투쟁',
#   '옥고',
#   '명월',
#   '국동',
#   '지회',
#   '청년',
#   '군사',
#   '훈련',
#   '교육',
#   '활동',
#   '사실',
#   '확인',
#   '함경남도',
#   '정평군',
#   '상면',
#   '조양리',
#   '사람',
#   '함흥중학교',
#   '학년',
#   '재학',
#   '학생',
#   '사건',
#   '일경',
#   '수배',
#   '만주',
#   '망명',
#   '만주',
#   '용정촌',
#   '독립만세시위',
#   '참가',
#   '만주',
#   '정서',
#   '무관학교',
#   '졸업',
#   '신흥무관학교',
#   '근무',
#   '청산리',
#   '전투',
#   '참가',
#   '서백리아',
#   '유시',
#   '전투',
#   '참전',
#   '한편',
#   '고려혁명군',
#   '사관학교',
#   '교관',
#   '근무',
#   '공산주의',
#   '반대',
#   '투쟁',
#   '형무소',
#   '옥고',
#   '만주',
#   '복귀',
#   '만주',
#   '명월',
#   '국동',
#   '지회',
#   '청년',
#   '군사',
#   '훈련',
#   '교관',
#   '청소년',
#   '군사',
#   '훈련',
#   '전념',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '건국포장',
#   '추서'],
#  ['박도경',
#   '의진',
#   '가담',
#   '동년',
#   '전북',
#   '부안',
#   '무장',
#   '고창',
#   '영광',
#   '의병',
#   '활동',
#   '체포',
#   '징역',
#   '사실',
#   '확인',
#   '전북',
#   '부안',
#   '출신',
#   '박도경',
#   '의진',
#   '참여',
#   '부안',
#   '무장',
#   '고창',
#   '영광',
#   '의병',
#   '활동',
#   '전개',
#   '광무황제',
#   '강제',
#   '퇴위',
#   '대한제국',
#   '군대',
#   '해산',
#   '전국',
#   '각지',
#   '의병',
#   '봉기',
#   '일제',
#   '국권침탈',
#   '항쟁',
#   '호남',
#   '지역',
#   '의병활동',
#   '전개',
#   '기삼연',
#   '전남',
#   '영광',
#   '수록산',
#   '석수암',
#   '결성',
#   '호남창의회맹소',
#   '대표',
#   '호남창의회맹소',
#   '이후',
#   '무장',
#   '법성포',
#   '고창',
#   '장성',
#   '전과',
#   '의병진',
#   '세력',
#   '박도경',
#   '호남창의회맹소',
#   '종사',
#   '포사대장',
#   '활동',
#   '음력',
#   '기삼연',
#   '체포',
#   '순국',
#   '박도경',
#   '호남창의회맹소',
#   '군사',
#   '수습',
#   '독자',
#   '의병진',
#   '편성',
#   '본진',
#   '포사',
#   '인근',
#   '의병',
#   '부대',
#   '연합',
#   '결성',
#   '군세',
#   '확장',
#   '효과',
#   '대일항전',
#   '전개',
#   '김영엽',
#   '의진',
#   '의진',
#   '필요',
#   '이합집산',
#   '광주',
#   '남포',
#   '부안',
#   '활동',
#   '부하',
#   '부안',
#   '상서면',
#   '일본군',
#   '기병대',
#   '교전',
#   '강금',
#   '박도경',
#   '의진',
#   '음력',
#   '참여',
#   '국권회복운동',
#   '박도경',
#   '휘하',
#   '의병',
#   '부안',
#   '무장',
#   '고창',
#   '영광',
#   '활동',
#   '체포',
#   '광주지방재판소',
#   '전주',
#   '지부',
#   '폭동',
#   '혐의',
#   '기소',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국포장',
#   '추서'],
#  ['일본',
#   '대판',
#   '계림동지회',
#   '조직',
#   '재일동포',
#   '학생',
#   '민족',
#   '의식',
#   '고취',
#   '활동',
#   '체포',
#   '대판지방재판소',
#   '징역',
#   '언도',
#   '사실',
#   '확인',
#   '제주도',
#   '제주',
#   '사람',
#   '일본',
#   '대판전문학교',
#   '야간부',
#   '재학',
#   '김봉각',
#   '김병목',
#   '고봉조',
#   '대판',
#   '조선인',
#   '학생',
#   '단결',
#   '도모',
#   '항일독립운동',
#   '전개',
#   '결의',
#   '동년',
#   '초순',
#   '판부',
#   '소재',
#   '김봉각',
#   '독립운동',
#   '근본',
#   '방침',
#   '의논',
#   '조선인',
#   '대중',
#   '상대',
#   '민족',
#   '의식',
#   '계몽',
#   '실천',
#   '단체',
#   '홍아연구회',
#   '독서',
#   '조직',
#   '결성',
#   '동회',
#   '조선',
#   '독립',
#   '이론',
#   '실천',
#   '연구',
#   '목적',
#   '항일결사',
#   '동년',
#   '중순',
#   '명칭',
#   '계림동지회',
#   '개칭',
#   '정치',
#   '사상',
#   '문예',
#   '종교',
#   '방면',
#   '전문',
#   '연구',
#   '당시',
#   '국제',
#   '정세',
#   '분석',
#   '독립운동',
#   '방향',
#   '모색',
#   '한편',
#   '연구',
#   '발표회',
#   '독립운동',
#   '지도자',
#   '수업',
#   '이때',
#   '사상이론연구부',
#   '책임',
#   '활약',
#   '동회',
#   '조직',
#   '일경',
#   '발각',
#   '대판지방재판소',
#   '치안유지법',
#   '위반',
#   '징역',
#   '언도',
#   '출옥',
#   '옥고',
#   '정부',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '수여'],
#  ['서울',
#   '운동',
#   '민족',
#   '대표',
#   '전국확산운동',
#   '참여',
#   '인중',
#   '학생',
#   '시위운동',
#   '최고지휘자',
#   '활동',
#   '피체',
#   '경성복심법원',
#   '징역',
#   '함남기자연맹',
#   '대회',
#   '운동',
#   '경성복심법원',
#   '금고',
#   '신간회',
#   '중앙집행위원장',
#   '선출',
#   '사실',
#   '확인',
#   '함남',
#   '원산',
#   '사람',
#   '당시',
#   '보성법률상업전문학교',
#   '학생',
#   '운동',
#   '민족',
#   '대표',
#   '인중',
#   '활약',
#   '신간회',
#   '중앙집행위원장',
#   '역임',
#   '손병희',
#   '이갑성',
#   '민족',
#   '대표',
#   '독립운동',
#   '계획',
#   '지시',
#   '김성득',
#   '김형기',
#   '김문진',
#   '김원벽',
#   '학교',
#   '학생',
#   '시위',
#   '참여',
#   '일체',
#   '임무',
#   '서북친목회',
#   '중심',
#   '동지',
#   '규합',
#   '이갑성',
#   '독립선언서',
#   '학생',
#   '지도자',
#   '회의',
#   '소집',
#   '학교',
#   '배부',
#   '학생',
#   '연락',
#   '책임',
#   '배재고등보통학교',
#   '기숙사',
#   '전문학교',
#   '학생',
#   '지도급',
#   '대표',
#   '장채',
#   '옥결',
#   '강우열',
#   '중등학교',
#   '대표',
#   '서울',
#   '학생',
#   '만세',
#   '시위',
#   '계획',
#   '김원벽',
#   '운동',
#   '최고',
#   '지휘자',
#   '추대',
#   '남대문역',
#   '서울역',
#   '광장',
#   '독립',
#   '만세',
#   '고창',
#   '시위',
#   '대열',
#   '주도',
#   '일경',
#   '이해',
#   '경성지방법원',
#   '예비',
#   '조사',
#   '소위',
#   '보안법',
#   '출판법',
#   '위반',
#   '소요죄',
#   '유죄',
#   '판결',
#   '경성복심법원',
#   '징역',
#   '언도',
#   '옥고',
#   '함남',
#   '기자대회',
#   '운동',
#   '경성복심법원',
#   '금고',
#   '언도',
#   '옥고',
#   '독립',
#   '활동',
#   '계속',
#   '신간회',
#   '원산',
#   '지회',
#   '정기총회',
#   '집행위원장',
#   '선출',
#   '이해',
#   '신간회',
#   '중앙',
#   '행회',
#   '위원',
#   '선출',
#   '다음',
#   '신간회',
#   '전체',
#   '대회',
#   '신간회',
#   '중앙집행위원장',
#   '선출',
#   '신간회',
#   '소파',
#   '활동',
#   '원산',
#   '노동',
#   '중진',
#   '원산',
#   '노동',
#   '회관',
#   '문제',
#   '관련',
#   '경성지방법원',
#   '검사국',
#   '공갈죄',
#   '기소',
#   '판결',
#   '결과',
#   '정부',
#   '공훈',
#   '건국훈장',
#   '독립장',
#   '수여'],
#  ['장단',
#   '고랑포',
#   '헌병보조원',
#   '옥문',
#   '다수',
#   '의병',
#   '구출',
#   '의병장',
#   '이은찬',
#   '오수영',
#   '강원호',
#   '토벌',
#   '맹서',
#   '방면',
#   '격전',
#   '포천',
#   '체포',
#   '교사',
#   '경기도',
#   '장단',
#   '고랑포',
#   '헌병보조원',
#   '정미칠조약',
#   '군대해산',
#   '일제',
#   '단행',
#   '의사',
#   '항일',
#   '무력',
#   '투쟁',
#   '전개',
#   '훈련',
#   '무기',
#   '의병',
#   '정규군',
#   '관군',
#   '일군',
#   '체포',
#   '이때',
#   '강기동',
#   '근무',
#   '장단',
#   '의병투쟁',
#   '체포',
#   '인물',
#   '다수',
#   '투옥',
#   '옥문',
#   '의병',
#   '구출',
#   '계기',
#   '의거',
#   '기치',
#   '의병',
#   '대장',
#   '각지',
#   '의병장',
#   '유기',
#   '관계',
#   '강기동',
#   '의진',
#   '양주',
#   '포천',
#   '중심',
#   '활약',
#   '주변',
#   '일대',
#   '경기도',
#   '양주',
#   '포천',
#   '위시',
#   '마전',
#   '황해도',
#   '토산',
#   '금천',
#   '재령',
#   '연기우',
#   '성서',
#   '이한경',
#   '활약',
#   '강기동',
#   '연기우',
#   '의진',
#   '비밀',
#   '연락',
#   '아래',
#   '밀착',
#   '전략',
#   '전개',
#   '연기우',
#   '군인',
#   '출신',
#   '의병장',
#   '군대',
#   '해산',
#   '직전',
#   '강화',
#   '진위대',
#   '봉기',
#   '장기간',
#   '투쟁',
#   '경력',
#   '소유자',
#   '현상금',
#   '사람',
#   '밀정',
#   '노출',
#   '방지',
#   '부대',
#   '소수',
#   '정예부대',
#   '편성',
#   '이은찬',
#   '체포',
#   '소식',
#   '강기동',
#   '남학',
#   '오수영',
#   '임명',
#   '격문',
#   '병사',
#   '대일',
#   '투쟁',
#   '지속',
#   '전개',
#   '맹서',
#   '포천',
#   '포천',
#   '왜병',
#   '접전',
#   '시기',
#   '강기동',
#   '의진',
#   '좌군',
#   '성서',
#   '휘하',
#   '인수',
#   '김순복',
#   '포천',
#   '지역',
#   '의병활동',
#   '체포',
#   '유죄',
#   '선고',
#   '강기동',
#   '이용규',
#   '영평',
#   '활약',
#   '일인',
#   '현상금',
#   '강기동',
#   '성서',
#   '양주',
#   '적군',
#   '교전',
#   '양주',
#   '노원',
#   '교전',
#   '서울',
#   '잠입',
#   '체포',
#   '순사',
#   '피신',
#   '강기동',
#   '강두필',
#   '병력',
#   '의병',
#   '부대',
#   '강원도',
#   '합방',
#   '일제',
#   '임시',
#   '파견대',
#   '대대',
#   '헌병',
#   '경찰대',
#   '연합',
#   '병력',
#   '경상도',
#   '일월산',
#   '중심',
#   '안동',
#   '예천',
#   '영춘',
#   '봉화',
#   '일대',
#   '포위',
#   '작전',
#   '전개',
#   '의병',
#   '일망타진',
#   '계획',
#   '추진',
#   '하순',
#   '초순',
#   '여단',
#   '병력',
#   '집중',
#   '대살',
#   '작전',
#   '전개',
#   '의병',
#   '부대',
#   '작전',
#   '사건',
#   '조작',
#   '신민회',
#   '소속',
#   '애국',
#   '계몽',
#   '운동가',
#   '거점',
#   '소탕',
#   '급진전',
#   '상당수',
#   '애국지사',
#   '두만강',
#   '압록강',
#   '만주',
#   '북간도',
#   '이동하',
#   '강기동',
#   '경기도',
#   '일대',
#   '활약',
#   '북간',
#   '도로',
#   '이동',
#   '원산',
#   '체포',
#   '압송',
#   '서울',
#   '용산',
#   '총살',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '대통령장',
#   '추서'],
#  ['평양',
#   '편리',
#   '직공',
#   '조합',
#   '발회식',
#   '축사',
#   '내용',
#   '체포',
#   '징역',
#   '옥고',
#   '평양청년동맹',
#   '신간회',
#   '평양지',
#   '위원',
#   '활동',
#   '고려공산청년회',
#   '가입',
#   '활동',
#   '체포',
#   '징역',
#   '사실',
#   '확인',
#   '평안남도',
#   '평양',
#   '청년운동',
#   '주도',
#   '체포',
#   '차례',
#   '옥고',
#   '강기',
#   '평양',
#   '편리',
#   '직공',
#   '조합',
#   '발회식',
#   '축사',
#   '빌미',
#   '소위',
#   '보안법',
#   '위반',
#   '징역',
#   '옥고',
#   '출옥',
#   '출옥',
#   '조선청년총동맹',
#   '평안남도',
#   '집행',
#   '위원',
#   '선출',
#   '평양',
#   '지역',
#   '청년',
#   '단체',
#   '총괄',
#   '평양청년동맹',
#   '집행위원장',
#   '청년운동',
#   '주도',
#   '한편',
#   '신간회',
#   '평양지',
#   '위원',
#   '활동',
#   '경성',
#   '당리',
#   '거주',
#   '비밀',
#   '결사',
#   '고려공산청년회',
#   '가입',
#   '그해',
#   '고려공산청년회',
#   '평안',
#   '남북',
#   '선임',
#   '빈민',
#   '구제',
#   '사회운동',
#   '실시',
#   '조선공산당',
#   '검거',
#   '사건',
#   '일경',
#   '강기',
#   '경성지방법원',
#   '치안유지법',
#   '위반',
#   '징역',
#   '선고',
#   '만기',
#   '출옥',
#   '후유증',
#   '출옥',
#   '마감',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['경남',
#   '함안군',
#   '함안',
#   '장날',
#   '이용',
#   '군중',
#   '독립',
#   '만세',
#   '고창',
#   '주재소',
#   '습격',
#   '기물',
#   '파괴',
#   '만세',
#   '시위',
#   '체포',
#   '징역',
#   '단성청년회',
#   '간부',
#   '활동',
#   '사실',
#   '확인',
#   '경남',
#   '산청',
#   '사람',
#   '경남',
#   '함안',
#   '장날',
#   '전개',
#   '독립만세운동',
#   '참가',
#   '금융조합',
#   '서기',
#   '재직',
#   '고종황제',
#   '인산',
#   '참배',
#   '서울',
#   '독립선언식',
#   '만세',
#   '시위',
#   '참가',
#   '독립선언서',
#   '휴대',
#   '거주지',
#   '함안면',
#   '서울',
#   '시위',
#   '자극',
#   '조한',
#   '이찬영',
#   '유지인사',
#   '모임',
#   '만세',
#   '시위운동',
#   '추진',
#   '대산면',
#   '한문',
#   '교사',
#   '안지호',
#   '연락',
#   '함안',
#   '장날',
#   '이용',
#   '만세',
#   '운동',
#   '전개',
#   '결의',
#   '태극기',
#   '제작',
#   '독립선언서',
#   '다량',
#   '사하',
#   '거사',
#   '당일',
#   '정오',
#   '주도',
#   '성동',
#   '시위',
#   '군중',
#   '태극기',
#   '독립선언서',
#   '독립',
#   '만세',
#   '고창',
#   '오후',
#   '시위',
#   '군중',
#   '시위',
#   '군중',
#   '독립',
#   '만세',
#   '고창',
#   '주재소',
#   '시위행진',
#   '전개',
#   '이때',
#   '출동',
#   '마산',
#   '경찰서',
#   '현지',
#   '일경',
#   '무력',
#   '시위군',
#   '해산',
#   '격노',
#   '시위',
#   '군중',
#   '주재소',
#   '공문서',
#   '파기',
#   '건물',
#   '파괴',
#   '사기',
#   '시위',
#   '군중',
#   '등기소',
#   '우체국',
#   '일본인',
#   '소학교',
#   '시위행진',
#   '건물',
#   '파괴',
#   '시위운동',
#   '전개',
#   '긴급',
#   '출동',
#   '마산',
#   '중포병',
#   '대대',
#   '총검',
#   '탄압',
#   '시위대',
#   '해산',
#   '만세',
#   '시위운동',
#   '참여',
#   '활동',
#   '체포',
#   '이해',
#   '부산지방법원',
#   '마산지청',
#   '소요',
#   '보안법',
#   '징역',
#   '옥고',
#   '출옥',
#   '산청군',
#   '성읍',
#   '개최',
#   '단성청년회',
#   '창립',
#   '총회',
#   '참가',
#   '사교',
#   '부장',
#   '선임',
#   '총무',
#   '직책',
#   '청년회',
#   '청년',
#   '계몽운동',
#   '종사',
#   '일경',
#   '체포',
#   '대구복심법원',
#   '징역',
#   '정부',
#   '고인',
#   '공훈',
#   '건국포장',
#   '추서'],
#  ['음력',
#   '만주',
#   '화룡현',
#   '국민회',
#   '가입',
#   '남부',
#   '지방',
#   '경호부장',
#   '장성순',
#   '휘하',
#   '송언',
#   '지회',
#   '경호원',
#   '일대',
#   '독립군',
#   '모집',
#   '일경',
#   '밀정',
#   '이덕선',
#   '달수',
#   '김덕기',
#   '주살',
#   '군자금',
#   '모집',
#   '활동',
#   '피체',
#   '무기징역',
#   '옥고',
#   '사실',
#   '확인',
#   '함북',
#   '회령',
#   '사람',
#   '음력',
#   '간도',
#   '화룡현',
#   '대한국민회',
#   '가입',
#   '남부',
#   '지방',
#   '경호부장',
#   '장성순',
#   '휘하',
#   '송언',
#   '지회',
#   '경호원',
#   '활약',
#   '말경',
#   '장성순',
#   '이하',
#   '함경준',
#   '장여',
#   '동지',
#   '화룡현',
#   '증봉',
#   '부근',
#   '야산',
#   '일제',
#   '밀정',
#   '이덕선',
#   '처단',
#   '한편',
#   '음력',
#   '두만강',
#   '건너',
#   '회령군',
#   '화풍',
#   '심동',
#   '김형섭',
#   '동민',
#   '군자금',
#   '제공',
#   '이날',
#   '마을',
#   '허육',
#   '별도',
#   '군자금',
#   '모금',
#   '활동',
#   '음력',
#   '순경',
#   '동료',
#   '고진홍',
#   '신언',
#   '증봉',
#   '부근',
#   '일제',
#   '헌병',
#   '보조원',
#   '남성',
#   '심문',
#   '밀정',
#   '단죄',
#   '군자금',
#   '모집활동',
#   '주력',
#   '일경',
#   '경성복심법원',
#   '제령',
#   '위반',
#   '무기징역',
#   '확정',
#   '옥고',
#   '출옥',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '독립장',
#   '추서'],
#  ['한국광복군', '지대', '입대', '국내', '정진', '교육훈련반', '편입', '사실', '확인'],
#  ['강원도',
#   '철원군',
#   '문면',
#   '다수',
#   '주민',
#   '동면',
#   '면사무소',
#   '태극기',
#   '독립',
#   '만세',
#   '고창',
#   '피체',
#   '징역',
#   '사실',
#   '확인',
#   '강원도',
#   '철원',
#   '사람',
#   '철원군',
#   '문면',
#   '천도교인',
#   '최재명',
#   '최재청',
#   '주붕',
#   '박용득',
#   '독립',
#   '만세',
#   '시위운동',
#   '계획',
#   '동년',
#   '철원군',
#   '문면',
#   '동리',
#   '만세',
#   '시위',
#   '면사무소',
#   '독립',
#   '만세',
#   '고창',
#   '활동',
#   '일경',
#   '이해',
#   '경성지방법원',
#   '보안법',
#   '위반',
#   '징역',
#   '언도',
#   '공소',
#   '경성복심법원',
#   '고등',
#   '법원',
#   '기각',
#   '확정',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['의병장',
#   '평북',
#   '영변',
#   '중심',
#   '활동',
#   '자위',
#   '단장',
#   '총기',
#   '탄약',
#   '모집',
#   '피체',
#   '탈출',
#   '피살',
#   '순국',
#   '사실',
#   '확인',
#   '평북',
#   '영변',
#   '사람',
#   '의병장',
#   '평북',
#   '영변',
#   '중심',
#   '활동',
#   '을사늑약',
#   '나라',
#   '국권',
#   '피탈',
#   '정미',
#   '조약',
#   '군대',
#   '해산',
#   '일제',
#   '식민지',
#   '상황',
#   '상황',
#   '강기찬',
#   '의병',
#   '일제',
#   '축출',
#   '국권',
#   '회복',
#   '강기찬',
#   '영변',
#   '동료',
#   '의병',
#   '인솔',
#   '총기',
#   '탄약',
#   '마련',
#   '자위단',
#   '단장',
#   '습격',
#   '자위단',
#   '한국',
#   '민중',
#   '의병',
#   '지원',
#   '동조',
#   '방지',
#   '일제',
#   '부일배',
#   '일본',
#   '관제',
#   '조직',
#   '의병',
#   '탄압',
#   '동원',
#   '강기찬',
#   '응징',
#   '무기',
#   '노획',
#   '공격',
#   '전투',
#   '과정',
#   '중과부적',
#   '관청',
#   '압송',
#   '도중',
#   '탈출',
#   '기도',
#   '자위',
#   '단원',
#   '피살',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['항일',
#   '목적',
#   '독서회',
#   '조직',
#   '소비조합',
#   '조직',
#   '상품',
#   '불매운동',
#   '야학교',
#   '설치',
#   '사상',
#   '교육',
#   '실시',
#   '체포',
#   '징역',
#   '언도',
#   '사실',
#   '확인',
#   '제주',
#   '사람',
#   '제주',
#   '삼덕리',
#   '김형수',
#   '김형수',
#   '고병희',
#   '조대수',
#   '동지',
#   '무정부주의',
#   '사상',
#   '연구',
#   '목적',
#   '비밀결사',
#   '독서회',
#   '조직',
#   '차례',
#   '모임',
#   '사회과학',
#   '서적',
#   '윤독',
#   '동지',
#   '규합',
#   '한편',
#   '소비조합',
#   '결성',
#   '일본',
#   '상품',
#   '불매운동',
#   '독서회',
#   '운영',
#   '계란',
#   '조합',
#   '결성',
#   '표면',
#   '우의',
#   '돈목',
#   '애경',
#   '상문',
#   '생활',
#   '향상',
#   '표방',
#   '무정부주의',
#   '이상',
#   '사회',
#   '실현',
#   '목적',
#   '계원',
#   '도청',
#   '은행',
#   '금융조합',
#   '학교',
#   '공무원',
#   '실업가',
#   '도내',
#   '유지',
#   '망라',
#   '계원',
#   '회비',
#   '은행',
#   '예금',
#   '노자',
#   '사상',
#   '생활',
#   '제주도',
#   '전통',
#   '사회',
#   '바탕',
#   '무정부주의',
#   '사회',
#   '실현',
#   '주목',
#   '단체',
#   '동리',
#   '야학',
#   '개설',
#   '항일민족의식',
#   '무정부주의',
#   '사상',
#   '고취',
#   '활동',
#   '동지',
#   '일경',
#   '광주지방법원',
#   '징역',
#   '언도',
#   '항소',
#   '대구복심법원',
#   '징역',
#   '확정',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '건국포장',
#   '추서'],
#  ['강서군',
#   '함종',
#   '독립만세운동',
#   '주동자',
#   '시위군',
#   '선봉',
#   '활동',
#   '체포',
#   '징역',
#   '사실',
#   '확인',
#   '평안남도',
#   '강서',
#   '사람',
#   '명건',
#   '김병선',
#   '김기준',
#   '김자지',
#   '박종권',
#   '윤태빈',
#   '최재은',
#   '함종',
#   '독립만세시위',
#   '주동',
#   '당시',
#   '경성의학전문학교',
#   '출신',
#   '의사',
#   '창림',
#   '김정현',
#   '이정연',
#   '독립만세시위',
#   '전개',
#   '결의',
#   '정오',
#   '공립보통학교',
#   '시위',
#   '군중',
#   '일장기',
#   '게양대',
#   '태극기',
#   '게양',
#   '독립선언서',
#   '낭독',
#   '군중',
#   '인솔',
#   '시위행진',
#   '시작',
#   '이때',
#   '헌병',
#   '출장',
#   '소장',
#   '상등병',
#   '시위',
#   '계획',
#   '통고',
#   '무력',
#   '개입',
#   '요구',
#   '시위',
#   '군중',
#   '폭력',
#   '무저항주의',
#   '호소',
#   '일본',
#   '헌병',
#   '시위',
#   '행렬',
#   '무력',
#   '개입',
#   '주동자',
#   '명단',
#   '작성',
#   '평화',
#   '만세',
#   '시위',
#   '군중',
#   '해산',
#   '일본',
#   '헌병',
#   '차별',
#   '사격',
#   '파악',
#   '주동자',
#   '체포',
#   '이때',
#   '가족',
#   '헌병',
#   '출장소',
#   '연행',
#   '철야',
#   '심문',
#   '헌병',
#   '머리',
#   '오물',
#   '시계',
#   '왼손',
#   '구둣발',
#   '시계',
#   '유리',
#   '파편',
#   '동맥',
#   '파열',
#   '실신',
#   '결국',
#   '이해',
#   '고등',
#   '법원',
#   '보안법',
#   '위반',
#   '혐의',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['평남',
#   '강서군',
#   '함종',
#   '독립만세운동',
#   '참여',
#   '독립청년단',
#   '가입',
#   '활동',
#   '체포',
#   '징역',
#   '대한독립청년단',
#   '사건',
#   '체포',
#   '징역',
#   '평남',
#   '강서군',
#   '함종',
#   '독립만세운동',
#   '참여',
#   '대한독립청년단',
#   '활동',
#   '체포',
#   '옥고',
#   '평남',
#   '강서군',
#   '함종',
#   '독립만세운동',
#   '참여',
#   '이날',
#   '시위',
#   '경성의학전문학교',
#   '출신',
#   '개업',
#   '강기',
#   '잡화상',
#   '김용수',
#   '오리',
#   '거주',
#   '이능',
#   '오영선',
#   '주도',
#   '공립보통학교',
#   '교정',
#   '군중',
#   '시위',
#   '부근',
#   '산승',
#   '광덕',
#   '계명',
#   '동리',
#   '참가',
#   '이날',
#   '시위',
#   '강기',
#   '평양복심법원',
#   '보안법',
#   '위반',
#   '징역',
#   '옥고',
#   '김현승',
#   '대한민국임시정부',
#   '원조',
#   '독립',
#   '달성',
#   '목적',
#   '강서군',
#   '함종',
#   '송동리',
#   '주민',
#   '중심',
#   '비밀결사',
#   '대한독립청년단',
#   '조직',
#   '인장',
#   '단원',
#   '증서',
#   '발행',
#   '단원',
#   '모집',
#   '단원',
#   '월사금',
#   '대한민국임시정부',
#   '이후',
#   '대민',
#   '윤석',
#   '군자금',
#   '모집',
#   '체포',
#   '평양지방법원',
#   '제령',
#   '위반',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['전국',
#   '각지',
#   '독립만세운동',
#   '호응',
#   '울산군',
#   '언양',
#   '읍내',
#   '장날',
#   '이용',
#   '만세',
#   '시위',
#   '계획',
#   '동지',
#   '비밀리',
#   '거사',
#   '준비',
#   '다음',
#   '언양',
#   '남부리',
#   '시장',
#   '군중',
#   '태극기',
#   '독립',
#   '만세',
#   '고창',
#   '피체',
#   '징역',
#   '사실',
#   '확인',
#   '경남',
#   '울산',
#   '사람',
#   '경남',
#   '울산',
#   '양면',
#   '남부리',
#   '시장',
#   '만세',
#   '시위운동',
#   '주도',
#   '언양',
#   '장날',
#   '만세',
#   '시위',
#   '운동',
#   '전국',
#   '확산',
#   '상황',
#   '천도교',
#   '계통',
#   '중심',
#   '추진',
#   '상남면',
#   '천도교',
#   '유지인',
#   '이무종',
#   '이규인',
#   '이성영',
#   '비밀리',
#   '만세',
#   '시위',
#   '계획',
#   '언양',
#   '장날',
#   '거사',
#   '동지',
#   '규합',
#   '강기',
#   '만세',
#   '시위',
#   '계획',
#   '참가',
#   '거사',
#   '태극기',
#   '제작',
#   '준비',
#   '진행',
#   '거사',
#   '이틀',
#   '주동',
#   '인물',
#   '가운데',
#   '최해규',
#   '일제',
#   '검거망',
#   '예비',
#   '검속',
#   '비밀',
#   '유지',
#   '거사',
#   '당일',
#   '언양',
#   '장터',
#   '만세',
#   '시위',
#   '거행',
#   '이날',
#   '강기',
#   '태극기',
#   '배포',
#   '독립',
#   '만세',
#   '고창',
#   '시위군',
#   '선두',
#   '시위',
#   '탄압',
#   '일경',
#   '투석',
#   '일본군',
#   '수비대',
#   '총격',
#   '시위군',
#   '현장',
#   '즉사',
#   '강기',
#   '현장',
#   '부산지방법원',
#   '울산',
#   '지청',
#   '보안법',
#   '위반',
#   '징역',
#   '공소',
#   '동년',
#   '대구복심법원',
#   '기각',
#   '확정',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['충남',
#   '천안군',
#   '입장면',
#   '양대리',
#   '장터',
#   '이민',
#   '학생',
#   '독립',
#   '만세',
#   '고창',
#   '체포',
#   '징역',
#   '사실',
#   '확인',
#   '충남',
#   '천안군',
#   '입장면',
#   '양대리',
#   '장터',
#   '만세',
#   '운동',
#   '주도',
#   '광명학교',
#   '교사',
#   '강기',
#   '학생',
#   '주민',
#   '모자',
#   '독립',
#   '만세',
#   '오전',
#   '양대리',
#   '시작',
#   '시위',
#   '행렬',
#   '하장리',
#   '입장시장',
#   '출동',
#   '천안헌병대',
#   '일대',
#   '충돌',
#   '남자',
#   '여자',
#   '체포',
#   '입장시장',
#   '시위',
#   '군중',
#   '독립선언서',
#   '배포',
#   '독립',
#   '만세',
#   '시위',
#   '계속',
#   '강기',
#   '체포',
#   '경성복심법원',
#   '고등',
#   '법원',
#   '보안법',
#   '위반',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['음력',
#   '양력',
#   '전남',
#   '함평군',
#   '월야면',
#   '예덕리',
#   '모양',
#   '독립운동',
#   '자금',
#   '모집',
#   '체포',
#   '징역',
#   '사실',
#   '확인',
#   '전라남도',
#   '함평군',
#   '독립운동',
#   '자금',
#   '모집',
#   '체포',
#   '옥고',
#   '전라남도',
#   '함평군',
#   '월야면',
#   '월계리',
#   '동기',
#   '동군',
#   '예덕리',
#   '모양',
#   '대한민국임시정부',
#   '군자금',
#   '모집',
#   '독립운동',
#   '자금',
#   '모집',
#   '체포',
#   '체포',
#   '광주지방법원',
#   '목포지청',
#   '보안법',
#   '위반',
#   '강도',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['김준',
#   '의진',
#   '활동',
#   '전남',
#   '창평',
#   '일병',
#   '교전',
#   '전사',
#   '순국',
#   '사실',
#   '확인',
#   '강길환',
#   '김태원',
#   '의진',
#   '활동',
#   '전남',
#   '창평',
#   '일병',
#   '교전',
#   '전사',
#   '순국',
#   '김태원',
#   '전남',
#   '나주',
#   '출신',
#   '결성',
#   '호남창의회맹소',
#   '선봉장',
#   '참여',
#   '동년',
#   '신덕순',
#   '정읍',
#   '내장사',
#   '합세',
#   '신덕순',
#   '도독',
#   '김태원',
#   '선봉',
#   '김율',
#   '호군',
#   '회문산',
#   '전투',
#   '신덕순',
#   '체포',
#   '의병진',
#   '월경',
#   '김태원',
#   '영광',
#   '나주',
#   '함평',
#   '무안',
#   '장성',
#   '독자',
#   '활동',
#   '당시',
#   '김태원',
#   '부대',
#   '의병',
#   '함평',
#   '주재소',
#   '습격',
#   '일본인',
#   '순사',
#   '사살',
#   '전라도',
#   '일원',
#   '항일투쟁',
#   '전개',
#   '김태원',
#   '부대',
#   '목표',
#   '소위',
#   '일본군',
#   '토벌대',
#   '동년',
#   '투입',
#   '일본군',
#   '토벌대',
#   '추격',
#   '김태원',
#   '부대',
#   '동년',
#   '창평',
#   '지곡',
#   '동촌',
#   '등지',
#   '전전',
#   '휘하',
#   '의병장',
#   '기삼연',
#   '전북',
#   '순창',
#   '체포',
#   '총살',
#   '동년',
#   '김율',
#   '체포',
#   '부하',
#   '등산',
#   '피살',
#   '순국',
#   '강길환',
#   '일본군',
#   '토벌대',
#   '추격',
#   '창평',
#   '무동',
#   '전사',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['경북',
#   '안동군',
#   '녹전면',
#   '서삼',
#   '동의',
#   '동장',
#   '재직',
#   '전국',
#   '전개',
#   '독립운동',
#   '자극',
#   '안동군',
#   '예안면',
#   '예안',
#   '장터',
#   '장날',
#   '운집',
#   '군중',
#   '독립',
#   '만세',
#   '고창',
#   '만세',
#   '시위',
#   '피체',
#   '징역',
#   '사실',
#   '확인',
#   '경북',
#   '안동',
#   '사람',
#   '안동군',
#   '녹전면',
#   '서삼',
#   '동의',
#   '동장',
#   '재직',
#   '전국',
#   '각지',
#   '전개',
#   '독립만세운동',
#   '호응',
#   '안동군',
#   '예안면',
#   '예안',
#   '장터',
#   '장날',
#   '이용',
#   '군중',
#   '태극기',
#   '독립',
#   '만세',
#   '만세',
#   '시위',
#   '일경',
#   '대구지방법원',
#   '안동',
#   '지청',
#   '보안법',
#   '위반',
#   '징역',
#   '언도',
#   '공소',
#   '대구복심법원',
#   '기각',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국포장',
#   '추서'],
#  ['함남',
#   '홍원군',
#   '천도',
#   '교구장',
#   '홍원군',
#   '천도교구',
#   '강인택',
#   '독립만세운동',
#   '참가',
#   '권유',
#   '해당',
#   '운동',
#   '전개',
#   '결의',
#   '홍원군',
#   '학천',
#   '풍산리',
#   '소재',
#   '강연',
#   '조선독립선언서',
#   '인쇄',
#   '홍원군',
#   '읍내',
#   '장터',
#   '시위',
#   '군중',
#   '선두',
#   '태극기',
#   '조선독립만세',
#   '시위',
#   '전개',
#   '체포',
#   '징역',
#   '함경남도',
#   '홍원',
#   '천교',
#   '도인',
#   '중심',
#   '전개',
#   '만세',
#   '운동',
#   '계획',
#   '시위',
#   '주도',
#   '함남',
#   '홍원',
#   '천도교',
#   '구장',
#   '재직',
#   '남섭',
#   '교주',
#   '손병희',
#   '독립만세운동',
#   '취지',
#   '호응',
#   '동지',
#   '규합',
#   '한편',
#   '읍내',
#   '장날',
#   '이용',
#   '규모',
#   '만세',
#   '운동',
#   '결의',
#   '남섭',
#   '홍원',
#   '읍내',
#   '신도',
#   '만세',
#   '운동',
#   '참가',
#   '권유',
#   '한편',
#   '김한욱',
#   '김세경',
#   '강인택',
#   '독립선언서',
#   '조선독립기',
#   '제작',
#   '남섭',
#   '읍내',
#   '장터',
#   '선두',
#   '태극기',
#   '조선독립만세',
#   '만세',
#   '운동',
#   '주도',
#   '시위',
#   '고등',
#   '법원',
#   '보안법',
#   '위반',
#   '징역',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['이강년',
#   '의병진',
#   '좌종사',
#   '활동',
#   '사실',
#   '확인',
#   '경북',
#   '문경',
#   '사람',
#   '국가',
#   '존망',
#   '기로',
#   '서자',
#   '강내영',
#   '국권회복',
#   '이강년',
#   '의진',
#   '참여',
#   '대일항전',
#   '이강년',
#   '병장',
#   '일제',
#   '국권침탈',
#   '충북',
#   '제천',
#   '재봉기',
#   '경상',
#   '강원',
#   '충청도',
#   '전공',
#   '이강년',
#   '병장',
#   '지방민',
#   '전폭',
#   '지원',
#   '지리',
#   '이점',
#   '이용',
#   '신출귀몰',
#   '유격',
#   '전술',
#   '구사',
#   '의병',
#   '승리',
#   '이강년',
#   '병장',
#   '청풍',
#   '작성전투',
#   '부상',
#   '교수',
#   '순국',
#   '후기',
#   '병사',
#   '활동',
#   '전개',
#   '이강년',
#   '의진',
#   '강내영',
#   '좌종사',
#   '선임',
#   '활동',
#   '정부',
#   '고인',
#   '공훈',
#   '건국포장',
#   '추서'],
#  ['진주',
#   '만세',
#   '사건',
#   '주모자',
#   '피체',
#   '대구',
#   '지법',
#   '복역',
#   '석방',
#   '경상',
#   '진주',
#   '사람',
#   '이강우',
#   '김재화',
#   '권채',
#   '박진환',
#   '박용근',
#   '강상호',
#   '진주',
#   '독립',
#   '만세',
#   '시위운동',
#   '주동',
#   '서울',
#   '독립만세운동',
#   '소식',
#   '진주',
#   '만세',
#   '시위운동',
#   '전개',
#   '결심',
#   '마을',
#   '애국',
#   '청년',
#   '구체',
#   '방법',
#   '논의',
#   '독립선언서',
#   '격문',
#   '비밀리',
#   '배부',
#   '인근',
#   '유지',
#   '민중',
#   '규합',
#   '이때',
#   '김재화',
#   '박진환',
#   '사회단체',
#   '독립만세운동',
#   '동참',
#   '권고',
#   '오후',
#   '시위군',
#   '애국가',
#   '제창',
#   '독립',
#   '만세',
#   '시위행진',
#   '전개',
#   '이때',
#   '일본',
#   '헌병',
#   '경찰',
#   '소방대',
#   '동원',
#   '시위',
#   '행렬',
#   '저지',
#   '해산',
#   '일본',
#   '군경',
#   '주동',
#   '인물',
#   '잉크',
#   '증거',
#   '그날',
#   '저녁',
#   '체포',
#   '시작',
#   '이때',
#   '체포',
#   '대구지방법원',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['학생',
#   '비밀결사',
#   '독서회',
#   '조직',
#   '주도',
#   '활동',
#   '광주',
#   '학생',
#   '시위',
#   '운동',
#   '일경',
#   '체포',
#   '구복',
#   '심원',
#   '징역형',
#   '확정',
#   '전남',
#   '나주',
#   '사람',
#   '광주사범학교',
#   '재학',
#   '당시',
#   '민족',
#   '차별',
#   '교육',
#   '일본인',
#   '교유',
#   '강전',
#   '타교',
#   '참여',
#   '선배',
#   '졸업',
#   '교내',
#   '학생운동',
#   '간부',
#   '선임',
#   '활약',
#   '장석천',
#   '김기권',
#   '김보섭',
#   '학생소비조합',
#   '설치',
#   '협의',
#   '광주',
#   '지역',
#   '중심',
#   '항일',
#   '학생',
#   '결사',
#   '진회',
#   '형식',
#   '해체',
#   '항일활동',
#   '학교',
#   '단위',
#   '분산',
#   '동경',
#   '장재',
#   '주장',
#   '학교',
#   '학생',
#   '대표',
#   '독서회중앙본부',
#   '조직',
#   '윤창하',
#   '재정부',
#   '위원',
#   '선임',
#   '동회',
#   '회비',
#   '징수',
#   '회계',
#   '사무',
#   '독서회',
#   '중앙본부',
#   '하부',
#   '조직',
#   '학교',
#   '독서회',
#   '설치',
#   '수피아여학교',
#   '뒷산',
#   '송동식',
#   '이신형',
#   '김재용',
#   '비밀결사',
#   '조직',
#   '협의',
#   '동년',
#   '광주형무소',
#   '뒷산',
#   '광주사범학교',
#   '독서회',
#   '조직',
#   '부서',
#   '결의',
#   '사항',
#   '재정부위원장',
#   '선임',
#   '동월',
#   '독서회',
#   '항일',
#   '의식',
#   '고취',
#   '인쇄물',
#   '임종근',
#   '교부',
#   '독서',
#   '회원',
#   '배포',
#   '독서회',
#   '중심',
#   '활약',
#   '광주학생독립운동',
#   '참가',
#   '활동',
#   '일경',
#   '고문',
#   '광주지방법원',
#   '징역',
#   '언도',
#   '대구복심법원',
#   '징역',
#   '확정',
#   '옥고',
#   '정부',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['남일',
#   '의병진',
#   '호군',
#   '강진',
#   '능주',
#   '해남',
#   '보성',
#   '나주',
#   '의병장',
#   '일군',
#   '전투',
#   '칙령',
#   '의병',
#   '해산',
#   '은거',
#   '밀고',
#   '체포',
#   '폭동죄',
#   '징역',
#   '사실',
#   '확인',
#   '강달',
#   '전남',
#   '나주',
#   '사람',
#   '군대해산',
#   '강행',
#   '의병운동',
#   '참여',
#   '당시',
#   '전라도',
#   '고광순',
#   '기삼연',
#   '이석용',
#   '유생',
#   '구국',
#   '항일',
#   '가치',
#   '이때',
#   '함평',
#   '신광면',
#   '기의',
#   '강달',
#   '남일',
#   '의진',
#   '가담',
#   '당시',
#   '남일',
#   '의진',
#   '부대',
#   '편성',
#   '다음',
#   '의병',
#   '대장',
#   '선봉장',
#   '강무경',
#   '임만',
#   '장인보',
#   '중군',
#   '안찬재',
#   '박사',
#   '후군장',
#   '노병',
#   '나성화',
#   '최우평',
#   '김성재',
#   '도통',
#   '김도숙',
#   '통장',
#   '유치선',
#   '진숙',
#   '량장',
#   '이세창',
#   '호군',
#   '강달',
#   '정관',
#   '선봉장',
#   '강무경',
#   '격문',
#   '작성',
#   '각지',
#   '살포',
#   '의병',
#   '모집',
#   '훈련',
#   '강달',
#   '남일',
#   '의진',
#   '호군',
#   '강진',
#   '오치동',
#   '전투',
#   '일군',
#   '접전',
#   '승리',
#   '능주',
#   '전투',
#   '해남',
#   '성내',
#   '군사',
#   '진격',
#   '왜적',
#   '살상',
#   '전과',
#   '의진',
#   '보성',
#   '천동',
#   '주둔',
#   '보성',
#   '의장',
#   '안규홍',
#   '통지',
#   '석호',
#   '회동',
#   '협조',
#   '의논',
#   '강달',
#   '후군장',
#   '김성재',
#   '군사',
#   '사기',
#   '사기',
#   '산상',
#   '깃발',
#   '왜병',
#   '싸움',
#   '접전',
#   '사살',
#   '남일',
#   '의진',
#   '휘하',
#   '장병',
#   '석정',
#   '전투',
#   '적과',
#   '접전',
#   '첩자',
#   '능주',
#   '일헌병대',
#   '밀통',
#   '야습',
#   '병졸',
#   '의병',
#   '해산',
#   '칙명',
#   '군사',
#   '해산',
#   '풍치',
#   '피신',
#   '체포',
#   '광주지방재판소',
#   '폭동죄',
#   '징역',
#   '언도',
#   '공소',
#   '확정',
#   '투옥',
#   '생활',
#   '일본',
#   '헌병',
#   '고문',
#   '하반신',
#   '발목',
#   '불구',
#   '출감',
#   '나주군',
#   '독립운동',
#   '참여',
#   '운동',
#   '영암군',
#   '시종면',
#   '봉소리',
#   '은거',
#   '생활',
#   '정부',
#   '고인',
#   '공로',
#   '건국훈장',
#   '애국장',
#   '건국포장',
#   '추서'],
#  ['산남',
#   '의진',
#   '정용기',
#   '의병진',
#   '입진',
#   '청하',
#   '의성',
#   '청송',
#   '활동',
#   '죽장면',
#   '입암',
#   '전투',
#   '대패',
#   '부상',
#   '피신',
#   '사실',
#   '확인',
#   '경북',
#   '영일',
#   '사람',
#   '정용기',
#   '산남',
#   '진에',
#   '참가',
#   '청하',
#   '의성',
#   '청송',
#   '항일',
#   '활동',
#   '이듬해',
#   '영일군',
#   '죽장면',
#   '입암',
#   '전투',
#   '전상',
#   '피신',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['충북',
#   '음성군',
#   '맹동면',
#   '마산리',
#   '와우형',
#   '강혜수',
#   '강구원',
#   '이용근',
#   '독립만세운동',
#   '주동',
#   '체포',
#   '사실',
#   '확인',
#   '충북',
#   '음성군',
#   '만세',
#   '운동',
#   '주도',
#   '맹동면',
#   '소재지',
#   '쌍정리',
#   '시작',
#   '시위',
#   '전체',
#   '확대',
#   '강대길',
#   '맹동면',
#   '마산리',
#   '와우형',
#   '강구원',
#   '횃불',
#   '독립만세운동',
#   '대대',
#   '전개',
#   '강대길',
#   '체포',
#   '공주지방법원',
#   '보안법',
#   '위반',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['전남',
#   '광주',
#   '숭일학교',
#   '교사',
#   '재직',
#   '동교',
#   '교사',
#   '학생',
#   '독립만세운동',
#   '결의',
#   '수피아여학교',
#   '연계',
#   '태극기',
#   '독립선언서',
#   '제작',
#   '준비',
#   '군중',
#   '배부',
#   '독립',
#   '만세',
#   '고창',
#   '활동',
#   '피체',
# ...
#   '경찰서',
#   '파견',
#   '일본',
#   '경찰',
#   '격전',
#   '전사',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['한국광복군', '지대', '입대', '국내', '정진', '교육훈련반', '편입'],
#  ['평북',
#   '영변군',
#   '동부동',
#   '천도교',
#   '구장',
#   '국장',
#   '배관',
#   '상경',
#   '종로',
#   '전개',
#   '독립만세운동',
#   '참여',
#   '천도교',
#   '중앙',
#   '총부',
#   '박인호',
#   '지시',
#   '영변군',
#   '동부동',
#   '만세',
#   '운동',
#   '준비',
#   '체포',
#   '징역',
#   '사실',
#   '확인',
#   '학성',
#   '평안북도',
#   '영변군',
#   '동부동',
#   '천도교',
#   '구장',
#   '국장',
#   '참배',
#   '상경',
#   '종로',
#   '독립만세운동',
#   '참여',
#   '천도교',
#   '중앙',
#   '총부',
#   '지시',
#   '영변군',
#   '동부동',
#   '만세',
#   '운동',
#   '준비',
#   '체포',
#   '옥고',
#   '학성',
#   '평양',
#   '천도교',
#   '도사',
#   '오영창',
#   '전보',
#   '서울',
#   '천도교',
#   '중앙',
#   '총부',
#   '탑골공원',
#   '독립',
#   '만세',
#   '계획',
#   '전달',
#   '다음',
#   '태화관',
#   '종로',
#   '이동',
#   '학생',
#   '만세',
#   '시위',
#   '참여',
#   '학성',
#   '중앙',
#   '총부',
#   '지시',
#   '지방',
#   '독립운동',
#   '전개',
#   '지시',
#   '영변',
#   '영변',
#   '차례',
#   '교인',
#   '접촉',
#   '독립',
#   '만세',
#   '시위',
#   '계획',
#   '준비',
#   '영변군',
#   '영변',
#   '용포',
#   '천도교',
#   '김형성',
#   '교도',
#   '독립',
#   '만세',
#   '대도주',
#   '명령',
#   '명령',
#   '이날',
#   '잠복',
#   '경찰',
#   '체포',
#   '학성',
#   '평양복심법원',
#   '보안법',
#   '위반',
#   '징역',
#   '상고',
#   '고등',
#   '법원',
#   '기각',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['국권',
#   '회복',
#   '의진',
#   '부하',
#   '양구',
#   '강릉',
#   '양양',
#   '각지',
#   '세력',
#   '활동',
#   '일경',
#   '습격',
#   '피체',
#   '순국',
#   '사실',
#   '확인',
#   '이강년',
#   '의병장',
#   '휘하',
#   '중군',
#   '대장',
#   '부하',
#   '강원도',
#   '양구',
#   '강릉',
#   '양양',
#   '활약',
#   '인제군',
#   '설령',
#   '부하',
#   '의병',
#   '훈련',
#   '실시',
#   '활동',
#   '동군',
#   '광암리',
#   '일경',
#   '습격',
#   '피살',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['충남',
#   '청양군',
#   '운곡면',
#   '면민',
#   '독립만세운동',
#   '전개',
#   '체포',
#   '사실',
#   '확인',
#   '충남',
#   '청양군',
#   '운곡면',
#   '면민',
#   '면내',
#   '횃불',
#   '독립',
#   '만세',
#   '절규',
#   '시경',
#   '운곡',
#   '면민',
#   '비봉',
#   '면민',
#   '운곡면',
#   '횃불',
#   '독립',
#   '만세',
#   '소리',
#   '이때',
#   '출동',
#   '일본',
#   '헌병',
#   '발포',
#   '시위',
#   '군중',
#   '강제',
#   '해산',
#   '대대',
#   '검거',
#   '연속',
#   '만세',
#   '시위',
#   '참가',
#   '일경',
#   '체포',
#   '청양',
#   '병분',
#   '견소',
#   '보안법',
#   '위반',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['한국',
#   '독립',
#   '지단',
#   '조직',
#   '사건',
#   '기소',
#   '동아일보',
#   '자황',
#   '연백',
#   '호동',
#   '사람',
#   '독립운동',
#   '고향',
#   '만세',
#   '시위',
#   '결심',
#   '유원',
#   '창만',
#   '상의',
#   '주민',
#   '거촌',
#   '일대',
#   '독립',
#   '만세',
#   '고창',
#   '결국',
#   '일경',
#   '체포',
#   '고등',
#   '법원',
#   '보안법',
#   '위반',
#   '죄명',
#   '징역형',
#   '옥고',
#   '출옥',
#   '정순경',
#   '편강',
#   '권유',
#   '독립운동',
#   '계속',
#   '조맹선',
#   '조직',
#   '대한독립단',
#   '가입',
#   '해주',
#   '지단',
#   '설립',
#   '주력',
#   '동지',
#   '체포',
#   '정순경',
#   '편강',
#   '부인',
#   '동년',
#   '면소',
#   '석방',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '대통령표창',
#   '추서'],
#  ['운동',
#   '경남',
#   '지역',
#   '연락',
#   '활약',
#   '일경',
#   '상해',
#   '망명',
#   '임시의정원',
#   '경상도',
#   '대표',
#   '의원',
#   '피선',
#   '임시정부',
#   '군무',
#   '위원',
#   '국무원',
#   '차장',
#   '재무',
#   '총장',
#   '노동',
#   '총판',
#   '국무원',
#   '역임',
#   '대한민국',
#   '기초',
#   '위원',
#   '활동',
#   '한국',
#   '국민당',
#   '창당',
#   '사실',
#   '확인',
#   '독립운동',
#   '당시',
#   '경남',
#   '지역',
#   '연락',
#   '책임자',
#   '활약',
#   '일경',
#   '중국',
#   '북경',
#   '망명',
#   '동년',
#   '대한민국',
#   '임시의정원',
#   '경상도',
#   '대표',
#   '위원',
#   '군무',
#   '위원회',
#   '이사',
#   '대한민국임시정부',
#   '국무원',
#   '차장',
#   '교통부',
#   '위원',
#   '초기',
#   '임시정부',
#   '업무',
#   '수행',
#   '공헌',
#   '북경',
#   '개최',
#   '군사통일회',
#   '발기인',
#   '사람',
#   '국내',
#   '노동당',
#   '대표',
#   '참석',
#   '대한민국임시정부',
#   '임시',
#   '정원',
#   '취소',
#   '국민대표회의',
#   '대체',
#   '요구',
#   '조선공',
#   '정부',
#   '수립',
#   '이상룡',
#   '대통령',
#   '추대',
#   '재무',
#   '총장',
#   '동년',
#   '이승만',
#   '정한경',
#   '미국',
#   '정부',
#   '제출',
#   '위임통치청원서',
#   '무효',
#   '주장',
#   '통박',
#   '국민대표회',
#   '임정',
#   '호파',
#   '창조',
#   '국민대표회',
#   '명의',
#   '도용',
#   '간부',
#   '이름',
#   '성토',
#   '규탄',
#   '박은식',
#   '국무총리',
#   '조각',
#   '참여',
#   '노동',
#   '총판',
#   '임명',
#   '국무령',
#   '추천',
#   '국무원',
#   '임명',
#   '대한민국임시정부',
#   '정원',
#   '의원',
#   '임정',
#   '기초',
#   '위원',
#   '피선',
#   '동년',
#   '상해인성소학교',
#   '급식',
#   '참석',
#   '축사',
#   '독립정신',
#   '고취',
#   '격려',
#   '임시정부',
#   '이동녕',
#   '주석',
#   '재직',
#   '재무',
#   '부장',
#   '임명',
#   '이동녕',
#   '한국',
#   '국민당',
#   '창당',
#   '특사',
#   '국내외',
#   '밀파',
#   '취지',
#   '선전',
#   '연락',
#   '도모',
#   '프랑스',
#   '조계',
#   '김신부',
#   '광제의원',
#   '사망',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '독립장',
#   '추서'],
#  ['전남',
#   '광양군',
#   '양면',
#   '도월리',
#   '박경래',
#   '지도',
#   '김희곤',
#   '강충',
#   '사회주의',
#   '사상',
#   '학습',
#   '비밀',
#   '결사',
#   '조직',
#   '동면',
#   '인리',
#   '김기문',
#   '혁명가',
#   '고창',
#   '시위',
#   '운동',
#   '동년',
#   '체포',
#   '징역',
#   '집행유예',
#   '미결',
#   '구류',
#   '통산',
#   '옥고',
#   '사실',
#   '확인',
#   '광양',
#   '공립보통학교',
#   '졸업',
#   '일본',
#   '능생수산학교',
#   '동안',
#   '귀국',
#   '일제',
#   '식민통치',
#   '부당',
#   '인식',
#   '사회과학',
#   '서적',
#   '사회주의',
#   '사상',
#   '접근',
#   '동생',
#   '김희곤',
#   '광양군',
#   '양면',
#   '도월리',
#   '박경래',
#   '지도',
#   '전남적색농민조합',
#   '결성',
#   '조직',
#   '항일운동',
#   '조합',
#   '단계',
#   '농민운동',
#   '전개',
#   '조직',
#   '비밀결사',
#   '구성원',
#   '사회과학',
#   '학습',
#   '식민지',
#   '현실',
#   '모순',
#   '자각',
#   '일제',
#   '식민지',
#   '지배',
#   '비판',
#   '안목',
#   '양면',
#   '인리',
#   '김기문',
#   '혁명가',
#   '고창',
#   '시위운동',
#   '동년',
#   '체포',
#   '치안유지법',
#   '위반',
#   '징역',
#   '집행유예',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '건국포장',
#   '추서'],
#  ['경남',
#   '고성군',
#   '회화면',
#   '배둔리',
#   '시장',
#   '인접',
#   '국천시장',
#   '군중',
#   '합세',
#   '군중',
#   '선두',
#   '태극기',
#   '독립',
#   '만세',
#   '고창',
#   '피체',
#   '징역',
#   '사실',
#   '확인',
#   '경남',
#   '고성',
#   '사람',
#   '고성군',
#   '회화',
#   '배둔리',
#   '장날',
#   '이용',
#   '최낙종',
#   '이정수',
#   '문태룡',
#   '독립',
#   '만세',
#   '시위운동',
#   '계획',
#   '장터',
#   '다수',
#   '군중',
#   '규합',
#   '태극기',
#   '독립',
#   '만세',
#   '고창',
#   '시위행진',
#   '일경',
#   '무력',
#   '탄압',
#   '시위',
#   '중단',
#   '주동자',
#   '사람',
#   '부산지방법원',
#   '마산지청',
#   '보안법',
#   '위반',
#   '징역',
#   '옥고',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['함남',
#   '홍원군',
#   '주익',
#   '조선',
#   '독립',
#   '사회',
#   '건설',
#   '의지',
#   '고양',
#   '문서',
#   '복사',
#   '배포',
#   '홍원',
#   '좌익',
#   '그룹',
#   '참여',
#   '체포',
#   '여독',
#   '사망',
#   '사실',
#   '확인',
#   '김갑룡',
#   '함경남도',
#   '홍원군',
#   '주익',
#   '조선',
#   '독립',
#   '홍원',
#   '노동조합',
#   '운동',
#   '염태',
#   '태평양노동조합',
#   '서부',
#   '격문',
#   '파업',
#   '전위',
#   '제목',
#   '문서',
#   '복사',
#   '인쇄',
#   '의뢰',
#   '복사',
#   '유인물',
#   '동지',
#   '배부',
#   '운동',
#   '제목',
#   '복사',
#   '문서',
#   '배포',
#   '홍원',
#   '노동조합',
#   '운동',
#   '협력',
#   '동지',
#   '규합',
#   '의식',
#   '교양',
#   '노력',
#   '조선',
#   '독립',
#   '홍원',
#   '노동조합',
#   '운동',
#   '주력',
#   '김갑룡',
#   '홍원',
#   '노동조합',
#   '건설',
#   '활동',
#   '소위',
#   '태평양노동조합사건',
#   '사건',
#   '관련',
#   '일제',
#   '경찰',
#   '체포',
#   '함흥형무소',
#   '수감',
#   '예심',
#   '보석',
#   '병보석',
#   '자택',
#   '치료',
#   '옥고',
#   '여독',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['남경',
#   '낙양분교',
#   '재학',
#   '김구',
#   '지시',
#   '중도',
#   '퇴학',
#   '남경중앙육군군관학교',
#   '입학',
#   '훈련',
#   '수류탄',
#   '투척',
#   '연습',
#   '파편',
#   '순국',
#   '사실',
#   '확인',
#   '강원도',
#   '사람',
#   '후반기',
#   '일제',
#   '중국',
#   '대륙',
#   '침략',
#   '강화',
#   '한인',
#   '독립운동',
#   '중국',
#   '국민당정부',
#   '국제',
#   '연대',
#   '형성',
#   '목적',
#   '장개석',
#   '국민당정부',
#   '재정',
#   '군사',
#   '지원',
#   '토대',
#   '독자',
#   '투쟁',
#   '역량',
#   '강화',
#   '중국',
#   '남경',
#   '중앙육군군관학교',
#   '장개석',
#   '회합',
#   '한인',
#   '특별',
#   '개설',
#   '중국',
#   '하남성',
#   '낙양',
#   '소재',
#   '중국중앙육군군관학교',
#   '낙양분교',
#   '한인',
#   '특별',
#   '설치',
#   '중국중앙육군군관학교',
#   '낙양분교',
#   '한인',
#   '특별',
#   '기생',
#   '입학',
#   '지형학',
#   '전술학',
#   '병기학',
#   '통신',
#   '정치학',
#   '학습',
#   '독립군',
#   '간부',
#   '양성',
#   '훈련',
#   '하순',
#   '중국',
#   '남경',
#   '중앙육군군관학교',
#   '교생',
#   '중심',
#   '한국특무대독립군',
#   '조직',
#   '입학',
#   '군사',
#   '훈련',
#   '동교',
#   '사격장',
#   '수류탄',
#   '투척',
#   '연습',
#   '중국인',
#   '학생',
#   '수류탄',
#   '파편',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['충남',
#   '청양군',
#   '화성면',
#   '농암리',
#   '군중',
#   '독립만세운동',
#   '전개',
#   '체포',
#   '사실',
#   '확인',
#   '충남',
#   '청양군',
#   '화성면',
#   '농암리',
#   '군중',
#   '독립만세운동',
#   '전개',
#   '김갑',
#   '체포',
#   '청양',
#   '병분',
#   '견소',
#   '보안법',
#   '위반',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['중국',
#   '상해',
#   '남양대학',
#   '졸업',
#   '대한민국',
#   '임시정부',
#   '의정원',
#   '참여',
#   '충청도',
#   '의원',
#   '피선',
#   '항일활동',
#   '전개',
#   '불란서',
#   '경유',
#   '독일',
#   '베를린',
#   '유학',
#   '백림',
#   '고려학우회',
#   '학생',
#   '단체',
#   '조직',
#   '활동',
#   '사실',
#   '확인',
#   '충남',
#   '서천',
#   '사람',
#   '월남',
#   '이상재',
#   '중국',
#   '상해',
#   '남양대학',
#   '여운형',
#   '서병호',
#   '조동호',
#   '교유',
#   '여운형',
#   '중국',
#   '대학',
#   '축구',
#   '대표',
#   '선수',
#   '선발',
#   '필리핀',
#   '원정',
#   '일제',
#   '침략',
#   '부당',
#   '세계',
#   '호소',
#   '민족',
#   '자주',
#   '주장',
#   '상해',
#   '해외',
#   '조선인',
#   '유학생회',
#   '주도',
#   '애국',
#   '동지',
#   '규합',
#   '국내',
#   '진입',
#   '군산',
#   '일경',
#   '고문',
#   '한국인',
#   '간수',
#   '도움',
#   '탈출',
#   '상해',
#   '상해',
#   '의정원',
#   '의원',
#   '임시정부',
#   '수립',
#   '참여',
#   '당시',
#   '임시정부',
#   '발행',
#   '채권',
#   '국내',
#   '전북',
#   '임피',
#   '독립운동',
#   '자금',
#   '모집',
#   '노력',
#   '대한민국임시정부',
#   '주선',
#   '독일',
#   '베를린',
#   '유학',
#   '베를린',
#   '고려학우회',
#   '조직',
#   '활동',
#   '귀국',
#   '이상재',
#   '권유',
#   '배재',
#   '학교',
#   '교감',
#   '근무',
#   '일경',
#   '탄압',
#   '북간',
#   '용정',
#   '동흥학교',
#   '교사',
#   '활동',
#   '귀국',
#   '민족',
#   '자본',
#   '육성',
#   '전북',
#   '완주',
#   '봉동',
#   '윤건중',
#   '설립',
#   '봉우',
#   '산업',
#   '조합',
#   '참여',
#   '이사',
#   '활동',
#   '사망',
#   '정부',
#   '고인',
#   '공훈',
#   '건국포장',
#   '추서'],
#  ['독립중흥단',
#   '중국',
#   '전현',
#   '태공',
#   '등지',
#   '활동',
#   '일경',
#   '기습',
#   '공격',
#   '교전',
#   '전사',
#   '순국',
#   '사실',
#   '확인',
#   '서간',
#   '지역',
#   '독립군',
#   '단체',
#   '활약',
#   '전후',
#   '해외',
#   '독립운동',
#   '기지',
#   '건설',
#   '움직임',
#   '독립운동가',
#   '사이',
#   '전개',
#   '움직임',
#   '독립전쟁',
#   '기반',
#   '계기',
#   '만주',
#   '지역',
#   '중심',
#   '무장투쟁',
#   '적극',
#   '대두',
#   '동포',
#   '절대',
#   '지지',
#   '독립군',
#   '부대',
#   '편성',
#   '압록강',
#   '두만강',
#   '국내',
#   '진공',
#   '작전',
#   '전개',
#   '일본군',
#   '국경',
#   '수비대',
#   '교란',
#   '무장활동',
#   '전개',
#   '청산리전투',
#   '봉오동전투',
#   '만주',
#   '진출',
#   '일본군',
#   '격퇴',
#   '전투',
#   '일제',
#   '대대',
#   '탄압',
#   '밀산',
#   '지역',
#   '이동한',
#   '독립군',
#   '진용',
#   '편성',
#   '대한독립군단',
#   '조직',
#   '밀산',
#   '겨울',
#   '대한독립군단',
#   '이동',
#   '시작',
#   '노령',
#   '연해주',
#   '흑룡',
#   '일대',
#   '활동',
#   '문창범',
#   '도움',
#   '국경',
#   '하천',
#   '우수리',
#   '도착',
#   '김갑수',
#   '시점',
#   '독립중흥단',
#   '중국',
#   '봉천',
#   '전현',
#   '태공',
#   '등지',
#   '활동',
#   '평북',
#   '벽동경찰서',
#   '일경',
#   '기습',
#   '공격',
#   '교전',
#   '전사',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['대한제국군',
#   '출신',
#   '군대',
#   '해산',
#   '의병',
#   '투신',
#   '김태원',
#   '김준',
#   '의진',
#   '소속',
#   '포수',
#   '활동',
#   '등산',
#   '전투',
#   '패전',
#   '각지',
#   '전전',
#   '일경',
#   '체포',
#   '저항',
#   '피살',
#   '순국',
#   '사실',
#   '확인',
#   '전남',
#   '함평',
#   '사람',
#   '제국',
#   '군인',
#   '군대해산',
#   '이후',
#   '의병',
#   '가담',
#   '김태원',
#   '의진',
#   '활약',
#   '제국',
#   '식민지',
#   '일제',
#   '러일전쟁',
#   '승리',
#   '을사조약',
#   '강제',
#   '체결',
#   '한편',
#   '통감부',
#   '설치',
#   '침략',
#   '정책',
#   '가속',
#   '헤이그',
#   '특사',
#   '활동',
#   '빌미',
#   '광무황제',
#   '강제',
#   '퇴위',
#   '군대해산',
#   '강행',
#   '김갑수',
#   '대한제국',
#   '군대',
#   '해산',
#   '의병',
#   '투신',
#   '김태원',
#   '의진',
#   '가담',
#   '포수',
#   '활약',
#   '김태원',
#   '을사조약',
#   '강제',
#   '체결',
#   '최익현',
#   '이남규',
#   '의병',
#   '순국',
#   '소식',
#   '비분강개',
#   '성재',
#   '기삼연',
#   '장성',
#   '일가',
#   '참봉',
#   '김돈',
#   '의논',
#   '의병',
#   '규합',
#   '호남창의회맹소',
#   '합류',
#   '선봉장',
#   '동년',
#   '고창',
#   '일본군',
#   '활약',
#   '김태원',
#   '일본군',
#   '차례',
#   '전투',
#   '일본군',
#   '천단',
#   '조장',
#   '길전승',
#   '철도',
#   '삼전',
#   '사살',
#   '전남',
#   '일대',
#   '전과',
#   '김갑수',
#   '김태원',
#   '등산',
#   '전투',
#   '참전',
#   '의진',
#   '패산',
#   '각지',
#   '전전',
#   '광주군',
#   '마지',
#   '마운',
#   '일본',
#   '순사',
#   '체포',
#   '김갑수',
#   '호송',
#   '저항',
#   '이유',
#   '피살',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['충남',
#   '청양군',
#   '정산시장',
#   '군중',
#   '태극기',
#   '독립',
#   '만세',
#   '고창',
#   '활동',
#   '일경',
#   '체포',
#   '사실',
#   '확인',
#   '오후',
#   '충남',
#   '청양군',
#   '정산시장',
#   '주민',
#   '태극기',
#   '독립',
#   '만세',
#   '장터',
#   '행진',
#   '일본',
#   '헌병',
#   '출동',
#   '시위',
#   '참여',
#   '강제',
#   '연행',
#   '분노',
#   '시위',
#   '군중',
#   '피검자',
#   '석방',
#   '요구',
#   '헌병주재소',
#   '쇄도',
#   '주도',
#   '목면',
#   '안심리',
#   '거주',
#   '향교',
#   '직원',
#   '일본',
#   '철수',
#   '주장',
#   '항거',
#   '일본',
#   '헌병',
#   '공포',
#   '제지',
#   '앞가슴',
#   '항의',
#   '일본',
#   '헌병',
#   '야만',
#   '가슴',
#   '발포',
#   '현장',
#   '순국',
#   '이튿날',
#   '아침',
#   '시장',
#   '사람',
#   '시신',
#   '고향',
#   '운구',
#   '태극기',
#   '독립',
#   '만세',
#   '운구',
#   '행렬',
#   '동참',
#   '공주',
#   '지원',
#   '일본',
#   '헌병',
#   '운구',
#   '행렬',
#   '차별',
#   '사격',
#   '감행',
#   '사상자',
#   '발생',
#   '김갑종',
#   '만세',
#   '운동',
#   '참여',
#   '일경',
#   '체포',
#   '소위',
#   '보안법',
#   '위반',
#   '청양',
#   '병분',
#   '견소',
#   '만세',
#   '시위',
#   '참가',
#   '태형',
#   '인사',
#   '정부',
#   '고인',
#   '공훈',
#   '대통령표창',
#   '추서'],
#  ['함북',
#   '성진',
#   '신간회',
#   '지부',
#   '청년동맹',
#   '해소',
#   '단체',
#   '기반',
#   '농민조합',
#   '조직',
#   '군내',
#   '지부',
#   '결성',
#   '농민조합',
#   '설치',
#   '활동',
#   '전개',
#   '피체',
#   '심중',
#   '옥사',
#   '사실',
#   '확인',
#   '신간회',
#   '성진',
#   '지회',
#   '성진청년동맹',
#   '활동',
#   '성진농민조합',
#   '결성',
#   '항일투쟁',
#   '전개',
#   '성진농민조합',
#   '신간회',
#   '지부',
#   '청년동맹',
#   '해소',
#   '조직원',
#   '기반',
#   '조직',
#   '조직',
#   '결성',
#   '이후',
#   '성진농민조합',
#   '소작료',
#   '인하',
#   '투쟁',
#   '채권',
#   '문서',
#   '탈취',
#   '소각',
#   '투쟁',
#   '스파이',
#   '징벌',
#   '투쟁',
#   '야학',
#   '철폐',
#   '반대',
#   '투쟁',
#   '전개',
#   '성진',
#   '농조',
#   '조직',
#   '관할',
#   '농민조합본부임시통제위원회',
#   '지도위원회',
#   '기구',
#   '설치',
#   '운영',
#   '조합',
#   '하부',
#   '조직',
#   '지부',
#   '설치',
#   '조합원',
#   '규모',
#   '조직',
#   '발전',
#   '지역',
#   '어린아이',
#   '혁명가',
#   '정도',
#   '농조',
#   '대중',
#   '기반',
#   '일제',
#   '무장',
#   '경찰',
#   '동원',
#   '규모',
#   '탄압',
#   '개시',
#   '조합원',
#   '가운데',
#   '검사국',
#   '송환',
#   '수난',
#   '이때',
#   '김갑진',
#   '성진농민조합',
#   '주동자',
#   '지목',
#   '고문',
#   '옥중',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애족장',
#   '추서'],
#  ['용정',
#   '외연',
#   '집강',
#   '소석',
#   '혁신단',
#   '분대장',
#   '활동',
#   '대원',
#   '일본',
#   '총영사관',
#   '경찰대',
#   '시간',
#   '동안',
#   '교전',
#   '탄환',
#   '방준',
#   '박덕',
#   '전사',
#   '순국',
#   '사실',
#   '확인',
#   '혁신단',
#   '독립운동',
#   '전개',
#   '인물',
#   '중반',
#   '만주',
#   '지역',
#   '정의부',
#   '참의부',
#   '신민부',
#   '독립운동',
#   '단체',
#   '중심',
#   '대일항전',
#   '전개',
#   '민족유일당',
#   '운동',
#   '전개',
#   '효과',
#   '항일투쟁',
#   '통합',
#   '운동',
#   '진행',
#   '시기',
#   '오상현',
#   '중심',
#   '지역',
#   '혁신단',
#   '조직',
#   '활동',
#   '혁신단',
#   '분대장',
#   '활동',
#   '김강',
#   '만주',
#   '화룡현',
#   '연길',
#   '시외',
#   '연집',
#   '소석',
#   '혁신단',
#   '분대장',
#   '익과',
#   '동지',
#   '방준',
#   '박덕',
#   '일본',
#   '영사관',
#   '경찰대',
#   '시간',
#   '동안',
#   '교전',
#   '전사',
#   '순국',
#   '정부',
#   '고인',
#   '공훈',
#   '건국훈장',
#   '애국장',
#   '추서'],
#  ['광주', '시내', '운동', '주동', '대구복심법원', '언도', '사실', '확인'],
#  ['평양',
#   '숭실학교',
#   '졸업',
#   '사건',
#   '관련',
#   '혐의',
#   '위험',
#   '간도',
#   '망명',
#   '하얼빈',
#   '청년',
#   '규합',
#   '독립운동',
#   '전개',
#   '용정',
#   '민회',
#   '일본',
#   '조사',
#   '부원',
#   '대동협신회',
#   '제회',
#   '평의원',
#   '활동',
#   '운동',
#   '대한국민회',
#   '통신',
#   '부원',
#   '중부',
#   '경호부장',
#   '활동',
#   '간도청년회',
#   '간도청년단',
#   '발기',
#   '동회',
#   '중요',
#   '인물',
#   '활동',
#   '간도',
#   '사건',
#   '연루',
#   '노령',
#   '간도',
#   '오지',
#   '피신',
#   '연길현',
#   '태평',
#   '용포',
#   '일경',
#   '피체',
#   '피살',
#   '순국',
#   '사실',
#   '확인'],
#  ['경북',
#   '의성군',
#   '점곡면',
#   '마을',
#   '사람',
#   '점곡면',
#   '주재소',
#   '독립',
#   '만세',
#   '활동',
#   '체포',
#   '징역',
#   '사실',
#   '확인'],
#  ['전남', '장흥', '남면', '전남운동협의회', '참여', '활동', '체포', '기소유예'],
#  ['김수민',
#   '수민',
#   '진에',
#   '소속',
#   '경기도',
#   '양근',
#   '장단',
#   '일본',
#   '헌병대',
#   '교전',
#   '활동',
#   '피체',
#   '유형',
#   '사실',
#   '확인'],
#  ['경기도',
#   '시흥군',
#   '서면',
#   '하리',
#   '최호천',
#   '노온',
#   '사리',
#   '경찰관',
#   '주재소',
#   '독립',
#   '만세',
#   '구금',
#   '이정석',
#   '석방',
#   '활동',
#   '체포',
#   '징역',
#   '사실',
#   '확인'],
#  ['경북', '순흥', '부친', '의병장', '김휘정', '의병활동', '전개', '체포', '처형', '사실', '확인'],
#  ['경기도', '이천군', '마장면', '독립만세운동', '참여', '활동', '체포'],
#  ['음력',
#   '평남',
#   '순천군',
#   '대한국민회',
#   '부인향촌회',
#   '조직',
#   '참여',
#   '의연금',
#   '모집',
#   '대한민국임시정부',
#   '지원',
#   '체포'],
#  ['파리강화회의',
#   '한국',
#   '독립',
#   '호소',
#   '김창숙',
#   '유림',
#   '대표',
#   '작성',
#   '독립청원서',
#   '유림',
#   '사람',
#   '서명',
#   '문서',
#   '배포',
#   '피체',
#   '특수',
#   '사실',
#   '확인'],
#  ['경북',
#   '안동',
#   '안동',
#   '농림',
#   '학생',
#   '중심',
#   '독립운동',
#   '비밀결사',
#   '명성',
#   '조직',
#   '연락',
#   '활동',
#   '이후',
#   '기관지',
#   '새벽',
#   '배포',
#   '항일사상',
#   '고취',
#   '활동',
#   '피체',
#   '기소유예',
#   '처분',
#   '출옥',
#   '사실',
#   '확인'],
#  ['중국',
#   '봉천',
#   '통화',
#   '홍전',
#   '도구',
#   '한족회',
#   '구정',
#   '활동',
#   '동년',
#   '일군',
#   '피체',
#   '피살',
#   '순국',
#   '사실',
#   '확인'],
#  ['충북', '괴산', '의병', '활동', '체포', '탈출', '기도', '피살', '순국', '사실', '확인'],
#  ['미국',
#   '시카',
#   '고시',
#   '망명',
#   '인국',
#   '민회',
#   '조직',
#   '참여',
#   '동회',
#   '자금',
#   '미화',
#   '임정',
#   '자금',
#   '지원',
#   '사실',
#   '임시정부',
#   '국무회의',
#   '재무',
#   '주미',
#   '제육',
#   '행서',
#   '재무',
#   '위원',
#   '선임',
#   '활동',
#   '재미교포',
#   '징수',
#   '인구',
#   '애국의연금',
#   '임시정부',
#   '군자금',
#   '송금',
#   '활동',
#   '사실',
#   '확인'],
#  ['도만',
#   '독립군',
#   '단인',
#   '광정단',
#   '입단',
#   '활동',
#   '정의부',
#   '입단',
#   '모연',
#   '소대장',
#   '정의부',
#   '지방',
#   '행정위원',
#   '지방',
#   '서기',
#   '임명',
#   '군단',
#   '중대',
#   '소대장',
#   '임명',
#   '이후',
#   '남만',
#   '지방',
#   '독립군',
#   '단인',
#   '조선혁명군',
#   '지휘관',
#   '활동',
#   '순국',
#   '사실',
#   '확인'],
#  ['보호조약',
#   '국가',
#   '위기',
#   '염려',
#   '애국',
#   '애족사상',
#   '신진',
#   '교육',
#   '문맹',
#   '퇴치',
#   '주력',
#   '각지',
#   '옥성',
#   '오봉',
#   '학교',
#   '설립',
#   '청년',
#   '모집',
#   '항일투쟁',
#   '의식',
#   '함양',
#   '구국항일투쟁',
#   '참여',
#   '이후',
#   '이승훈',
#   '제씨',
#   '서북학회',
#   '재일',
#   '유학생회',
#   '기회',
#   '운동',
#   '동지',
#   '각처',
#   '거사',
#   '선동',
#   '주선',
#   '계속',
#   '독립신문',
#   '등사',
#   '임정',
#   '남북',
#   '만주',
#   '평남',
#   '북도',
#   '배포',
#   '동년',
#   '순경',
#   '연산',
#   '애국지사',
#   '밀회',
#   '연락처',
#   '국내',
#   '유지',
#   '만주',
#   '상해',
#   '도피',
#   '혐의',
#   '삼부자',
#   '평양감옥',
#   '혹형',
#   '임정',
#   '김경',
#   '용천군',
#   '참사',
#   '임명',
#   '문하',
#   '청년',
#   '항일운동',
#   '참가',
#   '기타',
#   '항일행동',
#   '수차',
#   '검거',
#   '태형',
#   '군자금',
#   '거출',
#   '임정',
#   '송금',
#   '조선민족운동연감',
#   '한국',
#   '독립운동사',
#   '선천군',
#   '신성학교',
#   '보성학교',
#   '훈육',
#   '선생',
#   '애국',
#   '사상',
#   '고취',
#   '대한민국',
#   '독립사',
#   '저서'],
#  ...]

# %%
dictionary

# %%
corpus
# Out:
# [[(0, 1),
#   (1, 2),
#   (2, 1),
#   (3, 1),
#   (4, 1),
#   (5, 2),
#   (6, 4),
#   (7, 1),
#   (8, 1),
#   (9, 1),
#   (10, 1),
#   (11, 1),
#   (12, 1),
#   (13, 2),
#   (14, 2),
#   (15, 1),
#   (16, 2),
#   (17, 4),
#   (18, 1),
#   (19, 2),
#   (20, 2),
#   (21, 1),
#   (22, 1),
#   (23, 1),
#   (24, 2),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 2),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (42, 1),
#   (43, 1),
#   (44, 2),
#   (45, 1),
#   (46, 1),
#   (47, 2),
#   (48, 1),
#   (49, 2),
#   (50, 1),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 2)],
#  [(18, 2),
#   (55, 1),
#   (56, 1),
#   (57, 2),
#   (58, 1),
#   (59, 1),
#   (60, 2),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 1),
#   (65, 1),
#   (66, 1),
#   (67, 2),
#   (68, 1),
#   (69, 1),
#   (70, 1),
#   (71, 1),
#   (72, 1),
#   (73, 1),
#   (74, 1),
#   (75, 1),
#   (76, 1),
#   (77, 1),
#   (78, 1),
#   (79, 1),
#   (80, 1),
#   (81, 1),
#   (82, 1),
#   (83, 1),
#   (84, 1),
#   (85, 1),
#   (86, 2),
#   (87, 1),
#   (88, 1),
#   (89, 1),
#   (90, 3),
#   (91, 1),
#   (92, 1),
#   (93, 2),
#   (94, 2),
#   (95, 3),
#   (96, 1),
#   (97, 1)],
#  [(74, 1),
#   (78, 1),
#   (98, 1),
#   (99, 1),
#   (100, 1),
#   (101, 1),
#   (102, 1),
#   (103, 2),
#   (104, 2),
#   (105, 1),
#   (106, 1),
#   (107, 1),
#   (108, 1),
#   (109, 1),
#   (110, 2),
#   (111, 1),
#   (112, 1),
#   (113, 2),
#   (114, 1),
#   (115, 3),
#   (116, 2),
#   (117, 1),
#   (118, 2),
#   (119, 1),
#   (120, 1),
#   (121, 1),
#   (122, 1),
#   (123, 1)],
#  [(39, 1),
#   (47, 1),
#   (53, 1),
#   (78, 1),
#   (109, 1),
#   (119, 1),
#   (124, 1),
#   (125, 1),
#   (126, 1),
#   (127, 1),
#   (128, 1),
#   (129, 1),
#   (130, 1),
#   (131, 1),
#   (132, 1),
#   (133, 1),
#   (134, 1),
#   (135, 4),
#   (136, 1),
#   (137, 1),
#   (138, 4),
#   (139, 1),
#   (140, 1),
#   (141, 4),
#   (142, 1),
#   (143, 1),
#   (144, 2),
#   (145, 1),
#   (146, 1),
#   (147, 1),
#   (148, 3),
#   (149, 1),
#   (150, 1),
#   (151, 1),
#   (152, 1),
#   (153, 1),
#   (154, 4),
#   (155, 1),
#   (156, 2),
#   (157, 1),
#   (158, 1),
#   (159, 1),
#   (160, 2),
#   (161, 1),
#   (162, 1),
#   (163, 1),
#   (164, 2),
#   (165, 1),
#   (166, 1),
#   (167, 1),
#   (168, 2),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (172, 1),
#   (173, 1),
#   (174, 1),
#   (175, 1),
#   (176, 1),
#   (177, 1)],
#  [(18, 1),
#   (25, 2),
#   (51, 1),
#   (116, 2),
#   (178, 1),
#   (179, 1),
#   (180, 3),
#   (181, 1),
#   (182, 2),
#   (183, 3),
#   (184, 2),
#   (185, 1),
#   (186, 1),
#   (187, 1),
#   (188, 2),
#   (189, 2),
#   (190, 1),
#   (191, 1),
#   (192, 1),
#   (193, 2),
#   (194, 1),
#   (195, 3),
#   (196, 3),
#   (197, 1),
#   (198, 1),
#   (199, 3),
#   (200, 1),
#   (201, 1),
#   (202, 1)],
#  [(86, 1),
#   (105, 1),
#   (114, 1),
#   (138, 3),
#   (203, 1),
#   (204, 1),
#   (205, 1),
#   (206, 1),
#   (207, 1),
#   (208, 1),
#   (209, 1),
#   (210, 1),
#   (211, 1),
#   (212, 3),
#   (213, 1),
#   (214, 1),
#   (215, 4),
#   (216, 1),
#   (217, 1),
#   (218, 1),
#   (219, 1),
#   (220, 1),
#   (221, 1),
#   (222, 1),
#   (223, 1),
#   (224, 1),
#   (225, 1),
#   (226, 1),
#   (227, 1),
#   (228, 2),
#   (229, 1),
#   (230, 1),
#   (231, 1),
#   (232, 1),
#   (233, 1),
#   (234, 1),
#   (235, 1),
#   (236, 3),
#   (237, 1),
#   (238, 1),
#   (239, 1),
#   (240, 1),
#   (241, 1),
#   (242, 1),
#   (243, 1),
#   (244, 1),
#   (245, 1),
#   (246, 2),
#   (247, 1),
#   (248, 1),
#   (249, 1),
#   (250, 1),
#   (251, 2),
#   (252, 1),
#   (253, 1),
#   (254, 1),
#   (255, 1),
#   (256, 1),
#   (257, 1),
#   (258, 1),
#   (259, 1),
#   (260, 1),
#   (261, 8),
#   (262, 1),
#   (263, 1),
#   (264, 1),
#   (265, 2),
#   (266, 2),
#   (267, 2),
#   (268, 1),
#   (269, 8),
#   (270, 1),
#   (271, 1),
#   (272, 1),
#   (273, 1),
#   (274, 1),
#   (275, 3),
#   (276, 1),
#   (277, 1),
#   (278, 1),
#   (279, 2),
#   (280, 1),
#   (281, 3),
#   (282, 5),
#   (283, 1),
#   (284, 1),
#   (285, 1),
#   (286, 1)],
#  [(9, 2),
#   (43, 1),
#   (78, 1),
#   (146, 4),
#   (148, 1),
#   (157, 1),
#   (197, 1),
#   (222, 2),
#   (259, 1),
#   (271, 1),
#   (275, 1),
#   (282, 2),
#   (287, 2),
#   (288, 1),
#   (289, 2),
#   (290, 1),
#   (291, 2),
#   (292, 1),
#   (293, 2),
#   (294, 11),
#   (295, 2),
#   (296, 1),
#   (297, 2),
#   (298, 1),
#   (299, 2),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 2),
#   (304, 1),
#   (305, 1),
#   (306, 1),
#   (307, 3),
#   (308, 2),
#   (309, 1),
#   (310, 1),
#   (311, 2),
#   (312, 1),
#   (313, 1),
#   (314, 1),
#   (315, 1),
#   (316, 2),
#   (317, 1),
#   (318, 1),
#   (319, 1),
#   (320, 2),
#   (321, 1),
#   (322, 1),
#   (323, 1),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 1),
#   (328, 1),
#   (329, 1),
#   (330, 2),
#   (331, 4),
#   (332, 1),
#   (333, 2),
#   (334, 1),
#   (335, 1),
#   (336, 2),
#   (337, 1),
#   (338, 1),
#   (339, 1),
#   (340, 1),
#   (341, 1),
#   (342, 2),
#   (343, 4),
#   (344, 1),
#   (345, 2),
#   (346, 1),
#   (347, 4),
#   (348, 1),
#   (349, 2),
#   (350, 1),
#   (351, 1),
#   (352, 2),
#   (353, 1),
#   (354, 1),
#   (355, 1),
#   (356, 1),
#   (357, 1),
#   (358, 1),
#   (359, 2),
#   (360, 1),
#   (361, 2),
#   (362, 1),
#   (363, 2),
#   (364, 1),
#   (365, 3),
#   (366, 1),
#   (367, 1),
#   (368, 2),
#   (369, 1),
#   (370, 1),
#   (371, 1),
#   (372, 3),
#   (373, 1),
#   (374, 2)],
#  [(53, 2),
#   (121, 2),
#   (268, 2),
#   (375, 2),
#   (376, 2),
#   (377, 5),
#   (378, 3),
#   (379, 5),
#   (380, 2),
#   (381, 1),
#   (382, 1),
#   (383, 1),
#   (384, 2),
#   (385, 2),
#   (386, 7),
#   (387, 2),
#   (388, 2),
#   (389, 1),
#   (390, 3)],
#  [(169, 1), (361, 1), (391, 1), (392, 1), (393, 1), (394, 1)],
#  [(55, 1),
#   (70, 2),
#   (102, 1),
#   (111, 1),
#   (115, 3),
#   (119, 2),
#   (163, 1),
#   (186, 1),
#   (187, 1),
#   (195, 1),
#   (256, 1),
#   (295, 1),
#   (317, 1),
#   (395, 1),
#   (396, 2),
#   (397, 1),
#   (398, 1),
#   (399, 1),
#   (400, 1),
#   (401, 1),
#   (402, 1),
#   (403, 1),
#   (404, 1),
#   (405, 3),
#   (406, 1),
#   (407, 1),
#   (408, 8),
#   (409, 2),
#   (410, 5),
#   (411, 1),
#   (412, 1),
#   (413, 1),
#   (414, 1),
#   (415, 1),
#   (416, 1),
#   (417, 1),
#   (418, 1),
#   (419, 1),
#   (420, 1),
#   (421, 1),
#   (422, 1),
#   (423, 1),
#   (424, 1),
#   (425, 1),
#   (426, 1),
#   (427, 1),
#   (428, 1),
#   (429, 1)],
#  [(57, 1),
#   (172, 2),
#   (430, 2),
#   (431, 2),
#   (432, 1),
#   (433, 1),
#   (434, 1),
#   (435, 1),
#   (436, 2),
#   (437, 1),
#   (438, 1)],
#  [(4, 1),
#   (93, 1),
#   (97, 1),
#   (107, 1),
#   (252, 1),
#   (419, 1),
#   (439, 3),
#   (440, 2),
#   (441, 1),
#   (442, 2),
#   (443, 2),
#   (444, 1),
#   (445, 1),
#   (446, 1),
#   (447, 1),
#   (448, 1),
#   (449, 1),
#   (450, 1),
#   (451, 2),
#   (452, 4),
#   (453, 1),
#   (454, 2),
#   (455, 1),
#   (456, 1)],
#  [(105, 2),
#   (137, 1),
#   (163, 1),
#   (197, 1),
#   (203, 1),
#   (224, 1),
#   (257, 1),
#   (267, 1),
#   (276, 2),
#   (314, 2),
#   (457, 1),
#   (458, 2),
#   (459, 1),
#   (460, 1),
#   (461, 1),
#   (462, 1),
#   (463, 2),
#   (464, 1),
#   (465, 1),
#   (466, 1),
#   (467, 2),
#   (468, 1),
#   (469, 2),
#   (470, 2),
#   (471, 2),
#   (472, 1),
#   (473, 1),
#   (474, 2),
#   (475, 1),
#   (476, 1),
#   (477, 1),
#   (478, 1),
#   (479, 1),
#   (480, 1),
#   (481, 2),
#   (482, 3),
#   (483, 3),
#   (484, 1),
#   (485, 1),
#   (486, 2),
#   (487, 1),
#   (488, 1),
#   (489, 1),
#   (490, 2),
#   (491, 1),
#   (492, 2),
#   (493, 3),
#   (494, 1),
#   (495, 1),
#   (496, 2),
#   (497, 1),
#   (498, 1),
#   (499, 1),
#   (500, 1),
#   (501, 1)],
#  [(18, 4),
#   (57, 2),
#   (88, 1),
#   (108, 1),
#   (109, 1),
#   (143, 2),
#   (175, 1),
#   (185, 2),
#   (225, 2),
#   (329, 2),
#   (397, 1),
#   (502, 2),
#   (503, 1),
#   (504, 2),
#   (505, 1),
#   (506, 2),
#   (507, 2),
#   (508, 2),
#   (509, 2),
#   (510, 2),
#   (511, 2),
#   (512, 2),
#   (513, 2),
#   (514, 4),
#   (515, 2),
#   (516, 1),
#   (517, 2),
#   (518, 2)],
#  [(48, 1),
#   (86, 1),
#   (185, 1),
#   (257, 1),
#   (283, 1),
#   (405, 3),
#   (498, 1),
#   (519, 1),
#   (520, 3),
#   (521, 1),
#   (522, 1),
#   (523, 2),
#   (524, 1),
#   (525, 1),
#   (526, 1),
#   (527, 1),
#   (528, 3),
#   (529, 1),
#   (530, 1),
#   (531, 3),
#   (532, 2),
#   (533, 2),
#   (534, 1),
#   (535, 1),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (539, 1),
#   (540, 1),
#   (541, 1),
#   (542, 1),
#   (543, 1)],
#  [(30, 1),
#   (32, 2),
#   (46, 2),
#   (59, 1),
#   (60, 1),
#   (83, 1),
#   (96, 1),
#   (102, 1),
#   (109, 3),
#   (114, 1),
#   (119, 5),
#   (143, 2),
#   (172, 1),
#   (187, 1),
#   (195, 2),
#   (233, 1),
#   (305, 1),
#   (309, 2),
#   (329, 4),
#   (331, 1),
#   (412, 1),
#   (465, 2),
#   (487, 1),
#   (515, 4),
#   (516, 5),
#   (544, 1),
#   (545, 1),
#   (546, 1),
#   (547, 1),
#   (548, 1),
#   (549, 1),
#   (550, 1),
#   (551, 5),
#   (552, 1),
#   (553, 1),
#   (554, 2),
#   (555, 1),
#   (556, 1),
#   (557, 1),
#   (558, 1),
#   (559, 1),
#   (560, 1),
#   (561, 1),
#   (562, 1),
#   (563, 1),
#   (564, 1),
#   (565, 1),
#   (566, 2),
#   (567, 1),
#   (568, 1),
#   (569, 2),
#   (570, 1),
#   (571, 2),
#   (572, 1),
#   (573, 1),
#   (574, 1),
#   (575, 1),
#   (576, 1),
#   (577, 1),
#   (578, 2),
#   (579, 1),
#   (580, 2),
#   (581, 1),
#   (582, 2),
#   (583, 1),
#   (584, 2),
#   (585, 1),
#   (586, 1),
#   (587, 1),
#   (588, 9),
#   (589, 5),
#   (590, 1),
#   (591, 1)],
#  [(27, 1),
#   (87, 2),
#   (100, 1),
#   (428, 1),
#   (556, 1),
#   (592, 1),
#   (593, 2),
#   (594, 1),
#   (595, 1),
#   (596, 1)],
#  [(53, 1),
#   (78, 1),
#   (86, 1),
#   (102, 2),
#   (103, 3),
#   (104, 2),
#   (138, 1),
#   (222, 1),
#   (239, 2),
#   (493, 1),
#   (512, 1),
#   (597, 1),
#   (598, 2),
#   (599, 1),
#   (600, 1),
#   (601, 1),
#   (602, 1),
#   (603, 1),
#   (604, 1),
#   (605, 1),
#   (606, 1),
#   (607, 2),
#   (608, 5),
#   (609, 1),
#   (610, 1),
#   (611, 2),
#   (612, 5),
#   (613, 1),
#   (614, 1),
#   (615, 1)],
#  [(55, 1),
#   (85, 1),
#   (137, 1),
#   (159, 1),
#   (177, 2),
#   (268, 2),
#   (305, 1),
#   (322, 1),
#   (443, 1),
#   (445, 1),
#   (450, 2),
#   (454, 9),
#   (455, 3),
#   (616, 1),
#   (617, 1),
#   (618, 1),
#   (619, 1),
#   (620, 1),
#   (621, 2),
#   (622, 1),
#   (623, 1),
#   (624, 1),
#   (625, 1),
#   (626, 1),
#   (627, 1),
#   (628, 1),
#   (629, 1),
#   (630, 1),
#   (631, 1),
#   (632, 2),
#   (633, 1),
#   (634, 1),
#   (635, 1),
#   (636, 1),
#   (637, 1),
#   (638, 1),
#   (639, 1),
#   (640, 1),
#   (641, 1),
#   (642, 1),
#   (643, 2),
#   (644, 3),
#   (645, 1),
#   (646, 1),
#   (647, 1),
#   (648, 1),
#   (649, 1),
#   (650, 1),
#   (651, 1),
#   (652, 2),
#   (653, 1),
#   (654, 1),
#   (655, 1),
#   (656, 1),
#   (657, 1),
#   (658, 1),
#   (659, 1),
#   (660, 1),
#   (661, 1)],
#  [(25, 1),
#   (27, 1),
#   (52, 1),
#   (150, 1),
#   (172, 1),
#   (182, 1),
#   (268, 1),
#   (309, 1),
#   (397, 1),
#   (448, 1),
#   (459, 1),
#   (477, 1),
#   (500, 1),
#   (512, 1),
#   (515, 1),
#   (516, 2),
#   (646, 1),
#   (662, 1),
#   (663, 1),
#   (664, 1),
#   (665, 2),
#   (666, 1),
#   (667, 1),
#   (668, 1),
#   (669, 1),
#   (670, 1),
#   (671, 2),
#   (672, 1),
#   (673, 2),
#   (674, 1),
#   (675, 1),
#   (676, 3),
#   (677, 1),
#   (678, 1),
#   (679, 1),
#   (680, 1),
#   (681, 2),
#   (682, 1),
#   (683, 2),
#   (684, 2),
#   (685, 1),
#   (686, 1),
#   (687, 1),
#   (688, 1),
#   (689, 2),
#   (690, 1),
#   (691, 1),
#   (692, 1),
#   (693, 1),
#   (694, 1),
#   (695, 1),
#   (696, 1),
#   (697, 1),
#   (698, 1),
#   (699, 1),
#   (700, 4),
#   (701, 1),
#   (702, 2),
#   (703, 2),
#   (704, 1),
#   (705, 1),
#   (706, 1),
#   (707, 1)],
#  [(193, 1),
#   (214, 1),
#   (403, 1),
#   (418, 1),
#   (428, 1),
#   (475, 1),
#   (540, 1),
#   (700, 1),
#   (708, 2),
#   (709, 1),
#   (710, 2),
#   (711, 1),
#   (712, 2),
#   (713, 1),
#   (714, 1),
#   (715, 1),
#   (716, 1),
#   (717, 1),
#   (718, 1),
#   (719, 1),
#   (720, 1),
#   (721, 1),
#   (722, 1),
#   (723, 2),
#   (724, 1),
#   (725, 1)],
#  [(86, 1),
#   (102, 1),
#   (111, 1),
#   (115, 1),
#   (169, 1),
#   (222, 3),
#   (230, 3),
#   (244, 1),
#   (281, 1),
#   (290, 1),
#   (302, 1),
#   (307, 1),
#   (331, 1),
#   (385, 3),
#   (388, 1),
#   (462, 5),
#   (479, 1),
#   (606, 1),
#   (611, 1),
#   (652, 1),
#   (726, 1),
#   (727, 1),
#   (728, 1),
#   (729, 3),
#   (730, 3),
#   (731, 3),
#   (732, 1),
#   (733, 1),
#   (734, 1),
#   (735, 1),
#   (736, 1),
#   (737, 1),
#   (738, 1),
#   (739, 1),
#   (740, 1),
#   (741, 1),
#   (742, 1),
#   (743, 1),
#   (744, 3),
#   (745, 2)],
#  [(27, 1),
#   (107, 1),
#   (192, 2),
#   (441, 1),
#   (447, 8),
#   (459, 1),
#   (467, 2),
#   (519, 1),
#   (660, 1),
#   (746, 1),
#   (747, 1),
#   (748, 1),
#   (749, 1),
#   (750, 1),
#   (751, 2),
#   (752, 1),
#   (753, 1),
#   (754, 1),
#   (755, 1),
#   (756, 1),
#   (757, 2),
#   (758, 2),
#   (759, 1),
#   (760, 2),
#   (761, 1),
#   (762, 3),
#   (763, 2)],
#  [(55, 1),
#   (59, 1),
#   (93, 3),
#   (107, 1),
#   (126, 1),
#   (137, 1),
#   (148, 1),
#   (161, 1),
#   (181, 1),
#   (187, 1),
#   (194, 1),
#   (198, 1),
#   (200, 1),
#   (250, 1),
#   (295, 1),
#   (338, 1),
#   (397, 1),
#   (402, 4),
#   (423, 1),
#   (441, 1),
#   (515, 2),
#   (545, 1),
#   (549, 3),
#   (595, 2),
#   (660, 1),
#   (764, 2),
#   (765, 1),
#   (766, 2),
#   (767, 2),
#   (768, 1),
#   (769, 1),
#   (770, 2),
#   (771, 2),
#   (772, 1),
#   (773, 1),
#   (774, 3),
#   (775, 1),
#   (776, 1),
#   (777, 2),
#   (778, 2),
#   (779, 1),
#   (780, 2),
#   (781, 1),
#   (782, 1),
#   (783, 1),
#   (784, 1),
#   (785, 2),
#   (786, 1)],
#  [(29, 2),
#   (93, 1),
#   (96, 1),
#   (116, 2),
#   (129, 1),
#   (180, 1),
#   (289, 4),
#   (321, 1),
#   (361, 1),
#   (367, 1),
#   (547, 1),
#   (555, 1),
#   (610, 1),
#   (620, 2),
#   (660, 1),
#   (665, 1),
#   (772, 1),
#   (776, 1),
#   (787, 1),
#   (788, 1),
#   (789, 1),
#   (790, 1),
#   (791, 2),
#   (792, 1),
#   (793, 1),
#   (794, 1),
#   (795, 4),
#   (796, 2),
#   (797, 1),
#   (798, 1),
#   (799, 1),
#   (800, 2)],
#  [(59, 1),
#   (78, 1),
#   (122, 4),
#   (126, 1),
#   (203, 1),
#   (276, 1),
#   (292, 4),
#   (454, 2),
#   (560, 2),
#   (612, 2),
#   (614, 1),
#   (660, 2),
#   (674, 1),
#   (723, 1),
#   (776, 1),
#   (785, 1),
#   (801, 1),
#   (802, 1),
#   (803, 1),
#   (804, 1),
#   (805, 1),
#   (806, 1),
#   (807, 1),
#   (808, 1),
#   (809, 1),
#   (810, 1),
#   (811, 1),
#   (812, 3),
#   (813, 2),
#   (814, 1),
#   (815, 1),
#   (816, 3),
#   (817, 1),
#   (818, 1),
#   (819, 1),
#   (820, 2),
#   (821, 1),
#   (822, 1),
#   (823, 1),
#   (824, 1),
#   (825, 1),
#   (826, 2),
#   (827, 1),
#   (828, 1),
#   (829, 1),
#   (830, 1)],
#  [(106, 1),
#   (297, 1),
#   (363, 2),
#   (394, 2),
#   (463, 2),
#   (466, 1),
#   (476, 1),
#   (498, 2),
#   (610, 1),
#   (620, 1),
#   (726, 2),
#   (800, 2),
#   (831, 1),
#   (832, 1),
#   (833, 1),
#   (834, 4),
#   (835, 1),
#   (836, 2),
#   (837, 1),
#   (838, 1),
#   (839, 1),
#   (840, 1),
#   (841, 2)],
#  [(842, 1), (843, 1)],
#  [(18, 2),
#   (83, 1),
#   (119, 2),
#   (141, 1),
#   (166, 2),
#   (215, 3),
#   (295, 1),
#   (317, 1),
#   (486, 2),
#   (723, 2),
#   (844, 1),
#   (845, 2),
#   (846, 3),
#   (847, 4),
#   (848, 2),
#   (849, 1),
#   (850, 1),
#   (851, 2),
#   (852, 1),
#   (853, 1),
#   (854, 1),
#   (855, 1),
#   (856, 1),
#   (857, 1),
#   (858, 2),
#   (859, 1),
#   (860, 1),
#   (861, 1),
#   (862, 1),
#   (863, 1),
#   (864, 1),
#   (865, 1),
#   (866, 1),
#   (867, 3)],
#  [(7, 1),
#   (86, 1),
#   (97, 1),
#   (214, 1),
#   (215, 1),
#   (283, 1),
#   (285, 1),
#   (418, 1),
#   (520, 1),
#   (526, 1),
#   (532, 1),
#   (581, 1),
#   (678, 1),
#   (709, 1),
#   (717, 1),
#   (868, 1),
#   (869, 1),
#   (870, 1),
#   (871, 1),
#   (872, 1),
#   (873, 1),
#   (874, 1),
#   (875, 2),
#   (876, 1),
#   (877, 1),
#   (878, 1),
#   (879, 1),
#   (880, 1),
#   (881, 4),
#   (882, 6),
#   (883, 1),
#   (884, 1),
#   (885, 1),
#   (886, 1),
#   (887, 6),
#   (888, 1),
#   (889, 1),
#   (890, 1),
#   (891, 4),
#   (892, 2),
#   (893, 1),
#   (894, 1),
#   (895, 1),
#   (896, 1),
#   (897, 1),
#   (898, 1),
#   (899, 1),
#   (900, 1),
#   (901, 1),
#   (902, 4),
#   (903, 1),
#   (904, 1)],
#  [(2, 1),
#   (46, 1),
#   (57, 1),
#   (70, 1),
#   (88, 1),
#   (143, 1),
#   (170, 1),
#   (186, 1),
#   (195, 2),
#   (318, 1),
#   (422, 1),
#   (434, 1),
#   (512, 1),
#   (515, 1),
#   (516, 1),
#   (546, 1),
#   (557, 1),
#   (560, 1),
#   (562, 1),
#   (905, 1),
#   (906, 2),
#   (907, 2),
#   (908, 1),
#   (909, 1),
#   (910, 2),
#   (911, 1),
#   (912, 1),
#   (913, 1),
#   (914, 1),
#   (915, 1),
#   (916, 1),
#   (917, 2),
#   (918, 1),
#   (919, 3),
#   (920, 1),
#   (921, 1),
#   (922, 1),
#   (923, 1),
#   (924, 1),
#   (925, 2),
#   (926, 1),
#   (927, 1),
#   (928, 1),
#   (929, 1),
#   (930, 1)],
#  [(7, 1),
#   (46, 1),
#   (56, 1),
#   (59, 1),
#   (78, 1),
#   (93, 2),
#   (150, 1),
#   (166, 1),
#   (194, 1),
#   (198, 1),
#   (200, 2),
#   (217, 1),
#   (225, 1),
#   (252, 2),
#   (264, 1),
#   (315, 1),
#   (333, 4),
#   (384, 1),
#   (387, 1),
#   (407, 2),
#   (434, 1),
#   (438, 1),
#   (519, 1),
#   (594, 1),
#   (620, 4),
#   (634, 1),
#   (641, 1),
#   (642, 1),
#   (665, 2),
#   (711, 1),
#   (792, 2),
#   (795, 4),
#   (800, 2),
#   (803, 2),
#   (805, 1),
#   (927, 1),
#   (931, 1),
#   (932, 1),
#   (933, 1),
#   (934, 1),
#   (935, 1),
#   (936, 1),
#   (937, 7),
#   (938, 1),
#   (939, 2),
#   (940, 2),
#   (941, 1),
#   (942, 1),
#   (943, 1),
#   (944, 1),
#   (945, 1),
#   (946, 1),
#   (947, 3),
#   (948, 1),
#   (949, 1),
#   (950, 1),
#   (951, 1),
#   (952, 1),
#   (953, 1)],
#  [(32, 1),
#   (42, 1),
#   (47, 1),
#   (78, 1),
#   (86, 1),
#   (108, 1),
#   (125, 1),
#   (131, 1),
#   (137, 2),
#   (154, 1),
#   (155, 1),
#   (159, 1),
#   (170, 1),
#   (175, 1),
#   (177, 1),
#   (180, 1),
#   (194, 1),
#   (214, 1),
#   (220, 1),
#   (227, 1),
#   (236, 1),
#   (342, 1),
#   (348, 1),
#   (403, 1),
#   (474, 1),
#   (475, 1),
#   (484, 3),
#   (488, 1),
#   (499, 1),
#   (540, 1),
#   (546, 1),
#   (549, 1),
#   (556, 1),
#   (560, 1),
#   (568, 1),
#   (604, 1),
#   (640, 1),
#   (663, 1),
#   (679, 1),
#   (712, 1),
#   (717, 1),
#   (723, 3),
#   (781, 1),
#   (795, 1),
#   (847, 1),
#   (867, 1),
#   (868, 1),
#   (885, 1),
#   (886, 3),
#   (890, 1),
#   (898, 1),
#   (904, 1),
#   (954, 9),
#   (955, 1),
#   (956, 1),
#   (957, 1),
#   (958, 1),
#   (959, 1),
#   (960, 1),
#   (961, 2),
#   (962, 1),
#   (963, 1),
#   (964, 1),
#   (965, 1),
#   (966, 1),
#   (967, 1),
#   (968, 1),
#   (969, 1),
#   (970, 1),
#   (971, 1),
#   (972, 2),
#   (973, 1),
#   (974, 1),
#   (975, 3),
#   (976, 1),
#   (977, 1),
#   (978, 1),
#   (979, 1),
#   (980, 3),
#   (981, 1),
#   (982, 1),
#   (983, 1),
#   (984, 1),
#   (985, 1),
#   (986, 4),
#   (987, 3),
#   (988, 1),
#   (989, 1),
#   (990, 1),
#   (991, 1),
#   (992, 1),
#   (993, 1),
#   (994, 1),
#   (995, 1),
#   (996, 1),
#   (997, 1),
#   (998, 1),
#   (999, 2),
#   (1000, 1),
#   (1001, 1),
#   (1002, 1),
#   (1003, 1),
#   (1004, 1),
#   (1005, 1),
#   (1006, 3),
#   (1007, 1),
#   (1008, 1),
#   (1009, 1),
#   (1010, 1),
#   (1011, 1),
#   (1012, 1),
#   (1013, 1),
#   (1014, 1),
#   (1015, 1),
#   (1016, 1),
#   (1017, 1),
#   (1018, 1),
#   (1019, 1),
#   (1020, 1),
#   (1021, 1),
#   (1022, 1),
#   (1023, 6),
#   (1024, 1),
#   (1025, 2),
#   (1026, 2)],
#  [(88, 1),
#   (108, 1),
#   (119, 1),
#   (122, 4),
#   (126, 1),
#   (150, 1),
#   (182, 1),
#   (268, 1),
#   (331, 1),
#   (333, 1),
#   (338, 1),
#   (361, 1),
#   (387, 1),
#   (503, 1),
#   (568, 1),
#   (578, 1),
#   (591, 1),
#   (803, 1),
#   (937, 2),
#   (1027, 1),
#   (1028, 1),
#   (1029, 3),
#   (1030, 1),
#   (1031, 1),
#   (1032, 1),
#   (1033, 1),
#   (1034, 1),
#   (1035, 1),
#   (1036, 1),
#   (1037, 1),
#   (1038, 2),
#   (1039, 2),
#   (1040, 2),
#   (1041, 1),
#   (1042, 2),
#   (1043, 1),
#   (1044, 2)],
#  [(4, 1),
#   (47, 1),
#   (57, 1),
#   (78, 1),
#   (80, 1),
#   (82, 1),
#   (119, 1),
#   (169, 1),
#   (172, 1),
#   (187, 1),
#   (190, 1),
#   (191, 1),
#   (204, 1),
#   (250, 2),
#   (252, 1),
#   (289, 1),
#   (331, 1),
#   (365, 1),
#   (388, 1),
#   (543, 1),
#   (547, 1),
#   (549, 1),
#   (556, 1),
#   (645, 1),
#   (712, 1),
#   (753, 1),
#   (776, 2),
#   (812, 1),
#   (896, 1),
#   (1045, 1),
#   (1046, 2),
#   (1047, 1),
#   (1048, 1),
#   (1049, 1),
#   (1050, 1),
#   (1051, 1),
#   (1052, 1),
#   (1053, 1),
#   (1054, 1),
#   (1055, 1),
#   (1056, 1),
#   (1057, 2),
#   (1058, 1),
#   (1059, 1),
#   (1060, 1),
#   (1061, 1),
#   (1062, 1),
#   (1063, 1),
#   (1064, 1),
#   (1065, 1),
#   (1066, 1),
#   (1067, 1),
#   (1068, 1),
#   (1069, 1),
#   (1070, 1),
#   (1071, 1),
#   (1072, 1),
#   (1073, 1),
#   (1074, 1),
#   (1075, 1),
#   (1076, 1),
#   (1077, 1),
#   (1078, 1),
#   (1079, 1),
#   (1080, 1),
#   (1081, 1),
#   (1082, 2),
#   (1083, 1),
#   (1084, 1),
#   (1085, 3),
#   (1086, 1),
#   (1087, 1)],
#  [(16, 2),
#   (105, 1),
#   (106, 1),
#   (138, 1),
#   (166, 2),
#   (315, 1),
#   (377, 1),
#   (421, 1),
#   (451, 1),
#   (457, 1),
#   (481, 1),
#   (493, 1),
#   (610, 1),
#   (620, 1),
#   (786, 1),
#   (904, 2),
#   (970, 1),
#   (973, 3),
#   (1088, 1),
#   (1089, 2),
#   (1090, 2),
#   (1091, 2),
#   (1092, 1),
#   (1093, 1),
#   (1094, 1),
#   (1095, 1),
#   (1096, 1),
#   (1097, 1),
#   (1098, 1),
#   (1099, 1),
#   (1100, 2),
#   (1101, 1),
#   (1102, 1),
#   (1103, 1),
#   (1104, 1),
#   (1105, 1),
#   (1106, 1),
#   (1107, 3),
#   (1108, 1),
#   (1109, 1)],
#  [(656, 1), (1110, 1), (1111, 1), (1112, 1), (1113, 1), (1114, 1)],
#  [(107, 1),
#   (137, 1),
#   (181, 1),
#   (252, 1),
#   (441, 1),
#   (447, 2),
#   (455, 1),
#   (620, 1),
#   (768, 1),
#   (786, 1),
#   (803, 1),
#   (955, 2),
#   (1115, 1),
#   (1116, 1),
#   (1117, 1),
#   (1118, 3)],
#  [(12, 1),
#   (102, 1),
#   (172, 1),
#   (173, 2),
#   (193, 1),
#   (214, 1),
#   (307, 2),
#   (366, 1),
#   (459, 1),
#   (486, 1),
#   (539, 2),
#   (604, 1),
#   (632, 1),
#   (710, 2),
#   (714, 2),
#   (719, 1),
#   (721, 1),
#   (724, 1),
#   (725, 1),
#   (756, 1),
#   (974, 1),
#   (984, 1),
#   (1094, 1),
#   (1119, 1),
#   (1120, 1),
#   (1121, 1),
#   (1122, 1),
#   (1123, 1),
#   (1124, 1),
#   (1125, 1),
#   (1126, 1),
#   (1127, 1),
#   (1128, 4),
#   (1129, 1),
#   (1130, 1),
#   (1131, 1),
#   (1132, 2)],
#  [(17, 4),
#   (93, 1),
#   (109, 1),
#   (111, 1),
#   (143, 4),
#   (187, 1),
#   (268, 1),
#   (295, 1),
#   (338, 1),
#   (340, 1),
#   (341, 1),
#   (397, 1),
#   (412, 3),
#   (427, 1),
#   (489, 1),
#   (509, 1),
#   (510, 1),
#   (513, 1),
#   (515, 2),
#   (516, 1),
#   (567, 2),
#   (570, 1),
#   (666, 1),
#   (786, 1),
#   (811, 1),
#   (919, 1),
#   (1038, 1),
#   (1050, 1),
#   (1059, 1),
#   (1115, 1),
#   (1133, 1),
#   (1134, 2),
#   (1135, 3),
#   (1136, 1),
#   (1137, 1),
#   (1138, 2),
#   (1139, 2),
#   (1140, 2),
#   (1141, 2),
#   (1142, 1),
#   (1143, 1),
#   (1144, 1),
#   (1145, 1),
#   (1146, 1),
#   (1147, 1),
#   (1148, 1)],
#  [(27, 1),
#   (57, 1),
#   (85, 1),
#   (86, 1),
#   (97, 1),
#   (107, 1),
#   (252, 1),
#   (304, 1),
#   (342, 1),
#   (441, 1),
#   (458, 1),
#   (595, 1),
#   (638, 1),
#   (650, 1),
#   (712, 2),
#   (754, 1),
#   (756, 1),
#   (776, 1),
#   (1044, 1),
#   (1068, 1),
#   (1075, 1),
#   (1103, 1),
#   (1149, 1),
#   (1150, 1),
#   (1151, 2),
#   (1152, 1),
#   (1153, 1),
#   (1154, 1),
#   (1155, 1),
#   (1156, 1),
#   (1157, 1),
#   (1158, 1),
#   (1159, 1),
#   (1160, 1),
#   (1161, 1),
#   (1162, 1),
#   (1163, 1),
#   (1164, 1),
#   (1165, 3),
#   (1166, 1),
#   (1167, 1),
#   (1168, 1),
#   (1169, 1),
#   (1170, 1),
#   (1171, 1),
#   (1172, 2),
#   (1173, 1),
#   (1174, 1)],
#  [(21, 1),
#   (86, 1),
#   (102, 3),
#   (103, 3),
#   (104, 1),
#   (109, 1),
#   (222, 2),
#   (451, 2),
#   (602, 1),
#   (610, 1),
#   (612, 3),
#   (613, 1),
#   (688, 1),
#   (807, 1),
#   (1027, 1),
#   (1100, 1),
#   (1115, 1),
#   (1150, 4),
#   (1154, 1),
#   (1155, 1),
#   (1172, 4),
#   (1175, 1),
#   (1176, 1),
#   (1177, 1),
#   (1178, 1),
#   (1179, 1)],
#  [(47, 1),
#   (73, 2),
#   (82, 1),
#   (108, 1),
#   (172, 1),
#   (181, 1),
#   (187, 1),
#   (190, 1),
#   (192, 1),
#   (203, 1),
#   (217, 1),
#   (250, 1),
#   (292, 1),
#   (341, 1),
#   (418, 2),
#   (423, 1),
#   (450, 1),
#   (451, 1),
#   (454, 2),
#   (545, 1),
#   (595, 1),
#   (714, 1),
#   (768, 1),
#   (781, 1),
#   (786, 1),
#   (868, 1),
#   (938, 1),
#   (1054, 1),
#   (1068, 2),
#   (1180, 1),
#   (1181, 1),
#   (1182, 1),
#   (1183, 1),
#   (1184, 2),
#   (1185, 1),
#   (1186, 5),
#   (1187, 3),
#   (1188, 1),
#   (1189, 1),
#   (1190, 1),
#   (1191, 1),
#   (1192, 1),
#   (1193, 1),
#   (1194, 2),
#   (1195, 1),
#   (1196, 1)],
#  [(27, 1),
#   (59, 1),
#   (107, 1),
#   (276, 1),
#   (441, 1),
#   (549, 1),
#   (620, 1),
#   (1082, 1),
#   (1173, 1),
#   (1197, 1),
#   (1198, 1),
#   (1199, 1),
#   (1200, 1),
#   (1201, 1),
#   (1202, 2)],
#  [(222, 1),
#   (397, 1),
#   (464, 1),
#   (505, 1),
#   (1203, 1),
#   (1204, 1),
#   (1205, 1),
#   (1206, 2),
#   (1207, 3)],
#  [(51, 1),
#   (80, 1),
#   (86, 1),
#   (150, 1),
#   (257, 3),
#   (465, 1),
#   (474, 1),
#   (486, 1),
#   (526, 1),
#   (528, 1),
#   (532, 1),
#   (534, 1),
#   (540, 1),
#   (542, 3),
#   (603, 1),
#   (785, 1),
#   (875, 1),
#   (880, 1),
#   (886, 3),
#   (891, 1),
#   (892, 1),
#   (902, 1),
#   (904, 1),
#   (1160, 1),
#   (1208, 2),
#   (1209, 1),
#   (1210, 7),
#   (1211, 2),
#   (1212, 1),
#   (1213, 1),
#   (1214, 1),
#   (1215, 1),
#   (1216, 1),
#   (1217, 1),
#   (1218, 2),
#   (1219, 1),
#   (1220, 1),
#   (1221, 1),
#   (1222, 4),
#   (1223, 2),
#   (1224, 1),
#   (1225, 2),
#   (1226, 1)],
#  [(155, 2),
#   (181, 1),
#   (187, 1),
#   (250, 1),
#   (392, 4),
#   (418, 2),
#   (423, 1),
#   (768, 1),
#   (868, 1),
#   (1073, 1),
#   (1074, 2),
#   (1195, 1),
#   (1227, 1),
#   (1228, 2),
#   (1229, 2),
#   (1230, 2),
#   (1231, 2),
#   (1232, 1)],
#  [(57, 2),
#   (82, 1),
#   (107, 1),
#   (192, 2),
#   (196, 1),
#   (250, 1),
#   (441, 1),
#   (443, 1),
#   (450, 4),
#   (454, 1),
#   (512, 1),
#   (626, 1),
#   (629, 1),
#   (642, 1),
#   (646, 1),
#   (658, 1),
#   (800, 2),
#   (835, 2),
#   (865, 1),
#   (1074, 1),
#   (1195, 1),
#   (1233, 1),
#   (1234, 1),
#   (1235, 1),
#   (1236, 2),
#   (1237, 1),
#   (1238, 1),
#   (1239, 1),
#   (1240, 1),
#   (1241, 1),
#   (1242, 3),
#   (1243, 4)],
#  [(87, 1),
#   (133, 1),
#   (227, 1),
#   (250, 1),
#   (251, 1),
#   (265, 1),
#   (331, 1),
#   (680, 1),
#   (871, 1),
#   (878, 1),
#   (892, 1),
#   (1244, 1),
#   (1245, 1),
#   (1246, 1),
#   (1247, 1),
#   (1248, 1),
#   (1249, 1),
#   (1250, 3),
#   (1251, 1),
#   (1252, 1),
#   (1253, 1),
#   (1254, 1),
#   (1255, 6),
#   (1256, 1),
#   (1257, 1),
#   (1258, 1),
#   (1259, 1),
#   (1260, 1),
#   (1261, 1),
#   (1262, 2),
#   (1263, 1),
#   (1264, 1),
#   (1265, 1),
#   (1266, 1)],
#  [(27, 1),
#   (41, 1),
#   (73, 1),
#   (119, 1),
#   (159, 1),
#   (180, 1),
#   (305, 1),
#   (341, 1),
#   (595, 2),
#   (632, 1),
#   (634, 1),
#   (640, 1),
#   (776, 1),
#   (781, 1),
#   (893, 1),
#   (1068, 1),
#   (1096, 1),
#   (1126, 1),
#   (1173, 1),
#   (1227, 1),
#   (1245, 1),
#   (1267, 1),
#   (1268, 1),
#   (1269, 1),
#   (1270, 1),
#   (1271, 1),
#   (1272, 2),
#   (1273, 1),
#   (1274, 1),
#   (1275, 1),
#   (1276, 1),
#   (1277, 1),
#   (1278, 1),
#   (1279, 1),
#   (1280, 1),
#   (1281, 1),
#   (1282, 1),
#   (1283, 1),
#   (1284, 1),
#   (1285, 1),
#   (1286, 4)],
#  [(14, 1),
#   (53, 1),
#   (57, 1),
#   (60, 1),
#   (80, 1),
#   (83, 1),
#   (85, 1),
#   (93, 3),
#   (109, 2),
#   (111, 2),
#   (123, 1),
#   (167, 1),
#   (187, 1),
#   (195, 1),
#   (204, 1),
#   (229, 1),
#   (295, 1),
#   (331, 3),
#   (360, 1),
#   (362, 1),
#   (383, 1),
#   (397, 1),
#   (398, 1),
#   (503, 1),
#   (520, 2),
#   (786, 2),
#   (909, 1),
#   (910, 1),
#   (1135, 6),
#   (1148, 1),
#   (1211, 1),
#   (1287, 2),
#   (1288, 1),
#   (1289, 1),
#   (1290, 1),
#   (1291, 1),
#   (1292, 1),
#   (1293, 1),
#   (1294, 2),
#   (1295, 1),
#   (1296, 1),
#   (1297, 1),
#   (1298, 1),
#   (1299, 1),
#   (1300, 1),
#   (1301, 1),
#   (1302, 1),
#   (1303, 1),
#   (1304, 1),
#   (1305, 1),
#   (1306, 1),
#   (1307, 1),
#   (1308, 2),
#   (1309, 1),
#   (1310, 1)],
#  [(60, 1),
#   (180, 1),
#   (181, 1),
#   (215, 3),
#   (217, 1),
#   (246, 1),
#   (266, 1),
#   (486, 4),
#   (499, 1),
#   (530, 1),
#   (567, 2),
#   (680, 1),
#   (716, 1),
#   (772, 1),
#   (786, 1),
#   (867, 1),
#   (868, 1),
#   (870, 1),
#   (875, 1),
#   (886, 1),
#   (892, 1),
#   (894, 1),
#   (898, 1),
#   (904, 1),
#   (920, 1),
#   (962, 1),
#   (967, 1),
#   (990, 1),
#   (1010, 3),
#   (1020, 1),
#   (1062, 2),
#   (1164, 1),
#   (1211, 2),
#   (1215, 1),
#   (1216, 2),
#   (1220, 1),
#   (1225, 1),
#   (1226, 3),
#   (1311, 1),
#   (1312, 2),
#   (1313, 1),
#   (1314, 1),
#   (1315, 1),
#   (1316, 1),
#   (1317, 1),
#   (1318, 1),
#   (1319, 1),
#   (1320, 5),
#   (1321, 1),
#   (1322, 3),
#   (1323, 1),
#   (1324, 1),
#   (1325, 1),
#   (1326, 1),
#   (1327, 3),
#   (1328, 1),
#   (1329, 1),
#   (1330, 1),
#   (1331, 1),
#   (1332, 1),
#   (1333, 1),
#   (1334, 1),
#   (1335, 1),
#   (1336, 2),
#   (1337, 1),
#   (1338, 1),
#   (1339, 1),
#   (1340, 1),
#   (1341, 1),
#   (1342, 1),
#   (1343, 1),
#   (1344, 1),
#   (1345, 1),
#   (1346, 1),
#   (1347, 2),
#   (1348, 2),
#   (1349, 1),
#   (1350, 1),
#   (1351, 2)],
#  [(486, 2),
#   (499, 2),
#   (536, 1),
#   (686, 1),
#   (821, 1),
#   (892, 1),
#   (1251, 1),
#   (1352, 2),
#   (1353, 1),
#   (1354, 2),
#   (1355, 2),
#   (1356, 1),
#   (1357, 2),
#   (1358, 2),
#   (1359, 2)],
#  [(27, 1),
#   (87, 2),
#   (100, 1),
#   (428, 1),
#   (556, 1),
#   (592, 1),
#   (593, 2),
#   (594, 1),
#   (595, 1),
#   (596, 1)],
#  [(57, 2),
#   (82, 1),
#   (181, 1),
#   (187, 1),
#   (237, 2),
#   (252, 1),
#   (397, 1),
#   (520, 2),
#   (523, 1),
#   (549, 4),
#   (634, 2),
#   (769, 1),
#   (779, 1),
#   (784, 1),
#   (786, 1),
#   (1068, 1),
#   (1074, 2),
#   (1298, 2),
#   (1360, 1),
#   (1361, 3)],
#  [(9, 1),
#   (25, 1),
#   (47, 1),
#   (70, 1),
#   (78, 1),
#   (102, 1),
#   (148, 1),
#   (159, 1),
#   (196, 1),
#   (222, 1),
#   (229, 2),
#   (290, 1),
#   (353, 1),
#   (409, 4),
#   (410, 1),
#   (418, 1),
#   (428, 2),
#   (498, 1),
#   (557, 2),
#   (571, 1),
#   (581, 1),
#   (652, 1),
#   (818, 1),
#   (913, 1),
#   (955, 1),
#   (1041, 1),
#   (1117, 5),
#   (1118, 1),
#   (1152, 1),
#   (1189, 1),
#   (1195, 1),
#   (1240, 1),
#   (1244, 4),
#   (1293, 1),
#   (1362, 2),
#   (1363, 2),
#   (1364, 2),
#   (1365, 3),
#   (1366, 2),
#   (1367, 1),
#   (1368, 1),
#   (1369, 2),
#   (1370, 1),
#   (1371, 1),
#   (1372, 1),
#   (1373, 1),
#   (1374, 1),
#   (1375, 1),
#   (1376, 2),
#   (1377, 1)],
#  [(25, 1),
#   (38, 1),
#   (70, 1),
#   (93, 1),
#   (102, 2),
#   (111, 1),
#   (115, 1),
#   (233, 1),
#   (309, 1),
#   (353, 1),
#   (409, 4),
#   (410, 1),
#   (415, 3),
#   (585, 1),
#   (803, 2),
#   (890, 1),
#   (915, 1),
#   (942, 1),
#   (955, 1),
#   (1220, 1),
#   (1240, 1),
#   (1265, 1),
#   (1363, 2),
#   (1370, 1),
#   (1371, 1),
#   (1373, 1),
#   (1374, 1),
#   (1378, 1),
#   (1379, 1),
#   (1380, 1),
#   (1381, 2),
#   (1382, 1),
#   (1383, 1),
#   (1384, 2),
#   (1385, 1),
#   (1386, 1),
#   (1387, 1),
#   (1388, 1),
#   (1389, 1)],
#  [(9, 1),
#   (14, 2),
#   (25, 1),
#   (61, 3),
#   (68, 1),
#   (78, 1),
#   (93, 4),
#   (116, 2),
#   (118, 1),
#   (120, 2),
#   (126, 2),
#   (182, 2),
#   (195, 1),
#   (289, 1),
#   (304, 2),
#   (329, 1),
#   (333, 1),
#   (348, 1),
#   (357, 3),
#   (388, 1),
#   (430, 3),
#   (432, 3),
#   (517, 5),
#   (518, 1),
#   (520, 3),
#   (545, 1),
#   (554, 1),
#   (650, 1),
#   (769, 1),
#   (788, 2),
#   (793, 2),
#   (803, 1),
#   (818, 1),
#   (820, 2),
#   (835, 1),
#   (864, 3),
#   (925, 3),
#   (932, 2),
#   (945, 2),
#   (966, 2),
#   (1060, 1),
#   (1085, 1),
#   (1124, 2),
#   (1164, 2),
#   (1227, 1),
#   (1278, 3),
#   (1390, 1),
#   (1391, 2),
#   (1392, 2),
#   (1393, 1),
#   (1394, 2),
#   (1395, 1),
#   (1396, 2),
#   (1397, 2),
#   (1398, 1),
#   (1399, 1),
#   (1400, 2),
#   (1401, 1),
#   (1402, 2),
#   (1403, 1),
#   (1404, 1),
#   (1405, 2),
#   (1406, 1),
#   (1407, 2),
#   (1408, 1),
#   (1409, 1),
#   (1410, 1),
#   (1411, 2),
#   (1412, 2),
#   (1413, 2),
#   (1414, 2)],
#  [(27, 1),
#   (39, 1),
#   (78, 1),
#   (80, 1),
#   (82, 1),
#   (97, 1),
#   (126, 1),
#   (190, 1),
#   (250, 1),
#   (252, 1),
#   (450, 1),
#   (549, 1),
#   (556, 1),
#   (595, 1),
#   (609, 1),
#   (650, 2),
#   (657, 1),
#   (712, 1),
#   (753, 1),
#   (776, 2),
#   (785, 1),
#   (812, 1),
#   (868, 1),
#   (869, 1),
#   (975, 1),
#   (1046, 2),
#   (1047, 1),
#   (1049, 1),
#   (1055, 1),
#   (1056, 1),
#   (1057, 3),
#   (1058, 1),
#   (1062, 1),
#   (1065, 1),
#   (1067, 1),
#   (1068, 2),
#   (1069, 1),
#   (1071, 1),
#   (1072, 1),
#   (1075, 1),
#   (1076, 1),
#   (1077, 1),
#   (1081, 1),
#   (1082, 2),
#   (1083, 1),
#   (1084, 1),
#   (1085, 4),
#   (1086, 1),
#   (1087, 2),
#   (1165, 1),
#   (1183, 1),
#   (1198, 1),
#   (1282, 1),
#   (1366, 1),
#   (1382, 1),
#   (1415, 1),
#   (1416, 1),
#   (1417, 1),
#   (1418, 1),
#   (1419, 1),
#   (1420, 1),
#   (1421, 2),
#   (1422, 1),
#   (1423, 1),
#   (1424, 1),
#   (1425, 1),
#   (1426, 1),
#   (1427, 1),
#   (1428, 1),
#   (1429, 1),
#   (1430, 1),
#   (1431, 1),
#   (1432, 1),
#   (1433, 1),
#   (1434, 1),
#   (1435, 1),
#   (1436, 1),
#   (1437, 1),
#   (1438, 1),
#   (1439, 1),
#   (1440, 1),
#   (1441, 1),
#   (1442, 1),
#   (1443, 1),
#   (1444, 1),
#   (1445, 1),
#   (1446, 2)],
#  [(7, 1),
#   (11, 1),
#   (55, 1),
#   (86, 2),
#   (155, 1),
#   (237, 1),
#   (484, 1),
#   (486, 1),
#   (491, 1),
#   (521, 1),
#   (535, 2),
#   (538, 2),
#   (615, 1),
#   (673, 1),
#   (679, 1),
#   (695, 1),
#   (720, 1),
#   (758, 3),
#   (768, 1),
#   (773, 1),
#   (847, 1),
#   (886, 4),
#   (898, 1),
#   (962, 1),
#   (971, 1),
#   (987, 2),
#   (1006, 5),
#   (1028, 1),
#   (1117, 3),
#   (1219, 2),
#   (1251, 1),
#   (1295, 1),
#   (1447, 1),
#   (1448, 1),
#   (1449, 4),
#   (1450, 2),
#   (1451, 1),
#   (1452, 1),
#   (1453, 2),
#   (1454, 1),
#   (1455, 1),
#   (1456, 1),
#   (1457, 1),
#   (1458, 1),
#   (1459, 1),
#   (1460, 1),
#   (1461, 1),
#   (1462, 2),
#   (1463, 1),
#   (1464, 1),
#   (1465, 1),
#   (1466, 2),
#   (1467, 3)],
#  [(44, 1),
#   (47, 1),
#   (55, 1),
#   (82, 1),
#   (101, 3),
#   (119, 1),
#   (163, 1),
#   (172, 1),
#   (181, 1),
#   (187, 1),
#   (192, 1),
#   (196, 1),
#   (250, 1),
#   (309, 1),
#   (423, 1),
#   (450, 2),
#   (585, 2),
#   (625, 1),
#   (632, 2),
#   (640, 1),
#   (712, 1),
#   (775, 1),
#   (835, 1),
#   (869, 1),
#   (900, 1),
#   (945, 1),
#   (1072, 1),
#   (1184, 1),
#   (1191, 1),
#   (1227, 1),
#   (1269, 1),
#   (1293, 1),
#   (1368, 1),
#   (1382, 1),
#   (1468, 3),
#   (1469, 1),
#   (1470, 1),
#   (1471, 2),
#   (1472, 2),
#   (1473, 1),
#   (1474, 1),
#   (1475, 1),
#   (1476, 6),
#   (1477, 2),
#   (1478, 1),
#   (1479, 1),
#   (1480, 1),
#   (1481, 1),
#   (1482, 1)],
#  [(193, 1),
#   (214, 1),
#   (215, 3),
#   (401, 1),
#   (403, 1),
#   (418, 1),
#   (428, 1),
#   (475, 1),
#   (539, 2),
#   (581, 1),
#   (700, 1),
#   (710, 1),
#   (711, 1),
#   (712, 1),
#   (714, 1),
#   (716, 1),
#   (719, 1),
#   (720, 1),
#   (721, 1),
#   (723, 1),
#   (724, 1),
#   (867, 2),
#   (870, 1),
#   (895, 1),
#   (898, 2),
#   (1018, 1),
#   (1213, 2),
#   (1483, 1),
#   (1484, 2),
#   (1485, 1),
#   (1486, 1),
#   (1487, 2),
#   (1488, 1),
#   (1489, 1),
#   (1490, 1),
#   (1491, 2),
#   (1492, 3)],
#  [(27, 1),
#   (39, 1),
#   (78, 1),
#   (80, 1),
#   (82, 1),
#   (97, 1),
#   (126, 1),
#   (187, 2),
#   (250, 1),
#   (252, 1),
#   (450, 1),
#   (549, 1),
#   (556, 1),
#   (595, 1),
#   (609, 1),
#   (650, 2),
#   (657, 1),
#   (712, 1),
#   (776, 2),
#   (785, 1),
#   (812, 1),
#   (868, 1),
#   (869, 1),
#   (975, 1),
#   (1046, 2),
#   (1047, 1),
#   (1049, 1),
#   (1055, 1),
#   (1056, 1),
#   (1057, 3),
#   (1062, 1),
#   (1065, 1),
#   (1067, 1),
#   (1068, 1),
#   (1069, 1),
#   (1071, 1),
#   (1072, 1),
#   (1075, 1),
#   (1076, 1),
#   (1077, 1),
#   (1081, 1),
#   (1082, 2),
#   (1083, 1),
#   (1084, 1),
#   (1085, 4),
#   (1087, 2),
#   (1165, 1),
#   (1183, 1),
#   (1198, 1),
#   (1282, 1),
#   (1366, 1),
#   (1382, 1),
#   (1415, 1),
#   (1416, 1),
#   (1418, 1),
#   (1419, 1),
#   (1420, 1),
#   (1421, 2),
#   (1422, 1),
#   (1423, 1),
#   (1424, 1),
#   (1425, 1),
#   (1426, 1),
#   (1427, 1),
#   (1428, 1),
#   (1429, 1),
#   (1430, 1),
#   (1431, 1),
#   (1432, 1),
#   (1433, 1),
#   (1434, 1),
#   (1435, 1),
#   (1436, 1),
#   (1437, 1),
#   (1438, 1),
#   (1439, 1),
#   (1440, 1),
#   (1441, 1),
#   (1442, 1),
#   (1443, 1),
#   (1444, 1),
#   (1445, 1),
#   (1446, 1),
#   (1493, 1)],
#  [(27, 1),
#   (73, 1),
#   (78, 1),
#   (86, 1),
#   (107, 1),
#   (127, 1),
#   (137, 1),
#   (177, 2),
#   (305, 1),
#   (439, 1),
#   (441, 1),
#   (450, 2),
#   (454, 4),
#   (455, 1),
#   (616, 1),
#   (618, 1),
#   (621, 5),
#   (626, 1),
#   (629, 1),
#   (631, 2),
#   (639, 1),
#   (643, 1),
#   (651, 3),
#   (652, 1),
#   (654, 1),
#   (656, 1),
#   (658, 1),
#   (660, 1),
#   (835, 2),
#   (1200, 1),
#   (1401, 1),
#   (1438, 1),
#   (1494, 1),
#   (1495, 1),
#   (1496, 2),
#   (1497, 1),
#   (1498, 2),
#   (1499, 1),
#   (1500, 1),
#   (1501, 1),
#   (1502, 1),
#   (1503, 1)],
#  [(1, 1),
#   (86, 1),
#   (99, 2),
#   (110, 1),
#   (181, 1),
#   (436, 1),
#   (480, 1),
#   (620, 1),
#   (673, 2),
#   (768, 1),
#   (843, 5),
#   (852, 1),
#   (1028, 1),
#   (1345, 1),
#   (1448, 1),
#   (1504, 1),
#   (1505, 2),
#   (1506, 1),
#   (1507, 1),
#   (1508, 1),
#   (1509, 1)],
#  [(27, 1),
#   (57, 1),
#   (83, 3),
#   (84, 1),
#   (89, 1),
#   (93, 3),
#   (116, 2),
#   (189, 1),
#   (190, 1),
#   (192, 2),
#   (325, 1),
#   (337, 1),
#   (423, 1),
#   (451, 1),
#   (568, 1),
#   (660, 3),
#   (769, 3),
#   (807, 1),
#   (835, 1),
#   (981, 1),
#   (1100, 1),
#   (1185, 1),
#   (1214, 1),
#   (1228, 2),
#   (1281, 1),
#   (1294, 1),
#   (1399, 5),
#   (1503, 1),
#   (1510, 1),
#   (1511, 1),
#   (1512, 1),
#   (1513, 1),
#   (1514, 2),
#   (1515, 1),
#   (1516, 1),
#   (1517, 1),
#   (1518, 1),
#   (1519, 2),
#   (1520, 1)],
#  [(14, 2),
#   (83, 1),
#   (85, 1),
#   (88, 1),
#   (132, 1),
#   (195, 3),
#   (225, 2),
#   (320, 1),
#   (360, 1),
#   (372, 2),
#   (379, 1),
#   (434, 1),
#   (475, 1),
#   (602, 1),
#   (681, 1),
#   (703, 2),
#   (706, 2),
#   (761, 2),
#   (765, 1),
#   (814, 1),
#   (825, 1),
#   (918, 2),
#   (1002, 3),
#   (1039, 1),
#   (1094, 1),
#   (1106, 1),
#   (1140, 2),
#   (1227, 1),
#   (1387, 1),
#   (1412, 1),
#   (1521, 1),
#   (1522, 1),
#   (1523, 2),
#   (1524, 1),
#   (1525, 1),
#   (1526, 2),
#   (1527, 3),
#   (1528, 1),
#   (1529, 1),
#   (1530, 1),
#   (1531, 1),
#   (1532, 2)],
#  [(30, 1),
#   (79, 1),
#   (105, 1),
#   (111, 2),
#   (146, 1),
#   (211, 1),
#   (222, 1),
#   (377, 1),
#   (389, 4),
#   (493, 2),
#   (581, 4),
#   (610, 1),
#   (620, 1),
#   (679, 1),
#   (726, 1),
#   (973, 2),
#   (977, 2),
#   (983, 1),
#   (1093, 3),
#   (1203, 1),
#   (1369, 1),
#   (1533, 1),
#   (1534, 1),
#   (1535, 1),
#   (1536, 1),
#   (1537, 1),
#   (1538, 1),
#   (1539, 1),
#   (1540, 1),
#   (1541, 4),
#   (1542, 1),
#   (1543, 1),
#   (1544, 1),
#   (1545, 1),
#   (1546, 1),
#   (1547, 1)],
#  [(31, 1),
#   (47, 1),
#   (51, 1),
#   (70, 1),
#   (80, 1),
#   (102, 2),
#   (108, 1),
#   (132, 2),
#   (155, 3),
#   (193, 1),
#   (195, 1),
#   (199, 1),
#   (434, 1),
#   (503, 2),
#   (554, 1),
#   (562, 1),
#   (632, 2),
#   (709, 1),
#   (723, 1),
#   (771, 1),
#   (774, 1),
#   (903, 1),
#   (929, 1),
#   (1194, 1),
#   (1203, 1),
#   (1212, 1),
#   (1273, 1),
#   (1369, 1),
#   (1392, 1),
#   (1459, 1),
#   (1548, 3),
#   (1549, 1),
#   (1550, 1),
#   (1551, 1),
#   (1552, 1),
#   (1553, 1),
#   (1554, 1),
#   (1555, 1),
#   (1556, 1),
#   (1557, 1),
#   (1558, 1),
#   (1559, 3),
#   (1560, 1),
#   (1561, 1),
#   (1562, 1),
#   (1563, 1),
#   (1564, 1),
#   (1565, 1)],
#  [(47, 1),
#   (53, 1),
#   (78, 1),
#   (102, 2),
#   (126, 2),
#   (138, 1),
#   (161, 1),
#   (166, 3),
#   (173, 1),
#   (317, 2),
#   (372, 1),
#   (374, 1),
#   (377, 3),
#   (498, 1),
#   (567, 2),
#   (583, 1),
#   (605, 1),
#   (679, 3),
#   (728, 1),
#   (846, 1),
#   (930, 1),
#   (977, 1),
#   (978, 1),
#   (1027, 1),
#   (1032, 1),
#   (1093, 2),
#   (1106, 1),
#   (1107, 2),
#   (1276, 2),
#   (1543, 1),
#   (1553, 2),
#   (1566, 1),
#   (1567, 1),
#   (1568, 1),
#   (1569, 2),
#   (1570, 2),
#   (1571, 2),
#   (1572, 1),
#   (1573, 1),
#   (1574, 1),
#   (1575, 1),
#   (1576, 1),
#   (1577, 1)],
#  [(27, 1),
#   (91, 1),
#   (122, 1),
#   (126, 1),
#   (150, 1),
#   (170, 1),
#   (217, 2),
#   (292, 1),
#   (595, 1),
#   (624, 1),
#   (637, 1),
#   (658, 1),
#   (781, 1),
#   (945, 1),
#   (1015, 1),
#   (1100, 1),
#   (1184, 1),
#   (1200, 1),
#   (1269, 1),
#   (1273, 2),
#   (1470, 2),
#   (1478, 1),
#   (1501, 1),
#   (1578, 1),
#   (1579, 1),
#   (1580, 1),
#   (1581, 1),
#   (1582, 1),
#   (1583, 6),
#   (1584, 2),
#   (1585, 1),
#   (1586, 1),
#   (1587, 1),
#   (1588, 1),
#   (1589, 1),
#   (1590, 1),
#   (1591, 1),
#   (1592, 1)],
#  [(0, 2),
#   (30, 1),
#   (46, 1),
#   (53, 2),
#   (60, 1),
#   (79, 1),
#   (83, 3),
#   (85, 1),
#   (88, 1),
#   (108, 3),
#   (109, 2),
#   (124, 1),
#   (132, 1),
#   (144, 2),
#   (161, 1),
#   (167, 1),
#   (170, 1),
#   (175, 1),
#   (182, 1),
#   (195, 3),
#   (201, 1),
#   (217, 1),
#   (233, 1),
#   (287, 1),
#   (295, 1),
#   (338, 1),
#   (399, 1),
#   (420, 1),
#   (427, 1),
#   (453, 2),
#   (503, 3),
#   (510, 1),
#   (512, 1),
#   (513, 2),
#   (549, 1),
#   (562, 1),
#   (568, 1),
#   (585, 1),
#   (632, 1),
#   (634, 1),
#   (697, 1),
#   (714, 2),
#   (769, 4),
#   (782, 1),
#   (847, 1),
#   (864, 3),
#   (900, 1),
#   (910, 1),
#   (912, 1),
#   (953, 1),
#   (1059, 2),
#   (1087, 1),
#   (1144, 1),
#   (1146, 1),
#   (1273, 1),
#   (1275, 1),
#   (1276, 1),
#   (1289, 1),
#   (1290, 1),
#   (1297, 1),
#   (1421, 1),
#   (1424, 1),
#   (1554, 1),
#   (1593, 1),
#   (1594, 1),
#   (1595, 1),
#   (1596, 1),
#   (1597, 2),
#   (1598, 1),
#   (1599, 1),
#   (1600, 5),
#   (1601, 2),
#   (1602, 2),
#   (1603, 5),
#   (1604, 1),
#   (1605, 1),
#   (1606, 1),
#   (1607, 2),
#   (1608, 1),
#   (1609, 1),
#   (1610, 1),
#   (1611, 1),
#   (1612, 1),
#   (1613, 1),
#   (1614, 1),
#   (1615, 1),
#   (1616, 1),
#   (1617, 1),
#   (1618, 4),
#   (1619, 1),
#   (1620, 1),
#   (1621, 2),
#   (1622, 1),
#   (1623, 1),
#   (1624, 1),
#   (1625, 3),
#   (1626, 1),
#   (1627, 1),
#   (1628, 1),
#   (1629, 1),
#   (1630, 1),
#   (1631, 1),
#   (1632, 1),
#   (1633, 1),
#   (1634, 1),
#   (1635, 1),
#   (1636, 1),
#   (1637, 1),
#   (1638, 1),
#   (1639, 1),
#   (1640, 1),
#   (1641, 1)],
#  [(181, 1),
#   (252, 1),
#   (620, 1),
#   (803, 1),
#   (893, 1),
#   (1068, 1),
#   (1096, 1),
#   (1642, 1),
#   (1643, 1),
#   (1644, 1),
#   (1645, 1),
#   (1646, 2),
#   (1647, 1)],
#  [(80, 2),
#   (121, 1),
#   (180, 2),
#   (182, 1),
#   (246, 1),
#   (459, 3),
#   (473, 1),
#   (486, 1),
#   (493, 1),
#   (521, 2),
#   (526, 3),
#   (619, 1),
#   (635, 1),
#   (636, 4),
#   (650, 1),
#   (756, 1),
#   (789, 2),
#   (800, 2),
#   (895, 1),
#   (955, 5),
#   (1010, 1),
#   (1215, 1),
#   (1217, 1),
#   (1219, 1),
#   (1229, 1),
#   (1648, 1),
#   (1649, 1),
#   (1650, 1),
#   (1651, 2),
#   (1652, 1),
#   (1653, 1),
#   (1654, 1),
#   (1655, 3),
#   (1656, 1),
#   (1657, 1),
#   (1658, 1),
#   (1659, 2),
#   (1660, 1),
#   (1661, 1),
#   (1662, 1),
#   (1663, 2),
#   (1664, 3),
#   (1665, 1),
#   (1666, 3),
#   (1667, 2)],
#  [(57, 1),
#   (660, 1),
#   (945, 1),
#   (1054, 1),
#   (1184, 2),
#   (1227, 1),
#   (1468, 1),
#   (1476, 4),
#   (1477, 2),
#   (1580, 1),
#   (1668, 1),
#   (1669, 2),
#   (1670, 1),
#   (1671, 1)],
#  [(85, 1),
#   (99, 1),
#   (150, 1),
#   (163, 1),
#   (360, 1),
#   (587, 1),
#   (619, 1),
#   (622, 1),
#   (635, 1),
#   (638, 1),
#   (647, 1),
#   (650, 1),
#   (659, 1),
#   (660, 1),
#   (709, 1),
#   (765, 1),
#   (843, 2),
#   (1027, 1),
#   (1082, 1),
#   (1162, 1),
#   (1173, 2),
#   (1184, 1),
#   (1194, 1),
#   (1274, 1),
#   (1278, 1),
#   (1401, 1),
#   (1564, 1),
#   (1672, 1),
#   (1673, 1),
#   (1674, 1),
#   (1675, 1),
#   (1676, 1),
#   (1677, 1),
#   (1678, 1),
#   (1679, 1),
#   (1680, 1),
#   (1681, 1),
#   (1682, 1),
#   (1683, 1),
#   (1684, 3),
#   (1685, 1),
#   (1686, 2),
#   (1687, 1),
#   (1688, 1),
#   (1689, 2),
#   (1690, 1),
#   (1691, 1),
#   (1692, 1),
#   (1693, 1)],
#  [(23, 1),
#   (39, 1),
#   (42, 1),
#   (47, 3),
#   (78, 2),
#   (80, 1),
#   (86, 1),
#   (97, 2),
#   (111, 1),
#   (115, 2),
#   (138, 4),
#   (147, 1),
#   (161, 2),
#   (169, 2),
#   (185, 1),
#   (217, 1),
#   (218, 2),
#   (267, 4),
#   (298, 1),
#   (307, 1),
#   (314, 1),
#   (332, 1),
#   (365, 3),
#   (369, 1),
#   (371, 1),
#   (385, 3),
#   (388, 1),
#   (410, 1),
#   (462, 7),
#   (469, 1),
#   (471, 1),
#   (479, 2),
#   (491, 1),
#   (496, 1),
#   (554, 1),
#   (602, 1),
#   (611, 2),
#   (632, 2),
#   (670, 1),
#   (712, 1),
#   (733, 2),
#   (736, 2),
#   (737, 1),
#   (740, 1),
#   (741, 1),
#   (743, 2),
#   (744, 1),
#   (922, 1),
#   (959, 1),
#   (1022, 2),
#   (1060, 5),
#   (1215, 1),
#   (1310, 1),
#   (1694, 1),
#   (1695, 3),
#   (1696, 1),
#   (1697, 1),
#   (1698, 1),
#   (1699, 1),
#   (1700, 1),
#   (1701, 1),
#   (1702, 1),
#   (1703, 1),
#   (1704, 1),
#   (1705, 1),
#   (1706, 1),
#   (1707, 1),
#   (1708, 1),
#   (1709, 1),
#   (1710, 1),
#   (1711, 1),
#   (1712, 1),
#   (1713, 1),
#   (1714, 1),
#   (1715, 1),
#   (1716, 2),
#   (1717, 2),
#   (1718, 1),
#   (1719, 1),
#   (1720, 1),
#   (1721, 1),
#   (1722, 1),
#   (1723, 1),
#   (1724, 1),
#   (1725, 1),
#   (1726, 1),
#   (1727, 2),
#   (1728, 1),
#   (1729, 2),
#   (1730, 1),
#   (1731, 1),
#   (1732, 1),
#   (1733, 1),
#   (1734, 1),
#   (1735, 1),
#   (1736, 1),
#   (1737, 1),
#   (1738, 2),
#   (1739, 2),
#   (1740, 1),
#   (1741, 2),
#   (1742, 1),
#   (1743, 2),
#   (1744, 1),
#   (1745, 1),
#   (1746, 1),
#   (1747, 1),
#   (1748, 1),
#   (1749, 2)],
#  [(18, 3),
#   (53, 6),
#   (57, 1),
#   (80, 1),
#   (111, 1),
#   (137, 1),
#   (144, 1),
#   (169, 1),
#   (283, 5),
#   (289, 1),
#   (295, 1),
#   (300, 1),
#   (305, 1),
#   (331, 2),
#   (348, 1),
#   (390, 5),
#   (401, 1),
#   (427, 1),
#   (453, 1),
#   (498, 1),
#   (557, 1),
#   (580, 2),
#   (581, 1),
#   (693, 1),
#   (721, 1),
#   (722, 2),
#   (751, 1),
#   (804, 8),
#   (818, 4),
#   (830, 1),
#   (897, 1),
#   (910, 1),
#   (952, 2),
#   (953, 1),
#   (967, 1),
#   (1035, 1),
#   (1059, 1),
#   (1126, 1),
#   (1152, 1),
#   (1170, 1),
#   (1228, 1),
#   (1240, 2),
#   (1247, 1),
#   (1275, 1),
#   (1282, 2),
#   (1387, 1),
#   (1398, 1),
#   (1401, 1),
#   (1451, 1),
#   (1487, 1),
#   (1617, 1),
#   (1628, 1),
#   (1651, 1),
#   (1687, 1),
#   (1750, 1),
#   (1751, 1),
#   (1752, 1),
#   (1753, 1),
#   (1754, 2),
#   (1755, 3),
#   (1756, 1),
#   (1757, 1),
#   (1758, 1),
#   (1759, 8),
#   (1760, 1),
#   (1761, 1),
#   (1762, 1),
#   (1763, 2),
#   (1764, 1),
#   (1765, 3),
#   (1766, 1),
#   (1767, 1),
#   (1768, 1),
#   (1769, 1),
#   (1770, 2),
#   (1771, 1),
#   (1772, 1),
#   (1773, 1),
#   (1774, 5),
#   (1775, 1),
#   (1776, 1),
#   (1777, 2),
#   (1778, 1),
#   (1779, 3),
#   (1780, 1),
#   (1781, 2),
#   (1782, 2),
#   (1783, 1),
#   (1784, 2),
#   (1785, 1),
#   (1786, 1),
#   (1787, 1),
#   (1788, 1),
#   (1789, 1),
#   (1790, 1),
#   (1791, 1),
#   (1792, 1)],
#  [(12, 1),
#   (151, 3),
#   (173, 1),
#   (177, 2),
#   (217, 1),
#   (474, 1),
#   (717, 1),
#   (1027, 1),
#   (1121, 1),
#   (1793, 1),
#   (1794, 1),
#   (1795, 2),
#   (1796, 3),
#   (1797, 1),
#   (1798, 2),
#   (1799, 2),
#   (1800, 1),
#   (1801, 1)],
#  [(27, 1),
#   (137, 1),
#   (217, 1),
#   (342, 1),
#   (619, 1),
#   (635, 1),
#   (645, 1),
#   (647, 1),
#   (650, 1),
#   (709, 1),
#   (843, 2),
#   (1000, 1),
#   (1162, 2),
#   (1173, 1),
#   (1184, 1),
#   (1278, 1),
#   (1674, 1),
#   (1676, 2),
#   (1678, 1),
#   (1681, 1),
#   (1684, 2),
#   (1686, 3),
#   (1688, 1),
#   (1689, 1),
#   (1693, 1),
#   (1802, 1),
#   (1803, 1),
#   (1804, 1),
#   (1805, 1),
#   (1806, 2),
#   (1807, 1),
#   (1808, 1)],
#  [(10, 3),
#   (61, 1),
#   (93, 4),
#   (116, 2),
#   (118, 1),
#   (225, 1),
#   (277, 1),
#   (295, 2),
#   (322, 1),
#   (357, 1),
#   (432, 2),
#   (451, 2),
#   (473, 1),
#   (482, 1),
#   (549, 3),
#   (620, 1),
#   (647, 1),
#   (650, 2),
#   (695, 1),
#   (755, 1),
#   (966, 1),
#   (1200, 1),
#   (1293, 1),
#   (1308, 1),
#   (1394, 1),
#   (1405, 2),
#   (1414, 1),
#   (1602, 1),
#   (1639, 1),
#   (1809, 1),
#   (1810, 1),
#   (1811, 2),
#   (1812, 1),
#   (1813, 1),
#   (1814, 1),
#   (1815, 1),
#   (1816, 1),
#   (1817, 1),
#   (1818, 2),
#   (1819, 1),
#   (1820, 1),
#   (1821, 1),
#   (1822, 1)],
#  [(18, 1),
#   (39, 1),
#   (48, 1),
#   (56, 1),
#   (59, 1),
#   (60, 1),
#   (75, 1),
#   (88, 1),
#   (101, 1),
#   (172, 1),
#   (195, 1),
#   (203, 1),
#   (292, 1),
#   (354, 1),
#   (388, 1),
#   (519, 1),
#   (646, 1),
#   (653, 3),
#   (1153, 1),
#   (1217, 1),
#   (1227, 1),
#   (1278, 1),
#   (1373, 1),
#   (1444, 1),
#   (1470, 3),
#   (1478, 1),
#   (1628, 1),
#   (1809, 2),
#   (1823, 2),
#   (1824, 1),
#   (1825, 1),
#   (1826, 1),
#   (1827, 2),
#   (1828, 1),
#   (1829, 3),
#   (1830, 1),
#   (1831, 1),
#   (1832, 6),
#   (1833, 1),
#   (1834, 1),
#   (1835, 1),
#   (1836, 1),
#   (1837, 1),
#   (1838, 1),
#   (1839, 1),
#   (1840, 1)],
#  [(30, 1),
#   (60, 1),
#   (82, 1),
#   (97, 1),
#   (252, 1),
#   (455, 1),
#   (535, 1),
#   (568, 1),
#   (620, 1),
#   (866, 1),
#   (955, 1),
#   (1184, 1),
#   (1276, 1),
#   (1480, 1),
#   (1643, 1),
#   (1841, 1),
#   (1842, 1),
#   (1843, 1),
#   (1844, 1)],
#  [(49, 1),
#   (78, 3),
#   (111, 2),
#   (250, 1),
#   (253, 2),
#   (389, 1),
#   (558, 2),
#   (620, 1),
#   (710, 1),
#   (711, 1),
#   (798, 2),
#   (800, 3),
#   (932, 2),
#   (1144, 1),
#   (1267, 1),
#   (1276, 1),
#   (1278, 2),
#   (1285, 1),
#   (1308, 1),
#   (1364, 1),
#   (1372, 1),
#   (1539, 1),
#   (1582, 2),
#   (1638, 2),
#   (1699, 1),
#   (1701, 1),
#   (1845, 1),
#   (1846, 1),
#   (1847, 2),
#   (1848, 1),
#   (1849, 2),
#   (1850, 1),
#   (1851, 1),
#   (1852, 2)],
#  [(49, 1),
#   (51, 1),
#   (59, 1),
#   (83, 2),
#   (93, 1),
#   (102, 1),
#   (138, 2),
#   (146, 1),
#   (164, 1),
#   (264, 2),
#   (281, 2),
#   (315, 1),
#   (317, 2),
#   (331, 1),
#   (343, 2),
#   (348, 1),
#   (349, 1),
#   (355, 1),
#   (434, 1),
#   (498, 1),
#   (867, 1),
#   (881, 1),
#   (890, 1),
#   (894, 1),
#   (904, 1),
#   (1113, 1),
#   (1459, 2),
#   (1557, 1),
#   (1609, 1),
#   (1705, 1),
#   (1853, 1),
#   (1854, 1),
#   (1855, 1),
#   (1856, 1),
#   (1857, 3),
#   (1858, 1),
#   (1859, 1),
#   (1860, 1),
#   (1861, 1),
#   (1862, 1),
#   (1863, 1),
#   (1864, 2),
#   (1865, 1),
#   (1866, 2),
#   (1867, 1),
#   (1868, 1)],
#  [(11, 2),
#   (86, 2),
#   (773, 2),
#   (786, 2),
#   (892, 2),
#   (971, 6),
#   (1006, 3),
#   (1028, 2),
#   (1084, 2),
#   (1122, 2),
#   (1129, 2),
#   (1247, 2),
#   (1448, 2),
#   (1451, 2),
#   (1869, 2),
#   (1870, 2),
#   (1871, 2),
#   (1872, 2),
#   (1873, 2)],
#  [(9, 1),
#   (82, 1),
#   (132, 1),
#   (190, 1),
#   (191, 1),
#   (305, 1),
#   (423, 1),
#   (507, 1),
#   (556, 1),
#   (753, 1),
#   (994, 1),
#   (1054, 1),
#   (1063, 2),
#   (1184, 4),
#   (1282, 1),
#   (1286, 1),
#   (1588, 1),
#   (1629, 1),
#   (1874, 1),
#   (1875, 1),
#   (1876, 2),
#   (1877, 2),
#   (1878, 1),
#   (1879, 1)],
#  [(18, 1),
#   (116, 1),
#   (295, 1),
#   (343, 1),
#   (459, 1),
#   (650, 1),
#   (925, 1),
#   (1278, 1),
#   (1880, 3),
#   (1881, 1),
#   (1882, 1),
#   (1883, 1),
#   (1884, 1),
#   (1885, 1),
#   (1886, 1),
#   (1887, 1)],
#  [(888, 1), (955, 1), (1839, 1), (1888, 1), (1889, 1)],
#  [(102, 1),
#   (111, 1),
#   (115, 4),
#   (121, 3),
#   (169, 1),
#   (368, 1),
#   (371, 1),
#   (463, 2),
#   (728, 1),
#   (838, 1),
#   (841, 5),
#   (881, 1),
#   (1060, 6),
#   (1113, 1),
#   (1544, 3),
#   (1845, 4),
#   (1890, 1),
#   (1891, 1),
#   (1892, 4),
#   (1893, 3),
#   (1894, 1),
#   (1895, 1),
#   (1896, 1),
#   (1897, 1),
#   (1898, 1),
#   (1899, 1),
#   (1900, 1),
#   (1901, 5)],
#  [(173, 1),
#   (219, 4),
#   (233, 1),
#   (295, 1),
#   (383, 1),
#   (410, 3),
#   (434, 1),
#   (484, 1),
#   (498, 1),
#   (535, 1),
#   (599, 2),
#   (656, 4),
#   (687, 1),
#   (867, 1),
#   (900, 1),
#   (942, 1),
#   (1111, 2),
#   (1169, 1),
#   (1612, 1),
#   (1902, 1),
#   (1903, 1),
#   (1904, 1),
#   (1905, 1),
#   (1906, 1),
#   (1907, 1),
#   (1908, 1),
#   (1909, 1),
#   (1910, 2),
#   (1911, 1),
#   (1912, 2),
#   (1913, 1),
#   (1914, 1),
#   (1915, 1),
#   (1916, 1),
#   (1917, 1),
#   (1918, 1)],
#  [(53, 1),
#   (169, 1),
#   (179, 1),
#   (233, 1),
#   (246, 3),
#   (248, 3),
#   (290, 1),
#   (298, 2),
#   (300, 2),
#   (320, 3),
#   (331, 1),
#   (332, 1),
#   (371, 1),
#   (372, 1),
#   (376, 7),
#   (377, 12),
#   (379, 7),
#   (381, 1),
#   (384, 3),
#   (386, 2),
#   (388, 11),
#   (554, 2),
#   (829, 1),
#   (942, 1),
#   (950, 2),
#   (1064, 3),
#   (1426, 1),
#   (1545, 4),
#   (1765, 2),
#   (1804, 1),
#   (1878, 1),
#   (1919, 1),
#   (1920, 1),
#   (1921, 1),
#   (1922, 1),
#   (1923, 1),
#   (1924, 1),
#   (1925, 1),
#   (1926, 1),
#   (1927, 8),
#   (1928, 1),
#   (1929, 2),
#   (1930, 1),
#   (1931, 1),
#   (1932, 1),
#   (1933, 1),
#   (1934, 1),
#   (1935, 1),
#   (1936, 2),
#   (1937, 3),
#   (1938, 2),
#   (1939, 1),
#   (1940, 1)],
#  [(78, 1),
#   (102, 5),
#   (109, 2),
#   (144, 1),
#   (145, 1),
#   (147, 1),
#   (181, 1),
#   (204, 1),
#   (222, 2),
#   (295, 1),
#   (332, 1),
#   (383, 1),
#   (464, 1),
#   (498, 1),
#   (503, 1),
#   (580, 1),
#   (610, 1),
#   (620, 1),
#   (768, 1),
#   (800, 6),
#   (821, 1),
#   (835, 1),
#   (903, 1),
#   (1027, 1),
#   (1125, 1),
#   (1164, 1),
#   (1217, 1),
#   (1364, 1),
#   (1582, 3),
#   (1845, 3),
#   (1941, 5),
#   (1942, 3),
#   (1943, 4),
#   (1944, 1),
#   (1945, 3),
#   (1946, 2),
#   (1947, 1)],
#  [(10, 1),
#   (27, 1),
#   (105, 1),
#   (138, 1),
#   (172, 1),
#   (204, 1),
#   (211, 2),
#   (212, 2),
#   (215, 1),
#   (219, 2),
#   (228, 2),
#   (229, 1),
#   (231, 1),
#   (233, 1),
#   (243, 1),
#   (246, 1),
#   (249, 1),
#   (261, 5),
#   (264, 1),
#   (267, 4),
#   (269, 6),
#   (270, 1),
#   (275, 1),
#   (281, 1),
#   (314, 1),
#   (316, 1),
#   (371, 1),
#   (372, 2),
#   (400, 1),
#   (412, 1),
#   (477, 1),
#   (482, 1),
#   (497, 1),
#   (554, 1),
#   (571, 1),
#   (673, 2),
#   (679, 1),
#   (714, 2),
#   (722, 1),
#   (788, 1),
#   (802, 1),
#   (806, 1),
#   (841, 1),
#   (886, 2),
#   (898, 2),
#   (900, 1),
#   (911, 1),
#   (927, 1),
#   (1027, 1),
#   (1119, 1),
#   (1125, 1),
#   (1362, 1),
#   (1364, 2),
#   (1385, 2),
#   (1533, 1),
#   (1556, 1),
#   (1899, 1),
#   (1945, 2),
#   (1948, 1),
#   (1949, 1),
#   (1950, 1),
#   (1951, 1),
#   (1952, 1),
#   (1953, 1),
#   (1954, 1),
#   (1955, 1),
#   (1956, 2),
#   (1957, 1),
#   (1958, 1),
#   (1959, 1),
#   (1960, 1),
#   (1961, 1),
# ...
#   (2467, 1),
#   (2500, 1),
#   (2543, 4),
#   (2555, 1),
#   (2602, 1),
#   (2646, 2),
#   (2674, 1),
#   (2741, 1),
#   (2801, 1),
#   (2837, 1),
#   (2863, 1),
#   (2931, 1),
#   (2995, 1),
#   (3008, 2),
#   (3010, 1),
#   (3022, 1),
#   (3030, 1),
#   (3032, 1),
#   (3046, 1),
#   (3091, 1),
#   (3106, 1),
#   (3114, 1),
#   (3151, 1),
#   (3194, 1),
#   (3202, 1),
#   (3265, 1),
#   (3310, 2),
#   (3311, 1),
#   (3342, 1),
#   (3455, 1),
#   (3457, 1),
#   (3496, 1),
#   (3506, 1),
#   (3514, 1),
#   (3520, 1),
#   (3542, 1),
#   (3547, 6),
#   (3562, 6),
#   (3566, 3),
#   (3571, 1),
#   (3575, 1),
#   (3579, 1),
#   (3582, 6),
#   (3643, 1),
#   (3648, 1),
#   (3722, 1),
#   (3773, 1),
#   (3777, 1),
#   (3778, 1),
#   (3780, 1),
#   (3786, 2),
#   (3787, 1),
#   (3789, 1),
#   (3790, 2),
#   (3798, 1),
#   (3867, 1),
#   (3913, 1),
#   (3938, 1),
#   (4015, 2),
#   (4113, 1),
#   (4143, 1),
#   (4157, 1),
#   (4224, 1),
#   (4231, 1),
#   (4280, 1),
#   (4350, 1),
#   (4361, 1),
#   (4362, 1),
#   (4415, 2),
#   (4430, 1),
#   (4441, 1),
#   (4456, 1),
#   (4471, 1),
#   (4593, 1),
#   (4706, 1),
#   (4710, 1),
#   (4734, 1),
#   (4736, 1),
#   (4740, 1),
#   (4745, 1),
#   (4772, 2),
#   (5004, 1),
#   (5012, 1),
#   (5020, 1),
#   (5021, 1),
#   (5022, 1),
#   (5023, 1),
#   (5024, 1),
#   (5025, 1),
#   (5026, 1),
#   (5027, 2),
#   (5028, 1),
#   (5029, 1),
#   (5030, 2),
#   (5031, 1),
#   (5032, 1),
#   (5033, 1),
#   (5034, 1),
#   (5035, 1)],
#  [(21, 1),
#   (44, 1),
#   (70, 1),
#   (78, 1),
#   (105, 3),
#   (121, 1),
#   (146, 1),
#   (222, 4),
#   (309, 1),
#   (398, 1),
#   (405, 2),
#   (498, 1),
#   (522, 1),
#   (695, 1),
#   (714, 1),
#   (765, 1),
#   (803, 1),
#   (900, 1),
#   (1119, 1),
#   (1381, 1),
#   (1608, 1),
#   (1620, 1),
#   (1654, 1),
#   (2649, 1),
#   (2721, 1),
#   (3642, 1),
#   (3708, 1),
#   (5036, 1)],
#  [(2, 1),
#   (14, 1),
#   (18, 3),
#   (48, 1),
#   (51, 1),
#   (53, 1),
#   (60, 1),
#   (88, 1),
#   (91, 1),
#   (93, 3),
#   (94, 1),
#   (114, 1),
#   (131, 1),
#   (132, 1),
#   (217, 1),
#   (290, 1),
#   (397, 1),
#   (427, 1),
#   (428, 1),
#   (431, 1),
#   (503, 2),
#   (520, 3),
#   (532, 1),
#   (545, 1),
#   (564, 1),
#   (585, 1),
#   (595, 1),
#   (630, 1),
#   (697, 2),
#   (769, 1),
#   (776, 1),
#   (864, 1),
#   (938, 2),
#   (953, 1),
#   (959, 1),
#   (994, 1),
#   (1289, 1),
#   (1297, 1),
#   (1733, 1),
#   (1982, 2),
#   (2023, 2),
#   (2029, 1),
#   (2055, 1),
#   (2123, 1),
#   (2238, 1),
#   (2330, 1),
#   (2393, 2),
#   (2544, 1),
#   (3369, 5),
#   (3371, 1),
#   (3426, 1),
#   (3976, 1)],
#  [(107, 1),
#   (177, 2),
#   (441, 1),
#   (450, 1),
#   (455, 1),
#   (637, 1),
#   (643, 1),
#   (644, 3),
#   (646, 1),
#   (705, 1),
#   (1096, 1),
#   (1124, 1),
#   (1470, 1),
#   (1675, 1),
#   (2530, 1),
#   (2797, 1),
#   (3438, 1),
#   (4290, 1)],
#  [(2, 1),
#   (30, 1),
#   (53, 3),
#   (59, 1),
#   (60, 1),
#   (72, 1),
#   (83, 2),
#   (84, 1),
#   (114, 1),
#   (131, 1),
#   (290, 1),
#   (428, 1),
#   (487, 1),
#   (503, 2),
#   (520, 2),
#   (532, 1),
#   (545, 1),
#   (563, 1),
#   (564, 1),
#   (660, 1),
#   (663, 1),
#   (769, 2),
#   (953, 3),
#   (966, 1),
#   (1297, 1),
#   (1564, 1),
#   (1673, 1),
#   (1733, 1),
#   (1799, 1),
#   (1982, 1),
#   (2023, 1),
#   (2122, 1),
#   (3301, 1),
#   (3369, 6)],
#  [(7, 2),
#   (40, 1),
#   (43, 1),
#   (88, 1),
#   (90, 1),
#   (116, 2),
#   (118, 1),
#   (120, 1),
#   (182, 1),
#   (183, 1),
#   (185, 1),
#   (186, 1),
#   (202, 1),
#   (397, 1),
#   (430, 3),
#   (519, 1),
#   (520, 2),
#   (565, 1),
#   (581, 1),
#   (582, 3),
#   (665, 2),
#   (797, 1),
#   (798, 2),
#   (818, 1),
#   (864, 2),
#   (925, 3),
#   (983, 1),
#   (1113, 1),
#   (1483, 1),
#   (1552, 2),
#   (1687, 1),
#   (1819, 2),
#   (1820, 1),
#   (1830, 1),
#   (1836, 1),
#   (1839, 1),
#   (1909, 1),
#   (1979, 1),
#   (2049, 2),
#   (2053, 1),
#   (2058, 2),
#   (2073, 1),
#   (2362, 1),
#   (2714, 1),
#   (2807, 1),
#   (3328, 1),
#   (3809, 1),
#   (4037, 1),
#   (4119, 1),
#   (4320, 1),
#   (4417, 1)],
#  [(109, 1), (295, 1), (1060, 1), (1392, 1), (1839, 1), (1981, 1), (2035, 1)],
#  [(39, 1),
#   (101, 2),
#   (122, 2),
#   (131, 1),
#   (304, 1),
#   (315, 1),
#   (412, 1),
#   (656, 1),
#   (803, 1),
#   (813, 1),
#   (940, 1),
#   (1028, 1),
#   (1054, 1),
#   (1059, 1),
#   (1278, 1),
#   (1308, 1),
#   (1387, 1),
#   (1426, 1),
#   (1872, 1),
#   (2316, 1),
#   (2643, 1),
#   (3346, 1),
#   (4299, 1),
#   (4303, 2),
#   (4460, 1),
#   (4736, 1),
#   (5033, 1),
#   (5037, 1),
#   (5038, 1),
#   (5039, 1)],
#  [(80, 1),
#   (88, 1),
#   (109, 1),
#   (185, 2),
#   (277, 1),
#   (329, 1),
#   (391, 1),
#   (397, 2),
#   (428, 2),
#   (430, 1),
#   (434, 1),
#   (505, 2),
#   (570, 2),
#   (582, 1),
#   (663, 2),
#   (1124, 1),
#   (1133, 2),
#   (1195, 1),
#   (1267, 1),
#   (1819, 1),
#   (1839, 1),
#   (2034, 1),
#   (2035, 1),
#   (2402, 2),
#   (2680, 1),
#   (2801, 1),
#   (2808, 1),
#   (2836, 1),
#   (3339, 1),
#   (3960, 1)],
#  [(76, 1),
#   (83, 2),
#   (93, 2),
#   (116, 2),
#   (122, 1),
#   (137, 1),
#   (198, 1),
#   (304, 1),
#   (305, 1),
#   (313, 2),
#   (441, 1),
#   (545, 1),
#   (547, 1),
#   (556, 1),
#   (630, 1),
#   (642, 1),
#   (660, 1),
#   (699, 1),
#   (711, 1),
#   (769, 1),
#   (771, 1),
#   (775, 1),
#   (803, 1),
#   (809, 2),
#   (812, 1),
#   (814, 2),
#   (864, 1),
#   (880, 1),
#   (934, 1),
#   (1113, 1),
#   (1154, 2),
#   (1194, 1),
#   (1267, 1),
#   (1275, 1),
#   (1297, 2),
#   (1400, 1),
#   (1819, 1),
#   (1839, 1),
#   (2018, 1),
#   (2053, 2),
#   (2169, 1),
#   (2193, 1),
#   (2238, 1),
#   (2323, 2),
#   (2928, 1),
#   (3378, 1),
#   (3556, 1),
#   (3836, 2),
#   (4068, 1),
#   (4942, 1),
#   (5039, 1)],
#  [(46, 1),
#   (47, 2),
#   (88, 1),
#   (96, 1),
#   (181, 1),
#   (185, 1),
#   (187, 1),
#   (195, 2),
#   (320, 2),
#   (371, 2),
#   (397, 1),
#   (504, 1),
#   (505, 1),
#   (570, 1),
#   (723, 1),
#   (814, 1),
#   (825, 1),
#   (1295, 1),
#   (1816, 1),
#   (1981, 1),
#   (2034, 2),
#   (2035, 1),
#   (2118, 1),
#   (2321, 1),
#   (2753, 1),
#   (3926, 2),
#   (5040, 1)],
#  [(53, 1),
#   (60, 1),
#   (108, 1),
#   (122, 1),
#   (126, 1),
#   (133, 1),
#   (135, 1),
#   (138, 1),
#   (141, 1),
#   (148, 1),
#   (154, 4),
#   (157, 1),
#   (160, 1),
#   (168, 1),
#   (169, 1),
#   (418, 1),
#   (488, 1),
#   (503, 1),
#   (568, 1),
#   (620, 1),
#   (709, 1),
#   (813, 2),
#   (1005, 2),
#   (1278, 1),
#   (1282, 1),
#   (2769, 1),
#   (4573, 1),
#   (5041, 1)],
#  [(4, 1),
#   (137, 1),
#   (175, 1),
#   (180, 1),
#   (257, 2),
#   (266, 1),
#   (484, 1),
#   (498, 1),
#   (504, 1),
#   (539, 2),
#   (756, 1),
#   (785, 1),
#   (892, 2),
#   (894, 1),
#   (901, 3),
#   (926, 1),
#   (951, 1),
#   (956, 1),
#   (967, 1),
#   (986, 1),
#   (1060, 3),
#   (1123, 1),
#   (1215, 3),
#   (1216, 1),
#   (1894, 1),
#   (2098, 2),
#   (2417, 1),
#   (2822, 1),
#   (2823, 5),
#   (2825, 1),
#   (3003, 1),
#   (3029, 1),
#   (3160, 1),
#   (3266, 1),
#   (3555, 1),
#   (3578, 1),
#   (3684, 1),
#   (3686, 1),
#   (3689, 1),
#   (3690, 1),
#   (3981, 1),
#   (4191, 1),
#   (4675, 1),
#   (5042, 1),
#   (5043, 1)],
#  [(656, 1), (1110, 1), (1111, 1), (1112, 1), (1113, 1), (1114, 1)],
#  [(107, 1),
#   (122, 1),
#   (174, 1),
#   (217, 1),
#   (239, 5),
#   (264, 4),
#   (268, 1),
#   (438, 4),
#   (441, 1),
#   (444, 1),
#   (451, 1),
#   (454, 7),
#   (652, 1),
#   (768, 1),
#   (773, 1),
#   (788, 2),
#   (996, 1),
#   (1079, 1),
#   (1128, 3),
#   (1179, 1),
#   (1235, 2),
#   (1382, 2),
#   (1499, 1),
#   (1530, 4),
#   (1544, 4),
#   (1782, 3),
#   (2000, 1),
#   (2492, 2),
#   (2591, 1),
#   (2969, 1),
#   (3836, 1),
#   (5019, 1),
#   (5039, 1),
#   (5044, 4)],
#  [(338, 1),
#   (464, 1),
#   (526, 3),
#   (678, 1),
#   (710, 1),
#   (725, 1),
#   (867, 1),
#   (868, 1),
#   (904, 1),
#   (955, 1),
#   (967, 1),
#   (1255, 1),
#   (1342, 1),
#   (2016, 2),
#   (3629, 2),
#   (4923, 1),
#   (5045, 2)],
#  [(126, 1),
#   (556, 1),
#   (596, 2),
#   (619, 1),
#   (635, 1),
#   (709, 1),
#   (752, 1),
#   (842, 3),
#   (843, 2),
#   (1082, 1),
#   (1475, 1),
#   (1501, 1),
#   (1644, 4),
#   (1676, 1),
#   (1689, 1),
#   (1775, 1),
#   (3655, 1)],
#  [(7, 1),
#   (59, 1),
#   (107, 1),
#   (115, 2),
#   (148, 1),
#   (167, 1),
#   (411, 1),
#   (441, 1),
#   (462, 1),
#   (558, 1),
#   (611, 1),
#   (765, 1),
#   (835, 1),
#   (1104, 1),
#   (1153, 1),
#   (1267, 1),
#   (1278, 1),
#   (1888, 1),
#   (2381, 1),
#   (3103, 1),
#   (3266, 1),
#   (4556, 1)],
#  [(25, 1),
#   (35, 1),
#   (78, 3),
#   (146, 1),
#   (204, 1),
#   (222, 3),
#   (233, 1),
#   (289, 1),
#   (297, 1),
#   (300, 2),
#   (310, 1),
#   (315, 1),
#   (317, 2),
#   (343, 2),
#   (345, 1),
#   (348, 1),
#   (349, 2),
#   (355, 2),
#   (357, 1),
#   (358, 1),
#   (360, 1),
#   (363, 2),
#   (364, 1),
#   (384, 1),
#   (385, 3),
#   (407, 2),
#   (574, 1),
#   (582, 1),
#   (650, 1),
#   (784, 1),
#   (789, 1),
#   (908, 1),
#   (951, 1),
#   (957, 2),
#   (1003, 3),
#   (1042, 1),
#   (1060, 1),
#   (1074, 1),
#   (1240, 1),
#   (1364, 2),
#   (1369, 1),
#   (1372, 2),
#   (1653, 1),
#   (1701, 1),
#   (1785, 1),
#   (1788, 1),
#   (1882, 1),
#   (1921, 1),
#   (1928, 1),
#   (1987, 1),
#   (2194, 1),
#   (2225, 2),
#   (2525, 1),
#   (2546, 1),
#   (2596, 2),
#   (2687, 1),
#   (3124, 1),
#   (3126, 2),
#   (3141, 2),
#   (3154, 1),
#   (3159, 1),
#   (3168, 1),
#   (3227, 1),
#   (3283, 1),
#   (3439, 1),
#   (3480, 2),
#   (3723, 2),
#   (3762, 2),
#   (3820, 2),
#   (3960, 2),
#   (4448, 1),
#   (5046, 1),
#   (5047, 4),
#   (5048, 1),
#   (5049, 1),
#   (5050, 1),
#   (5051, 2)],
#  [(83, 1),
#   (88, 1),
#   (96, 1),
#   (108, 1),
#   (109, 1),
#   (116, 2),
#   (143, 2),
#   (193, 2),
#   (329, 2),
#   (503, 1),
#   (509, 2),
#   (510, 1),
#   (580, 2),
#   (809, 1),
#   (814, 1),
#   (825, 1),
#   (1038, 1),
#   (1116, 1),
#   (1155, 1),
#   (1185, 3),
#   (1556, 1),
#   (1602, 1),
#   (1791, 1),
#   (1875, 1),
#   (1980, 1),
#   (2019, 1),
#   (2021, 1),
#   (2023, 1),
#   (2075, 2),
#   (2238, 1),
#   (2250, 1),
#   (3083, 1),
#   (3276, 1),
#   (3382, 1),
#   (3544, 1),
#   (3572, 1),
#   (4202, 1),
#   (4964, 2),
#   (5052, 2)],
#  [(137, 1),
#   (172, 1),
#   (190, 1),
#   (192, 1),
#   (250, 1),
#   (712, 1),
#   (776, 1),
#   (785, 1),
#   (1058, 1),
#   (1165, 1),
#   (1184, 1),
#   (1738, 1),
#   (2362, 1),
#   (4489, 1),
#   (4524, 2)],
#  [(9, 1),
#   (26, 1),
#   (77, 2),
#   (150, 1),
#   (179, 2),
#   (180, 1),
#   (184, 4),
#   (195, 1),
#   (196, 1),
#   (412, 1),
#   (634, 1),
#   (770, 4),
#   (800, 1),
#   (865, 1),
#   (932, 1),
#   (1104, 1),
#   (1242, 5),
#   (1243, 2),
#   (1502, 1),
#   (1569, 1),
#   (1570, 1),
#   (1574, 1),
#   (1595, 1),
#   (1836, 2),
#   (1928, 1),
#   (1944, 2),
#   (1947, 1),
#   (2050, 1),
#   (2093, 1),
#   (2283, 1),
#   (2305, 3),
#   (2496, 1),
#   (2571, 1),
#   (2582, 1),
#   (2587, 1),
#   (2802, 1),
#   (2936, 1),
#   (3238, 1),
#   (4812, 1)],
#  [(111, 1),
#   (121, 1),
#   (138, 1),
#   (161, 1),
#   (164, 3),
#   (175, 1),
#   (204, 1),
#   (215, 2),
#   (301, 1),
#   (303, 3),
#   (353, 1),
#   (372, 4),
#   (438, 1),
#   (512, 1),
#   (663, 2),
#   (696, 2),
#   (723, 1),
#   (769, 1),
#   (867, 3),
#   (880, 1),
#   (905, 1),
#   (955, 1),
#   (1133, 1),
#   (1413, 1),
#   (1732, 1),
#   (1787, 3),
#   (1819, 1),
#   (1850, 1),
#   (2185, 3),
#   (2210, 1),
#   (2357, 1),
#   (2734, 1),
#   (2745, 1),
#   (2772, 2),
#   (2928, 1),
#   (3366, 1),
#   (3763, 1),
#   (3872, 2),
#   (4198, 1),
#   (4207, 2),
#   (4291, 3),
#   (4964, 1),
#   (5053, 2),
#   (5054, 1)],
#  [(619, 1), (635, 1), (843, 2), (1689, 1), (5055, 2)],
#  [(9, 1),
#   (21, 1),
#   (60, 1),
#   (83, 1),
#   (93, 1),
#   (95, 1),
#   (123, 1),
#   (146, 5),
#   (148, 1),
#   (159, 1),
#   (172, 1),
#   (173, 1),
#   (222, 1),
#   (293, 1),
#   (327, 1),
#   (339, 2),
#   (343, 2),
#   (344, 2),
#   (360, 1),
#   (402, 1),
#   (549, 1),
#   (574, 1),
#   (667, 2),
#   (835, 1),
#   (847, 1),
#   (925, 1),
#   (977, 1),
#   (1038, 1),
#   (1174, 1),
#   (1265, 1),
#   (1290, 1),
#   (1364, 1),
#   (1369, 1),
#   (1400, 2),
#   (1556, 1),
#   (1928, 1),
#   (1939, 1),
#   (2011, 1),
#   (2115, 1),
#   (2154, 1),
#   (2210, 1),
#   (2238, 2),
#   (2260, 1),
#   (2323, 1),
#   (2328, 1),
#   (2468, 1),
#   (2839, 1),
#   (2962, 1),
#   (3198, 1),
#   (3550, 1),
#   (3609, 1),
#   (3873, 1),
#   (3960, 1),
#   (4092, 1),
#   (4270, 1),
#   (4429, 1),
#   (5056, 1),
#   (5057, 2),
#   (5058, 1)],
#  [(27, 1),
#   (39, 1),
#   (43, 1),
#   (135, 1),
#   (138, 3),
#   (172, 1),
#   (179, 1),
#   (213, 2),
#   (224, 1),
#   (236, 1),
#   (257, 2),
#   (314, 1),
#   (316, 1),
#   (459, 2),
#   (465, 2),
#   (471, 1),
#   (478, 2),
#   (480, 1),
#   (484, 1),
#   (486, 1),
#   (491, 1),
#   (556, 1),
#   (673, 1),
#   (823, 1),
#   (836, 1),
#   (886, 1),
#   (898, 2),
#   (959, 1),
#   (970, 1),
#   (996, 1),
#   (1183, 1),
#   (1426, 1),
#   (1549, 1),
#   (1553, 1),
#   (1567, 1),
#   (1716, 1),
#   (1854, 1),
#   (1939, 1),
#   (1959, 1),
#   (2090, 1),
#   (2369, 2),
#   (2584, 1),
#   (2767, 1),
#   (2912, 2),
#   (3471, 2),
#   (3475, 2),
#   (3550, 1),
#   (3835, 1),
#   (3865, 1),
#   (3962, 1),
#   (4145, 1),
#   (4320, 1),
#   (5059, 1),
#   (5060, 1)],
#  [(86, 1),
#   (111, 1),
#   (193, 1),
#   (214, 2),
#   (268, 1),
#   (403, 1),
#   (474, 1),
#   (486, 3),
#   (532, 1),
#   (576, 1),
#   (615, 1),
#   (640, 1),
#   (679, 1),
#   (680, 1),
#   (693, 1),
#   (703, 1),
#   (709, 3),
#   (715, 2),
#   (720, 2),
#   (722, 2),
#   (860, 1),
#   (868, 2),
#   (869, 1),
#   (875, 1),
#   (879, 1),
#   (894, 1),
#   (897, 1),
#   (902, 1),
#   (920, 1),
#   (962, 2),
#   (1035, 1),
#   (1209, 1),
#   (1210, 6),
#   (1213, 2),
#   (1215, 1),
#   (1216, 1),
#   (1221, 2),
#   (1225, 1),
#   (1313, 1),
#   (1466, 2),
#   (1628, 2),
#   (1633, 1),
#   (1778, 1),
#   (1788, 1),
#   (1869, 1),
#   (2198, 1),
#   (2200, 1),
#   (2208, 1),
#   (2210, 1),
#   (2211, 1),
#   (2213, 1),
#   (2267, 1),
#   (2386, 2),
#   (2417, 1),
#   (2729, 1),
#   (2971, 1),
#   (3558, 1),
#   (3561, 1),
#   (4740, 1),
#   (5061, 1)],
#  [(85, 1),
#   (99, 1),
#   (150, 1),
#   (163, 1),
#   (360, 1),
#   (587, 1),
#   (619, 1),
#   (622, 1),
#   (635, 1),
#   (638, 1),
#   (647, 1),
#   (650, 1),
#   (659, 1),
#   (660, 1),
#   (709, 1),
#   (765, 1),
#   (843, 2),
#   (1027, 1),
#   (1082, 1),
#   (1162, 1),
#   (1173, 2),
#   (1184, 1),
#   (1194, 1),
#   (1274, 1),
#   (1278, 1),
#   (1401, 1),
#   (1564, 1),
#   (1672, 1),
#   (1673, 1),
#   (1674, 1),
#   (1675, 1),
#   (1676, 1),
#   (1677, 1),
#   (1678, 1),
#   (1679, 1),
#   (1680, 1),
#   (1681, 1),
#   (1682, 1),
#   (1683, 1),
#   (1684, 3),
#   (1686, 2),
#   (1687, 1),
#   (1688, 1),
#   (1689, 1),
#   (1690, 1),
#   (1691, 1),
#   (1692, 1),
#   (1693, 1)],
#  [(18, 1),
#   (30, 1),
#   (51, 1),
#   (56, 1),
#   (60, 1),
#   (79, 1),
#   (111, 3),
#   (166, 1),
#   (172, 1),
#   (203, 1),
#   (211, 1),
#   (258, 1),
#   (340, 1),
#   (557, 1),
#   (570, 1),
#   (581, 4),
#   (625, 1),
#   (626, 2),
#   (632, 1),
#   (723, 4),
#   (881, 1),
#   (937, 3),
#   (1038, 1),
#   (1106, 1),
#   (1165, 1),
#   (1305, 1),
#   (1567, 3),
#   (1770, 1),
#   (1885, 1),
#   (1981, 2),
#   (1998, 1),
#   (2066, 1),
#   (2075, 1),
#   (2082, 1),
#   (2122, 1),
#   (2226, 1),
#   (2305, 1),
#   (2576, 2),
#   (2827, 1),
#   (2883, 3),
#   (2884, 2),
#   (3096, 1),
#   (3767, 1),
#   (3923, 2),
#   (4965, 2),
#   (5062, 1)],
#  [(51, 1),
#   (219, 1),
#   (257, 2),
#   (263, 1),
#   (269, 1),
#   (285, 1),
#   (371, 1),
#   (475, 1),
#   (781, 1),
#   (878, 1),
#   (958, 2),
#   (1107, 1),
#   (1191, 1),
#   (1465, 1),
#   (1500, 3),
#   (1602, 2),
#   (1864, 1),
#   (1866, 1),
#   (2051, 2),
#   (2154, 1),
#   (3422, 1),
#   (3486, 1),
#   (4185, 1),
#   (4434, 1),
#   (4546, 1),
#   (4864, 2),
#   (5063, 5)],
#  [(187, 1), (520, 1), (595, 1), (774, 1)],
#  [(83, 1),
#   (97, 1),
#   (119, 1),
#   (121, 1),
#   (122, 1),
#   (230, 2),
#   (317, 1),
#   (457, 3),
#   (499, 1),
#   (689, 1),
#   (781, 1),
#   (836, 1),
#   (910, 1),
#   (932, 1),
#   (945, 1),
#   (1089, 1),
#   (1093, 1),
#   (1541, 1),
#   (1591, 1),
#   (1924, 1),
#   (1925, 1),
#   (2055, 1),
#   (2088, 1),
#   (2154, 1),
#   (2664, 1),
#   (3355, 1),
#   (5064, 1),
#   (5065, 1)],
#  [(1096, 1), (2160, 1), (4695, 2)],
#  [(748, 1), (1392, 1), (2034, 1), (2402, 1)],
#  [(536, 1), (661, 1), (679, 1), (1006, 1), (1450, 1), (1487, 1), (3991, 1)],
#  [(5, 1), (1278, 1), (2170, 1), (2627, 1), (2819, 1), (2995, 1), (3237, 1)],
#  [(717, 1), (2229, 1), (2771, 1), (4709, 1)],
#  [(1657, 1), (4574, 1)],
#  [(222, 1), (608, 1), (612, 1), (1093, 1), (2722, 1), (5066, 1)],
#  [(416, 2),
#   (1164, 1),
#   (1174, 1),
#   (2305, 1),
#   (2642, 1),
#   (2643, 1),
#   (2649, 1),
#   (2747, 1),
#   (4274, 1)],
#  [(6, 1),
#   (78, 1),
#   (109, 1),
#   (155, 2),
#   (1392, 1),
#   (1839, 1),
#   (2005, 1),
#   (2593, 1),
#   (3011, 1),
#   (4950, 1)],
#  [(463, 1), (497, 1), (1959, 1), (4308, 1), (4654, 1)],
#  [(87, 1), (173, 1), (1121, 1), (5067, 1)],
#  [(317, 1),
#   (331, 1),
#   (362, 1),
#   (385, 2),
#   (910, 1),
#   (1372, 1),
#   (1924, 1),
#   (1935, 1),
#   (2266, 1),
#   (2525, 1),
#   (3399, 1),
#   (3401, 1),
#   (5068, 1),
#   (5069, 1),
#   (5070, 1)],
#  [(138, 2),
#   (260, 1),
#   (1003, 2),
#   (1064, 1),
#   (1362, 1),
#   (1866, 2),
#   (1892, 1),
#   (1952, 1),
#   (1962, 2),
#   (2624, 1),
#   (2708, 2),
#   (2848, 1),
#   (3077, 1),
#   (4029, 1),
#   (5071, 2),
#   (5072, 1)],
#  [(51, 1),
#   (55, 1),
#   (59, 1),
#   (93, 1),
#   (96, 1),
#   (97, 1),
#   (119, 2),
#   (126, 1),
#   (143, 1),
#   (146, 1),
#   (148, 1),
#   (159, 2),
#   (195, 1),
#   (223, 1),
#   (232, 1),
#   (240, 1),
#   (295, 1),
#   (341, 1),
#   (518, 1),
#   (612, 1),
#   (732, 1),
#   (868, 1),
#   (985, 1),
#   (1003, 1),
#   (1032, 1),
#   (1101, 1),
#   (1104, 1),
#   (1247, 1),
#   (1364, 1),
#   (1372, 3),
#   (1552, 1),
#   (1690, 1),
#   (1873, 1),
#   (1945, 1),
#   (2119, 1),
#   (2513, 1),
#   (2539, 1),
#   (2590, 1),
#   (2603, 1),
#   (2816, 1),
#   (2836, 1),
#   (3146, 1),
#   (3228, 1),
#   (3399, 1),
#   (3624, 1),
#   (4270, 1),
#   (4303, 1),
#   (4391, 1),
#   (4429, 1),
#   (4445, 1),
#   (5005, 1),
#   (5073, 1),
#   (5074, 1)],
#  ...]

# %%
import re
import nltk
from nltk import sent_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from gensim import corpora

# %%
# input College Supp Essay 
essay_input = """I inhale deeply and blow harder than I thought possible, pushing the tiny ember from its resting place on the candle out into the air. The room erupts around me, and 'Happy Birthday!' cheers echo through the halls. It's time to make a wish. In my mind, that new Limited Edition Deluxe Ben 10 watch will soon be mine. My parents and the aunties and uncles around me attempt to point me in a different direction. 'Wish that you get to go to the temple every day when you're older! Wish that you memorize all your Sanskrit texts before you turn 6! Wish that you can live in India after college!' My ears listen, but my mind tunes them out, as nothing could possibly compare to that toy watch! What I never realized on my third birthday is that those wishes quietly tell the story of how my family hopes my life will play out. In this version of my life, there wasn't much room for change, personal growth, or 'rocking the boat.' A vital aspect of my family's cultural background is their focus on accepting things as they are. Growing up, I was discouraged from questioning others or asking questions that didn't have definitive yes or no answers. If I innocently asked my grandma why she expected me to touch her feet, my dad would grab my hand in a sudden swoop, look me sternly in the eye, and tell me not to disrespect her like that again. At home, if I mentioned that I had tried eggs for breakfast at a friend's house, I'd be looked at like I had just committed a felony for eating what my parents considered meat. If I asked the priest at the temple why he had asked an Indian man and his white wife to leave, I'd be met with a condescending glare and told that I should also leave for asking such questions.In direct contrast, my curiosity was invited and encouraged at school. After an environmental science lesson, I stayed for a few minutes after class to ask my 4th-grade science teacher with wide eyes how it was possible that Niagara Falls doesn't run out of flowing water. Instead of scolding me for asking her a 'dumb question,' she smiled and explained the intricacy of the water cycle. Now, if a teacher mentions that we'll learn about why a certain proof or idea works only in a future class, I'll stay after to ask more or pour through an advanced textbook to try to understand it. While my perspective was widening at school, the receptiveness to raising complex questions at home was diminishing. After earning my driver's license, I registered as an organ donor. My small checkmark on a piece of paper led to an intense clash between my and my parents' moral platform. I wanted to ensure that I positively contributed to society, while my parents believed that organ donation was an unfamiliar and unnecessary cultural taboo. I would often ask for clarity or for reasons that supported their ideologies. Their response would usually entail feeling a deep, visceral sense that traditions must be followed exactly as taught, without objection. Told in one language to keep asking questions and in another to ask only the right ones, I chose exploring questions that don't have answers, rather than accepting answers that don't get questioned. When it comes to the maze of learning, even when I take a wrong turn and encounter roadblocks that are meant to stop me, I've learned to climb over them and keep moving forward. My curiosity strengthens with each hurdle and has expanded into a pure love of learning new things. I've become someone who seeks to understand things at a fundamental level and who finds excitement in taking on big questions that have yet to be solved. I'm no longer afraid to rock the boat. "},{"index":1,"personal_essay":"Ever since I first held a small foam Spiderman basketball in my tiny hands and watched my idol Kobe Bryant hit every three-pointer he attempted, I've wanted to understand and replicate his flawless jump shot. As my math education progressed in school, I began to realize I had the tools to create a perfect shot formula. After learning about variables for the first time in 5th grade Algebra, I began to treat each aspect of Kobe's jump shot as a different variable, each combination of variables resulting in a unique solution. While in 7th-grade geometry, I graphed the arc of his shot, and after learning about quadratic equations in 8th grade, I expressed his shot as a parabolic function that would ensure a swish when shooting from any spot. After calculus lessons in 10th and 11th grade, I was excited to finally solve for the perfect velocity and acceleration needed on my release. At Brown, I hope to explore this intellectual pursuit through a different lens. What if I could maximize the odds of making shots if I understood the science behind one's mental mindset and focus through CLPS 500: Perception and Action? Or use astrophysics to account for drag and gravitational force anywhere in the universe? Or use data science to break down the analytics of the NBA's best shooters? Through the Open Curriculum, I see myself not only becoming a more complete learner, but also a more complete thinker, applying a flexible mindset to any problem I encounter. Brown's Open Curriculum allows students to explore broadly while also diving deeply into their academic pursuits. Tell us about an academic interest (or interests) that excites you, and how you might use the Open Curriculum to pursue it. I've been playing the Mridangam since I was five years old. It's a simple instrument: A wood barrel covered on two ends by goatskin with leather straps surrounding the hull. This instrument serves as a connection between me and one of the most beautiful aspects of my culture: Carnatic music. As a young child, I'd be taken to the temple every weekend for three-hour-long Carnatic music concerts, where the most accomplished teenagers and young adults in our local Indian community would perform. I would watch in awe as the mridangists' hands moved gracefully, flowing across the goatskin as if they weren't making contact, while simultaneously producing sharp rhythmic patterns that never failed to fall on the beat. Hoping to be like these idols on the stage, I trained intensely with my teacher, a strict man who taught me that the simple drum I was playing had thousands of years of culture behind it. Building up from simple strokes, I realized that the finger speed I'd had been awestruck by wasn't some magical talent, it was instead a science perfected by repeated practice."""

# %%
# tokenize sentence
sent_token_re = sent_tokenize(essay_input)

# %%
processed_data = []
for i in sent_token_re:
    tokens_re = nltk.word_tokenize(i)
    # stopwords 제거, 각 문장을 소문자로 변환하고, 명사만 추출, 문장별로 리스트 만들어서 리스트에 다시 담기
    stop = set(stopwords.words('english'))
    clean_tokens = [tok for tok in tokens_re if len(tok.lower())>1 and (tok.lower() not in stop)]
    tagged = nltk.pos_tag(clean_tokens)
    allnoun = [word for word, pos in tagged if pos in ['NN','NNP']]
    processed_data.append(allnoun)

# %%
processed_data
# Out:
# [['harder', 'ember', 'place', 'candle', 'air'],
#  ['room', 'Birthday'],
#  [],
#  ['time'],
#  ['Limited', 'Edition', 'Deluxe', 'Ben', 'watch', 'mine'],
#  ['point', 'direction'],
#  ['get', 'day'],
#  ['memorize', 'Sanskrit', 'texts', 'turn'],
#  ['India', 'college'],
#  ['nothing', 'toy', 'watch'],
#  ['birthday', 'story', 'family', 'life', 'play'],
#  ['version', 'life', 'room', 'change', 'growth', 'boat'],
#  ['family', 'background', 'focus'],
#  [],
#  ['grandma', 'hand', 'swoop', 'look', 'eye', 'disrespect'],
#  ['home', 'friend', 'house', 'felony', 'meat'],
#  ['temple',
#   'man',
#   'wife',
#   'glare',
#   'questions.In',
#   'contrast',
#   'curiosity',
#   'school'],
#  ['science',
#   'lesson',
#   'class',
#   'science',
#   'teacher',
#   'Niagara',
#   'Falls',
#   'water'],
#  ['question', 'water', 'cycle'],
#  ['teacher', 'proof', 'idea', 'class', 'pour', 'try', 'understand'],
#  ['perspective', 'school', 'receptiveness', 'home', 'diminishing'],
#  ['driver', 'license', 'donor'],
#  ['checkmark', 'piece', 'paper', 'clash', 'platform'],
#  ['society', 'donation', 'taboo'],
#  ['clarity'],
#  ['response', 'sense', 'objection'],
#  ['Told', 'language', 'ask', 'right'],
#  ['climb'],
#  ['curiosity', 'hurdle', 'pure'],
#  ['someone', 'level'],
#  ['rock', 'boat'],
#  ['index',
#   ':1',
#   'personal_essay',
#   'Ever',
#   'foam',
#   'Spiderman',
#   'basketball',
#   'Kobe',
#   'Bryant',
#   'three-pointer',
#   'understand',
#   'replicate',
#   'flawless',
#   'jump',
#   'shot'],
#  ['math', 'education', 'school', 'shot', 'formula'],
#  ['time',
#   'grade',
#   'Algebra',
#   'Kobe',
#   'jump',
#   'shot',
#   'combination',
#   'solution'],
#  ['geometry', 'function', 'shooting', 'spot'],
#  ['grade', 'velocity', 'acceleration', 'release'],
#  ['Brown', 'pursuit'],
#  ['science', 'mindset', 'focus', 'CLPS', 'Perception', 'Action'],
#  ['use', 'force'],
#  ['use', 'science', 'break', 'NBA'],
#  ['Curriculum', 'learner', 'thinker', 'mindset', 'problem', 'encounter'],
#  ['Brown', 'Open', 'Curriculum'],
#  ['interest', 'Open', 'Curriculum', 'pursue'],
#  ['Mridangam'],
#  ['instrument', 'wood', 'barrel', 'leather', 'hull'],
#  ['instrument', 'connection', 'beautiful', 'culture', 'Carnatic', 'music'],
#  ['child', 'weekend', 'Carnatic', 'music', 'Indian', 'community'],
#  ['awe', 'fall', 'beat'],
#  ['stage', 'man', 'drum', 'culture'],
#  ['speed', 'talent', 'science', 'practice']]

# %%
dictionary = corpora.Dictionary(processed_data)
dictionary

# %%
def get_nouns(sentence): 
    tagged = nltk.pos_tag(sentence) 
    nouns = [s for s, t in tagged if t in ['SL', 'NNG', 'NNP'] and len(s) > 1] 
    return nouns

# %%
get_nouns(essay_input)
# Out:
# []

# %%
def clean_text(text):
    #영문, 숫자만 남기고 제거한다. :param text: :return: 
    pattern = '[^|0-9|a-zA-Z]+' 
    text = re.sub(pattern=pattern, repl=' ', string=text) 
    return text

# %%
cln_re = clean_text(essay_input)
cln_re
# Out:
# 'I inhale deeply and blow harder than I thought possible pushing the tiny ember from its resting place on the candle out into the air The room erupts around me and Happy Birthday cheers echo through the halls It s time to make a wish In my mind that new Limited Edition Deluxe Ben 10 watch will soon be mine My parents and the aunties and uncles around me attempt to point me in a different direction Wish that you get to go to the temple every day when you re older Wish that you memorize all your Sanskrit texts before you turn 6 Wish that you can live in India after college My ears listen but my mind tunes them out as nothing could possibly compare to that toy watch What I never realized on my third birthday is that those wishes quietly tell the story of how my family hopes my life will play out In this version of my life there wasn t much room for change personal growth or rocking the boat A vital aspect of my family s cultural background is their focus on accepting things as they are Growing up I was discouraged from questioning others or asking questions that didn t have definitive yes or no answers If I innocently asked my grandma why she expected me to touch her feet my dad would grab my hand in a sudden swoop look me sternly in the eye and tell me not to disrespect her like that again At home if I mentioned that I had tried eggs for breakfast at a friend s house I d be looked at like I had just committed a felony for eating what my parents considered meat If I asked the priest at the temple why he had asked an Indian man and his white wife to leave I d be met with a condescending glare and told that I should also leave for asking such questions In direct contrast my curiosity was invited and encouraged at school After an environmental science lesson I stayed for a few minutes after class to ask my 4th grade science teacher with wide eyes how it was possible that Niagara Falls doesn t run out of flowing water Instead of scolding me for asking her a dumb question she smiled and explained the intricacy of the water cycle Now if a teacher mentions that we ll learn about why a certain proof or idea works only in a future class I ll stay after to ask more or pour through an advanced textbook to try to understand it While my perspective was widening at school the receptiveness to raising complex questions at home was diminishing After earning my driver s license I registered as an organ donor My small checkmark on a piece of paper led to an intense clash between my and my parents moral platform I wanted to ensure that I positively contributed to society while my parents believed that organ donation was an unfamiliar and unnecessary cultural taboo I would often ask for clarity or for reasons that supported their ideologies Their response would usually entail feeling a deep visceral sense that traditions must be followed exactly as taught without objection Told in one language to keep asking questions and in another to ask only the right ones I chose exploring questions that don t have answers rather than accepting answers that don t get questioned When it comes to the maze of learning even when I take a wrong turn and encounter roadblocks that are meant to stop me I ve learned to climb over them and keep moving forward My curiosity strengthens with each hurdle and has expanded into a pure love of learning new things I ve become someone who seeks to understand things at a fundamental level and who finds excitement in taking on big questions that have yet to be solved I m no longer afraid to rock the boat index 1 personal essay Ever since I first held a small foam Spiderman basketball in my tiny hands and watched my idol Kobe Bryant hit every three pointer he attempted I ve wanted to understand and replicate his flawless jump shot As my math education progressed in school I began to realize I had the tools to create a perfect shot formula After learning about variables for the first time in 5th grade Algebra I began to treat each asp ...

# %%
get_nouns(cln_re)
# Out:
# []

# %%
def tokenize(txt): 
    sent_token =  sent_tokenize(txt)
    result_dt = []
    for snt in sent_token:
        tokenizer = word_tokenize
        ct_re = clean_text(tokenizer)
        get_nouns_re = get_nouns(ct_re)
        wd_token_re = tokenizer(get_nouns_re)
        result_dt.append(wd_token_re)

    return result_dt
