# %% [markdown]
# ## 수집한 단어를 정규식을 활용하여 리스트로 변환 _ actionVerbs

# %%
import re

# %%
#Academic Verbs
academicVerbs = """abandon
abduct
abhor
abolish
abominate
abscond
abuse
accelerate
accomplish
accost
accrue
accumulate
accuse
achieve
acquire
act
activate
Actualized
adapt
address
adjust
administer
advance
advise
advocate
affirm
afflict
affray
affront
aggravate
agitate 
aid
ail
aim
alert
allocate
altercate
amplify
analyze
annihilate
annoy
antagonize
anticipate
appoint
apprehend
approach
arbitrate
arrange
arrest
assault
assemble
assess
assign
assist
assure
attack
attain
attract
audit
augment
authenticate
author
authorize
automate
avert
avoid
award
balance
bang
bank
bar
bash
battle
beat
berate
bicker
biff
bill
billow
bite
blast
blend
Blended
block
blow
bolster
boost
brabble
brace
brawl
brief
brighten
broke
buck
built
bump
burst
bury
bushwhack
calculate
calm
campaign
cancel
capitalize
carry out
catch
centralize
certify
chair
challenge
champion
change
channel
charge
chart
charter
chase
check
choke
circumscribe
circumvent
clap
clarify
clash
classify
climb
clip
clutch
coach
Co-authored
Coded
collaborate
collapse
collar
collate
collect
collide
combat
combine
command
commandeer
commit
communicate
compile
complete
compose
compute
conceive
conceptualize
condense
conduct
confer
configure
confront
conserve
consolidate
construct
consult
contend
contract
contribute
control
converse
convert
convey
cooperate
coordinate
Coproduced
correlate
correspond
counsel
count
Crafted
cram
crash
crawl
create
creep
cripple
critique
croak
crouch
crush
cultivate
cure
curse
curtail
customize
cut
dance
dare
dart
dash
daunt 
deal
debate
debut
decide
deck
decorate
decrease
deduct
deface
defame
defeat
Defended
define
defy
delegate
delete
deliberate
delineate
deliver
demonstrate
demoralize 
deplore
deprecate
derive
descend
describe
design
designate
despise
destroy
detail
detect
determine
detest
detonate
develop
devise
diagnose
dictate
dig
diminish
direct
disable
disapprove
discard
discharge
discomfort 
discompose 
discourage 
discover
discuss
disdain
disesteem
disfavor
disharmonize
dishearten 
dismay 
dispatch
dispirit 
display
dispute
dissect
dissent
disservice
distinguish
distress 
distribute
disturb 
ditch
dive
divert
divide
document
dodge
dominate
dope
double
douse
draft
drag
drain
dramatize
drape
draw
dress
drill
drink
drip
drive
drop
drown
drug
dry
duel
dunk
earn
ease
edge
edit
educate
effect
eject
elevate
eliminate
elope
elude
emerge
employ
emulate
enable
enact
encounter
encourage
endeavor
endure
enforce
Enforced
engage
engineer
enhance
enjoin
enlarge
enlighten
enlist
enraged
ensnare
ensure
enter
envy
equip
erupt
escalate
escape
establish
estimate
evacuate
evade
evaluate
evict
examine
exceed
execrate
execute
exert
exhale
exhibit
exit
expand
expedite
Expedited
expel
experience
experiment
explain
explode
expose
extend
extirpate
extract
extricate
face
facilitate
fade
fake
fall
falter
fan
fashion
fast
fear
feed
fend
field
fight
file
fill
finger
fix
flag
flap
flash
flatten
flaunt
flay
flee
flick
flinch
fling
flip
flit
float
flog
flounder
flout
flush
fly
focus
fondle
force
forecast
Forecasted
forge
form
formalize
formulate
fornicate
foster
found
fray
freak
frustrate
Fulfill
fumble
fund
furnish
gain
gall
gallop
gash
gather
generate
gesture
gnaw
gossip
gouge
govern
grab
graduate
grapple
grasp
greet
Grew
grind
grip
Groomed
grope
ground
grow
growl
grunt
guard
guide
gyrate
hack
hail
halt
halve
hammer
handle
hang
harass
hassle
hasten
haul
head
helm
hesitate
hide
hijack
hinder
hire
hit
hitch
hobble
hoist
hold
hover
huff
hug
hurl
hurtle
hypothesize
icky
identify
ignore
illustrate
imitate
impeach
implement
importune
improve
Improved
improvise
incense
inch
increase
incriminate
index
indict
indignant
indignation
indignity
individualize
induce
inequity
infighting
inflame
inflate
inflict
influence
inform
infuriate
initiate
Initiated
inject
injure
innovate
insert
inspect
inspire
Inspired
install
instigate
institute
instruct
Instructed
insult
integrate
intensify
interchange
interpret
interview
introduce
invade
invent
Invented
inventory
invest
investigate
Investigated
involve
irateness
isolate
itemize
jab
jam
jangle
jar
jeer
jerk
jimmy
jingle
join
Joined
jolt
judge
jump
justify
keel
keynote
kibitz
kick
kidnap
kill
kneel
knife
label
land
lash
launch
lead
lean
leap
learn
lecture
led
left
lessen
level
liaise
license
lick
lift
Lifted
limp
link
list
listen
loathe
locate
log
lower
lunge
lurch
magnify
maim
maintain
manage
Managed
mangle
manipulate
manufacture
march
mark
market
Married
massage
master
mastermind
maul
maximize
measure
meddle
mediate
meet
mend
mentor
Mentored
merge
Merged
mimic
mingle
minimize
mobilize
Mobilized
mock
model
mold
molest
monitor
motivate
Motivated
mourn
move
multiply
mumble
murder
muster
mutilate
nab
nag
nail
narrow
needle
negotiate
Negotiated
network
nick
nip
nominate
nurture
object
observe
obtain
occupy
offense
offer
officiate
operate
Operated
oppose
oppress
orchestrate
order
organize
Organized
originate
Originated
outline
Outlined
outpace
Outpaced
outperform
Outperformed
outrage
overcome
overhaul
Oversaw
oversee
pack
paddle
page
pander
panic
parachute
parade
paralyze
park
parry
participate
Partnered
party
pass
pat
patrol
pause
paw
peel
peep
penetrate
perceive
perfect
perform
Performed
persuade
photograph
pick
picket
pile
pilot
pin
pinch
pioneer
Pioneered
pique
pirate
pitch
placate
place
plan
plod
plow
plunge
pocket
poke
polish
pore
pose
position
pounce
pound
pout
pray
predict
preen
prepare
Prepared
prescribe
present
preside
primp
print
prioritize
probe
process
procure
prod
produce
Produced
profitable
program
Programmed
project
promote
prompt
proofread
propel
propose
protect
protest
prove
provide
provoke
pry
publicize
Publicized
publish
Published
pull
pummel
pump
punch
purchase
purge
pursue
push
qualify
quarrel
quell
question
quibble
quicken
quit
quiz
race
raid
raise
Raised
rally
ram
rank
rankle
ransack
rape
rate
rattle
ravage
rave
reach
Reached
read
realize
Realized
rebuild
receive
recline
recommend
reconcile
reconnoiter
record
recoup
recruit
redeem
reduce
reel
refer
regain
regulate
reinforce
rejoin
relate
relax
relay
relent
relieve
Remodeled
remove
render
renew
renovate
reorganize
repair
repel
report
reposition
represent
repress
repulse
repulsion
research
resign
resist
resolve
respond
restore
retain
retaliate
retreat
retrieve
reveal
review
revise
revitalize
revolutionize
ride
rip
rise
risk
rob
rock
roil
roll
romp
rub
ruffle
run
rupture
rush
sail
salute
sap
satisfy
save
saw
scald
scale
scamper
scan
scar
scare
scatter
scavenge
schedule
scold
scoop
scoot
score
scorn
scour
scout
scrap
scrape
scratch
scrawl
scream
screen
screw
scrub
scruff
scuffle
sculpt
scuttle
seal
sear
search
secure
seduce
segment
seize
select
sell
sense
serve
service
set
set up
sever
sew
shake
shanghai
shape
Shaped
share
sharpen
shatter
shave
shave down
shear
shell
shield
shift
shiver
shock
shoot
shorten
shoulder
shout
shove
shovel
shrink
shun
shut
sidestep
sigh
signal
simplify
sip
sit
size
skid
skim
skip
skirt
slacken
slam
slap
slash
slaughter
slay
slide
slug
smack
smash
smear
smell
smite
smuggle
snap
snare
snarl
snatch
snicker
sniff
snitch
snoop
snub
snuff
snuggle
soak
sock
soil
sold
solve
sort
spark
spear
spearhead
Spearheaded
specialize
specify
spell
spike
spin
splatter
splice
split
spot
spray
spread
spring
sprint
spur
spurn
spy
squabble
squash
squeak
squelch
stack
staff
stagger
stamp
stand
standardize
startle
steal
steer
step
stick
stiffen
stifle
stimulate
stock
stomp
stop
strain
strangle
strap
strategize
streamline
strengthen
stress
strike
strip
strive
stroke
struck
structure
struggle
stub
study
stuff
stumble
stun
subdue
submerge
submit
succeed
suck
suggest
sum
summarize
summon
superintend
supervise
supply
support
supress
surpass
surrender
survey
suspend
sustain
swagger
swallow
swap
sway
swear
swerve
swim
swing
swipe
switch
synergize
synthesize
systematize
tabulate
tackle
talk
tangle
tap
target
taste
Taught
taunt
teach
team
tear
tease
terminate
terrorize
test
thin
thrash
thread
threaten
throw
tick
tickle
tie
tighten
tilt
tip
tolerate
top
torture
toss
touch
tout
track
train
Trained
transcribe
transfer
transform
Transformed
translate
transport
trap
tread
treat
trim
trip
triple
trot
trounce
tuck
tug
tumble
turn
tutor
twist
type
uncover
undergo
undertake
Undertook
undo
undress
unfold
unhinge 
unify
unite
United
unnerve
unravel
unsettle 
untangle
unveil
unwelcome
unwind
update
usher
utilize
vacate
validate
value
vanish
vanquish
vault
vent
verbalize
verify
veto
vex
violate
volunteer
wade
walk
wallop
wander
ward
watch
wave
wedge
weed
weigh
whack
whale
whip
whirl
whistle
widen
wield
wiggle
win
withdraw
wound
Wove
wrangle
wreck
wrench
wrestle
write
wrought
yank
yell
yelp
yield
zap
zip
"""

# %%
remove = academicVerbs.replace("  "," ") # 변환
remove_ = re.sub(r"\t", " ", remove) # 제거
remove__ = re.sub(r"\n", " ", remove_) # 제거
remove__ = remove__.replace("   ", " ")
remove__ = remove__.replace("  ", " ")
remove__ = remove__.replace(" ", ",")
remove__ = remove__.replace("…/", " ")
remove__ = remove__.replace("…", " ")
remove__ = remove__.replace("/", " ")
remove__ = remove__.replace(" ", ",")
remove__ = remove__.replace(")", ",")
remove__ = remove__.replace("(", ",")
preprossed = remove__.split(",") # 단어를 리스트로 변환
preprossed
# Out:
# ['abandon',
#  'abduct',
#  'abhor',
#  'abolish',
#  'abominate',
#  'abscond',
#  'abuse',
#  'accelerate',
#  'accomplish',
#  'accost',
#  'accrue',
#  'accumulate',
#  'accuse',
#  'achieve',
#  'acquire',
#  'act',
#  'activate',
#  'Actualized',
#  'adapt',
#  'address',
#  'adjust',
#  'administer',
#  'advance',
#  'advise',
#  'advocate',
#  'affirm',
#  'afflict',
#  'affray',
#  'affront',
#  'aggravate',
#  'agitate\xa0',
#  'aid',
#  'ail',
#  'aim',
#  'alert',
#  'allocate',
#  'altercate',
#  'amplify',
#  'analyze',
#  'annihilate',
#  'annoy',
#  'antagonize',
#  'anticipate',
#  'appoint',
#  'apprehend',
#  'approach',
#  'arbitrate',
#  'arrange',
#  'arrest',
#  'assault',
#  'assemble',
#  'assess',
#  'assign',
#  'assist',
#  'assure',
#  'attack',
#  'attain',
#  'attract',
#  'audit',
#  'augment',
#  'authenticate',
#  'author',
#  'authorize',
#  'automate',
#  'avert',
#  'avoid',
#  'award',
#  'balance',
#  'bang',
#  'bank',
#  'bar',
#  'bash',
#  'battle',
#  'beat',
#  'berate',
#  'bicker',
#  'biff',
#  'bill',
#  'billow',
#  'bite',
#  'blast',
#  'blend',
#  'Blended',
#  'block',
#  'blow',
#  'bolster',
#  'boost',
#  'brabble',
#  'brace',
#  'brawl',
#  'brief',
#  'brighten',
#  'broke',
#  'buck',
#  'built',
#  'bump',
#  'burst',
#  'bury',
#  'bushwhack',
#  'calculate',
#  'calm',
#  'campaign',
#  'cancel',
#  'capitalize',
#  'carry',
#  'out',
#  'catch',
#  'centralize',
#  'certify',
#  'chair',
#  'challenge',
#  'champion',
#  'change',
#  'channel',
#  'charge',
#  'chart',
#  'charter',
#  'chase',
#  'check',
#  'choke',
#  'circumscribe',
#  'circumvent',
#  'clap',
#  'clarify',
#  'clash',
#  'classify',
#  'climb',
#  'clip',
#  'clutch',
#  'coach',
#  'Co-authored',
#  'Coded',
#  'collaborate',
#  'collapse',
#  'collar',
#  'collate',
#  'collect',
#  'collide',
#  'combat',
#  'combine',
#  'command',
#  'commandeer',
#  'commit',
#  'communicate',
#  'compile',
#  'complete',
#  'compose',
#  'compute',
#  'conceive',
#  'conceptualize',
#  'condense',
#  'conduct',
#  'confer',
#  'configure',
#  'confront',
#  'conserve',
#  'consolidate',
#  'construct',
#  'consult',
#  'contend',
#  'contract',
#  'contribute',
#  'control',
#  'converse',
#  'convert',
#  'convey',
#  'cooperate',
#  'coordinate',
#  'Coproduced',
#  'correlate',
#  'correspond',
#  'counsel',
#  'count',
#  'Crafted',
#  'cram',
#  'crash',
#  'crawl',
#  'create',
#  'creep',
#  'cripple',
#  'critique',
#  'croak',
#  'crouch',
#  'crush',
#  'cultivate',
#  'cure',
#  'curse',
#  'curtail',
#  'customize',
#  'cut',
#  'dance',
#  'dare',
#  'dart',
#  'dash',
#  'daunt\xa0',
#  'deal',
#  'debate',
#  'debut',
#  'decide',
#  'deck',
#  'decorate',
#  'decrease',
#  'deduct',
#  'deface',
#  'defame',
#  'defeat',
#  'Defended',
#  'define',
#  'defy',
#  'delegate',
#  'delete',
#  'deliberate',
#  'delineate',
#  'deliver',
#  'demonstrate',
#  'demoralize\xa0',
#  'deplore',
#  'deprecate',
#  'derive',
#  'descend',
#  'describe',
#  'design',
#  'designate',
#  'despise',
#  'destroy',
#  'detail',
#  'detect',
#  'determine',
#  'detest',
#  'detonate',
#  'develop',
#  'devise',
#  'diagnose',
#  'dictate',
#  'dig',
#  'diminish',
#  'direct',
#  'disable',
#  'disapprove',
#  'discard',
#  'discharge',
#  'discomfort\xa0',
#  'discompose\xa0',
#  'discourage\xa0',
#  'discover',
#  'discuss',
#  'disdain',
#  'disesteem',
#  'disfavor',
#  'disharmonize',
#  'dishearten\xa0',
#  'dismay\xa0',
#  'dispatch',
#  'dispirit\xa0',
#  'display',
#  'dispute',
#  'dissect',
#  'dissent',
#  'disservice',
#  'distinguish',
#  'distress\xa0',
#  'distribute',
#  'disturb\xa0',
#  'ditch',
#  'dive',
#  'divert',
#  'divide',
#  'document',
#  'dodge',
#  'dominate',
#  'dope',
#  'double',
#  'douse',
#  'draft',
#  'drag',
#  'drain',
#  'dramatize',
#  'drape',
#  'draw',
#  'dress',
#  'drill',
#  'drink',
#  'drip',
#  'drive',
#  'drop',
#  'drown',
#  'drug',
#  'dry',
#  'duel',
#  'dunk',
#  'earn',
#  'ease',
#  'edge',
#  'edit',
#  'educate',
#  'effect',
#  'eject',
#  'elevate',
#  'eliminate',
#  'elope',
#  'elude',
#  'emerge',
#  'employ',
#  'emulate',
#  'enable',
#  'enact',
#  'encounter',
#  'encourage',
#  'endeavor',
#  'endure',
#  'enforce',
#  'Enforced',
#  'engage',
#  'engineer',
#  'enhance',
#  'enjoin',
#  'enlarge',
#  'enlighten',
#  'enlist',
#  'enraged',
#  'ensnare',
#  'ensure',
#  'enter',
#  'envy',
#  'equip',
#  'erupt',
#  'escalate',
#  'escape',
#  'establish',
#  'estimate',
#  'evacuate',
#  'evade',
#  'evaluate',
#  'evict',
#  'examine',
#  'exceed',
#  'execrate',
#  'execute',
#  'exert',
#  'exhale',
#  'exhibit',
#  'exit',
#  'expand',
#  'expedite',
#  'Expedited',
#  'expel',
#  'experience',
#  'experiment',
#  'explain',
#  'explode',
#  'expose',
#  'extend',
#  'extirpate',
#  'extract',
#  'extricate',
#  'face',
#  'facilitate',
#  'fade',
#  'fake',
#  'fall',
#  'falter',
#  'fan',
#  'fashion',
#  'fast',
#  'fear',
#  'feed',
#  'fend',
#  'field',
#  'fight',
#  'file',
#  'fill',
#  'finger',
#  'fix',
#  'flag',
#  'flap',
#  'flash',
#  'flatten',
#  'flaunt',
#  'flay',
#  'flee',
#  'flick',
#  'flinch',
#  'fling',
#  'flip',
#  'flit',
#  'float',
#  'flog',
#  'flounder',
#  'flout',
#  'flush',
#  'fly',
#  'focus',
#  'fondle',
#  'force',
#  'forecast',
#  'Forecasted',
#  'forge',
#  'form',
#  'formalize',
#  'formulate',
#  'fornicate',
#  'foster',
#  'found',
#  'fray',
#  'freak',
#  'frustrate',
#  'Fulfill',
#  'fumble',
#  'fund',
#  'furnish',
#  'gain',
#  'gall',
#  'gallop',
#  'gash',
#  'gather',
#  'generate',
#  'gesture',
#  'gnaw',
#  'gossip',
#  'gouge',
#  'govern',
#  'grab',
#  'graduate',
#  'grapple',
#  'grasp',
#  'greet',
#  'Grew',
#  'grind',
#  'grip',
#  'Groomed',
#  'grope',
#  'ground',
#  'grow',
#  'growl',
#  'grunt',
#  'guard',
#  'guide',
#  'gyrate',
#  'hack',
#  'hail',
#  'halt',
#  'halve',
#  'hammer',
#  'handle',
#  'hang',
#  'harass',
#  'hassle',
#  'hasten',
#  'haul',
#  'head',
#  'helm',
#  'hesitate',
#  'hide',
#  'hijack',
#  'hinder',
#  'hire',
#  'hit',
#  'hitch',
#  'hobble',
#  'hoist',
#  'hold',
#  'hover',
#  'huff',
#  'hug',
#  'hurl',
#  'hurtle',
#  'hypothesize',
#  'icky',
#  'identify',
#  'ignore',
#  'illustrate',
#  'imitate',
#  'impeach',
#  'implement',
#  'importune',
#  'improve',
#  'Improved',
#  'improvise',
#  'incense',
#  'inch',
#  'increase',
#  'incriminate',
#  'index',
#  'indict',
#  'indignant',
#  'indignation',
#  'indignity',
#  'individualize',
#  'induce',
#  'inequity',
#  'infighting',
#  'inflame',
#  'inflate',
#  'inflict',
#  'influence',
#  'inform',
#  'infuriate',
#  'initiate',
#  'Initiated',
#  'inject',
#  'injure',
#  'innovate',
#  'insert',
#  'inspect',
#  'inspire',
#  'Inspired',
#  'install',
#  'instigate',
#  'institute',
#  'instruct',
#  'Instructed',
#  'insult',
#  'integrate',
#  'intensify',
#  'interchange',
#  'interpret',
#  'interview',
#  'introduce',
#  'invade',
#  'invent',
#  'Invented',
#  'inventory',
#  'invest',
#  'investigate',
#  'Investigated',
#  'involve',
#  'irateness',
#  'isolate',
#  'itemize',
#  'jab',
#  'jam',
#  'jangle',
#  'jar',
#  'jeer',
#  'jerk',
#  'jimmy',
#  'jingle',
#  'join',
#  'Joined',
#  'jolt',
#  'judge',
#  'jump',
#  'justify',
#  'keel',
#  'keynote',
#  'kibitz',
#  'kick',
#  'kidnap',
#  'kill',
#  'kneel',
#  'knife',
#  'label',
#  'land',
#  'lash',
#  'launch',
#  'lead',
#  'lean',
#  'leap',
#  'learn',
#  'lecture',
#  'led',
#  'left',
#  'lessen',
#  'level',
#  'liaise',
#  'license',
#  'lick',
#  'lift',
#  'Lifted',
#  'limp',
#  'link',
#  'list',
#  'listen',
#  'loathe',
#  'locate',
#  'log',
#  'lower',
#  'lunge',
#  'lurch',
#  'magnify',
#  'maim',
#  'maintain',
#  'manage',
#  'Managed',
#  'mangle',
#  'manipulate',
#  'manufacture',
#  'march',
#  'mark',
#  'market',
#  'Married',
#  'massage',
#  'master',
#  'mastermind',
#  'maul',
#  'maximize',
#  'measure',
#  'meddle',
#  'mediate',
#  'meet',
#  'mend',
#  'mentor',
#  'Mentored',
#  'merge',
#  'Merged',
#  'mimic',
#  'mingle',
#  'minimize',
#  'mobilize',
#  'Mobilized',
#  'mock',
#  'model',
#  'mold',
#  'molest',
#  'monitor',
#  'motivate',
#  'Motivated',
#  'mourn',
#  'move',
#  'multiply',
#  'mumble',
#  'murder',
#  'muster',
#  'mutilate',
#  'nab',
#  'nag',
#  'nail',
#  'narrow',
#  'needle',
#  'negotiate',
#  'Negotiated',
#  'network',
#  'nick',
#  'nip',
#  'nominate',
#  'nurture',
#  'object',
#  'observe',
#  'obtain',
#  'occupy',
#  'offense',
#  'offer',
#  'officiate',
#  'operate',
#  'Operated',
#  'oppose',
#  'oppress',
#  'orchestrate',
#  'order',
#  'organize',
#  'Organized',
#  'originate',
#  'Originated',
#  'outline',
#  'Outlined',
#  'outpace',
#  'Outpaced',
#  'outperform',
#  'Outperformed',
#  'outrage',
#  'overcome',
#  'overhaul',
#  'Oversaw',
#  'oversee',
#  'pack',
#  'paddle',
#  'page',
#  'pander',
#  'panic',
#  'parachute',
#  'parade',
#  'paralyze',
#  'park',
#  'parry',
#  'participate',
#  'Partnered',
#  'party',
#  'pass',
#  'pat',
#  'patrol',
#  'pause',
#  'paw',
#  'peel',
#  'peep',
#  'penetrate',
#  'perceive',
#  'perfect',
#  'perform',
#  'Performed',
#  'persuade',
#  'photograph',
#  'pick',
#  'picket',
#  'pile',
#  'pilot',
#  'pin',
#  'pinch',
#  'pioneer',
#  'Pioneered',
#  'pique',
#  'pirate',
#  'pitch',
#  'placate',
#  'place',
#  'plan',
#  'plod',
#  'plow',
#  'plunge',
#  'pocket',
#  'poke',
#  'polish',
#  'pore',
#  'pose',
#  'position',
#  'pounce',
#  'pound',
#  'pout',
#  'pray',
#  'predict',
#  'preen',
#  'prepare',
#  'Prepared',
#  'prescribe',
#  'present',
#  'preside',
#  'primp',
#  'print',
#  'prioritize',
#  'probe',
#  'process',
#  'procure',
#  'prod',
#  'produce',
#  'Produced',
#  'profitable',
#  'program',
#  'Programmed',
#  'project',
#  'promote',
#  'prompt',
#  'proofread',
#  'propel',
#  'propose',
#  'protect',
#  'protest',
#  'prove',
#  'provide',
#  'provoke',
#  'pry',
#  'publicize',
#  'Publicized',
#  'publish',
#  'Published',
#  'pull',
#  'pummel',
#  'pump',
#  'punch',
#  'purchase',
#  'purge',
#  'pursue',
#  'push',
#  'qualify',
#  'quarrel',
#  'quell',
#  'question',
#  'quibble',
#  'quicken',
#  'quit',
#  'quiz',
#  'race',
#  'raid',
#  'raise',
#  'Raised',
#  'rally',
#  'ram',
#  'rank',
#  'rankle',
#  'ransack',
#  'rape',
#  'rate',
#  'rattle',
#  'ravage',
#  'rave',
#  'reach',
#  'Reached',
#  'read',
#  'realize',
#  'Realized',
#  'rebuild',
#  'receive',
#  'recline',
#  'recommend',
#  'reconcile',
#  'reconnoiter',
#  'record',
#  'recoup',
#  'recruit',
#  'redeem',
#  'reduce',
#  'reel',
#  'refer',
#  'regain',
#  'regulate',
#  'reinforce',
#  'rejoin',
#  'relate',
#  'relax',
#  'relay',
#  'relent',
#  'relieve',
#  'Remodeled',
#  'remove',
#  'render',
#  'renew',
#  'renovate',
#  'reorganize',
#  'repair',
#  'repel',
#  'report',
#  'reposition',
#  'represent',
#  'repress',
#  'repulse',
#  'repulsion',
#  'research',
#  'resign',
#  'resist',
#  'resolve',
#  'respond',
#  'restore',
#  'retain',
#  'retaliate',
#  'retreat',
#  'retrieve',
#  'reveal',
#  'review',
#  'revise',
#  'revitalize',
#  'revolutionize',
#  'ride',
#  'rip',
#  'rise',
#  'risk',
#  'rob',
#  'rock',
#  'roil',
#  'roll',
#  'romp',
#  'rub',
#  'ruffle',
#  'run',
#  'rupture',
#  'rush',
#  'sail',
#  'salute',
#  'sap',
#  'satisfy',
#  'save',
#  'saw',
#  'scald',
#  'scale',
#  'scamper',
#  'scan',
#  'scar',
#  'scare',
#  'scatter',
#  'scavenge',
#  'schedule',
#  'scold',
#  'scoop',
#  'scoot',
#  'score',
#  'scorn',
#  'scour',
#  'scout',
#  'scrap',
#  'scrape',
#  'scratch',
#  'scrawl',
#  'scream',
#  'screen',
#  'screw',
#  'scrub',
#  'scruff',
#  'scuffle',
#  'sculpt',
#  'scuttle',
#  'seal',
#  'sear',
#  'search',
#  'secure',
#  'seduce',
#  'segment',
#  'seize',
#  'select',
#  'sell',
#  'sense',
#  'serve',
#  'service',
#  'set',
#  'set',
#  'up',
#  'sever',
#  'sew',
#  'shake',
#  'shanghai',
#  'shape',
#  'Shaped',
#  'share',
#  'sharpen',
#  'shatter',
#  'shave',
#  'shave',
#  'down',
#  'shear',
#  'shell',
#  'shield',
#  'shift',
#  'shiver',
#  'shock',
#  'shoot',
#  'shorten',
#  'shoulder',
#  'shout',
#  'shove',
#  'shovel',
#  'shrink',
#  'shun',
#  'shut',
#  'sidestep',
#  'sigh',
#  'signal',
#  'simplify',
#  'sip',
#  'sit',
#  'size',
#  'skid',
#  'skim',
#  'skip',
#  'skirt',
#  'slacken',
#  'slam',
#  'slap',
#  'slash',
#  'slaughter',
#  'slay',
#  'slide',
#  'slug',
#  'smack',
#  'smash',
#  'smear',
#  'smell',
#  'smite',
#  'smuggle',
#  'snap',
#  'snare',
#  'snarl',
#  'snatch',
#  'snicker',
#  'sniff',
#  'snitch',
#  'snoop',
#  'snub',
#  'snuff',
#  'snuggle',
#  'soak',
#  'sock',
#  'soil',
#  'sold',
#  'solve',
#  'sort',
#  'spark',
#  'spear',
#  'spearhead',
#  'Spearheaded',
#  'specialize',
#  'specify',
#  'spell',
#  'spike',
#  'spin',
#  'splatter',
#  'splice',
#  'split',
#  'spot',
#  'spray',
#  'spread',
#  'spring',
#  'sprint',
#  'spur',
#  'spurn',
#  'spy',
#  'squabble',
#  'squash',
#  'squeak',
#  'squelch',
#  'stack',
#  'staff',
#  'stagger',
#  'stamp',
#  'stand',
#  ...]

# %%
# 소문자로 변환
pre_lower_wd = [i.lower() for i in preprossed]
pre_lower_wd
# Out:
# ['abandon',
#  'abduct',
#  'abhor',
#  'abolish',
#  'abominate',
#  'abscond',
#  'abuse',
#  'accelerate',
#  'accomplish',
#  'accost',
#  'accrue',
#  'accumulate',
#  'accuse',
#  'achieve',
#  'acquire',
#  'act',
#  'activate',
#  'actualized',
#  'adapt',
#  'address',
#  'adjust',
#  'administer',
#  'advance',
#  'advise',
#  'advocate',
#  'affirm',
#  'afflict',
#  'affray',
#  'affront',
#  'aggravate',
#  'agitate\xa0',
#  'aid',
#  'ail',
#  'aim',
#  'alert',
#  'allocate',
#  'altercate',
#  'amplify',
#  'analyze',
#  'annihilate',
#  'annoy',
#  'antagonize',
#  'anticipate',
#  'appoint',
#  'apprehend',
#  'approach',
#  'arbitrate',
#  'arrange',
#  'arrest',
#  'assault',
#  'assemble',
#  'assess',
#  'assign',
#  'assist',
#  'assure',
#  'attack',
#  'attain',
#  'attract',
#  'audit',
#  'augment',
#  'authenticate',
#  'author',
#  'authorize',
#  'automate',
#  'avert',
#  'avoid',
#  'award',
#  'balance',
#  'bang',
#  'bank',
#  'bar',
#  'bash',
#  'battle',
#  'beat',
#  'berate',
#  'bicker',
#  'biff',
#  'bill',
#  'billow',
#  'bite',
#  'blast',
#  'blend',
#  'blended',
#  'block',
#  'blow',
#  'bolster',
#  'boost',
#  'brabble',
#  'brace',
#  'brawl',
#  'brief',
#  'brighten',
#  'broke',
#  'buck',
#  'built',
#  'bump',
#  'burst',
#  'bury',
#  'bushwhack',
#  'calculate',
#  'calm',
#  'campaign',
#  'cancel',
#  'capitalize',
#  'carry',
#  'out',
#  'catch',
#  'centralize',
#  'certify',
#  'chair',
#  'challenge',
#  'champion',
#  'change',
#  'channel',
#  'charge',
#  'chart',
#  'charter',
#  'chase',
#  'check',
#  'choke',
#  'circumscribe',
#  'circumvent',
#  'clap',
#  'clarify',
#  'clash',
#  'classify',
#  'climb',
#  'clip',
#  'clutch',
#  'coach',
#  'co-authored',
#  'coded',
#  'collaborate',
#  'collapse',
#  'collar',
#  'collate',
#  'collect',
#  'collide',
#  'combat',
#  'combine',
#  'command',
#  'commandeer',
#  'commit',
#  'communicate',
#  'compile',
#  'complete',
#  'compose',
#  'compute',
#  'conceive',
#  'conceptualize',
#  'condense',
#  'conduct',
#  'confer',
#  'configure',
#  'confront',
#  'conserve',
#  'consolidate',
#  'construct',
#  'consult',
#  'contend',
#  'contract',
#  'contribute',
#  'control',
#  'converse',
#  'convert',
#  'convey',
#  'cooperate',
#  'coordinate',
#  'coproduced',
#  'correlate',
#  'correspond',
#  'counsel',
#  'count',
#  'crafted',
#  'cram',
#  'crash',
#  'crawl',
#  'create',
#  'creep',
#  'cripple',
#  'critique',
#  'croak',
#  'crouch',
#  'crush',
#  'cultivate',
#  'cure',
#  'curse',
#  'curtail',
#  'customize',
#  'cut',
#  'dance',
#  'dare',
#  'dart',
#  'dash',
#  'daunt\xa0',
#  'deal',
#  'debate',
#  'debut',
#  'decide',
#  'deck',
#  'decorate',
#  'decrease',
#  'deduct',
#  'deface',
#  'defame',
#  'defeat',
#  'defended',
#  'define',
#  'defy',
#  'delegate',
#  'delete',
#  'deliberate',
#  'delineate',
#  'deliver',
#  'demonstrate',
#  'demoralize\xa0',
#  'deplore',
#  'deprecate',
#  'derive',
#  'descend',
#  'describe',
#  'design',
#  'designate',
#  'despise',
#  'destroy',
#  'detail',
#  'detect',
#  'determine',
#  'detest',
#  'detonate',
#  'develop',
#  'devise',
#  'diagnose',
#  'dictate',
#  'dig',
#  'diminish',
#  'direct',
#  'disable',
#  'disapprove',
#  'discard',
#  'discharge',
#  'discomfort\xa0',
#  'discompose\xa0',
#  'discourage\xa0',
#  'discover',
#  'discuss',
#  'disdain',
#  'disesteem',
#  'disfavor',
#  'disharmonize',
#  'dishearten\xa0',
#  'dismay\xa0',
#  'dispatch',
#  'dispirit\xa0',
#  'display',
#  'dispute',
#  'dissect',
#  'dissent',
#  'disservice',
#  'distinguish',
#  'distress\xa0',
#  'distribute',
#  'disturb\xa0',
#  'ditch',
#  'dive',
#  'divert',
#  'divide',
#  'document',
#  'dodge',
#  'dominate',
#  'dope',
#  'double',
#  'douse',
#  'draft',
#  'drag',
#  'drain',
#  'dramatize',
#  'drape',
#  'draw',
#  'dress',
#  'drill',
#  'drink',
#  'drip',
#  'drive',
#  'drop',
#  'drown',
#  'drug',
#  'dry',
#  'duel',
#  'dunk',
#  'earn',
#  'ease',
#  'edge',
#  'edit',
#  'educate',
#  'effect',
#  'eject',
#  'elevate',
#  'eliminate',
#  'elope',
#  'elude',
#  'emerge',
#  'employ',
#  'emulate',
#  'enable',
#  'enact',
#  'encounter',
#  'encourage',
#  'endeavor',
#  'endure',
#  'enforce',
#  'enforced',
#  'engage',
#  'engineer',
#  'enhance',
#  'enjoin',
#  'enlarge',
#  'enlighten',
#  'enlist',
#  'enraged',
#  'ensnare',
#  'ensure',
#  'enter',
#  'envy',
#  'equip',
#  'erupt',
#  'escalate',
#  'escape',
#  'establish',
#  'estimate',
#  'evacuate',
#  'evade',
#  'evaluate',
#  'evict',
#  'examine',
#  'exceed',
#  'execrate',
#  'execute',
#  'exert',
#  'exhale',
#  'exhibit',
#  'exit',
#  'expand',
#  'expedite',
#  'expedited',
#  'expel',
#  'experience',
#  'experiment',
#  'explain',
#  'explode',
#  'expose',
#  'extend',
#  'extirpate',
#  'extract',
#  'extricate',
#  'face',
#  'facilitate',
#  'fade',
#  'fake',
#  'fall',
#  'falter',
#  'fan',
#  'fashion',
#  'fast',
#  'fear',
#  'feed',
#  'fend',
#  'field',
#  'fight',
#  'file',
#  'fill',
#  'finger',
#  'fix',
#  'flag',
#  'flap',
#  'flash',
#  'flatten',
#  'flaunt',
#  'flay',
#  'flee',
#  'flick',
#  'flinch',
#  'fling',
#  'flip',
#  'flit',
#  'float',
#  'flog',
#  'flounder',
#  'flout',
#  'flush',
#  'fly',
#  'focus',
#  'fondle',
#  'force',
#  'forecast',
#  'forecasted',
#  'forge',
#  'form',
#  'formalize',
#  'formulate',
#  'fornicate',
#  'foster',
#  'found',
#  'fray',
#  'freak',
#  'frustrate',
#  'fulfill',
#  'fumble',
#  'fund',
#  'furnish',
#  'gain',
#  'gall',
#  'gallop',
#  'gash',
#  'gather',
#  'generate',
#  'gesture',
#  'gnaw',
#  'gossip',
#  'gouge',
#  'govern',
#  'grab',
#  'graduate',
#  'grapple',
#  'grasp',
#  'greet',
#  'grew',
#  'grind',
#  'grip',
#  'groomed',
#  'grope',
#  'ground',
#  'grow',
#  'growl',
#  'grunt',
#  'guard',
#  'guide',
#  'gyrate',
#  'hack',
#  'hail',
#  'halt',
#  'halve',
#  'hammer',
#  'handle',
#  'hang',
#  'harass',
#  'hassle',
#  'hasten',
#  'haul',
#  'head',
#  'helm',
#  'hesitate',
#  'hide',
#  'hijack',
#  'hinder',
#  'hire',
#  'hit',
#  'hitch',
#  'hobble',
#  'hoist',
#  'hold',
#  'hover',
#  'huff',
#  'hug',
#  'hurl',
#  'hurtle',
#  'hypothesize',
#  'icky',
#  'identify',
#  'ignore',
#  'illustrate',
#  'imitate',
#  'impeach',
#  'implement',
#  'importune',
#  'improve',
#  'improved',
#  'improvise',
#  'incense',
#  'inch',
#  'increase',
#  'incriminate',
#  'index',
#  'indict',
#  'indignant',
#  'indignation',
#  'indignity',
#  'individualize',
#  'induce',
#  'inequity',
#  'infighting',
#  'inflame',
#  'inflate',
#  'inflict',
#  'influence',
#  'inform',
#  'infuriate',
#  'initiate',
#  'initiated',
#  'inject',
#  'injure',
#  'innovate',
#  'insert',
#  'inspect',
#  'inspire',
#  'inspired',
#  'install',
#  'instigate',
#  'institute',
#  'instruct',
#  'instructed',
#  'insult',
#  'integrate',
#  'intensify',
#  'interchange',
#  'interpret',
#  'interview',
#  'introduce',
#  'invade',
#  'invent',
#  'invented',
#  'inventory',
#  'invest',
#  'investigate',
#  'investigated',
#  'involve',
#  'irateness',
#  'isolate',
#  'itemize',
#  'jab',
#  'jam',
#  'jangle',
#  'jar',
#  'jeer',
#  'jerk',
#  'jimmy',
#  'jingle',
#  'join',
#  'joined',
#  'jolt',
#  'judge',
#  'jump',
#  'justify',
#  'keel',
#  'keynote',
#  'kibitz',
#  'kick',
#  'kidnap',
#  'kill',
#  'kneel',
#  'knife',
#  'label',
#  'land',
#  'lash',
#  'launch',
#  'lead',
#  'lean',
#  'leap',
#  'learn',
#  'lecture',
#  'led',
#  'left',
#  'lessen',
#  'level',
#  'liaise',
#  'license',
#  'lick',
#  'lift',
#  'lifted',
#  'limp',
#  'link',
#  'list',
#  'listen',
#  'loathe',
#  'locate',
#  'log',
#  'lower',
#  'lunge',
#  'lurch',
#  'magnify',
#  'maim',
#  'maintain',
#  'manage',
#  'managed',
#  'mangle',
#  'manipulate',
#  'manufacture',
#  'march',
#  'mark',
#  'market',
#  'married',
#  'massage',
#  'master',
#  'mastermind',
#  'maul',
#  'maximize',
#  'measure',
#  'meddle',
#  'mediate',
#  'meet',
#  'mend',
#  'mentor',
#  'mentored',
#  'merge',
#  'merged',
#  'mimic',
#  'mingle',
#  'minimize',
#  'mobilize',
#  'mobilized',
#  'mock',
#  'model',
#  'mold',
#  'molest',
#  'monitor',
#  'motivate',
#  'motivated',
#  'mourn',
#  'move',
#  'multiply',
#  'mumble',
#  'murder',
#  'muster',
#  'mutilate',
#  'nab',
#  'nag',
#  'nail',
#  'narrow',
#  'needle',
#  'negotiate',
#  'negotiated',
#  'network',
#  'nick',
#  'nip',
#  'nominate',
#  'nurture',
#  'object',
#  'observe',
#  'obtain',
#  'occupy',
#  'offense',
#  'offer',
#  'officiate',
#  'operate',
#  'operated',
#  'oppose',
#  'oppress',
#  'orchestrate',
#  'order',
#  'organize',
#  'organized',
#  'originate',
#  'originated',
#  'outline',
#  'outlined',
#  'outpace',
#  'outpaced',
#  'outperform',
#  'outperformed',
#  'outrage',
#  'overcome',
#  'overhaul',
#  'oversaw',
#  'oversee',
#  'pack',
#  'paddle',
#  'page',
#  'pander',
#  'panic',
#  'parachute',
#  'parade',
#  'paralyze',
#  'park',
#  'parry',
#  'participate',
#  'partnered',
#  'party',
#  'pass',
#  'pat',
#  'patrol',
#  'pause',
#  'paw',
#  'peel',
#  'peep',
#  'penetrate',
#  'perceive',
#  'perfect',
#  'perform',
#  'performed',
#  'persuade',
#  'photograph',
#  'pick',
#  'picket',
#  'pile',
#  'pilot',
#  'pin',
#  'pinch',
#  'pioneer',
#  'pioneered',
#  'pique',
#  'pirate',
#  'pitch',
#  'placate',
#  'place',
#  'plan',
#  'plod',
#  'plow',
#  'plunge',
#  'pocket',
#  'poke',
#  'polish',
#  'pore',
#  'pose',
#  'position',
#  'pounce',
#  'pound',
#  'pout',
#  'pray',
#  'predict',
#  'preen',
#  'prepare',
#  'prepared',
#  'prescribe',
#  'present',
#  'preside',
#  'primp',
#  'print',
#  'prioritize',
#  'probe',
#  'process',
#  'procure',
#  'prod',
#  'produce',
#  'produced',
#  'profitable',
#  'program',
#  'programmed',
#  'project',
#  'promote',
#  'prompt',
#  'proofread',
#  'propel',
#  'propose',
#  'protect',
#  'protest',
#  'prove',
#  'provide',
#  'provoke',
#  'pry',
#  'publicize',
#  'publicized',
#  'publish',
#  'published',
#  'pull',
#  'pummel',
#  'pump',
#  'punch',
#  'purchase',
#  'purge',
#  'pursue',
#  'push',
#  'qualify',
#  'quarrel',
#  'quell',
#  'question',
#  'quibble',
#  'quicken',
#  'quit',
#  'quiz',
#  'race',
#  'raid',
#  'raise',
#  'raised',
#  'rally',
#  'ram',
#  'rank',
#  'rankle',
#  'ransack',
#  'rape',
#  'rate',
#  'rattle',
#  'ravage',
#  'rave',
#  'reach',
#  'reached',
#  'read',
#  'realize',
#  'realized',
#  'rebuild',
#  'receive',
#  'recline',
#  'recommend',
#  'reconcile',
#  'reconnoiter',
#  'record',
#  'recoup',
#  'recruit',
#  'redeem',
#  'reduce',
#  'reel',
#  'refer',
#  'regain',
#  'regulate',
#  'reinforce',
#  'rejoin',
#  'relate',
#  'relax',
#  'relay',
#  'relent',
#  'relieve',
#  'remodeled',
#  'remove',
#  'render',
#  'renew',
#  'renovate',
#  'reorganize',
#  'repair',
#  'repel',
#  'report',
#  'reposition',
#  'represent',
#  'repress',
#  'repulse',
#  'repulsion',
#  'research',
#  'resign',
#  'resist',
#  'resolve',
#  'respond',
#  'restore',
#  'retain',
#  'retaliate',
#  'retreat',
#  'retrieve',
#  'reveal',
#  'review',
#  'revise',
#  'revitalize',
#  'revolutionize',
#  'ride',
#  'rip',
#  'rise',
#  'risk',
#  'rob',
#  'rock',
#  'roil',
#  'roll',
#  'romp',
#  'rub',
#  'ruffle',
#  'run',
#  'rupture',
#  'rush',
#  'sail',
#  'salute',
#  'sap',
#  'satisfy',
#  'save',
#  'saw',
#  'scald',
#  'scale',
#  'scamper',
#  'scan',
#  'scar',
#  'scare',
#  'scatter',
#  'scavenge',
#  'schedule',
#  'scold',
#  'scoop',
#  'scoot',
#  'score',
#  'scorn',
#  'scour',
#  'scout',
#  'scrap',
#  'scrape',
#  'scratch',
#  'scrawl',
#  'scream',
#  'screen',
#  'screw',
#  'scrub',
#  'scruff',
#  'scuffle',
#  'sculpt',
#  'scuttle',
#  'seal',
#  'sear',
#  'search',
#  'secure',
#  'seduce',
#  'segment',
#  'seize',
#  'select',
#  'sell',
#  'sense',
#  'serve',
#  'service',
#  'set',
#  'set',
#  'up',
#  'sever',
#  'sew',
#  'shake',
#  'shanghai',
#  'shape',
#  'shaped',
#  'share',
#  'sharpen',
#  'shatter',
#  'shave',
#  'shave',
#  'down',
#  'shear',
#  'shell',
#  'shield',
#  'shift',
#  'shiver',
#  'shock',
#  'shoot',
#  'shorten',
#  'shoulder',
#  'shout',
#  'shove',
#  'shovel',
#  'shrink',
#  'shun',
#  'shut',
#  'sidestep',
#  'sigh',
#  'signal',
#  'simplify',
#  'sip',
#  'sit',
#  'size',
#  'skid',
#  'skim',
#  'skip',
#  'skirt',
#  'slacken',
#  'slam',
#  'slap',
#  'slash',
#  'slaughter',
#  'slay',
#  'slide',
#  'slug',
#  'smack',
#  'smash',
#  'smear',
#  'smell',
#  'smite',
#  'smuggle',
#  'snap',
#  'snare',
#  'snarl',
#  'snatch',
#  'snicker',
#  'sniff',
#  'snitch',
#  'snoop',
#  'snub',
#  'snuff',
#  'snuggle',
#  'soak',
#  'sock',
#  'soil',
#  'sold',
#  'solve',
#  'sort',
#  'spark',
#  'spear',
#  'spearhead',
#  'spearheaded',
#  'specialize',
#  'specify',
#  'spell',
#  'spike',
#  'spin',
#  'splatter',
#  'splice',
#  'split',
#  'spot',
#  'spray',
#  'spread',
#  'spring',
#  'sprint',
#  'spur',
#  'spurn',
#  'spy',
#  'squabble',
#  'squash',
#  'squeak',
#  'squelch',
#  'stack',
#  'staff',
#  'stagger',
#  'stamp',
#  'stand',
#  ...]

# %% [markdown]
# # 이것을 단어 원형으로 변환

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# 방법 1 : 표제어추출, 동사는 현재형으로 변환
lemma_list =[]
for i in preprossed:
    lema_re = lemmatizer.lemmatize(i, pos='v') #표제어 추출, 동사는 현재형으로 변환
    lemma_list.append(lema_re)
    
lemma_list
# Out:
# ['abandon',
#  'abduct',
#  'abhor',
#  'abolish',
#  'abominate',
#  'abscond',
#  'abuse',
#  'accelerate',
#  'accomplish',
#  'accost',
#  'accrue',
#  'accumulate',
#  'accuse',
#  'achieve',
#  'acquire',
#  'act',
#  'activate',
#  'Actualized',
#  'adapt',
#  'address',
#  'adjust',
#  'administer',
#  'advance',
#  'advise',
#  'advocate',
#  'affirm',
#  'afflict',
#  'affray',
#  'affront',
#  'aggravate',
#  'agitate\xa0',
#  'aid',
#  'ail',
#  'aim',
#  'alert',
#  'allocate',
#  'altercate',
#  'amplify',
#  'analyze',
#  'annihilate',
#  'annoy',
#  'antagonize',
#  'anticipate',
#  'appoint',
#  'apprehend',
#  'approach',
#  'arbitrate',
#  'arrange',
#  'arrest',
#  'assault',
#  'assemble',
#  'assess',
#  'assign',
#  'assist',
#  'assure',
#  'attack',
#  'attain',
#  'attract',
#  'audit',
#  'augment',
#  'authenticate',
#  'author',
#  'authorize',
#  'automate',
#  'avert',
#  'avoid',
#  'award',
#  'balance',
#  'bang',
#  'bank',
#  'bar',
#  'bash',
#  'battle',
#  'beat',
#  'berate',
#  'bicker',
#  'biff',
#  'bill',
#  'billow',
#  'bite',
#  'blast',
#  'blend',
#  'Blended',
#  'block',
#  'blow',
#  'bolster',
#  'boost',
#  'brabble',
#  'brace',
#  'brawl',
#  'brief',
#  'brighten',
#  'break',
#  'buck',
#  'build',
#  'bump',
#  'burst',
#  'bury',
#  'bushwhack',
#  'calculate',
#  'calm',
#  'campaign',
#  'cancel',
#  'capitalize',
#  'carry',
#  'out',
#  'catch',
#  'centralize',
#  'certify',
#  'chair',
#  'challenge',
#  'champion',
#  'change',
#  'channel',
#  'charge',
#  'chart',
#  'charter',
#  'chase',
#  'check',
#  'choke',
#  'circumscribe',
#  'circumvent',
#  'clap',
#  'clarify',
#  'clash',
#  'classify',
#  'climb',
#  'clip',
#  'clutch',
#  'coach',
#  'Co-authored',
#  'Coded',
#  'collaborate',
#  'collapse',
#  'collar',
#  'collate',
#  'collect',
#  'collide',
#  'combat',
#  'combine',
#  'command',
#  'commandeer',
#  'commit',
#  'communicate',
#  'compile',
#  'complete',
#  'compose',
#  'compute',
#  'conceive',
#  'conceptualize',
#  'condense',
#  'conduct',
#  'confer',
#  'configure',
#  'confront',
#  'conserve',
#  'consolidate',
#  'construct',
#  'consult',
#  'contend',
#  'contract',
#  'contribute',
#  'control',
#  'converse',
#  'convert',
#  'convey',
#  'cooperate',
#  'coordinate',
#  'Coproduced',
#  'correlate',
#  'correspond',
#  'counsel',
#  'count',
#  'Crafted',
#  'cram',
#  'crash',
#  'crawl',
#  'create',
#  'creep',
#  'cripple',
#  'critique',
#  'croak',
#  'crouch',
#  'crush',
#  'cultivate',
#  'cure',
#  'curse',
#  'curtail',
#  'customize',
#  'cut',
#  'dance',
#  'dare',
#  'dart',
#  'dash',
#  'daunt\xa0',
#  'deal',
#  'debate',
#  'debut',
#  'decide',
#  'deck',
#  'decorate',
#  'decrease',
#  'deduct',
#  'deface',
#  'defame',
#  'defeat',
#  'Defended',
#  'define',
#  'defy',
#  'delegate',
#  'delete',
#  'deliberate',
#  'delineate',
#  'deliver',
#  'demonstrate',
#  'demoralize\xa0',
#  'deplore',
#  'deprecate',
#  'derive',
#  'descend',
#  'describe',
#  'design',
#  'designate',
#  'despise',
#  'destroy',
#  'detail',
#  'detect',
#  'determine',
#  'detest',
#  'detonate',
#  'develop',
#  'devise',
#  'diagnose',
#  'dictate',
#  'dig',
#  'diminish',
#  'direct',
#  'disable',
#  'disapprove',
#  'discard',
#  'discharge',
#  'discomfort\xa0',
#  'discompose\xa0',
#  'discourage\xa0',
#  'discover',
#  'discuss',
#  'disdain',
#  'disesteem',
#  'disfavor',
#  'disharmonize',
#  'dishearten\xa0',
#  'dismay\xa0',
#  'dispatch',
#  'dispirit\xa0',
#  'display',
#  'dispute',
#  'dissect',
#  'dissent',
#  'disservice',
#  'distinguish',
#  'distress\xa0',
#  'distribute',
#  'disturb\xa0',
#  'ditch',
#  'dive',
#  'divert',
#  'divide',
#  'document',
#  'dodge',
#  'dominate',
#  'dope',
#  'double',
#  'douse',
#  'draft',
#  'drag',
#  'drain',
#  'dramatize',
#  'drape',
#  'draw',
#  'dress',
#  'drill',
#  'drink',
#  'drip',
#  'drive',
#  'drop',
#  'drown',
#  'drug',
#  'dry',
#  'duel',
#  'dunk',
#  'earn',
#  'ease',
#  'edge',
#  'edit',
#  'educate',
#  'effect',
#  'eject',
#  'elevate',
#  'eliminate',
#  'elope',
#  'elude',
#  'emerge',
#  'employ',
#  'emulate',
#  'enable',
#  'enact',
#  'encounter',
#  'encourage',
#  'endeavor',
#  'endure',
#  'enforce',
#  'Enforced',
#  'engage',
#  'engineer',
#  'enhance',
#  'enjoin',
#  'enlarge',
#  'enlighten',
#  'enlist',
#  'enrage',
#  'ensnare',
#  'ensure',
#  'enter',
#  'envy',
#  'equip',
#  'erupt',
#  'escalate',
#  'escape',
#  'establish',
#  'estimate',
#  'evacuate',
#  'evade',
#  'evaluate',
#  'evict',
#  'examine',
#  'exceed',
#  'execrate',
#  'execute',
#  'exert',
#  'exhale',
#  'exhibit',
#  'exit',
#  'expand',
#  'expedite',
#  'Expedited',
#  'expel',
#  'experience',
#  'experiment',
#  'explain',
#  'explode',
#  'expose',
#  'extend',
#  'extirpate',
#  'extract',
#  'extricate',
#  'face',
#  'facilitate',
#  'fade',
#  'fake',
#  'fall',
#  'falter',
#  'fan',
#  'fashion',
#  'fast',
#  'fear',
#  'fee',
#  'fend',
#  'field',
#  'fight',
#  'file',
#  'fill',
#  'finger',
#  'fix',
#  'flag',
#  'flap',
#  'flash',
#  'flatten',
#  'flaunt',
#  'flay',
#  'flee',
#  'flick',
#  'flinch',
#  'fling',
#  'flip',
#  'flit',
#  'float',
#  'flog',
#  'flounder',
#  'flout',
#  'flush',
#  'fly',
#  'focus',
#  'fondle',
#  'force',
#  'forecast',
#  'Forecasted',
#  'forge',
#  'form',
#  'formalize',
#  'formulate',
#  'fornicate',
#  'foster',
#  'find',
#  'fray',
#  'freak',
#  'frustrate',
#  'Fulfill',
#  'fumble',
#  'fund',
#  'furnish',
#  'gain',
#  'gall',
#  'gallop',
#  'gash',
#  'gather',
#  'generate',
#  'gesture',
#  'gnaw',
#  'gossip',
#  'gouge',
#  'govern',
#  'grab',
#  'graduate',
#  'grapple',
#  'grasp',
#  'greet',
#  'Grew',
#  'grind',
#  'grip',
#  'Groomed',
#  'grope',
#  'grind',
#  'grow',
#  'growl',
#  'grunt',
#  'guard',
#  'guide',
#  'gyrate',
#  'hack',
#  'hail',
#  'halt',
#  'halve',
#  'hammer',
#  'handle',
#  'hang',
#  'harass',
#  'hassle',
#  'hasten',
#  'haul',
#  'head',
#  'helm',
#  'hesitate',
#  'hide',
#  'hijack',
#  'hinder',
#  'hire',
#  'hit',
#  'hitch',
#  'hobble',
#  'hoist',
#  'hold',
#  'hover',
#  'huff',
#  'hug',
#  'hurl',
#  'hurtle',
#  'hypothesize',
#  'icky',
#  'identify',
#  'ignore',
#  'illustrate',
#  'imitate',
#  'impeach',
#  'implement',
#  'importune',
#  'improve',
#  'Improved',
#  'improvise',
#  'incense',
#  'inch',
#  'increase',
#  'incriminate',
#  'index',
#  'indict',
#  'indignant',
#  'indignation',
#  'indignity',
#  'individualize',
#  'induce',
#  'inequity',
#  'infighting',
#  'inflame',
#  'inflate',
#  'inflict',
#  'influence',
#  'inform',
#  'infuriate',
#  'initiate',
#  'Initiated',
#  'inject',
#  'injure',
#  'innovate',
#  'insert',
#  'inspect',
#  'inspire',
#  'Inspired',
#  'install',
#  'instigate',
#  'institute',
#  'instruct',
#  'Instructed',
#  'insult',
#  'integrate',
#  'intensify',
#  'interchange',
#  'interpret',
#  'interview',
#  'introduce',
#  'invade',
#  'invent',
#  'Invented',
#  'inventory',
#  'invest',
#  'investigate',
#  'Investigated',
#  'involve',
#  'irateness',
#  'isolate',
#  'itemize',
#  'jab',
#  'jam',
#  'jangle',
#  'jar',
#  'jeer',
#  'jerk',
#  'jimmy',
#  'jingle',
#  'join',
#  'Joined',
#  'jolt',
#  'judge',
#  'jump',
#  'justify',
#  'keel',
#  'keynote',
#  'kibitz',
#  'kick',
#  'kidnap',
#  'kill',
#  'kneel',
#  'knife',
#  'label',
#  'land',
#  'lash',
#  'launch',
#  'lead',
#  'lean',
#  'leap',
#  'learn',
#  'lecture',
#  'lead',
#  'leave',
#  'lessen',
#  'level',
#  'liaise',
#  'license',
#  'lick',
#  'lift',
#  'Lifted',
#  'limp',
#  'link',
#  'list',
#  'listen',
#  'loathe',
#  'locate',
#  'log',
#  'lower',
#  'lunge',
#  'lurch',
#  'magnify',
#  'maim',
#  'maintain',
#  'manage',
#  'Managed',
#  'mangle',
#  'manipulate',
#  'manufacture',
#  'march',
#  'mark',
#  'market',
#  'Married',
#  'massage',
#  'master',
#  'mastermind',
#  'maul',
#  'maximize',
#  'measure',
#  'meddle',
#  'mediate',
#  'meet',
#  'mend',
#  'mentor',
#  'Mentored',
#  'merge',
#  'Merged',
#  'mimic',
#  'mingle',
#  'minimize',
#  'mobilize',
#  'Mobilized',
#  'mock',
#  'model',
#  'mold',
#  'molest',
#  'monitor',
#  'motivate',
#  'Motivated',
#  'mourn',
#  'move',
#  'multiply',
#  'mumble',
#  'murder',
#  'muster',
#  'mutilate',
#  'nab',
#  'nag',
#  'nail',
#  'narrow',
#  'needle',
#  'negotiate',
#  'Negotiated',
#  'network',
#  'nick',
#  'nip',
#  'nominate',
#  'nurture',
#  'object',
#  'observe',
#  'obtain',
#  'occupy',
#  'offense',
#  'offer',
#  'officiate',
#  'operate',
#  'Operated',
#  'oppose',
#  'oppress',
#  'orchestrate',
#  'order',
#  'organize',
#  'Organized',
#  'originate',
#  'Originated',
#  'outline',
#  'Outlined',
#  'outpace',
#  'Outpaced',
#  'outperform',
#  'Outperformed',
#  'outrage',
#  'overcome',
#  'overhaul',
#  'Oversaw',
#  'oversee',
#  'pack',
#  'paddle',
#  'page',
#  'pander',
#  'panic',
#  'parachute',
#  'parade',
#  'paralyze',
#  'park',
#  'parry',
#  'participate',
#  'Partnered',
#  'party',
#  'pass',
#  'pat',
#  'patrol',
#  'pause',
#  'paw',
#  'peel',
#  'peep',
#  'penetrate',
#  'perceive',
#  'perfect',
#  'perform',
#  'Performed',
#  'persuade',
#  'photograph',
#  'pick',
#  'picket',
#  'pile',
#  'pilot',
#  'pin',
#  'pinch',
#  'pioneer',
#  'Pioneered',
#  'pique',
#  'pirate',
#  'pitch',
#  'placate',
#  'place',
#  'plan',
#  'plod',
#  'plow',
#  'plunge',
#  'pocket',
#  'poke',
#  'polish',
#  'pore',
#  'pose',
#  'position',
#  'pounce',
#  'pound',
#  'pout',
#  'pray',
#  'predict',
#  'preen',
#  'prepare',
#  'Prepared',
#  'prescribe',
#  'present',
#  'preside',
#  'primp',
#  'print',
#  'prioritize',
#  'probe',
#  'process',
#  'procure',
#  'prod',
#  'produce',
#  'Produced',
#  'profitable',
#  'program',
#  'Programmed',
#  'project',
#  'promote',
#  'prompt',
#  'proofread',
#  'propel',
#  'propose',
#  'protect',
#  'protest',
#  'prove',
#  'provide',
#  'provoke',
#  'pry',
#  'publicize',
#  'Publicized',
#  'publish',
#  'Published',
#  'pull',
#  'pummel',
#  'pump',
#  'punch',
#  'purchase',
#  'purge',
#  'pursue',
#  'push',
#  'qualify',
#  'quarrel',
#  'quell',
#  'question',
#  'quibble',
#  'quicken',
#  'quit',
#  'quiz',
#  'race',
#  'raid',
#  'raise',
#  'Raised',
#  'rally',
#  'ram',
#  'rank',
#  'rankle',
#  'ransack',
#  'rape',
#  'rate',
#  'rattle',
#  'ravage',
#  'rave',
#  'reach',
#  'Reached',
#  'read',
#  'realize',
#  'Realized',
#  'rebuild',
#  'receive',
#  'recline',
#  'recommend',
#  'reconcile',
#  'reconnoiter',
#  'record',
#  'recoup',
#  'recruit',
#  'redeem',
#  'reduce',
#  'reel',
#  'refer',
#  'regain',
#  'regulate',
#  'reinforce',
#  'rejoin',
#  'relate',
#  'relax',
#  'relay',
#  'relent',
#  'relieve',
#  'Remodeled',
#  'remove',
#  'render',
#  'renew',
#  'renovate',
#  'reorganize',
#  'repair',
#  'repel',
#  'report',
#  'reposition',
#  'represent',
#  'repress',
#  'repulse',
#  'repulsion',
#  'research',
#  'resign',
#  'resist',
#  'resolve',
#  'respond',
#  'restore',
#  'retain',
#  'retaliate',
#  'retreat',
#  'retrieve',
#  'reveal',
#  'review',
#  'revise',
#  'revitalize',
#  'revolutionize',
#  'ride',
#  'rip',
#  'rise',
#  'risk',
#  'rob',
#  'rock',
#  'roil',
#  'roll',
#  'romp',
#  'rub',
#  'ruffle',
#  'run',
#  'rupture',
#  'rush',
#  'sail',
#  'salute',
#  'sap',
#  'satisfy',
#  'save',
#  'saw',
#  'scald',
#  'scale',
#  'scamper',
#  'scan',
#  'scar',
#  'scare',
#  'scatter',
#  'scavenge',
#  'schedule',
#  'scold',
#  'scoop',
#  'scoot',
#  'score',
#  'scorn',
#  'scour',
#  'scout',
#  'scrap',
#  'scrape',
#  'scratch',
#  'scrawl',
#  'scream',
#  'screen',
#  'screw',
#  'scrub',
#  'scruff',
#  'scuffle',
#  'sculpt',
#  'scuttle',
#  'seal',
#  'sear',
#  'search',
#  'secure',
#  'seduce',
#  'segment',
#  'seize',
#  'select',
#  'sell',
#  'sense',
#  'serve',
#  'service',
#  'set',
#  'set',
#  'up',
#  'sever',
#  'sew',
#  'shake',
#  'shanghai',
#  'shape',
#  'Shaped',
#  'share',
#  'sharpen',
#  'shatter',
#  'shave',
#  'shave',
#  'down',
#  'shear',
#  'shell',
#  'shield',
#  'shift',
#  'shiver',
#  'shock',
#  'shoot',
#  'shorten',
#  'shoulder',
#  'shout',
#  'shove',
#  'shovel',
#  'shrink',
#  'shun',
#  'shut',
#  'sidestep',
#  'sigh',
#  'signal',
#  'simplify',
#  'sip',
#  'sit',
#  'size',
#  'skid',
#  'skim',
#  'skip',
#  'skirt',
#  'slacken',
#  'slam',
#  'slap',
#  'slash',
#  'slaughter',
#  'slay',
#  'slide',
#  'slug',
#  'smack',
#  'smash',
#  'smear',
#  'smell',
#  'smite',
#  'smuggle',
#  'snap',
#  'snare',
#  'snarl',
#  'snatch',
#  'snicker',
#  'sniff',
#  'snitch',
#  'snoop',
#  'snub',
#  'snuff',
#  'snuggle',
#  'soak',
#  'sock',
#  'soil',
#  'sell',
#  'solve',
#  'sort',
#  'spark',
#  'spear',
#  'spearhead',
#  'Spearheaded',
#  'specialize',
#  'specify',
#  'spell',
#  'spike',
#  'spin',
#  'splatter',
#  'splice',
#  'split',
#  'spot',
#  'spray',
#  'spread',
#  'spring',
#  'sprint',
#  'spur',
#  'spurn',
#  'spy',
#  'squabble',
#  'squash',
#  'squeak',
#  'squelch',
#  'stack',
#  'staff',
#  'stagger',
#  'stamp',
#  'stand',
#  ...]

# %%
# 방법 2: 표제어 추출
ext_lema = [lemmatizer.lemmatize(w) for w in preprossed]
# 중복값을 제거하고
rm_dupli = set(ext_lema)
# 다시 리스트로 만들고
re_li = list(rm_dupli)
# 빈 값은 제거하고
get_wd =list(filter(None, re_li))
# 소문자로 모두 변환
lower_wd = [i.lower() for i in get_wd]
lower_wd
# Out:
# ['count',
#  'fade',
#  'chart',
#  'scrape',
#  'circumvent',
#  'size',
#  'qualify',
#  'crawl',
#  'deprecate',
#  'split',
#  'project',
#  'complete',
#  'obtain',
#  'trim',
#  'expedite',
#  'rally',
#  'clip',
#  'flog',
#  'freak',
#  'nip',
#  'expedited',
#  'buck',
#  'contribute',
#  'enhance',
#  'regain',
#  'serve',
#  'soak',
#  'improvise',
#  'illustrate',
#  'jimmy',
#  'lessen',
#  'romp',
#  'sever',
#  'smack',
#  'configure',
#  'scale',
#  'saw',
#  'undertake',
#  'edit',
#  'confront',
#  'prompt',
#  'jangle',
#  'stimulate',
#  'operate',
#  'flaunt',
#  'reinforce',
#  'process',
#  'decorate',
#  'pitch',
#  'meddle',
#  'unhinge\xa0',
#  'wander',
#  'protect',
#  'bang',
#  'demonstrate',
#  'cultivate',
#  'charge',
#  'document',
#  'contend',
#  'slide',
#  'prioritize',
#  'mold',
#  'bank',
#  'fan',
#  'mentor',
#  'wound',
#  'disfavor',
#  'stock',
#  'experience',
#  'narrow',
#  'protest',
#  'determine',
#  'indignant',
#  'conduct',
#  'evade',
#  'aggravate',
#  'scatter',
#  'splice',
#  'grow',
#  'oppose',
#  'invade',
#  'toss',
#  'parade',
#  'correlate',
#  'assure',
#  'shout',
#  'drug',
#  'inspect',
#  'brawl',
#  'converse',
#  'log',
#  'overhaul',
#  'offense',
#  'joined',
#  'sew',
#  'detect',
#  'flip',
#  'pirate',
#  'brief',
#  'receive',
#  'infuriate',
#  'specify',
#  'superintend',
#  'instruct',
#  'wrought',
#  'justify',
#  'battle',
#  'scratch',
#  'aim',
#  'taunt',
#  'block',
#  'exit',
#  'transport',
#  'describe',
#  'hurl',
#  'save',
#  'reached',
#  'retreat',
#  'ward',
#  'dissent',
#  'fund',
#  'outperformed',
#  'repress',
#  'squelch',
#  'snoop',
#  'formalize',
#  'flee',
#  'flinch',
#  'cut',
#  'manage',
#  'act',
#  'bushwhack',
#  'flit',
#  'nominate',
#  'index',
#  'taste',
#  'enable',
#  'hypothesize',
#  'grope',
#  'tolerate',
#  'wove',
#  'edge',
#  'needle',
#  'operated',
#  'sprint',
#  'flush',
#  'bill',
#  'cram',
#  'submit',
#  'decrease',
#  'network',
#  'produced',
#  'strike',
#  'accomplish',
#  'learn',
#  'ram',
#  'effect',
#  'slaughter',
#  'structure',
#  'afflict',
#  'list',
#  'tick',
#  'succeed',
#  'dissect',
#  'counsel',
#  'enforced',
#  'investigate',
#  'compute',
#  'deal',
#  'importune',
#  'scout',
#  'snicker',
#  'trained',
#  'pander',
#  'extricate',
#  'fulfill',
#  'tickle',
#  'pocket',
#  'sense',
#  'drop',
#  'hit',
#  'feed',
#  'managed',
#  'infighting',
#  'bury',
#  'gather',
#  'oversaw',
#  'program',
#  'flap',
#  'wrestle',
#  'sip',
#  'augment',
#  'object',
#  'vanish',
#  'formulate',
#  'initiated',
#  'actualized',
#  'drink',
#  'swim',
#  'screen',
#  'itemize',
#  'lifted',
#  'scan',
#  'evacuate',
#  'strip',
#  'outrage',
#  'lower',
#  'abominate',
#  'accost',
#  'wade',
#  'inventory',
#  'gesture',
#  'improved',
#  'organized',
#  'enlarge',
#  'integrate',
#  'support',
#  'administer',
#  'originate',
#  'shape',
#  'sold',
#  'track',
#  'define',
#  'halve',
#  'insert',
#  'defended',
#  'suggest',
#  'undergo',
#  'arbitrate',
#  'forecast',
#  'stamp',
#  'keel',
#  'smash',
#  'defeat',
#  'gash',
#  'roll',
#  'sculpt',
#  'listen',
#  'huff',
#  'lick',
#  'turn',
#  'wave',
#  'assault',
#  'swipe',
#  'yelp',
#  'halt',
#  'pry',
#  'deliberate',
#  'snarl',
#  'conceive',
#  'inflame',
#  'skid',
#  'appoint',
#  'unite',
#  'fend',
#  'march',
#  'surpass',
#  'pin',
#  'encounter',
#  'pounce',
#  'abduct',
#  'taught',
#  'challenge',
#  'sniff',
#  'sway',
#  'violate',
#  'mock',
#  'deck',
#  'educate',
#  'pas',
#  'dress',
#  'revitalize',
#  'daunt\xa0',
#  'placate',
#  'supervise',
#  'verbalize',
#  'enforce',
#  'inject',
#  'tighten',
#  'shrink',
#  'ditch',
#  'smear',
#  'yell',
#  'unveil',
#  'engineer',
#  'apprehend',
#  'co-authored',
#  'detonate',
#  'abandon',
#  'molest',
#  'poke',
#  'clarify',
#  'acquire',
#  'position',
#  'stomp',
#  'stifle',
#  'rebuild',
#  'pose',
#  'double',
#  'inform',
#  'annihilate',
#  'extend',
#  'grunt',
#  'lead',
#  'mumble',
#  'authenticate',
#  'crash',
#  'wiggle',
#  'collaborate',
#  'fake',
#  'fast',
#  'induce',
#  'kick',
#  'compile',
#  'undress',
#  'dictate',
#  'sap',
#  'tap',
#  'swear',
#  'nurture',
#  'shaped',
#  'squash',
#  'improve',
#  'teach',
#  'elope',
#  'specialize',
#  'united',
#  'shell',
#  'strangle',
#  'unnerve',
#  'dive',
#  'escape',
#  'shoot',
#  'record',
#  'clutch',
#  'outline',
#  'grew',
#  'nag',
#  'annoy',
#  'rate',
#  'bite',
#  'resign',
#  'resist',
#  'stun',
#  'massage',
#  'muster',
#  'sell',
#  'stand',
#  'spread',
#  'summon',
#  'uncover',
#  'seduce',
#  'solve',
#  'consult',
#  'unravel',
#  'perform',
#  'locate',
#  'stub',
#  'engage',
#  'conserve',
#  'sit',
#  'staff',
#  'rankle',
#  'execute',
#  'discharge',
#  'initiate',
#  'diagnose',
#  'officiate',
#  'spike',
#  'exert',
#  'disservice',
#  'douse',
#  'dunk',
#  'fight',
#  'interchange',
#  'panic',
#  'smite',
#  'skim',
#  'tout',
#  'fear',
#  'occupy',
#  'repulsion',
#  'revise',
#  'shanghai',
#  'walk',
#  'drive',
#  'adjust',
#  'clap',
#  'spot',
#  'drip',
#  'propel',
#  'sum',
#  'tease',
#  'whack',
#  'label',
#  'quibble',
#  'scrub',
#  'detail',
#  'keynote',
#  'crafted',
#  'jeer',
#  'tear',
#  'participate',
#  'bicker',
#  'enact',
#  'nab',
#  'grab',
#  'stop',
#  'thrash',
#  'represent',
#  'approach',
#  'plod',
#  'tilt',
#  'raised',
#  'merge',
#  'command',
#  'subdue',
#  'outperform',
#  'trap',
#  'swap',
#  'scar',
#  'perceive',
#  'incriminate',
#  'stuff',
#  'sustain',
#  'analyze',
#  'parachute',
#  'deface',
#  'inflict',
#  'whirl',
#  'discard',
#  'usher',
#  'wield',
#  'regulate',
#  'explode',
#  'antagonize',
#  'prepare',
#  'splatter',
#  'thread',
#  'wedge',
#  'slash',
#  'ignore',
#  'form',
#  'transfer',
#  'transformed',
#  'type',
#  'automate',
#  'inspired',
#  'roil',
#  'jump',
#  'imitate',
#  'insult',
#  'dart',
#  'snap',
#  'jolt',
#  'abscond',
#  'pray',
#  'vacate',
#  'dance',
#  'nail',
#  'rank',
#  'gall',
#  'originated',
#  'scoop',
#  'coproduced',
#  'erupt',
#  'shatter',
#  'signal',
#  'repel',
#  'shut',
#  'bolster',
#  'falter',
#  'establish',
#  'watch',
#  'deplore',
#  'circumscribe',
#  'measure',
#  'steer',
#  'reorganize',
#  'stick',
#  'gnaw',
#  'slap',
#  'maintain',
#  'stumble',
#  'advise',
#  'dope',
#  'outpaced',
#  'focus',
#  'picket',
#  'convey',
#  'extirpate',
#  'respond',
#  'snare',
#  'throw',
#  'plow',
#  'deduct',
#  'publicized',
#  'swerve',
#  'swallow',
#  'recoup',
#  'spur',
#  'snitch',
#  'combine',
#  'helm',
#  'retrieve',
#  'spring',
#  'select',
#  'treat',
#  'secure',
#  'volunteer',
#  'zip',
#  'increase',
#  'research',
#  'scoot',
#  'dare',
#  'abolish',
#  'furnish',
#  'slacken',
#  'arrest',
#  'handle',
#  'supply',
#  'decide',
#  'fling',
#  'trot',
#  'target',
#  'grasp',
#  'lunge',
#  'ruffle',
#  'accrue',
#  'mutilate',
#  'license',
#  'frustrate',
#  'pack',
#  'repulse',
#  'simplify',
#  'develop',
#  'ensnare',
#  'control',
#  'hinder',
#  'address',
#  'confer',
#  'eliminate',
#  'examine',
#  'resolve',
#  'rob',
#  'affront',
#  'head',
#  'broke',
#  'terrorize',
#  'flick',
#  'expose',
#  'translate',
#  'search',
#  'invent',
#  'distress\xa0',
#  'reposition',
#  'agitate\xa0',
#  'berate',
#  'fray',
#  'limp',
#  'ail',
#  'hassle',
#  'customize',
#  'dig',
#  'flout',
#  'update',
#  'unfold',
#  'foster',
#  'check',
#  'campaign',
#  'surrender',
#  'execrate',
#  'purge',
#  'contract',
#  'survey',
#  'endure',
#  'dry',
#  'sail',
#  'renovate',
#  'outlined',
#  'step',
#  'snub',
#  'strategize',
#  'startle',
#  'strap',
#  'strive',
#  'quicken',
#  'stress',
#  'wrangle',
#  'grip',
#  'outpace',
#  'catch',
#  'collar',
#  'chase',
#  'collapse',
#  'disdain',
#  'emerge',
#  'exhibit',
#  'flag',
#  'fill',
#  'motivate',
#  'rave',
#  'escalate',
#  'force',
#  'refer',
#  'crush',
#  'tip',
#  'indignation',
#  'drag',
#  'rape',
#  'remove',
#  'value',
#  'parry',
#  'dominate',
#  'indignity',
#  'liaise',
#  'publicize',
#  'shave',
#  'untangle',
#  'skip',
#  'jingle',
#  'shear',
#  'wallop',
#  'demoralize\xa0',
#  'mediate',
#  'negotiated',
#  'unify',
#  'anticipate',
#  'injure',
#  'struggle',
#  'mobilize',
#  'champion',
#  'dispatch',
#  'scavenge',
#  'scrawl',
#  'centralize',
#  'link',
#  'pioneer',
#  'prove',
#  'attain',
#  'drown',
#  'shun',
#  'achieve',
#  'yank',
#  'prescribe',
#  'activate',
#  'supress',
#  'segment',
#  'draw',
#  'reel',
#  'accelerate',
#  'file',
#  'hail',
#  'reduce',
#  'delegate',
#  'suck',
#  'meet',
#  'question',
#  'order',
#  'change',
#  'debut',
#  'elevate',
#  'land',
#  'design',
#  'flay',
#  'maim',
#  'offer',
#  'pique',
#  'realize',
#  'collate',
#  'oversee',
#  'interview',
#  'level',
#  'preside',
#  'sock',
#  'threaten',
#  'alert',
#  'produce',
#  'jar',
#  'master',
#  'billow',
#  'grind',
#  'grapple',
#  'park',
#  'groomed',
#  'display',
#  'remodeled',
#  'squabble',
#  'disapprove',
#  'calm',
#  'shock',
#  'diminish',
#  'pile',
#  'forecasted',
#  'standardize',
#  'swing',
#  'cripple',
#  'ride',
#  'collect',
#  'read',
#  'tie',
#  'emulate',
#  'whistle',
#  'combat',
#  'instigate',
#  'duel',
#  'incense',
#  'rub',
#  'torture',
#  'quell',
#  'repair',
#  'zap',
#  'consolidate',
#  'raise',
#  'reach',
#  'introduce',
#  'submerge',
#  'fashion',
#  'divide',
#  'commandeer',
#  'allocate',
#  'probe',
#  'recruit',
#  'polish',
#  'trip',
#  'pilot',
#  'married',
#  'identify',
#  'construct',
#  'hang',
#  'irateness',
#  'discover',
#  'fondle',
#  'switch',
#  'ass',
#  'scald',
#  'hammer',
#  'ensure',
#  'exhale',
#  'rejoin',
#  'page',
#  'sigh',
#  'intensify',
#  'judge',
#  'draft',
#  'pursue',
#  'run',
#  'persuade',
#  'distinguish',
#  'ground',
#  'destroy',
#  'investigated',
#  'published',
#  'redeem',
#  'relieve',
#  'vex',
#  'wreck',
#  'trounce',
#  'summarize',
#  'stroke',
#  'equip',
#  'seize',
#  'hug',
#  'minimize',
#  'eject',
#  'mingle',
#  'partnered',
#  'exceed',
#  'touch',
#  'nick',
#  'transform',
#  'reveal',
#  'beat',
#  'shake',
#  'mobilized',
#  'shift',
#  'mentored',
#  'climb',
#  'scamper',
#  'train',
#  'spray',
#  'unsettle\xa0',
#  'brighten',
#  'graduate',
#  'spell',
#  'vault',
#  'unwelcome',
#  'schedule',
#  'hurtle',
#  'recommend',
#  'correspond',
#  'accumulate',
#  'enlist',
#  'inequity',
#  'seal',
#  'provide',
#  'prod',
#  'team',
#  'procure',
#  'kill',
#  'blow',
#  'dramatize',
#  'balance',
#  'curtail',
#  'enlighten',
#  'hire',
#  'stagger',
#  'hitch',
#  'cure',
#  'assign',
#  'convert',
#  'hesitate',
#  'proofread',
#  'render',
#  'create',
#  'charter',
#  'audit',
#  'indict',
#  'squeak',
#  'scuffle',
#  'elude',
#  'shiver',
#  'brace',
#  'observe',
#  'extract',
#  'disharmonize',
#  'invented',
#  'choke',
#  'scorn',
#  'affirm',
#  'prepared',
#  'scare',
#  'experiment',
#  'accuse',
#  'shoulder',
#  'endeavor',
#  'invest',
#  'synergize',
#  'debate',
#  'compose',
#  'gallop',
#  'evict',
#  'promote',
#  'print',
#  'publish',
#  'found',
#  'inch',
#  'avoid',
#  'model',
#  'pull',
#  'relate',
#  'satisfy',
#  'discompose\xa0',
#  'classify',
#  'mimic',
#  'hobble',
#  'disesteem',
#  'photograph',
#  'chair',
#  'ravage',
#  'spy',
#  'wrench',
#  'relay',
#  'influence',
#  'field',
#  'tutor',
#  'up',
#  'paw',
#  'bash',
#  'despise',
#  'discus',
#  'evaluate',
#  'quarrel',
#  'rupture',
#  'spin',
#  'present',
#  'scuttle',
#  'plan',
#  'amplify',
#  'finger',
#  'derive',
#  'mourn',
#  'calculate',
#  'share',
#  'adapt',
#  'screw',
#  'jerk',
#  'aid',
#  'attack',
#  'spearhead',
#  'manufacture',
#  'kidnap',
#  'divert',
#  'harass',
#  'distribute',
#  'brabble',
#  'leap',
#  'pinch',
#  'steal',
#  'capitalize',
#  'loathe',
#  'spearheaded',
#  'mend',
#  'hoist',
#  'assist',
#  'jab',
#  'innovate',
#  'market',
#  'altercate',
#  'install',
#  'purchase',
#  'reconnoiter',
#  'perfect',
#  'enraged',
#  'expand',
#  'inflate',
#  'author',
#  'collide',
#  'built',
#  'cancel',
#  'coordinate',
#  'dismay\xa0',
#  'haul',
#  'lurch',
#  'isolate',
#  'spear',
#  'spurn',
#  'plunge',
#  'top',
#  'scold',
#  'withdraw',
#  'utilize',
#  'greet',
#  'envy',
#  'push',
#  'retain',
#  'negotiate',
#  'hasten',
#  'abuse',
#  'rise',
#  'systematize',
#  'hijack',
#  'merged',
#  'tabulate',
#  'pick',
#  'interpret',
#  'sharpen',
#  'overcome',
#  'motivated',
#  'performed',
#  'unwind',
#  'write',
#  'communicate',
#  'dishearten\xa0',
#  'flash',
#  'score',
#  'spark',
#  'forge',
#  'weed',
#  'paddle',
#  'programmed',
#  'slam',
#  'rattle',
#  'tuck',
#  'veto',
#  'implement',
#  'scruff',
#  'join',
#  'swagger',
#  'ransack',
#  'down',
#  'realized',
#  'test',
#  'defy',
#  'instructed',
#  'review',
#  'bar',
#  'guide',
#  'float',
#  'hover',
#  'race',
#  'commit',
#  'hide',
#  'predict',
#  'primp',
#  'croak',
#  'struck',
#  'abhor',
#  'discourage\xa0',
#  'disable',
#  'pummel',
#  'carry',
#  'gain',
#  'restore',
#  'led',
#  'icky',
#  'attract',
#  'talk',
#  'clash',
#  'discomfort\xa0',
#  ...]

# %%
# 다양하게 전처리 한 단어를 모두 모아서 중복제거
actionVerbs_all = list(set(pre_lower_wd + lemma_list + lower_wd))
# 빈 값은 제거하고
actionVerbs_all_re =list(filter(None, actionVerbs_all))
actionVerbs_all_re[:5]
# Out:
# ['scrape', 'size', 'qualify', 'project', 'flog']

# %%
# 소문자로 모두 변환
words_list_re = [i.lower() for i in actionVerbs_all_re]
words_list_re
# Out:
# ['scrape',
#  'size',
#  'qualify',
#  'project',
#  'flog',
#  'freak',
#  'nip',
#  'buck',
#  'contribute',
#  'improvise',
#  'illustrate',
#  'lessen',
#  'romp',
#  'sever',
#  'jangle',
#  'flaunt',
#  'wander',
#  'meddle',
#  'unhinge\xa0',
#  'charge',
#  'document',
#  'contend',
#  'bank',
#  'fan',
#  'wound',
#  'disfavor',
#  'protest',
#  'conduct',
#  'grow',
#  'assure',
#  'offense',
#  'joined',
#  'detect',
#  'brief',
#  'receive',
#  'infuriate',
#  'specify',
#  'scratch',
#  'block',
#  'transport',
#  'describe',
#  'fund',
#  'outperformed',
#  'enable',
#  'mentored',
#  'sprint',
#  'ram',
#  'structure',
#  'list',
#  'wedge',
#  'compute',
#  'scout',
#  'pander',
#  'fulfill',
#  'sense',
#  'drop',
#  'feed',
#  'managed',
#  'infighting',
#  'bury',
#  'augment',
#  'vanish',
#  'initiated',
#  'screen',
#  'scan',
#  'evacuate',
#  'accost',
#  'organized',
#  'enlarge',
#  'integrate',
#  'administer',
#  'shape',
#  'reached',
#  'inspired',
#  'stamp',
#  'keel',
#  'halt',
#  'inflame',
#  'mobilized',
#  'skid',
#  'pounce',
#  'challenge',
#  'sniff',
#  'mock',
#  'revitalize',
#  'daunt\xa0',
#  'inject',
#  'pose',
#  'annihilate',
#  'lead',
#  'fake',
#  'induce',
#  'initiated',
#  'groomed',
#  'shaped',
#  'improve',
#  'teach',
#  'escape',
#  'record',
#  'outline',
#  'nag',
#  'synergize',
#  'bite',
#  'massage',
#  'oversaw',
#  'seduce',
#  'solve',
#  'consult',
#  'initiate',
#  'diagnose',
#  'exert',
#  'disservice',
#  'interchange',
#  'propel',
#  'whack',
#  'label',
#  'bicker',
#  'stop',
#  'approach',
#  'sustain',
#  'inflict',
#  'whirl',
#  'regulate',
#  'splatter',
#  'form',
#  'transfer',
#  'automate',
#  'imitate',
#  'insult',
#  'snap',
#  'pray',
#  'scoop',
#  'originated',
#  'bolster',
#  'falter',
#  'establish',
#  'measure',
#  'reorganize',
#  'maintain',
#  'advise',
#  'dope',
#  'focus',
#  'plow',
#  'swallow',
#  'spur',
#  'combine',
#  'secure',
#  'scoot',
#  'dare',
#  'decide',
#  'license',
#  'frustrate',
#  'simplify',
#  'hinder',
#  'rob',
#  'affront',
#  'broke',
#  'flick',
#  'invent',
#  'ail',
#  'update',
#  'unfold',
#  'campaign',
#  'surrender',
#  'startle',
#  'chase',
#  'exhibit',
#  'disdain',
#  'rave',
#  'refer',
#  'crush',
#  'indignation',
#  'indignity',
#  'shave',
#  'untangle',
#  'jingle',
#  'anticipate',
#  'injure',
#  'mobilize',
#  'scavenge',
#  'scrawl',
#  'work',
#  'attain',
#  'achieve',
#  'activate',
#  'hail',
#  'pique',
#  'debut',
#  'threaten',
#  'sock',
#  'published',
#  'park',
#  'display',
#  'remodeled',
#  'disapprove',
#  'standardize',
#  'whistle',
#  'repair',
#  'raise',
#  'introduce',
#  'divide',
#  'prepared',
#  'recruit',
#  'construct',
#  'irateness',
#  'rejoin',
#  'page',
#  'sigh',
#  'judge',
#  'run',
#  'destroy',
#  'vex',
#  'minimize',
#  'eject',
#  'touch',
#  'nick',
#  'mentored',
#  'climb',
#  'spray',
#  'vault',
#  'find',
#  'accumulate',
#  'enlist',
#  'inequity',
#  'team',
#  'prod',
#  'dramatize',
#  'balance',
#  'curtail',
#  'hesitate',
#  'render',
#  'audit',
#  'scuffle',
#  'elude',
#  'shaped',
#  'observe',
#  'affirm',
#  'experiment',
#  'tilt',
#  'debate',
#  'gallop',
#  'print',
#  'discus',
#  'plan',
#  'amplify',
#  'share',
#  'divert',
#  'harass',
#  'capitalize',
#  'hoist',
#  'assist',
#  'jab',
#  'innovate',
#  'perfect',
#  'dismay\xa0',
#  'transformed',
#  'fee',
#  'withdraw',
#  'negotiate',
#  'hasten',
#  'tabulate',
#  'interpret',
#  'write',
#  'motivated',
#  'performed',
#  'score',
#  'paddle',
#  'hover',
#  'race',
#  'abhor',
#  'attract',
#  'earn',
#  'risk',
#  'gouge',
#  'devise',
#  'mark',
#  'rock',
#  'oppress',
#  'salute',
#  'coded',
#  'estimate',
#  'whale',
#  'snuggle',
#  'preen',
#  'drain',
#  'forecasted',
#  'snatch',
#  'critique',
#  'lecture',
#  'study',
#  'boost',
#  'raid',
#  'manipulate',
#  'institute',
#  'launch',
#  'tumble',
#  'soil',
#  'triple',
#  'pat',
#  'fumble',
#  'vanquish',
#  'burst',
#  'drill',
#  'encourage',
#  'cooperate',
#  'dodge',
#  'mastermind',
#  'pause',
#  'guard',
#  'rush',
#  'provoke',
#  'sear',
#  'knife',
#  'move',
#  'quit',
#  'assemble',
#  'hack',
#  'count',
#  'chart',
#  'circumvent',
#  'deprecate',
#  'enforced',
#  'complete',
#  'clip',
#  'regain',
#  'produced',
#  'edit',
#  'confront',
#  'stimulate',
#  'operate',
#  'reinforce',
#  'pitch',
#  'protect',
#  'bang',
#  'slide',
#  'mold',
#  'experience',
#  'indignant',
#  'invade',
#  'overhaul',
#  'flip',
#  'superintend',
#  'hurl',
#  'ward',
#  'squelch',
#  'snoop',
#  'flinch',
#  'manage',
#  'taste',
#  'grope',
#  'wove',
#  'operated',
#  'flush',
#  'taught',
#  'effect',
#  'succeed',
#  'counsel',
#  'enforced',
#  'trained',
#  'pocket',
#  'oversaw',
#  'object',
#  'formulate',
#  'actualized',
#  'swim',
#  'itemize',
#  'lifted',
#  'lower',
#  'improved',
#  'define',
#  'arbitrate',
#  'smash',
#  'defeat',
#  'lick',
#  'wave',
#  'yelp',
#  'pry',
#  'deliberate',
#  'snarl',
#  'conceive',
#  'fend',
#  'march',
#  'violate',
#  'educate',
#  'united',
#  'tighten',
#  'shrink',
#  'molest',
#  'position',
#  'detonate',
#  'abandon',
#  'acquire',
#  'rebuild',
#  'authenticate',
#  'wiggle',
#  'kick',
#  'compile',
#  'swear',
#  'motivated',
#  'squash',
#  'elope',
#  'shoot',
#  'clutch',
#  'leave',
#  'annoy',
#  'stand',
#  'uncover',
#  'locate',
#  'conserve',
#  'rankle',
#  'execute',
#  'officiate',
#  'fight',
#  'dunk',
#  'wield',
#  'panic',
#  'repulsion',
#  'walk',
#  'enrage',
#  'drive',
#  'tease',
#  'drip',
#  'keynote',
#  'nab',
#  'enact',
#  'thrash',
#  'instructed',
#  'co-authored',
#  'plod',
#  'discard',
#  'blended',
#  'antagonize',
#  'thread',
#  'type',
#  'transformed',
#  'roil',
#  'inspired',
#  'outperformed',
#  'dart',
#  'abscond',
#  'vacate',
#  'coproduced',
#  'shut',
#  'steer',
#  'circumscribe',
#  'gnaw',
#  'outpaced',
#  'swerve',
#  'helm',
#  'select',
#  'zip',
#  'abolish',
#  'trot',
#  'handle',
#  'grasp',
#  'lunge',
#  'pack',
#  'develop',
#  'address',
#  'confer',
#  'eliminate',
#  'terrorize',
#  'expose',
#  'translate',
#  'fray',
#  'berate',
#  'foster',
#  'check',
#  'endure',
#  'step',
#  'outlined',
#  'snub',
#  'strategize',
#  'strap',
#  'strive',
#  'wrangle',
#  'outpace',
#  'flag',
#  'tip',
#  'parry',
#  'skip',
#  'break',
#  'merged',
#  'champion',
#  'drown',
#  'yank',
#  'reduce',
#  'offer',
#  'interview',
#  'preside',
#  'alert',
#  'jar',
#  'billow',
#  'forecasted',
#  'cripple',
#  'ride',
#  'instigate',
#  'incense',
#  'torture',
#  'zap',
#  'commandeer',
#  'allocate',
#  'polish',
#  'married',
#  'hang',
#  'switch',
#  'hammer',
#  'intensify',
#  'draft',
#  'ground',
#  'redeem',
#  'published',
#  'wreck',
#  'summarize',
#  'seize',
#  'hug',
#  'transform',
#  'reveal',
#  'beat',
#  'mobilized',
#  'unsettle\xa0',
#  'brighten',
#  'hurtle',
#  'provide',
#  'blow',
#  'submerge',
#  'enlighten',
#  'squeak',
#  'brace',
#  'extract',
#  'choke',
#  'operated',
#  'compose',
#  'promote',
#  'publish',
#  'pull',
#  'found',
#  'inch',
#  'satisfy',
#  'classify',
#  'disesteem',
#  'photograph',
#  'wrench',
#  'up',
#  'paw',
#  'spin',
#  'spearheaded',
#  'adapt',
#  'screw',
#  'jerk',
#  'aid',
#  'kidnap',
#  'purchase',
#  'tutor',
#  'isolate',
#  'plunge',
#  'envy',
#  'rise',
#  'systematize',
#  'unwind',
#  'dishearten\xa0',
#  'publicized',
#  'slam',
#  'tuck',
#  'build',
#  'swagger',
#  'down',
#  'negotiated',
#  'instructed',
#  'review',
#  'float',
#  'defended',
#  'assess',
#  'carry',
#  'gain',
#  'icky',
#  'employ',
#  'fall',
#  'investigated',
#  'transcribe',
#  'blended',
#  'blend',
#  'outlined',
#  'twist',
#  'direct',
#  'fly',
#  'relent',
#  'maximize',
#  'retaliate',
#  'yield',
#  'stack',
#  'suspend',
#  'ease',
#  'mangle',
#  'avert',
#  'unnerve',
#  'flounder',
#  'descend',
#  'murder',
#  'set',
#  'advance',
#  'dispute',
#  'affray',
#  'widen',
#  'rip',
#  'enter',
#  'arrange',
#  'service',
#  'dispirit\xa0',
#  'paralyze',
#  'award',
#  'pass',
#  'inspire',
#  'sort',
#  'expel',
#  'place',
#  'slug',
#  'kibitz',
#  'curse',
#  'explain',
#  'peep',
#  'out',
#  'dash',
#  'fade',
#  'trim',
#  'obtain',
#  'expedite',
#  'enhance',
#  'married',
#  'smack',
#  'saw',
#  'prompt',
#  'process',
#  'partnered',
#  'cultivate',
#  'pioneered',
#  'invented',
#  'coded',
#  'determine',
#  'evade',
#  'scatter',
#  'oppose',
#  'toss',
#  'correlate',
#  'shout',
#  'drug',
#  'inspect',
#  'brawl',
#  'converse',
#  'log',
#  'sew',
#  'pirate',
#  'instruct',
#  'wrought',
#  'exit',
#  'crafted',
#  'retreat',
#  'repress',
#  'flee',
#  'cut',
#  'act',
#  'flit',
#  'index',
#  'hypothesize',
#  'tolerate',
#  'cram',
#  'decrease',
#  'network',
#  'strike',
#  'learn',
#  'afflict',
#  'snicker',
#  'investigate',
#  'importune',
#  'extricate',
#  'tickle',
#  'hit',
#  'gather',
#  'program',
#  'flap',
#  'drink',
#  'outrage',
#  'abominate',
#  'inventory',
#  'support',
#  'sold',
#  'halve',
#  'insert',
#  'defended',
#  'suggest',
#  'forecast',
#  'sculpt',
#  'listen',
#  'huff',
#  'appoint',
#  'unite',
#  'surpass',
#  'encounter',
#  'deck',
#  'lifted',
#  'pas',
#  'dress',
#  'organized',
#  'verbalize',
#  'supervise',
#  'yell',
#  'engineer',
#  'co-authored',
#  'apprehend',
#  'poke',
#  'clarify',
#  'double',
#  'inform',
#  'mumble',
#  'crash',
#  'collaborate',
#  'fast',
#  'undress',
#  'sap',
#  'tap',
#  'nurture',
#  'specialize',
#  'shell',
#  'grew',
#  'rate',
#  'united',
#  'muster',
#  'sell',
#  'spread',
#  'summon',
#  'unravel',
#  'perform',
#  'stub',
#  'engage',
#  'staff',
#  'discharge',
#  'smite',
#  'skim',
#  'fear',
#  'occupy',
#  'revise',
#  'shanghai',
#  'clap',
#  'detail',
#  'crafted',
#  'represent',
#  'raised',
#  'command',
#  'outperform',
#  'trap',
#  'swap',
#  'scar',
#  'incriminate',
#  'analyze',
#  'parachute',
#  'jump',
#  'nail',
#  'rank',
#  'unveil',
#  'gall',
#  'repel',
#  'deplore',
#  'slap',
#  'stumble',
#  'picket',
#  'throw',
#  'undertook',
#  'publicized',
#  'recoup',
#  'spring',
#  'increase',
#  'research',
#  'slacken',
#  'supply',
#  'accrue',
#  'mutilate',
#  'ensnare',
#  'control',
#  'resolve',
#  'distress\xa0',
#  'customize',
#  'flout',
#  'execrate',
#  'purge',
#  'contract',
#  'dry',
#  'renovate',
#  'managed',
#  'stress',
#  'grip',
#  'collar',
#  'emerge',
#  'motivate',
#  'escalate',
#  'force',
#  'remove',
#  'value',
#  'mediate',
#  'dispatch',
#  'pioneer',
#  'link',
#  'prove',
#  'trained',
#  'prescribe',
#  'segment',
#  'meet',
#  'order',
#  'change',
#  'realize',
#  'flay',
#  'maim',
#  'collate',
#  'oversee',
#  'level',
#  'produce',
#  'master',
#  'grind',
#  'groomed',
#  'shock',
#  'diminish',
#  'swing',
#  'tie',
#  'combat',
#  'duel',
#  'rub',
#  'quell',
#  'consolidate',
#  'reach',
#  'trip',
#  'pilot',
#  'fondle',
#  'ensure',
#  'investigated',
#  'relieve',
#  'trounce',
#  'equip',
#  'mingle',
#  'shake',
#  'scamper',
#  'train',
#  'spell',
#  'schedule',
#  'recommend',
#  'correspond',
#  'procure',
#  'kill',
#  'hire',
#  'hitch',
#  'cure',
#  'proofread',
#  'create',
#  'shiver',
#  'scorn',
#  'prepared',
#  'scare',
#  'shoulder',
#  'endeavor',
#  'outpaced',
#  'evict',
#  'model',
#  'relate',
#  'discompose\xa0',
#  'hobble',
#  'ravage',
#  'influence',
#  'field',
#  'wind',
#  'rupture',
#  'bash',
#  'despise',
#  'improved',
#  'present',
#  'scuttle',
#  'finger',
#  'derive',
#  'expedited',
#  'actualized',
#  'calculate',
#  'attack',
#  'leap',
#  'pinch',
#  'loathe',
#  'spearheaded',
#  'market',
#  'reconnoiter',
#  'author',
#  'haul',
#  'cancel',
#  'spear',
#  'spurn',
#  'scold',
#  'utilize',
#  'push',
#  'abuse',
#  'hijack',
#  'merged',
#  'pick',
#  'communicate',
#  'flash',
#  'forge',
#  'programmed',
#  'veto',
#  'scruff',
#  'join',
#  'ransack',
#  'test',
#  'realized',
#  'defy',
#  'guide',
#  'commit',
#  'hide',
#  'croak',
#  'discourage\xa0',
#  'pummel',
#  'talk',
#  'clash',
#  'synthesize',
#  'flatten',
#  'deliver',
#  'face',
#  'facilitate',
#  'peel',
#  'delineate',
#  'quiz',
#  'condense',
#  'tackle',
#  'relax',
#  'sidestep',
#  'authorize',
#  'shield',
#  'performed',
#  'slay',
#  'scream',
#  'lean',
#  'patrol',
#  'report',
#  'orchestrate',
#  'thin',
#  'shove',
#  'bump',
#  'scour',
#  'fix',
#  'vent',
#  'defame',
#  'undertook',
#  'strengthen',
#  'conceptualize',
#  'generate',
#  'revolutionize',
#  'programmed',
#  'profitable',
#  'tug',
#  'crawl',
#  'split',
#  'rally',
#  'expedited',
#  'soak',
#  'serve',
#  'jimmy',
#  'configure',
#  'scale',
#  'undertake',
#  'decorate',
#  'demonstrate',
#  'prioritize',
#  'mentor',
#  'stock',
#  'narrow',
#  'aggravate',
#  'splice',
#  'parade',
#  'justify',
#  'battle',
#  'aim',
#  'taunt',
#  'save',
#  'reached',
#  'dissent',
#  'formalize',
#  'bushwhack',
#  'nominate',
#  'coproduced',
#  'edge',
#  'needle',
#  'bill',
#  'submit',
#  'produced',
#  'accomplish',
#  'slaughter',
#  'tick',
#  'dissect',
#  'deal',
#  'wrestle',
#  'sip',
#  'strip',
#  'wade',
#  'gesture',
#  'grew',
#  'originate',
#  'track',
#  ...]

# %%
# csv 파일로 저장하기
import csv

f = open('actionVerbsForPS.csv', 'w', encoding='utf-8')

for i in words_list_re:
    f.write(i + ",")
    
f.close()

# %%
# load data
import pandas as pd
chk_data = pd.read_csv("actionVerbsForPS.csv")
chk_data
# Out:
# Empty DataFrame
# Columns: [scrape, size, qualify, project, flog, freak, nip, buck, contribute, improvise, illustrate, lessen, romp, sever, jangle, flaunt, wander, meddle, unhinge , charge, document, contend, bank, fan, wound, disfavor, protest, conduct, grow, assure, offense, joined, detect, brief, receive, infuriate, specify, scratch, block, transport, describe, fund, outperformed, enable, mentored, sprint, ram, structure, list, wedge, compute, scout, pander, fulfill, sense, drop, feed, managed, infighting, bury, augment, vanish, initiated, screen, scan, evacuate, accost, organized, enlarge, integrate, administer, shape, reached, inspired, stamp, keel, halt, inflame, mobilized, skid, pounce, challenge, sniff, mock, revitalize, daunt , inject, pose, annihilate, lead, fake, induce, initiated.1, groomed, shaped, improve, teach, escape, record, outline, ...]
# Index: []
#
# [0 rows x 1253 columns]

# %%
# 불용어 제거

from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
stop = stopwords.words('english')
stop_words = set(stopwords.words('english')) 

result = []
for w in lower_wd: 
    if w not in stop_words: 
        result.append(w)

# %%
result
# Out:
# ['discus',
#  'assault',
#  'abscond',
#  'stagger',
#  'provoke',
#  'channel',
#  'improvise',
#  'scar',
#  'rattle',
#  'document',
#  'mediate',
#  'tug',
#  'negotiate',
#  'rejoin',
#  'nick',
#  'derive',
#  'operate',
#  'pin',
#  'clap',
#  'afflict',
#  'collapse',
#  'slacken',
#  'combat',
#  'crawl',
#  'rub',
#  'balance',
#  'skid',
#  'design',
#  'snuggle',
#  'spark',
#  'wrestle',
#  'rush',
#  'specify',
#  'taunt',
#  'recline',
#  'count',
#  'award',
#  'abuse',
#  'nag',
#  'discover',
#  'draft',
#  'indignant',
#  'nominate',
#  'quarrel',
#  'escape',
#  'wade',
#  'roll',
#  'yield',
#  'debate',
#  'flounder',
#  'hover',
#  'parade',
#  'indignity',
#  'splice',
#  'paralyze',
#  'hoist',
#  'actualized',
#  'preside',
#  'unwelcome',
#  'helm',
#  'narrow',
#  'coded',
#  'grasp',
#  'pat',
#  'raised',
#  'sock',
#  'hug',
#  'trip',
#  'needle',
#  'probe',
#  'demonstrate',
#  'brabble',
#  'shear',
#  'improved',
#  'reduce',
#  'scrap',
#  'oversaw',
#  'save',
#  'sear',
#  'walk',
#  'party',
#  'expand',
#  'formalize',
#  'inspire',
#  'revolutionize',
#  'ail',
#  'construct',
#  'dance',
#  'lower',
#  'force',
#  'stumble',
#  'activate',
#  'mourn',
#  'stand',
#  'shield',
#  'blended',
#  'reveal',
#  'influence',
#  'condense',
#  'undertook',
#  'renew',
#  'drive',
#  'sigh',
#  'dress',
#  'shun',
#  'cram',
#  'manage',
#  'dramatize',
#  'oppress',
#  'anticipate',
#  'huff',
#  'relieve',
#  'plan',
#  'enlist',
#  'interchange',
#  'choke',
#  'scuffle',
#  'nab',
#  'parachute',
#  'sit',
#  'flout',
#  'jab',
#  'specialize',
#  'suggest',
#  'shape',
#  'orchestrate',
#  'charter',
#  'deprecate',
#  'facilitate',
#  'thread',
#  'launch',
#  'strip',
#  'spurn',
#  'instruct',
#  'spell',
#  'stress',
#  'torture',
#  'shrink',
#  'nip',
#  'scrape',
#  'extract',
#  'enable',
#  'envy',
#  'sap',
#  'oppose',
#  'quell',
#  'judge',
#  'purchase',
#  'gouge',
#  'block',
#  'curtail',
#  'shut',
#  'exhibit',
#  'slaughter',
#  'emerge',
#  'dispute',
#  'search',
#  'utilize',
#  'page',
#  'contribute',
#  'race',
#  'observe',
#  'destroy',
#  'expose',
#  'govern',
#  'grip',
#  'hurl',
#  'calm',
#  'jar',
#  'head',
#  'rape',
#  'tackle',
#  'undergo',
#  'offer',
#  'affirm',
#  'remove',
#  'scan',
#  'boost',
#  'abolish',
#  'detest',
#  'fade',
#  'shake',
#  'shoulder',
#  'whack',
#  'undress',
#  'avert',
#  'scare',
#  'trounce',
#  'dig',
#  'abhor',
#  'shiver',
#  'pick',
#  'crush',
#  'organized',
#  'succeed',
#  'disservice',
#  'jolt',
#  'stamp',
#  'gall',
#  'cripple',
#  'deplore',
#  'realized',
#  'fondle',
#  'supress',
#  'circumvent',
#  'encourage',
#  'size',
#  'slide',
#  'smite',
#  'illustrate',
#  'drain',
#  'prepared',
#  'dart',
#  'attack',
#  'instigate',
#  'growl',
#  'convey',
#  'haul',
#  'create',
#  'affray',
#  'extricate',
#  'prod',
#  'reconcile',
#  'represent',
#  'resolve',
#  'augment',
#  'whip',
#  'challenge',
#  'parry',
#  'charge',
#  'perform',
#  'install',
#  'chart',
#  'gash',
#  'snitch',
#  'multiply',
#  'arrest',
#  'face',
#  'grind',
#  'finger',
#  'originate',
#  'tie',
#  'disfavor',
#  'revitalize',
#  'seduce',
#  'repair',
#  'kill',
#  'serve',
#  'joined',
#  'outrage',
#  'record',
#  'grew',
#  'devise',
#  'ruffle',
#  'audit',
#  'furnish',
#  'meet',
#  'douse',
#  'plunge',
#  'strive',
#  'pique',
#  'double',
#  'minimize',
#  'rankle',
#  'shorten',
#  'bushwhack',
#  'stop',
#  'conduct',
#  'retrieve',
#  'support',
#  'complete',
#  'tick',
#  'threaten',
#  'attain',
#  'decrease',
#  'undo',
#  'exceed',
#  'fornicate',
#  'induce',
#  'predict',
#  'summon',
#  'hijack',
#  'supervise',
#  'object',
#  'stimulate',
#  'shave',
#  'programmed',
#  'present',
#  'contend',
#  'revise',
#  'supply',
#  'penetrate',
#  'split',
#  'co-authored',
#  'survey',
#  'exit',
#  'blend',
#  'innovate',
#  'jangle',
#  'estimate',
#  'fling',
#  'hasten',
#  'sail',
#  'fall',
#  'skirt',
#  'crouch',
#  'spike',
#  'avoid',
#  'reached',
#  'scream',
#  'type',
#  'flash',
#  'keynote',
#  'confer',
#  'carry',
#  'trot',
#  'insult',
#  'bill',
#  'customize',
#  'conceptualize',
#  'form',
#  'grow',
#  'molest',
#  'spearhead',
#  'expedited',
#  'poke',
#  'salute',
#  'zip',
#  'control',
#  'annihilate',
#  'stifle',
#  'convert',
#  'nail',
#  'pile',
#  'loathe',
#  'quibble',
#  'extirpate',
#  'arbitrate',
#  'outline',
#  'respond',
#  'violate',
#  'stuff',
#  'grapple',
#  'file',
#  'incriminate',
#  'encounter',
#  'master',
#  'scruff',
#  'equip',
#  'hesitate',
#  'address',
#  'mangle',
#  'endeavor',
#  'gyrate',
#  'arrange',
#  'question',
#  'whistle',
#  'brace',
#  'itemize',
#  'screw',
#  'pounce',
#  'secure',
#  'polish',
#  'detonate',
#  'beat',
#  'fast',
#  'usher',
#  'aim',
#  'drill',
#  'dissect',
#  'repulse',
#  'bite',
#  'march',
#  'scratch',
#  'handle',
#  'skip',
#  'mend',
#  'leap',
#  'elope',
#  'partnered',
#  'simplify',
#  'snub',
#  'fend',
#  'fight',
#  'approach',
#  'patrol',
#  'act',
#  'propose',
#  'ravage',
#  'report',
#  'snicker',
#  'perfect',
#  'spring',
#  'wiggle',
#  'thrash',
#  'shoot',
#  'performed',
#  'bash',
#  'centralize',
#  'regulate',
#  'publicize',
#  'turn',
#  'plow',
#  'land',
#  'quicken',
#  'describe',
#  'incense',
#  'top',
#  'strap',
#  'antagonize',
#  'enjoin',
#  'participate',
#  'invade',
#  'snarl',
#  'shaped',
#  'intensify',
#  'enlighten',
#  'blow',
#  'compute',
#  'icky',
#  'bicker',
#  'placate',
#  'research',
#  'determine',
#  'overcome',
#  'improve',
#  'effect',
#  'screen',
#  'halt',
#  'compile',
#  'assure',
#  'dope',
#  'dishearten\xa0',
#  'introduce',
#  'jimmy',
#  'invent',
#  'lash',
#  'mock',
#  'descend',
#  'inflame',
#  'license',
#  'tread',
#  'experience',
#  'strategize',
#  'advise',
#  'consult',
#  'croak',
#  'hold',
#  'vacate',
#  'hammer',
#  'wrought',
#  'pry',
#  'compose',
#  'configure',
#  'retreat',
#  'aid',
#  'led',
#  'divide',
#  'mastermind',
#  'fix',
#  'defy',
#  'chair',
#  'gnaw',
#  'list',
#  'wave',
#  'enter',
#  'synthesize',
#  'hitch',
#  'wrangle',
#  'individualize',
#  'blast',
#  'chase',
#  'reinforce',
#  'soil',
#  'advocate',
#  'project',
#  'stub',
#  'operated',
#  'startle',
#  'pursue',
#  'test',
#  'resist',
#  'sever',
#  'sidestep',
#  'pocket',
#  'focus',
#  'switch',
#  'strain',
#  'clip',
#  'lifted',
#  'reach',
#  'unsettle\xa0',
#  'correspond',
#  'merged',
#  'render',
#  'rob',
#  'scoot',
#  'shell',
#  'transport',
#  'toss',
#  'battle',
#  'set',
#  'exert',
#  'dispatch',
#  'pilot',
#  'transformed',
#  'write',
#  'raid',
#  'primp',
#  'tilt',
#  'isolate',
#  'fulfill',
#  'plod',
#  'unravel',
#  'knife',
#  'field',
#  'pray',
#  'pitch',
#  'snare',
#  'skim',
#  'standardize',
#  'retaliate',
#  'dissent',
#  'listen',
#  'initiated',
#  'step',
#  'strengthen',
#  'enforce',
#  'disapprove',
#  'proofread',
#  'surpass',
#  'snatch',
#  'rock',
#  'discard',
#  'ransack',
#  'grope',
#  'merge',
#  'counsel',
#  'abduct',
#  'recruit',
#  'stun',
#  'collect',
#  'hypothesize',
#  'flee',
#  'pack',
#  'motivate',
#  'inch',
#  'establish',
#  'label',
#  'swagger',
#  'inequity',
#  'communicate',
#  'sum',
#  'extend',
#  'sprint',
#  'accomplish',
#  'attract',
#  'decide',
#  'repel',
#  'scorn',
#  'dismay\xa0',
#  'offense',
#  'detect',
#  'relate',
#  'inject',
#  'ass',
#  'catch',
#  'preen',
#  'slap',
#  'tumble',
#  'twist',
#  'clutch',
#  'fear',
#  'diagnose',
#  'enhance',
#  'imitate',
#  'distress\xa0',
#  'punch',
#  'index',
#  'raise',
#  'swear',
#  'relax',
#  'change',
#  'receive',
#  'review',
#  'sculpt',
#  'push',
#  'clash',
#  'burst',
#  'draw',
#  'flinch',
#  'dictate',
#  'protect',
#  'splatter',
#  'gain',
#  'swerve',
#  'falter',
#  'deliver',
#  'disdain',
#  'keel',
#  'print',
#  'converse',
#  'sniff',
#  'inflate',
#  'verbalize',
#  'spread',
#  'hobble',
#  'produce',
#  'guard',
#  'realize',
#  'deduct',
#  'pas',
#  'discourage\xa0',
#  'service',
#  'sell',
#  'advance',
#  'suck',
#  'swing',
#  'shout',
#  'wedge',
#  'pout',
#  'crafted',
#  'drag',
#  'verify',
#  'outpace',
#  'reel',
#  'tighten',
#  'strangle',
#  'diminish',
#  'explode',
#  'divert',
#  'scuttle',
#  'sense',
#  'interview',
#  'dodge',
#  'champion',
#  'inflict',
#  'stroke',
#  'drink',
#  'scale',
#  'cure',
#  'lift',
#  'apprehend',
#  'lean',
#  'exhale',
#  'sold',
#  'weigh',
#  'tip',
#  'vex',
#  'grunt',
#  'provide',
#  'tolerate',
#  'formulate',
#  'prescribe',
#  'shatter',
#  'adjust',
#  'creep',
#  'published',
#  'update',
#  'flatten',
#  'swap',
#  'maul',
#  'experiment',
#  'tickle',
#  'invest',
#  'deface',
#  'bank',
#  'ensure',
#  'scamper',
#  'authorize',
#  'berate',
#  'enact',
#  'swim',
#  'scout',
#  'triple',
#  'frustrate',
#  'wrench',
#  'coproduced',
#  'enforced',
#  'submit',
#  'quit',
#  'yelp',
#  'contract',
#  'wander',
#  'zap',
#  'volunteer',
#  'jerk',
#  'managed',
#  'roil',
#  'market',
#  'prepare',
#  'fake',
#  'sway',
#  'ease',
#  'perceive',
#  'value',
#  'purge',
#  'recoup',
#  'read',
#  'outperformed',
#  'pull',
#  'shovel',
#  'taught',
#  'deck',
#  'nurture',
#  'teach',
#  'rank',
#  'renovate',
#  'yank',
#  'flick',
#  'measure',
#  'persuade',
#  'meddle',
#  'stick',
#  'scoop',
#  'picket',
#  'hire',
#  'join',
#  'display',
#  'propel',
#  'restore',
#  'wreck',
#  'built',
#  'clarify',
#  'instructed',
#  'irateness',
#  'profitable',
#  'elevate',
#  'wove',
#  'network',
#  'flap',
#  'watch',
#  'defeat',
#  'dash',
#  'escalate',
#  'hail',
#  'rate',
#  'study',
#  'eject',
#  'develop',
#  'hassle',
#  'outpaced',
#  'accelerate',
#  'bar',
#  'paddle',
#  'weed',
#  'endure',
#  'publish',
#  'accumulate',
#  'found',
#  'pioneer',
#  'scatter',
#  'greet',
#  'tout',
#  'ground',
#  'collide',
#  'stock',
#  'spray',
#  'jump',
#  'vault',
#  'struck',
#  'surrender',
#  'limp',
#  'slash',
#  'squabble',
#  'employ',
#  'transform',
#  'smuggle',
#  'fly',
#  'mark',
#  'oversee',
#  'refer',
#  'drown',
#  'translate',
#  'earn',
#  'deal',
#  'administer',
#  'occupy',
#  'terminate',
#  'discomfort\xa0',
#  'redeem',
#  'spur',
#  'identify',
#  'learn',
#  'talk',
#  'mentored',
#  'conserve',
#  'pose',
#  'sustain',
#  'delete',
#  'feed',
#  'streamline',
#  'deliberate',
#  'cooperate',
#  'drape',
#  'infighting',
#  'prompt',
#  'romp',
#  'mumble',
#  'bump',
#  'manufacture',
#  'adapt',
#  'treat',
#  'engineer',
#  'elude',
#  'defended',
#  'drip',
#  'maximize',
#  'struggle',
#  'fan',
#  'discharge',
#  'vanish',
#  'decorate',
#  'tangle',
#  'quiz',
#  'systematize',
#  'eliminate',
#  'collate',
#  'shift',
#  'liaise',
#  'coach',
#  'author',
#  'gossip',
#  'expel',
#  'accrue',
#  'manipulate',
#  'model',
#  'spot',
#  'pirate',
#  'evaluate',
#  'integrate',
#  'process',
#  'publicized',
#  'remodeled',
#  'stack',
#  'trim',
#  'commandeer',
#  'injure',
#  'lead',
#  'bolster',
#  'tutor',
#  'vanquish',
#  'kibitz',
#  'repulsion',
#  'overhaul',
#  'pinch',
#  'rise',
#  'spin',
#  'dare',
#  'fill',
#  'consolidate',
#  'foster',
#  'hide',
#  'vent',
#  'unify',
#  'indignation',
#  'scrawl',
#  'lecture',
#  'hinder',
#  'combine',
#  'muster',
#  'peel',
#  'spear',
#  'snuff',
#  'examine',
#  'mingle',
#  'detail',
#  'implement',
#  'reposition',
#  'altercate',
#  'enlarge',
#  'summarize',
#  'soak',
#  'duel',
#  'hit',
#  'undertake',
#  'analyze',
#  'automate',
#  'shove',
#  'train',
#  'unhinge\xa0',
#  'win',
#  'obtain',
#  'assign',
#  'collaborate',
#  'level',
#  'forecasted',
#  'schedule',
#  'tear',
#  'accost',
#  'trap',
#  'scold',
#  'target',
#  'delegate',
#  'brawl',
#  'appoint',
#  'veto',
#  'expedite',
#  'evacuate',
#  'lunge',
#  'segment',
#  'tease',
#  'transcribe',
#  'resign',
#  'strike',
#  'throw',
#  'ride',
#  'grab',
#  'authenticate',
#  'biff',
#  'insert',
#  'locate',
#  'paw',
#  'pioneered',
#  'flit',
#  'outlined',
#  'magnify',
#  'move',
#  'protest',
#  'relent',
#  'investigate',
#  'calculate',
#  'involve',
#  'scavenge',
#  'mutilate',
#  'gather',
#  'snoop',
#  'spearheaded',
#  'smell',
#  'place',
#  'bury',
#  'collar',
#  'initiate',
#  'order',
#  'explain',
#  'float',
#  'reconnoiter',
#  'photograph',
#  'slug',
#  'swallow',
#  'circumscribe',
#  'regain',
#  'impeach',
#  'broke',
#  'accuse',
#  'smash',
#  'allocate',
#  'ram',
#  'demoralize\xa0',
#  'steer',
#  'spy',
#  'rave',
#  'uncover',
#  'yell',
#  'classify',
#  'unveil',
#  'peep',
#  'squeak',
#  'staff',
#  'terrorize',
#  'maim',
#  'slay',
#  'coordinate',
#  'evade',
#  'justify',
#  'widen',
#  'inspect',
#  'inform',
#  'pound',
#  'importune',
#  'originated',
#  'seal',
#  'drug',
#  'satisfy',
#  'fashion',
#  'flaunt',
#  'mold',
#  'hack',
#  'ensnare',
#  'select',
#  'abominate',
#  'lick',
#  'scour',
#  'fumble',
#  'sip',
#  'despise',
#  'gesture',
#  'indict',
#  'sort',
#  'smear',
#  'synergize',
#  'trained',
#  'tuck',
#  'campaign',
#  'dive',
#  'harass',
#  'dry',
#  'sew',
#  'solve',
#  'capitalize',
#  ...]

# %%
import pickle

# save
with open('data_communityWords.pickle', 'wb') as f:
    pickle.dump(result, f, pickle.HIGHEST_PROTOCOL)

# load
with open('data_communityWords.pickle', 'rb') as f:
    result = pickle.load(f)
    
result
# Out:
# ['discus',
#  'assault',
#  'abscond',
#  'stagger',
#  'provoke',
#  'channel',
#  'improvise',
#  'scar',
#  'rattle',
#  'document',
#  'mediate',
#  'tug',
#  'negotiate',
#  'rejoin',
#  'nick',
#  'derive',
#  'operate',
#  'pin',
#  'clap',
#  'afflict',
#  'collapse',
#  'slacken',
#  'combat',
#  'crawl',
#  'rub',
#  'balance',
#  'skid',
#  'design',
#  'snuggle',
#  'spark',
#  'wrestle',
#  'rush',
#  'specify',
#  'taunt',
#  'recline',
#  'count',
#  'award',
#  'abuse',
#  'nag',
#  'discover',
#  'draft',
#  'indignant',
#  'nominate',
#  'quarrel',
#  'escape',
#  'wade',
#  'roll',
#  'yield',
#  'debate',
#  'flounder',
#  'hover',
#  'parade',
#  'indignity',
#  'splice',
#  'paralyze',
#  'hoist',
#  'actualized',
#  'preside',
#  'unwelcome',
#  'helm',
#  'narrow',
#  'coded',
#  'grasp',
#  'pat',
#  'raised',
#  'sock',
#  'hug',
#  'trip',
#  'needle',
#  'probe',
#  'demonstrate',
#  'brabble',
#  'shear',
#  'improved',
#  'reduce',
#  'scrap',
#  'oversaw',
#  'save',
#  'sear',
#  'walk',
#  'party',
#  'expand',
#  'formalize',
#  'inspire',
#  'revolutionize',
#  'ail',
#  'construct',
#  'dance',
#  'lower',
#  'force',
#  'stumble',
#  'activate',
#  'mourn',
#  'stand',
#  'shield',
#  'blended',
#  'reveal',
#  'influence',
#  'condense',
#  'undertook',
#  'renew',
#  'drive',
#  'sigh',
#  'dress',
#  'shun',
#  'cram',
#  'manage',
#  'dramatize',
#  'oppress',
#  'anticipate',
#  'huff',
#  'relieve',
#  'plan',
#  'enlist',
#  'interchange',
#  'choke',
#  'scuffle',
#  'nab',
#  'parachute',
#  'sit',
#  'flout',
#  'jab',
#  'specialize',
#  'suggest',
#  'shape',
#  'orchestrate',
#  'charter',
#  'deprecate',
#  'facilitate',
#  'thread',
#  'launch',
#  'strip',
#  'spurn',
#  'instruct',
#  'spell',
#  'stress',
#  'torture',
#  'shrink',
#  'nip',
#  'scrape',
#  'extract',
#  'enable',
#  'envy',
#  'sap',
#  'oppose',
#  'quell',
#  'judge',
#  'purchase',
#  'gouge',
#  'block',
#  'curtail',
#  'shut',
#  'exhibit',
#  'slaughter',
#  'emerge',
#  'dispute',
#  'search',
#  'utilize',
#  'page',
#  'contribute',
#  'race',
#  'observe',
#  'destroy',
#  'expose',
#  'govern',
#  'grip',
#  'hurl',
#  'calm',
#  'jar',
#  'head',
#  'rape',
#  'tackle',
#  'undergo',
#  'offer',
#  'affirm',
#  'remove',
#  'scan',
#  'boost',
#  'abolish',
#  'detest',
#  'fade',
#  'shake',
#  'shoulder',
#  'whack',
#  'undress',
#  'avert',
#  'scare',
#  'trounce',
#  'dig',
#  'abhor',
#  'shiver',
#  'pick',
#  'crush',
#  'organized',
#  'succeed',
#  'disservice',
#  'jolt',
#  'stamp',
#  'gall',
#  'cripple',
#  'deplore',
#  'realized',
#  'fondle',
#  'supress',
#  'circumvent',
#  'encourage',
#  'size',
#  'slide',
#  'smite',
#  'illustrate',
#  'drain',
#  'prepared',
#  'dart',
#  'attack',
#  'instigate',
#  'growl',
#  'convey',
#  'haul',
#  'create',
#  'affray',
#  'extricate',
#  'prod',
#  'reconcile',
#  'represent',
#  'resolve',
#  'augment',
#  'whip',
#  'challenge',
#  'parry',
#  'charge',
#  'perform',
#  'install',
#  'chart',
#  'gash',
#  'snitch',
#  'multiply',
#  'arrest',
#  'face',
#  'grind',
#  'finger',
#  'originate',
#  'tie',
#  'disfavor',
#  'revitalize',
#  'seduce',
#  'repair',
#  'kill',
#  'serve',
#  'joined',
#  'outrage',
#  'record',
#  'grew',
#  'devise',
#  'ruffle',
#  'audit',
#  'furnish',
#  'meet',
#  'douse',
#  'plunge',
#  'strive',
#  'pique',
#  'double',
#  'minimize',
#  'rankle',
#  'shorten',
#  'bushwhack',
#  'stop',
#  'conduct',
#  'retrieve',
#  'support',
#  'complete',
#  'tick',
#  'threaten',
#  'attain',
#  'decrease',
#  'undo',
#  'exceed',
#  'fornicate',
#  'induce',
#  'predict',
#  'summon',
#  'hijack',
#  'supervise',
#  'object',
#  'stimulate',
#  'shave',
#  'programmed',
#  'present',
#  'contend',
#  'revise',
#  'supply',
#  'penetrate',
#  'split',
#  'co-authored',
#  'survey',
#  'exit',
#  'blend',
#  'innovate',
#  'jangle',
#  'estimate',
#  'fling',
#  'hasten',
#  'sail',
#  'fall',
#  'skirt',
#  'crouch',
#  'spike',
#  'avoid',
#  'reached',
#  'scream',
#  'type',
#  'flash',
#  'keynote',
#  'confer',
#  'carry',
#  'trot',
#  'insult',
#  'bill',
#  'customize',
#  'conceptualize',
#  'form',
#  'grow',
#  'molest',
#  'spearhead',
#  'expedited',
#  'poke',
#  'salute',
#  'zip',
#  'control',
#  'annihilate',
#  'stifle',
#  'convert',
#  'nail',
#  'pile',
#  'loathe',
#  'quibble',
#  'extirpate',
#  'arbitrate',
#  'outline',
#  'respond',
#  'violate',
#  'stuff',
#  'grapple',
#  'file',
#  'incriminate',
#  'encounter',
#  'master',
#  'scruff',
#  'equip',
#  'hesitate',
#  'address',
#  'mangle',
#  'endeavor',
#  'gyrate',
#  'arrange',
#  'question',
#  'whistle',
#  'brace',
#  'itemize',
#  'screw',
#  'pounce',
#  'secure',
#  'polish',
#  'detonate',
#  'beat',
#  'fast',
#  'usher',
#  'aim',
#  'drill',
#  'dissect',
#  'repulse',
#  'bite',
#  'march',
#  'scratch',
#  'handle',
#  'skip',
#  'mend',
#  'leap',
#  'elope',
#  'partnered',
#  'simplify',
#  'snub',
#  'fend',
#  'fight',
#  'approach',
#  'patrol',
#  'act',
#  'propose',
#  'ravage',
#  'report',
#  'snicker',
#  'perfect',
#  'spring',
#  'wiggle',
#  'thrash',
#  'shoot',
#  'performed',
#  'bash',
#  'centralize',
#  'regulate',
#  'publicize',
#  'turn',
#  'plow',
#  'land',
#  'quicken',
#  'describe',
#  'incense',
#  'top',
#  'strap',
#  'antagonize',
#  'enjoin',
#  'participate',
#  'invade',
#  'snarl',
#  'shaped',
#  'intensify',
#  'enlighten',
#  'blow',
#  'compute',
#  'icky',
#  'bicker',
#  'placate',
#  'research',
#  'determine',
#  'overcome',
#  'improve',
#  'effect',
#  'screen',
#  'halt',
#  'compile',
#  'assure',
#  'dope',
#  'dishearten\xa0',
#  'introduce',
#  'jimmy',
#  'invent',
#  'lash',
#  'mock',
#  'descend',
#  'inflame',
#  'license',
#  'tread',
#  'experience',
#  'strategize',
#  'advise',
#  'consult',
#  'croak',
#  'hold',
#  'vacate',
#  'hammer',
#  'wrought',
#  'pry',
#  'compose',
#  'configure',
#  'retreat',
#  'aid',
#  'led',
#  'divide',
#  'mastermind',
#  'fix',
#  'defy',
#  'chair',
#  'gnaw',
#  'list',
#  'wave',
#  'enter',
#  'synthesize',
#  'hitch',
#  'wrangle',
#  'individualize',
#  'blast',
#  'chase',
#  'reinforce',
#  'soil',
#  'advocate',
#  'project',
#  'stub',
#  'operated',
#  'startle',
#  'pursue',
#  'test',
#  'resist',
#  'sever',
#  'sidestep',
#  'pocket',
#  'focus',
#  'switch',
#  'strain',
#  'clip',
#  'lifted',
#  'reach',
#  'unsettle\xa0',
#  'correspond',
#  'merged',
#  'render',
#  'rob',
#  'scoot',
#  'shell',
#  'transport',
#  'toss',
#  'battle',
#  'set',
#  'exert',
#  'dispatch',
#  'pilot',
#  'transformed',
#  'write',
#  'raid',
#  'primp',
#  'tilt',
#  'isolate',
#  'fulfill',
#  'plod',
#  'unravel',
#  'knife',
#  'field',
#  'pray',
#  'pitch',
#  'snare',
#  'skim',
#  'standardize',
#  'retaliate',
#  'dissent',
#  'listen',
#  'initiated',
#  'step',
#  'strengthen',
#  'enforce',
#  'disapprove',
#  'proofread',
#  'surpass',
#  'snatch',
#  'rock',
#  'discard',
#  'ransack',
#  'grope',
#  'merge',
#  'counsel',
#  'abduct',
#  'recruit',
#  'stun',
#  'collect',
#  'hypothesize',
#  'flee',
#  'pack',
#  'motivate',
#  'inch',
#  'establish',
#  'label',
#  'swagger',
#  'inequity',
#  'communicate',
#  'sum',
#  'extend',
#  'sprint',
#  'accomplish',
#  'attract',
#  'decide',
#  'repel',
#  'scorn',
#  'dismay\xa0',
#  'offense',
#  'detect',
#  'relate',
#  'inject',
#  'ass',
#  'catch',
#  'preen',
#  'slap',
#  'tumble',
#  'twist',
#  'clutch',
#  'fear',
#  'diagnose',
#  'enhance',
#  'imitate',
#  'distress\xa0',
#  'punch',
#  'index',
#  'raise',
#  'swear',
#  'relax',
#  'change',
#  'receive',
#  'review',
#  'sculpt',
#  'push',
#  'clash',
#  'burst',
#  'draw',
#  'flinch',
#  'dictate',
#  'protect',
#  'splatter',
#  'gain',
#  'swerve',
#  'falter',
#  'deliver',
#  'disdain',
#  'keel',
#  'print',
#  'converse',
#  'sniff',
#  'inflate',
#  'verbalize',
#  'spread',
#  'hobble',
#  'produce',
#  'guard',
#  'realize',
#  'deduct',
#  'pas',
#  'discourage\xa0',
#  'service',
#  'sell',
#  'advance',
#  'suck',
#  'swing',
#  'shout',
#  'wedge',
#  'pout',
#  'crafted',
#  'drag',
#  'verify',
#  'outpace',
#  'reel',
#  'tighten',
#  'strangle',
#  'diminish',
#  'explode',
#  'divert',
#  'scuttle',
#  'sense',
#  'interview',
#  'dodge',
#  'champion',
#  'inflict',
#  'stroke',
#  'drink',
#  'scale',
#  'cure',
#  'lift',
#  'apprehend',
#  'lean',
#  'exhale',
#  'sold',
#  'weigh',
#  'tip',
#  'vex',
#  'grunt',
#  'provide',
#  'tolerate',
#  'formulate',
#  'prescribe',
#  'shatter',
#  'adjust',
#  'creep',
#  'published',
#  'update',
#  'flatten',
#  'swap',
#  'maul',
#  'experiment',
#  'tickle',
#  'invest',
#  'deface',
#  'bank',
#  'ensure',
#  'scamper',
#  'authorize',
#  'berate',
#  'enact',
#  'swim',
#  'scout',
#  'triple',
#  'frustrate',
#  'wrench',
#  'coproduced',
#  'enforced',
#  'submit',
#  'quit',
#  'yelp',
#  'contract',
#  'wander',
#  'zap',
#  'volunteer',
#  'jerk',
#  'managed',
#  'roil',
#  'market',
#  'prepare',
#  'fake',
#  'sway',
#  'ease',
#  'perceive',
#  'value',
#  'purge',
#  'recoup',
#  'read',
#  'outperformed',
#  'pull',
#  'shovel',
#  'taught',
#  'deck',
#  'nurture',
#  'teach',
#  'rank',
#  'renovate',
#  'yank',
#  'flick',
#  'measure',
#  'persuade',
#  'meddle',
#  'stick',
#  'scoop',
#  'picket',
#  'hire',
#  'join',
#  'display',
#  'propel',
#  'restore',
#  'wreck',
#  'built',
#  'clarify',
#  'instructed',
#  'irateness',
#  'profitable',
#  'elevate',
#  'wove',
#  'network',
#  'flap',
#  'watch',
#  'defeat',
#  'dash',
#  'escalate',
#  'hail',
#  'rate',
#  'study',
#  'eject',
#  'develop',
#  'hassle',
#  'outpaced',
#  'accelerate',
#  'bar',
#  'paddle',
#  'weed',
#  'endure',
#  'publish',
#  'accumulate',
#  'found',
#  'pioneer',
#  'scatter',
#  'greet',
#  'tout',
#  'ground',
#  'collide',
#  'stock',
#  'spray',
#  'jump',
#  'vault',
#  'struck',
#  'surrender',
#  'limp',
#  'slash',
#  'squabble',
#  'employ',
#  'transform',
#  'smuggle',
#  'fly',
#  'mark',
#  'oversee',
#  'refer',
#  'drown',
#  'translate',
#  'earn',
#  'deal',
#  'administer',
#  'occupy',
#  'terminate',
#  'discomfort\xa0',
#  'redeem',
#  'spur',
#  'identify',
#  'learn',
#  'talk',
#  'mentored',
#  'conserve',
#  'pose',
#  'sustain',
#  'delete',
#  'feed',
#  'streamline',
#  'deliberate',
#  'cooperate',
#  'drape',
#  'infighting',
#  'prompt',
#  'romp',
#  'mumble',
#  'bump',
#  'manufacture',
#  'adapt',
#  'treat',
#  'engineer',
#  'elude',
#  'defended',
#  'drip',
#  'maximize',
#  'struggle',
#  'fan',
#  'discharge',
#  'vanish',
#  'decorate',
#  'tangle',
#  'quiz',
#  'systematize',
#  'eliminate',
#  'collate',
#  'shift',
#  'liaise',
#  'coach',
#  'author',
#  'gossip',
#  'expel',
#  'accrue',
#  'manipulate',
#  'model',
#  'spot',
#  'pirate',
#  'evaluate',
#  'integrate',
#  'process',
#  'publicized',
#  'remodeled',
#  'stack',
#  'trim',
#  'commandeer',
#  'injure',
#  'lead',
#  'bolster',
#  'tutor',
#  'vanquish',
#  'kibitz',
#  'repulsion',
#  'overhaul',
#  'pinch',
#  'rise',
#  'spin',
#  'dare',
#  'fill',
#  'consolidate',
#  'foster',
#  'hide',
#  'vent',
#  'unify',
#  'indignation',
#  'scrawl',
#  'lecture',
#  'hinder',
#  'combine',
#  'muster',
#  'peel',
#  'spear',
#  'snuff',
#  'examine',
#  'mingle',
#  'detail',
#  'implement',
#  'reposition',
#  'altercate',
#  'enlarge',
#  'summarize',
#  'soak',
#  'duel',
#  'hit',
#  'undertake',
#  'analyze',
#  'automate',
#  'shove',
#  'train',
#  'unhinge\xa0',
#  'win',
#  'obtain',
#  'assign',
#  'collaborate',
#  'level',
#  'forecasted',
#  'schedule',
#  'tear',
#  'accost',
#  'trap',
#  'scold',
#  'target',
#  'delegate',
#  'brawl',
#  'appoint',
#  'veto',
#  'expedite',
#  'evacuate',
#  'lunge',
#  'segment',
#  'tease',
#  'transcribe',
#  'resign',
#  'strike',
#  'throw',
#  'ride',
#  'grab',
#  'authenticate',
#  'biff',
#  'insert',
#  'locate',
#  'paw',
#  'pioneered',
#  'flit',
#  'outlined',
#  'magnify',
#  'move',
#  'protest',
#  'relent',
#  'investigate',
#  'calculate',
#  'involve',
#  'scavenge',
#  'mutilate',
#  'gather',
#  'snoop',
#  'spearheaded',
#  'smell',
#  'place',
#  'bury',
#  'collar',
#  'initiate',
#  'order',
#  'explain',
#  'float',
#  'reconnoiter',
#  'photograph',
#  'slug',
#  'swallow',
#  'circumscribe',
#  'regain',
#  'impeach',
#  'broke',
#  'accuse',
#  'smash',
#  'allocate',
#  'ram',
#  'demoralize\xa0',
#  'steer',
#  'spy',
#  'rave',
#  'uncover',
#  'yell',
#  'classify',
#  'unveil',
#  'peep',
#  'squeak',
#  'staff',
#  'terrorize',
#  'maim',
#  'slay',
#  'coordinate',
#  'evade',
#  'justify',
#  'widen',
#  'inspect',
#  'inform',
#  'pound',
#  'importune',
#  'originated',
#  'seal',
#  'drug',
#  'satisfy',
#  'fashion',
#  'flaunt',
#  'mold',
#  'hack',
#  'ensnare',
#  'select',
#  'abominate',
#  'lick',
#  'scour',
#  'fumble',
#  'sip',
#  'despise',
#  'gesture',
#  'indict',
#  'sort',
#  'smear',
#  'synergize',
#  'trained',
#  'tuck',
#  'campaign',
#  'dive',
#  'harass',
#  'dry',
#  'sew',
#  'solve',
#  'capitalize',
#  ...]

# %% [markdown]
# # 이제 이 값을 보기좋게 한줄로 정리를 할 수도 있다.
# 복붙하면 됨. ㅎㅎㅎ.
#
# <br> 참고 : http://javascriptcompressor.com/

# %%
['seems','point','magnificent','confident','given','superior','notably','seen','subject','total','beautiful','repeatedly','come','either','position','sound','mean','light','think?','usually','delicious','rightly','reaction','wicked','expert','it’s','doubtless','evidence','go','surely','really','methinks','cannot','matter.','giving','sure','naturally','carelessly','fabulous','ask','said','estimation','quite','large','typically','complete','unexpected','never','suppose','may','care','reckon','...','unforeseeable','minority','complex','lovely','believe','superb','maybe','primarily','mind','..','observed','possibly','generally','probably','consideration','safely','picturesque','like','great','likely','imagine','consider','bet','standpoint','it’s','sheer','wisely','undoubtedly','prof','tell','opposite',"i'd",'suggests','i’d','initial','incredibly','simply','deadly','main','merely','amazingly','adverbs','staggering','idea','sensational','dare','eye','you’d','seriously','expressed','high','agree','well','positively','pleasant','question','perhaps','unpredictable','conviction','marvellous','excellent','unforeseen','old','thoughtfully','mainly','consistently','sufficiently','astonishing','truthfully','glorious','feeling','idiot','definitely','extraordinary','support','quality','topic','solely','understanding','satisfying','everyone','increasingly','pleasurable','obvious','might','resembles','doubt','delightful','phenomenal','must','conceit','ridiculously','appears','take','wa','find','unduly','opinion','honest','impression','confidentially','disagree','constantly','help','change',"i'm",'way','think','suspect','stunning','could','money','i’ll','complicated','course','alone','least','heavily','judgement','one','due','clear','tend','highly','positive','according','enjoyable','exclusively','bravely','argue','book','precisely','plainly','chiefly','i’ve','best','cleverly','difficult','top','predominantly','personally','wrote','can’t','far','taste','suggest','enormously','prime','unfortunately','unique','summarise','pretend','purely','want','reservation','deny','controversial','rather','right','pleasing','perspective','outta','dreadfully','kindly','indeed','presumably','exactly','wonderful',"one's",'frequently','know','regard','unbelievably','certain','pretty','fulfilling','obviously','matter','although','first-rate','sight','conceivably','sit','awesome','terrific','particularly','gather','thinking','postulate','familiar','perfectly','look','unbelievable','mistaken','vantage','grand','one','conclusion','part','imho','speaking','conclude','standing','classic','humble','scenic','won’t','stupidly','stand','frank','....','impressive','reasonable','spectacular','view','side','absolute','maintain','would','infer','serious','outstanding','mixed','fact','breathtaking','person','say','unlikely','neither','shred','personal','belief','sitting','know','weighing','fortunately','wish','sterling','without','absolutely','admit','utter','mostly','completely','attractive','majestic','totally','shadow','continually','sake','personally','people','towards','fair','claimed','technically','presume','truly','commenting','noticed',"i'm",'exactly.','viewpoint','crazy','speaking','assume','always','limited','much','theoretically','head','gratifying','fantastic','incredible','read','get','reckoning','bitterly','even','correct','without','remarkable','knowledge','tremendous','obviously','exquisite','disappointingly','thought','assumes','especially','miraculous','rewarding','strongly','convinced','concerned','exceptional','case','argument','actual','amazing','i’m','surprising','imposing','charming','entirely','hold','quite','pure','clearly','brilliant','sat','fairly','assessment','understand','surprisingly','seem','guess','generously','see','certainly','foolishly','whole','particular','perfect','wrong','issue','extremely','judgment','argued','frankly','luckily','experience','feel','this.','frankly','saying','later','situation','unusual']
# Out:
# ['seems',
#  'point',
#  'magnificent',
#  'confident',
#  'given',
#  'superior',
#  'notably',
#  'seen',
#  'subject',
#  'total',
#  'beautiful',
#  'repeatedly',
#  'come',
#  'either',
#  'position',
#  'sound',
#  'mean',
#  'light',
#  'think?',
#  'usually',
#  'delicious',
#  'rightly',
#  'reaction',
#  'wicked',
#  'expert',
#  'it’s',
#  'doubtless',
#  'evidence',
#  'go',
#  'surely',
#  'really',
#  'methinks',
#  'cannot',
#  'matter.',
#  'giving',
#  'sure',
#  'naturally',
#  'carelessly',
#  'fabulous',
#  'ask',
#  'said',
#  'estimation',
#  'quite',
#  'large',
#  'typically',
#  'complete',
#  'unexpected',
#  'never',
#  'suppose',
#  'may',
#  'care',
#  'reckon',
#  '...',
#  'unforeseeable',
#  'minority',
#  'complex',
#  'lovely',
#  'believe',
#  'superb',
#  'maybe',
#  'primarily',
#  'mind',
#  '..',
#  'observed',
#  'possibly',
#  'generally',
#  'probably',
#  'consideration',
#  'safely',
#  'picturesque',
#  'like',
#  'great',
#  'likely',
#  'imagine',
#  'consider',
#  'bet',
#  'standpoint',
#  'it’s',
#  'sheer',
#  'wisely',
#  'undoubtedly',
#  'prof',
#  'tell',
#  'opposite',
#  "i'd",
#  'suggests',
#  'i’d',
#  'initial',
#  'incredibly',
#  'simply',
#  'deadly',
#  'main',
#  'merely',
#  'amazingly',
#  'adverbs',
#  'staggering',
#  'idea',
#  'sensational',
#  'dare',
#  'eye',
#  'you’d',
#  'seriously',
#  'expressed',
#  'high',
#  'agree',
#  'well',
#  'positively',
#  'pleasant',
#  'question',
#  'perhaps',
#  'unpredictable',
#  'conviction',
#  'marvellous',
#  'excellent',
#  'unforeseen',
#  'old',
#  'thoughtfully',
#  'mainly',
#  'consistently',
#  'sufficiently',
#  'astonishing',
#  'truthfully',
#  'glorious',
#  'feeling',
#  'idiot',
#  'definitely',
#  'extraordinary',
#  'support',
#  'quality',
#  'topic',
#  'solely',
#  'understanding',
#  'satisfying',
#  'everyone',
#  'increasingly',
#  'pleasurable',
#  'obvious',
#  'might',
#  'resembles',
#  'doubt',
#  'delightful',
#  'phenomenal',
#  'must',
#  'conceit',
#  'ridiculously',
#  'appears',
#  'take',
#  'wa',
#  'find',
#  'unduly',
#  'opinion',
#  'honest',
#  'impression',
#  'confidentially',
#  'disagree',
#  'constantly',
#  'help',
#  'change',
#  "i'm",
#  'way',
#  'think',
#  'suspect',
#  'stunning',
#  'could',
#  'money',
#  'i’ll',
#  'complicated',
#  'course',
#  'alone',
#  'least',
#  'heavily',
#  'judgement',
#  'one',
#  'due',
#  'clear',
#  'tend',
#  'highly',
#  'positive',
#  'according',
#  'enjoyable',
#  'exclusively',
#  'bravely',
#  'argue',
#  'book',
#  'precisely',
#  'plainly',
#  'chiefly',
#  'i’ve',
#  'best',
#  'cleverly',
#  'difficult',
#  'top',
#  'predominantly',
#  'personally',
#  'wrote',
#  'can’t',
#  'far',
#  'taste',
#  'suggest',
#  'enormously',
#  'prime',
#  'unfortunately',
#  'unique',
#  'summarise',
#  'pretend',
#  'purely',
#  'want',
#  'reservation',
#  'deny',
#  'controversial',
#  'rather',
#  'right',
#  'pleasing',
#  'perspective',
#  'outta',
#  'dreadfully',
#  'kindly',
#  'indeed',
#  'presumably',
#  'exactly',
#  'wonderful',
#  "one's",
#  'frequently',
#  'know',
#  'regard',
#  'unbelievably',
#  'certain',
#  'pretty',
#  'fulfilling',
#  'obviously',
#  'matter',
#  'although',
#  'first-rate',
#  'sight',
#  'conceivably',
#  'sit',
#  'awesome',
#  'terrific',
#  'particularly',
#  'gather',
#  'thinking',
#  'postulate',
#  'familiar',
#  'perfectly',
#  'look',
#  'unbelievable',
#  'mistaken',
#  'vantage',
#  'grand',
#  'one',
#  'conclusion',
#  'part',
#  'imho',
#  'speaking',
#  'conclude',
#  'standing',
#  'classic',
#  'humble',
#  'scenic',
#  'won’t',
#  'stupidly',
#  'stand',
#  'frank',
#  '....',
#  'impressive',
#  'reasonable',
#  'spectacular',
#  'view',
#  'side',
#  'absolute',
#  'maintain',
#  'would',
#  'infer',
#  'serious',
#  'outstanding',
#  'mixed',
#  'fact',
#  'breathtaking',
#  'person',
#  'say',
#  'unlikely',
#  'neither',
#  'shred',
#  'personal',
#  'belief',
#  'sitting',
#  'know',
#  'weighing',
#  'fortunately',
#  'wish',
#  'sterling',
#  'without',
#  'absolutely',
#  'admit',
#  'utter',
#  'mostly',
#  'completely',
#  'attractive',
#  'majestic',
#  'totally',
#  'shadow',
#  'continually',
#  'sake',
#  'personally',
#  'people',
#  'towards',
#  'fair',
#  'claimed',
#  'technically',
#  'presume',
#  'truly',
#  'commenting',
#  'noticed',
#  "i'm",
#  'exactly.',
#  'viewpoint',
#  'crazy',
#  'speaking',
#  'assume',
#  'always',
#  'limited',
#  'much',
#  'theoretically',
#  'head',
#  'gratifying',
#  'fantastic',
#  'incredible',
#  'read',
#  'get',
#  'reckoning',
#  'bitterly',
#  'even',
#  'correct',
#  'without',
#  'remarkable',
#  'knowledge',
#  'tremendous',
#  'obviously',
#  'exquisite',
#  'disappointingly',
#  'thought',
#  'assumes',
#  'especially',
#  'miraculous',
#  'rewarding',
#  'strongly',
#  'convinced',
#  'concerned',
#  'exceptional',
#  'case',
#  'argument',
#  'actual',
#  'amazing',
#  'i’m',
#  'surprising',
#  'imposing',
#  'charming',
#  'entirely',
#  'hold',
#  'quite',
#  'pure',
#  'clearly',
#  'brilliant',
#  'sat',
#  'fairly',
#  'assessment',
#  'understand',
#  'surprisingly',
#  'seem',
#  'guess',
#  'generously',
#  'see',
#  'certainly',
#  'foolishly',
#  'whole',
#  'particular',
#  'perfect',
#  'wrong',
#  'issue',
#  'extremely',
#  'judgment',
#  'argued',
#  'frankly',
#  'luckily',
#  'experience',
#  'feel',
#  'this.',
#  'frankly',
#  'saying',
#  'later',
#  'situation',
#  'unusual']
