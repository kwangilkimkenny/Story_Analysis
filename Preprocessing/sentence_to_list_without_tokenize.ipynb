# %% [markdown]
# # 긴 단어로 구성된 명칭을 전체 에세이 문장에서 존재하는지에 대한 판단 코드

# %%
import re
from difflib import SequenceMatcher

# %%
sentences = """RSI (Research Science Institute) at MIT	5
MIT Women's Technology Program (WTP)	5
MITES (Minority Introduction to Engineering and Sciences)	5
LAUNCH at MIT	5
SSP (Summer Science Program)	5
Garcia MRSEC Summer Research Program	5
SIMONS Summer Research Program	4
High School Summer Science Research Program(HSSSRP) at Baylor U	4
CTY Civic  Leadership Institute Program	4
CTY Global Issues in the 21th century	4
Brown Leadership Institute	3
Brown TheaterBridge	3
Brown Intensive English Program (IEP)	3
Brown Environmental Leadership Lab (BELL)	3
CTD (Northwestern)	3
NASA Women in STEM Program	5
NASA Goddard Space Flight Center Internship	5
NASA National Space Club Scholars Program	5
NASA INSPIRE Program	5
TASP (Telluride Association Summer Program)	5
TASS (Telluride Association Sophomore Seminar)	5
The ROSS Mathematics Program	5
PROMYS (Program in Mathematics for Young Scientists)	5
MathWorks Honors Summer Math Camp (HSMC)	4
MOSP (Mathematics Olympiad Summer Program)	5
Governor's School of New Jersey	3
HSHSP (Michigan State University  High school Honors Sciences Program)	4
The Physics of Atomic Nuclei Program at NSCL (National Superconducting Cyclotron Laboratory)	5
Stanford Institute of Medicine Summer Research	4
SUMaC (Stanford U Mathematics Camp)	5
HCSSiM (Hampshire College Summer Studies in Math)	5
Summer Internship Program in Neurological Science National Institute of Health (NIH)	5
SIP (Summer Internship Program in Biomedical Research)	3
Link Summer Science Explorations at Kopernik Observatory	3
Barnard College Saturday Science Seminars (S-Cubed)	3
NYU Tisch School of the Arts High School Program	4
NYU Summer at Steinhardt School	3
New Jersey Scholars Program	3
LEAD Business (Leadership Education and Development)	3
LEAD Engineering (Leadership Education and Development)	3
LEAD Computer Science (Leadership Education and Development)	3
Bronfman Youth Fellowship in Israel	3
Jackson Laboratory Summer Student Program	3
Davidson Institute Young Scholars Stars Summer	3
Business Leadership Program	3
Summer at Walnut Hill	4
CMU SAMS (The Summer Academy for Math + Science)	3
Architecture Pre-College	3
Carnegie Mellon Drama Pre-College Program	3
Carnegie Mellon Art & Design Pre-College	3
Carnegie Mellon Music Pre-College	3
Carnegie Mellon National High School Game Academy	3
Kenyon College The Young Writers Workshop	3
UPenn SAAST (Summer Academy in Applied Science and Technology)	3
U Penn VETS	3
U Penn Wharton Sports Business Academy	4
U Penn LBW (Leadership in Business)	5
U Penn-Nursing Summer Institute	3
U Penn M&TSI Management & Technology Summer Institute	5
U Penn Art & Architecture Summer Program	4
U Penn TREES Teen Research and Education in Environmental Science	3
U Penn Biomedical Research Academy	4
U Penn Chemistry Research Academy	3
U Penn Experimental Physics Research Academy	3
U Penn Social Justice Research Academy	4
U Penn Art in the City Academy	3
U Penn Startalk Urdo, Hindi, and Chinese Academy	3
U Penn Law Summer Academy	3
U Penn Summer BOOT UP Camp	3
Cornell U Research Apprenticeship in Biological Sciences (RABS)	5
Harvard Debate Council Summer Programs	4
SSEP (Summer Science & Engineering Program) at Smith College	3
Yale Young Global Scholars	4
Yale English for High School Students	3
Summer Journalism Program Princeton University	4
Stanford Summer Humanities Institute	4
Northwestern U Medill Cherub Journalism Program	5
(AMSP) AwesomeMath Summer Program	3
Canada/USA Math Camp	4
iD Tech Summer Computer Camp Programs	3
UC San Diego Academic Connections Research Scholars	3
JSA Junior Statesmen of America Summer School	4
VAMPY Summer Program for Verbally and Pathematically Precocious Youths	3
Startalk Chinese at Brigham Young U	3
Startalk Arabic Brigham Young U	3
Startalk ChineseU of Mississippi	3
Concordia Summer Villages	3
The Great Books Summer Program	3
ISSYP (International Summer School for Young Physicists)	5
RISE (Research Internship in Science and Engineering) Boston U	4
Boston U High School Honors	3
Boston U High School Seminars	3
National Scholars Institute (NSI) U of Iowa	4
Secondary Student Training Program (SSTP) at U of Iowa	4
High School BLIPS Berkeley Lab Internships for Precollegiate Students	3
COSMOS California State Summer School for Mathematics and Science	4
(UF-SSTP) Student Science Training Program U of Florida	3
Young Scholars Program UC Davis	3
MMSS (Michigan Math and Science Scholars)	4
Dartmouth Debate Workshop	4
Dartmouth Debate Institute	4
The Health Careers Institute at Dartmouth	3
University of Texas El Paso High School Law Camp	3
NBA Crump Law Camp	3
(GLW) Girls' Leadership Worldwide, Elenor Roosevelt Center at Val-Kill	3
WashU High School Summer Scholars	3
WashU Architecture Discovery Program	3
WashU Portfolio Plus Program	3
UIUC Discover Architecture Pre-College Program	3
Exeter Foreign Language Summer Programs	3
Phillips Andover MS2 Program ( Math and Science for Minority Students)	3
Choate Rosemary Hall Summer Session for High School Students	3
Hotchkiss School Summer Leadership and Social Change Program	3
Classical Music Summer Program at Curtis Institute	3
Summer Internship for High School Students	3
Indiana U High School Journalism Institute	3
National Youth Science Camp	3
RISD Pre-College	3
Columbia Scholastic Press Association (CSPA) Summer Workshop	3
Aspen Music Festival School	3
Boston University Tanglewood Institute(BUTI)	5
Boston University Visual Arts Summer Institute	3
Boston University Summer Theater Institute	3
Bowdoin International Music Festival	3
Eastern Music Festival Summer Study	3
Interlochen Summer Arts Camp	5
Greenwood Chamber Music Camp	3
Mathlinks	3
Math Zoom Summer Academy	3
Rutgers Young Scholars Program in Discrete Mathematics	3
Stanford Clinical Anatomy Summer Research Scholars Program	4
Stanford Surgical Anatomy for High School Seniors and Pre-Med students	4
Google Computer Science Summer Institute (CSSI)	5
UCSF Biomedical and Health Sciences Internship for High School Students	3
Iowa Young Writers Studio	5
Sewanee Young Writers' Conference	4
Harvard medical school DCP	4
Tufts University Adventures in Veterinary Medicine Program	4
CNSI NanoScience Lab Program	3
Mathematics Summer Camp at Stony Brook University	3
School of Creative and Performing Arts Summer Camp	3
The School of Cinematic Arts Summer Program at USC	4
BU Summer Investigative Journalism Workshop	3
Johns Hopkins Engineering Innovation	4
Rensselaer Robotics Engineering Academy	4
The Rockefeller University Summer Neuroscience Program	3
U Chicago Research in the Biological Sciences (RIBS)	4
High School Field Schools with ArchaeoSpain	3
Center for American Archaeology High School Field School	3
Summer Journalism@NYU	3
U of Iowa Summer Journalism Workshops	3
Hankuk University of Foreign Studies International Summer Session in Korean & East Asian Studies	3
Barnard College Young Women's Leadership Institute	3
Notre Dame Pre-College Summer Scholars Program	3
Notre Dame Global Leadership Seminars	5
Emerson College Summer Journalism Institute	3
Columbia Epidemiology Summer Online Course	3
Startalk U of Mississippi	3
Middlebury Monterey Language Academy	4
The Metropolitan Museum of Art Summer Internships for High School Students	3
Tufts University European Center Summer Program	3
French Heritage Language Program Summer Camp	3
Emory University Youth Theological Initiative Summer Academy	3
Summer Linguistics Institute for Youth Scholars at Ohio State University	3
National Security Language Initiative for Youth (NSLI-Y)	3
Brandeis University Genesis Summer Program in Social Entrepreneurship	3
Wake Forest School of Medicines Camp Med	3
University of Miami Nursing Pre-Entry Program	3
Pharmacy Summer Camp at University of Houston	3
Cleveland Clinic Pharmacy Internship Program	3
The Kansas University School of Pharmacy Summer Camp	3
Julliard Summer Dance Intensive	4
American Dance Festival Program at Duke University	3
Mpulse Summer Dance Institute at U Michigan	3
UCLA Summer Dance/Performing Arts Summer Institutes	3
New York City Dance Alliance Summer Intensive	3
School of Visual Arts Summer Pre-College	3
Parsons Pre College Academy	3
The Fashion Institute of Technology’s Pre-college Programs	3
MPulse Summer Performing Arts Institutes	3
Peabody Preparatory Annapolis Campus Music Theory Workshop	3
UC Berkeley embARC Summer Design Academy	3
Hospitality Management Summer Program at U of New Hampshire	3
Les Roches International School of Hotel Management Summer Program	3
Journey for Juniors at Culinary Institute of America	3
Chicago Culinary, Hospitality and Business Camps for High School Students at Kendall College	3
Institute On Neuroscience (ION/Teach) at Emory University	3
Introduction to Radar for Student Engineers at MIT Lincoln Laboratory	3
The Institute for Speech and Debate	3
Rosetta Institute Cancer/Neuroscience Summer Camps	3
U Penn Game Design Summer	3"""

# %%
sent_list = sentences.split('\n')
sent_list
# Out:
# ['RSI (Research Science Institute) at MIT\t5',
#  "MIT Women's Technology Program (WTP)\t5",
#  'MITES (Minority Introduction to Engineering and Sciences)\t5',
#  'LAUNCH at MIT\t5',
#  'SSP (Summer Science Program)\t5',
#  'Garcia MRSEC Summer Research Program\t5',
#  'SIMONS Summer Research Program\t4',
#  'High School Summer Science Research Program(HSSSRP) at Baylor U\t4',
#  'CTY Civic  Leadership Institute Program\t4',
#  'CTY Global Issues in the 21th century\t4',
#  'Brown Leadership Institute\t3',
#  'Brown TheaterBridge\t3',
#  'Brown Intensive English Program (IEP)\t3',
#  'Brown Environmental Leadership Lab (BELL)\t3',
#  'CTD (Northwestern)\t3',
#  'NASA Women in STEM Program\t5',
#  'NASA Goddard Space Flight Center Internship\t5',
#  'NASA National Space Club Scholars Program\t5',
#  'NASA INSPIRE Program\t5',
#  'TASP (Telluride Association Summer Program)\t5',
#  'TASS (Telluride Association Sophomore Seminar)\t5',
#  'The ROSS Mathematics Program\t5',
#  'PROMYS (Program in Mathematics for Young Scientists)\t5',
#  'MathWorks Honors Summer Math Camp (HSMC)\t4',
#  'MOSP (Mathematics Olympiad Summer Program)\t5',
#  "Governor's School of New Jersey\t3",
#  'HSHSP (Michigan State University  High school Honors Sciences Program)\t4',
#  'The Physics of Atomic Nuclei Program at NSCL (National Superconducting Cyclotron Laboratory)\t5',
#  'Stanford Institute of Medicine Summer Research\t4',
#  'SUMaC (Stanford U Mathematics Camp)\t5',
#  'HCSSiM (Hampshire College Summer Studies in Math)\t5',
#  'Summer Internship Program in Neurological Science National Institute of Health (NIH)\t5',
#  'SIP (Summer Internship Program in Biomedical Research)\t3',
#  'Link Summer Science Explorations at Kopernik Observatory\t3',
#  'Barnard College Saturday Science Seminars (S-Cubed)\t3',
#  'NYU Tisch School of the Arts High School Program\t4',
#  'NYU Summer at Steinhardt School\t3',
#  'New Jersey Scholars Program\t3',
#  'LEAD Business (Leadership Education and Development)\t3',
#  'LEAD Engineering (Leadership Education and Development)\t3',
#  'LEAD Computer Science (Leadership Education and Development)\t3',
#  'Bronfman Youth Fellowship in Israel\t3',
#  'Jackson Laboratory Summer Student Program\t3',
#  'Davidson Institute Young Scholars Stars Summer\t3',
#  'Business Leadership Program\t3',
#  'Summer at Walnut Hill\t4',
#  'CMU SAMS (The Summer Academy for Math + Science)\t3',
#  'Architecture Pre-College\t3',
#  'Carnegie Mellon Drama Pre-College Program\t3',
#  'Carnegie Mellon Art & Design Pre-College\t3',
#  'Carnegie Mellon Music Pre-College\t3',
#  'Carnegie Mellon National High School Game Academy\t3',
#  'Kenyon College The Young Writers Workshop\t3',
#  'UPenn SAAST (Summer Academy in Applied Science and Technology)\t3',
#  'U Penn VETS\t3',
#  'U Penn Wharton Sports Business Academy\t4',
#  'U Penn LBW (Leadership in Business)\t5',
#  'U Penn-Nursing Summer Institute\t3',
#  'U Penn M&TSI Management & Technology Summer Institute\t5',
#  'U Penn Art & Architecture Summer Program\t4',
#  'U Penn TREES Teen Research and Education in Environmental Science\t3',
#  'U Penn Biomedical Research Academy\t4',
#  'U Penn Chemistry Research Academy\t3',
#  'U Penn Experimental Physics Research Academy\t3',
#  'U Penn Social Justice Research Academy\t4',
#  'U Penn Art in the City Academy\t3',
#  'U Penn Startalk Urdo, Hindi, and Chinese Academy\t3',
#  'U Penn Law Summer Academy\t3',
#  'U Penn Summer BOOT UP Camp\t3',
#  'Cornell U Research Apprenticeship in Biological Sciences (RABS)\t5',
#  'Harvard Debate Council Summer Programs\t4',
#  'SSEP (Summer Science & Engineering Program) at Smith College\t3',
#  'Yale Young Global Scholars\t4',
#  'Yale English for High School Students\t3',
#  'Summer Journalism Program Princeton University\t4',
#  'Stanford Summer Humanities Institute\t4',
#  'Northwestern U Medill Cherub Journalism Program\t5',
#  '(AMSP) AwesomeMath Summer Program\t3',
#  'Canada/USA Math Camp\t4',
#  'iD Tech Summer Computer Camp Programs\t3',
#  'UC San Diego Academic Connections Research Scholars\t3',
#  'JSA Junior Statesmen of America Summer School\t4',
#  'VAMPY Summer Program for Verbally and Pathematically Precocious Youths\t3',
#  'Startalk Chinese at Brigham Young U\t3',
#  'Startalk Arabic Brigham Young U\t3',
#  'Startalk ChineseU of Mississippi\t3',
#  'Concordia Summer Villages\t3',
#  'The Great Books Summer Program\t3',
#  'ISSYP (International Summer School for Young Physicists)\t5',
#  'RISE (Research Internship in Science and Engineering) Boston U\t4',
#  'Boston U High School Honors\t3',
#  'Boston U High School Seminars\t3',
#  'National Scholars Institute (NSI) U of Iowa\t4',
#  'Secondary Student Training Program (SSTP) at U of Iowa\t4',
#  'High School BLIPS Berkeley Lab Internships for Precollegiate Students\t3',
#  'COSMOS California State Summer School for Mathematics and Science\t4',
#  '(UF-SSTP) Student Science Training Program U of Florida\t3',
#  'Young Scholars Program UC Davis\t3',
#  'MMSS (Michigan Math and Science Scholars)\t4',
#  'Dartmouth Debate Workshop\t4',
#  'Dartmouth Debate Institute\t4',
#  'The Health Careers Institute at Dartmouth\t3',
#  'University of Texas El Paso High School Law Camp\t3',
#  'NBA Crump Law Camp\t3',
#  "(GLW) Girls' Leadership Worldwide, Elenor Roosevelt Center at Val-Kill\t3",
#  'WashU High School Summer Scholars\t3',
#  'WashU Architecture Discovery Program\t3',
#  'WashU Portfolio Plus Program\t3',
#  'UIUC Discover Architecture Pre-College Program\t3',
#  'Exeter Foreign Language Summer Programs\t3',
#  'Phillips Andover MS2 Program ( Math and Science for Minority Students)\t3',
#  'Choate Rosemary Hall Summer Session for High School Students\t3',
#  'Hotchkiss School Summer Leadership and Social Change Program\t3',
#  'Classical Music Summer Program at Curtis Institute\t3',
#  'Summer Internship for High School Students\t3',
#  'Indiana U High School Journalism Institute\t3',
#  'National Youth Science Camp\t3',
#  'RISD Pre-College\t3',
#  'Columbia Scholastic Press Association (CSPA) Summer Workshop\t3',
#  'Aspen Music Festival School\t3',
#  'Boston University Tanglewood Institute(BUTI)\t5',
#  'Boston University Visual Arts Summer Institute\t3',
#  'Boston University Summer Theater Institute\t3',
#  'Bowdoin International Music Festival\t3',
#  'Eastern Music Festival Summer Study\t3',
#  'Interlochen Summer Arts Camp\t5',
#  'Greenwood Chamber Music Camp\t3',
#  'Mathlinks\t3',
#  'Math Zoom Summer Academy\t3',
#  'Rutgers Young Scholars Program in Discrete Mathematics\t3',
#  'Stanford Clinical Anatomy Summer Research Scholars Program\t4',
#  'Stanford Surgical Anatomy for High School Seniors and Pre-Med students\t4',
#  'Google Computer Science Summer Institute (CSSI)\t5',
#  'UCSF Biomedical and Health Sciences Internship for High School Students\t3',
#  'Iowa Young Writers Studio\t5',
#  "Sewanee Young Writers' Conference\t4",
#  'Harvard medical school DCP\t4',
#  'Tufts University Adventures in Veterinary Medicine Program\t4',
#  'CNSI NanoScience Lab Program\t3',
#  'Mathematics Summer Camp at Stony Brook University\t3',
#  'School of Creative and Performing Arts Summer Camp\t3',
#  'The School of Cinematic Arts Summer Program at USC\t4',
#  'BU Summer Investigative Journalism Workshop\t3',
#  'Johns Hopkins Engineering Innovation\t4',
#  'Rensselaer Robotics Engineering Academy\t4',
#  'The Rockefeller University Summer Neuroscience Program\t3',
#  'U Chicago Research in the Biological Sciences (RIBS)\t4',
#  'High School Field Schools with ArchaeoSpain\t3',
#  'Center for American Archaeology High School Field School\t3',
#  'Summer Journalism@NYU\t3',
#  'U of Iowa Summer Journalism Workshops\t3',
#  'Hankuk University of Foreign Studies International Summer Session in Korean & East Asian Studies\t3',
#  "Barnard College Young Women's Leadership Institute\t3",
#  'Notre Dame Pre-College Summer Scholars Program\t3',
#  'Notre Dame Global Leadership Seminars\t5',
#  'Emerson College Summer Journalism Institute\t3',
#  'Columbia Epidemiology Summer Online Course\t3',
#  'Startalk U of Mississippi\t3',
#  'Middlebury Monterey Language Academy\t4',
#  'The Metropolitan Museum of Art Summer Internships for High School Students\t3',
#  'Tufts University European Center Summer Program\t3',
#  'French Heritage Language Program Summer Camp\t3',
#  'Emory University Youth Theological Initiative Summer Academy\t3',
#  'Summer Linguistics Institute for Youth Scholars at Ohio State University\t3',
#  'National Security Language Initiative for Youth (NSLI-Y)\t3',
#  'Brandeis University Genesis Summer Program in Social Entrepreneurship\t3',
#  'Wake Forest School of Medicines Camp Med\t3',
#  'University of Miami Nursing Pre-Entry Program\t3',
#  'Pharmacy Summer Camp at University of Houston\t3',
#  'Cleveland Clinic Pharmacy Internship Program\t3',
#  'The Kansas University School of Pharmacy Summer Camp\t3',
#  'Julliard Summer Dance Intensive\t4',
#  'American Dance Festival Program at Duke University\t3',
#  'Mpulse Summer Dance Institute at U Michigan\t3',
#  'UCLA Summer Dance/Performing Arts Summer Institutes\t3',
#  'New York City Dance Alliance Summer Intensive\t3',
#  'School of Visual Arts Summer Pre-College\t3',
#  'Parsons Pre College Academy\t3',
#  'The Fashion Institute of Technology’s Pre-college Programs\t3',
#  'MPulse Summer Performing Arts Institutes\t3',
#  'Peabody Preparatory Annapolis Campus Music Theory Workshop\t3',
#  'UC Berkeley embARC Summer Design Academy\t3',
#  'Hospitality Management Summer Program at U of New Hampshire\t3',
#  'Les Roches International School of Hotel Management Summer Program\t3',
#  'Journey for Juniors at Culinary Institute of America\t3',
#  'Chicago Culinary, Hospitality and Business Camps for High School Students at Kendall College\t3',
#  'Institute On Neuroscience (ION/Teach) at Emory University\t3',
#  'Introduction to Radar for Student Engineers at MIT Lincoln Laboratory\t3',
#  'The Institute for Speech and Debate\t3',
#  'Rosetta Institute Cancer/Neuroscience Summer Camps\t3',
#  'U Penn Game Design Summer\t3']

# %%
# 각 리스트를 다시 단어로 스플릿하여 개별 리스트로 만듬
sentence_list = []
for i in sent_list:
    i_ = re.sub("[()]", "", i)
    j = i_.split()
    sentence_list.append(j)

sentence_list
# Out:
# [['RSI', 'Research', 'Science', 'Institute', 'at', 'MIT', '5'],
#  ['MIT', "Women's", 'Technology', 'Program', 'WTP', '5'],
#  ['MITES',
#   'Minority',
#   'Introduction',
#   'to',
#   'Engineering',
#   'and',
#   'Sciences',
#   '5'],
#  ['LAUNCH', 'at', 'MIT', '5'],
#  ['SSP', 'Summer', 'Science', 'Program', '5'],
#  ['Garcia', 'MRSEC', 'Summer', 'Research', 'Program', '5'],
#  ['SIMONS', 'Summer', 'Research', 'Program', '4'],
#  ['High',
#   'School',
#   'Summer',
#   'Science',
#   'Research',
#   'ProgramHSSSRP',
#   'at',
#   'Baylor',
#   'U',
#   '4'],
#  ['CTY', 'Civic', 'Leadership', 'Institute', 'Program', '4'],
#  ['CTY', 'Global', 'Issues', 'in', 'the', '21th', 'century', '4'],
#  ['Brown', 'Leadership', 'Institute', '3'],
#  ['Brown', 'TheaterBridge', '3'],
#  ['Brown', 'Intensive', 'English', 'Program', 'IEP', '3'],
#  ['Brown', 'Environmental', 'Leadership', 'Lab', 'BELL', '3'],
#  ['CTD', 'Northwestern', '3'],
#  ['NASA', 'Women', 'in', 'STEM', 'Program', '5'],
#  ['NASA', 'Goddard', 'Space', 'Flight', 'Center', 'Internship', '5'],
#  ['NASA', 'National', 'Space', 'Club', 'Scholars', 'Program', '5'],
#  ['NASA', 'INSPIRE', 'Program', '5'],
#  ['TASP', 'Telluride', 'Association', 'Summer', 'Program', '5'],
#  ['TASS', 'Telluride', 'Association', 'Sophomore', 'Seminar', '5'],
#  ['The', 'ROSS', 'Mathematics', 'Program', '5'],
#  ['PROMYS', 'Program', 'in', 'Mathematics', 'for', 'Young', 'Scientists', '5'],
#  ['MathWorks', 'Honors', 'Summer', 'Math', 'Camp', 'HSMC', '4'],
#  ['MOSP', 'Mathematics', 'Olympiad', 'Summer', 'Program', '5'],
#  ["Governor's", 'School', 'of', 'New', 'Jersey', '3'],
#  ['HSHSP',
#   'Michigan',
#   'State',
#   'University',
#   'High',
#   'school',
#   'Honors',
#   'Sciences',
#   'Program',
#   '4'],
#  ['The',
#   'Physics',
#   'of',
#   'Atomic',
#   'Nuclei',
#   'Program',
#   'at',
#   'NSCL',
#   'National',
#   'Superconducting',
#   'Cyclotron',
#   'Laboratory',
#   '5'],
#  ['Stanford', 'Institute', 'of', 'Medicine', 'Summer', 'Research', '4'],
#  ['SUMaC', 'Stanford', 'U', 'Mathematics', 'Camp', '5'],
#  ['HCSSiM', 'Hampshire', 'College', 'Summer', 'Studies', 'in', 'Math', '5'],
#  ['Summer',
#   'Internship',
#   'Program',
#   'in',
#   'Neurological',
#   'Science',
#   'National',
#   'Institute',
#   'of',
#   'Health',
#   'NIH',
#   '5'],
#  ['SIP',
#   'Summer',
#   'Internship',
#   'Program',
#   'in',
#   'Biomedical',
#   'Research',
#   '3'],
#  ['Link',
#   'Summer',
#   'Science',
#   'Explorations',
#   'at',
#   'Kopernik',
#   'Observatory',
#   '3'],
#  ['Barnard', 'College', 'Saturday', 'Science', 'Seminars', 'S-Cubed', '3'],
#  ['NYU',
#   'Tisch',
#   'School',
#   'of',
#   'the',
#   'Arts',
#   'High',
#   'School',
#   'Program',
#   '4'],
#  ['NYU', 'Summer', 'at', 'Steinhardt', 'School', '3'],
#  ['New', 'Jersey', 'Scholars', 'Program', '3'],
#  ['LEAD', 'Business', 'Leadership', 'Education', 'and', 'Development', '3'],
#  ['LEAD', 'Engineering', 'Leadership', 'Education', 'and', 'Development', '3'],
#  ['LEAD',
#   'Computer',
#   'Science',
#   'Leadership',
#   'Education',
#   'and',
#   'Development',
#   '3'],
#  ['Bronfman', 'Youth', 'Fellowship', 'in', 'Israel', '3'],
#  ['Jackson', 'Laboratory', 'Summer', 'Student', 'Program', '3'],
#  ['Davidson', 'Institute', 'Young', 'Scholars', 'Stars', 'Summer', '3'],
#  ['Business', 'Leadership', 'Program', '3'],
#  ['Summer', 'at', 'Walnut', 'Hill', '4'],
#  ['CMU',
#   'SAMS',
#   'The',
#   'Summer',
#   'Academy',
#   'for',
#   'Math',
#   '+',
#   'Science',
#   '3'],
#  ['Architecture', 'Pre-College', '3'],
#  ['Carnegie', 'Mellon', 'Drama', 'Pre-College', 'Program', '3'],
#  ['Carnegie', 'Mellon', 'Art', '&', 'Design', 'Pre-College', '3'],
#  ['Carnegie', 'Mellon', 'Music', 'Pre-College', '3'],
#  ['Carnegie', 'Mellon', 'National', 'High', 'School', 'Game', 'Academy', '3'],
#  ['Kenyon', 'College', 'The', 'Young', 'Writers', 'Workshop', '3'],
#  ['UPenn',
#   'SAAST',
#   'Summer',
#   'Academy',
#   'in',
#   'Applied',
#   'Science',
#   'and',
#   'Technology',
#   '3'],
#  ['U', 'Penn', 'VETS', '3'],
#  ['U', 'Penn', 'Wharton', 'Sports', 'Business', 'Academy', '4'],
#  ['U', 'Penn', 'LBW', 'Leadership', 'in', 'Business', '5'],
#  ['U', 'Penn-Nursing', 'Summer', 'Institute', '3'],
#  ['U',
#   'Penn',
#   'M&TSI',
#   'Management',
#   '&',
#   'Technology',
#   'Summer',
#   'Institute',
#   '5'],
#  ['U', 'Penn', 'Art', '&', 'Architecture', 'Summer', 'Program', '4'],
#  ['U',
#   'Penn',
#   'TREES',
#   'Teen',
#   'Research',
#   'and',
#   'Education',
#   'in',
#   'Environmental',
#   'Science',
#   '3'],
#  ['U', 'Penn', 'Biomedical', 'Research', 'Academy', '4'],
#  ['U', 'Penn', 'Chemistry', 'Research', 'Academy', '3'],
#  ['U', 'Penn', 'Experimental', 'Physics', 'Research', 'Academy', '3'],
#  ['U', 'Penn', 'Social', 'Justice', 'Research', 'Academy', '4'],
#  ['U', 'Penn', 'Art', 'in', 'the', 'City', 'Academy', '3'],
#  ['U',
#   'Penn',
#   'Startalk',
#   'Urdo,',
#   'Hindi,',
#   'and',
#   'Chinese',
#   'Academy',
#   '3'],
#  ['U', 'Penn', 'Law', 'Summer', 'Academy', '3'],
#  ['U', 'Penn', 'Summer', 'BOOT', 'UP', 'Camp', '3'],
#  ['Cornell',
#   'U',
#   'Research',
#   'Apprenticeship',
#   'in',
#   'Biological',
#   'Sciences',
#   'RABS',
#   '5'],
#  ['Harvard', 'Debate', 'Council', 'Summer', 'Programs', '4'],
#  ['SSEP',
#   'Summer',
#   'Science',
#   '&',
#   'Engineering',
#   'Program',
#   'at',
#   'Smith',
#   'College',
#   '3'],
#  ['Yale', 'Young', 'Global', 'Scholars', '4'],
#  ['Yale', 'English', 'for', 'High', 'School', 'Students', '3'],
#  ['Summer', 'Journalism', 'Program', 'Princeton', 'University', '4'],
#  ['Stanford', 'Summer', 'Humanities', 'Institute', '4'],
#  ['Northwestern', 'U', 'Medill', 'Cherub', 'Journalism', 'Program', '5'],
#  ['AMSP', 'AwesomeMath', 'Summer', 'Program', '3'],
#  ['Canada/USA', 'Math', 'Camp', '4'],
#  ['iD', 'Tech', 'Summer', 'Computer', 'Camp', 'Programs', '3'],
#  ['UC',
#   'San',
#   'Diego',
#   'Academic',
#   'Connections',
#   'Research',
#   'Scholars',
#   '3'],
#  ['JSA', 'Junior', 'Statesmen', 'of', 'America', 'Summer', 'School', '4'],
#  ['VAMPY',
#   'Summer',
#   'Program',
#   'for',
#   'Verbally',
#   'and',
#   'Pathematically',
#   'Precocious',
#   'Youths',
#   '3'],
#  ['Startalk', 'Chinese', 'at', 'Brigham', 'Young', 'U', '3'],
#  ['Startalk', 'Arabic', 'Brigham', 'Young', 'U', '3'],
#  ['Startalk', 'ChineseU', 'of', 'Mississippi', '3'],
#  ['Concordia', 'Summer', 'Villages', '3'],
#  ['The', 'Great', 'Books', 'Summer', 'Program', '3'],
#  ['ISSYP',
#   'International',
#   'Summer',
#   'School',
#   'for',
#   'Young',
#   'Physicists',
#   '5'],
#  ['RISE',
#   'Research',
#   'Internship',
#   'in',
#   'Science',
#   'and',
#   'Engineering',
#   'Boston',
#   'U',
#   '4'],
#  ['Boston', 'U', 'High', 'School', 'Honors', '3'],
#  ['Boston', 'U', 'High', 'School', 'Seminars', '3'],
#  ['National', 'Scholars', 'Institute', 'NSI', 'U', 'of', 'Iowa', '4'],
#  ['Secondary',
#   'Student',
#   'Training',
#   'Program',
#   'SSTP',
#   'at',
#   'U',
#   'of',
#   'Iowa',
#   '4'],
#  ['High',
#   'School',
#   'BLIPS',
#   'Berkeley',
#   'Lab',
#   'Internships',
#   'for',
#   'Precollegiate',
#   'Students',
#   '3'],
#  ['COSMOS',
#   'California',
#   'State',
#   'Summer',
#   'School',
#   'for',
#   'Mathematics',
#   'and',
#   'Science',
#   '4'],
#  ['UF-SSTP',
#   'Student',
#   'Science',
#   'Training',
#   'Program',
#   'U',
#   'of',
#   'Florida',
#   '3'],
#  ['Young', 'Scholars', 'Program', 'UC', 'Davis', '3'],
#  ['MMSS', 'Michigan', 'Math', 'and', 'Science', 'Scholars', '4'],
#  ['Dartmouth', 'Debate', 'Workshop', '4'],
#  ['Dartmouth', 'Debate', 'Institute', '4'],
#  ['The', 'Health', 'Careers', 'Institute', 'at', 'Dartmouth', '3'],
#  ['University',
#   'of',
#   'Texas',
#   'El',
#   'Paso',
#   'High',
#   'School',
#   'Law',
#   'Camp',
#   '3'],
#  ['NBA', 'Crump', 'Law', 'Camp', '3'],
#  ['GLW',
#   "Girls'",
#   'Leadership',
#   'Worldwide,',
#   'Elenor',
#   'Roosevelt',
#   'Center',
#   'at',
#   'Val-Kill',
#   '3'],
#  ['WashU', 'High', 'School', 'Summer', 'Scholars', '3'],
#  ['WashU', 'Architecture', 'Discovery', 'Program', '3'],
#  ['WashU', 'Portfolio', 'Plus', 'Program', '3'],
#  ['UIUC', 'Discover', 'Architecture', 'Pre-College', 'Program', '3'],
#  ['Exeter', 'Foreign', 'Language', 'Summer', 'Programs', '3'],
#  ['Phillips',
#   'Andover',
#   'MS2',
#   'Program',
#   'Math',
#   'and',
#   'Science',
#   'for',
#   'Minority',
#   'Students',
#   '3'],
#  ['Choate',
#   'Rosemary',
#   'Hall',
#   'Summer',
#   'Session',
#   'for',
#   'High',
#   'School',
#   'Students',
#   '3'],
#  ['Hotchkiss',
#   'School',
#   'Summer',
#   'Leadership',
#   'and',
#   'Social',
#   'Change',
#   'Program',
#   '3'],
#  ['Classical', 'Music', 'Summer', 'Program', 'at', 'Curtis', 'Institute', '3'],
#  ['Summer', 'Internship', 'for', 'High', 'School', 'Students', '3'],
#  ['Indiana', 'U', 'High', 'School', 'Journalism', 'Institute', '3'],
#  ['National', 'Youth', 'Science', 'Camp', '3'],
#  ['RISD', 'Pre-College', '3'],
#  ['Columbia',
#   'Scholastic',
#   'Press',
#   'Association',
#   'CSPA',
#   'Summer',
#   'Workshop',
#   '3'],
#  ['Aspen', 'Music', 'Festival', 'School', '3'],
#  ['Boston', 'University', 'Tanglewood', 'InstituteBUTI', '5'],
#  ['Boston', 'University', 'Visual', 'Arts', 'Summer', 'Institute', '3'],
#  ['Boston', 'University', 'Summer', 'Theater', 'Institute', '3'],
#  ['Bowdoin', 'International', 'Music', 'Festival', '3'],
#  ['Eastern', 'Music', 'Festival', 'Summer', 'Study', '3'],
#  ['Interlochen', 'Summer', 'Arts', 'Camp', '5'],
#  ['Greenwood', 'Chamber', 'Music', 'Camp', '3'],
#  ['Mathlinks', '3'],
#  ['Math', 'Zoom', 'Summer', 'Academy', '3'],
#  ['Rutgers',
#   'Young',
#   'Scholars',
#   'Program',
#   'in',
#   'Discrete',
#   'Mathematics',
#   '3'],
#  ['Stanford',
#   'Clinical',
#   'Anatomy',
#   'Summer',
#   'Research',
#   'Scholars',
#   'Program',
#   '4'],
#  ['Stanford',
#   'Surgical',
#   'Anatomy',
#   'for',
#   'High',
#   'School',
#   'Seniors',
#   'and',
#   'Pre-Med',
#   'students',
#   '4'],
#  ['Google', 'Computer', 'Science', 'Summer', 'Institute', 'CSSI', '5'],
#  ['UCSF',
#   'Biomedical',
#   'and',
#   'Health',
#   'Sciences',
#   'Internship',
#   'for',
#   'High',
#   'School',
#   'Students',
#   '3'],
#  ['Iowa', 'Young', 'Writers', 'Studio', '5'],
#  ['Sewanee', 'Young', "Writers'", 'Conference', '4'],
#  ['Harvard', 'medical', 'school', 'DCP', '4'],
#  ['Tufts',
#   'University',
#   'Adventures',
#   'in',
#   'Veterinary',
#   'Medicine',
#   'Program',
#   '4'],
#  ['CNSI', 'NanoScience', 'Lab', 'Program', '3'],
#  ['Mathematics', 'Summer', 'Camp', 'at', 'Stony', 'Brook', 'University', '3'],
#  ['School',
#   'of',
#   'Creative',
#   'and',
#   'Performing',
#   'Arts',
#   'Summer',
#   'Camp',
#   '3'],
#  ['The',
#   'School',
#   'of',
#   'Cinematic',
#   'Arts',
#   'Summer',
#   'Program',
#   'at',
#   'USC',
#   '4'],
#  ['BU', 'Summer', 'Investigative', 'Journalism', 'Workshop', '3'],
#  ['Johns', 'Hopkins', 'Engineering', 'Innovation', '4'],
#  ['Rensselaer', 'Robotics', 'Engineering', 'Academy', '4'],
#  ['The',
#   'Rockefeller',
#   'University',
#   'Summer',
#   'Neuroscience',
#   'Program',
#   '3'],
#  ['U',
#   'Chicago',
#   'Research',
#   'in',
#   'the',
#   'Biological',
#   'Sciences',
#   'RIBS',
#   '4'],
#  ['High', 'School', 'Field', 'Schools', 'with', 'ArchaeoSpain', '3'],
#  ['Center',
#   'for',
#   'American',
#   'Archaeology',
#   'High',
#   'School',
#   'Field',
#   'School',
#   '3'],
#  ['Summer', 'Journalism@NYU', '3'],
#  ['U', 'of', 'Iowa', 'Summer', 'Journalism', 'Workshops', '3'],
#  ['Hankuk',
#   'University',
#   'of',
#   'Foreign',
#   'Studies',
#   'International',
#   'Summer',
#   'Session',
#   'in',
#   'Korean',
#   '&',
#   'East',
#   'Asian',
#   'Studies',
#   '3'],
#  ['Barnard', 'College', 'Young', "Women's", 'Leadership', 'Institute', '3'],
#  ['Notre', 'Dame', 'Pre-College', 'Summer', 'Scholars', 'Program', '3'],
#  ['Notre', 'Dame', 'Global', 'Leadership', 'Seminars', '5'],
#  ['Emerson', 'College', 'Summer', 'Journalism', 'Institute', '3'],
#  ['Columbia', 'Epidemiology', 'Summer', 'Online', 'Course', '3'],
#  ['Startalk', 'U', 'of', 'Mississippi', '3'],
#  ['Middlebury', 'Monterey', 'Language', 'Academy', '4'],
#  ['The',
#   'Metropolitan',
#   'Museum',
#   'of',
#   'Art',
#   'Summer',
#   'Internships',
#   'for',
#   'High',
#   'School',
#   'Students',
#   '3'],
#  ['Tufts', 'University', 'European', 'Center', 'Summer', 'Program', '3'],
#  ['French', 'Heritage', 'Language', 'Program', 'Summer', 'Camp', '3'],
#  ['Emory',
#   'University',
#   'Youth',
#   'Theological',
#   'Initiative',
#   'Summer',
#   'Academy',
#   '3'],
#  ['Summer',
#   'Linguistics',
#   'Institute',
#   'for',
#   'Youth',
#   'Scholars',
#   'at',
#   'Ohio',
#   'State',
#   'University',
#   '3'],
#  ['National',
#   'Security',
#   'Language',
#   'Initiative',
#   'for',
#   'Youth',
#   'NSLI-Y',
#   '3'],
#  ['Brandeis',
#   'University',
#   'Genesis',
#   'Summer',
#   'Program',
#   'in',
#   'Social',
#   'Entrepreneurship',
#   '3'],
#  ['Wake', 'Forest', 'School', 'of', 'Medicines', 'Camp', 'Med', '3'],
#  ['University', 'of', 'Miami', 'Nursing', 'Pre-Entry', 'Program', '3'],
#  ['Pharmacy', 'Summer', 'Camp', 'at', 'University', 'of', 'Houston', '3'],
#  ['Cleveland', 'Clinic', 'Pharmacy', 'Internship', 'Program', '3'],
#  ['The',
#   'Kansas',
#   'University',
#   'School',
#   'of',
#   'Pharmacy',
#   'Summer',
#   'Camp',
#   '3'],
#  ['Julliard', 'Summer', 'Dance', 'Intensive', '4'],
#  ['American', 'Dance', 'Festival', 'Program', 'at', 'Duke', 'University', '3'],
#  ['Mpulse', 'Summer', 'Dance', 'Institute', 'at', 'U', 'Michigan', '3'],
#  ['UCLA', 'Summer', 'Dance/Performing', 'Arts', 'Summer', 'Institutes', '3'],
#  ['New', 'York', 'City', 'Dance', 'Alliance', 'Summer', 'Intensive', '3'],
#  ['School', 'of', 'Visual', 'Arts', 'Summer', 'Pre-College', '3'],
#  ['Parsons', 'Pre', 'College', 'Academy', '3'],
#  ['The',
#   'Fashion',
#   'Institute',
#   'of',
#   'Technology’s',
#   'Pre-college',
#   'Programs',
#   '3'],
#  ['MPulse', 'Summer', 'Performing', 'Arts', 'Institutes', '3'],
#  ['Peabody',
#   'Preparatory',
#   'Annapolis',
#   'Campus',
#   'Music',
#   'Theory',
#   'Workshop',
#   '3'],
#  ['UC', 'Berkeley', 'embARC', 'Summer', 'Design', 'Academy', '3'],
#  ['Hospitality',
#   'Management',
#   'Summer',
#   'Program',
#   'at',
#   'U',
#   'of',
#   'New',
#   'Hampshire',
#   '3'],
#  ['Les',
#   'Roches',
#   'International',
#   'School',
#   'of',
#   'Hotel',
#   'Management',
#   'Summer',
#   'Program',
#   '3'],
#  ['Journey',
#   'for',
#   'Juniors',
#   'at',
#   'Culinary',
#   'Institute',
#   'of',
#   'America',
#   '3'],
#  ['Chicago',
#   'Culinary,',
#   'Hospitality',
#   'and',
#   'Business',
#   'Camps',
#   'for',
#   'High',
#   'School',
#   'Students',
#   'at',
#   'Kendall',
#   'College',
#   '3'],
#  ['Institute',
#   'On',
#   'Neuroscience',
#   'ION/Teach',
#   'at',
#   'Emory',
#   'University',
#   '3'],
#  ['Introduction',
#   'to',
#   'Radar',
#   'for',
#   'Student',
#   'Engineers',
#   'at',
#   'MIT',
#   'Lincoln',
#   'Laboratory',
#   '3'],
#  ['The', 'Institute', 'for', 'Speech', 'and', 'Debate', '3'],
#  ['Rosetta', 'Institute', 'Cancer/Neuroscience', 'Summer', 'Camps', '3'],
#  ['U', 'Penn', 'Game', 'Design', 'Summer', '3']]

# %%
essay_input = """This past summer, I had the privilege of participating in the University of Notre Dame’s Research Experience for Undergraduates (REU) program . Under the mentorship of Professor Wendy Bozeman and Professor Georgia Lebedev from the department of Biological Sciences, my goal this summer was to research the effects of cobalt iron oxide cored (CoFe2O3) titanium dioxide (TiO2) nanoparticles as a scaffold for drug delivery, specifically in the delivery of a compound known as curcumin, a flavonoid known for its anti-inflammatory effects. As a high school student trying to find a research opportunity, it was very difficult to find a place that was willing to take me in, but after many months of trying, I sought the help of my high school biology teacher, who used his resources to help me obtain a position in the program.				
Using equipment that a high school student could only dream of using, The Rockefeller University Summer Neuroscience Program, I was able to map apoptosis (programmed cell death) versus necrosis (cell death due to damage) in HeLa cells, a cervical cancer line, after treating them with curcumin-bound nanoparticles. Using flow cytometry to excite each individually suspended cell with a laser, the scattered light from the cells helped to determine which cells were living, had died from apoptosis or had died from necrosis. Using this collected data, it was possible to determine if the curcumin and/or the nanoparticles had played any significant role on the cervical cancer cells. Later, I was able to image cells in 4D through con-focal microscopy. From growing HeLa cells to trying to kill them with different compounds, I was able to gain the hands-on experience necessary for me to realize once again why I love science.				
Living on the Notre Dame campus with other REU students, UND athletes, and other summer school students was a whole other experience that prepared me for the world beyond high school. For 9 weeks, I worked, played and bonded with the other students, and had the opportunity to live the life of an independent college student.				
Along with the individually tailored research projects and the housing opportunity, there were seminars on public speaking, trips to the Fermi National Accelerator Laboratory, and one-on-one writing seminars for the end of the summer research papers we were each required to write. By the end of the summer, I wasn’t ready to leave the research that I was doing. While my research didn’t yield definitive results for the effects of curcumin on cervical cancer cells, my research on curcumin-functionalized CoFe2O4/TiO2 core-shell nanoconjugates indicated that there were many unknown factors affecting the HeLa cells, and spurred the lab to expand their research into determining whether or not the timing of the drug delivery mattered and whether or not the position of the binding site of the drugs would alter the results. Through this summer experience, I realized my ambition to pursue a career in research. I always knew that I would want to pursue a future in science, but the exciting world of research where the discoveries are limitless has captured my heart. This school year, the REU program has offered me a year-long job, and despite my obligations as a high school senior preparing for college, I couldn’t give up this offer, and so during this school year, I will be able to further both my research and interest in nanotechnology. """

# %%
# 문자열 매칭을 비교할 수 있다.  그렇다면 각 문장을 개별 비교하여 매칭되는 결과중 가장 높은 것이 하나라도 있다면 그것이 바로 일치하는 문자열임
all_comp = {}
for itm in sent_list:
    ratio = SequenceMatcher(None, itm, essay_input).ratio()
    ratio_ = ratio * 100
    all_comp[itm] = ratio_
all_comp
# Out:
# {'RSI (Research Science Institute) at MIT\t5': 1.0347801092267894,
#  "MIT Women's Technology Program (WTP)\t5": 0.34522439585730724,
#  'MITES (Minority Introduction to Engineering and Sciences)\t5': 0.3431512725193023,
#  'LAUNCH at MIT\t5': 0.4633651896901245,
#  'SSP (Summer Science Program)\t5': 0.40369088811995385,
#  'Garcia MRSEC Summer Research Program\t5': 0.4027617951668585,
#  'SIMONS Summer Research Program\t4': 0.2881844380403458,
#  'High School Summer Science Research Program(HSSSRP) at Baylor U\t4': 0.3425635169854411,
#  'CTY Civic  Leadership Institute Program\t4': 0.4599022707674619,
#  'CTY Global Issues in the 21th century\t4': 0.4026459591601955,
#  'Brown Leadership Institute\t3': 0.4039238315060588,
#  'Brown TheaterBridge\t3': 0.17346053772766695,
#  'Brown Intensive English Program (IEP)\t3': 0.5176876617773942,
#  'Brown Environmental Leadership Lab (BELL)\t3': 0.5745475438092502,
#  'CTD (Northwestern)\t3': 0.4048582995951417,
#  'NASA Women in STEM Program\t5': 0.4616272360069244,
#  'NASA Goddard Space Flight Center Internship\t5': 0.6316393913293138,
#  'NASA National Space Club Scholars Program\t5': 1.0341855788566505,
#  'NASA INSPIRE Program\t5': 0.46242774566473993,
#  'TASP (Telluride Association Summer Program)\t5': 1.4355440712029859,
#  'TASS (Telluride Association Sophomore Seminar)\t5': 0.6884681583476765,
#  'The ROSS Mathematics Program\t5': 0.8650519031141869,
#  'PROMYS (Program in Mathematics for Young Scientists)\t5': 0.1718213058419244,
#  'MathWorks Honors Summer Math Camp (HSMC)\t4': 0.40229885057471265,
#  'MOSP (Mathematics Olympiad Summer Program)\t5': 0.34462952326249285,
#  "Governor's School of New Jersey\t3": 0.5185825410544511,
#  'HSHSP (Michigan State University  High school Honors Sciences Program)\t4': 0.4558404558404558,
#  'The Physics of Atomic Nuclei Program at NSCL (National Superconducting Cyclotron Laboratory)\t5': 1.245753114382786,
#  'Stanford Institute of Medicine Summer Research\t4': 0.8032128514056224,
#  'SUMaC (Stanford U Mathematics Camp)\t5': 0.28776978417266186,
#  'HCSSiM (Hampshire College Summer Studies in Math)\t5': 0.17196904557179707,
#  'Summer Internship Program in Neurological Science National Institute of Health (NIH)\t5': 1.1350737797956867,
#  'SIP (Summer Internship Program in Biomedical Research)\t3': 0.6296508299942759,
#  'Link Summer Science Explorations at Kopernik Observatory\t3': 0.4576659038901602,
#  'Barnard College Saturday Science Seminars (S-Cubed)\t3': 0.6301919220853625,
#  'NYU Tisch School of the Arts High School Program\t4': 0.5160550458715597,
#  'NYU Summer at Steinhardt School\t3': 0.40334197637568425,
#  'New Jersey Scholars Program\t3': 0.7499278915488895,
#  'LEAD Business (Leadership Education and Development)\t3': 0.5154639175257731,
#  'LEAD Engineering (Leadership Education and Development)\t3': 0.34334763948497854,
#  'LEAD Computer Science (Leadership Education and Development)\t3': 0.5714285714285714,
#  'Bronfman Youth Fellowship in Israel\t3': 0.34532374100719426,
#  'Jackson Laboratory Summer Student Program\t3': 0.3447285262855501,
#  'Davidson Institute Young Scholars Stars Summer\t3': 0.45897877223178424,
#  'Business Leadership Program\t3': 0.7499278915488895,
#  'Summer at Walnut Hill\t4': 0.2889338341519792,
#  'CMU SAMS (The Summer Academy for Math + Science)\t3': 0.7454128440366973,
#  'Architecture Pre-College\t3': 0.4618937644341801,
#  'Carnegie Mellon Drama Pre-College Program\t3': 0.2872737719046251,
#  'Carnegie Mellon Art & Design Pre-College\t3': 0.40229885057471265,
#  'Carnegie Mellon Music Pre-College\t3': 0.4031097034264325,
#  'Carnegie Mellon National High School Game Academy\t3': 0.34393809114359414,
#  'Kenyon College The Young Writers Workshop\t3': 0.3447285262855501,
#  'UPenn SAAST (Summer Academy in Applied Science and Technology)\t3': 0.5139920045688178,
#  'U Penn VETS\t3': 0.28977108084613157,
#  'U Penn Wharton Sports Business Academy\t4': 0.5750431282346177,
#  'U Penn LBW (Leadership in Business)\t5': 0.46043165467625896,
#  'U Penn-Nursing Summer Institute\t3': 0.4609622587150677,
#  'U Penn M&TSI Management & Technology Summer Institute\t5': 0.572573718866304,
#  'U Penn Art & Architecture Summer Program\t4': 0.40229885057471265,
#  'U Penn TREES Teen Research and Education in Environmental Science\t3': 0.5135520684736091,
#  'U Penn Biomedical Research Academy\t4': 0.5181347150259068,
#  'U Penn Chemistry Research Academy\t3': 0.4031097034264325,
#  'U Penn Experimental Physics Research Academy\t3': 0.7462686567164178,
#  'U Penn Social Justice Research Academy\t4': 0.5750431282346177,
#  'U Penn Art in the City Academy\t3': 0.4034582132564841,
#  'U Penn Startalk Urdo, Hindi, and Chinese Academy\t3': 0.9174311926605505,
#  'U Penn Law Summer Academy\t3': 0.5772005772005772,
#  'U Penn Summer BOOT UP Camp\t3': 0.634737449509521,
#  'Cornell U Research Apprenticeship in Biological Sciences (RABS)\t5': 1.0847844704538967,
#  'Harvard Debate Council Summer Programs\t4': 0.5175388154111558,
#  'SSEP (Summer Science & Engineering Program) at Smith College\t3': 0.2285714285714286,
#  'Yale Young Global Scholars\t4': 0.5770340450086555,
#  'Yale English for High School Students\t3': 0.2876042565429969,
#  'Summer Journalism Program Princeton University\t4': 0.8605851979345954,
#  'Stanford Summer Humanities Institute\t4': 0.805523590333717,
#  'Northwestern U Medill Cherub Journalism Program\t5': 0.8603383997705765,
#  '(AMSP) AwesomeMath Summer Program\t3': 0.4031097034264325,
#  'Canada/USA Math Camp\t4': 0.40462427745664736,
#  'iD Tech Summer Computer Camp Programs\t3': 0.6902502157031924,
#  'UC San Diego Academic Connections Research Scholars\t3': 0.6301919220853625,
#  'JSA Junior Statesmen of America Summer School\t4': 0.3443328550932568,
#  'VAMPY Summer Program for Verbally and Pathematically Precocious Youths\t3': 0.2279202279202279,
#  'Startalk Chinese at Brigham Young U\t3': 0.28776978417266186,
#  'Startalk Arabic Brigham Young U\t3': 0.4609622587150677,
#  'Startalk ChineseU of Mississippi\t3': 0.3456221198156682,
#  'Concordia Summer Villages\t3': 0.6349206349206349,
#  'The Great Books Summer Program\t3': 1.3256484149855907,
#  'ISSYP (International Summer School for Young Physicists)\t5': 0.4576659038901602,
#  'RISE (Research Internship in Science and Engineering) Boston U\t4': 0.7424328954882925,
#  'Boston U High School Honors\t3': 0.4614940871070089,
#  'Boston U High School Seminars\t3': 0.3459210147016431,
#  'National Scholars Institute (NSI) U of Iowa\t4': 0.9187482055699111,
#  'Secondary Student Training Program (SSTP) at U of Iowa\t4': 0.5724098454493417,
#  'High School BLIPS Berkeley Lab Internships for Precollegiate Students\t3': 0.5129666571672842,
#  'COSMOS California State Summer School for Mathematics and Science\t4': 0.28530670470756064,
#  '(UF-SSTP) Student Science Training Program U of Florida\t3': 0.5722460658082975,
#  'Young Scholars Program UC Davis\t3': 0.864304235090752,
#  'MMSS (Michigan Math and Science Scholars)\t4': 0.4021832806664752,
#  'Dartmouth Debate Workshop\t4': 0.40404040404040403,
#  'Dartmouth Debate Institute\t4': 0.4616272360069244,
#  'The Health Careers Institute at Dartmouth\t3': 0.5170927894283253,
#  'University of Texas El Paso High School Law Camp\t3': 1.261467889908257,
#  'NBA Crump Law Camp\t3': 0.4048582995951417,
#  "(GLW) Girls' Leadership Worldwide, Elenor Roosevelt Center at Val-Kill\t3": 0.5698005698005698,
#  'WashU High School Summer Scholars\t3': 0.28793550244745175,
#  'WashU Architecture Discovery Program\t3': 0.23014959723820483,
#  'WashU Portfolio Plus Program\t3': 0.28835063437139563,
#  'UIUC Discover Architecture Pre-College Program\t3': 0.45897877223178424,
#  'Exeter Foreign Language Summer Programs\t3': 0.3449267030755964,
#  'Phillips Andover MS2 Program ( Math and Science for Minority Students)\t3': 0.4558404558404558,
#  'Choate Rosemary Hall Summer Session for High School Students\t3': 0.5714285714285714,
#  'Hotchkiss School Summer Leadership and Social Change Program\t3': 0.34285714285714286,
#  'Classical Music Summer Program at Curtis Institute\t3': 1.146131805157593,
#  'Summer Internship for High School Students\t3': 0.34462952326249285,
#  'Indiana U High School Journalism Institute\t3': 0.4595060310166571,
#  'National Youth Science Camp\t3': 0.6345543697721373,
#  'RISD Pre-College\t3': 0.4629629629629629,
#  'Columbia Scholastic Press Association (CSPA) Summer Workshop\t3': 0.7428571428571429,
#  'Aspen Music Festival School\t3': 0.3461205653302567,
#  'Boston University Tanglewood Institute(BUTI)\t5': 1.0332950631458095,
#  'Boston University Visual Arts Summer Institute\t3': 0.9179575444635685,
#  'Boston University Summer Theater Institute\t3': 1.321079839172889,
#  'Bowdoin International Music Festival\t3': 0.46029919447640966,
#  'Eastern Music Festival Summer Study\t3': 0.8057553956834532,
#  'Interlochen Summer Arts Camp\t5': 0.40369088811995385,
#  'Greenwood Chamber Music Camp\t3': 0.28835063437139563,
#  'Mathlinks\t3': 0.11597564511452595,
#  'Math Zoom Summer Academy\t3': 0.28868360277136257,
#  'Rutgers Young Scholars Program in Discrete Mathematics\t3': 0.8013737836290785,
#  'Stanford Clinical Anatomy Summer Research Scholars Program\t4': 0.9148084619782733,
#  'Stanford Surgical Anatomy for High School Seniors and Pre-Med students\t4': 0.4558404558404558,
#  'Google Computer Science Summer Institute (CSSI)\t5': 0.9176942930886148,
#  'UCSF Biomedical and Health Sciences Internship for High School Students\t3': 0.6266021076616348,
#  'Iowa Young Writers Studio\t5': 0.3463203463203463,
#  "Sewanee Young Writers' Conference\t4": 0.4031097034264325,
#  'Harvard medical school DCP\t4': 0.3462204270051933,
#  'Tufts University Adventures in Veterinary Medicine Program\t4': 1.5437392795883362,
#  'CNSI NanoScience Lab Program\t3': 0.5190311418685121,
#  'Mathematics Summer Camp at Stony Brook University\t3': 0.6878761822871883,
#  'School of Creative and Performing Arts Summer Camp\t3': 0.6303724928366762,
#  'The School of Cinematic Arts Summer Program at USC\t4': 1.5472779369627507,
#  'BU Summer Investigative Journalism Workshop\t3': 0.9761699684180305,
#  'Johns Hopkins Engineering Innovation\t4': 0.5753739930955121,
#  'Rensselaer Robotics Engineering Academy\t4': 0.4024144869215292,
#  'The Rockefeller University Summer Neuroscience Program\t3': 2.5186033199771036,
#  'U Chicago Research in the Biological Sciences (RIBS)\t4': 1.088201603665521,
#  'High School Field Schools with ArchaeoSpain\t3': 0.22968705139247778,
#  'Center for American Archaeology High School Field School\t3': 0.34324942791762014,
#  'Summer Journalism@NYU\t3': 0.23114706732158338,
#  'U of Iowa Summer Journalism Workshops\t3': 0.805291918320391,
#  'Hankuk University of Foreign Studies International Summer Session in Korean & East Asian Studies\t3': 0.5090497737556561,
#  "Barnard College Young Women's Leadership Institute\t3": 0.4584527220630372,
#  'Notre Dame Pre-College Summer Scholars Program\t3': 0.9179575444635685,
#  'Notre Dame Global Leadership Seminars\t5': 0.8628127696289906,
#  'Emerson College Summer Journalism Institute\t3': 0.8039046798736722,
#  'Columbia Epidemiology Summer Online Course\t3': 0.2871912693854107,
#  'Startalk U of Mississippi\t3': 0.23088023088023088,
#  'Middlebury Monterey Language Academy\t4': 0.34522439585730724,
#  'The Metropolitan Museum of Art Summer Internships for High School Students\t3': 0.910643141718839,
#  'Tufts University European Center Summer Program\t3': 1.7780326928591914,
#  'French Heritage Language Program Summer Camp\t3': 0.4592422502870264,
#  'Emory University Youth Theological Initiative Summer Academy\t3': 1.1428571428571428,
#  'Summer Linguistics Institute for Youth Scholars at Ohio State University\t3': 0.5125284738041003,
#  'National Security Language Initiative for Youth (NSLI-Y)\t3': 0.9153318077803204,
#  'Brandeis University Genesis Summer Program in Social Entrepreneurship\t3': 1.5958962667426617,
#  'Wake Forest School of Medicines Camp Med\t3': 0.3448275862068966,
#  'University of Miami Nursing Pre-Entry Program\t3': 1.205164992826399,
#  'Pharmacy Summer Camp at University of Houston\t3': 1.0329985652797704,
#  'Cleveland Clinic Pharmacy Internship Program\t3': 0.4592422502870264,
#  'The Kansas University School of Pharmacy Summer Camp\t3': 1.145475372279496,
#  'Julliard Summer Dance Intensive\t4': 0.5185825410544511,
#  'American Dance Festival Program at Duke University\t3': 0.6876790830945558,
#  'Mpulse Summer Dance Institute at U Michigan\t3': 0.45937410278495555,
#  'UCLA Summer Dance/Performing Arts Summer Institutes\t3': 0.40103122314523065,
#  'New York City Dance Alliance Summer Intensive\t3': 0.45911047345767575,
#  'School of Visual Arts Summer Pre-College\t3': 0.9770114942528736,
#  'Parsons Pre College Academy\t3': 0.5191808479953851,
#  'The Fashion Institute of Technology’s Pre-college Programs\t3': 0.5145797598627788,
#  'MPulse Summer Performing Arts Institutes\t3': 0.45977011494252873,
#  'Peabody Preparatory Annapolis Campus Music Theory Workshop\t3': 0.5717552887364208,
#  'UC Berkeley embARC Summer Design Academy\t3': 0.40229885057471265,
#  'Hospitality Management Summer Program at U of New Hampshire\t3': 0.40011431837667905,
#  'Les Roches International School of Hotel Management Summer Program\t3': 0.6274957216200799,
#  'Journey for Juniors at Culinary Institute of America\t3': 0.22909507445589922,
#  'Chicago Culinary, Hospitality and Business Camps for High School Students at Kendall College\t3': 0.28312570781426954,
#  'Institute On Neuroscience (ION/Teach) at Emory University\t3': 1.486988847583643,
#  'Introduction to Radar for Student Engineers at MIT Lincoln Laboratory\t3': 0.6269592476489028,
#  'The Institute for Speech and Debate\t3': 0.5179856115107914,
#  'Rosetta Institute Cancer/Neuroscience Summer Camps\t3': 0.3438395415472779,
#  'U Penn Game Design Summer\t3': 0.40404040404040403}

# %%
# 오름차순 정렬
sorted_data = sorted(all_comp.items(), key=lambda x: x[1], reverse=True)
sorted_data
# Out:
# [('The Rockefeller University Summer Neuroscience Program\t3',
#   2.5186033199771036),
#  ('Tufts University European Center Summer Program\t3', 1.7780326928591914),
#  ('Brandeis University Genesis Summer Program in Social Entrepreneurship\t3',
#   1.5958962667426617),
#  ('The School of Cinematic Arts Summer Program at USC\t4', 1.5472779369627507),
#  ('Tufts University Adventures in Veterinary Medicine Program\t4',
#   1.5437392795883362),
#  ('Institute On Neuroscience (ION/Teach) at Emory University\t3',
#   1.486988847583643),
#  ('TASP (Telluride Association Summer Program)\t5', 1.4355440712029859),
#  ('The Great Books Summer Program\t3', 1.3256484149855907),
#  ('Boston University Summer Theater Institute\t3', 1.321079839172889),
#  ('University of Texas El Paso High School Law Camp\t3', 1.261467889908257),
#  ('The Physics of Atomic Nuclei Program at NSCL (National Superconducting Cyclotron Laboratory)\t5',
#   1.245753114382786),
#  ('University of Miami Nursing Pre-Entry Program\t3', 1.205164992826399),
#  ('Classical Music Summer Program at Curtis Institute\t3', 1.146131805157593),
#  ('The Kansas University School of Pharmacy Summer Camp\t3',
#   1.145475372279496),
#  ('Emory University Youth Theological Initiative Summer Academy\t3',
#   1.1428571428571428),
#  ('Summer Internship Program in Neurological Science National Institute of Health (NIH)\t5',
#   1.1350737797956867),
#  ('U Chicago Research in the Biological Sciences (RIBS)\t4',
#   1.088201603665521),
#  ('Cornell U Research Apprenticeship in Biological Sciences (RABS)\t5',
#   1.0847844704538967),
#  ('RSI (Research Science Institute) at MIT\t5', 1.0347801092267894),
#  ('NASA National Space Club Scholars Program\t5', 1.0341855788566505),
#  ('Boston University Tanglewood Institute(BUTI)\t5', 1.0332950631458095),
#  ('Pharmacy Summer Camp at University of Houston\t3', 1.0329985652797704),
#  ('School of Visual Arts Summer Pre-College\t3', 0.9770114942528736),
#  ('BU Summer Investigative Journalism Workshop\t3', 0.9761699684180305),
#  ('National Scholars Institute (NSI) U of Iowa\t4', 0.9187482055699111),
#  ('Boston University Visual Arts Summer Institute\t3', 0.9179575444635685),
#  ('Notre Dame Pre-College Summer Scholars Program\t3', 0.9179575444635685),
#  ('Google Computer Science Summer Institute (CSSI)\t5', 0.9176942930886148),
#  ('U Penn Startalk Urdo, Hindi, and Chinese Academy\t3', 0.9174311926605505),
#  ('National Security Language Initiative for Youth (NSLI-Y)\t3',
#   0.9153318077803204),
#  ('Stanford Clinical Anatomy Summer Research Scholars Program\t4',
#   0.9148084619782733),
#  ('The Metropolitan Museum of Art Summer Internships for High School Students\t3',
#   0.910643141718839),
#  ('The ROSS Mathematics Program\t5', 0.8650519031141869),
#  ('Young Scholars Program UC Davis\t3', 0.864304235090752),
#  ('Notre Dame Global Leadership Seminars\t5', 0.8628127696289906),
#  ('Summer Journalism Program Princeton University\t4', 0.8605851979345954),
#  ('Northwestern U Medill Cherub Journalism Program\t5', 0.8603383997705765),
#  ('Eastern Music Festival Summer Study\t3', 0.8057553956834532),
#  ('Stanford Summer Humanities Institute\t4', 0.805523590333717),
#  ('U of Iowa Summer Journalism Workshops\t3', 0.805291918320391),
#  ('Emerson College Summer Journalism Institute\t3', 0.8039046798736722),
#  ('Stanford Institute of Medicine Summer Research\t4', 0.8032128514056224),
#  ('Rutgers Young Scholars Program in Discrete Mathematics\t3',
#   0.8013737836290785),
#  ('New Jersey Scholars Program\t3', 0.7499278915488895),
#  ('Business Leadership Program\t3', 0.7499278915488895),
#  ('U Penn Experimental Physics Research Academy\t3', 0.7462686567164178),
#  ('CMU SAMS (The Summer Academy for Math + Science)\t3', 0.7454128440366973),
#  ('Columbia Scholastic Press Association (CSPA) Summer Workshop\t3',
#   0.7428571428571429),
#  ('RISE (Research Internship in Science and Engineering) Boston U\t4',
#   0.7424328954882925),
#  ('iD Tech Summer Computer Camp Programs\t3', 0.6902502157031924),
#  ('TASS (Telluride Association Sophomore Seminar)\t5', 0.6884681583476765),
#  ('Mathematics Summer Camp at Stony Brook University\t3', 0.6878761822871883),
#  ('American Dance Festival Program at Duke University\t3', 0.6876790830945558),
#  ('Concordia Summer Villages\t3', 0.6349206349206349),
#  ('U Penn Summer BOOT UP Camp\t3', 0.634737449509521),
#  ('National Youth Science Camp\t3', 0.6345543697721373),
#  ('NASA Goddard Space Flight Center Internship\t5', 0.6316393913293138),
#  ('School of Creative and Performing Arts Summer Camp\t3', 0.6303724928366762),
#  ('Barnard College Saturday Science Seminars (S-Cubed)\t3',
#   0.6301919220853625),
#  ('UC San Diego Academic Connections Research Scholars\t3',
#   0.6301919220853625),
#  ('SIP (Summer Internship Program in Biomedical Research)\t3',
#   0.6296508299942759),
#  ('Les Roches International School of Hotel Management Summer Program\t3',
#   0.6274957216200799),
#  ('Introduction to Radar for Student Engineers at MIT Lincoln Laboratory\t3',
#   0.6269592476489028),
#  ('UCSF Biomedical and Health Sciences Internship for High School Students\t3',
#   0.6266021076616348),
#  ('U Penn Law Summer Academy\t3', 0.5772005772005772),
#  ('Yale Young Global Scholars\t4', 0.5770340450086555),
#  ('Johns Hopkins Engineering Innovation\t4', 0.5753739930955121),
#  ('U Penn Wharton Sports Business Academy\t4', 0.5750431282346177),
#  ('U Penn Social Justice Research Academy\t4', 0.5750431282346177),
#  ('Brown Environmental Leadership Lab (BELL)\t3', 0.5745475438092502),
#  ('U Penn M&TSI Management & Technology Summer Institute\t5',
#   0.572573718866304),
#  ('Secondary Student Training Program (SSTP) at U of Iowa\t4',
#   0.5724098454493417),
#  ('(UF-SSTP) Student Science Training Program U of Florida\t3',
#   0.5722460658082975),
#  ('Peabody Preparatory Annapolis Campus Music Theory Workshop\t3',
#   0.5717552887364208),
#  ('LEAD Computer Science (Leadership Education and Development)\t3',
#   0.5714285714285714),
#  ('Choate Rosemary Hall Summer Session for High School Students\t3',
#   0.5714285714285714),
#  ("(GLW) Girls' Leadership Worldwide, Elenor Roosevelt Center at Val-Kill\t3",
#   0.5698005698005698),
#  ('Parsons Pre College Academy\t3', 0.5191808479953851),
#  ('CNSI NanoScience Lab Program\t3', 0.5190311418685121),
#  ("Governor's School of New Jersey\t3", 0.5185825410544511),
#  ('Julliard Summer Dance Intensive\t4', 0.5185825410544511),
#  ('U Penn Biomedical Research Academy\t4', 0.5181347150259068),
#  ('The Institute for Speech and Debate\t3', 0.5179856115107914),
#  ('Brown Intensive English Program (IEP)\t3', 0.5176876617773942),
#  ('Harvard Debate Council Summer Programs\t4', 0.5175388154111558),
#  ('The Health Careers Institute at Dartmouth\t3', 0.5170927894283253),
#  ('NYU Tisch School of the Arts High School Program\t4', 0.5160550458715597),
#  ('LEAD Business (Leadership Education and Development)\t3',
#   0.5154639175257731),
#  ('The Fashion Institute of Technology’s Pre-college Programs\t3',
#   0.5145797598627788),
#  ('UPenn SAAST (Summer Academy in Applied Science and Technology)\t3',
#   0.5139920045688178),
#  ('U Penn TREES Teen Research and Education in Environmental Science\t3',
#   0.5135520684736091),
#  ('High School BLIPS Berkeley Lab Internships for Precollegiate Students\t3',
#   0.5129666571672842),
#  ('Summer Linguistics Institute for Youth Scholars at Ohio State University\t3',
#   0.5125284738041003),
#  ('Hankuk University of Foreign Studies International Summer Session in Korean & East Asian Studies\t3',
#   0.5090497737556561),
#  ('LAUNCH at MIT\t5', 0.4633651896901245),
#  ('RISD Pre-College\t3', 0.4629629629629629),
#  ('NASA INSPIRE Program\t5', 0.46242774566473993),
#  ('Architecture Pre-College\t3', 0.4618937644341801),
#  ('NASA Women in STEM Program\t5', 0.4616272360069244),
#  ('Dartmouth Debate Institute\t4', 0.4616272360069244),
#  ('Boston U High School Honors\t3', 0.4614940871070089),
#  ('U Penn-Nursing Summer Institute\t3', 0.4609622587150677),
#  ('Startalk Arabic Brigham Young U\t3', 0.4609622587150677),
#  ('U Penn LBW (Leadership in Business)\t5', 0.46043165467625896),
#  ('Bowdoin International Music Festival\t3', 0.46029919447640966),
#  ('CTY Civic  Leadership Institute Program\t4', 0.4599022707674619),
#  ('MPulse Summer Performing Arts Institutes\t3', 0.45977011494252873),
#  ('Indiana U High School Journalism Institute\t3', 0.4595060310166571),
#  ('Mpulse Summer Dance Institute at U Michigan\t3', 0.45937410278495555),
#  ('French Heritage Language Program Summer Camp\t3', 0.4592422502870264),
#  ('Cleveland Clinic Pharmacy Internship Program\t3', 0.4592422502870264),
#  ('New York City Dance Alliance Summer Intensive\t3', 0.45911047345767575),
#  ('Davidson Institute Young Scholars Stars Summer\t3', 0.45897877223178424),
#  ('UIUC Discover Architecture Pre-College Program\t3', 0.45897877223178424),
#  ("Barnard College Young Women's Leadership Institute\t3", 0.4584527220630372),
#  ('Link Summer Science Explorations at Kopernik Observatory\t3',
#   0.4576659038901602),
#  ('ISSYP (International Summer School for Young Physicists)\t5',
#   0.4576659038901602),
#  ('HSHSP (Michigan State University  High school Honors Sciences Program)\t4',
#   0.4558404558404558),
#  ('Phillips Andover MS2 Program ( Math and Science for Minority Students)\t3',
#   0.4558404558404558),
#  ('Stanford Surgical Anatomy for High School Seniors and Pre-Med students\t4',
#   0.4558404558404558),
#  ('CTD (Northwestern)\t3', 0.4048582995951417),
#  ('NBA Crump Law Camp\t3', 0.4048582995951417),
#  ('Canada/USA Math Camp\t4', 0.40462427745664736),
#  ('Dartmouth Debate Workshop\t4', 0.40404040404040403),
#  ('U Penn Game Design Summer\t3', 0.40404040404040403),
#  ('Brown Leadership Institute\t3', 0.4039238315060588),
#  ('SSP (Summer Science Program)\t5', 0.40369088811995385),
#  ('Interlochen Summer Arts Camp\t5', 0.40369088811995385),
#  ('U Penn Art in the City Academy\t3', 0.4034582132564841),
#  ('NYU Summer at Steinhardt School\t3', 0.40334197637568425),
#  ('Carnegie Mellon Music Pre-College\t3', 0.4031097034264325),
#  ('U Penn Chemistry Research Academy\t3', 0.4031097034264325),
#  ('(AMSP) AwesomeMath Summer Program\t3', 0.4031097034264325),
#  ("Sewanee Young Writers' Conference\t4", 0.4031097034264325),
#  ('Garcia MRSEC Summer Research Program\t5', 0.4027617951668585),
#  ('CTY Global Issues in the 21th century\t4', 0.4026459591601955),
#  ('Rensselaer Robotics Engineering Academy\t4', 0.4024144869215292),
#  ('MathWorks Honors Summer Math Camp (HSMC)\t4', 0.40229885057471265),
#  ('Carnegie Mellon Art & Design Pre-College\t3', 0.40229885057471265),
#  ('U Penn Art & Architecture Summer Program\t4', 0.40229885057471265),
#  ('UC Berkeley embARC Summer Design Academy\t3', 0.40229885057471265),
#  ('MMSS (Michigan Math and Science Scholars)\t4', 0.4021832806664752),
#  ('UCLA Summer Dance/Performing Arts Summer Institutes\t3',
#   0.40103122314523065),
#  ('Hospitality Management Summer Program at U of New Hampshire\t3',
#   0.40011431837667905),
#  ('Iowa Young Writers Studio\t5', 0.3463203463203463),
#  ('Harvard medical school DCP\t4', 0.3462204270051933),
#  ('Aspen Music Festival School\t3', 0.3461205653302567),
#  ('Boston U High School Seminars\t3', 0.3459210147016431),
#  ('Startalk ChineseU of Mississippi\t3', 0.3456221198156682),
#  ('Bronfman Youth Fellowship in Israel\t3', 0.34532374100719426),
#  ("MIT Women's Technology Program (WTP)\t5", 0.34522439585730724),
#  ('Middlebury Monterey Language Academy\t4', 0.34522439585730724),
#  ('Exeter Foreign Language Summer Programs\t3', 0.3449267030755964),
#  ('Wake Forest School of Medicines Camp Med\t3', 0.3448275862068966),
#  ('Jackson Laboratory Summer Student Program\t3', 0.3447285262855501),
#  ('Kenyon College The Young Writers Workshop\t3', 0.3447285262855501),
#  ('MOSP (Mathematics Olympiad Summer Program)\t5', 0.34462952326249285),
#  ('Summer Internship for High School Students\t3', 0.34462952326249285),
#  ('JSA Junior Statesmen of America Summer School\t4', 0.3443328550932568),
#  ('Carnegie Mellon National High School Game Academy\t3', 0.34393809114359414),
#  ('Rosetta Institute Cancer/Neuroscience Summer Camps\t3', 0.3438395415472779),
#  ('LEAD Engineering (Leadership Education and Development)\t3',
#   0.34334763948497854),
#  ('Center for American Archaeology High School Field School\t3',
#   0.34324942791762014),
#  ('MITES (Minority Introduction to Engineering and Sciences)\t5',
#   0.3431512725193023),
#  ('Hotchkiss School Summer Leadership and Social Change Program\t3',
#   0.34285714285714286),
#  ('High School Summer Science Research Program(HSSSRP) at Baylor U\t4',
#   0.3425635169854411),
#  ('U Penn VETS\t3', 0.28977108084613157),
#  ('Summer at Walnut Hill\t4', 0.2889338341519792),
#  ('Math Zoom Summer Academy\t3', 0.28868360277136257),
#  ('WashU Portfolio Plus Program\t3', 0.28835063437139563),
#  ('Greenwood Chamber Music Camp\t3', 0.28835063437139563),
#  ('SIMONS Summer Research Program\t4', 0.2881844380403458),
#  ('WashU High School Summer Scholars\t3', 0.28793550244745175),
#  ('SUMaC (Stanford U Mathematics Camp)\t5', 0.28776978417266186),
#  ('Startalk Chinese at Brigham Young U\t3', 0.28776978417266186),
#  ('Yale English for High School Students\t3', 0.2876042565429969),
#  ('Carnegie Mellon Drama Pre-College Program\t3', 0.2872737719046251),
#  ('Columbia Epidemiology Summer Online Course\t3', 0.2871912693854107),
#  ('COSMOS California State Summer School for Mathematics and Science\t4',
#   0.28530670470756064),
#  ('Chicago Culinary, Hospitality and Business Camps for High School Students at Kendall College\t3',
#   0.28312570781426954),
#  ('Summer Journalism@NYU\t3', 0.23114706732158338),
#  ('Startalk U of Mississippi\t3', 0.23088023088023088),
#  ('WashU Architecture Discovery Program\t3', 0.23014959723820483),
#  ('High School Field Schools with ArchaeoSpain\t3', 0.22968705139247778),
#  ('Journey for Juniors at Culinary Institute of America\t3',
#   0.22909507445589922),
#  ('SSEP (Summer Science & Engineering Program) at Smith College\t3',
#   0.2285714285714286),
#  ('VAMPY Summer Program for Verbally and Pathematically Precocious Youths\t3',
#   0.2279202279202279),
#  ('Brown TheaterBridge\t3', 0.17346053772766695),
#  ('HCSSiM (Hampshire College Summer Studies in Math)\t5', 0.17196904557179707),
#  ('PROMYS (Program in Mathematics for Young Scientists)\t5',
#   0.1718213058419244),
#  ('Mathlinks\t3', 0.11597564511452595)]

# %%
# 가장 큰 값 찾기
dic_max = max(all_comp.values())
for key, value in all_comp.items():
    if value  == dic_max:
        get_key = key
        
get_key
# Out:
# 'The Rockefeller University Summer Neuroscience Program\t3'

# %%
for key, value in all_comp.items():
    if max(all_comp.values()) > 2.2: # 2.2 이상의 결과값 중에서
        if value == max(all_comp.values()): # 결과 중 가장 큰 값이 일치한다면
            detected_summer_activity = key[:-2]
            result = key[-1:]
            break
    else:
        detected_summer_activity = "Not found"
        # 일치하지 않기 때문에 점수가 없음
        result = 0

# %%
detected_summer_activity
# Out:
# 'The Rockefeller University Summer Neuroscience Program'

# %%
result
# Out:
# '3'
