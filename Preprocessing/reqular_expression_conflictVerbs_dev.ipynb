# %% [markdown]
# ## 수집한 단어를 정규식을 활용하여 리스트로 변환 _ coonflictVerbs

# %%
import re

# %%
#Academic Verbs
academicVerbs = """abhor
abhorrence
abhorrent
abominable
abominate
abomination
abrasion
accost
accuse
acrimoniousness
acrimony
adversary
adverse
afflict
affray
affront
aggravate
aggravating
agitate 
ail
air rage
altercate
altercation
angered
angering
angriness
animosity
annihilate
annoyance
annoy
annoying
antagonism
antagonist
antagonistic
antagonize
antipathy
antipathy
apoplectic
appalling
archenemy
archfoe
argle-bargle
argue
argufy
argument
argy-bargy
assailant
assassinate
at odds with
attack
attacker
aversion
awful
bad
baffle
ballistic
bane
bang
bash
battle
battle royal
beastly
beating
belligerence
bicker
biff
bile
bilious
biliousness
biting
bitter
bitterness
blame
blow
blow up
blows
blowup
bludgeon
bonk
boo-boo
bop
bother 
bothersome
brabble
brattish
bratty
brawl
brazen
broil
bruise
bump
burdensome
burn
burst
cacophony
carking
catfight
cattiness
chafe
chafing
challenge
charge
cheesed off
choler
choleric
civil war
clash
clashing
clobber
clout
cold war
collide
collision
combat
combatant
competition
competitor
complaint
concern 
concussion
conflagration
conflict
confliction
confront
confrontation
contempt
contend
contention
contentiousness
contest
contestant
contestation
contrariant
contrariness
contrary
contrast
contretemps
controversy
controvert
contusion
counter
counter
crack
crankiness
crappy
crime
criminal
criminate
crippling
croak
cross fire
cruddy
crude
crummy
crump
crush
curse
cut
dander
dare
dart
daunt 
debate
deface
defame
defeat
defy
delirium
demoralize 
deplore
deprecate
deprecation
depress
despise
despite
despitefulness
destroy
detest
detestation
detonate
differ
difference
difficult
difficulty
disability
disable
disablement
disaccord
disagree
disagreeable
disagreement
disapprobation
disapproval
disapprove
discharge
discomfort 
discomforting
discompose 
disconsonant
discord
discordance
discordancy
discordant
discountenance
discountenance
discourage 
discrepant
disdain
disesteem
disfavor
disfigurement
disgust
disgusting
disharmonize
disharmony
dishearten 
dismay 
dismay 
dispatch
dispirit 
displeasing
displeasure
disputation
disputatiousness
dispute
disquiet 
disquieting
dissatisfaction
dissension
dissent
disservice
dissidence
dissonance
dissonance
dissonance
dissonant
distaste
distasteful
distractive
distress 
distressing
disturb
disturb 
disturbing
disunion
disunity
divarication
divide
dogfight
donnybrook
dreadful
dudgeon
duel
dustup
embitterment
empoisonment
emulation
encounter
endure
enemy
engage
engagement
enmity
enraged
enraging
envy
exasperating
exasperation
execrate
execration
execute
execution
exercise 
face
face-off
fall out
falling-out
feud
fight
fight
fight against
fighting
fissure
fistfight
fisticuffs
flare-up
foe
foul
fracas
fracas
fray
freak
friction
frustrating
fuming
furious
furor
fury
fuss
gall
galling
gash
ghastly
go off
god-awful
grapple
grating
grievance
gross
grudge
hammer out
handgrips
harsh
hassle
hate
hateful
hatefulness
hatred
heat
hellish
hideous
hinder
holy war
horn-mad
horrendous
horrible
horrid
horror
hostile
hostilities
hostility
hot war
hot-headedness
huff
icky
ill will
ill-wisher
imbroglio
impairment
impeach
importunate
importune
incensed
incompatibility
incompatible
incongruence
incongruent
incongruity
incongruous
incongruousness
inconsistence
inconsistency
inconsistent
inconsonance
inconsonant
inconveniencing
incriminate
indict
indignant
indignation
indignity
indignity
inequity
infighting
inflamed
inflict
infuriate
infuriated
infuriating
inharmoniousness
inharmony
injustice
insult
interfere
invade
invader
invidious
invidiousness
irascibility
irascibleness
irate
irateness
ire
ireful
irksome
irritability
irritating
irritation
jangle
jangling
jar
jarring
jaundice
jealous
jealousy
joust
kickup
kill
killing
knock down
knock off
laceration
lawsuit
lesion
limited war
livid
lividity
lividness
loathe
loathing
loathsome
logomachy
lousy
mad
maddening
madness
malevolence
malice
malicious
maliciousness
malignancy
malignant
malignity
match
mayhem
meanness
melee
miff
mischievous
miserable
mismatch
misunderstanding
mix-up
moody
murder
mutilation
nasty
nausea
nauseating
nauseous
nemesis
nettlesome
nettling
noisome
nonconcur
nonconcurrence
object
objection
obnoxious
obscene
odious
odium
offense
offensive
oppose
opposed
opposing
oppress
oppression
orneriness
outbrave
outburst
outface
outrage
outraged
painful
paradoxical
peev
peeving
perturb
pesky
pestiferous
pestilent
pestilential
pesty
pique
plaguey
police action
pound
protest
protestation
pugnaciousness
pugnacity
punch
punch-out
punch-up
put-down
quarrel
quarrelsomeness
quell
querulousness
quibble
rabid
rage
rancor
rankled
rankling
rebarbative
repel
repellent
repress
repugnance
repugnant
repulsion
repulsive
resentment
resist
revolting
revulsion
revulsive
riled
riley
riling
rival
rivalry
road rage
roiled
romp
rotten
rough-and-tumble
ruckus
ruction
ruffle
run-in
run-in
rupture
scald
scandalous
scar
scathe
schism
scorn
scrap
scrape
scratch
scrimmage
scrum
scuffle
seamy
sear
set-to
shatter
shirty
shock
shocking
shoot
sick
sickening
skirmish
slam
slap
slaughter
slay
slug
slugfest
smack
smash
smite
sock
sore
sour
spat
spite
spitefulness
splinter
squabble
square off
squash
squelch
stand against
stand up to
steam up
strain
stressful
strife
struggle
sucky
sue
suffer
supress
swat
tangle
teed off
temper
terminate
thorny
thump
thwack
tick off
ticked
tiff
tolerate
torment 
torture
trouble
troublesome
troubling
tug-of-war
tussle
ugly
uncongenial
undergo
undo
uneasy
unfair
unfairness
unfavorable
unhinge 
unjustness
unlovely
unmixable
unnerve
unpalatable
unpleasing
unsavory
unsettle 
unwelcome
upset 
upsetting
vendetta
vengefulness
venom
veto
vexation
vexatious
vexing
vexing
vile
villain
villainous
vindictiveness
virulence
vitriol
wallop
war
warfare
whack
whale
wicked
withstand
world war
worrisome
worry
wound
wrangle
wrath
wrathful
wrathfulness
wretched
wrong
wroth
yucky
zap

"""

# %%
remove = academicVerbs.replace("  "," ") # 변환
remove_ = re.sub(r"\t", " ", remove) # 제거
remove__ = re.sub(r"\n", " ", remove_) # 제거
remove__ = remove__.replace("   ", " ")
remove__ = remove__.replace("  ", " ")
remove__ = remove__.replace(" ", ",")
remove__ = remove__.replace("…/", " ")
remove__ = remove__.replace("…", " ")
remove__ = remove__.replace("/", " ")
remove__ = remove__.replace(" ", ",")
remove__ = remove__.replace(")", ",")
remove__ = remove__.replace("(", ",")
preprossed = remove__.split(",") # 단어를 리스트로 변환
preprossed
# Out:
# ['abhor',
#  'abhorrence',
#  'abhorrent',
#  'abominable',
#  'abominate',
#  'abomination',
#  'abrasion',
#  'accost',
#  'accuse',
#  'acrimoniousness',
#  'acrimony',
#  'adversary',
#  'adverse',
#  'afflict',
#  'affray',
#  'affront',
#  'aggravate',
#  'aggravating',
#  'agitate\xa0',
#  'ail',
#  'air',
#  'rage',
#  'altercate',
#  'altercation',
#  'angered',
#  'angering',
#  'angriness',
#  'animosity',
#  'annihilate',
#  'annoyance',
#  'annoy',
#  'annoying',
#  'antagonism',
#  'antagonist',
#  'antagonistic',
#  'antagonize',
#  'antipathy',
#  'antipathy',
#  'apoplectic',
#  'appalling',
#  'archenemy',
#  'archfoe',
#  'argle-bargle',
#  'argue',
#  'argufy',
#  'argument',
#  'argy-bargy',
#  'assailant',
#  'assassinate',
#  'at',
#  'odds',
#  'with',
#  'attack',
#  'attacker',
#  'aversion',
#  'awful',
#  'bad',
#  'baffle',
#  'ballistic',
#  'bane',
#  'bang',
#  'bash',
#  'battle',
#  'battle',
#  'royal',
#  'beastly',
#  'beating',
#  'belligerence',
#  'bicker',
#  'biff',
#  'bile',
#  'bilious',
#  'biliousness',
#  'biting',
#  'bitter',
#  'bitterness',
#  'blame',
#  'blow',
#  'blow',
#  'up',
#  'blows',
#  'blowup',
#  'bludgeon',
#  'bonk',
#  'boo-boo',
#  'bop',
#  'bother\xa0',
#  'bothersome',
#  'brabble',
#  'brattish',
#  'bratty',
#  'brawl',
#  'brazen',
#  'broil',
#  'bruise',
#  'bump',
#  'burdensome',
#  'burn',
#  'burst',
#  'cacophony',
#  'carking',
#  'catfight',
#  'cattiness',
#  'chafe',
#  'chafing',
#  'challenge',
#  'charge',
#  'cheesed',
#  'off',
#  'choler',
#  'choleric',
#  'civil',
#  'war',
#  'clash',
#  'clashing',
#  'clobber',
#  'clout',
#  'cold',
#  'war',
#  'collide',
#  'collision',
#  'combat',
#  'combatant',
#  'competition',
#  'competitor',
#  'complaint',
#  'concern\xa0',
#  'concussion',
#  'conflagration',
#  'conflict',
#  'confliction',
#  'confront',
#  'confrontation',
#  'contempt',
#  'contend',
#  'contention',
#  'contentiousness',
#  'contest',
#  'contestant',
#  'contestation',
#  'contrariant',
#  'contrariness',
#  'contrary',
#  'contrast',
#  'contretemps',
#  'controversy',
#  'controvert',
#  'contusion',
#  'counter',
#  'counter',
#  'crack',
#  'crankiness',
#  'crappy',
#  'crime',
#  'criminal',
#  'criminate',
#  'crippling',
#  'croak',
#  'cross',
#  'fire',
#  'cruddy',
#  'crude',
#  'crummy',
#  'crump',
#  'crush',
#  'curse',
#  'cut',
#  'dander',
#  'dare',
#  'dart',
#  'daunt\xa0',
#  'debate',
#  'deface',
#  'defame',
#  'defeat',
#  'defy',
#  'delirium',
#  'demoralize\xa0',
#  'deplore',
#  'deprecate',
#  'deprecation',
#  'depress',
#  'despise',
#  'despite',
#  'despitefulness',
#  'destroy',
#  'detest',
#  'detestation',
#  'detonate',
#  'differ',
#  'difference',
#  'difficult',
#  'difficulty',
#  'disability',
#  'disable',
#  'disablement',
#  'disaccord',
#  'disagree',
#  'disagreeable',
#  'disagreement',
#  'disapprobation',
#  'disapproval',
#  'disapprove',
#  'discharge',
#  'discomfort\xa0',
#  'discomforting',
#  'discompose\xa0',
#  'disconsonant',
#  'discord',
#  'discordance',
#  'discordancy',
#  'discordant',
#  'discountenance',
#  'discountenance',
#  'discourage\xa0',
#  'discrepant',
#  'disdain',
#  'disesteem',
#  'disfavor',
#  'disfigurement',
#  'disgust',
#  'disgusting',
#  'disharmonize',
#  'disharmony',
#  'dishearten\xa0',
#  'dismay\xa0',
#  'dismay\xa0',
#  'dispatch',
#  'dispirit\xa0',
#  'displeasing',
#  'displeasure',
#  'disputation',
#  'disputatiousness',
#  'dispute',
#  'disquiet\xa0',
#  'disquieting',
#  'dissatisfaction',
#  'dissension',
#  'dissent',
#  'disservice',
#  'dissidence',
#  'dissonance',
#  'dissonance',
#  'dissonance',
#  'dissonant',
#  'distaste',
#  'distasteful',
#  'distractive',
#  'distress\xa0',
#  'distressing',
#  'disturb',
#  'disturb\xa0',
#  'disturbing',
#  'disunion',
#  'disunity',
#  'divarication',
#  'divide',
#  'dogfight',
#  'donnybrook',
#  'dreadful',
#  'dudgeon',
#  'duel',
#  'dustup',
#  'embitterment',
#  'empoisonment',
#  'emulation',
#  'encounter',
#  'endure',
#  'enemy',
#  'engage',
#  'engagement',
#  'enmity',
#  'enraged',
#  'enraging',
#  'envy',
#  'exasperating',
#  'exasperation',
#  'execrate',
#  'execration',
#  'execute',
#  'execution',
#  'exercise\xa0',
#  'face',
#  'face-off',
#  'fall',
#  'out',
#  'falling-out',
#  'feud',
#  'fight',
#  'fight',
#  'fight',
#  'against',
#  'fighting',
#  'fissure',
#  'fistfight',
#  'fisticuffs',
#  'flare-up',
#  'foe',
#  'foul',
#  'fracas',
#  'fracas',
#  'fray',
#  'freak',
#  'friction',
#  'frustrating',
#  'fuming',
#  'furious',
#  'furor',
#  'fury',
#  'fuss',
#  'gall',
#  'galling',
#  'gash',
#  'ghastly',
#  'go',
#  'off',
#  'god-awful',
#  'grapple',
#  'grating',
#  'grievance',
#  'gross',
#  'grudge',
#  'hammer',
#  'out',
#  'handgrips',
#  'harsh',
#  'hassle',
#  'hate',
#  'hateful',
#  'hatefulness',
#  'hatred',
#  'heat',
#  'hellish',
#  'hideous',
#  'hinder',
#  'holy',
#  'war',
#  'horn-mad',
#  'horrendous',
#  'horrible',
#  'horrid',
#  'horror',
#  'hostile',
#  'hostilities',
#  'hostility',
#  'hot',
#  'war',
#  'hot-headedness',
#  'huff',
#  'icky',
#  'ill',
#  'will',
#  'ill-wisher',
#  'imbroglio',
#  'impairment',
#  'impeach',
#  'importunate',
#  'importune',
#  'incensed',
#  'incompatibility',
#  'incompatible',
#  'incongruence',
#  'incongruent',
#  'incongruity',
#  'incongruous',
#  'incongruousness',
#  'inconsistence',
#  'inconsistency',
#  'inconsistent',
#  'inconsonance',
#  'inconsonant',
#  'inconveniencing',
#  'incriminate',
#  'indict',
#  'indignant',
#  'indignation',
#  'indignity',
#  'indignity',
#  'inequity',
#  'infighting',
#  'inflamed',
#  'inflict',
#  'infuriate',
#  'infuriated',
#  'infuriating',
#  'inharmoniousness',
#  'inharmony',
#  'injustice',
#  'insult',
#  'interfere',
#  'invade',
#  'invader',
#  'invidious',
#  'invidiousness',
#  'irascibility',
#  'irascibleness',
#  'irate',
#  'irateness',
#  'ire',
#  'ireful',
#  'irksome',
#  'irritability',
#  'irritating',
#  'irritation',
#  'jangle',
#  'jangling',
#  'jar',
#  'jarring',
#  'jaundice',
#  'jealous',
#  'jealousy',
#  'joust',
#  'kickup',
#  'kill',
#  'killing',
#  'knock',
#  'down',
#  'knock',
#  'off',
#  'laceration',
#  'lawsuit',
#  'lesion',
#  'limited',
#  'war',
#  'livid',
#  'lividity',
#  'lividness',
#  'loathe',
#  'loathing',
#  'loathsome',
#  'logomachy',
#  'lousy',
#  'mad',
#  'maddening',
#  'madness',
#  'malevolence',
#  'malice',
#  'malicious',
#  'maliciousness',
#  'malignancy',
#  'malignant',
#  'malignity',
#  'match',
#  'mayhem',
#  'meanness',
#  'melee',
#  'miff',
#  'mischievous',
#  'miserable',
#  'mismatch',
#  'misunderstanding',
#  'mix-up',
#  'moody',
#  'murder',
#  'mutilation',
#  'nasty',
#  'nausea',
#  'nauseating',
#  'nauseous',
#  'nemesis',
#  'nettlesome',
#  'nettling',
#  'noisome',
#  'nonconcur',
#  'nonconcurrence',
#  'object',
#  'objection',
#  'obnoxious',
#  'obscene',
#  'odious',
#  'odium',
#  'offense',
#  'offensive',
#  'oppose',
#  'opposed',
#  'opposing',
#  'oppress',
#  'oppression',
#  'orneriness',
#  'outbrave',
#  'outburst',
#  'outface',
#  'outrage',
#  'outraged',
#  'painful',
#  'paradoxical',
#  'peev',
#  'peeving',
#  'perturb',
#  'pesky',
#  'pestiferous',
#  'pestilent',
#  'pestilential',
#  'pesty',
#  'pique',
#  'plaguey',
#  'police',
#  'action',
#  'pound',
#  'protest',
#  'protestation',
#  'pugnaciousness',
#  'pugnacity',
#  'punch',
#  'punch-out',
#  'punch-up',
#  'put-down',
#  'quarrel',
#  'quarrelsomeness',
#  'quell',
#  'querulousness',
#  'quibble',
#  'rabid',
#  'rage',
#  'rancor',
#  'rankled',
#  'rankling',
#  'rebarbative',
#  'repel',
#  'repellent',
#  'repress',
#  'repugnance',
#  'repugnant',
#  'repulsion',
#  'repulsive',
#  'resentment',
#  'resist',
#  'revolting',
#  'revulsion',
#  'revulsive',
#  'riled',
#  'riley',
#  'riling',
#  'rival',
#  'rivalry',
#  'road',
#  'rage',
#  'roiled',
#  'romp',
#  'rotten',
#  'rough-and-tumble',
#  'ruckus',
#  'ruction',
#  'ruffle',
#  'run-in',
#  'run-in',
#  'rupture',
#  'scald',
#  'scandalous',
#  'scar',
#  'scathe',
#  'schism',
#  'scorn',
#  'scrap',
#  'scrape',
#  'scratch',
#  'scrimmage',
#  'scrum',
#  'scuffle',
#  'seamy',
#  'sear',
#  'set-to',
#  'shatter',
#  'shirty',
#  'shock',
#  'shocking',
#  'shoot',
#  'sick',
#  'sickening',
#  'skirmish',
#  'slam',
#  'slap',
#  'slaughter',
#  'slay',
#  'slug',
#  'slugfest',
#  'smack',
#  'smash',
#  'smite',
#  'sock',
#  'sore',
#  'sour',
#  'spat',
#  'spite',
#  'spitefulness',
#  'splinter',
#  'squabble',
#  'square',
#  'off',
#  'squash',
#  'squelch',
#  'stand',
#  'against',
#  'stand',
#  'up',
#  'to',
#  'steam',
#  'up',
#  'strain',
#  'stressful',
#  'strife',
#  'struggle',
#  'sucky',
#  'sue',
#  'suffer',
#  'supress',
#  'swat',
#  'tangle',
#  'teed',
#  'off',
#  'temper',
#  'terminate',
#  'thorny',
#  'thump',
#  'thwack',
#  'tick',
#  'off',
#  'ticked',
#  'tiff',
#  'tolerate',
#  'torment\xa0',
#  'torture',
#  'trouble',
#  'troublesome',
#  'troubling',
#  'tug-of-war',
#  'tussle',
#  'ugly',
#  'uncongenial',
#  'undergo',
#  'undo',
#  'uneasy',
#  'unfair',
#  'unfairness',
#  'unfavorable',
#  'unhinge\xa0',
#  'unjustness',
#  'unlovely',
#  'unmixable',
#  'unnerve',
#  'unpalatable',
#  'unpleasing',
#  'unsavory',
#  'unsettle\xa0',
#  'unwelcome',
#  'upset\xa0',
#  'upsetting',
#  'vendetta',
#  'vengefulness',
#  'venom',
#  'veto',
#  'vexation',
#  'vexatious',
#  'vexing',
#  'vexing',
#  'vile',
#  'villain',
#  'villainous',
#  'vindictiveness',
#  'virulence',
#  'vitriol',
#  'wallop',
#  'war',
#  'warfare',
#  'whack',
#  'whale',
#  'wicked',
#  'withstand',
#  'world',
#  'war',
#  'worrisome',
#  'worry',
#  'wound',
#  'wrangle',
#  'wrath',
#  'wrathful',
#  'wrathfulness',
#  'wretched',
#  'wrong',
#  'wroth',
#  'yucky',
#  'zap',
#  '']

# %%
# 소문자로 변환
pre_lower_wd = [i.lower() for i in preprossed]
pre_lower_wd
# Out:
# ['abhor',
#  'abhorrence',
#  'abhorrent',
#  'abominable',
#  'abominate',
#  'abomination',
#  'abrasion',
#  'accost',
#  'accuse',
#  'acrimoniousness',
#  'acrimony',
#  'adversary',
#  'adverse',
#  'afflict',
#  'affray',
#  'affront',
#  'aggravate',
#  'aggravating',
#  'agitate\xa0',
#  'ail',
#  'air',
#  'rage',
#  'altercate',
#  'altercation',
#  'angered',
#  'angering',
#  'angriness',
#  'animosity',
#  'annihilate',
#  'annoyance',
#  'annoy',
#  'annoying',
#  'antagonism',
#  'antagonist',
#  'antagonistic',
#  'antagonize',
#  'antipathy',
#  'antipathy',
#  'apoplectic',
#  'appalling',
#  'archenemy',
#  'archfoe',
#  'argle-bargle',
#  'argue',
#  'argufy',
#  'argument',
#  'argy-bargy',
#  'assailant',
#  'assassinate',
#  'at',
#  'odds',
#  'with',
#  'attack',
#  'attacker',
#  'aversion',
#  'awful',
#  'bad',
#  'baffle',
#  'ballistic',
#  'bane',
#  'bang',
#  'bash',
#  'battle',
#  'battle',
#  'royal',
#  'beastly',
#  'beating',
#  'belligerence',
#  'bicker',
#  'biff',
#  'bile',
#  'bilious',
#  'biliousness',
#  'biting',
#  'bitter',
#  'bitterness',
#  'blame',
#  'blow',
#  'blow',
#  'up',
#  'blows',
#  'blowup',
#  'bludgeon',
#  'bonk',
#  'boo-boo',
#  'bop',
#  'bother\xa0',
#  'bothersome',
#  'brabble',
#  'brattish',
#  'bratty',
#  'brawl',
#  'brazen',
#  'broil',
#  'bruise',
#  'bump',
#  'burdensome',
#  'burn',
#  'burst',
#  'cacophony',
#  'carking',
#  'catfight',
#  'cattiness',
#  'chafe',
#  'chafing',
#  'challenge',
#  'charge',
#  'cheesed',
#  'off',
#  'choler',
#  'choleric',
#  'civil',
#  'war',
#  'clash',
#  'clashing',
#  'clobber',
#  'clout',
#  'cold',
#  'war',
#  'collide',
#  'collision',
#  'combat',
#  'combatant',
#  'competition',
#  'competitor',
#  'complaint',
#  'concern\xa0',
#  'concussion',
#  'conflagration',
#  'conflict',
#  'confliction',
#  'confront',
#  'confrontation',
#  'contempt',
#  'contend',
#  'contention',
#  'contentiousness',
#  'contest',
#  'contestant',
#  'contestation',
#  'contrariant',
#  'contrariness',
#  'contrary',
#  'contrast',
#  'contretemps',
#  'controversy',
#  'controvert',
#  'contusion',
#  'counter',
#  'counter',
#  'crack',
#  'crankiness',
#  'crappy',
#  'crime',
#  'criminal',
#  'criminate',
#  'crippling',
#  'croak',
#  'cross',
#  'fire',
#  'cruddy',
#  'crude',
#  'crummy',
#  'crump',
#  'crush',
#  'curse',
#  'cut',
#  'dander',
#  'dare',
#  'dart',
#  'daunt\xa0',
#  'debate',
#  'deface',
#  'defame',
#  'defeat',
#  'defy',
#  'delirium',
#  'demoralize\xa0',
#  'deplore',
#  'deprecate',
#  'deprecation',
#  'depress',
#  'despise',
#  'despite',
#  'despitefulness',
#  'destroy',
#  'detest',
#  'detestation',
#  'detonate',
#  'differ',
#  'difference',
#  'difficult',
#  'difficulty',
#  'disability',
#  'disable',
#  'disablement',
#  'disaccord',
#  'disagree',
#  'disagreeable',
#  'disagreement',
#  'disapprobation',
#  'disapproval',
#  'disapprove',
#  'discharge',
#  'discomfort\xa0',
#  'discomforting',
#  'discompose\xa0',
#  'disconsonant',
#  'discord',
#  'discordance',
#  'discordancy',
#  'discordant',
#  'discountenance',
#  'discountenance',
#  'discourage\xa0',
#  'discrepant',
#  'disdain',
#  'disesteem',
#  'disfavor',
#  'disfigurement',
#  'disgust',
#  'disgusting',
#  'disharmonize',
#  'disharmony',
#  'dishearten\xa0',
#  'dismay\xa0',
#  'dismay\xa0',
#  'dispatch',
#  'dispirit\xa0',
#  'displeasing',
#  'displeasure',
#  'disputation',
#  'disputatiousness',
#  'dispute',
#  'disquiet\xa0',
#  'disquieting',
#  'dissatisfaction',
#  'dissension',
#  'dissent',
#  'disservice',
#  'dissidence',
#  'dissonance',
#  'dissonance',
#  'dissonance',
#  'dissonant',
#  'distaste',
#  'distasteful',
#  'distractive',
#  'distress\xa0',
#  'distressing',
#  'disturb',
#  'disturb\xa0',
#  'disturbing',
#  'disunion',
#  'disunity',
#  'divarication',
#  'divide',
#  'dogfight',
#  'donnybrook',
#  'dreadful',
#  'dudgeon',
#  'duel',
#  'dustup',
#  'embitterment',
#  'empoisonment',
#  'emulation',
#  'encounter',
#  'endure',
#  'enemy',
#  'engage',
#  'engagement',
#  'enmity',
#  'enraged',
#  'enraging',
#  'envy',
#  'exasperating',
#  'exasperation',
#  'execrate',
#  'execration',
#  'execute',
#  'execution',
#  'exercise\xa0',
#  'face',
#  'face-off',
#  'fall',
#  'out',
#  'falling-out',
#  'feud',
#  'fight',
#  'fight',
#  'fight',
#  'against',
#  'fighting',
#  'fissure',
#  'fistfight',
#  'fisticuffs',
#  'flare-up',
#  'foe',
#  'foul',
#  'fracas',
#  'fracas',
#  'fray',
#  'freak',
#  'friction',
#  'frustrating',
#  'fuming',
#  'furious',
#  'furor',
#  'fury',
#  'fuss',
#  'gall',
#  'galling',
#  'gash',
#  'ghastly',
#  'go',
#  'off',
#  'god-awful',
#  'grapple',
#  'grating',
#  'grievance',
#  'gross',
#  'grudge',
#  'hammer',
#  'out',
#  'handgrips',
#  'harsh',
#  'hassle',
#  'hate',
#  'hateful',
#  'hatefulness',
#  'hatred',
#  'heat',
#  'hellish',
#  'hideous',
#  'hinder',
#  'holy',
#  'war',
#  'horn-mad',
#  'horrendous',
#  'horrible',
#  'horrid',
#  'horror',
#  'hostile',
#  'hostilities',
#  'hostility',
#  'hot',
#  'war',
#  'hot-headedness',
#  'huff',
#  'icky',
#  'ill',
#  'will',
#  'ill-wisher',
#  'imbroglio',
#  'impairment',
#  'impeach',
#  'importunate',
#  'importune',
#  'incensed',
#  'incompatibility',
#  'incompatible',
#  'incongruence',
#  'incongruent',
#  'incongruity',
#  'incongruous',
#  'incongruousness',
#  'inconsistence',
#  'inconsistency',
#  'inconsistent',
#  'inconsonance',
#  'inconsonant',
#  'inconveniencing',
#  'incriminate',
#  'indict',
#  'indignant',
#  'indignation',
#  'indignity',
#  'indignity',
#  'inequity',
#  'infighting',
#  'inflamed',
#  'inflict',
#  'infuriate',
#  'infuriated',
#  'infuriating',
#  'inharmoniousness',
#  'inharmony',
#  'injustice',
#  'insult',
#  'interfere',
#  'invade',
#  'invader',
#  'invidious',
#  'invidiousness',
#  'irascibility',
#  'irascibleness',
#  'irate',
#  'irateness',
#  'ire',
#  'ireful',
#  'irksome',
#  'irritability',
#  'irritating',
#  'irritation',
#  'jangle',
#  'jangling',
#  'jar',
#  'jarring',
#  'jaundice',
#  'jealous',
#  'jealousy',
#  'joust',
#  'kickup',
#  'kill',
#  'killing',
#  'knock',
#  'down',
#  'knock',
#  'off',
#  'laceration',
#  'lawsuit',
#  'lesion',
#  'limited',
#  'war',
#  'livid',
#  'lividity',
#  'lividness',
#  'loathe',
#  'loathing',
#  'loathsome',
#  'logomachy',
#  'lousy',
#  'mad',
#  'maddening',
#  'madness',
#  'malevolence',
#  'malice',
#  'malicious',
#  'maliciousness',
#  'malignancy',
#  'malignant',
#  'malignity',
#  'match',
#  'mayhem',
#  'meanness',
#  'melee',
#  'miff',
#  'mischievous',
#  'miserable',
#  'mismatch',
#  'misunderstanding',
#  'mix-up',
#  'moody',
#  'murder',
#  'mutilation',
#  'nasty',
#  'nausea',
#  'nauseating',
#  'nauseous',
#  'nemesis',
#  'nettlesome',
#  'nettling',
#  'noisome',
#  'nonconcur',
#  'nonconcurrence',
#  'object',
#  'objection',
#  'obnoxious',
#  'obscene',
#  'odious',
#  'odium',
#  'offense',
#  'offensive',
#  'oppose',
#  'opposed',
#  'opposing',
#  'oppress',
#  'oppression',
#  'orneriness',
#  'outbrave',
#  'outburst',
#  'outface',
#  'outrage',
#  'outraged',
#  'painful',
#  'paradoxical',
#  'peev',
#  'peeving',
#  'perturb',
#  'pesky',
#  'pestiferous',
#  'pestilent',
#  'pestilential',
#  'pesty',
#  'pique',
#  'plaguey',
#  'police',
#  'action',
#  'pound',
#  'protest',
#  'protestation',
#  'pugnaciousness',
#  'pugnacity',
#  'punch',
#  'punch-out',
#  'punch-up',
#  'put-down',
#  'quarrel',
#  'quarrelsomeness',
#  'quell',
#  'querulousness',
#  'quibble',
#  'rabid',
#  'rage',
#  'rancor',
#  'rankled',
#  'rankling',
#  'rebarbative',
#  'repel',
#  'repellent',
#  'repress',
#  'repugnance',
#  'repugnant',
#  'repulsion',
#  'repulsive',
#  'resentment',
#  'resist',
#  'revolting',
#  'revulsion',
#  'revulsive',
#  'riled',
#  'riley',
#  'riling',
#  'rival',
#  'rivalry',
#  'road',
#  'rage',
#  'roiled',
#  'romp',
#  'rotten',
#  'rough-and-tumble',
#  'ruckus',
#  'ruction',
#  'ruffle',
#  'run-in',
#  'run-in',
#  'rupture',
#  'scald',
#  'scandalous',
#  'scar',
#  'scathe',
#  'schism',
#  'scorn',
#  'scrap',
#  'scrape',
#  'scratch',
#  'scrimmage',
#  'scrum',
#  'scuffle',
#  'seamy',
#  'sear',
#  'set-to',
#  'shatter',
#  'shirty',
#  'shock',
#  'shocking',
#  'shoot',
#  'sick',
#  'sickening',
#  'skirmish',
#  'slam',
#  'slap',
#  'slaughter',
#  'slay',
#  'slug',
#  'slugfest',
#  'smack',
#  'smash',
#  'smite',
#  'sock',
#  'sore',
#  'sour',
#  'spat',
#  'spite',
#  'spitefulness',
#  'splinter',
#  'squabble',
#  'square',
#  'off',
#  'squash',
#  'squelch',
#  'stand',
#  'against',
#  'stand',
#  'up',
#  'to',
#  'steam',
#  'up',
#  'strain',
#  'stressful',
#  'strife',
#  'struggle',
#  'sucky',
#  'sue',
#  'suffer',
#  'supress',
#  'swat',
#  'tangle',
#  'teed',
#  'off',
#  'temper',
#  'terminate',
#  'thorny',
#  'thump',
#  'thwack',
#  'tick',
#  'off',
#  'ticked',
#  'tiff',
#  'tolerate',
#  'torment\xa0',
#  'torture',
#  'trouble',
#  'troublesome',
#  'troubling',
#  'tug-of-war',
#  'tussle',
#  'ugly',
#  'uncongenial',
#  'undergo',
#  'undo',
#  'uneasy',
#  'unfair',
#  'unfairness',
#  'unfavorable',
#  'unhinge\xa0',
#  'unjustness',
#  'unlovely',
#  'unmixable',
#  'unnerve',
#  'unpalatable',
#  'unpleasing',
#  'unsavory',
#  'unsettle\xa0',
#  'unwelcome',
#  'upset\xa0',
#  'upsetting',
#  'vendetta',
#  'vengefulness',
#  'venom',
#  'veto',
#  'vexation',
#  'vexatious',
#  'vexing',
#  'vexing',
#  'vile',
#  'villain',
#  'villainous',
#  'vindictiveness',
#  'virulence',
#  'vitriol',
#  'wallop',
#  'war',
#  'warfare',
#  'whack',
#  'whale',
#  'wicked',
#  'withstand',
#  'world',
#  'war',
#  'worrisome',
#  'worry',
#  'wound',
#  'wrangle',
#  'wrath',
#  'wrathful',
#  'wrathfulness',
#  'wretched',
#  'wrong',
#  'wroth',
#  'yucky',
#  'zap',
#  '']

# %% [markdown]
# # 이것을 단어 원형으로 변환

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# 방법 1 : 표제어추출, 동사는 현재형으로 변환
lemma_list =[]
for i in preprossed:
    lema_re = lemmatizer.lemmatize(i, pos='v') #표제어 추출, 동사는 현재형으로 변환
    lemma_list.append(lema_re)
    
lemma_list
# Out:
# ['abhor',
#  'abhorrence',
#  'abhorrent',
#  'abominable',
#  'abominate',
#  'abomination',
#  'abrasion',
#  'accost',
#  'accuse',
#  'acrimoniousness',
#  'acrimony',
#  'adversary',
#  'adverse',
#  'afflict',
#  'affray',
#  'affront',
#  'aggravate',
#  'aggravate',
#  'agitate\xa0',
#  'ail',
#  'air',
#  'rage',
#  'altercate',
#  'altercation',
#  'anger',
#  'anger',
#  'angriness',
#  'animosity',
#  'annihilate',
#  'annoyance',
#  'annoy',
#  'annoy',
#  'antagonism',
#  'antagonist',
#  'antagonistic',
#  'antagonize',
#  'antipathy',
#  'antipathy',
#  'apoplectic',
#  'appal',
#  'archenemy',
#  'archfoe',
#  'argle-bargle',
#  'argue',
#  'argufy',
#  'argument',
#  'argy-bargy',
#  'assailant',
#  'assassinate',
#  'at',
#  'odds',
#  'with',
#  'attack',
#  'attacker',
#  'aversion',
#  'awful',
#  'bad',
#  'baffle',
#  'ballistic',
#  'bane',
#  'bang',
#  'bash',
#  'battle',
#  'battle',
#  'royal',
#  'beastly',
#  'beat',
#  'belligerence',
#  'bicker',
#  'biff',
#  'bile',
#  'bilious',
#  'biliousness',
#  'bite',
#  'bitter',
#  'bitterness',
#  'blame',
#  'blow',
#  'blow',
#  'up',
#  'blow',
#  'blowup',
#  'bludgeon',
#  'bonk',
#  'boo-boo',
#  'bop',
#  'bother\xa0',
#  'bothersome',
#  'brabble',
#  'brattish',
#  'bratty',
#  'brawl',
#  'brazen',
#  'broil',
#  'bruise',
#  'bump',
#  'burdensome',
#  'burn',
#  'burst',
#  'cacophony',
#  'cark',
#  'catfight',
#  'cattiness',
#  'chafe',
#  'chafe',
#  'challenge',
#  'charge',
#  'cheese',
#  'off',
#  'choler',
#  'choleric',
#  'civil',
#  'war',
#  'clash',
#  'clash',
#  'clobber',
#  'clout',
#  'cold',
#  'war',
#  'collide',
#  'collision',
#  'combat',
#  'combatant',
#  'competition',
#  'competitor',
#  'complaint',
#  'concern\xa0',
#  'concussion',
#  'conflagration',
#  'conflict',
#  'confliction',
#  'confront',
#  'confrontation',
#  'contempt',
#  'contend',
#  'contention',
#  'contentiousness',
#  'contest',
#  'contestant',
#  'contestation',
#  'contrariant',
#  'contrariness',
#  'contrary',
#  'contrast',
#  'contretemps',
#  'controversy',
#  'controvert',
#  'contusion',
#  'counter',
#  'counter',
#  'crack',
#  'crankiness',
#  'crappy',
#  'crime',
#  'criminal',
#  'criminate',
#  'cripple',
#  'croak',
#  'cross',
#  'fire',
#  'cruddy',
#  'crude',
#  'crummy',
#  'crump',
#  'crush',
#  'curse',
#  'cut',
#  'dander',
#  'dare',
#  'dart',
#  'daunt\xa0',
#  'debate',
#  'deface',
#  'defame',
#  'defeat',
#  'defy',
#  'delirium',
#  'demoralize\xa0',
#  'deplore',
#  'deprecate',
#  'deprecation',
#  'depress',
#  'despise',
#  'despite',
#  'despitefulness',
#  'destroy',
#  'detest',
#  'detestation',
#  'detonate',
#  'differ',
#  'difference',
#  'difficult',
#  'difficulty',
#  'disability',
#  'disable',
#  'disablement',
#  'disaccord',
#  'disagree',
#  'disagreeable',
#  'disagreement',
#  'disapprobation',
#  'disapproval',
#  'disapprove',
#  'discharge',
#  'discomfort\xa0',
#  'discomforting',
#  'discompose\xa0',
#  'disconsonant',
#  'discord',
#  'discordance',
#  'discordancy',
#  'discordant',
#  'discountenance',
#  'discountenance',
#  'discourage\xa0',
#  'discrepant',
#  'disdain',
#  'disesteem',
#  'disfavor',
#  'disfigurement',
#  'disgust',
#  'disgust',
#  'disharmonize',
#  'disharmony',
#  'dishearten\xa0',
#  'dismay\xa0',
#  'dismay\xa0',
#  'dispatch',
#  'dispirit\xa0',
#  'displease',
#  'displeasure',
#  'disputation',
#  'disputatiousness',
#  'dispute',
#  'disquiet\xa0',
#  'disquiet',
#  'dissatisfaction',
#  'dissension',
#  'dissent',
#  'disservice',
#  'dissidence',
#  'dissonance',
#  'dissonance',
#  'dissonance',
#  'dissonant',
#  'distaste',
#  'distasteful',
#  'distractive',
#  'distress\xa0',
#  'distress',
#  'disturb',
#  'disturb\xa0',
#  'disturb',
#  'disunion',
#  'disunity',
#  'divarication',
#  'divide',
#  'dogfight',
#  'donnybrook',
#  'dreadful',
#  'dudgeon',
#  'duel',
#  'dustup',
#  'embitterment',
#  'empoisonment',
#  'emulation',
#  'encounter',
#  'endure',
#  'enemy',
#  'engage',
#  'engagement',
#  'enmity',
#  'enrage',
#  'enrage',
#  'envy',
#  'exasperate',
#  'exasperation',
#  'execrate',
#  'execration',
#  'execute',
#  'execution',
#  'exercise\xa0',
#  'face',
#  'face-off',
#  'fall',
#  'out',
#  'falling-out',
#  'feud',
#  'fight',
#  'fight',
#  'fight',
#  'against',
#  'fight',
#  'fissure',
#  'fistfight',
#  'fisticuffs',
#  'flare-up',
#  'foe',
#  'foul',
#  'fracas',
#  'fracas',
#  'fray',
#  'freak',
#  'friction',
#  'frustrate',
#  'fume',
#  'furious',
#  'furor',
#  'fury',
#  'fuss',
#  'gall',
#  'gall',
#  'gash',
#  'ghastly',
#  'go',
#  'off',
#  'god-awful',
#  'grapple',
#  'grate',
#  'grievance',
#  'gross',
#  'grudge',
#  'hammer',
#  'out',
#  'handgrips',
#  'harsh',
#  'hassle',
#  'hate',
#  'hateful',
#  'hatefulness',
#  'hatred',
#  'heat',
#  'hellish',
#  'hideous',
#  'hinder',
#  'holy',
#  'war',
#  'horn-mad',
#  'horrendous',
#  'horrible',
#  'horrid',
#  'horror',
#  'hostile',
#  'hostilities',
#  'hostility',
#  'hot',
#  'war',
#  'hot-headedness',
#  'huff',
#  'icky',
#  'ill',
#  'will',
#  'ill-wisher',
#  'imbroglio',
#  'impairment',
#  'impeach',
#  'importunate',
#  'importune',
#  'incense',
#  'incompatibility',
#  'incompatible',
#  'incongruence',
#  'incongruent',
#  'incongruity',
#  'incongruous',
#  'incongruousness',
#  'inconsistence',
#  'inconsistency',
#  'inconsistent',
#  'inconsonance',
#  'inconsonant',
#  'inconvenience',
#  'incriminate',
#  'indict',
#  'indignant',
#  'indignation',
#  'indignity',
#  'indignity',
#  'inequity',
#  'infighting',
#  'inflame',
#  'inflict',
#  'infuriate',
#  'infuriate',
#  'infuriate',
#  'inharmoniousness',
#  'inharmony',
#  'injustice',
#  'insult',
#  'interfere',
#  'invade',
#  'invader',
#  'invidious',
#  'invidiousness',
#  'irascibility',
#  'irascibleness',
#  'irate',
#  'irateness',
#  'ire',
#  'ireful',
#  'irksome',
#  'irritability',
#  'irritate',
#  'irritation',
#  'jangle',
#  'jangle',
#  'jar',
#  'jar',
#  'jaundice',
#  'jealous',
#  'jealousy',
#  'joust',
#  'kickup',
#  'kill',
#  'kill',
#  'knock',
#  'down',
#  'knock',
#  'off',
#  'laceration',
#  'lawsuit',
#  'lesion',
#  'limit',
#  'war',
#  'livid',
#  'lividity',
#  'lividness',
#  'loathe',
#  'loathe',
#  'loathsome',
#  'logomachy',
#  'lousy',
#  'mad',
#  'madden',
#  'madness',
#  'malevolence',
#  'malice',
#  'malicious',
#  'maliciousness',
#  'malignancy',
#  'malignant',
#  'malignity',
#  'match',
#  'mayhem',
#  'meanness',
#  'melee',
#  'miff',
#  'mischievous',
#  'miserable',
#  'mismatch',
#  'misunderstand',
#  'mix-up',
#  'moody',
#  'murder',
#  'mutilation',
#  'nasty',
#  'nausea',
#  'nauseate',
#  'nauseous',
#  'nemesis',
#  'nettlesome',
#  'nettle',
#  'noisome',
#  'nonconcur',
#  'nonconcurrence',
#  'object',
#  'objection',
#  'obnoxious',
#  'obscene',
#  'odious',
#  'odium',
#  'offense',
#  'offensive',
#  'oppose',
#  'oppose',
#  'oppose',
#  'oppress',
#  'oppression',
#  'orneriness',
#  'outbrave',
#  'outburst',
#  'outface',
#  'outrage',
#  'outrage',
#  'painful',
#  'paradoxical',
#  'peev',
#  'peeve',
#  'perturb',
#  'pesky',
#  'pestiferous',
#  'pestilent',
#  'pestilential',
#  'pesty',
#  'pique',
#  'plaguey',
#  'police',
#  'action',
#  'pound',
#  'protest',
#  'protestation',
#  'pugnaciousness',
#  'pugnacity',
#  'punch',
#  'punch-out',
#  'punch-up',
#  'put-down',
#  'quarrel',
#  'quarrelsomeness',
#  'quell',
#  'querulousness',
#  'quibble',
#  'rabid',
#  'rage',
#  'rancor',
#  'rankle',
#  'rankle',
#  'rebarbative',
#  'repel',
#  'repellent',
#  'repress',
#  'repugnance',
#  'repugnant',
#  'repulsion',
#  'repulsive',
#  'resentment',
#  'resist',
#  'revolt',
#  'revulsion',
#  'revulsive',
#  'rile',
#  'riley',
#  'rile',
#  'rival',
#  'rivalry',
#  'road',
#  'rage',
#  'roil',
#  'romp',
#  'rotten',
#  'rough-and-tumble',
#  'ruckus',
#  'ruction',
#  'ruffle',
#  'run-in',
#  'run-in',
#  'rupture',
#  'scald',
#  'scandalous',
#  'scar',
#  'scathe',
#  'schism',
#  'scorn',
#  'scrap',
#  'scrape',
#  'scratch',
#  'scrimmage',
#  'scrum',
#  'scuffle',
#  'seamy',
#  'sear',
#  'set-to',
#  'shatter',
#  'shirty',
#  'shock',
#  'shock',
#  'shoot',
#  'sick',
#  'sicken',
#  'skirmish',
#  'slam',
#  'slap',
#  'slaughter',
#  'slay',
#  'slug',
#  'slugfest',
#  'smack',
#  'smash',
#  'smite',
#  'sock',
#  'sore',
#  'sour',
#  'spat',
#  'spite',
#  'spitefulness',
#  'splinter',
#  'squabble',
#  'square',
#  'off',
#  'squash',
#  'squelch',
#  'stand',
#  'against',
#  'stand',
#  'up',
#  'to',
#  'steam',
#  'up',
#  'strain',
#  'stressful',
#  'strife',
#  'struggle',
#  'sucky',
#  'sue',
#  'suffer',
#  'supress',
#  'swat',
#  'tangle',
#  'tee',
#  'off',
#  'temper',
#  'terminate',
#  'thorny',
#  'thump',
#  'thwack',
#  'tick',
#  'off',
#  'tick',
#  'tiff',
#  'tolerate',
#  'torment\xa0',
#  'torture',
#  'trouble',
#  'troublesome',
#  'trouble',
#  'tug-of-war',
#  'tussle',
#  'ugly',
#  'uncongenial',
#  'undergo',
#  'undo',
#  'uneasy',
#  'unfair',
#  'unfairness',
#  'unfavorable',
#  'unhinge\xa0',
#  'unjustness',
#  'unlovely',
#  'unmixable',
#  'unnerve',
#  'unpalatable',
#  'unpleasing',
#  'unsavory',
#  'unsettle\xa0',
#  'unwelcome',
#  'upset\xa0',
#  'upset',
#  'vendetta',
#  'vengefulness',
#  'venom',
#  'veto',
#  'vexation',
#  'vexatious',
#  'vex',
#  'vex',
#  'vile',
#  'villain',
#  'villainous',
#  'vindictiveness',
#  'virulence',
#  'vitriol',
#  'wallop',
#  'war',
#  'warfare',
#  'whack',
#  'whale',
#  'wicked',
#  'withstand',
#  'world',
#  'war',
#  'worrisome',
#  'worry',
#  'wind',
#  'wrangle',
#  'wrath',
#  'wrathful',
#  'wrathfulness',
#  'wretched',
#  'wrong',
#  'wroth',
#  'yucky',
#  'zap',
#  '']

# %%
# 방법 2: 표제어 추출
ext_lema = [lemmatizer.lemmatize(w) for w in preprossed]
# 중복값을 제거하고
rm_dupli = set(ext_lema)
# 다시 리스트로 만들고
re_li = list(rm_dupli)
# 빈 값은 제거하고
get_wd =list(filter(None, re_li))
# 소문자로 모두 변환
lower_wd = [i.lower() for i in get_wd]
lower_wd
# Out:
# ['discountenance',
#  'lousy',
#  'scrape',
#  'vengefulness',
#  'bop',
#  'enraging',
#  'deprecate',
#  'obscene',
#  'empoisonment',
#  'angriness',
#  'freak',
#  'livid',
#  'distasteful',
#  'mutilation',
#  'sour',
#  'lawsuit',
#  'abominable',
#  'romp',
#  'smack',
#  'pestilential',
#  'seamy',
#  'opposed',
#  'rebarbative',
#  'confront',
#  'controversy',
#  'jangle',
#  'grievance',
#  'divarication',
#  'fracas',
#  'unhinge\xa0',
#  'miserable',
#  'war',
#  'god-awful',
#  'bang',
#  'malice',
#  'animosity',
#  'charge',
#  'pesky',
#  'contend',
#  'bitter',
#  'nonconcurrence',
#  'wound',
#  'against',
#  'villain',
#  'disfavor',
#  'horror',
#  'villainous',
#  'dreadful',
#  'protest',
#  'indignant',
#  'foe',
#  'aggravate',
#  'argument',
#  'oppose',
#  'invade',
#  'choler',
#  'brawl',
#  'confliction',
#  'conflict',
#  'dissonance',
#  'offense',
#  'burdensome',
#  'irksome',
#  'dissension',
#  'acrimoniousness',
#  'embitterment',
#  'infuriate',
#  'execution',
#  'contretemps',
#  'battle',
#  'fissure',
#  'hostility',
#  'scratch',
#  'tug-of-war',
#  'wrathfulness',
#  'rankling',
#  'horrible',
#  'painful',
#  'rabid',
#  'belligerence',
#  'dissent',
#  'repress',
#  'squelch',
#  'warfare',
#  'ballistic',
#  'cut',
#  'chafe',
#  'crankiness',
#  'antipathy',
#  'tolerate',
#  'burn',
#  'hateful',
#  'disagreeable',
#  'punch-up',
#  'bothersome',
#  'rough-and-tumble',
#  'slugfest',
#  'unpalatable',
#  'slaughter',
#  'afflict',
#  'tick',
#  'contrary',
#  'strife',
#  'importune',
#  'dissidence',
#  'rotten',
#  'with',
#  'disaccord',
#  'bratty',
#  'horn-mad',
#  'infighting',
#  'ruction',
#  'irascibility',
#  'resentment',
#  'abhorrence',
#  'mix-up',
#  'vexatious',
#  'object',
#  'sickening',
#  'adversary',
#  'set-to',
#  'outrage',
#  'infuriating',
#  'abominate',
#  'accost',
#  'worry',
#  'scrum',
#  'contrast',
#  'angering',
#  'wrong',
#  'wicked',
#  'clobber',
#  'undergo',
#  'fuming',
#  'smash',
#  'defeat',
#  'gash',
#  'vile',
#  'huff',
#  'contest',
#  'ill-wisher',
#  'put-down',
#  'incompatible',
#  'encounter',
#  'foul',
#  'objection',
#  'concussion',
#  'challenge',
#  'exercise\xa0',
#  'moody',
#  'daunt\xa0',
#  'jangling',
#  'contempt',
#  'difference',
#  'air',
#  'detonate',
#  'distractive',
#  'brattish',
#  'hellish',
#  'thump',
#  'antagonism',
#  'annihilate',
#  'impairment',
#  'thwack',
#  'joust',
#  'brazen',
#  'unfavorable',
#  'schism',
#  'injustice',
#  'malevolence',
#  'unsavory',
#  'mischievous',
#  'squash',
#  'disapprobation',
#  'crime',
#  'obnoxious',
#  'repugnant',
#  'shoot',
#  'wretched',
#  'malignant',
#  'resist',
#  'annoy',
#  'steam',
#  'knock',
#  'malignancy',
#  'stand',
#  'repulsive',
#  'upset\xa0',
#  'bonk',
#  'hatefulness',
#  'ill',
#  'vendetta',
#  'engage',
#  'archfoe',
#  'bitterness',
#  'donnybrook',
#  'difficult',
#  'execute',
#  'discharge',
#  'imbroglio',
#  'melee',
#  'crummy',
#  'disservice',
#  'fight',
#  'smite',
#  'unjustness',
#  'repulsion',
#  'awful',
#  'clashing',
#  'inconsonance',
#  'gross',
#  'odious',
#  'incongruence',
#  'inconsistency',
#  'contrariness',
#  'oppression',
#  'riling',
#  'whack',
#  'quibble',
#  'inharmoniousness',
#  'fuss',
#  'catfight',
#  'bicker',
#  'confrontation',
#  'deprecation',
#  'horrid',
#  'execration',
#  'irate',
#  'disunity',
#  'adverse',
#  'harsh',
#  'jealousy',
#  'scar',
#  'uneasy',
#  'fighting',
#  'fistfight',
#  'incriminate',
#  'troublesome',
#  'deface',
#  'disquiet\xa0',
#  'ruckus',
#  'bludgeon',
#  'argy-bargy',
#  'inflict',
#  'combatant',
#  'crippling',
#  'antagonize',
#  'bile',
#  'angered',
#  'insult',
#  'dart',
#  'inflamed',
#  'shatter',
#  'nauseating',
#  'bane',
#  'gall',
#  'aggravating',
#  'incongruent',
#  'contestant',
#  'repel',
#  'worrisome',
#  'deplore',
#  'inconveniencing',
#  'slap',
#  'antagonistic',
#  'rival',
#  'rancor',
#  'attacker',
#  'disturb',
#  'incompatibility',
#  'feud',
#  'scathe',
#  'plaguey',
#  'crump',
#  'dare',
#  'hot',
#  'scandalous',
#  'ruffle',
#  'handgrip',
#  'hinder',
#  'jaundice',
#  'exasperating',
#  'affront',
#  'disunion',
#  'enmity',
#  'aversion',
#  'distress\xa0',
#  'agitate\xa0',
#  'fray',
#  'ail',
#  'hassle',
#  'hot-headedness',
#  'difficulty',
#  'police',
#  'importunate',
#  'pugnaciousness',
#  'flare-up',
#  'contusion',
#  'outface',
#  'execrate',
#  'discordance',
#  'roiled',
#  'inconsistent',
#  'go',
#  'endure',
#  'repugnance',
#  'temper',
#  'ugly',
#  'loathsome',
#  'incensed',
#  'wrangle',
#  'rivalry',
#  'disdain',
#  'beating',
#  'crush',
#  'indignation',
#  'ghastly',
#  'nausea',
#  'maliciousness',
#  'indignity',
#  'world',
#  'disagreement',
#  'shocking',
#  'wallop',
#  'swat',
#  'demoralize\xa0',
#  'invidiousness',
#  'trouble',
#  'pugnacity',
#  'blame',
#  'struggle',
#  'argufy',
#  'controvert',
#  'fire',
#  'hostile',
#  'inconsistence',
#  'contentiousness',
#  'dispatch',
#  'square',
#  'laceration',
#  'orneriness',
#  'cross',
#  'malicious',
#  'frustrating',
#  'odium',
#  'competitor',
#  'cold',
#  'supress',
#  'lividness',
#  'cattiness',
#  'discomforting',
#  'misunderstanding',
#  'nemesis',
#  'spite',
#  'disfigurement',
#  'baffle',
#  'thorny',
#  'match',
#  'pique',
#  'sock',
#  'argle-bargle',
#  'jar',
#  'grapple',
#  'outbrave',
#  'disability',
#  'incongruous',
#  'disharmony',
#  'assassinate',
#  'stressful',
#  'squabble',
#  'disapprove',
#  'fisticuffs',
#  'shock',
#  'falling-out',
#  'revolting',
#  'venom',
#  'archenemy',
#  'beastly',
#  'irritation',
#  'combat',
#  'malignity',
#  'duel',
#  'cruddy',
#  'invader',
#  'will',
#  'torture',
#  'quell',
#  'peeving',
#  'zap',
#  'riled',
#  'wrathful',
#  'divide',
#  'splinter',
#  'distressing',
#  'disagree',
#  'virulence',
#  'action',
#  'disputation',
#  'irateness',
#  'grudge',
#  'quarrelsomeness',
#  'scald',
#  'abrasion',
#  'hammer',
#  'unmixable',
#  'horrendous',
#  'torment\xa0',
#  'complaint',
#  'opposing',
#  'skirmish',
#  'destroy',
#  'contention',
#  'disconsonant',
#  'bruise',
#  'riley',
#  'ire',
#  'miff',
#  'unfairness',
#  'clout',
#  'dissonant',
#  'contestation',
#  'paradoxical',
#  'abomination',
#  'unsettle\xa0',
#  'unwelcome',
#  'nonconcur',
#  'engagement',
#  'apoplectic',
#  'inequity',
#  'jealous',
#  'irascibleness',
#  'crappy',
#  'pestilent',
#  'kill',
#  'blow',
#  'lividity',
#  'run-in',
#  'discordant',
#  'disturbing',
#  'indict',
#  'disputatiousness',
#  'scuffle',
#  'crack',
#  'incongruity',
#  'blowup',
#  'disharmonize',
#  'scorn',
#  'accuse',
#  'tiff',
#  'interfere',
#  'grating',
#  'debate',
#  'unlovely',
#  'dudgeon',
#  'carking',
#  'exasperation',
#  'discompose\xa0',
#  'withstand',
#  'depress',
#  'bother\xa0',
#  'disesteem',
#  'mismatch',
#  'collision',
#  'outraged',
#  'nauseous',
#  'up',
#  'rupture',
#  'bash',
#  'despise',
#  'quarrel',
#  'killing',
#  'ireful',
#  'dander',
#  'appalling',
#  'irritability',
#  'broil',
#  'limited',
#  'displeasure',
#  'punch-out',
#  'mayhem',
#  'attack',
#  'altercation',
#  'mad',
#  'despitefulness',
#  'unfair',
#  'unpleasing',
#  'brabble',
#  'biliousness',
#  'logomachy',
#  'furious',
#  'dogfight',
#  'furor',
#  'loathe',
#  'assailant',
#  'despite',
#  'cacophony',
#  'infuriated',
#  'jarring',
#  'altercate',
#  'face-off',
#  'vexation',
#  'invidious',
#  'enraged',
#  'dismay\xa0',
#  'collide',
#  'revulsive',
#  'outburst',
#  'querulousness',
#  'shirty',
#  'concern\xa0',
#  'displeasing',
#  'envy',
#  'discrepant',
#  'boo-boo',
#  'sick',
#  'tussle',
#  'disapproval',
#  'dishearten\xa0',
#  'troubling',
#  'discordancy',
#  'disgust',
#  'delirium',
#  'conflagration',
#  'slam',
#  'veto',
#  'chafing',
#  'disablement',
#  'peev',
#  'heat',
#  'maddening',
#  'rage',
#  'nettling',
#  'down',
#  'teed',
#  'biting',
#  'defy',
#  'vindictiveness',
#  'sore',
#  'perturb',
#  'kickup',
#  'croak',
#  'rankled',
#  'abhor',
#  'discourage\xa0',
#  'disable',
#  'icky',
#  'nettlesome',
#  'cheesed',
#  'wrath',
#  'bad',
#  'off',
#  'clash',
#  'discomfort\xa0',
#  'dissatisfaction',
#  'enemy',
#  'revulsion',
#  'fall',
#  'holy',
#  'oppress',
#  'face',
#  'bilious',
#  'disturb\xa0',
#  'spat',
#  'at',
#  'choleric',
#  'disquieting',
#  'nasty',
#  'sucky',
#  'friction',
#  'undo',
#  'whale',
#  'abhorrent',
#  'punch',
#  'yucky',
#  'tangle',
#  'crude',
#  'hate',
#  'terminate',
#  'pestiferous',
#  'royal',
#  'noisome',
#  'suffer',
#  'galling',
#  'annoyance',
#  'to',
#  'strain',
#  'pesty',
#  'scrimmage',
#  'differ',
#  'criminal',
#  'contrariant',
#  'slay',
#  'irritating',
#  'biff',
#  'lesion',
#  'ticked',
#  'civil',
#  'unnerve',
#  'protestation',
#  'pound',
#  'scrap',
#  'murder',
#  'disgusting',
#  'antagonist',
#  'dispute',
#  'road',
#  'affray',
#  'detestation',
#  'emulation',
#  'bump',
#  'dispirit\xa0',
#  'repellent',
#  'spitefulness',
#  'burst',
#  'defame',
#  'meanness',
#  'inharmony',
#  'wroth',
#  'detest',
#  'madness',
#  'sear',
#  'annoying',
#  'acrimony',
#  'fury',
#  'incongruousness',
#  'discord',
#  'competition',
#  'slug',
#  'counter',
#  'vitriol',
#  'argue',
#  'vexing',
#  'criminate',
#  'curse',
#  'distaste',
#  'inconsonant',
#  'offensive',
#  'dustup',
#  'loathing',
#  'hideous',
#  'out',
#  'odds',
#  'sue',
#  'hatred',
#  'upsetting',
#  'uncongenial',
#  'impeach']

# %%
# 다양하게 전처리 한 단어를 모두 모아서 중복제거
actionVerbs_all = list(set(pre_lower_wd + lemma_list + lower_wd))
# 빈 값은 제거하고
actionVerbs_all_re =list(filter(None, actionVerbs_all))
actionVerbs_all_re[:5]
# Out:
# ['nettle', 'discountenance', 'lousy', 'scrape', 'vengefulness']

# %%
# 소문자로 모두 변환
words_list_re = [i.lower() for i in actionVerbs_all_re]
words_list_re
# Out:
# ['nettle',
#  'discountenance',
#  'lousy',
#  'scrape',
#  'vengefulness',
#  'bop',
#  'enraging',
#  'deprecate',
#  'obscene',
#  'empoisonment',
#  'angriness',
#  'freak',
#  'livid',
#  'distasteful',
#  'mutilation',
#  'sour',
#  'lawsuit',
#  'abominable',
#  'romp',
#  'smack',
#  'pestilential',
#  'seamy',
#  'opposed',
#  'rebarbative',
#  'confront',
#  'controversy',
#  'jangle',
#  'grievance',
#  'divarication',
#  'fracas',
#  'unhinge\xa0',
#  'miserable',
#  'war',
#  'god-awful',
#  'bang',
#  'malice',
#  'animosity',
#  'charge',
#  'pesky',
#  'contend',
#  'bitter',
#  'nonconcurrence',
#  'wound',
#  'against',
#  'villain',
#  'disfavor',
#  'horror',
#  'villainous',
#  'dreadful',
#  'protest',
#  'indignant',
#  'foe',
#  'aggravate',
#  'argument',
#  'oppose',
#  'invade',
#  'choler',
#  'brawl',
#  'confliction',
#  'conflict',
#  'dissonance',
#  'offense',
#  'burdensome',
#  'irksome',
#  'dissension',
#  'acrimoniousness',
#  'embitterment',
#  'infuriate',
#  'execution',
#  'contretemps',
#  'battle',
#  'fissure',
#  'hostility',
#  'scratch',
#  'tug-of-war',
#  'wrathfulness',
#  'rankling',
#  'horrible',
#  'painful',
#  'rabid',
#  'belligerence',
#  'revolt',
#  'dissent',
#  'repress',
#  'squelch',
#  'warfare',
#  'ballistic',
#  'cut',
#  'chafe',
#  'crankiness',
#  'antipathy',
#  'tolerate',
#  'burn',
#  'hateful',
#  'disagreeable',
#  'punch-up',
#  'bothersome',
#  'rough-and-tumble',
#  'slugfest',
#  'unpalatable',
#  'slaughter',
#  'afflict',
#  'tick',
#  'contrary',
#  'strife',
#  'importune',
#  'dissidence',
#  'rotten',
#  'with',
#  'disaccord',
#  'peeve',
#  'bratty',
#  'horn-mad',
#  'infighting',
#  'ruction',
#  'irascibility',
#  'resentment',
#  'abhorrence',
#  'mix-up',
#  'vexatious',
#  'object',
#  'sickening',
#  'rile',
#  'adversary',
#  'set-to',
#  'outrage',
#  'infuriating',
#  'abominate',
#  'accost',
#  'worry',
#  'scrum',
#  'contrast',
#  'angering',
#  'wrong',
#  'wicked',
#  'clobber',
#  'undergo',
#  'fuming',
#  'smash',
#  'defeat',
#  'gash',
#  'vile',
#  'huff',
#  'contest',
#  'ill-wisher',
#  'put-down',
#  'inflame',
#  'misunderstand',
#  'incompatible',
#  'encounter',
#  'foul',
#  'objection',
#  'concussion',
#  'disquiet',
#  'challenge',
#  'exercise\xa0',
#  'moody',
#  'daunt\xa0',
#  'jangling',
#  'contempt',
#  'difference',
#  'air',
#  'detonate',
#  'distractive',
#  'brattish',
#  'hellish',
#  'thump',
#  'antagonism',
#  'annihilate',
#  'impairment',
#  'thwack',
#  'joust',
#  'brazen',
#  'unfavorable',
#  'schism',
#  'injustice',
#  'malevolence',
#  'unsavory',
#  'mischievous',
#  'squash',
#  'disapprobation',
#  'crime',
#  'obnoxious',
#  'repugnant',
#  'shoot',
#  'wretched',
#  'malignant',
#  'resist',
#  'annoy',
#  'bite',
#  'steam',
#  'knock',
#  'malignancy',
#  'stand',
#  'repulsive',
#  'upset\xa0',
#  'bonk',
#  'hatefulness',
#  'ill',
#  'vendetta',
#  'engage',
#  'archfoe',
#  'bitterness',
#  'donnybrook',
#  'difficult',
#  'rankle',
#  'execute',
#  'discharge',
#  'imbroglio',
#  'melee',
#  'crummy',
#  'disservice',
#  'fight',
#  'smite',
#  'unjustness',
#  'repulsion',
#  'enrage',
#  'awful',
#  'clashing',
#  'inconsonance',
#  'gross',
#  'odious',
#  'incongruence',
#  'inconsistency',
#  'contrariness',
#  'oppression',
#  'riling',
#  'whack',
#  'quibble',
#  'inharmoniousness',
#  'fuss',
#  'catfight',
#  'bicker',
#  'confrontation',
#  'hostilities',
#  'deprecation',
#  'horrid',
#  'grate',
#  'execration',
#  'irate',
#  'disunity',
#  'adverse',
#  'harsh',
#  'jealousy',
#  'scar',
#  'uneasy',
#  'fighting',
#  'fistfight',
#  'incriminate',
#  'troublesome',
#  'blows',
#  'deface',
#  'disquiet\xa0',
#  'ruckus',
#  'bludgeon',
#  'argy-bargy',
#  'inflict',
#  'combatant',
#  'crippling',
#  'antagonize',
#  'bile',
#  'angered',
#  'roil',
#  'insult',
#  'dart',
#  'inflamed',
#  'shatter',
#  'nauseating',
#  'bane',
#  'gall',
#  'aggravating',
#  'incongruent',
#  'contestant',
#  'repel',
#  'worrisome',
#  'deplore',
#  'inconveniencing',
#  'slap',
#  'antagonistic',
#  'rival',
#  'rancor',
#  'attacker',
#  'disturb',
#  'incompatibility',
#  'feud',
#  'scathe',
#  'plaguey',
#  'crump',
#  'dare',
#  'hot',
#  'scandalous',
#  'ruffle',
#  'handgrip',
#  'frustrate',
#  'hinder',
#  'exasperate',
#  'jaundice',
#  'exasperating',
#  'affront',
#  'disunion',
#  'enmity',
#  'aversion',
#  'distress\xa0',
#  'anger',
#  'agitate\xa0',
#  'fray',
#  'ail',
#  'hassle',
#  'hot-headedness',
#  'difficulty',
#  'police',
#  'importunate',
#  'pugnaciousness',
#  'flare-up',
#  'contusion',
#  'outface',
#  'execrate',
#  'discordance',
#  'roiled',
#  'inconsistent',
#  'go',
#  'endure',
#  'repugnance',
#  'temper',
#  'ugly',
#  'loathsome',
#  'incensed',
#  'wrangle',
#  'rivalry',
#  'disdain',
#  'displease',
#  'beating',
#  'crush',
#  'indignation',
#  'madden',
#  'ghastly',
#  'nausea',
#  'maliciousness',
#  'indignity',
#  'world',
#  'disagreement',
#  'shocking',
#  'wallop',
#  'swat',
#  'demoralize\xa0',
#  'invidiousness',
#  'trouble',
#  'pugnacity',
#  'blame',
#  'struggle',
#  'argufy',
#  'controvert',
#  'fire',
#  'hostile',
#  'inconsistence',
#  'contentiousness',
#  'dispatch',
#  'square',
#  'laceration',
#  'orneriness',
#  'cross',
#  'malicious',
#  'frustrating',
#  'odium',
#  'competitor',
#  'cold',
#  'supress',
#  'inconvenience',
#  'lividness',
#  'cattiness',
#  'discomforting',
#  'misunderstanding',
#  'nemesis',
#  'spite',
#  'disfigurement',
#  'baffle',
#  'thorny',
#  'match',
#  'pique',
#  'sock',
#  'cheese',
#  'argle-bargle',
#  'jar',
#  'grapple',
#  'outbrave',
#  'disability',
#  'incongruous',
#  'disharmony',
#  'assassinate',
#  'stressful',
#  'squabble',
#  'disapprove',
#  'fisticuffs',
#  'shock',
#  'falling-out',
#  'revolting',
#  'venom',
#  'nauseate',
#  'cripple',
#  'archenemy',
#  'beastly',
#  'irritation',
#  'combat',
#  'malignity',
#  'duel',
#  'cruddy',
#  'invader',
#  'will',
#  'torture',
#  'incense',
#  'quell',
#  'peeving',
#  'zap',
#  'riled',
#  'wrathful',
#  'divide',
#  'splinter',
#  'distressing',
#  'disagree',
#  'handgrips',
#  'action',
#  'virulence',
#  'disputation',
#  'irateness',
#  'grudge',
#  'quarrelsomeness',
#  'scald',
#  'abrasion',
#  'hammer',
#  'unmixable',
#  'horrendous',
#  'torment\xa0',
#  'complaint',
#  'opposing',
#  'skirmish',
#  'destroy',
#  'contention',
#  'limit',
#  'disconsonant',
#  'vex',
#  'bruise',
#  'riley',
#  'ire',
#  'miff',
#  'sicken',
#  'upset',
#  'unfairness',
#  'clout',
#  'beat',
#  'dissonant',
#  'contestation',
#  'paradoxical',
#  'abomination',
#  'unsettle\xa0',
#  'unwelcome',
#  'nonconcur',
#  'engagement',
#  'apoplectic',
#  'inequity',
#  'jealous',
#  'irascibleness',
#  'crappy',
#  'pestilent',
#  'kill',
#  'blow',
#  'lividity',
#  'run-in',
#  'discordant',
#  'disturbing',
#  'indict',
#  'disputatiousness',
#  'scuffle',
#  'crack',
#  'incongruity',
#  'blowup',
#  'disharmonize',
#  'scorn',
#  'accuse',
#  'tiff',
#  'interfere',
#  'grating',
#  'debate',
#  'unlovely',
#  'dudgeon',
#  'carking',
#  'exasperation',
#  'discompose\xa0',
#  'withstand',
#  'depress',
#  'bother\xa0',
#  'disesteem',
#  'tee',
#  'mismatch',
#  'collision',
#  'outraged',
#  'nauseous',
#  'wind',
#  'up',
#  'rupture',
#  'bash',
#  'despise',
#  'quarrel',
#  'killing',
#  'ireful',
#  'dander',
#  'appalling',
#  'irritability',
#  'broil',
#  'limited',
#  'displeasure',
#  'punch-out',
#  'mayhem',
#  'attack',
#  'altercation',
#  'mad',
#  'despitefulness',
#  'unfair',
#  'unpleasing',
#  'brabble',
#  'biliousness',
#  'logomachy',
#  'furious',
#  'dogfight',
#  'furor',
#  'loathe',
#  'assailant',
#  'despite',
#  'cacophony',
#  'infuriated',
#  'jarring',
#  'altercate',
#  'face-off',
#  'vexation',
#  'invidious',
#  'enraged',
#  'dismay\xa0',
#  'collide',
#  'revulsive',
#  'outburst',
#  'querulousness',
#  'shirty',
#  'concern\xa0',
#  'displeasing',
#  'envy',
#  'discrepant',
#  'boo-boo',
#  'sick',
#  'tussle',
#  'disapproval',
#  'dishearten\xa0',
#  'troubling',
#  'discordancy',
#  'disgust',
#  'delirium',
#  'conflagration',
#  'slam',
#  'veto',
#  'chafing',
#  'disablement',
#  'peev',
#  'heat',
#  'maddening',
#  'rage',
#  'nettling',
#  'down',
#  'teed',
#  'biting',
#  'defy',
#  'vindictiveness',
#  'sore',
#  'perturb',
#  'kickup',
#  'croak',
#  'rankled',
#  'abhor',
#  'discourage\xa0',
#  'disable',
#  'icky',
#  'nettlesome',
#  'cheesed',
#  'wrath',
#  'bad',
#  'off',
#  'clash',
#  'discomfort\xa0',
#  'dissatisfaction',
#  'enemy',
#  'revulsion',
#  'fall',
#  'holy',
#  'oppress',
#  'face',
#  'bilious',
#  'disturb\xa0',
#  'spat',
#  'at',
#  'choleric',
#  'disquieting',
#  'nasty',
#  'fume',
#  'sucky',
#  'friction',
#  'undo',
#  'whale',
#  'abhorrent',
#  'cark',
#  'punch',
#  'yucky',
#  'tangle',
#  'crude',
#  'hate',
#  'terminate',
#  'pestiferous',
#  'royal',
#  'noisome',
#  'suffer',
#  'galling',
#  'annoyance',
#  'to',
#  'strain',
#  'pesty',
#  'scrimmage',
#  'differ',
#  'criminal',
#  'contrariant',
#  'slay',
#  'irritating',
#  'biff',
#  'irritate',
#  'lesion',
#  'ticked',
#  'civil',
#  'unnerve',
#  'protestation',
#  'pound',
#  'scrap',
#  'murder',
#  'disgusting',
#  'antagonist',
#  'dispute',
#  'road',
#  'affray',
#  'detestation',
#  'emulation',
#  'bump',
#  'dispirit\xa0',
#  'repellent',
#  'spitefulness',
#  'burst',
#  'defame',
#  'meanness',
#  'distress',
#  'inharmony',
#  'wroth',
#  'detest',
#  'madness',
#  'sear',
#  'annoying',
#  'acrimony',
#  'fury',
#  'incongruousness',
#  'discord',
#  'competition',
#  'slug',
#  'counter',
#  'vitriol',
#  'argue',
#  'vexing',
#  'appal',
#  'criminate',
#  'curse',
#  'distaste',
#  'inconsonant',
#  'offensive',
#  'dustup',
#  'loathing',
#  'hideous',
#  'out',
#  'odds',
#  'sue',
#  'hatred',
#  'upsetting',
#  'uncongenial',
#  'impeach']

# %%
# csv 파일로 저장하기
import csv

f = open('conflictWorsForPS.csv', 'w', encoding='utf-8')

for i in words_list_re:
    f.write(i + ",")
    
f.close()

# %%
# load data
import pandas as pd
chk_data = pd.read_csv("conflictWorsForPS.csv")
chk_data
# Out:
# Empty DataFrame
# Columns: [nettle, discountenance, lousy, scrape, vengefulness, bop, enraging, deprecate, obscene, empoisonment, angriness, freak, livid, distasteful, mutilation, sour, lawsuit, abominable, romp, smack, pestilential, seamy, opposed, rebarbative, confront, controversy, jangle, grievance, divarication, fracas, unhinge , miserable, war, god-awful, bang, malice, animosity, charge, pesky, contend, bitter, nonconcurrence, wound, against, villain, disfavor, horror, villainous, dreadful, protest, indignant, foe, aggravate, argument, oppose, invade, choler, brawl, confliction, conflict, dissonance, offense, burdensome, irksome, dissension, acrimoniousness, embitterment, infuriate, execution, contretemps, battle, fissure, hostility, scratch, tug-of-war, wrathfulness, rankling, horrible, painful, rabid, belligerence, revolt, dissent, repress, squelch, warfare, ballistic, cut, chafe, crankiness, antipathy, tolerate, burn, hateful, disagreeable, punch-up, bothersome, rough-and-tumble, slugfest, unpalatable, ...]
# Index: []
#
# [0 rows x 685 columns]

# %%
# 불용어 제거

from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
stop = stopwords.words('english')
stop_words = set(stopwords.words('english')) 

result = []
for w in lower_wd: 
    if w not in stop_words: 
        result.append(w)

# %%
result
# Out:
# ['discus',
#  'assault',
#  'abscond',
#  'stagger',
#  'provoke',
#  'channel',
#  'improvise',
#  'scar',
#  'rattle',
#  'document',
#  'mediate',
#  'tug',
#  'negotiate',
#  'rejoin',
#  'nick',
#  'derive',
#  'operate',
#  'pin',
#  'clap',
#  'afflict',
#  'collapse',
#  'slacken',
#  'combat',
#  'crawl',
#  'rub',
#  'balance',
#  'skid',
#  'design',
#  'snuggle',
#  'spark',
#  'wrestle',
#  'rush',
#  'specify',
#  'taunt',
#  'recline',
#  'count',
#  'award',
#  'abuse',
#  'nag',
#  'discover',
#  'draft',
#  'indignant',
#  'nominate',
#  'quarrel',
#  'escape',
#  'wade',
#  'roll',
#  'yield',
#  'debate',
#  'flounder',
#  'hover',
#  'parade',
#  'indignity',
#  'splice',
#  'paralyze',
#  'hoist',
#  'actualized',
#  'preside',
#  'unwelcome',
#  'helm',
#  'narrow',
#  'coded',
#  'grasp',
#  'pat',
#  'raised',
#  'sock',
#  'hug',
#  'trip',
#  'needle',
#  'probe',
#  'demonstrate',
#  'brabble',
#  'shear',
#  'improved',
#  'reduce',
#  'scrap',
#  'oversaw',
#  'save',
#  'sear',
#  'walk',
#  'party',
#  'expand',
#  'formalize',
#  'inspire',
#  'revolutionize',
#  'ail',
#  'construct',
#  'dance',
#  'lower',
#  'force',
#  'stumble',
#  'activate',
#  'mourn',
#  'stand',
#  'shield',
#  'blended',
#  'reveal',
#  'influence',
#  'condense',
#  'undertook',
#  'renew',
#  'drive',
#  'sigh',
#  'dress',
#  'shun',
#  'cram',
#  'manage',
#  'dramatize',
#  'oppress',
#  'anticipate',
#  'huff',
#  'relieve',
#  'plan',
#  'enlist',
#  'interchange',
#  'choke',
#  'scuffle',
#  'nab',
#  'parachute',
#  'sit',
#  'flout',
#  'jab',
#  'specialize',
#  'suggest',
#  'shape',
#  'orchestrate',
#  'charter',
#  'deprecate',
#  'facilitate',
#  'thread',
#  'launch',
#  'strip',
#  'spurn',
#  'instruct',
#  'spell',
#  'stress',
#  'torture',
#  'shrink',
#  'nip',
#  'scrape',
#  'extract',
#  'enable',
#  'envy',
#  'sap',
#  'oppose',
#  'quell',
#  'judge',
#  'purchase',
#  'gouge',
#  'block',
#  'curtail',
#  'shut',
#  'exhibit',
#  'slaughter',
#  'emerge',
#  'dispute',
#  'search',
#  'utilize',
#  'page',
#  'contribute',
#  'race',
#  'observe',
#  'destroy',
#  'expose',
#  'govern',
#  'grip',
#  'hurl',
#  'calm',
#  'jar',
#  'head',
#  'rape',
#  'tackle',
#  'undergo',
#  'offer',
#  'affirm',
#  'remove',
#  'scan',
#  'boost',
#  'abolish',
#  'detest',
#  'fade',
#  'shake',
#  'shoulder',
#  'whack',
#  'undress',
#  'avert',
#  'scare',
#  'trounce',
#  'dig',
#  'abhor',
#  'shiver',
#  'pick',
#  'crush',
#  'organized',
#  'succeed',
#  'disservice',
#  'jolt',
#  'stamp',
#  'gall',
#  'cripple',
#  'deplore',
#  'realized',
#  'fondle',
#  'supress',
#  'circumvent',
#  'encourage',
#  'size',
#  'slide',
#  'smite',
#  'illustrate',
#  'drain',
#  'prepared',
#  'dart',
#  'attack',
#  'instigate',
#  'growl',
#  'convey',
#  'haul',
#  'create',
#  'affray',
#  'extricate',
#  'prod',
#  'reconcile',
#  'represent',
#  'resolve',
#  'augment',
#  'whip',
#  'challenge',
#  'parry',
#  'charge',
#  'perform',
#  'install',
#  'chart',
#  'gash',
#  'snitch',
#  'multiply',
#  'arrest',
#  'face',
#  'grind',
#  'finger',
#  'originate',
#  'tie',
#  'disfavor',
#  'revitalize',
#  'seduce',
#  'repair',
#  'kill',
#  'serve',
#  'joined',
#  'outrage',
#  'record',
#  'grew',
#  'devise',
#  'ruffle',
#  'audit',
#  'furnish',
#  'meet',
#  'douse',
#  'plunge',
#  'strive',
#  'pique',
#  'double',
#  'minimize',
#  'rankle',
#  'shorten',
#  'bushwhack',
#  'stop',
#  'conduct',
#  'retrieve',
#  'support',
#  'complete',
#  'tick',
#  'threaten',
#  'attain',
#  'decrease',
#  'undo',
#  'exceed',
#  'fornicate',
#  'induce',
#  'predict',
#  'summon',
#  'hijack',
#  'supervise',
#  'object',
#  'stimulate',
#  'shave',
#  'programmed',
#  'present',
#  'contend',
#  'revise',
#  'supply',
#  'penetrate',
#  'split',
#  'co-authored',
#  'survey',
#  'exit',
#  'blend',
#  'innovate',
#  'jangle',
#  'estimate',
#  'fling',
#  'hasten',
#  'sail',
#  'fall',
#  'skirt',
#  'crouch',
#  'spike',
#  'avoid',
#  'reached',
#  'scream',
#  'type',
#  'flash',
#  'keynote',
#  'confer',
#  'carry',
#  'trot',
#  'insult',
#  'bill',
#  'customize',
#  'conceptualize',
#  'form',
#  'grow',
#  'molest',
#  'spearhead',
#  'expedited',
#  'poke',
#  'salute',
#  'zip',
#  'control',
#  'annihilate',
#  'stifle',
#  'convert',
#  'nail',
#  'pile',
#  'loathe',
#  'quibble',
#  'extirpate',
#  'arbitrate',
#  'outline',
#  'respond',
#  'violate',
#  'stuff',
#  'grapple',
#  'file',
#  'incriminate',
#  'encounter',
#  'master',
#  'scruff',
#  'equip',
#  'hesitate',
#  'address',
#  'mangle',
#  'endeavor',
#  'gyrate',
#  'arrange',
#  'question',
#  'whistle',
#  'brace',
#  'itemize',
#  'screw',
#  'pounce',
#  'secure',
#  'polish',
#  'detonate',
#  'beat',
#  'fast',
#  'usher',
#  'aim',
#  'drill',
#  'dissect',
#  'repulse',
#  'bite',
#  'march',
#  'scratch',
#  'handle',
#  'skip',
#  'mend',
#  'leap',
#  'elope',
#  'partnered',
#  'simplify',
#  'snub',
#  'fend',
#  'fight',
#  'approach',
#  'patrol',
#  'act',
#  'propose',
#  'ravage',
#  'report',
#  'snicker',
#  'perfect',
#  'spring',
#  'wiggle',
#  'thrash',
#  'shoot',
#  'performed',
#  'bash',
#  'centralize',
#  'regulate',
#  'publicize',
#  'turn',
#  'plow',
#  'land',
#  'quicken',
#  'describe',
#  'incense',
#  'top',
#  'strap',
#  'antagonize',
#  'enjoin',
#  'participate',
#  'invade',
#  'snarl',
#  'shaped',
#  'intensify',
#  'enlighten',
#  'blow',
#  'compute',
#  'icky',
#  'bicker',
#  'placate',
#  'research',
#  'determine',
#  'overcome',
#  'improve',
#  'effect',
#  'screen',
#  'halt',
#  'compile',
#  'assure',
#  'dope',
#  'dishearten\xa0',
#  'introduce',
#  'jimmy',
#  'invent',
#  'lash',
#  'mock',
#  'descend',
#  'inflame',
#  'license',
#  'tread',
#  'experience',
#  'strategize',
#  'advise',
#  'consult',
#  'croak',
#  'hold',
#  'vacate',
#  'hammer',
#  'wrought',
#  'pry',
#  'compose',
#  'configure',
#  'retreat',
#  'aid',
#  'led',
#  'divide',
#  'mastermind',
#  'fix',
#  'defy',
#  'chair',
#  'gnaw',
#  'list',
#  'wave',
#  'enter',
#  'synthesize',
#  'hitch',
#  'wrangle',
#  'individualize',
#  'blast',
#  'chase',
#  'reinforce',
#  'soil',
#  'advocate',
#  'project',
#  'stub',
#  'operated',
#  'startle',
#  'pursue',
#  'test',
#  'resist',
#  'sever',
#  'sidestep',
#  'pocket',
#  'focus',
#  'switch',
#  'strain',
#  'clip',
#  'lifted',
#  'reach',
#  'unsettle\xa0',
#  'correspond',
#  'merged',
#  'render',
#  'rob',
#  'scoot',
#  'shell',
#  'transport',
#  'toss',
#  'battle',
#  'set',
#  'exert',
#  'dispatch',
#  'pilot',
#  'transformed',
#  'write',
#  'raid',
#  'primp',
#  'tilt',
#  'isolate',
#  'fulfill',
#  'plod',
#  'unravel',
#  'knife',
#  'field',
#  'pray',
#  'pitch',
#  'snare',
#  'skim',
#  'standardize',
#  'retaliate',
#  'dissent',
#  'listen',
#  'initiated',
#  'step',
#  'strengthen',
#  'enforce',
#  'disapprove',
#  'proofread',
#  'surpass',
#  'snatch',
#  'rock',
#  'discard',
#  'ransack',
#  'grope',
#  'merge',
#  'counsel',
#  'abduct',
#  'recruit',
#  'stun',
#  'collect',
#  'hypothesize',
#  'flee',
#  'pack',
#  'motivate',
#  'inch',
#  'establish',
#  'label',
#  'swagger',
#  'inequity',
#  'communicate',
#  'sum',
#  'extend',
#  'sprint',
#  'accomplish',
#  'attract',
#  'decide',
#  'repel',
#  'scorn',
#  'dismay\xa0',
#  'offense',
#  'detect',
#  'relate',
#  'inject',
#  'ass',
#  'catch',
#  'preen',
#  'slap',
#  'tumble',
#  'twist',
#  'clutch',
#  'fear',
#  'diagnose',
#  'enhance',
#  'imitate',
#  'distress\xa0',
#  'punch',
#  'index',
#  'raise',
#  'swear',
#  'relax',
#  'change',
#  'receive',
#  'review',
#  'sculpt',
#  'push',
#  'clash',
#  'burst',
#  'draw',
#  'flinch',
#  'dictate',
#  'protect',
#  'splatter',
#  'gain',
#  'swerve',
#  'falter',
#  'deliver',
#  'disdain',
#  'keel',
#  'print',
#  'converse',
#  'sniff',
#  'inflate',
#  'verbalize',
#  'spread',
#  'hobble',
#  'produce',
#  'guard',
#  'realize',
#  'deduct',
#  'pas',
#  'discourage\xa0',
#  'service',
#  'sell',
#  'advance',
#  'suck',
#  'swing',
#  'shout',
#  'wedge',
#  'pout',
#  'crafted',
#  'drag',
#  'verify',
#  'outpace',
#  'reel',
#  'tighten',
#  'strangle',
#  'diminish',
#  'explode',
#  'divert',
#  'scuttle',
#  'sense',
#  'interview',
#  'dodge',
#  'champion',
#  'inflict',
#  'stroke',
#  'drink',
#  'scale',
#  'cure',
#  'lift',
#  'apprehend',
#  'lean',
#  'exhale',
#  'sold',
#  'weigh',
#  'tip',
#  'vex',
#  'grunt',
#  'provide',
#  'tolerate',
#  'formulate',
#  'prescribe',
#  'shatter',
#  'adjust',
#  'creep',
#  'published',
#  'update',
#  'flatten',
#  'swap',
#  'maul',
#  'experiment',
#  'tickle',
#  'invest',
#  'deface',
#  'bank',
#  'ensure',
#  'scamper',
#  'authorize',
#  'berate',
#  'enact',
#  'swim',
#  'scout',
#  'triple',
#  'frustrate',
#  'wrench',
#  'coproduced',
#  'enforced',
#  'submit',
#  'quit',
#  'yelp',
#  'contract',
#  'wander',
#  'zap',
#  'volunteer',
#  'jerk',
#  'managed',
#  'roil',
#  'market',
#  'prepare',
#  'fake',
#  'sway',
#  'ease',
#  'perceive',
#  'value',
#  'purge',
#  'recoup',
#  'read',
#  'outperformed',
#  'pull',
#  'shovel',
#  'taught',
#  'deck',
#  'nurture',
#  'teach',
#  'rank',
#  'renovate',
#  'yank',
#  'flick',
#  'measure',
#  'persuade',
#  'meddle',
#  'stick',
#  'scoop',
#  'picket',
#  'hire',
#  'join',
#  'display',
#  'propel',
#  'restore',
#  'wreck',
#  'built',
#  'clarify',
#  'instructed',
#  'irateness',
#  'profitable',
#  'elevate',
#  'wove',
#  'network',
#  'flap',
#  'watch',
#  'defeat',
#  'dash',
#  'escalate',
#  'hail',
#  'rate',
#  'study',
#  'eject',
#  'develop',
#  'hassle',
#  'outpaced',
#  'accelerate',
#  'bar',
#  'paddle',
#  'weed',
#  'endure',
#  'publish',
#  'accumulate',
#  'found',
#  'pioneer',
#  'scatter',
#  'greet',
#  'tout',
#  'ground',
#  'collide',
#  'stock',
#  'spray',
#  'jump',
#  'vault',
#  'struck',
#  'surrender',
#  'limp',
#  'slash',
#  'squabble',
#  'employ',
#  'transform',
#  'smuggle',
#  'fly',
#  'mark',
#  'oversee',
#  'refer',
#  'drown',
#  'translate',
#  'earn',
#  'deal',
#  'administer',
#  'occupy',
#  'terminate',
#  'discomfort\xa0',
#  'redeem',
#  'spur',
#  'identify',
#  'learn',
#  'talk',
#  'mentored',
#  'conserve',
#  'pose',
#  'sustain',
#  'delete',
#  'feed',
#  'streamline',
#  'deliberate',
#  'cooperate',
#  'drape',
#  'infighting',
#  'prompt',
#  'romp',
#  'mumble',
#  'bump',
#  'manufacture',
#  'adapt',
#  'treat',
#  'engineer',
#  'elude',
#  'defended',
#  'drip',
#  'maximize',
#  'struggle',
#  'fan',
#  'discharge',
#  'vanish',
#  'decorate',
#  'tangle',
#  'quiz',
#  'systematize',
#  'eliminate',
#  'collate',
#  'shift',
#  'liaise',
#  'coach',
#  'author',
#  'gossip',
#  'expel',
#  'accrue',
#  'manipulate',
#  'model',
#  'spot',
#  'pirate',
#  'evaluate',
#  'integrate',
#  'process',
#  'publicized',
#  'remodeled',
#  'stack',
#  'trim',
#  'commandeer',
#  'injure',
#  'lead',
#  'bolster',
#  'tutor',
#  'vanquish',
#  'kibitz',
#  'repulsion',
#  'overhaul',
#  'pinch',
#  'rise',
#  'spin',
#  'dare',
#  'fill',
#  'consolidate',
#  'foster',
#  'hide',
#  'vent',
#  'unify',
#  'indignation',
#  'scrawl',
#  'lecture',
#  'hinder',
#  'combine',
#  'muster',
#  'peel',
#  'spear',
#  'snuff',
#  'examine',
#  'mingle',
#  'detail',
#  'implement',
#  'reposition',
#  'altercate',
#  'enlarge',
#  'summarize',
#  'soak',
#  'duel',
#  'hit',
#  'undertake',
#  'analyze',
#  'automate',
#  'shove',
#  'train',
#  'unhinge\xa0',
#  'win',
#  'obtain',
#  'assign',
#  'collaborate',
#  'level',
#  'forecasted',
#  'schedule',
#  'tear',
#  'accost',
#  'trap',
#  'scold',
#  'target',
#  'delegate',
#  'brawl',
#  'appoint',
#  'veto',
#  'expedite',
#  'evacuate',
#  'lunge',
#  'segment',
#  'tease',
#  'transcribe',
#  'resign',
#  'strike',
#  'throw',
#  'ride',
#  'grab',
#  'authenticate',
#  'biff',
#  'insert',
#  'locate',
#  'paw',
#  'pioneered',
#  'flit',
#  'outlined',
#  'magnify',
#  'move',
#  'protest',
#  'relent',
#  'investigate',
#  'calculate',
#  'involve',
#  'scavenge',
#  'mutilate',
#  'gather',
#  'snoop',
#  'spearheaded',
#  'smell',
#  'place',
#  'bury',
#  'collar',
#  'initiate',
#  'order',
#  'explain',
#  'float',
#  'reconnoiter',
#  'photograph',
#  'slug',
#  'swallow',
#  'circumscribe',
#  'regain',
#  'impeach',
#  'broke',
#  'accuse',
#  'smash',
#  'allocate',
#  'ram',
#  'demoralize\xa0',
#  'steer',
#  'spy',
#  'rave',
#  'uncover',
#  'yell',
#  'classify',
#  'unveil',
#  'peep',
#  'squeak',
#  'staff',
#  'terrorize',
#  'maim',
#  'slay',
#  'coordinate',
#  'evade',
#  'justify',
#  'widen',
#  'inspect',
#  'inform',
#  'pound',
#  'importune',
#  'originated',
#  'seal',
#  'drug',
#  'satisfy',
#  'fashion',
#  'flaunt',
#  'mold',
#  'hack',
#  'ensnare',
#  'select',
#  'abominate',
#  'lick',
#  'scour',
#  'fumble',
#  'sip',
#  'despise',
#  'gesture',
#  'indict',
#  'sort',
#  'smear',
#  'synergize',
#  'trained',
#  'tuck',
#  'campaign',
#  'dive',
#  'harass',
#  'dry',
#  'sew',
#  'solve',
#  'capitalize',
#  ...]

# %%
import pickle

# save
with open('data_communityWords.pickle', 'wb') as f:
    pickle.dump(result, f, pickle.HIGHEST_PROTOCOL)

# load
with open('data_communityWords.pickle', 'rb') as f:
    result = pickle.load(f)
    
result
# Out:
# ['discus',
#  'assault',
#  'abscond',
#  'stagger',
#  'provoke',
#  'channel',
#  'improvise',
#  'scar',
#  'rattle',
#  'document',
#  'mediate',
#  'tug',
#  'negotiate',
#  'rejoin',
#  'nick',
#  'derive',
#  'operate',
#  'pin',
#  'clap',
#  'afflict',
#  'collapse',
#  'slacken',
#  'combat',
#  'crawl',
#  'rub',
#  'balance',
#  'skid',
#  'design',
#  'snuggle',
#  'spark',
#  'wrestle',
#  'rush',
#  'specify',
#  'taunt',
#  'recline',
#  'count',
#  'award',
#  'abuse',
#  'nag',
#  'discover',
#  'draft',
#  'indignant',
#  'nominate',
#  'quarrel',
#  'escape',
#  'wade',
#  'roll',
#  'yield',
#  'debate',
#  'flounder',
#  'hover',
#  'parade',
#  'indignity',
#  'splice',
#  'paralyze',
#  'hoist',
#  'actualized',
#  'preside',
#  'unwelcome',
#  'helm',
#  'narrow',
#  'coded',
#  'grasp',
#  'pat',
#  'raised',
#  'sock',
#  'hug',
#  'trip',
#  'needle',
#  'probe',
#  'demonstrate',
#  'brabble',
#  'shear',
#  'improved',
#  'reduce',
#  'scrap',
#  'oversaw',
#  'save',
#  'sear',
#  'walk',
#  'party',
#  'expand',
#  'formalize',
#  'inspire',
#  'revolutionize',
#  'ail',
#  'construct',
#  'dance',
#  'lower',
#  'force',
#  'stumble',
#  'activate',
#  'mourn',
#  'stand',
#  'shield',
#  'blended',
#  'reveal',
#  'influence',
#  'condense',
#  'undertook',
#  'renew',
#  'drive',
#  'sigh',
#  'dress',
#  'shun',
#  'cram',
#  'manage',
#  'dramatize',
#  'oppress',
#  'anticipate',
#  'huff',
#  'relieve',
#  'plan',
#  'enlist',
#  'interchange',
#  'choke',
#  'scuffle',
#  'nab',
#  'parachute',
#  'sit',
#  'flout',
#  'jab',
#  'specialize',
#  'suggest',
#  'shape',
#  'orchestrate',
#  'charter',
#  'deprecate',
#  'facilitate',
#  'thread',
#  'launch',
#  'strip',
#  'spurn',
#  'instruct',
#  'spell',
#  'stress',
#  'torture',
#  'shrink',
#  'nip',
#  'scrape',
#  'extract',
#  'enable',
#  'envy',
#  'sap',
#  'oppose',
#  'quell',
#  'judge',
#  'purchase',
#  'gouge',
#  'block',
#  'curtail',
#  'shut',
#  'exhibit',
#  'slaughter',
#  'emerge',
#  'dispute',
#  'search',
#  'utilize',
#  'page',
#  'contribute',
#  'race',
#  'observe',
#  'destroy',
#  'expose',
#  'govern',
#  'grip',
#  'hurl',
#  'calm',
#  'jar',
#  'head',
#  'rape',
#  'tackle',
#  'undergo',
#  'offer',
#  'affirm',
#  'remove',
#  'scan',
#  'boost',
#  'abolish',
#  'detest',
#  'fade',
#  'shake',
#  'shoulder',
#  'whack',
#  'undress',
#  'avert',
#  'scare',
#  'trounce',
#  'dig',
#  'abhor',
#  'shiver',
#  'pick',
#  'crush',
#  'organized',
#  'succeed',
#  'disservice',
#  'jolt',
#  'stamp',
#  'gall',
#  'cripple',
#  'deplore',
#  'realized',
#  'fondle',
#  'supress',
#  'circumvent',
#  'encourage',
#  'size',
#  'slide',
#  'smite',
#  'illustrate',
#  'drain',
#  'prepared',
#  'dart',
#  'attack',
#  'instigate',
#  'growl',
#  'convey',
#  'haul',
#  'create',
#  'affray',
#  'extricate',
#  'prod',
#  'reconcile',
#  'represent',
#  'resolve',
#  'augment',
#  'whip',
#  'challenge',
#  'parry',
#  'charge',
#  'perform',
#  'install',
#  'chart',
#  'gash',
#  'snitch',
#  'multiply',
#  'arrest',
#  'face',
#  'grind',
#  'finger',
#  'originate',
#  'tie',
#  'disfavor',
#  'revitalize',
#  'seduce',
#  'repair',
#  'kill',
#  'serve',
#  'joined',
#  'outrage',
#  'record',
#  'grew',
#  'devise',
#  'ruffle',
#  'audit',
#  'furnish',
#  'meet',
#  'douse',
#  'plunge',
#  'strive',
#  'pique',
#  'double',
#  'minimize',
#  'rankle',
#  'shorten',
#  'bushwhack',
#  'stop',
#  'conduct',
#  'retrieve',
#  'support',
#  'complete',
#  'tick',
#  'threaten',
#  'attain',
#  'decrease',
#  'undo',
#  'exceed',
#  'fornicate',
#  'induce',
#  'predict',
#  'summon',
#  'hijack',
#  'supervise',
#  'object',
#  'stimulate',
#  'shave',
#  'programmed',
#  'present',
#  'contend',
#  'revise',
#  'supply',
#  'penetrate',
#  'split',
#  'co-authored',
#  'survey',
#  'exit',
#  'blend',
#  'innovate',
#  'jangle',
#  'estimate',
#  'fling',
#  'hasten',
#  'sail',
#  'fall',
#  'skirt',
#  'crouch',
#  'spike',
#  'avoid',
#  'reached',
#  'scream',
#  'type',
#  'flash',
#  'keynote',
#  'confer',
#  'carry',
#  'trot',
#  'insult',
#  'bill',
#  'customize',
#  'conceptualize',
#  'form',
#  'grow',
#  'molest',
#  'spearhead',
#  'expedited',
#  'poke',
#  'salute',
#  'zip',
#  'control',
#  'annihilate',
#  'stifle',
#  'convert',
#  'nail',
#  'pile',
#  'loathe',
#  'quibble',
#  'extirpate',
#  'arbitrate',
#  'outline',
#  'respond',
#  'violate',
#  'stuff',
#  'grapple',
#  'file',
#  'incriminate',
#  'encounter',
#  'master',
#  'scruff',
#  'equip',
#  'hesitate',
#  'address',
#  'mangle',
#  'endeavor',
#  'gyrate',
#  'arrange',
#  'question',
#  'whistle',
#  'brace',
#  'itemize',
#  'screw',
#  'pounce',
#  'secure',
#  'polish',
#  'detonate',
#  'beat',
#  'fast',
#  'usher',
#  'aim',
#  'drill',
#  'dissect',
#  'repulse',
#  'bite',
#  'march',
#  'scratch',
#  'handle',
#  'skip',
#  'mend',
#  'leap',
#  'elope',
#  'partnered',
#  'simplify',
#  'snub',
#  'fend',
#  'fight',
#  'approach',
#  'patrol',
#  'act',
#  'propose',
#  'ravage',
#  'report',
#  'snicker',
#  'perfect',
#  'spring',
#  'wiggle',
#  'thrash',
#  'shoot',
#  'performed',
#  'bash',
#  'centralize',
#  'regulate',
#  'publicize',
#  'turn',
#  'plow',
#  'land',
#  'quicken',
#  'describe',
#  'incense',
#  'top',
#  'strap',
#  'antagonize',
#  'enjoin',
#  'participate',
#  'invade',
#  'snarl',
#  'shaped',
#  'intensify',
#  'enlighten',
#  'blow',
#  'compute',
#  'icky',
#  'bicker',
#  'placate',
#  'research',
#  'determine',
#  'overcome',
#  'improve',
#  'effect',
#  'screen',
#  'halt',
#  'compile',
#  'assure',
#  'dope',
#  'dishearten\xa0',
#  'introduce',
#  'jimmy',
#  'invent',
#  'lash',
#  'mock',
#  'descend',
#  'inflame',
#  'license',
#  'tread',
#  'experience',
#  'strategize',
#  'advise',
#  'consult',
#  'croak',
#  'hold',
#  'vacate',
#  'hammer',
#  'wrought',
#  'pry',
#  'compose',
#  'configure',
#  'retreat',
#  'aid',
#  'led',
#  'divide',
#  'mastermind',
#  'fix',
#  'defy',
#  'chair',
#  'gnaw',
#  'list',
#  'wave',
#  'enter',
#  'synthesize',
#  'hitch',
#  'wrangle',
#  'individualize',
#  'blast',
#  'chase',
#  'reinforce',
#  'soil',
#  'advocate',
#  'project',
#  'stub',
#  'operated',
#  'startle',
#  'pursue',
#  'test',
#  'resist',
#  'sever',
#  'sidestep',
#  'pocket',
#  'focus',
#  'switch',
#  'strain',
#  'clip',
#  'lifted',
#  'reach',
#  'unsettle\xa0',
#  'correspond',
#  'merged',
#  'render',
#  'rob',
#  'scoot',
#  'shell',
#  'transport',
#  'toss',
#  'battle',
#  'set',
#  'exert',
#  'dispatch',
#  'pilot',
#  'transformed',
#  'write',
#  'raid',
#  'primp',
#  'tilt',
#  'isolate',
#  'fulfill',
#  'plod',
#  'unravel',
#  'knife',
#  'field',
#  'pray',
#  'pitch',
#  'snare',
#  'skim',
#  'standardize',
#  'retaliate',
#  'dissent',
#  'listen',
#  'initiated',
#  'step',
#  'strengthen',
#  'enforce',
#  'disapprove',
#  'proofread',
#  'surpass',
#  'snatch',
#  'rock',
#  'discard',
#  'ransack',
#  'grope',
#  'merge',
#  'counsel',
#  'abduct',
#  'recruit',
#  'stun',
#  'collect',
#  'hypothesize',
#  'flee',
#  'pack',
#  'motivate',
#  'inch',
#  'establish',
#  'label',
#  'swagger',
#  'inequity',
#  'communicate',
#  'sum',
#  'extend',
#  'sprint',
#  'accomplish',
#  'attract',
#  'decide',
#  'repel',
#  'scorn',
#  'dismay\xa0',
#  'offense',
#  'detect',
#  'relate',
#  'inject',
#  'ass',
#  'catch',
#  'preen',
#  'slap',
#  'tumble',
#  'twist',
#  'clutch',
#  'fear',
#  'diagnose',
#  'enhance',
#  'imitate',
#  'distress\xa0',
#  'punch',
#  'index',
#  'raise',
#  'swear',
#  'relax',
#  'change',
#  'receive',
#  'review',
#  'sculpt',
#  'push',
#  'clash',
#  'burst',
#  'draw',
#  'flinch',
#  'dictate',
#  'protect',
#  'splatter',
#  'gain',
#  'swerve',
#  'falter',
#  'deliver',
#  'disdain',
#  'keel',
#  'print',
#  'converse',
#  'sniff',
#  'inflate',
#  'verbalize',
#  'spread',
#  'hobble',
#  'produce',
#  'guard',
#  'realize',
#  'deduct',
#  'pas',
#  'discourage\xa0',
#  'service',
#  'sell',
#  'advance',
#  'suck',
#  'swing',
#  'shout',
#  'wedge',
#  'pout',
#  'crafted',
#  'drag',
#  'verify',
#  'outpace',
#  'reel',
#  'tighten',
#  'strangle',
#  'diminish',
#  'explode',
#  'divert',
#  'scuttle',
#  'sense',
#  'interview',
#  'dodge',
#  'champion',
#  'inflict',
#  'stroke',
#  'drink',
#  'scale',
#  'cure',
#  'lift',
#  'apprehend',
#  'lean',
#  'exhale',
#  'sold',
#  'weigh',
#  'tip',
#  'vex',
#  'grunt',
#  'provide',
#  'tolerate',
#  'formulate',
#  'prescribe',
#  'shatter',
#  'adjust',
#  'creep',
#  'published',
#  'update',
#  'flatten',
#  'swap',
#  'maul',
#  'experiment',
#  'tickle',
#  'invest',
#  'deface',
#  'bank',
#  'ensure',
#  'scamper',
#  'authorize',
#  'berate',
#  'enact',
#  'swim',
#  'scout',
#  'triple',
#  'frustrate',
#  'wrench',
#  'coproduced',
#  'enforced',
#  'submit',
#  'quit',
#  'yelp',
#  'contract',
#  'wander',
#  'zap',
#  'volunteer',
#  'jerk',
#  'managed',
#  'roil',
#  'market',
#  'prepare',
#  'fake',
#  'sway',
#  'ease',
#  'perceive',
#  'value',
#  'purge',
#  'recoup',
#  'read',
#  'outperformed',
#  'pull',
#  'shovel',
#  'taught',
#  'deck',
#  'nurture',
#  'teach',
#  'rank',
#  'renovate',
#  'yank',
#  'flick',
#  'measure',
#  'persuade',
#  'meddle',
#  'stick',
#  'scoop',
#  'picket',
#  'hire',
#  'join',
#  'display',
#  'propel',
#  'restore',
#  'wreck',
#  'built',
#  'clarify',
#  'instructed',
#  'irateness',
#  'profitable',
#  'elevate',
#  'wove',
#  'network',
#  'flap',
#  'watch',
#  'defeat',
#  'dash',
#  'escalate',
#  'hail',
#  'rate',
#  'study',
#  'eject',
#  'develop',
#  'hassle',
#  'outpaced',
#  'accelerate',
#  'bar',
#  'paddle',
#  'weed',
#  'endure',
#  'publish',
#  'accumulate',
#  'found',
#  'pioneer',
#  'scatter',
#  'greet',
#  'tout',
#  'ground',
#  'collide',
#  'stock',
#  'spray',
#  'jump',
#  'vault',
#  'struck',
#  'surrender',
#  'limp',
#  'slash',
#  'squabble',
#  'employ',
#  'transform',
#  'smuggle',
#  'fly',
#  'mark',
#  'oversee',
#  'refer',
#  'drown',
#  'translate',
#  'earn',
#  'deal',
#  'administer',
#  'occupy',
#  'terminate',
#  'discomfort\xa0',
#  'redeem',
#  'spur',
#  'identify',
#  'learn',
#  'talk',
#  'mentored',
#  'conserve',
#  'pose',
#  'sustain',
#  'delete',
#  'feed',
#  'streamline',
#  'deliberate',
#  'cooperate',
#  'drape',
#  'infighting',
#  'prompt',
#  'romp',
#  'mumble',
#  'bump',
#  'manufacture',
#  'adapt',
#  'treat',
#  'engineer',
#  'elude',
#  'defended',
#  'drip',
#  'maximize',
#  'struggle',
#  'fan',
#  'discharge',
#  'vanish',
#  'decorate',
#  'tangle',
#  'quiz',
#  'systematize',
#  'eliminate',
#  'collate',
#  'shift',
#  'liaise',
#  'coach',
#  'author',
#  'gossip',
#  'expel',
#  'accrue',
#  'manipulate',
#  'model',
#  'spot',
#  'pirate',
#  'evaluate',
#  'integrate',
#  'process',
#  'publicized',
#  'remodeled',
#  'stack',
#  'trim',
#  'commandeer',
#  'injure',
#  'lead',
#  'bolster',
#  'tutor',
#  'vanquish',
#  'kibitz',
#  'repulsion',
#  'overhaul',
#  'pinch',
#  'rise',
#  'spin',
#  'dare',
#  'fill',
#  'consolidate',
#  'foster',
#  'hide',
#  'vent',
#  'unify',
#  'indignation',
#  'scrawl',
#  'lecture',
#  'hinder',
#  'combine',
#  'muster',
#  'peel',
#  'spear',
#  'snuff',
#  'examine',
#  'mingle',
#  'detail',
#  'implement',
#  'reposition',
#  'altercate',
#  'enlarge',
#  'summarize',
#  'soak',
#  'duel',
#  'hit',
#  'undertake',
#  'analyze',
#  'automate',
#  'shove',
#  'train',
#  'unhinge\xa0',
#  'win',
#  'obtain',
#  'assign',
#  'collaborate',
#  'level',
#  'forecasted',
#  'schedule',
#  'tear',
#  'accost',
#  'trap',
#  'scold',
#  'target',
#  'delegate',
#  'brawl',
#  'appoint',
#  'veto',
#  'expedite',
#  'evacuate',
#  'lunge',
#  'segment',
#  'tease',
#  'transcribe',
#  'resign',
#  'strike',
#  'throw',
#  'ride',
#  'grab',
#  'authenticate',
#  'biff',
#  'insert',
#  'locate',
#  'paw',
#  'pioneered',
#  'flit',
#  'outlined',
#  'magnify',
#  'move',
#  'protest',
#  'relent',
#  'investigate',
#  'calculate',
#  'involve',
#  'scavenge',
#  'mutilate',
#  'gather',
#  'snoop',
#  'spearheaded',
#  'smell',
#  'place',
#  'bury',
#  'collar',
#  'initiate',
#  'order',
#  'explain',
#  'float',
#  'reconnoiter',
#  'photograph',
#  'slug',
#  'swallow',
#  'circumscribe',
#  'regain',
#  'impeach',
#  'broke',
#  'accuse',
#  'smash',
#  'allocate',
#  'ram',
#  'demoralize\xa0',
#  'steer',
#  'spy',
#  'rave',
#  'uncover',
#  'yell',
#  'classify',
#  'unveil',
#  'peep',
#  'squeak',
#  'staff',
#  'terrorize',
#  'maim',
#  'slay',
#  'coordinate',
#  'evade',
#  'justify',
#  'widen',
#  'inspect',
#  'inform',
#  'pound',
#  'importune',
#  'originated',
#  'seal',
#  'drug',
#  'satisfy',
#  'fashion',
#  'flaunt',
#  'mold',
#  'hack',
#  'ensnare',
#  'select',
#  'abominate',
#  'lick',
#  'scour',
#  'fumble',
#  'sip',
#  'despise',
#  'gesture',
#  'indict',
#  'sort',
#  'smear',
#  'synergize',
#  'trained',
#  'tuck',
#  'campaign',
#  'dive',
#  'harass',
#  'dry',
#  'sew',
#  'solve',
#  'capitalize',
#  ...]

# %% [markdown]
# # 이제 이 값을 보기좋게 한줄로 정리를 할 수도 있다.
# 복붙하면 됨. ㅎㅎㅎ.
#
# <br> 참고 : http://javascriptcompressor.com/

# %%
['seems','point','magnificent','confident','given','superior','notably','seen','subject','total','beautiful','repeatedly','come','either','position','sound','mean','light','think?','usually','delicious','rightly','reaction','wicked','expert','it’s','doubtless','evidence','go','surely','really','methinks','cannot','matter.','giving','sure','naturally','carelessly','fabulous','ask','said','estimation','quite','large','typically','complete','unexpected','never','suppose','may','care','reckon','...','unforeseeable','minority','complex','lovely','believe','superb','maybe','primarily','mind','..','observed','possibly','generally','probably','consideration','safely','picturesque','like','great','likely','imagine','consider','bet','standpoint','it’s','sheer','wisely','undoubtedly','prof','tell','opposite',"i'd",'suggests','i’d','initial','incredibly','simply','deadly','main','merely','amazingly','adverbs','staggering','idea','sensational','dare','eye','you’d','seriously','expressed','high','agree','well','positively','pleasant','question','perhaps','unpredictable','conviction','marvellous','excellent','unforeseen','old','thoughtfully','mainly','consistently','sufficiently','astonishing','truthfully','glorious','feeling','idiot','definitely','extraordinary','support','quality','topic','solely','understanding','satisfying','everyone','increasingly','pleasurable','obvious','might','resembles','doubt','delightful','phenomenal','must','conceit','ridiculously','appears','take','wa','find','unduly','opinion','honest','impression','confidentially','disagree','constantly','help','change',"i'm",'way','think','suspect','stunning','could','money','i’ll','complicated','course','alone','least','heavily','judgement','one','due','clear','tend','highly','positive','according','enjoyable','exclusively','bravely','argue','book','precisely','plainly','chiefly','i’ve','best','cleverly','difficult','top','predominantly','personally','wrote','can’t','far','taste','suggest','enormously','prime','unfortunately','unique','summarise','pretend','purely','want','reservation','deny','controversial','rather','right','pleasing','perspective','outta','dreadfully','kindly','indeed','presumably','exactly','wonderful',"one's",'frequently','know','regard','unbelievably','certain','pretty','fulfilling','obviously','matter','although','first-rate','sight','conceivably','sit','awesome','terrific','particularly','gather','thinking','postulate','familiar','perfectly','look','unbelievable','mistaken','vantage','grand','one','conclusion','part','imho','speaking','conclude','standing','classic','humble','scenic','won’t','stupidly','stand','frank','....','impressive','reasonable','spectacular','view','side','absolute','maintain','would','infer','serious','outstanding','mixed','fact','breathtaking','person','say','unlikely','neither','shred','personal','belief','sitting','know','weighing','fortunately','wish','sterling','without','absolutely','admit','utter','mostly','completely','attractive','majestic','totally','shadow','continually','sake','personally','people','towards','fair','claimed','technically','presume','truly','commenting','noticed',"i'm",'exactly.','viewpoint','crazy','speaking','assume','always','limited','much','theoretically','head','gratifying','fantastic','incredible','read','get','reckoning','bitterly','even','correct','without','remarkable','knowledge','tremendous','obviously','exquisite','disappointingly','thought','assumes','especially','miraculous','rewarding','strongly','convinced','concerned','exceptional','case','argument','actual','amazing','i’m','surprising','imposing','charming','entirely','hold','quite','pure','clearly','brilliant','sat','fairly','assessment','understand','surprisingly','seem','guess','generously','see','certainly','foolishly','whole','particular','perfect','wrong','issue','extremely','judgment','argued','frankly','luckily','experience','feel','this.','frankly','saying','later','situation','unusual']
# Out:
# ['seems',
#  'point',
#  'magnificent',
#  'confident',
#  'given',
#  'superior',
#  'notably',
#  'seen',
#  'subject',
#  'total',
#  'beautiful',
#  'repeatedly',
#  'come',
#  'either',
#  'position',
#  'sound',
#  'mean',
#  'light',
#  'think?',
#  'usually',
#  'delicious',
#  'rightly',
#  'reaction',
#  'wicked',
#  'expert',
#  'it’s',
#  'doubtless',
#  'evidence',
#  'go',
#  'surely',
#  'really',
#  'methinks',
#  'cannot',
#  'matter.',
#  'giving',
#  'sure',
#  'naturally',
#  'carelessly',
#  'fabulous',
#  'ask',
#  'said',
#  'estimation',
#  'quite',
#  'large',
#  'typically',
#  'complete',
#  'unexpected',
#  'never',
#  'suppose',
#  'may',
#  'care',
#  'reckon',
#  '...',
#  'unforeseeable',
#  'minority',
#  'complex',
#  'lovely',
#  'believe',
#  'superb',
#  'maybe',
#  'primarily',
#  'mind',
#  '..',
#  'observed',
#  'possibly',
#  'generally',
#  'probably',
#  'consideration',
#  'safely',
#  'picturesque',
#  'like',
#  'great',
#  'likely',
#  'imagine',
#  'consider',
#  'bet',
#  'standpoint',
#  'it’s',
#  'sheer',
#  'wisely',
#  'undoubtedly',
#  'prof',
#  'tell',
#  'opposite',
#  "i'd",
#  'suggests',
#  'i’d',
#  'initial',
#  'incredibly',
#  'simply',
#  'deadly',
#  'main',
#  'merely',
#  'amazingly',
#  'adverbs',
#  'staggering',
#  'idea',
#  'sensational',
#  'dare',
#  'eye',
#  'you’d',
#  'seriously',
#  'expressed',
#  'high',
#  'agree',
#  'well',
#  'positively',
#  'pleasant',
#  'question',
#  'perhaps',
#  'unpredictable',
#  'conviction',
#  'marvellous',
#  'excellent',
#  'unforeseen',
#  'old',
#  'thoughtfully',
#  'mainly',
#  'consistently',
#  'sufficiently',
#  'astonishing',
#  'truthfully',
#  'glorious',
#  'feeling',
#  'idiot',
#  'definitely',
#  'extraordinary',
#  'support',
#  'quality',
#  'topic',
#  'solely',
#  'understanding',
#  'satisfying',
#  'everyone',
#  'increasingly',
#  'pleasurable',
#  'obvious',
#  'might',
#  'resembles',
#  'doubt',
#  'delightful',
#  'phenomenal',
#  'must',
#  'conceit',
#  'ridiculously',
#  'appears',
#  'take',
#  'wa',
#  'find',
#  'unduly',
#  'opinion',
#  'honest',
#  'impression',
#  'confidentially',
#  'disagree',
#  'constantly',
#  'help',
#  'change',
#  "i'm",
#  'way',
#  'think',
#  'suspect',
#  'stunning',
#  'could',
#  'money',
#  'i’ll',
#  'complicated',
#  'course',
#  'alone',
#  'least',
#  'heavily',
#  'judgement',
#  'one',
#  'due',
#  'clear',
#  'tend',
#  'highly',
#  'positive',
#  'according',
#  'enjoyable',
#  'exclusively',
#  'bravely',
#  'argue',
#  'book',
#  'precisely',
#  'plainly',
#  'chiefly',
#  'i’ve',
#  'best',
#  'cleverly',
#  'difficult',
#  'top',
#  'predominantly',
#  'personally',
#  'wrote',
#  'can’t',
#  'far',
#  'taste',
#  'suggest',
#  'enormously',
#  'prime',
#  'unfortunately',
#  'unique',
#  'summarise',
#  'pretend',
#  'purely',
#  'want',
#  'reservation',
#  'deny',
#  'controversial',
#  'rather',
#  'right',
#  'pleasing',
#  'perspective',
#  'outta',
#  'dreadfully',
#  'kindly',
#  'indeed',
#  'presumably',
#  'exactly',
#  'wonderful',
#  "one's",
#  'frequently',
#  'know',
#  'regard',
#  'unbelievably',
#  'certain',
#  'pretty',
#  'fulfilling',
#  'obviously',
#  'matter',
#  'although',
#  'first-rate',
#  'sight',
#  'conceivably',
#  'sit',
#  'awesome',
#  'terrific',
#  'particularly',
#  'gather',
#  'thinking',
#  'postulate',
#  'familiar',
#  'perfectly',
#  'look',
#  'unbelievable',
#  'mistaken',
#  'vantage',
#  'grand',
#  'one',
#  'conclusion',
#  'part',
#  'imho',
#  'speaking',
#  'conclude',
#  'standing',
#  'classic',
#  'humble',
#  'scenic',
#  'won’t',
#  'stupidly',
#  'stand',
#  'frank',
#  '....',
#  'impressive',
#  'reasonable',
#  'spectacular',
#  'view',
#  'side',
#  'absolute',
#  'maintain',
#  'would',
#  'infer',
#  'serious',
#  'outstanding',
#  'mixed',
#  'fact',
#  'breathtaking',
#  'person',
#  'say',
#  'unlikely',
#  'neither',
#  'shred',
#  'personal',
#  'belief',
#  'sitting',
#  'know',
#  'weighing',
#  'fortunately',
#  'wish',
#  'sterling',
#  'without',
#  'absolutely',
#  'admit',
#  'utter',
#  'mostly',
#  'completely',
#  'attractive',
#  'majestic',
#  'totally',
#  'shadow',
#  'continually',
#  'sake',
#  'personally',
#  'people',
#  'towards',
#  'fair',
#  'claimed',
#  'technically',
#  'presume',
#  'truly',
#  'commenting',
#  'noticed',
#  "i'm",
#  'exactly.',
#  'viewpoint',
#  'crazy',
#  'speaking',
#  'assume',
#  'always',
#  'limited',
#  'much',
#  'theoretically',
#  'head',
#  'gratifying',
#  'fantastic',
#  'incredible',
#  'read',
#  'get',
#  'reckoning',
#  'bitterly',
#  'even',
#  'correct',
#  'without',
#  'remarkable',
#  'knowledge',
#  'tremendous',
#  'obviously',
#  'exquisite',
#  'disappointingly',
#  'thought',
#  'assumes',
#  'especially',
#  'miraculous',
#  'rewarding',
#  'strongly',
#  'convinced',
#  'concerned',
#  'exceptional',
#  'case',
#  'argument',
#  'actual',
#  'amazing',
#  'i’m',
#  'surprising',
#  'imposing',
#  'charming',
#  'entirely',
#  'hold',
#  'quite',
#  'pure',
#  'clearly',
#  'brilliant',
#  'sat',
#  'fairly',
#  'assessment',
#  'understand',
#  'surprisingly',
#  'seem',
#  'guess',
#  'generously',
#  'see',
#  'certainly',
#  'foolishly',
#  'whole',
#  'particular',
#  'perfect',
#  'wrong',
#  'issue',
#  'extremely',
#  'judgment',
#  'argued',
#  'frankly',
#  'luckily',
#  'experience',
#  'feel',
#  'this.',
#  'frankly',
#  'saying',
#  'later',
#  'situation',
#  'unusual']
